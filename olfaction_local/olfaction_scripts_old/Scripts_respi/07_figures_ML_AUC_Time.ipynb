# %%
from brainpipe.system import study
from os.path import isfile, join, exists
from os import makedirs
import numpy as np
from itertools import product
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# #### Add the region information to the big mama csv file

# %%
conds = ['low','high']
###############################################################################
st = study('Olfacto')
pathdata = join(st.path, 'figure/Classif_TPSim_Encoding_Retrieval_Odor_1000perm/')
###############################################################################

dfname = '2_all_subjects_info_elecs_AUC_Signif_th_0.01.csv'
df = pd.read_csv(pathdata+dfname)
print(df.columns)

# Add information about the lobe of elecs
dict_regions ={ 'ACC':'Frontal','IFG':'Frontal','MFG':'Frontal','SFG':'Frontal',
                'Amg':'Olf','pPirT':'Olf','Amg-PirT':'Olf','Ins':'Olf','OFC':'Olf',
                'HC':'MTL','PHG':'MTL','FuG':'Temporal','ITG':'Temporal',
                'MTG':'Temporal','STG':'Temporal'}
df['region'] = df['labels'].map(dict_regions)

df.to_csv(pathdata+dfname.replace('.csv','_region.csv'))
# Out:
# -> Olfacto loaded
# Index(['subjects', 'elecs', 'channels', 'labels', '2_theta_AUC', '3_alpha_AUC',
#        '4_beta_AUC', '5_gamma1_AUC', '6_gamma2_AUC', '2_theta_Pow0',
#        '3_alpha_Pow0', '4_beta_Pow0', '5_gamma1_Pow0', '6_gamma2_Pow0',
#        '2_theta_Pow1', '3_alpha_Pow1', '4_beta_Pow1', '5_gamma1_Pow1',
#        '6_gamma2_Pow1', '('theta', 'min_win1')', '('alpha', 'min_win1')',
#        '('beta', 'min_win1')', '('gamma1', 'min_win1')',
#        '('gamma2', 'min_win1')'],
#       dtype='object')

# %% [markdown]
# #### Plot AUC and Time by region for each frequency

# %%
st = study('Olfacto')
pathdata = join(st.path, 'figure/Classif_TPSim_Encoding_Retrieval_Odor_1000perm/')
path2save = join(pathdata, 'AUC_Time_By_freq_region/' )
###############################################################################
if not exists(path2save):
    makedirs(path2save)
###############################################################################

freqs = ['2_theta', '3_alpha', '4_beta','5_gamma1','6_gamma2']
freqnames = [freq[2:] for freq in freqs]

dfname = '2_all_subjects_info_elecs_AUC_Signif_th_0.01_region.csv'
df = pd.read_csv(pathdata+dfname)
df.drop(['Unnamed: 0'],inplace=True, axis=1)

for f,freq in enumerate(freqs):
    #keep only significant electrodes (boolean col keep only 1 value)
    df_freq = pd.concat([df[['subjects','region']],df.filter(like=freqnames[f])], axis=1)
    df_freq = df_freq.loc[df_freq.iloc[:,-1] > 0]
    
    #group result by region
    df_gr = df_freq.groupby(['region']).agg(('count','mean','std','sem'))
    print(df_gr)
    
#     #Plot Mean Time 
#     fig = plt.figure()
#     plt.title('Mean Decoding Time by region for '+freqnames[f])
#     plt.ylabel('Mean Time (ms)')
#     xticks, w = np.arange(0,4), 0.8
#     time = df_gr.filter(like=('Time'))
#     plt.xticks(xticks,time.index.get_level_values(0).values)
#     plt.ylim(0,2000)
#     plt.bar(xticks,time.iloc[:,1]*100,yerr=time.iloc[:,3]*100, color='b')
#     plt.savefig(path2save+'Time_'+freq+'_signif_th_01.png')
#     plt.savefig(path2save+'Time_'+freq+'_signif_th_01.pdf')
#     plt.clf()
#     plt.close()
    
    #Plot Mean AUC Score
    fig = plt.figure()
    plt.title('Mean AUC Score by region for '+freqnames[f])
    plt.ylabel('Mean AUC')
    xticks, w = np.arange(0,4), 0.8
    auc = df_gr.filter(like=('AUC'))
    plt.xticks(xticks,auc.index.get_level_values(0).values)
    plt.ylim(0.5,1)
    plt.bar(xticks,auc.iloc[:,1],yerr=auc.iloc[:,3],color='darkorange')
    plt.savefig(path2save+'AUC_'+freq+'_signif_th_01.png')
    plt.savefig(path2save+'AUC_'+freq+'_signif_th_01.pdf')
    plt.clf()
    plt.close()
# Out:
# -> Olfacto loaded
#          2_theta_AUC                               2_theta_Pow0            \
#                count      mean       std       sem        count      mean
# region
# Frontal            8  0.731433  0.039674  0.014027            8  0.021955
# MTL                3  0.742593  0.049636  0.028657            3 -0.182165
# Olf                2  0.739082  0.014094  0.009966            2 -0.146740
# Temporal          10  0.718551  0.030368  0.009603           10 -0.026868
#
#                              2_theta_Pow1                                \
#                std       sem        count      mean       std       sem
# region
# Frontal   0.356209  0.125939            8 -0.119168  0.254556  0.089999
# MTL       0.047495  0.027421            3  0.321611  0.176671  0.102001
# Olf       0.338831  0.239590            2 -0.222722  0.391472  0.276812
# Temporal  0.190751  0.060321           10  0.151927  0.267621  0.084629
#
#          ('theta', 'min_win1')
#                          count mean  std  sem
# region
# Frontal                      8    1  0.0  0.0
# MTL                          3    1  0.0  0.0
# Olf                          2    1  0.0  0.0
# Temporal                    10    1  0.0  0.0
# <div id='11b044b7-2158-488b-8082-c682c0c2003a'></div>
#          3_alpha_AUC                               3_alpha_Pow0            \
#                count      mean       std       sem        count      mean
# region
# Frontal            3  0.700370  0.011684  0.006746            3  0.096101
# MTL                3  0.708456  0.012953  0.007479            3 -0.184708
# Olf                2  0.702385  0.020472  0.014476            2  0.267345
# Temporal           6  0.715976  0.025651  0.010472            6 -0.050820
#
#                              3_alpha_Pow1                                \
#                std       sem        count      mean       std       sem
# region
# Frontal   0.405946  0.234373            3 -0.058023  0.234823  0.135575
# MTL       0.088155  0.050896            3  0.205620  0.119473  0.068978
# Olf       0.086025  0.060829            2 -0.217723  0.029824  0.021088
# Temporal  0.204514  0.083493            6  0.114678  0.266709  0.108884
#
#          ('alpha', 'min_win1')
#                          count mean  std  sem
# region
# Frontal                      3    1  0.0  0.0
# MTL                          3    1  0.0  0.0
# Olf                          2    1  0.0  0.0
# Temporal                     6    1  0.0  0.0
# <div id='a013b006-759e-4793-a55c-2437b90c1ef1'></div>
#          4_beta_AUC                               4_beta_Pow0            \
#               count      mean       std       sem       count      mean
# region
# Frontal           6  0.750045  0.054769  0.022359           6 -0.022448
# MTL               7  0.710873  0.023565  0.008907           7 -0.043720
# Olf               4  0.720816  0.026431  0.013216           4  0.112092
# Temporal          2  0.771827  0.043664  0.030875           2 -0.268564
#
#                              4_beta_Pow1                                \
#                std       sem       count      mean       std       sem
# region
# Frontal   0.339207  0.138481           6 -0.038235  0.316102  0.129048
# MTL       0.136705  0.051670           7  0.239426  0.252439  0.095413
# Olf       0.283281  0.141641           4 -0.124202  0.184989  0.092495
# Temporal  0.051596  0.036484           2  0.296662  0.027920  0.019743
#
#          ('beta', 'min_win1')
#                         count mean  std  sem
# region
# Frontal                     6    1  0.0  0.0
# MTL                         7    1  0.0  0.0
# Olf                         4    1  0.0  0.0
# Temporal                    2    1  0.0  0.0
# <div id='60734560-e2ee-4535-ba0c-bcee78eec9dd'></div>
#          5_gamma1_AUC                               5_gamma1_Pow0            \
#                 count      mean       std       sem         count      mean
# region
# Frontal             3  0.763062  0.043183  0.024932             3  0.095474
# MTL                 3  0.723359  0.032477  0.018751             3  0.041404
# Olf                 3  0.719233  0.031114  0.017964             3  0.090747
# Temporal            4  0.723329  0.014077  0.007039             4 -0.094370
#
#                              5_gamma1_Pow1                                \
#                std       sem         count      mean       std       sem
# region
# Frontal   0.550746  0.317973             3  0.052383  0.274645  0.158566
# MTL       0.248725  0.143602             3  0.204953  0.271477  0.156738
# Olf       0.181325  0.104688             3 -0.066288  0.403474  0.232946
# Temporal  0.272193  0.136097             4  0.108062  0.167958  0.083979
#
#          ('gamma1', 'min_win1')
#                           count mean  std  sem
# region
# Frontal                       3    1  0.0  0.0
# MTL                           3    1  0.0  0.0
# Olf                           3    1  0.0  0.0
# Temporal                      4    1  0.0  0.0
# <div id='b723d94b-6576-4f07-acb2-6a9ad5a663fa'></div>
#          6_gamma2_AUC                               6_gamma2_Pow0            \
#                 count      mean       std       sem         count      mean
# region
# Frontal             4  0.746766  0.029402  0.014701             4  0.346903
# MTL                 3  0.746773  0.024171  0.013955             3  0.047920
# Olf                 3  0.710794  0.007270  0.004197             3 -0.164046
# Temporal            2  0.701303  0.010924  0.007725             2 -0.088648
#
#                              6_gamma2_Pow1                                \
#                std       sem         count      mean       std       sem
# region
# Frontal   0.159984  0.079992             4 -0.143125  0.141999  0.070999
# MTL       0.300891  0.173720             3 -0.076786  0.285087  0.164595
# Olf       0.101519  0.058612             3  0.217331  0.138150  0.079761
# Temporal  0.241165  0.170529             2 -0.071930  0.308717  0.218296
#
#          ('gamma2', 'min_win1')
#                           count mean  std  sem
# region
# Frontal                       4    1  0.0  0.0
# MTL                           3    1  0.0  0.0
# Olf                           3    1  0.0  0.0
# Temporal                      2    1  0.0  0.0
# <div id='a4733d5b-f393-47da-bc2f-bc9b924cf3e9'></div>

# %% [markdown]
# ### Plot AUC and Time by region for all freqs

# %%
st = study('Olfacto')
pathdata = join(st.path, 'figure/0_Classif_Power_E_EpiPerf_LowHigh_1000perm/')
path2save = join(pathdata, 'AUC_Time_By_freq_region/' )
###############################################################################
if not exists(path2save):
    makedirs(path2save)
###############################################################################

freqs = ['2_theta', '3_alpha', '4_beta','5_gamma1','6_gamma2']
rois = ['Frontal','MTL','Olf','Temporal']
freqnames = [freq[2:] for freq in freqs]

dfname = '2_all_subjects_info_elecs_AUC_Signif_th_0.01_region.csv'
df = pd.read_csv(pathdata+dfname)
df.drop(['Unnamed: 0'],inplace=True, axis=1)

result_auc = pd.DataFrame()
result_time = pd.DataFrame()
for freq in freqs:
    df2 = pd.concat([df[['subjects','region']],df.filter(like=freq[2:])], axis=1)
    df2 = df2.loc[df2.iloc[:,-1] > 0]
    df2 = df2.groupby(['region']).agg(('mean','sem'))
    auc = df2.filter(like='AUC')
    time = df2.filter(like='Time')
    result_auc = pd.concat([result_auc, auc], axis=1)
    result_time = pd.concat([result_time, time], axis=1)
print(result_auc, result_time)
dfsave = pd.concat([result_auc,result_time],ignore_index=False)
dfsave.to_csv(path2save+'AUC_Time_by_region.csv')

for i,roi in enumerate(rois):
    print(roi)
    #Plot Mean AUC Score
    fig = plt.figure()
    plt.title('Mean AUC Score for '+roi)
    plt.ylabel('Mean AUC')
    xticks, w = np.arange(0,len(freqnames)), 0.8
    plt.xticks(xticks,freqnames)
    plt.ylim(0.7,0.9)
    data = result_auc.iloc[i,np.arange(0,result_auc.shape[1],2)]
    plt.bar(xticks,data,yerr=result_auc.iloc[i,np.arange(1,result_auc.shape[1],2)],
            color='darkorange')
    #print(roi,'auc',data)
    plt.savefig(path2save+'AUC_'+roi+'_signif_th_01.png')
    plt.savefig(path2save+'AUC_'+roi+'_signif_th_01.pdf')
    plt.clf()
    plt.close()

    #Plot Mean Time Score
    fig = plt.figure()
    plt.title('Mean Time Score for '+roi)
    plt.ylabel('Mean Time (ms)')
    xticks, w = np.arange(0,len(freqnames)), 0.8
    plt.xticks(xticks,freqnames)
    plt.ylim(0,1200)
    data = (result_time.iloc[i,np.arange(0,result_time.shape[1],2)])*100
    plt.bar(xticks,data, yerr=(result_time.iloc[i,np.arange(1,result_time.shape[1],2)])*100,
            color='blue')
    #print(roi,'time',data)
    plt.savefig(path2save+'Time_'+roi+'_signif_th_01.png')
    plt.savefig(path2save+'Time_'+roi+'_signif_th_01.pdf')
    plt.clf()
    plt.close()
# Out:
# -> Olfacto loaded
#          2_theta_AUC           3_alpha_AUC           4_beta_AUC            \
#                 mean       sem        mean       sem       mean       sem
# region
# Frontal     0.893659  0.009710    0.867454  0.008156   0.894378  0.010640
# MTL         0.842500  0.008278    0.860463  0.006483   0.860526  0.010059
# Olf         0.866865  0.007507    0.860893  0.007299   0.875225  0.007479
# Temporal    0.863750  0.010707    0.855624  0.005412   0.860767  0.006310
#
#          5_gamma1_AUC           6_gamma2_AUC
#                  mean       sem         mean       sem
# region
# Frontal      0.902508  0.008711     0.916472  0.008706
# MTL          0.861061  0.008075     0.858897  0.008713
# Olf          0.877240  0.009985     0.889917  0.009774
# Temporal     0.862941  0.008962     0.879130  0.008809            2_theta_Time           3_alpha_Time           4_beta_Time            \
#                  mean       sem         mean       sem        mean       sem
# region
# Frontal      5.869565  0.986679     7.000000  1.544546    8.740741  1.121650
# MTL          6.571429  1.986348     6.222222  1.596679    9.333333  1.287076
# Olf         10.055556  0.810359     7.714286  1.091569    8.222222  1.110130
# Temporal     8.285714  1.360464     8.739130  0.902823    8.724138  0.887650
#
#          5_gamma1_Time           6_gamma2_Time
#                   mean       sem          mean       sem
# region
# Frontal       9.787234  0.858616     10.036364  0.725655
# MTL           7.909091  1.659433      9.733333  1.565907
# Olf          10.428571  1.190381      9.400000  1.386780
# Temporal     10.058824  0.948957      8.692308  0.966786
# Frontal
# MTL
# Olf
# Temporal

# %%
st = study('Olfacto')
pathdata = join(st.path, 'figure/Classif_TPSim_Encoding_Retrieval_Odor_1000perm/')
path2save = join(pathdata, 'AUC_Time_By_freq_region/' )
###############################################################################
if not exists(path2save):
    makedirs(path2save)
###############################################################################

freqs = ['2_theta', '3_alpha', '4_beta','5_gamma1','6_gamma2']
nb_elecs = [143, 77, 92, 144] #encoding
#nb_elecs = [144, 62, 75, 114] #retrieval
freqnames = [freq[2:] for freq in freqs]

dfname = '2_all_subjects_info_elecs_AUC_Signif_th_0.01_region.csv'
df = pd.read_csv(pathdata+dfname)
df.drop(['Unnamed: 0'],inplace=True, axis=1)
 
df_roi = pd.concat([df[['subjects','region']],df.filter(like=('min_win'))],axis=1)
df_roi = df_roi.groupby(['region']).agg('sum')
rois = df_roi.index.get_level_values(0).values
print(df_roi, rois)

#Plot number of signif electrodes
for i,roi in enumerate(rois):
    fig = plt.figure()
    plt.title('Signif electrodes in '+roi+' region')
    plt.ylabel('#electrodes (%)')
    xticks, w = np.arange(0,len(freqnames)), 0.8
    plt.xticks(xticks,freqnames)
    #plt.ylim(0,30) if roi == 'Frontal' else plt.ylim(0,12)
    plt.ylim(0,10)
    data = (df_roi.iloc[i,:]/nb_elecs[i])*100
    plt.bar(xticks,data,color='grey')
    plt.savefig(path2save+'Nb_elecs_'+roi+'_signif_th_01.png')
    plt.savefig(path2save+'Nb_elecs_'+roi+'_signif_th_01.pdf')
    plt.clf()
    plt.close()
# Out:
# -> Olfacto loaded
#           ('theta', 'min_win1')  ('alpha', 'min_win1')  ('beta', 'min_win1')  \
# region
# Frontal                       8                      3                     6
# MTL                           3                      3                     7
# Olf                           2                      2                     4
# Temporal                     10                      6                     2
#
#           ('gamma1', 'min_win1')  ('gamma2', 'min_win1')
# region
# Frontal                        3                       4
# MTL                            3                       3
# Olf                            3                       3
# Temporal                       4                       2   ['Frontal' 'MTL' 'Olf' 'Temporal']

# %% [markdown]
# ### Plot the number of electrodes that decode in both encoding and retrieval by freq and region

# %%
from os import listdir
from os.path import isfile, join
import numpy as np

th = '0.01'
freqs = ['2_theta', '3_alpha', '4_beta','5_gamma1','6_gamma2']
###############################################################################
path = r'/media/karim/Datas4To/1_Analyses_Intra_EM_Odor/Olfacto/figure/'
path_npz_enc = join(path, '0_Classif_Power_E_EpiPerf_LowHigh_1000perm/')
path_npz_ret = join(path, '0_Classif_Power_R_EpiPerf_LowHigh_1000perm/')
npz_form = 'All_subjects_sources_{}_odor_low_high_sel_physFT.npz'
mask_form = 'All_subjects_mask_stat_{}_minwin1_th'+th+'.npy'
path2save = join(path, 'Conjonction/')
###############################################################################

for freq in freqs:
    mat_enc = np.load(path_npz_enc+npz_form.format(freq))
    xyz0, labels0 = mat_enc['s_xyz'], mat_enc['s_MAI_RL']
    mask0 = np.load(path_npz_enc+'masks_stat/'+mask_form.format(freq))
    mat_ret = np.load(path_npz_ret+npz_form.format(freq))
    xyz1, labels1 = mat_ret['s_xyz'], mat_ret['s_MAI_RL']
    mask1 = np.load(path_npz_ret+'masks_stat/'+mask_form.format(freq))
    xyz_all = np.unique(np.concatenate((xyz0,xyz1),axis=0),axis=0)
    print(xyz0.shape,xyz1.shape,xyz_all.shape)
    
    #create an array of region labels for encoding and retrieval
    dict_regions ={ 'ACC':'Frontal','IFG':'Frontal','MFG':'Frontal','SFG':'Frontal',
                'Amg':'Olf','pPirT':'Olf','Amg-PirT':'Olf','Ins':'Olf','OFC':'Olf',
                'HC':'MTL','PHG':'MTL','FuG':'Temporal','ITG':'Temporal',
                'MTG':'Temporal','STG':'Temporal'}
    regions0 = np.vectorize(dict_regions.get)(labels0)
    regions1 = np.vectorize(dict_regions.get)(labels1)

    #loop on all elecs and create a code indicating when it decodes
    codes_elecs, region_elecs = [], []
    for i, elec in enumerate(xyz_all):
        in_1 = np.where(np.all(elec == xyz0, 1))[0] #encoding
        in_2 = np.where(np.all(elec == xyz1, 1))[0] #retrieval

        if in_1.size and in_2.size: #decode in both
            sig0,sig1 = mask0[in_1], mask1[in_2]
            if sig0 == False and sig1 == False:
                codes_elecs.append(2)
                region_elecs.append(regions0[in_1][0])
            if sig0 == False and sig1 == True:
                codes_elecs.append(0)
                region_elecs.append(regions0[in_1][0])
            if sig0 == True and sig1 == False:
                codes_elecs.append(1)
                region_elecs.append(regions1[in_2][0])
        if in_1.size and not in_2.size: #decode only in encoding
            if mask0[in_1] == False:
                codes_elecs.append(0)
                region_elecs.append(regions0[in_1][0])
        if not in_1.size and in_2.size: #decode only in retrieval
            if mask1[in_2] == False:
                codes_elecs.append(1)
                region_elecs.append(regions1[in_2][0])
    
    codes_elecs = np.asarray(codes_elecs)[np.newaxis]
    region_elecs = np.asarray(region_elecs)[np.newaxis]
    count = np.ones(shape=region_elecs.shape)
    print(freq,'regions',region_elecs.shape,codes_elecs.shape, count.shape)
    concat = np.concatenate((codes_elecs,region_elecs,count),axis=0).swapaxes(0,1)
    df = pd.DataFrame(concat,columns=['codes_elecs','region_elecs','count'])
    df_gr = df.groupby(['codes_elecs','region_elecs']).count()
    df_gr = df_gr.unstack(level=0).T
    codes = df_gr.index.get_level_values(1).values
    rois = df_gr.columns.get_level_values(0).values
    print(df_gr, codes, rois)
    
    #Plot number of signif electrodes
    fig = plt.figure()
    plt.title('Signif electrodes for '+freq)
    plt.ylabel('#electrodes')
    xticks, w = np.arange(0,len(rois)), 0.8
    plt.xticks(xticks,rois)
    plt.ylim(0,80)
    colors = ["#114693", "#DA0615", "#30169A"]
    legends = ['Encoding','Retrieval','Both']
    bottom = np.zeros(len(df_gr.columns))
    for i,code in enumerate(codes):   
        plt.bar(xticks,df_gr.iloc[i,:],color=colors[i],bottom=bottom,label=legends[i])
        bottom += df_gr.iloc[i,:]
    print('count',freq,df_gr.iloc[i,:])
    plt.legend(loc='best')
    plt.savefig(path2save+'Nb_elecs_'+freq+'_signif_th_01.png')
    plt.savefig(path2save+'Nb_elecs_'+freq+'_signif_th_01.pdf')
    plt.clf()
    plt.close()
# Out:
# (456, 3) (395, 3) (461, 3)
# 2_theta regions (1, 106) (1, 106) (1, 106)
# region_elecs       Frontal  MTL   Olf  Temporal
#       codes_elecs
# count 0               19.0  8.0  16.0      10.0
#       1               22.0  4.0   6.0      12.0
#       2                4.0  2.0   3.0       NaN ['0' '1' '2'] ['Frontal' 'MTL' 'Olf' 'Temporal']
# count 2_theta region_elecs
# Frontal     4.0
# MTL         2.0
# Olf         3.0
# Temporal    NaN
# Name: (count, 2), dtype: float64
# (456, 3) (395, 3) (461, 3)
# 3_alpha regions (1, 109) (1, 109) (1, 109)
# region_elecs       Frontal   MTL   Olf  Temporal
#       codes_elecs
# count 0               16.0  12.0  13.0      15.0
#       1               19.0   5.0   7.0      14.0
#       2                4.0   2.0   2.0       NaN ['0' '1' '2'] ['Frontal' 'MTL' 'Olf' 'Temporal']
# count 3_alpha region_elecs
# Frontal     4.0
# MTL         2.0
# Olf         2.0
# Temporal    NaN
# Name: (count, 2), dtype: float64
# (456, 3) (395, 3) (461, 3)
# 4_beta regions (1, 125) (1, 125) (1, 125)
# region_elecs       Frontal  MTL  Olf  Temporal
#       codes_elecs
# count 0                 22   15   16        19
#       1                 18    5    2        14
#       2                  5    1    5         3 ['0' '1' '2'] ['Frontal' 'MTL' 'Olf' 'Temporal']
# count 4_beta region_elecs
# Frontal     5
# MTL         1
# Olf         5
# Temporal    3
# Name: (count, 2), dtype: int64
# (456, 3) (395, 3) (461, 3)
# 5_gamma1 regions (1, 133) (1, 133) (1, 133)
# region_elecs       Frontal  MTL  Olf  Temporal
#       codes_elecs
# count 0                 37   10   21        22
#       1                 15    6   11         5
#       2                  2    1    1         2 ['0' '1' '2'] ['Frontal' 'MTL' 'Olf' 'Temporal']
# count 5_gamma1 region_elecs
# Frontal     2
# MTL         1
# Olf         1
# Temporal    2
# Name: (count, 2), dtype: int64
# (456, 3) (395, 3) (461, 3)
# 6_gamma2 regions (1, 154) (1, 154) (1, 154)
# region_elecs       Frontal   MTL   Olf  Temporal
#       codes_elecs
# count 0               45.0  16.0  20.0      24.0
#       1               18.0   5.0   6.0       9.0
#       2                7.0   NaN   2.0       2.0 ['0' '1' '2'] ['Frontal' 'MTL' 'Olf' 'Temporal']
# count 6_gamma2 region_elecs
# Frontal     7.0
# MTL         NaN
# Olf         2.0
# Temporal    2.0
# Name: (count, 2), dtype: float64

# %% [markdown]
# #### Plot Power change by region for each frequency

# %%
st = study('Olfacto')
pathdata = join(st.path, 'figure/Classif_TPSim_Encoding_Retrieval_Odor_1000perm/')
path2save = join(pathdata, 'Power_By_freq_region/' )
###############################################################################
if not exists(path2save):
    makedirs(path2save)
###############################################################################

freqs = ['2_theta', '3_alpha', '4_beta','5_gamma1','6_gamma2']
conds = ['low','high']
freqnames = [freq[2:] for freq in freqs]

dfname = '2_all_subjects_info_elecs_AUC_Signif_th_0.01_region.csv'
df = pd.read_csv(pathdata+dfname)
df.drop(['Unnamed: 0'],inplace=True, axis=1)

for f,freq in enumerate(freqs):
    #keep only significant electrodes (boolean col keep only 1 value)
    df_freq = pd.concat([df[['subjects','labels']],df.filter(like=freqnames[f])], axis=1)
    df_freq = df_freq.loc[df_freq.iloc[:,-1] > 0]
    df_freq['Pow_all_conds'] = (df_freq[freq+'_Pow0']+df_freq[freq+'_Pow1'])/2
    print(df_freq.columns)
    
    #group result by region
    df_gr = df_freq.groupby(['labels','subjects']).agg(('mean'))
    power = df_gr.filter(like=('Pow'))
    power['ratio_pow0'] = (power.iloc[:,0] - power.iloc[:,6])/power.iloc[:,7]
    power['ratio_pow1'] = (power.iloc[:,3] - power.iloc[:,6])/power.iloc[:,7]
#     print(power)
    
    #Plot Mean Z-scored power
    fig = plt.figure()
    #plt.title('Mean TPSim (SME) by region for '+freqnames[f])
    plt.title('Mean Power (SME) by region for '+freqnames[f])
    plt.ylabel('Power (μV²)')
    rois = np.unique(power.index.get_level_values(0).values)
    xticks, w = np.arange(0,len(rois)*len(conds),len(conds)), 1
    colors_w = ['cornflowerblue','blue']
    
    for i, cond in enumerate(conds):
        df_plot = power[[freq+'_Pow'+str(i)]].iloc[:,-2+i]
        df_plot = df_plot.unstack()
        print(df_plot)
        mean = df_plot.mean(axis=1)
        err = df_plot.sem(axis=1)
        print(mean.shape, err.shape,xticks.shape)
        print()
        plt.bar(xticks+i,mean,color=colors_w[i],label=cond,yerr=err)
        
    plt.legend(loc=0,handletextpad=0.1, frameon=False)
    plt.xticks(xticks+0.5,rois)
    plt.ylim(-0.5,0.5)
    plt.savefig(path2save+'Power_'+freq+'_by_patient_signif_th_01.png')
    plt.savefig(path2save+'Power_'+freq+'_by_patient_signif_th_01.pdf')
    plt.clf()
    plt.close()
# Out:
# -> Olfacto loaded
# Index(['subjects', 'labels', '2_theta_AUC', '2_theta_Pow0', '2_theta_Pow1',
#        '('theta', 'min_win1')', 'Pow_all_conds'],
#       dtype='object')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-84ed6754ca5e> in <module>()
#      25     df_gr = df_freq.groupby(['labels','subjects']).agg(('mean'))
#      26     power = df_gr.filter(like=('Pow'))
# ---> 27     power['ratio_pow0'] = (power.iloc[:,0] - power.iloc[:,6])/power.iloc[:,7]
#      28     power['ratio_pow1'] = (power.iloc[:,3] - power.iloc[:,6])/power.iloc[:,7]
#      29 #     print(power)
#
# ~/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# ~/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1660     def _getitem_tuple(self, tup):
#    1661
# -> 1662         self._has_valid_tuple(tup)
#    1663         try:
#    1664             return self._getitem_lowerdim(tup)
#
# ~/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     187             if i >= self.obj.ndim:
#     188                 raise IndexingError('Too many indexers')
# --> 189             if not self._has_valid_type(k, i):
#     190                 raise ValueError("Location based indexing can only have [%s] "
#     191                                  "types" % self._valid_types)
#
# ~/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1595             return True
#    1596         elif is_integer(key):
# -> 1597             return self._is_valid_integer(key, axis)
#    1598         elif is_list_like_indexer(key):
#    1599             return self._is_valid_list_like(key, axis)
#
# ~/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _is_valid_integer(self, key, axis)
#    1636         l = len(ax)
#    1637         if key >= l or key < -l:
# -> 1638             raise IndexError("single positional indexer is out-of-bounds")
#    1639         return True
#    1640
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ### % of electrode decreases & increases across frequencies

# %%
st = study('Olfacto')
pathdata = join(st.path, 'figure/Classif_TPSim_Encoding_Retrieval_Odor_1000perm/')
path2save = join(pathdata, 'Power_By_freq_region/' )
###############################################################################
if not exists(path2save):
    makedirs(path2save)
###############################################################################
freqs = ['2_theta', '3_alpha', '4_beta','5_gamma1','6_gamma2']
conds = ['low','high']
freqnames = [freq[2:] for freq in freqs]
###############################################################################
groups_roi = 'region'#'region'

dfname = '2_all_subjects_info_elecs_AUC_Signif_th_0.01_region.csv'
df = pd.read_csv(pathdata+dfname)
#df.drop(['Unnamed: 0','aal', 'aal_RL', 'BA',
#       '2_theta_AUC', '3_alpha_AUC', '4_beta_AUC', '5_gamma1_AUC',
#       '6_gamma2_AUC','2_theta_Time', '3_alpha_Time', '4_beta_Time', '5_gamma1_Time',
#       '6_gamma2_Time'],inplace=True, axis=1)
df.drop(['Unnamed: 0','2_theta_AUC', '3_alpha_AUC', '4_beta_AUC', '5_gamma1_AUC',
       '6_gamma2_AUC'],inplace=True, axis=1)
regions = np.unique(df[[groups_roi]]) #'region'

for roi in regions:
    elecs_inc, elecs_dec, elecs_ratio = [],[],[]
    for f,freq in enumerate(freqs):
        #keep only significant electrodes (boolean col keep only 1 value)
        df_freq = pd.concat([df[['subjects','channels',groups_roi]],df.filter(like=freqnames[f])], axis=1)
        df_freq = df_freq.loc[df_freq.iloc[:,-1] > 0]
        df_freq = df_freq.loc[df_freq.region == roi]
        df_freq['modulation'] = np.sign(df_freq[freq+'_Pow1'] - df_freq[freq+'_Pow0'])
        #create a value of 1 for increase, -1 for decrease and 0 for no change
        
        #compute signif elecs, increasing and decreasing elecs
        df_mod = df_freq[['channels',groups_roi,'modulation']].groupby([groups_roi,'modulation']).count()
        print(df_mod)
        mod = df_mod.values[:]
        index0 = df_mod.index.get_level_values(1)[0]
        print(mod,len(mod),index0)
        
        tot = [mod[0][0]+mod[1][0] if len(mod)==2 else mod[0][0]]
        inc = [(mod[1][0]/tot)*100 if len(mod)==2 else 0]
        inc = [(mod[0][0]/tot)*100 if len(mod)==1 and index0==1 else inc ]
        dec = [(mod[0][0]/tot)*100 if len(mod)==2 else 0]
        dec = [(mod[0][0]/tot)*100 if len(mod)==1 and index0==-1 else dec]
        print('inc',inc,'dec',dec)
        elecs_ratio.append(tot[0]), elecs_inc.append(inc[0][0]), elecs_dec.append(dec[0][0])
    print(roi, elecs_ratio, elecs_inc, elecs_dec)
    print('shapes inc dec', len(elecs_inc), len(elecs_dec))
    
    #Plot Mean Z-scored power
    fig = plt.figure()
    plt.title('Mean Power (SME) by freq for '+roi)
    plt.ylabel('% of signif elecs')
    xticks = np.arange(0,len(freqnames))
    
    plt.plot(xticks, elecs_inc, 'r-')
    plt.plot(xticks, elecs_dec, 'b-')
    plt.xticks(xticks,freqnames)
    plt.ylim(0,100)
    plt.savefig(path2save+'Percent_'+roi+'_signif_th_01.png')
    plt.savefig(path2save+'Percent_'+roi+'_signif_th_01.pdf')
    plt.clf()
    plt.close()
# Out:
# -> Olfacto loaded
#                     channels
# region  modulation
# Frontal -1.0               5
#          1.0               3
# [[5]
#  [3]] 2 -1.0
# inc [[array([ 37.5])]] dec [[array([ 62.5])]]
#                     channels
# region  modulation
# Frontal -1.0               2
#          1.0               1
# [[2]
#  [1]] 2 -1.0
# inc [[array([ 33.33333333])]] dec [[array([ 66.66666667])]]
#                     channels
# region  modulation
# Frontal -1.0               3
#          1.0               3
# [[3]
#  [3]] 2 -1.0
# inc [[array([ 50.])]] dec [[array([ 50.])]]
#                     channels
# region  modulation
# Frontal -1.0               2
#          1.0               1
# [[2]
#  [1]] 2 -1.0
# inc [[array([ 33.33333333])]] dec [[array([ 66.66666667])]]
#                     channels
# region  modulation
# Frontal -1.0               4
# [[4]] 1 -1.0
# inc [[0]] dec [array([ 100.])]
# Frontal [8, 3, 6, 3, 4] [array([ 37.5]), array([ 33.33333333]), array([ 50.]), array([ 33.33333333]), 0] [array([ 62.5]), array([ 66.66666667]), array([ 50.]), array([ 66.66666667]), 100.0]
# shapes inc dec 5 5
#                    channels
# region modulation
# MTL    1.0                3
# [[3]] 1 1.0
# inc [array([ 100.])] dec [[0]]
#                    channels
# region modulation
# MTL    1.0                3
# [[3]] 1 1.0
# inc [array([ 100.])] dec [[0]]
#                    channels
# region modulation
# MTL    -1.0               1
#         1.0               6
# [[1]
#  [6]] 2 -1.0
# inc [[array([ 85.71428571])]] dec [[array([ 14.28571429])]]
#                    channels
# region modulation
# MTL    -1.0               1
#         1.0               2
# [[1]
#  [2]] 2 -1.0
# inc [[array([ 66.66666667])]] dec [[array([ 33.33333333])]]
#                    channels
# region modulation
# MTL    -1.0               2
#         1.0               1
# [[2]
#  [1]] 2 -1.0
# inc [[array([ 33.33333333])]] dec [[array([ 66.66666667])]]
# MTL [3, 3, 7, 3, 3] [100.0, 100.0, array([ 85.71428571]), array([ 66.66666667]), array([ 33.33333333])] [0, 0, array([ 14.28571429]), array([ 33.33333333]), array([ 66.66666667])]
# shapes inc dec 5 5
#                    channels
# region modulation
# Olf    -1.0               1
#         1.0               1
# [[1]
#  [1]] 2 -1.0
# inc [[array([ 50.])]] dec [[array([ 50.])]]
#                    channels
# region modulation
# Olf    -1.0               2
# [[2]] 1 -1.0
# inc [[0]] dec [array([ 100.])]
#                    channels
# region modulation
# Olf    -1.0               3
#         1.0               1
# [[3]
#  [1]] 2 -1.0
# inc [[array([ 25.])]] dec [[array([ 75.])]]
#                    channels
# region modulation
# Olf    -1.0               2
#         1.0               1
# [[2]
#  [1]] 2 -1.0
# inc [[array([ 33.33333333])]] dec [[array([ 66.66666667])]]
#                    channels
# region modulation
# Olf    1.0                3
# [[3]] 1 1.0
# inc [array([ 100.])] dec [[0]]
# Olf [2, 2, 4, 3, 3] [array([ 50.]), 0, array([ 25.]), array([ 33.33333333]), 100.0] [array([ 50.]), 100.0, array([ 75.]), array([ 66.66666667]), 0]
# shapes inc dec 5 5
#                      channels
# region   modulation
# Temporal -1.0               3
#           1.0               7
# [[3]
#  [7]] 2 -1.0
# inc [[array([ 70.])]] dec [[array([ 30.])]]
#                      channels
# region   modulation
# Temporal -1.0               2
#           1.0               4
# [[2]
#  [4]] 2 -1.0
# inc [[array([ 66.66666667])]] dec [[array([ 33.33333333])]]
#                      channels
# region   modulation
# Temporal 1.0                2
# [[2]] 1 1.0
# inc [array([ 100.])] dec [[0]]
#                      channels
# region   modulation
# Temporal -1.0               1
#           1.0               3
# [[1]
#  [3]] 2 -1.0
# inc [[array([ 75.])]] dec [[array([ 25.])]]
#                      channels
# region   modulation
# Temporal -1.0               1
#           1.0               1
# [[1]
#  [1]] 2 -1.0
# inc [[array([ 50.])]] dec [[array([ 50.])]]
# Temporal [10, 6, 2, 4, 2] [array([ 70.]), array([ 66.66666667]), 100.0, array([ 75.]), array([ 50.])] [array([ 30.]), array([ 33.33333333]), 0, array([ 25.]), array([ 50.])]
# shapes inc dec 5 5

# %%
Rich = np.array([-2, 2, 3, -4, -3, 1])
Poor = np.array([3, 1, 4, -5, -2, -1])

sign = np.sign(Rich-Poor)
print(sign)
# Out:
# [-1  1 -1  1 -1  1]

# %%
print(elecs_inc[:])
print(elecs_inc[0][0])
# Out:
# [[array([ 37.5])], [array([ 33.33333333])], [array([ 50.])], [array([ 33.33333333])], [[0]]]
# [ 37.5]

# %%
st = study('Olfacto')
pathdata = join(st.path, 'figure/0_Classif_Power_R_EpiPerf_LowHigh_1000perm/')
path2save = join(pathdata, 'Power_By_freq_region/' )
###############################################################################
if not exists(path2save):
    makedirs(path2save)
###############################################################################
freqs = ['2_theta','3_alpha','4_beta','5_gamma1','6_gamma2']
conds = ['low','high']
freqnames = [freq[2:] for freq in freqs]
###############################################################################
groups_roi = 'region'#'region'

dfname = '2_all_subjects_info_elecs_AUC_Signif_th_0.01_region.csv'
df = pd.read_csv(pathdata+dfname)
df.drop(['Unnamed: 0','aal', 'aal_RL', 'BA',
       '2_theta_AUC', '3_alpha_AUC', '4_beta_AUC', '5_gamma1_AUC',
       '6_gamma2_AUC','2_theta_Time', '3_alpha_Time', '4_beta_Time', '5_gamma1_Time',
       '6_gamma2_Time'],inplace=True, axis=1)

regions = np.unique(df[[groups_roi]]) #'region'

for roi in regions:
    for f,freq in enumerate(freqs):
    #keep only significant electrodes (boolean col keep only 1 value)
        df_freq = pd.concat([df[['subjects','channels','region','s_Mai_RL']],df.filter(like=freqnames[f])], axis=1)
        df_freq = df_freq.loc[df_freq.iloc[:,-1] > 0]
        df_freq = df_freq.loc[df_freq.region == roi]
        df_freq['modulation'] = np.sign(df_freq[freq+'_Pow1'] - df_freq[freq+'_Pow0'])
        df2 = df_freq[['modulation','s_Mai_RL','channels']].groupby(['modulation','s_Mai_RL']).count()
        print(roi,freq,df2)
# Out:
# -> Olfacto loaded
# Frontal 2_theta                      channels
# modulation s_Mai_RL
# -1.0       ACC              2
#            IFG              1
#            MFG              2
#            SFG              4
#  1.0       IFG              6
#            MFG              2
#            SFG              9
# Frontal 3_alpha                      channels
# modulation s_Mai_RL
# -1.0       ACC              2
#            IFG              2
#            MFG              1
#            SFG              5
#  1.0       ACC              1
#            IFG              4
#            MFG              4
#            SFG              4
# Frontal 4_beta                      channels
# modulation s_Mai_RL
# -1.0       IFG              1
#            MFG              2
#            SFG              2
#  1.0       ACC              2
#            IFG              2
#            MFG              5
#            SFG              9
# Frontal 5_gamma1                      channels
# modulation s_Mai_RL
# -1.0       ACC              2
#            IFG              5
#            MFG              5
#            SFG              2
#  1.0       MFG              1
#            SFG              2
# Frontal 6_gamma2                      channels
# modulation s_Mai_RL
# -1.0       ACC              2
#            IFG              3
#            MFG              6
#            SFG              5
#  1.0       IFG              3
#            SFG              6
# MTL 2_theta                      channels
# modulation s_Mai_RL
# -1.0       HC               3
#            PHG              1
#  1.0       HC               1
#            PHG              1
# MTL 3_alpha                      channels
# modulation s_Mai_RL
# -1.0       HC               1
#            PHG              1
#  1.0       HC               2
#            PHG              3
# MTL 4_beta                      channels
# modulation s_Mai_RL
# -1.0       HC               1
#  1.0       HC               3
#            PHG              2
# MTL 5_gamma1                      channels
# modulation s_Mai_RL
# -1.0       HC               4
#  1.0       HC               3
# MTL 6_gamma2                      channels
# modulation s_Mai_RL
# -1.0       HC               1
#            PHG              2
#  1.0       HC               2
# Olf 2_theta                      channels
# modulation s_Mai_RL
# -1.0       Ins              2
#  1.0       Ins              2
#            OFC              4
#            pPirT            1
# Olf 3_alpha                      channels
# modulation s_Mai_RL
# -1.0       Ins              1
#            OFC              1
#  1.0       Amg              2
#            Amg-PirT         1
#            Ins              3
#            OFC              1
# Olf 4_beta                      channels
# modulation s_Mai_RL
# -1.0       OFC              2
#  1.0       Ins              4
#            OFC              1
# Olf 5_gamma1                      channels
# modulation s_Mai_RL
# -1.0       Ins              2
#            OFC              7
#  1.0       Ins              2
#            OFC              1
# Olf 6_gamma2                      channels
# modulation s_Mai_RL
# -1.0       Ins              1
#            OFC              3
#  1.0       Amg              1
#            Ins              2
#            OFC              1
# Temporal 2_theta                      channels
# modulation s_Mai_RL
# -1.0       FuG              1
#            ITG              1
#            MTG              2
#  1.0       FuG              1
#            ITG              2
#            MTG              4
#            STG              1
# Temporal 3_alpha                      channels
# modulation s_Mai_RL
# -1.0       FuG              4
#            ITG              3
#            MTG              5
#  1.0       MTG              2
# Temporal 4_beta                      channels
# modulation s_Mai_RL
# -1.0       FuG              1
#            ITG              6
#            MTG              2
#  1.0       FuG              1
#            ITG              3
#            STG              4
# Temporal 5_gamma1                      channels
# modulation s_Mai_RL
# -1.0       ITG              1
#            MTG              2
#            STG              2
#  1.0       ITG              1
#            MTG              1
# Temporal 6_gamma2                      channels
# modulation s_Mai_RL
# -1.0       FuG              1
#            ITG              1
#            STG              3
#  1.0       FuG              1
#            ITG              1
#            MTG              4
