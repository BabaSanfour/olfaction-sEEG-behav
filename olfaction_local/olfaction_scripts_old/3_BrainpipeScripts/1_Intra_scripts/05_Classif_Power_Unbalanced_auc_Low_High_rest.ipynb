# %% [markdown]
# ## Import Libraries

# %%
from os import path
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MaxNLocator
import scipy.io as sio

from brainpipe.classification import *
from brainpipe.system import study
from brainpipe.feature import power, amplitude, sigfilt
from brainpipe.visual import *
from brainpipe.statistics import *
from scipy.stats import *

# %% [markdown]
# ## Power Decoding - Partial//Detailed Encoding
# ### For ALL time points

# %%
PATH ='/media/karim/Datas4To/1_Analyses_Intra_EM_Odor/Olfacto/database/Retrieval_Rest_LowHigh/'
mat = np.load(PATH+'VACJ_odor_high_bipo_sel_physFT.npz')['x']
print(mat.shape)
# Out:
# (74, 1536, 12)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import StratifiedKFold as SKFold
from sklearn.metrics import roc_auc_score
from numpy.random import permutation

conds,phases, subjects = ['low','high'],['odor'],['SEMC','VACJ','FERJ','LEFC','PIRJ','CHAF']#,'MICP','VACJ','SEMC','LEFC','PIRJ']
color_codes = ['darkorange','blue']
st = study('Olfacto')
freqs = 7
nperm = 1000

for su,phase in product(subjects,phases):
    path_pow = path.join(st.path, 'feature/TPSim_Enc_Ret_By_Odor/TPS_R_p_by_cond/')
    save_path = path.join(st.path, 'classified/Classif_TPSim_Encoding_Retrieval_Odor_1000perm/')

    pow_list = []
    #=========================== Load Power files (nfreq, nelec, nwin, ntrial) =================================    
    mat0 = np.load(path.join(path_pow, su+'_'+phase+'_'+conds[0]+'_bipo_sel_physFT_pow'+bsl+'.npz'))
    names, channels, freq_names, time = mat0['Mai_RL'], mat0['channels'],mat0['fname'], mat0['time']
    #print(mat0['xpow'].shape,time.shape,time[17:42])
    pow_list.append(mat0['xpow'][:,:,18,:][:,:,np.newaxis,:])
    nelecs = mat0['xpow'].shape[1]
    mat1 = np.load(path.join(path_pow, su+'_'+phase+'_'+conds[1]+'_bipo_sel_physFT_pow'+bsl+'.npz'))
    pow_list.append(mat1['xpow'][:,:,18,:][:,:,np.newaxis,:])
    print (su, 'power shape: ', [pow.shape for pow in pow_list])
    # =========================== Select Power for 1 elec 1 freq =================================                 
    iterator = range(nelecs)
    for elec_num in iterator:
        for freq in range(2,freqs):
            elec, elec_label, freq_name = channels[elec_num], names[elec_num], freq_names[freq]
            print ('elec ', elec, 'elec_label ', elec_label)
            #Filenames to save
            name_auc = (save_path+str(freq)+'_'+freq_name+'/auc/'+su +'_auc_'+conds[0]+'_'+conds[1]+'_'+str(elec_label)+'_('+str(elec_num)+').npy')
            name_perm = (save_path+str(freq)+'_'+freq_name+'/auc/'+su +'_perm_'+str(elec_label)+'_('+str(elec_num)+').npy')
                        
            if path.exists(name_auc):
                print(su,bsl,phase,elec_num,freq,'already computed')
            else:
                print('--» processing',su, 'elec', elec_num,'/',nelecs, 'freq',freq)
                pow_data_elec = []
                for i,power in enumerate(pow_list):
                    pow_data_elec.append(power[freq,elec_num].swapaxes(0,1))
                nwin = power.shape[1]

        # =============================  Classification Computation ============================================================           
                # create a data matrix, concatenate along the trial dimension
                x = np.concatenate(pow_data_elec, axis=0)
                print ('Size of the concatenated data: ', x.shape, 'Number time windows : ', x.shape[1])
                y = np.hstack([np.array([i]*len(power)) for i, power in enumerate(pow_data_elec)])
                print ('Size of label for classif: ', len(y))

                auc = np.array([])
                for t in range(x.shape[1]):
                    X = x[:,t]
                    X = X.reshape(-1, 1)
                    score_rep = []
                    for i in range(10):
                        k = 5
                        skf = SKFold(n_splits=k, random_state=None, shuffle=True)
                        skf.get_n_splits(X, y)
                        score_cv = []
                        for train_index, test_index in skf.split(X, y):
                            clf = LDA()
                            X_train, X_test = X[train_index], X[test_index]
                            y_train, y_test = y[train_index], y[test_index]
                            clf.fit(X=X_train, y=y_train)
                            y_pred = clf.predict(X_test)
                            score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                        score_rep.append(np.mean(score_cv))
                    score_rep = np.asarray(score_rep).reshape(1,len(score_rep))
                    auc = np.vstack((auc, score_rep)) if np.size(auc) else score_rep
                auc = np.swapaxes(auc,0,1)

                perm_scores = np.array([])
                for t in range(x.shape[1]):
                    X = x[:,t]
                    X = X.reshape(-1, 1)
                    perm_rep = []
                    for perm in range(nperm):
                        y_perm = y[permutation(len(y))]
                        score_cv = []
                        for train_index, test_index in skf.split(X, y_perm):
                            clf = LDA()
                            X_train, X_test = X[train_index], X[test_index]
                            y_train, y_test = y_perm[train_index], y_perm[test_index]
                            clf.fit(X=X_train, y=y_train)
                            y_pred = clf.predict(X_test)
                            score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                        perm_rep.append(np.mean(score_cv))
                    perm_rep = np.asarray(perm_rep).reshape(1,len(perm_rep))
                    perm_scores = np.vstack((perm_scores, perm_rep)) if np.size(perm_scores) else perm_rep
                perm_scores = np.swapaxes(perm_scores,0,1)           
                th_0_05_perm = perm_pvalue2level(perm_scores, p=0.01, maxst=True)
                th_0_01_perm = perm_pvalue2level(perm_scores, p=0.001, maxst=True)
                print('th_perm 005: ', th_0_05_perm[0], '001',th_0_01_perm[0], 'auc_max', np.max(auc))

        # ============================== PLOT POWER ANALYSIS + STATS & DECODING ACCURACY ===================================================
#                 # plot and figure parameters
#                 xfmt = ScalarFormatter(useMathText=True)
#                 xfmt.set_powerlimits((0,3))
#                 fig = plt.figure(1,figsize=(7,7))
#                 title = 'Power-Stats-DA for '+su+' '+conds[0]+' vs '+conds[1]+' '+str(elec)+' '+str(elec_label)+' ('+str(elec_num)+')'
#                 fig.suptitle(title, fontsize=12)

#                 # Plot the POW + STATS
#                 plt.subplot(211)        
#                 BorderPlot(time, x, y=y, kind='sem', alpha=0.2, color=color_codes,linewidth=2, 
#                            ncol=1, xlabel='Time (s)',ylabel = r'Power', legend=conds)
#                 rmaxis(plt.gca(), ['right', 'top'])
#                 addLines(plt.gca(), vLines=[0], vColor=['darkgray'], vWidth=[2])
#                 plt.legend(loc=0, handletextpad=0.1, frameon=False)
#                 plt.gca().yaxis.set_major_locator(MaxNLocator(3,integer=True))

#                 # Plot DA for the POW
#                 plt.subplot(212)
#                 BorderPlot(time, auc, color='b', kind='sd',xlabel='Time (s)', ylim=[0.4,1.], ylabel='Decoding accuracy (%)',linewidth=2, alpha=0.3)
#                 rmaxis(plt.gca(), ['right', 'top'])
#                 addLines(plt.gca(), vLines=[0], vColor=['darkgray'], vWidth=[2])
#                 plt.gca().yaxis.set_major_locator(MaxNLocator(3,integer=True))
#                 plt.plot(time, th_0_05_perm*np.ones(len(time)), '--', color='r', linewidth=2)
#                 #plt.plot(times_plot, th_0_01_perm*np.ones(len(times_plot)), '--', color='orange', linewidth=2)

                #Save plots
                np.save(name_auc, auc)
                np.save(name_perm, perm_scores)
#                 plt.savefig(plot_name, dpi=300, bbox_inches='tight')
#                 plt.clf()
#                 plt.close() 
                del X, auc, pow_data_elec
    del pow_list

# %% [markdown]
# #### ML for the TPSim - ST analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import StratifiedKFold as SKFold
from sklearn.metrics import roc_auc_score
from numpy.random import permutation

conds,phases, subjects = ['low','high'],['odor'],['SEMC','VACJ','FERJ','LEFC','PIRJ','CHAF']#,'MICP','VACJ','SEMC','LEFC','PIRJ']
freq_names = ['2_theta','3_alpha','4_beta','5_gamma1','6_gamma2']
color_codes = ['darkorange','blue']
st = study('Olfacto')
nperm = 1000

for su,phase in product(subjects,phases):
    path_pow = path.join(st.path, 'feature/TPSim_Enc_Ret_By_Odor/TPS_R_p_by_cond/')
    save_path = path.join(st.path, 'classified/Classif_TPSim_Encoding_Retrieval_Odor_1000perm/')

    pow_list = []
    #=========================== Load Power files (nfreq, nelec, nwin, ntrial) =================================    
    mat0 = np.load(path.join(path_pow, 'TPS_spear_'+su+'_'+phase+'_'+conds[0]+'.npz'))
    names, channels = mat0['label'], mat0['channel']
    #print(mat0['xpow'].shape,time.shape,time[17:42])
    pow_list.append(mat0['TPS']) #nfreq, nelecs, ntrials
    nelecs = mat0['TPS'].shape[1]
    mat1 = np.load(path.join(path_pow, 'TPS_spear_'+su+'_'+phase+'_'+conds[1]+'.npz'))
    pow_list.append(mat1['TPS'])
    print (su, 'power shape: ', [pow.shape for pow in pow_list])
    
    # =========================== Select Power for 1 elec 1 freq =================================                 
    iterator = range(nelecs)
    for elec_num in iterator:
        for freq in range(len(freq_names)):
            elec, elec_label, freq_name = channels[elec_num], names[elec_num], freq_names[freq]
            print ('elec ', elec, 'elec_label ', elec_label)
            #Filenames to save
            name_auc = (save_path+freq_name+'/'+su +'_auc_'+conds[0]+'_'+conds[1]+'_'+str(elec_label)+'_('+str(elec_num)+').npy')
            name_perm = (save_path+freq_name+'/'+su +'_perm_'+str(elec_label)+'_('+str(elec_num)+').npy')
                        
            if not path.exists(name_auc):
                #print(su,phase,elec_num,freq,'already computed')
            #else:
                print('--» processing',su, 'elec', elec_num,'/',nelecs, 'freq',freq)
                pow_data_elec = []
                for i,power in enumerate(pow_list):
                    pow_data_elec.append(power[freq,elec_num][np.newaxis].swapaxes(0,1))
                print('mean TPSim for low & high', [np.mean(power) for power in pow_data_elec])
                nwin = power.shape[1]

        # =============================  Classification Computation ============================================================           
                # create a data matrix, concatenate along the trial dimension
                x = np.concatenate(pow_data_elec, axis=0)
                print ('Size of the concatenated data: ', x.shape, 'Number time windows : ', x.shape[1])
                y = np.hstack([np.array([i]*len(power)) for i, power in enumerate(pow_data_elec)])
                print ('Size of label for classif: ', len(y))

                auc = np.array([])
                for t in range(x.shape[1]):
                    X = x[:,t]
                    X = X.reshape(-1, 1)
                    score_rep = []
                    for i in range(10):
                        k = 5
                        skf = SKFold(n_splits=k, random_state=None, shuffle=True)
                        skf.get_n_splits(X, y)
                        score_cv = []
                        for train_index, test_index in skf.split(X, y):
                            clf = LDA()
                            X_train, X_test = X[train_index], X[test_index]
                            y_train, y_test = y[train_index], y[test_index]
                            clf.fit(X=X_train, y=y_train)
                            y_pred = clf.predict(X_test)
                            score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                        score_rep.append(np.mean(score_cv))
                    score_rep = np.asarray(score_rep).reshape(1,len(score_rep))
                    auc = np.vstack((auc, score_rep)) if np.size(auc) else score_rep
                auc = np.swapaxes(auc,0,1)
                
                perm_scores = np.array([])
                for t in range(x.shape[1]):
                    X = x[:,t]
                    X = X.reshape(-1, 1)
                    perm_rep = []
                    for perm in range(nperm):
                        y_perm = y[permutation(len(y))]
                        score_cv = []
                        for train_index, test_index in skf.split(X, y_perm):
                            clf = LDA()
                            X_train, X_test = X[train_index], X[test_index]
                            y_train, y_test = y_perm[train_index], y_perm[test_index]
                            clf.fit(X=X_train, y=y_train)
                            y_pred = clf.predict(X_test)
                            score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                        perm_rep.append(np.mean(score_cv))
                    perm_rep = np.asarray(perm_rep).reshape(1,len(perm_rep))
                    perm_scores = np.vstack((perm_scores, perm_rep)) if np.size(perm_scores) else perm_rep
                perm_scores = np.swapaxes(perm_scores,0,1)           
                th_0_05_perm = perm_pvalue2level(perm_scores, p=0.05, maxst=True)
                th_0_01_perm = perm_pvalue2level(perm_scores, p=0.01, maxst=True)
                th_0_001_perm = perm_pvalue2level(perm_scores, p=0.001, maxst=True)
                print('th_perm 05: ', th_0_05_perm[0], '01',th_0_01_perm[0],
                      '001',th_0_001_perm[0], 'auc_mean', np.mean(auc))
                np.save(name_auc, auc)
                np.save(name_perm, perm_scores)
                del X, auc, pow_data_elec
    del pow_list
# Out:
# -> Olfacto loaded
# SEMC power shape:  [(5, 65, 93), (5, 65, 27)]
# elec  b12-b11 elec_label  MTG
# --» processing SEMC elec 0 / 65 freq 0
# mean TPSim for low & high [0.01409976554288948, 0.10994152046783627]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514444444444 auc_mean 0.5
# elec  b12-b11 elec_label  MTG
# --» processing SEMC elec 0 / 65 freq 1
# mean TPSim for low & high [-0.016848573045517016, 0.080980228348649361]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  b12-b11 elec_label  MTG
# --» processing SEMC elec 0 / 65 freq 2
# mean TPSim for low & high [0.11378446115288218, 0.16819827346143135]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.516666666667 auc_mean 0.5
# elec  b12-b11 elec_label  MTG
# --» processing SEMC elec 0 / 65 freq 3
# mean TPSim for low & high [0.044191122968712089, 0.086494012809802276]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.534444444444 auc_mean 0.5
# elec  b12-b11 elec_label  MTG
# --» processing SEMC elec 0 / 65 freq 4
# mean TPSim for low & high [0.17207534966448379, 0.28098022834864933]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.545555555556 auc_mean 0.5
# elec  b2-b1 elec_label  HC
# --» processing SEMC elec 1 / 65 freq 0
# mean TPSim for low & high [-0.0078098471986417593, -0.10665552770815927]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  b2-b1 elec_label  HC
# --» processing SEMC elec 1 / 65 freq 1
# mean TPSim for low & high [-0.052631578947368418, 0.20339738234475074]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.516666666667 auc_mean 0.498391812865
# elec  b2-b1 elec_label  HC
# --» processing SEMC elec 1 / 65 freq 2
# mean TPSim for low & high [-0.075317325571994498, -0.015984405458089681]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.506140350877 001 0.556666666667 auc_mean 0.5
# elec  b2-b1 elec_label  HC
# --» processing SEMC elec 1 / 65 freq 3
# mean TPSim for low & high [0.090904681057482409, -0.10453912559175717]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.516666666667 auc_mean 0.5
# elec  b2-b1 elec_label  HC
# --» processing SEMC elec 1 / 65 freq 4
# mean TPSim for low & high [0.12731829573934839, 0.35265942634363684]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.508888888889 001 0.54 auc_mean 0.5
# elec  b3-b2 elec_label  HC
# --» processing SEMC elec 2 / 65 freq 0
# mean TPSim for low & high [0.10375939849624061, -0.00077972709551659216]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52918128655 auc_mean 0.5
# elec  b3-b2 elec_label  HC
# --» processing SEMC elec 2 / 65 freq 1
# mean TPSim for low & high [0.089788988600533609, 0.1343915343915344]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.552280701754 auc_mean 0.5
# elec  b3-b2 elec_label  HC
# --» processing SEMC elec 2 / 65 freq 2
# mean TPSim for low & high [0.019613550004042361, -0.36992481203007516]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.49281871345
# elec  b3-b2 elec_label  HC
# --» processing SEMC elec 2 / 65 freq 3
# mean TPSim for low & high [0.032338911795618056, -0.095071010860484528]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514444444444 auc_mean 0.5
# elec  b3-b2 elec_label  HC
# --» processing SEMC elec 2 / 65 freq 4
# mean TPSim for low & high [-0.043301802894332608, -0.040879977722082995]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  b4-b3 elec_label  HC
# --» processing SEMC elec 3 / 65 freq 0
# mean TPSim for low & high [0.17019969278033792, -0.055806182121971581]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  b4-b3 elec_label  HC
# --» processing SEMC elec 3 / 65 freq 1
# mean TPSim for low & high [0.0097825208181744703, 0.19654692286271233]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.498888888889
# elec  b4-b3 elec_label  HC
# --» processing SEMC elec 3 / 65 freq 2
# mean TPSim for low & high [0.083709273182957386, -0.26009468114731266]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.554736842105 auc_mean 0.500994152047
# elec  b4-b3 elec_label  HC
# --» processing SEMC elec 3 / 65 freq 3
# mean TPSim for low & high [-0.0052389037108901181, -0.14564188248398771]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.54 auc_mean 0.5
# elec  b4-b3 elec_label  HC
# --» processing SEMC elec 3 / 65 freq 4
# mean TPSim for low & high [0.14447408844692375, -0.18707880813143965]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.503777777778
# elec  b5-b4 elec_label  HC
# --» processing SEMC elec 4 / 65 freq 0
# mean TPSim for low & high [-0.054555744199207702, 0.058535226956279565]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.5 auc_mean 0.5
# elec  b5-b4 elec_label  HC
# --» processing SEMC elec 4 / 65 freq 1
# mean TPSim for low & high [0.072503840245775733, 0.10041771094402671]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.55783625731 auc_mean 0.5
# elec  b5-b4 elec_label  HC
# --» processing SEMC elec 4 / 65 freq 2
# mean TPSim for low & high [-0.13551620987953752, 0.15410749094959619]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.50234502924
# elec  b5-b4 elec_label  HC
# --» processing SEMC elec 4 / 65 freq 3
# mean TPSim for low & high [0.05104697226938313, 0.076301865775549996]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.516666666667 auc_mean 0.5
# elec  b5-b4 elec_label  HC
# --» processing SEMC elec 4 / 65 freq 4
# mean TPSim for low & high [0.059810817365995611, -0.067112225006961859]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.557251461988 auc_mean 0.5
# elec  b6-b5 elec_label  PHG
# --» processing SEMC elec 5 / 65 freq 0
# mean TPSim for low & high [-0.12424609911876462, -0.21002506265664159]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52918128655 auc_mean 0.5
# elec  b6-b5 elec_label  PHG
# --» processing SEMC elec 5 / 65 freq 1
# mean TPSim for low & high [0.076837254426388529, 0.35210247841826786]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  b6-b5 elec_label  PHG
# --» processing SEMC elec 5 / 65 freq 2
# mean TPSim for low & high [-0.058581938717762148, 0.05786688944583681]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514736842105 auc_mean 0.5
# elec  b6-b5 elec_label  PHG
# --» processing SEMC elec 5 / 65 freq 3
# mean TPSim for low & high [0.15165332686555094, 0.18150932887774993]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.511403508772 auc_mean 0.5
# elec  b6-b5 elec_label  PHG
# --» processing SEMC elec 5 / 65 freq 4
# mean TPSim for low & high [-0.081688091195731269, -0.00016708437761068701]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.597251461988 auc_mean 0.499444444444
# elec  e2-e1 elec_label  Ins
# --» processing SEMC elec 6 / 65 freq 0
# mean TPSim for low & high [0.2027811464144231, 0.0076301865775549827]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.540584795322 auc_mean 0.5
# elec  e2-e1 elec_label  Ins
# --» processing SEMC elec 6 / 65 freq 1
# mean TPSim for low & high [-0.064758670870725205, -0.22729044834307993]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.533099415205 auc_mean 0.5
# elec  e2-e1 elec_label  Ins
# --» processing SEMC elec 6 / 65 freq 2
# mean TPSim for low & high [0.026889805158056428, 0.10164299637983847]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.54 auc_mean 0.5
# elec  e2-e1 elec_label  Ins
# --» processing SEMC elec 6 / 65 freq 3
# mean TPSim for low & high [0.1350958040261945, 0.019715956558061815]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.503333333333 001 0.576666666667 auc_mean 0.5
# elec  e2-e1 elec_label  Ins
# --» processing SEMC elec 6 / 65 freq 4
# mean TPSim for low & high [0.025580079230333889, -0.09896964633806736]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.516666666667 auc_mean 0.5
# elec  e3-e2 elec_label  Ins
# --» processing SEMC elec 7 / 65 freq 0
# mean TPSim for low & high [-0.025224351200582099, 0.17671957671957672]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.524210526316 auc_mean 0.5
# elec  e3-e2 elec_label  Ins
# --» processing SEMC elec 7 / 65 freq 1
# mean TPSim for low & high [-0.0044951087395909139, -0.14346978557504872]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  e3-e2 elec_label  Ins
# --» processing SEMC elec 7 / 65 freq 2
# mean TPSim for low & high [0.095205756326299615, -0.33639654692286269]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.536356725146
# elec  e3-e2 elec_label  Ins
# --» processing SEMC elec 7 / 65 freq 3
# mean TPSim for low & high [0.29400921658986173, -0.098635477582845979]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.528947368421 auc_mean 0.543461988304
# elec  e3-e2 elec_label  Ins
# --» processing SEMC elec 7 / 65 freq 4
# mean TPSim for low & high [0.14599401730131781, 0.011194653299916448]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.572280701754 auc_mean 0.5
# elec  e4-e3 elec_label  IFG
# --» processing SEMC elec 8 / 65 freq 0
# mean TPSim for low & high [0.16182391462527287, 0.12548036758563072]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.503625730994 001 0.522222222222 auc_mean 0.5
# elec  e4-e3 elec_label  IFG
# --» processing SEMC elec 8 / 65 freq 1
# mean TPSim for low & high [0.066084566254345542, -0.26839320523531046]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.525555555556 auc_mean 0.512795321637
# elec  e4-e3 elec_label  IFG
# --» processing SEMC elec 8 / 65 freq 2
# mean TPSim for low & high [0.055590589376667464, 0.0059593428014480514]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  e4-e3 elec_label  IFG
# --» processing SEMC elec 8 / 65 freq 3
# mean TPSim for low & high [0.12034926024739266, -0.17766638819270394]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.566432748538 auc_mean 0.495847953216
# elec  e4-e3 elec_label  IFG
# --» processing SEMC elec 8 / 65 freq 4
# mean TPSim for low & high [0.10626566416040102, -0.21715399610136449]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.496198830409
# elec  e7-e6 elec_label  IFG
# --» processing SEMC elec 9 / 65 freq 0
# mean TPSim for low & high [0.077031287897162251, 0.021832358674463929]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  e7-e6 elec_label  IFG
# --» processing SEMC elec 9 / 65 freq 1
# mean TPSim for low & high [0.21731748726655348, 0.08471177944862153]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.506140350877 001 0.52 auc_mean 0.499473684211
# elec  e7-e6 elec_label  IFG
# --» processing SEMC elec 9 / 65 freq 2
# mean TPSim for low & high [0.069787371654943808, 0.14023948760790864]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  e7-e6 elec_label  IFG
# --» processing SEMC elec 9 / 65 freq 3
# mean TPSim for low & high [0.00029105020616056204, 0.40885547201336675]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.477994152047
# elec  e7-e6 elec_label  IFG
# --» processing SEMC elec 9 / 65 freq 4
# mean TPSim for low & high [-0.05885681946802488, 0.10888331940963519]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.533333333333 auc_mean 0.499473684211
# elec  e8-e7 elec_label  IFG
# --» processing SEMC elec 10 / 65 freq 0
# mean TPSim for low & high [-0.020033955857385405, 0.2222779170147591]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.494064327485
# elec  e8-e7 elec_label  IFG
# --» processing SEMC elec 10 / 65 freq 1
# mean TPSim for low & high [-0.10557037755679519, 0.031578947368421047]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.54 auc_mean 0.5
# elec  e8-e7 elec_label  IFG
# --» processing SEMC elec 10 / 65 freq 2
# mean TPSim for low & high [0.2292343762632387, 0.1610136452241715]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.514444444444 001 0.556666666667 auc_mean 0.5
# elec  e8-e7 elec_label  IFG
# --» processing SEMC elec 10 / 65 freq 3
# mean TPSim for low & high [-0.012903225806451622, 0.081091617933723187]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514736842105 auc_mean 0.5
# elec  e8-e7 elec_label  IFG
# --» processing SEMC elec 10 / 65 freq 4
# mean TPSim for low & high [-0.037496968227019166, 0.0095238095238095056]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.509473684211 auc_mean 0.5
# elec  f2-f1 elec_label  OFC
# --» processing SEMC elec 11 / 65 freq 0
# mean TPSim for low & high [0.18222976796830781, 0.060484544695070995]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.522807017544 auc_mean 0.5
# elec  f2-f1 elec_label  OFC
# --» processing SEMC elec 11 / 65 freq 1
# mean TPSim for low & high [0.024512895141078503, -0.10604288499025341]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.523333333333 auc_mean 0.5
# elec  f2-f1 elec_label  OFC
# --» processing SEMC elec 11 / 65 freq 2
# mean TPSim for low & high [0.025822621068801031, 0.14954051796157058]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.511403508772 auc_mean 0.5
# elec  f2-f1 elec_label  OFC
# --» processing SEMC elec 11 / 65 freq 3
# mean TPSim for low & high [0.041620179480960466, -0.14831523252575882]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.505847953216 001 0.535321637427 auc_mean 0.495087719298
# elec  f2-f1 elec_label  OFC
# --» processing SEMC elec 11 / 65 freq 4
# mean TPSim for low & high [-0.096434634974533098, -0.37421331105541633]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.522807017544 auc_mean 0.5
# elec  f3-f2 elec_label  OFC
# --» processing SEMC elec 12 / 65 freq 0
# mean TPSim for low & high [-0.12814293799013662, 0.16480089111668056]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.558421052632 auc_mean 0.5
# elec  f3-f2 elec_label  OFC
# --» processing SEMC elec 12 / 65 freq 1
# mean TPSim for low & high [0.029315223542727777, 0.31367307156780838]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.503333333333 auc_mean 0.5
# elec  f3-f2 elec_label  OFC
# --» processing SEMC elec 12 / 65 freq 2
# mean TPSim for low & high [0.15005255073166787, 0.028292954608744078]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514444444444 auc_mean 0.5
# elec  f3-f2 elec_label  OFC
# --» processing SEMC elec 12 / 65 freq 3
# mean TPSim for low & high [0.015732880588568185, -0.1465329991645781]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.535321637427 auc_mean 0.5
# elec  f3-f2 elec_label  OFC
# --» processing SEMC elec 12 / 65 freq 4
# mean TPSim for low & high [0.02460991187646535, -0.22199944305207459]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.525555555556 auc_mean 0.5
# elec  f4-f3 elec_label  OFC
# --» processing SEMC elec 13 / 65 freq 0
# mean TPSim for low & high [0.052874120785835546, -0.093790030632135868]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.540292397661 auc_mean 0.5
# elec  f4-f3 elec_label  OFC
# --» processing SEMC elec 13 / 65 freq 1
# mean TPSim for low & high [0.14204867006225241, 0.21303258145363402]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  f4-f3 elec_label  OFC
# --» processing SEMC elec 13 / 65 freq 2
# mean TPSim for low & high [-0.030527932735063459, -0.076636034530771377]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.508888888889 auc_mean 0.5
# elec  f4-f3 elec_label  OFC
# --» processing SEMC elec 13 / 65 freq 3
# mean TPSim for low & high [0.060522273425499248, -0.3187412976886661]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.516666666667 auc_mean 0.524520467836
# elec  f4-f3 elec_label  OFC
# --» processing SEMC elec 13 / 65 freq 4
# mean TPSim for low & high [-0.072697873716549413, 0.032804232804232822]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.516666666667 auc_mean 0.5
# elec  f5-f4 elec_label  OFC
# --» processing SEMC elec 14 / 65 freq 0
# mean TPSim for low & high [-0.16997332039776858, -0.067167919799498724]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.500584795322 001 0.605321637427 auc_mean 0.5
# elec  f5-f4 elec_label  OFC
# --» processing SEMC elec 14 / 65 freq 1
# mean TPSim for low & high [-0.074233972026841288, 0.093233082706766904]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  f5-f4 elec_label  OFC
# --» processing SEMC elec 14 / 65 freq 2
# mean TPSim for low & high [0.035071549842347796, -0.055137844611528798]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.542807017544 auc_mean 0.5
# elec  f5-f4 elec_label  OFC
# --» processing SEMC elec 14 / 65 freq 3
# mean TPSim for low & high [0.058953836203411741, 0.29145084934558618]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.560058479532 auc_mean 0.498421052632
# elec  f5-f4 elec_label  OFC
# --» processing SEMC elec 14 / 65 freq 4
# mean TPSim for low & high [0.040439809200420403, -0.42974101921470331]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.536169590643
# elec  f6-f5 elec_label  OFC
# --» processing SEMC elec 15 / 65 freq 0
# mean TPSim for low & high [-0.13891179561807743, 0.11283764967975493]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.525847953216 auc_mean 0.500614035088
# elec  f6-f5 elec_label  OFC
# --» processing SEMC elec 15 / 65 freq 1
# mean TPSim for low & high [0.026663432775487102, 0.024171539961013639]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.531111111111 auc_mean 0.5
# elec  f6-f5 elec_label  OFC
# --» processing SEMC elec 15 / 65 freq 2
# mean TPSim for low & high [-0.014083596086991675, 0.19186856028961291]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.536666666667 auc_mean 0.5
# elec  f6-f5 elec_label  OFC
# --» processing SEMC elec 15 / 65 freq 3
# mean TPSim for low & high [0.049268332120624141, 0.046950710108604847]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.573625730994 auc_mean 0.5
# elec  f6-f5 elec_label  OFC
# --» processing SEMC elec 15 / 65 freq 4
# mean TPSim for low & high [0.074379497129921576, 0.0093010303536619418]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.505555555556 auc_mean 0.5
# elec  f7-f6 elec_label  MFG
# --» processing SEMC elec 16 / 65 freq 0
# mean TPSim for low & high [0.091276578543132036, 0.11495405179615706]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.534444444444 auc_mean 0.5
# elec  f7-f6 elec_label  MFG
# --» processing SEMC elec 16 / 65 freq 1
# mean TPSim for low & high [0.053698763036623812, 0.19877471456418827]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.531403508772 auc_mean 0.5
# elec  f7-f6 elec_label  MFG
# --» processing SEMC elec 16 / 65 freq 2
# mean TPSim for low & high [0.073005093378607777, 0.046226677805625199]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.531403508772 auc_mean 0.5
# elec  f7-f6 elec_label  MFG
# --» processing SEMC elec 16 / 65 freq 3
# mean TPSim for low & high [-0.062462608133236307, 0.075132275132275134]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.639766081871 auc_mean 0.5
# elec  f7-f6 elec_label  MFG
# --» processing SEMC elec 16 / 65 freq 4
# mean TPSim for low & high [0.01907995795941465, -0.10799220272904485]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.5 auc_mean 0.5
# elec  f8-f7 elec_label  MFG
# --» processing SEMC elec 17 / 65 freq 0
# mean TPSim for low & high [0.012337294850028296, 0.27123363965469227]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  f8-f7 elec_label  MFG
# --» processing SEMC elec 17 / 65 freq 1
# mean TPSim for low & high [-0.055105505699733194, -0.033806739069896938]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  f8-f7 elec_label  MFG
# --» processing SEMC elec 17 / 65 freq 2
# mean TPSim for low & high [0.28288463093216909, -0.018657755499860772]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.50918128655 001 0.551111111111 auc_mean 0.586356725146
# elec  f8-f7 elec_label  MFG
# --» processing SEMC elec 17 / 65 freq 3
# mean TPSim for low & high [-0.060991187646535695, 0.009133945976051246]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  f8-f7 elec_label  MFG
# --» processing SEMC elec 17 / 65 freq 4
# mean TPSim for low & high [0.21864338265017386, -0.22667780562517401]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.551111111111 auc_mean 0.54598245614
# elec  j2-j1 elec_label  IFG
# --» processing SEMC elec 18 / 65 freq 0
# mean TPSim for low & high [0.034990702562858751, 0.027067669172932327]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.547777777778 auc_mean 0.5
# elec  j2-j1 elec_label  IFG
# --» processing SEMC elec 18 / 65 freq 1
# mean TPSim for low & high [-0.049397687767806599, 0.10219994430520744]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514736842105 auc_mean 0.5
# elec  j2-j1 elec_label  IFG
# --» processing SEMC elec 18 / 65 freq 2
# mean TPSim for low & high [-0.001681623413372137, -0.22690058479532155]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52918128655 auc_mean 0.498228070175
# elec  j2-j1 elec_label  IFG
# --» processing SEMC elec 18 / 65 freq 3
# mean TPSim for low & high [0.09190718732314658, 0.018602060707323859]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.59918128655 auc_mean 0.5
# elec  j2-j1 elec_label  IFG
# --» processing SEMC elec 18 / 65 freq 4
# mean TPSim for low & high [0.094122402781146378, 0.25129490392648285]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.548070175439 auc_mean 0.5
# elec  j3-j2 elec_label  IFG
# --» processing SEMC elec 19 / 65 freq 0
# mean TPSim for low & high [0.02139219015280135, 0.27969924812030073]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.566140350877 auc_mean 0.497865497076
# elec  j3-j2 elec_label  IFG
# --» processing SEMC elec 19 / 65 freq 1
# mean TPSim for low & high [0.080216670709030644, 0.073739905318852675]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514736842105 auc_mean 0.5
# elec  j3-j2 elec_label  IFG
# --» processing SEMC elec 19 / 65 freq 2
# mean TPSim for low & high [-0.038596491228070177, -0.058925090504037873]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.553391812865 auc_mean 0.5
# elec  j3-j2 elec_label  IFG
# --» processing SEMC elec 19 / 65 freq 3
# mean TPSim for low & high [0.17852696256770956, 0.1946532999164578]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.554736842105 auc_mean 0.5
# elec  j3-j2 elec_label  IFG
# --» processing SEMC elec 19 / 65 freq 4
# mean TPSim for low & high [0.090565122483628413, -0.019326093010303521]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.536666666667 auc_mean 0.5
# elec  j4-j3 elec_label  IFG
# --» processing SEMC elec 20 / 65 freq 0
# mean TPSim for low & high [-0.10584525830705795, -0.25485937064884429]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.536666666667 auc_mean 0.5
# elec  j4-j3 elec_label  IFG
# --» processing SEMC elec 20 / 65 freq 1
# mean TPSim for low & high [-0.041086587436332769, 0.016764132553606228]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.531403508772 auc_mean 0.5
# elec  j4-j3 elec_label  IFG
# --» processing SEMC elec 20 / 65 freq 2
# mean TPSim for low & high [-0.13422265340771281, 0.050236702868281809]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.531988304094 auc_mean 0.494064327485
# elec  j4-j3 elec_label  IFG
# --» processing SEMC elec 20 / 65 freq 3
# mean TPSim for low & high [-0.035572802975179882, -0.27875243664717347]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.525555555556 auc_mean 0.498918128655
# elec  j4-j3 elec_label  IFG
# --» processing SEMC elec 20 / 65 freq 4
# mean TPSim for low & high [0.099086425741773759, -0.09267613478139794]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  j5-j4 elec_label  STG
# --» processing SEMC elec 21 / 65 freq 0
# mean TPSim for low & high [-0.22997817123453795, -0.086104149262043989]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.50918128655 001 0.606725146199 auc_mean 0.497894736842
# elec  j5-j4 elec_label  STG
# --» processing SEMC elec 21 / 65 freq 1
# mean TPSim for low & high [-0.12025224351200578, -0.068003341687552218]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52918128655 auc_mean 0.5
# elec  j5-j4 elec_label  STG
# --» processing SEMC elec 21 / 65 freq 2
# mean TPSim for low & high [-0.022265340771283042, 0.0069618490671122238]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.537543859649 auc_mean 0.5
# elec  j5-j4 elec_label  STG
# --» processing SEMC elec 21 / 65 freq 3
# mean TPSim for low & high [-0.1937747594793435, -0.045502645502645496]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.529473684211 auc_mean 0.5
# elec  j5-j4 elec_label  STG
# --» processing SEMC elec 21 / 65 freq 4
# mean TPSim for low & high [0.16366723259762311, -0.23692564745196323]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.508888888889 001 0.571403508772 auc_mean 0.67349122807
# elec  j6-j5 elec_label  STG
# --» processing SEMC elec 22 / 65 freq 0
# mean TPSim for low & high [0.048492198237529295, -0.066221108326371458]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.511111111111 001 0.54918128655 auc_mean 0.5
# elec  j6-j5 elec_label  STG
# --» processing SEMC elec 22 / 65 freq 1
# mean TPSim for low & high [0.11819872261298404, -0.46416040100250622]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514736842105 auc_mean 0.660947368421
# elec  j6-j5 elec_label  STG
# --» processing SEMC elec 22 / 65 freq 2
# mean TPSim for low & high [0.041652518392756077, -0.14647730437204121]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.516666666667 auc_mean 0.498333333333
# elec  j6-j5 elec_label  STG
# --» processing SEMC elec 22 / 65 freq 3
# mean TPSim for low & high [-0.04252566901123777, 0.07580061264271791]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.521169590643 auc_mean 0.5
# elec  j6-j5 elec_label  STG
# --» processing SEMC elec 22 / 65 freq 4
# mean TPSim for low & high [-0.054588083111003299, 0.035756056808688395]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.545847953216 auc_mean 0.5
# elec  k10-k9 elec_label  MFG
# --» processing SEMC elec 23 / 65 freq 0
# mean TPSim for low & high [-0.050384024577572975, 0.15789473684210525]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.523625730994 auc_mean 0.5
# elec  k10-k9 elec_label  MFG
# --» processing SEMC elec 23 / 65 freq 1
# mean TPSim for low & high [-0.058210041232112528, -0.24333054859370642]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.517543859649 auc_mean 0.5
# elec  k10-k9 elec_label  MFG
# --» processing SEMC elec 23 / 65 freq 2
# mean TPSim for low & high [0.18902093944538764, 0.058925090504037859]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.514736842105 001 0.567777777778 auc_mean 0.5
# elec  k10-k9 elec_label  MFG
# --» processing SEMC elec 23 / 65 freq 3
# mean TPSim for low & high [0.10471339639421134, 0.22322472848788635]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.504210526316 001 0.536666666667 auc_mean 0.5
# elec  k10-k9 elec_label  MFG
# --» processing SEMC elec 23 / 65 freq 4
# mean TPSim for low & high [0.25423235508125153, 0.22695627958785852]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.516666666667 001 0.636959064327 auc_mean 0.5
# elec  k11-k10 elec_label  MFG
# --» processing SEMC elec 24 / 65 freq 0
# mean TPSim for low & high [0.062365591397849453, -0.077360066833751018]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.5 auc_mean 0.5
# elec  k11-k10 elec_label  MFG
# --» processing SEMC elec 24 / 65 freq 1
# mean TPSim for low & high [-0.087913331716387724, 0.088888888888888892]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.562807017544 auc_mean 0.5
# elec  k11-k10 elec_label  MFG
# --» processing SEMC elec 24 / 65 freq 2
# mean TPSim for low & high [-0.09205271242622684, 0.35577833472570319]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.661187134503
# elec  k11-k10 elec_label  MFG
# --» processing SEMC elec 24 / 65 freq 3
# mean TPSim for low & high [-0.004462769827795296, -0.068838763575605685]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.538362573099 auc_mean 0.5
# elec  k11-k10 elec_label  MFG
# --» processing SEMC elec 24 / 65 freq 4
# mean TPSim for low & high [0.10387258468752529, -0.06494012809802284]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  k12-k11 elec_label  MFG
# --» processing SEMC elec 25 / 65 freq 0
# mean TPSim for low & high [0.12238661169051661, 0.044890002784739647]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.563157894737 auc_mean 0.5
# elec  k12-k11 elec_label  MFG
# --» processing SEMC elec 25 / 65 freq 1
# mean TPSim for low & high [-0.019484194356859885, 0.094681147312726241]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.516666666667 auc_mean 0.5
# elec  k12-k11 elec_label  MFG
# --» processing SEMC elec 25 / 65 freq 2
# mean TPSim for low & high [-0.017349826178349091, -0.21353383458646616]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.506140350877 auc_mean 0.5
# elec  k12-k11 elec_label  MFG
# --» processing SEMC elec 25 / 65 freq 3
# mean TPSim for low & high [-0.10919233567790444, 0.030186577554998598]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  k12-k11 elec_label  MFG
# --» processing SEMC elec 25 / 65 freq 4
# mean TPSim for low & high [-0.052841781874039921, 0.23592314118629906]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.54 auc_mean 0.505649122807
# elec  k2-k1 elec_label  ACC
# --» processing SEMC elec 26 / 65 freq 0
# mean TPSim for low & high [-0.030754305117632785, 0.020272904483430779]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514444444444 auc_mean 0.5
# elec  k2-k1 elec_label  ACC
# --» processing SEMC elec 26 / 65 freq 1
# mean TPSim for low & high [0.29428409734012445, 0.27023113338902816]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.523333333333 001 0.549473684211 auc_mean 0.5
# elec  k2-k1 elec_label  ACC
# --» processing SEMC elec 26 / 65 freq 2
# mean TPSim for low & high [-0.009426792788422662, 0.283375104427736]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.524210526316 auc_mean 0.499473684211
# elec  k2-k1 elec_label  ACC
# --» processing SEMC elec 26 / 65 freq 3
# mean TPSim for low & high [0.024318861670304795, -0.11361737677527149]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.54 auc_mean 0.5
# elec  k2-k1 elec_label  ACC
# --» processing SEMC elec 26 / 65 freq 4
# mean TPSim for low & high [0.21461718813161934, 0.20334168755221385]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.509473684211 001 0.58865497076 auc_mean 0.5
# elec  k9-k8 elec_label  MFG
# --» processing SEMC elec 27 / 65 freq 0
# mean TPSim for low & high [-0.063853181340447901, -0.19170147591200221]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.516666666667 auc_mean 0.5
# elec  k9-k8 elec_label  MFG
# --» processing SEMC elec 27 / 65 freq 1
# mean TPSim for low & high [0.017495351281429362, -0.03269284321915901]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.525555555556 auc_mean 0.5
# elec  k9-k8 elec_label  MFG
# --» processing SEMC elec 27 / 65 freq 2
# mean TPSim for low & high [-0.023898455816961761, 0.13528265107212475]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.511403508772 auc_mean 0.5
# elec  k9-k8 elec_label  MFG
# --» processing SEMC elec 27 / 65 freq 3
# mean TPSim for low & high [0.33684210526315783, 0.047563352826510703]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.625321637427 auc_mean 0.527766081871
# elec  k9-k8 elec_label  MFG
# --» processing SEMC elec 27 / 65 freq 4
# mean TPSim for low & high [0.12633195892958202, 0.17883597883597885]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.58918128655 auc_mean 0.5
# elec  o10-o9 elec_label  OFC
# --» processing SEMC elec 28 / 65 freq 0
# mean TPSim for low & high [-0.0098310291858678921, -0.13227513227513227]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.540584795322 auc_mean 0.5
# elec  o10-o9 elec_label  OFC
# --» processing SEMC elec 28 / 65 freq 1
# mean TPSim for low & high [0.013161937100816548, -0.02027290448343079]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.542222222222 auc_mean 0.5
# elec  o10-o9 elec_label  OFC
# --» processing SEMC elec 28 / 65 freq 2
# mean TPSim for low & high [0.011027568922305756, 0.166193260930103]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.534736842105 auc_mean 0.5
# elec  o10-o9 elec_label  OFC
# --» processing SEMC elec 28 / 65 freq 3
# mean TPSim for low & high [0.23077047457353062, -0.042105263157894743]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# /home/karim/anaconda3/lib/python3.5/site-packages/sklearn/discriminant_analysis.py:402: RuntimeWarning: invalid value encountered in true_divide
#   S**2))[:self._max_components]
# th_perm 05:  0.5 01 0.5 001 0.573918128655 auc_mean 0.549415204678
# elec  o10-o9 elec_label  OFC
# --» processing SEMC elec 28 / 65 freq 4
# mean TPSim for low & high [0.19152720510954799, 0.031913116123642435]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514736842105 auc_mean 0.499473684211
# elec  o11-o10 elec_label  IFG
# --» processing SEMC elec 29 / 65 freq 0
# mean TPSim for low & high [-0.010105909936130647, -0.44706209969367866]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.529473684211 auc_mean 0.498216374269
# elec  o11-o10 elec_label  IFG
# --» processing SEMC elec 29 / 65 freq 1
# mean TPSim for low & high [0.09801924165251838, -0.12843219159008634]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.499473684211
# elec  o11-o10 elec_label  IFG
# --» processing SEMC elec 29 / 65 freq 2
# mean TPSim for low & high [-0.04407793677742744, -0.2147591200222779]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514736842105 auc_mean 0.5
# elec  o11-o10 elec_label  IFG
# --» processing SEMC elec 29 / 65 freq 3
# mean TPSim for low & high [0.032387420163311517, 0.13093845725424669]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.52 auc_mean 0.5
# elec  o11-o10 elec_label  IFG
# --» processing SEMC elec 29 / 65 freq 4
# mean TPSim for low & high [0.14657611771363893, 0.20245057087162352]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.525847953216 auc_mean 0.5
# elec  o12-o11 elec_label  IFG
# --» processing SEMC elec 30 / 65 freq 0
# mean TPSim for low & high [0.081574905004446599, -0.55834029518240047]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.517777777778 auc_mean 0.721719298246
# elec  o12-o11 elec_label  IFG
# --» processing SEMC elec 30 / 65 freq 1
# mean TPSim for low & high [-0.057547093540302366, 0.029072681704260653]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514444444444 auc_mean 0.5
# elec  o12-o11 elec_label  IFG
# --» processing SEMC elec 30 / 65 freq 2
# mean TPSim for low & high [-0.059616783895221917, -0.32286271233639652]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.540584795322 auc_mean 0.5
# elec  o12-o11 elec_label  IFG
# --» processing SEMC elec 30 / 65 freq 3
# mean TPSim for low & high [0.074525022233001864, -0.065552770815928724]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.554444444444 auc_mean 0.5
# elec  o12-o11 elec_label  IFG
# --» processing SEMC elec 30 / 65 freq 4
# mean TPSim for low & high [0.1464144231546608, 0.088777499303815094]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.517543859649 auc_mean 0.5
# elec  o13-o12 elec_label  IFG
# --» processing SEMC elec 31 / 65 freq 0
# mean TPSim for low & high [-0.015199288543940488, -0.2205513784461153]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.509473684211 001 0.551695906433 auc_mean 0.498947368421
# elec  o13-o12 elec_label  IFG
# --» processing SEMC elec 31 / 65 freq 1
# mean TPSim for low & high [0.067636834020535205, -0.077081592871066543]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.543625730994 auc_mean 0.5
# elec  o13-o12 elec_label  IFG
# --» processing SEMC elec 31 / 65 freq 2
# mean TPSim for low & high [0.092068881882124656, -0.18791423001949317]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.503625730994 001 0.536666666667 auc_mean 0.489766081871
# elec  o13-o12 elec_label  IFG
# --» processing SEMC elec 31 / 65 freq 3
# mean TPSim for low & high [0.090144716630285379, -0.2051239209133946]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.514444444444 auc_mean 0.486280701754
# elec  o13-o12 elec_label  IFG
# --» processing SEMC elec 31 / 65 freq 4
# mean TPSim for low & high [-0.12316274557361143, 0.19587858535226954]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.50701754386 001 0.531695906433 auc_mean 0.56530994152
# elec  o2-o1 elec_label  ACC
# --» processing SEMC elec 32 / 65 freq 0
# mean TPSim for low & high [-0.18640148758994263, 0.16112503480924534]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# th_perm 05:  0.5 01 0.5 001 0.602514619883 auc_mean 0.548526315789
# elec  o2-o1 elec_label  ACC
# --» processing SEMC elec 32 / 65 freq 1
# mean TPSim for low & high [-0.16033632468267439, 0.081481481481481488]
# Size of the concatenated data:  (120, 1) Number time windows :  1
# Size of label for classif:  120
# ...
# --» processing CHAF elec 47 / 57 freq 0
# mean TPSim for low & high [0.21345029239766078, 0.031812865497076022]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.522222222222 01 0.583333333333 001 0.655555555556 auc_mean 0.498888888889
# elec  i'10-i'9 elec_label  SFG
# --» processing CHAF elec 47 / 57 freq 1
# mean TPSim for low & high [-0.00041771094402674887, 0.094937343358395959]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.513888888889 01 0.580555555556 001 0.666666666667 auc_mean 0.495555555556
# elec  i'10-i'9 elec_label  SFG
# --» processing CHAF elec 47 / 57 freq 2
# mean TPSim for low & high [-0.019131161236424388, 0.10539682539682538]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.530555555556 01 0.586111111111 001 0.652777777778 auc_mean 0.492222222222
# elec  i'10-i'9 elec_label  SFG
# --» processing CHAF elec 47 / 57 freq 3
# mean TPSim for low & high [-0.22255639097744359, 0.077460317460317465]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.513888888889 01 0.558333333333 001 0.727777777778 auc_mean 0.534444444444
# elec  i'10-i'9 elec_label  SFG
# --» processing CHAF elec 47 / 57 freq 4
# mean TPSim for low & high [0.46106934001670841, -0.13326649958228906]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.502777777778 01 0.544444444444 001 0.65 auc_mean 0.712777777778
# elec  i'11-i'10 elec_label  SFG
# --» processing CHAF elec 48 / 57 freq 0
# mean TPSim for low & high [0.11161236424394318, 0.18980785296574768]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.505555555556 01 0.555555555556 001 0.655555555556 auc_mean 0.497777777778
# elec  i'11-i'10 elec_label  SFG
# --» processing CHAF elec 48 / 57 freq 1
# mean TPSim for low & high [0.09089390142021718, -0.12464494569757725]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.519444444444 01 0.569444444444 001 0.633333333333 auc_mean 0.496944444444
# elec  i'11-i'10 elec_label  SFG
# --» processing CHAF elec 48 / 57 freq 2
# mean TPSim for low & high [-0.0094402673350041863, -0.065162907268170422]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.513888888889 01 0.569444444444 001 0.766666666667 auc_mean 0.497777777778
# elec  i'11-i'10 elec_label  SFG
# --» processing CHAF elec 48 / 57 freq 3
# mean TPSim for low & high [-0.045112781954887202, -0.02108604845446951]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.522222222222 01 0.563888888889 001 0.655555555556 auc_mean 0.5
# elec  i'11-i'10 elec_label  SFG
# --» processing CHAF elec 48 / 57 freq 4
# mean TPSim for low & high [0.16917293233082706, -0.077928153717627416]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.522222222222 01 0.572222222222 001 0.669444444444 auc_mean 0.508333333333
# elec  i'12-i'11 elec_label  SFG
# --» processing CHAF elec 49 / 57 freq 0
# mean TPSim for low & high [-0.34527986633249785, 0.046750208855471993]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.5 01 0.608333333333 001 0.675 auc_mean 0.499722222222
# elec  i'12-i'11 elec_label  SFG
# --» processing CHAF elec 49 / 57 freq 1
# mean TPSim for low & high [0.030659983291562245, -0.080167084377610678]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.522222222222 01 0.586111111111 001 0.702777777778 auc_mean 0.496666666667
# elec  i'12-i'11 elec_label  SFG
# --» processing CHAF elec 49 / 57 freq 2
# mean TPSim for low & high [0.1130325814536341, 0.0048454469507101094]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.502777777778 01 0.55 001 0.638888888889 auc_mean 0.496666666667
# elec  i'12-i'11 elec_label  SFG
# --» processing CHAF elec 49 / 57 freq 3
# mean TPSim for low & high [0.3399331662489557, 0.061687552213867985]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.502777777778 01 0.558333333333 001 0.647222222222 auc_mean 0.4825
# elec  i'12-i'11 elec_label  SFG
# --» processing CHAF elec 49 / 57 freq 4
# mean TPSim for low & high [0.14945697577276523, -0.063759398496240613]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.525 01 0.586111111111 001 0.608333333333 auc_mean 0.464722222222
# elec  i'13-i'12 elec_label  SFG
# --» processing CHAF elec 50 / 57 freq 0
# mean TPSim for low & high [0.047284878863826235, 0.24594820384294064]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.513888888889 01 0.552777777778 001 0.580555555556 auc_mean 0.515555555556
# elec  i'13-i'12 elec_label  SFG
# --» processing CHAF elec 50 / 57 freq 1
# mean TPSim for low & high [0.38061821219715947, 0.12046783625730992]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.525 01 0.583333333333 001 0.666666666667 auc_mean 0.506111111111
# elec  i'13-i'12 elec_label  SFG
# --» processing CHAF elec 50 / 57 freq 2
# mean TPSim for low & high [-0.017961570593149553, 0.065263157894736842]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.511111111111 01 0.6 001 0.713888888889 auc_mean 0.5
# elec  i'13-i'12 elec_label  SFG
# --» processing CHAF elec 50 / 57 freq 3
# mean TPSim for low & high [-0.18638262322472846, 0.14426065162907267]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.502777777778 01 0.563888888889 001 0.652777777778 auc_mean 0.513055555556
# elec  i'13-i'12 elec_label  SFG
# --» processing CHAF elec 50 / 57 freq 4
# mean TPSim for low & high [0.18262322472848788, 0.0033751044277360001]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.505555555556 01 0.555555555556 001 0.713888888889 auc_mean 0.486666666667
# elec  i'14-i'13 elec_label  SFG
# --» processing CHAF elec 51 / 57 freq 0
# mean TPSim for low & high [0.32497911445279865, 0.20217209690893903]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.516666666667 01 0.563888888889 001 0.633333333333 auc_mean 0.5
# elec  i'14-i'13 elec_label  SFG
# --» processing CHAF elec 51 / 57 freq 1
# mean TPSim for low & high [0.063826232247284884, 0.15418546365914787]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.5 01 0.575 001 0.658333333333 auc_mean 0.5
# elec  i'14-i'13 elec_label  SFG
# --» processing CHAF elec 51 / 57 freq 2
# mean TPSim for low & high [-0.12706766917293233, 0.096942355889724316]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.513888888889 01 0.555555555556 001 0.627777777778 auc_mean 0.494722222222
# elec  i'14-i'13 elec_label  SFG
# --» processing CHAF elec 51 / 57 freq 3
# mean TPSim for low & high [-0.11069340016708439, -0.058111946532999156]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.513888888889 01 0.577777777778 001 0.680555555556 auc_mean 0.5
# elec  i'14-i'13 elec_label  SFG
# --» processing CHAF elec 51 / 57 freq 4
# mean TPSim for low & high [-0.0031746031746031573, -0.12447786131996658]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.513888888889 01 0.563888888889 001 0.641666666667 auc_mean 0.493333333333
# elec  i'15-i'14 elec_label  SFG
# --» processing CHAF elec 52 / 57 freq 0
# mean TPSim for low & high [0.2327485380116959, 0.18813700918964074]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.505555555556 01 0.552777777778 001 0.663888888889 auc_mean 0.5
# elec  i'15-i'14 elec_label  SFG
# --» processing CHAF elec 52 / 57 freq 1
# mean TPSim for low & high [0.065246449456975761, 0.20431077694235583]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.502777777778 01 0.561111111111 001 0.741666666667 auc_mean 0.491111111111
# elec  i'15-i'14 elec_label  SFG
# --» processing CHAF elec 52 / 57 freq 2
# mean TPSim for low & high [-0.082957393483709271, -0.031177944862155391]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.511111111111 01 0.547222222222 001 0.633333333333 auc_mean 0.5
# elec  i'15-i'14 elec_label  SFG
# --» processing CHAF elec 52 / 57 freq 3
# mean TPSim for low & high [0.03734335839598997, -0.10065162907268167]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.522222222222 01 0.575 001 0.630555555556 auc_mean 0.491111111111
# elec  i'15-i'14 elec_label  SFG
# --» processing CHAF elec 52 / 57 freq 4
# mean TPSim for low & high [-0.33141186299081027, -0.0045446950710108592]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.522222222222 01 0.577777777778 001 0.638888888889 auc_mean 0.555
# elec  i'8-i'7 elec_label  SFG
# --» processing CHAF elec 53 / 57 freq 0
# mean TPSim for low & high [0.026900584795321609, 0.18489557226399328]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.5 01 0.558333333333 001 0.683333333333 auc_mean 0.492777777778
# elec  i'8-i'7 elec_label  SFG
# --» processing CHAF elec 53 / 57 freq 1
# mean TPSim for low & high [-0.011194653299916452, 0.067802840434419392]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.511111111111 01 0.552777777778 001 0.630555555556 auc_mean 0.5
# elec  i'8-i'7 elec_label  SFG
# --» processing CHAF elec 53 / 57 freq 2
# mean TPSim for low & high [0.12247284878863827, 0.09804511278195488]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.511111111111 01 0.580555555556 001 0.638888888889 auc_mean 0.5
# elec  i'8-i'7 elec_label  SFG
# --» processing CHAF elec 53 / 57 freq 3
# mean TPSim for low & high [0.10000000000000001, -0.016407685881370079]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.513888888889 01 0.558333333333 001 0.655555555556 auc_mean 0.497777777778
# elec  i'8-i'7 elec_label  SFG
# --» processing CHAF elec 53 / 57 freq 4
# mean TPSim for low & high [0.27468671679197992, 0.0012698412698412629]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.502777777778 01 0.558333333333 001 0.638888888889 auc_mean 0.543611111111
# elec  i'9-i'8 elec_label  SFG
# --» processing CHAF elec 54 / 57 freq 0
# mean TPSim for low & high [0.181203007518797, 0.01827903091060985]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.525 01 0.575 001 0.627777777778 auc_mean 0.494444444444
# elec  i'9-i'8 elec_label  SFG
# --» processing CHAF elec 54 / 57 freq 1
# mean TPSim for low & high [-0.04887218045112781, 0.085948203842940663]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.502777777778 01 0.561111111111 001 0.597222222222 auc_mean 0.497777777778
# elec  i'9-i'8 elec_label  SFG
# --» processing CHAF elec 54 / 57 freq 2
# mean TPSim for low & high [-0.059732664995822873, -0.17924812030075185]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.516666666667 01 0.572222222222 001 0.633333333333 auc_mean 0.482222222222
# elec  i'9-i'8 elec_label  SFG
# --» processing CHAF elec 54 / 57 freq 3
# mean TPSim for low & high [-0.2279866332497911, -0.070910609857978257]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.513888888889 01 0.558333333333 001 0.636111111111 auc_mean 0.5
# elec  i'9-i'8 elec_label  SFG
# --» processing CHAF elec 54 / 57 freq 4
# mean TPSim for low & high [0.029490392648287359, -0.33497076023391803]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.522222222222 01 0.583333333333 001 0.625 auc_mean 0.624722222222
# elec  j'14-j'13 elec_label  MFG
# --» processing CHAF elec 55 / 57 freq 0
# mean TPSim for low & high [-0.1177109440267335, 0.12170426065162906]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.5 01 0.558333333333 001 0.644444444444 auc_mean 0.4875
# elec  j'14-j'13 elec_label  MFG
# --» processing CHAF elec 55 / 57 freq 1
# mean TPSim for low & high [-0.15455304928989139, -0.036524644945697557]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.502777777778 01 0.572222222222 001 0.716666666667 auc_mean 0.5025
# elec  j'14-j'13 elec_label  MFG
# --» processing CHAF elec 55 / 57 freq 2
# mean TPSim for low & high [-0.049206349206349205, -0.071111111111111111]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.511111111111 01 0.572222222222 001 0.675 auc_mean 0.5
# elec  j'14-j'13 elec_label  MFG
# --» processing CHAF elec 55 / 57 freq 3
# mean TPSim for low & high [0.0027568922305764298, -0.17878028404344193]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.516666666667 01 0.558333333333 001 0.636111111111 auc_mean 0.507222222222
# elec  j'14-j'13 elec_label  MFG
# --» processing CHAF elec 55 / 57 freq 4
# mean TPSim for low & high [0.25605680868838765, -0.18970760233918124]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.5 01 0.533333333333 001 0.608333333333 auc_mean 0.609722222222
# elec  j'15-j'14 elec_label  MFG
# --» processing CHAF elec 56 / 57 freq 0
# mean TPSim for low & high [-0.31520467836257304, 0.063692564745196342]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.5 01 0.547222222222 001 0.666666666667 auc_mean 0.559166666667
# elec  j'15-j'14 elec_label  MFG
# --» processing CHAF elec 56 / 57 freq 1
# mean TPSim for low & high [0.35121136173767747, -0.11485380116959064]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.5 01 0.563888888889 001 0.666666666667 auc_mean 0.688333333333
# elec  j'15-j'14 elec_label  MFG
# --» processing CHAF elec 56 / 57 freq 2
# mean TPSim for low & high [-0.23500417710944024, 0.0508939014202172]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.513888888889 01 0.580555555556 001 0.652777777778 auc_mean 0.497222222222
# elec  j'15-j'14 elec_label  MFG
# --» processing CHAF elec 56 / 57 freq 3
# mean TPSim for low & high [0.059732664995822873, 0.13052631578947366]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.522222222222 01 0.572222222222 001 0.633333333333 auc_mean 0.5
# elec  j'15-j'14 elec_label  MFG
# --» processing CHAF elec 56 / 57 freq 4
# mean TPSim for low & high [-0.060233918128654959, -0.0083876357560568066]
# Size of the concatenated data:  (63, 1) Number time windows :  1
# Size of label for classif:  63
# th_perm 05:  0.516666666667 01 0.561111111111 001 0.619444444444 auc_mean 0.5

# %%
from sklearn.model_selection import StratifiedKFold
X = np.array([[1, 2], [3, 4], [1, 2], [3, 4], [2,6], [8,3],[4,2],[4,3]])
y = np.array([0,0,1,1,1,1,1,1])
skf = StratifiedKFold(n_splits=2,shuffle=True)
for i in range(10):
    for train_index, test_index in skf.split(X, y):
        print(i, "TRAIN:", train_index, "TEST:", test_index)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
# Out:
# 0 TRAIN: [1 2 4 5] TEST: [0 3 6 7]
# 0 TRAIN: [0 3 6 7] TEST: [1 2 4 5]
# 1 TRAIN: [0 5 6 7] TEST: [1 2 3 4]
# 1 TRAIN: [1 2 3 4] TEST: [0 5 6 7]
# 2 TRAIN: [1 2 3 6] TEST: [0 4 5 7]
# 2 TRAIN: [0 4 5 7] TEST: [1 2 3 6]
# 3 TRAIN: [1 4 6 7] TEST: [0 2 3 5]
# 3 TRAIN: [0 2 3 5] TEST: [1 4 6 7]
# 4 TRAIN: [1 3 5 6] TEST: [0 2 4 7]
# 4 TRAIN: [0 2 4 7] TEST: [1 3 5 6]
# 5 TRAIN: [1 3 5 7] TEST: [0 2 4 6]
# 5 TRAIN: [0 2 4 6] TEST: [1 3 5 7]
# 6 TRAIN: [1 4 5 7] TEST: [0 2 3 6]
# 6 TRAIN: [0 2 3 6] TEST: [1 4 5 7]
# 7 TRAIN: [1 2 4 7] TEST: [0 3 5 6]
# 7 TRAIN: [0 3 5 6] TEST: [1 2 4 7]
# 8 TRAIN: [0 3 4 6] TEST: [1 2 5 7]
# 8 TRAIN: [1 2 5 7] TEST: [0 3 4 6]
# 9 TRAIN: [1 3 6 7] TEST: [0 2 4 5]
# 9 TRAIN: [0 2 4 5] TEST: [1 3 6 7]

# %%
# score_rep = np.asarray([])
# for i in range(10):
#     score_cv = []
#     for train_index, test_index in cv.split(X, y):
#         X_train, X_test = X[train_index], X[test_index]
#         y_train, y_test = y[train_index], y[test_index]
#         clf.fit(X=X_train, y=y_train)
#         y_pred = clf.predict(X_test)
#         score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
#     score_rep = np.vstack(append(np.mean(score_cv))
# score_rep = np.asarray(score_rep)

sc_rep = np.array([])
for i in range(10):
    score_cv = []
    for j in range(5):
        x = list(np.random.rand(15))
        score_cv.append(x)
    sc_rep = np.vstack((sc_rep,np.mean(score_cv))) if np.size(sc_rep) else np.mean(score_cv)
print(sc_rep.shape)
#             score_rep = np.vstack(append(np.mean(score_cv))
#         score_rep = np.asarray(score_rep)
# Out:
# (10, 1)
