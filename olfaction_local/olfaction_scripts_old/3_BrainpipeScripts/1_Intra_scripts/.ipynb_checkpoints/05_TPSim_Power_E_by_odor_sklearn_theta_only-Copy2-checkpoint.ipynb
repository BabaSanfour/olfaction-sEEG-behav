# %% [markdown]
# ## Import Libraries

# %%
from os import path, makedirs
from itertools import product
import numpy as np
import scipy.io as sio

from brainpipe.system import study
from brainpipe.statistics import *
from utils import rename_elecs

# %% [markdown]
# ## Power Decoding - Partial//Detailed Encoding
# ### For ALL time points

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import StratifiedKFold as SKFold
from sklearn.model_selection import permutation_test_score
from sklearn.metrics import roc_auc_score
from numpy.random import permutation

st = study('Olfacto')
exp, meth = 'Enc', 'BETWEEN'#'Enc'
conds, subjects = ['low','high'],['PIRJ','FERJ','CHAF','LEFC','VACJ','SEMC']
freqs = ['theta']
path_pow = path.join(st.path, 'feature/TPSim_2groups_Enc/TPS_btw_v=1_elecs=all/')
filename = path.join(path_pow, 'TPS_pears_{}_{}_btw_{}.npz') #su cond freq
save_path = path.join(st.path, 'classified/TPSim_clf_all_theta_last_analyses/')
#su, method(global,btw,wth),exp (E,R,ER),freq
if exp == 'Enc_Ret':
    name_classif = path.join(save_path, 
            '{}_LDA_clf_'+meth+'_E_R_newscore_'+conds[0]+'_'+conds[1]+'_{}_k=5.npz')
else:
    name_classif = path.join(save_path, 
         '{}_LDA_clf_'+meth+'_'+exp[0]+'_newscore_'+conds[0]+'_'+conds[1]+'_{}_k=5.npz')
rois_to_keep = ['ACC','aHC','IFG','Ins_olf','MFG','OFC_olf','PHG','SFG','pPirT','Amg']

nperm = 1000

if not path.exists(save_path):
    makedirs(save_path)

for su,freq in product(subjects,freqs):
    #for freq in freqs:
    pow_list = []
    #=========================== Load Power files (nfreq, nelec, nwin, ntrial) =================================    
    mat0 = np.load(filename.format(su,conds[0],freq),allow_pickle=True)
    labels = mat0['label']
    x,y,z = mat0['xyz'][:,0], mat0['xyz'][:,1], mat0['xyz'][:,2]
    new_labels = rename_elecs(labels,x,y,z)
    idx_rois = np.isin(new_labels, rois_to_keep)
    
    pow_list.append(mat0['tps'][idx_rois])
    nelecs = mat0['tps'][idx_rois].shape[0]
    mat1 = np.load(filename.format(su,conds[1],freq),allow_pickle=True)
    print(mat1.files)
    pow_list.append(mat1['tps'][idx_rois])
    print (su,mat0.files, 'TPS shape: ', [pow.shape for pow in pow_list])

    #=========================== Create dict for all results =================================    
    #if not path.exists(name_classif.format(su,freq)):
    kwargs = {}
    kwargs['names'], kwargs['channels'] = new_labels[idx_rois], mat0['channel'][idx_rois]
    kwargs['xyz'] = mat0['xyz'][idx_rois]

    # =========================== Select Power for 1 elec 1 freq =================================                 
    permut,auc = np.zeros((nelecs,nperm)),np.zeros((nelecs))
    for elec_num in range(nelecs):
        print('--» processing',su, 'elec', elec_num,'/',nelecs)
        pow_data_elec = [power[elec_num][:,np.newaxis] for power in pow_list]

        # create a data matrix, concatenate along the trial dimension
        x = np.concatenate(pow_data_elec, axis=0)
        print ('Size of the concatenated data: ', x.shape)
        y = np.hstack([np.array([i]*len(power)) for i, power in enumerate(pow_data_elec)])
        print ('Size of label for classif: ', len(y))

        clf = LDA()
        cv = SKFold(5)
        score, permutation_scores, pvalue = permutation_test_score(
        clf, x, y, scoring="roc_auc", cv=cv, n_permutations=nperm, n_jobs=-1)
        permut[elec_num] += permutation_scores
        auc[elec_num] += score
        print("Classification score %s (pvalue : %s)" % (score, pvalue))

    kwargs['perm'], kwargs['auc'] = permut, auc
    #Save plots
    np.savez(name_classif.format(su,freq), **kwargs)
    del x, y, pow_data_elec, permutation_scores, score
    #else:
    #    print(name_classif.format(su,freq), 'already computed')
    del pow_list
# Out:
# -> Olfacto loaded
# ['tps', 'pval', 'label', 'channel', 'xyz']
# PIRJ ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(24, 91), (24, 55)]
# --» processing PIRJ elec 0 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.4423710792131844 (pvalue : 0.6723276723276723)
# --» processing PIRJ elec 1 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.7171185539606592 (pvalue : 0.000999000999000999)
# --» processing PIRJ elec 2 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.5563530037214248 (pvalue : 0.26673326673326675)
# --» processing PIRJ elec 3 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.7355661881977671 (pvalue : 0.000999000999000999)
# --» processing PIRJ elec 4 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.5236576289207868 (pvalue : 0.5094905094905094)
# --» processing PIRJ elec 5 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.6308346624136097 (pvalue : 0.006993006993006993)
# --» processing PIRJ elec 6 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.5338649654439129 (pvalue : 0.4225774225774226)
# --» processing PIRJ elec 7 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.5936735778841042 (pvalue : 0.08191808191808192)
# --» processing PIRJ elec 8 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.6183944710260499 (pvalue : 0.01898101898101898)
# --» processing PIRJ elec 9 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.5603934077618288 (pvalue : 0.23976023976023977)
# --» processing PIRJ elec 10 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.3536416799574694 (pvalue : 0.984015984015984)
# --» processing PIRJ elec 11 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.5807017543859649 (pvalue : 0.10989010989010989)
# --» processing PIRJ elec 12 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.43221690590111644 (pvalue : 0.7692307692307693)
# --» processing PIRJ elec 13 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.7422115895800105 (pvalue : 0.000999000999000999)
# --» processing PIRJ elec 14 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.6770866560340245 (pvalue : 0.001998001998001998)
# --» processing PIRJ elec 15 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.8000531632110579 (pvalue : 0.000999000999000999)
# --» processing PIRJ elec 16 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.43274853801169594 (pvalue : 0.7872127872127872)
# --» processing PIRJ elec 17 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.6547581073896863 (pvalue : 0.003996003996003996)
# --» processing PIRJ elec 18 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.6703880914407231 (pvalue : 0.000999000999000999)
# --» processing PIRJ elec 19 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.5943115364167996 (pvalue : 0.057942057942057944)
# --» processing PIRJ elec 20 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.5348219032429559 (pvalue : 0.4385614385614386)
# --» processing PIRJ elec 21 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.6813928761297182 (pvalue : 0.001998001998001998)
# --» processing PIRJ elec 22 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.691866028708134 (pvalue : 0.000999000999000999)
# --» processing PIRJ elec 23 / 24
# Size of the concatenated data:  (146, 1)
# Size of label for classif:  146
# Classification score 0.6314726209463051 (pvalue : 0.007992007992007992)
# ['tps', 'pval', 'label', 'channel', 'xyz']
# FERJ ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(32, 171), (32, 66)]
# --» processing FERJ elec 0 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.6655868501246653 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 1 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5887727398651768 (pvalue : 0.06593406593406594)
# --» processing FERJ elec 2 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.37365961769323114 (pvalue : 0.9660339660339661)
# --» processing FERJ elec 3 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.6120952996583249 (pvalue : 0.014985014985014986)
# --» processing FERJ elec 4 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5644122264290331 (pvalue : 0.14685314685314685)
# --» processing FERJ elec 5 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5539809770061872 (pvalue : 0.2047952047952048)
# --» processing FERJ elec 6 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5729227075445563 (pvalue : 0.0969030969030969)
# --» processing FERJ elec 7 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5682205189768215 (pvalue : 0.1038961038961039)
# --» processing FERJ elec 8 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.6127084680025857 (pvalue : 0.00999000999000999)
# --» processing FERJ elec 9 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.3698494782528396 (pvalue : 0.995004995004995)
# --» processing FERJ elec 10 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5587865915597008 (pvalue : 0.16283716283716285)
# --» processing FERJ elec 11 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5703296703296704 (pvalue : 0.07892107892107893)
# --» processing FERJ elec 12 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.7174383599593683 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 13 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.4099713731646505 (pvalue : 0.9270729270729271)
# --» processing FERJ elec 14 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5340437713546956 (pvalue : 0.4085914085914086)
# --» processing FERJ elec 15 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.6465453873857235 (pvalue : 0.001998001998001998)
# --» processing FERJ elec 16 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5550263182195955 (pvalue : 0.18581418581418582)
# --» processing FERJ elec 17 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.38849939975990394 (pvalue : 0.9760239760239761)
# --» processing FERJ elec 18 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5706085511127529 (pvalue : 0.08191808191808192)
# --» processing FERJ elec 19 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.517567642441592 (pvalue : 0.4755244755244755)
# --» processing FERJ elec 20 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5735081724997692 (pvalue : 0.0919080919080919)
# --» processing FERJ elec 21 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.4453596823344722 (pvalue : 0.7462537462537463)
# --» processing FERJ elec 22 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5384172130390618 (pvalue : 0.33466533466533466)
# --» processing FERJ elec 23 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.45675685658878934 (pvalue : 0.6843156843156843)
# --» processing FERJ elec 24 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.5684606150152368 (pvalue : 0.11488511488511488)
# --» processing FERJ elec 25 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.44958537261058273 (pvalue : 0.7812187812187812)
# --» processing FERJ elec 26 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.4565149136577709 (pvalue : 0.7302697302697303)
# --» processing FERJ elec 27 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.7094025302428664 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 28 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.6158407978576046 (pvalue : 0.012987012987012988)
# --» processing FERJ elec 29 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.3829642626281282 (pvalue : 0.974025974025974)
# --» processing FERJ elec 30 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.425206390248407 (pvalue : 0.8671328671328671)
# --» processing FERJ elec 31 / 32
# Size of the concatenated data:  (237, 1)
# Size of label for classif:  237
# Classification score 0.555816788253763 (pvalue : 0.2077922077922078)
# ['tps', 'pval', 'label', 'channel', 'xyz']
# CHAF ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(61, 15), (61, 105)]
# --» processing CHAF elec 0 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.7682539682539684 (pvalue : 0.001998001998001998)
# --» processing CHAF elec 1 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.6444444444444445 (pvalue : 0.07392607392607392)
# --» processing CHAF elec 2 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.6507936507936508 (pvalue : 0.057942057942057944)
# --» processing CHAF elec 3 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.711111111111111 (pvalue : 0.006993006993006993)
# --» processing CHAF elec 4 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.5492063492063493 (pvalue : 0.46553446553446554)
# --» processing CHAF elec 5 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.6063492063492063 (pvalue : 0.2007992007992008)
# --» processing CHAF elec 6 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.43809523809523815 (pvalue : 0.6013986013986014)
# --» processing CHAF elec 7 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.5492063492063493 (pvalue : 0.4565434565434565)
# --» processing CHAF elec 8 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.6952380952380952 (pvalue : 0.02197802197802198)
# --» processing CHAF elec 9 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.5873015873015873 (pvalue : 0.2987012987012987)
# --» processing CHAF elec 10 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.39047619047619053 (pvalue : 0.7502497502497503)
# --» processing CHAF elec 11 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.6444444444444445 (pvalue : 0.07892107892107893)
# --» processing CHAF elec 12 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.6730158730158731 (pvalue : 0.03296703296703297)
# --» processing CHAF elec 13 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.253968253968254 (pvalue : 0.98001998001998)
# --» processing CHAF elec 14 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.40634920634920635 (pvalue : 0.7352647352647352)
# --» processing CHAF elec 15 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.46984126984126995 (pvalue : 0.5044955044955045)
# --» processing CHAF elec 16 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.584126984126984 (pvalue : 0.2817182817182817)
# --» processing CHAF elec 17 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.45396825396825397 (pvalue : 0.5874125874125874)
# --» processing CHAF elec 18 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.5555555555555556 (pvalue : 0.4435564435564436)
# --» processing CHAF elec 19 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.6222222222222223 (pvalue : 0.14785214785214784)
# --» processing CHAF elec 20 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.6 (pvalue : 0.22977022977022976)
# --» processing CHAF elec 21 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.653968253968254 (pvalue : 0.06893106893106893)
# --» processing CHAF elec 22 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.47619047619047616 (pvalue : 0.5224775224775224)
# --» processing CHAF elec 23 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.6190476190476191 (pvalue : 0.15284715284715283)
# --» processing CHAF elec 24 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.3650793650793651 (pvalue : 0.8731268731268731)
# --» processing CHAF elec 25 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.6444444444444445 (pvalue : 0.09090909090909091)
# --» processing CHAF elec 26 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.40952380952380957 (pvalue : 0.7182817182817183)
# --» processing CHAF elec 27 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.6126984126984127 (pvalue : 0.17282717282717283)
# --» processing CHAF elec 28 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.46984126984126984 (pvalue : 0.5534465534465535)
# --» processing CHAF elec 29 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.7841269841269842 (pvalue : 0.001998001998001998)
# --» processing CHAF elec 30 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.5873015873015873 (pvalue : 0.2727272727272727)
# --» processing CHAF elec 31 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.3492063492063492 (pvalue : 0.913086913086913)
# --» processing CHAF elec 32 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
# Classification score 0.35238095238095235 (pvalue : 0.8911088911088911)
# --» processing CHAF elec 33 / 61
# Size of the concatenated data:  (120, 1)
# Size of label for classif:  120
