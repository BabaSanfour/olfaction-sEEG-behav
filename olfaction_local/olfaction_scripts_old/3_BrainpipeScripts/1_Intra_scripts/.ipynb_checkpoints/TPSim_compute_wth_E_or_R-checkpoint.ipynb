# %% [markdown]
# ### Compute TPSim by odor OR cond
# for Encoding OR Retrieval separately

# %%
from brainpipe.system import study
from itertools import combinations, product
import numpy as np
from os.path import join, exists
from os import makedirs
from joblib import Parallel, delayed
from scipy import stats

# %%
"""
Compute TPSim BY ODOR
"""
###############################################################################
st = study('Olfacto')
path_pow = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_odor_all_elecsFT/')
path2save = join(st.path, 'feature/TPSim_3groups_{}/by_odor_wth_v=1_elecs=all/')
pow_path = join(path_pow, '{}_odor_{}_bipo_all_{}_6freqs.npz')
savename = 'TPS_pears_{}_odor{}_wth_{}.npz'
###############################################################################
reps = ['Enc'] #Ret, Enc
for rep in reps:
    if not exists(path2save.format(rep)):
        makedirs(path2save.format(rep))
###############################################################################
#freqs = ['0_theta', '1_alpha', '2_beta','3_gamma']
freqs = ['delta','theta','alpha','beta','low_gamma','high_gamma'] # Name of each frequency
conds = ['high','low']
odors_su = {'CHAF': {5:12,7:68,8:36,9:96,1:6,2:2,3:68,4:8},
            'LEFC': {1:4,2:0,3:6,4:12,14:96,15:2,16:4,17:68},
            'PIRJ': {4:36,9:2,1:4,18:32,6:34,5:4,7:68}, #missing odor 15
            'VACJ': {14:6,15:64,16:68,17:8,10:6,11:4,12:4,13:40},
            'SEMC': {10:2,11:6,12:6,13:6,5:8,7:4,8:8,9:10},
            'FERJ': {16:6,17:6,5:8,7:6,12:8,13:8,2:6,1:10}}
to_take = [17,47]

def tpsim_by_odor(exp,su,odor,f,freq):
    mat = np.load(pow_path.format(su,odor,rep[0]),allow_pickle=True)
    pow_data = mat['xpow'][f,:,to_take[0]:to_take[1],:]
    print(su,odor,pow_data.shape)
    nelecs,npts,ntrials = pow_data.shape
    R_freq, p_freq = np.array([]), np.array([])
    for elec in range(nelecs):
        pow0 = pow_data[elec,:]
        R_trials, p_trials = np.array([]), np.array([])
        for t0, t1 in combinations(np.arange(ntrials), 2):
            R, p = stats.pearsonr(pow0[:,t0],pow0[:,t1])
            R_trials = np.vstack((R_trials,R)) if np.size(R_trials) else R
            p_trials = np.vstack((p_trials,p)) if np.size(p_trials) else p
        R_freq = np.vstack((R_freq,R_trials.T)) if np.size(R_freq) else R_trials.T
        p_freq = np.vstack((p_freq,p_trials.T)) if np.size(p_freq) else p_trials.T
        #print(R_freq.shape, p_freq.shape)
    R_freq = np.arctanh(R_freq)
    print(su,odor,freq,'R',R_freq.shape, p_freq.shape,'initial data',pow_data.shape)
    mat = {'tps':R_freq, 'pval':p_freq,'label':mat['labels'],
           'channel':mat['channels'], 'xyz':mat['xyz']}
    np.savez(path2save.format(exp)+savename.format(su,str(odor),freq),**mat)

for rep in reps:
    for su in odors_su:
        for f, freq in enumerate(freqs):
            for odor in odors_su[su]:
                tpsim_by_odor(rep,su,odor,f,freq)
#     Parallel(n_jobs=-1)(delayed(
#         tpsim_by_odor)(su,odor,freq) for odor,freq in product(odors_su[su],freqs))
# Out:
# -> Olfacto loaded
# CHAF 5 (61, 30, 1)
# CHAF 5 delta R (0,) (0,) initial data (61, 30, 1)
# CHAF 7 (61, 30, 4)
# CHAF 7 delta R (61, 6) (61, 6) initial data (61, 30, 4)
# CHAF 8 (61, 30, 3)
# CHAF 8 delta R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 9 (61, 30, 5)
# CHAF 9 delta R (61, 10) (61, 10) initial data (61, 30, 5)
# CHAF 1 (61, 30, 1)
# CHAF 1 delta R (0,) (0,) initial data (61, 30, 1)
# CHAF 2 (61, 30, 3)
# CHAF 2 delta R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 3 (61, 30, 3)
# CHAF 3 delta R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 4 (61, 30, 1)
# CHAF 4 delta R (0,) (0,) initial data (61, 30, 1)
# CHAF 5 (61, 30, 1)
# CHAF 5 theta R (0,) (0,) initial data (61, 30, 1)
# CHAF 7 (61, 30, 4)
# CHAF 7 theta R (61, 6) (61, 6) initial data (61, 30, 4)
# CHAF 8 (61, 30, 3)
# CHAF 8 theta R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 9 (61, 30, 5)
# CHAF 9 theta R (61, 10) (61, 10) initial data (61, 30, 5)
# CHAF 1 (61, 30, 1)
# CHAF 1 theta R (0,) (0,) initial data (61, 30, 1)
# CHAF 2 (61, 30, 3)
# CHAF 2 theta R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 3 (61, 30, 3)
# CHAF 3 theta R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 4 (61, 30, 1)
# CHAF 4 theta R (0,) (0,) initial data (61, 30, 1)
# CHAF 5 (61, 30, 1)
# CHAF 5 alpha R (0,) (0,) initial data (61, 30, 1)
# CHAF 7 (61, 30, 4)
# CHAF 7 alpha R (61, 6) (61, 6) initial data (61, 30, 4)
# CHAF 8 (61, 30, 3)
# CHAF 8 alpha R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 9 (61, 30, 5)
# CHAF 9 alpha R (61, 10) (61, 10) initial data (61, 30, 5)
# CHAF 1 (61, 30, 1)
# CHAF 1 alpha R (0,) (0,) initial data (61, 30, 1)
# CHAF 2 (61, 30, 3)
# CHAF 2 alpha R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 3 (61, 30, 3)
# CHAF 3 alpha R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 4 (61, 30, 1)
# CHAF 4 alpha R (0,) (0,) initial data (61, 30, 1)
# CHAF 5 (61, 30, 1)
# CHAF 5 beta R (0,) (0,) initial data (61, 30, 1)
# CHAF 7 (61, 30, 4)
# CHAF 7 beta R (61, 6) (61, 6) initial data (61, 30, 4)
# CHAF 8 (61, 30, 3)
# CHAF 8 beta R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 9 (61, 30, 5)
# CHAF 9 beta R (61, 10) (61, 10) initial data (61, 30, 5)
# CHAF 1 (61, 30, 1)
# CHAF 1 beta R (0,) (0,) initial data (61, 30, 1)
# CHAF 2 (61, 30, 3)
# CHAF 2 beta R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 3 (61, 30, 3)
# CHAF 3 beta R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 4 (61, 30, 1)
# CHAF 4 beta R (0,) (0,) initial data (61, 30, 1)
# CHAF 5 (61, 30, 1)
# CHAF 5 low_gamma R (0,) (0,) initial data (61, 30, 1)
# CHAF 7 (61, 30, 4)
# CHAF 7 low_gamma R (61, 6) (61, 6) initial data (61, 30, 4)
# CHAF 8 (61, 30, 3)
# CHAF 8 low_gamma R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 9 (61, 30, 5)
# CHAF 9 low_gamma R (61, 10) (61, 10) initial data (61, 30, 5)
# CHAF 1 (61, 30, 1)
# CHAF 1 low_gamma R (0,) (0,) initial data (61, 30, 1)
# CHAF 2 (61, 30, 3)
# CHAF 2 low_gamma R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 3 (61, 30, 3)
# CHAF 3 low_gamma R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 4 (61, 30, 1)
# CHAF 4 low_gamma R (0,) (0,) initial data (61, 30, 1)
# CHAF 5 (61, 30, 1)
# CHAF 5 high_gamma R (0,) (0,) initial data (61, 30, 1)
# CHAF 7 (61, 30, 4)
# CHAF 7 high_gamma R (61, 6) (61, 6) initial data (61, 30, 4)
# CHAF 8 (61, 30, 3)
# CHAF 8 high_gamma R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 9 (61, 30, 5)
# CHAF 9 high_gamma R (61, 10) (61, 10) initial data (61, 30, 5)
# CHAF 1 (61, 30, 1)
# CHAF 1 high_gamma R (0,) (0,) initial data (61, 30, 1)
# CHAF 2 (61, 30, 3)
# CHAF 2 high_gamma R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 3 (61, 30, 3)
# CHAF 3 high_gamma R (61, 3) (61, 3) initial data (61, 30, 3)
# CHAF 4 (61, 30, 1)
# CHAF 4 high_gamma R (0,) (0,) initial data (61, 30, 1)
# LEFC 1 (27, 30, 2)
# LEFC 1 delta R (27, 1) (27, 1) initial data (27, 30, 2)
# LEFC 2 (27, 30, 5)
# LEFC 2 delta R (27, 10) (27, 10) initial data (27, 30, 5)
# LEFC 3 (27, 30, 4)
# LEFC 3 delta R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 4 (27, 30, 4)
# LEFC 4 delta R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 14 (27, 30, 6)
# LEFC 14 delta R (27, 15) (27, 15) initial data (27, 30, 6)
# LEFC 15 (27, 30, 11)
# LEFC 15 delta R (27, 55) (27, 55) initial data (27, 30, 11)
# LEFC 16 (27, 30, 16)
# LEFC 16 delta R (27, 120) (27, 120) initial data (27, 30, 16)
# LEFC 17 (27, 30, 7)
# LEFC 17 delta R (27, 21) (27, 21) initial data (27, 30, 7)
# LEFC 1 (27, 30, 2)
# LEFC 1 theta R (27, 1) (27, 1) initial data (27, 30, 2)
# LEFC 2 (27, 30, 5)
# LEFC 2 theta R (27, 10) (27, 10) initial data (27, 30, 5)
# LEFC 3 (27, 30, 4)
# LEFC 3 theta R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 4 (27, 30, 4)
# LEFC 4 theta R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 14 (27, 30, 6)
# LEFC 14 theta R (27, 15) (27, 15) initial data (27, 30, 6)
# LEFC 15 (27, 30, 11)
# LEFC 15 theta R (27, 55) (27, 55) initial data (27, 30, 11)
# LEFC 16 (27, 30, 16)
# LEFC 16 theta R (27, 120) (27, 120) initial data (27, 30, 16)
# LEFC 17 (27, 30, 7)
# LEFC 17 theta R (27, 21) (27, 21) initial data (27, 30, 7)
# LEFC 1 (27, 30, 2)
# LEFC 1 alpha R (27, 1) (27, 1) initial data (27, 30, 2)
# LEFC 2 (27, 30, 5)
# LEFC 2 alpha R (27, 10) (27, 10) initial data (27, 30, 5)
# LEFC 3 (27, 30, 4)
# LEFC 3 alpha R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 4 (27, 30, 4)
# LEFC 4 alpha R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 14 (27, 30, 6)
# LEFC 14 alpha R (27, 15) (27, 15) initial data (27, 30, 6)
# LEFC 15 (27, 30, 11)
# LEFC 15 alpha R (27, 55) (27, 55) initial data (27, 30, 11)
# LEFC 16 (27, 30, 16)
# LEFC 16 alpha R (27, 120) (27, 120) initial data (27, 30, 16)
# LEFC 17 (27, 30, 7)
# LEFC 17 alpha R (27, 21) (27, 21) initial data (27, 30, 7)
# LEFC 1 (27, 30, 2)
# LEFC 1 beta R (27, 1) (27, 1) initial data (27, 30, 2)
# LEFC 2 (27, 30, 5)
# LEFC 2 beta R (27, 10) (27, 10) initial data (27, 30, 5)
# LEFC 3 (27, 30, 4)
# LEFC 3 beta R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 4 (27, 30, 4)
# LEFC 4 beta R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 14 (27, 30, 6)
# LEFC 14 beta R (27, 15) (27, 15) initial data (27, 30, 6)
# LEFC 15 (27, 30, 11)
# LEFC 15 beta R (27, 55) (27, 55) initial data (27, 30, 11)
# LEFC 16 (27, 30, 16)
# LEFC 16 beta R (27, 120) (27, 120) initial data (27, 30, 16)
# LEFC 17 (27, 30, 7)
# LEFC 17 beta R (27, 21) (27, 21) initial data (27, 30, 7)
# LEFC 1 (27, 30, 2)
# LEFC 1 low_gamma R (27, 1) (27, 1) initial data (27, 30, 2)
# LEFC 2 (27, 30, 5)
# LEFC 2 low_gamma R (27, 10) (27, 10) initial data (27, 30, 5)
# LEFC 3 (27, 30, 4)
# LEFC 3 low_gamma R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 4 (27, 30, 4)
# LEFC 4 low_gamma R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 14 (27, 30, 6)
# LEFC 14 low_gamma R (27, 15) (27, 15) initial data (27, 30, 6)
# LEFC 15 (27, 30, 11)
# LEFC 15 low_gamma R (27, 55) (27, 55) initial data (27, 30, 11)
# LEFC 16 (27, 30, 16)
# LEFC 16 low_gamma R (27, 120) (27, 120) initial data (27, 30, 16)
# LEFC 17 (27, 30, 7)
# LEFC 17 low_gamma R (27, 21) (27, 21) initial data (27, 30, 7)
# LEFC 1 (27, 30, 2)
# LEFC 1 high_gamma R (27, 1) (27, 1) initial data (27, 30, 2)
# LEFC 2 (27, 30, 5)
# LEFC 2 high_gamma R (27, 10) (27, 10) initial data (27, 30, 5)
# LEFC 3 (27, 30, 4)
# LEFC 3 high_gamma R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 4 (27, 30, 4)
# LEFC 4 high_gamma R (27, 6) (27, 6) initial data (27, 30, 4)
# LEFC 14 (27, 30, 6)
# LEFC 14 high_gamma R (27, 15) (27, 15) initial data (27, 30, 6)
# LEFC 15 (27, 30, 11)
# LEFC 15 high_gamma R (27, 55) (27, 55) initial data (27, 30, 11)
# LEFC 16 (27, 30, 16)
# LEFC 16 high_gamma R (27, 120) (27, 120) initial data (27, 30, 16)
# LEFC 17 (27, 30, 7)
# LEFC 17 high_gamma R (27, 21) (27, 21) initial data (27, 30, 7)
# PIRJ 4 (18, 30, 4)
# PIRJ 4 delta R (18, 6) (18, 6) initial data (18, 30, 4)
# PIRJ 9 (18, 30, 6)
# PIRJ 9 delta R (18, 15) (18, 15) initial data (18, 30, 6)
# PIRJ 1 (18, 30, 7)
# PIRJ 1 delta R (18, 21) (18, 21) initial data (18, 30, 7)
# PIRJ 18 (18, 30, 5)
# PIRJ 18 delta R (18, 10) (18, 10) initial data (18, 30, 5)
# PIRJ 6 (18, 30, 8)
# PIRJ 6 delta R (18, 28) (18, 28) initial data (18, 30, 8)
# PIRJ 5 (18, 30, 1)
# PIRJ 5 delta R (0,) (0,) initial data (18, 30, 1)
# PIRJ 7 (18, 30, 6)
# PIRJ 7 delta R (18, 15) (18, 15) initial data (18, 30, 6)
# PIRJ 4 (18, 30, 4)
# PIRJ 4 theta R (18, 6) (18, 6) initial data (18, 30, 4)
# PIRJ 9 (18, 30, 6)
# PIRJ 9 theta R (18, 15) (18, 15) initial data (18, 30, 6)
# PIRJ 1 (18, 30, 7)
# PIRJ 1 theta R (18, 21) (18, 21) initial data (18, 30, 7)
# PIRJ 18 (18, 30, 5)
# PIRJ 18 theta R (18, 10) (18, 10) initial data (18, 30, 5)
# PIRJ 6 (18, 30, 8)
# PIRJ 6 theta R (18, 28) (18, 28) initial data (18, 30, 8)
# PIRJ 5 (18, 30, 1)
# PIRJ 5 theta R (0,) (0,) initial data (18, 30, 1)
# PIRJ 7 (18, 30, 6)
# PIRJ 7 theta R (18, 15) (18, 15) initial data (18, 30, 6)
# PIRJ 4 (18, 30, 4)
# PIRJ 4 alpha R (18, 6) (18, 6) initial data (18, 30, 4)
# PIRJ 9 (18, 30, 6)
# PIRJ 9 alpha R (18, 15) (18, 15) initial data (18, 30, 6)
# PIRJ 1 (18, 30, 7)
# PIRJ 1 alpha R (18, 21) (18, 21) initial data (18, 30, 7)
# PIRJ 18 (18, 30, 5)
# PIRJ 18 alpha R (18, 10) (18, 10) initial data (18, 30, 5)
# PIRJ 6 (18, 30, 8)
# PIRJ 6 alpha R (18, 28) (18, 28) initial data (18, 30, 8)
# PIRJ 5 (18, 30, 1)
# PIRJ 5 alpha R (0,) (0,) initial data (18, 30, 1)
# PIRJ 7 (18, 30, 6)
# PIRJ 7 alpha R (18, 15) (18, 15) initial data (18, 30, 6)
# PIRJ 4 (18, 30, 4)
# PIRJ 4 beta R (18, 6) (18, 6) initial data (18, 30, 4)
# PIRJ 9 (18, 30, 6)
# PIRJ 9 beta R (18, 15) (18, 15) initial data (18, 30, 6)
# PIRJ 1 (18, 30, 7)
# PIRJ 1 beta R (18, 21) (18, 21) initial data (18, 30, 7)
# PIRJ 18 (18, 30, 5)
# PIRJ 18 beta R (18, 10) (18, 10) initial data (18, 30, 5)
# PIRJ 6 (18, 30, 8)
# PIRJ 6 beta R (18, 28) (18, 28) initial data (18, 30, 8)
# PIRJ 5 (18, 30, 1)
# PIRJ 5 beta R (0,) (0,) initial data (18, 30, 1)
# PIRJ 7 (18, 30, 6)
# PIRJ 7 beta R (18, 15) (18, 15) initial data (18, 30, 6)
# PIRJ 4 (18, 30, 4)
# PIRJ 4 low_gamma R (18, 6) (18, 6) initial data (18, 30, 4)
# PIRJ 9 (18, 30, 6)
# PIRJ 9 low_gamma R (18, 15) (18, 15) initial data (18, 30, 6)
# PIRJ 1 (18, 30, 7)
# PIRJ 1 low_gamma R (18, 21) (18, 21) initial data (18, 30, 7)
# PIRJ 18 (18, 30, 5)
# PIRJ 18 low_gamma R (18, 10) (18, 10) initial data (18, 30, 5)
# PIRJ 6 (18, 30, 8)
# PIRJ 6 low_gamma R (18, 28) (18, 28) initial data (18, 30, 8)
# PIRJ 5 (18, 30, 1)
# PIRJ 5 low_gamma R (0,) (0,) initial data (18, 30, 1)
# PIRJ 7 (18, 30, 6)
# PIRJ 7 low_gamma R (18, 15) (18, 15) initial data (18, 30, 6)
# PIRJ 4 (18, 30, 4)
# PIRJ 4 high_gamma R (18, 6) (18, 6) initial data (18, 30, 4)
# PIRJ 9 (18, 30, 6)
# PIRJ 9 high_gamma R (18, 15) (18, 15) initial data (18, 30, 6)
# PIRJ 1 (18, 30, 7)
# PIRJ 1 high_gamma R (18, 21) (18, 21) initial data (18, 30, 7)
# PIRJ 18 (18, 30, 5)
# PIRJ 18 high_gamma R (18, 10) (18, 10) initial data (18, 30, 5)
# PIRJ 6 (18, 30, 8)
# PIRJ 6 high_gamma R (18, 28) (18, 28) initial data (18, 30, 8)
# PIRJ 5 (18, 30, 1)
# PIRJ 5 high_gamma R (0,) (0,) initial data (18, 30, 1)
# PIRJ 7 (18, 30, 6)
# PIRJ 7 high_gamma R (18, 15) (18, 15) initial data (18, 30, 6)
# VACJ 14 (39, 30, 3)
# VACJ 14 delta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 15 (39, 30, 2)
# VACJ 15 delta R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 16 (39, 30, 3)
# VACJ 16 delta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 17 (39, 30, 2)
# VACJ 17 delta R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 10 (39, 30, 3)
# VACJ 10 delta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 11 (39, 30, 3)
# VACJ 11 delta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 12 (39, 30, 2)
# VACJ 12 delta R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 13 (39, 30, 4)
# VACJ 13 delta R (39, 6) (39, 6) initial data (39, 30, 4)
# VACJ 14 (39, 30, 3)
# VACJ 14 theta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 15 (39, 30, 2)
# VACJ 15 theta R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 16 (39, 30, 3)
# VACJ 16 theta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 17 (39, 30, 2)
# VACJ 17 theta R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 10 (39, 30, 3)
# VACJ 10 theta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 11 (39, 30, 3)
# VACJ 11 theta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 12 (39, 30, 2)
# VACJ 12 theta R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 13 (39, 30, 4)
# VACJ 13 theta R (39, 6) (39, 6) initial data (39, 30, 4)
# VACJ 14 (39, 30, 3)
# VACJ 14 alpha R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 15 (39, 30, 2)
# VACJ 15 alpha R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 16 (39, 30, 3)
# VACJ 16 alpha R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 17 (39, 30, 2)
# VACJ 17 alpha R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 10 (39, 30, 3)
# VACJ 10 alpha R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 11 (39, 30, 3)
# VACJ 11 alpha R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 12 (39, 30, 2)
# VACJ 12 alpha R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 13 (39, 30, 4)
# VACJ 13 alpha R (39, 6) (39, 6) initial data (39, 30, 4)
# VACJ 14 (39, 30, 3)
# VACJ 14 beta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 15 (39, 30, 2)
# VACJ 15 beta R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 16 (39, 30, 3)
# VACJ 16 beta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 17 (39, 30, 2)
# VACJ 17 beta R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 10 (39, 30, 3)
# VACJ 10 beta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 11 (39, 30, 3)
# VACJ 11 beta R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 12 (39, 30, 2)
# VACJ 12 beta R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 13 (39, 30, 4)
# VACJ 13 beta R (39, 6) (39, 6) initial data (39, 30, 4)
# VACJ 14 (39, 30, 3)
# VACJ 14 low_gamma R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 15 (39, 30, 2)
# VACJ 15 low_gamma R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 16 (39, 30, 3)
# VACJ 16 low_gamma R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 17 (39, 30, 2)
# VACJ 17 low_gamma R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 10 (39, 30, 3)
# VACJ 10 low_gamma R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 11 (39, 30, 3)
# VACJ 11 low_gamma R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 12 (39, 30, 2)
# VACJ 12 low_gamma R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 13 (39, 30, 4)
# VACJ 13 low_gamma R (39, 6) (39, 6) initial data (39, 30, 4)
# VACJ 14 (39, 30, 3)
# VACJ 14 high_gamma R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 15 (39, 30, 2)
# VACJ 15 high_gamma R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 16 (39, 30, 3)
# VACJ 16 high_gamma R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 17 (39, 30, 2)
# VACJ 17 high_gamma R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 10 (39, 30, 3)
# VACJ 10 high_gamma R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 11 (39, 30, 3)
# VACJ 11 high_gamma R (39, 3) (39, 3) initial data (39, 30, 3)
# VACJ 12 (39, 30, 2)
# VACJ 12 high_gamma R (39, 1) (39, 1) initial data (39, 30, 2)
# VACJ 13 (39, 30, 4)
# VACJ 13 high_gamma R (39, 6) (39, 6) initial data (39, 30, 4)
# SEMC 10 (53, 30, 7)
# SEMC 10 delta R (53, 21) (53, 21) initial data (53, 30, 7)
# SEMC 11 (53, 30, 4)
# SEMC 11 delta R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 12 (53, 30, 6)
# SEMC 12 delta R (53, 15) (53, 15) initial data (53, 30, 6)
# SEMC 13 (53, 30, 10)
# SEMC 13 delta R (53, 45) (53, 45) initial data (53, 30, 10)
# SEMC 5 (53, 30, 3)
# SEMC 5 delta R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 7 (53, 30, 4)
# SEMC 7 delta R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 8 (53, 30, 3)
# SEMC 8 delta R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 9 (53, 30, 3)
# SEMC 9 delta R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 10 (53, 30, 7)
# SEMC 10 theta R (53, 21) (53, 21) initial data (53, 30, 7)
# SEMC 11 (53, 30, 4)
# SEMC 11 theta R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 12 (53, 30, 6)
# SEMC 12 theta R (53, 15) (53, 15) initial data (53, 30, 6)
# SEMC 13 (53, 30, 10)
# SEMC 13 theta R (53, 45) (53, 45) initial data (53, 30, 10)
# SEMC 5 (53, 30, 3)
# SEMC 5 theta R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 7 (53, 30, 4)
# SEMC 7 theta R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 8 (53, 30, 3)
# SEMC 8 theta R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 9 (53, 30, 3)
# SEMC 9 theta R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 10 (53, 30, 7)
# SEMC 10 alpha R (53, 21) (53, 21) initial data (53, 30, 7)
# SEMC 11 (53, 30, 4)
# SEMC 11 alpha R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 12 (53, 30, 6)
# SEMC 12 alpha R (53, 15) (53, 15) initial data (53, 30, 6)
# SEMC 13 (53, 30, 10)
# SEMC 13 alpha R (53, 45) (53, 45) initial data (53, 30, 10)
# SEMC 5 (53, 30, 3)
# SEMC 5 alpha R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 7 (53, 30, 4)
# SEMC 7 alpha R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 8 (53, 30, 3)
# SEMC 8 alpha R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 9 (53, 30, 3)
# SEMC 9 alpha R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 10 (53, 30, 7)
# SEMC 10 beta R (53, 21) (53, 21) initial data (53, 30, 7)
# SEMC 11 (53, 30, 4)
# SEMC 11 beta R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 12 (53, 30, 6)
# SEMC 12 beta R (53, 15) (53, 15) initial data (53, 30, 6)
# SEMC 13 (53, 30, 10)
# SEMC 13 beta R (53, 45) (53, 45) initial data (53, 30, 10)
# SEMC 5 (53, 30, 3)
# SEMC 5 beta R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 7 (53, 30, 4)
# SEMC 7 beta R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 8 (53, 30, 3)
# SEMC 8 beta R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 9 (53, 30, 3)
# SEMC 9 beta R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 10 (53, 30, 7)
# SEMC 10 low_gamma R (53, 21) (53, 21) initial data (53, 30, 7)
# SEMC 11 (53, 30, 4)
# SEMC 11 low_gamma R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 12 (53, 30, 6)
# SEMC 12 low_gamma R (53, 15) (53, 15) initial data (53, 30, 6)
# SEMC 13 (53, 30, 10)
# SEMC 13 low_gamma R (53, 45) (53, 45) initial data (53, 30, 10)
# SEMC 5 (53, 30, 3)
# SEMC 5 low_gamma R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 7 (53, 30, 4)
# SEMC 7 low_gamma R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 8 (53, 30, 3)
# SEMC 8 low_gamma R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 9 (53, 30, 3)
# SEMC 9 low_gamma R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 10 (53, 30, 7)
# SEMC 10 high_gamma R (53, 21) (53, 21) initial data (53, 30, 7)
# SEMC 11 (53, 30, 4)
# SEMC 11 high_gamma R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 12 (53, 30, 6)
# SEMC 12 high_gamma R (53, 15) (53, 15) initial data (53, 30, 6)
# SEMC 13 (53, 30, 10)
# SEMC 13 high_gamma R (53, 45) (53, 45) initial data (53, 30, 10)
# SEMC 5 (53, 30, 3)
# SEMC 5 high_gamma R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 7 (53, 30, 4)
# SEMC 7 high_gamma R (53, 6) (53, 6) initial data (53, 30, 4)
# SEMC 8 (53, 30, 3)
# SEMC 8 high_gamma R (53, 3) (53, 3) initial data (53, 30, 3)
# SEMC 9 (53, 30, 3)
# SEMC 9 high_gamma R (53, 3) (53, 3) initial data (53, 30, 3)
# FERJ 16 (32, 30, 3)
# FERJ 16 delta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 17 (32, 30, 9)
# FERJ 17 delta R (32, 36) (32, 36) initial data (32, 30, 9)
# FERJ 5 (32, 30, 3)
# FERJ 5 delta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 7 (32, 30, 3)
# FERJ 7 delta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 12 (32, 30, 4)
# FERJ 12 delta R (32, 6) (32, 6) initial data (32, 30, 4)
# FERJ 13 (32, 30, 3)
# FERJ 13 delta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 2 (32, 30, 2)
# FERJ 2 delta R (32, 1) (32, 1) initial data (32, 30, 2)
# FERJ 1 (32, 30, 4)
# FERJ 1 delta R (32, 6) (32, 6) initial data (32, 30, 4)
# FERJ 16 (32, 30, 3)
# FERJ 16 theta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 17 (32, 30, 9)
# FERJ 17 theta R (32, 36) (32, 36) initial data (32, 30, 9)
# FERJ 5 (32, 30, 3)
# FERJ 5 theta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 7 (32, 30, 3)
# FERJ 7 theta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 12 (32, 30, 4)
# FERJ 12 theta R (32, 6) (32, 6) initial data (32, 30, 4)
# FERJ 13 (32, 30, 3)
# FERJ 13 theta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 2 (32, 30, 2)
# FERJ 2 theta R (32, 1) (32, 1) initial data (32, 30, 2)
# FERJ 1 (32, 30, 4)
# FERJ 1 theta R (32, 6) (32, 6) initial data (32, 30, 4)
# FERJ 16 (32, 30, 3)
# FERJ 16 alpha R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 17 (32, 30, 9)
# FERJ 17 alpha R (32, 36) (32, 36) initial data (32, 30, 9)
# FERJ 5 (32, 30, 3)
# FERJ 5 alpha R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 7 (32, 30, 3)
# FERJ 7 alpha R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 12 (32, 30, 4)
# FERJ 12 alpha R (32, 6) (32, 6) initial data (32, 30, 4)
# FERJ 13 (32, 30, 3)
# FERJ 13 alpha R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 2 (32, 30, 2)
# FERJ 2 alpha R (32, 1) (32, 1) initial data (32, 30, 2)
# FERJ 1 (32, 30, 4)
# FERJ 1 alpha R (32, 6) (32, 6) initial data (32, 30, 4)
# FERJ 16 (32, 30, 3)
# FERJ 16 beta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 17 (32, 30, 9)
# FERJ 17 beta R (32, 36) (32, 36) initial data (32, 30, 9)
# FERJ 5 (32, 30, 3)
# FERJ 5 beta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 7 (32, 30, 3)
# FERJ 7 beta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 12 (32, 30, 4)
# FERJ 12 beta R (32, 6) (32, 6) initial data (32, 30, 4)
# FERJ 13 (32, 30, 3)
# FERJ 13 beta R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 2 (32, 30, 2)
# FERJ 2 beta R (32, 1) (32, 1) initial data (32, 30, 2)
# FERJ 1 (32, 30, 4)
# FERJ 1 beta R (32, 6) (32, 6) initial data (32, 30, 4)
# FERJ 16 (32, 30, 3)
# FERJ 16 low_gamma R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 17 (32, 30, 9)
# FERJ 17 low_gamma R (32, 36) (32, 36) initial data (32, 30, 9)
# FERJ 5 (32, 30, 3)
# FERJ 5 low_gamma R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 7 (32, 30, 3)
# FERJ 7 low_gamma R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 12 (32, 30, 4)
# FERJ 12 low_gamma R (32, 6) (32, 6) initial data (32, 30, 4)
# FERJ 13 (32, 30, 3)
# FERJ 13 low_gamma R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 2 (32, 30, 2)
# FERJ 2 low_gamma R (32, 1) (32, 1) initial data (32, 30, 2)
# FERJ 1 (32, 30, 4)
# FERJ 1 low_gamma R (32, 6) (32, 6) initial data (32, 30, 4)
# FERJ 16 (32, 30, 3)
# FERJ 16 high_gamma R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 17 (32, 30, 9)
# FERJ 17 high_gamma R (32, 36) (32, 36) initial data (32, 30, 9)
# FERJ 5 (32, 30, 3)
# FERJ 5 high_gamma R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 7 (32, 30, 3)
# FERJ 7 high_gamma R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 12 (32, 30, 4)
# FERJ 12 high_gamma R (32, 6) (32, 6) initial data (32, 30, 4)
# FERJ 13 (32, 30, 3)
# FERJ 13 high_gamma R (32, 3) (32, 3) initial data (32, 30, 3)
# FERJ 2 (32, 30, 2)
# FERJ 2 high_gamma R (32, 1) (32, 1) initial data (32, 30, 2)
# FERJ 1 (32, 30, 4)
# FERJ 1 high_gamma R (32, 6) (32, 6) initial data (32, 30, 4)

# %%
"""
Compute TPSim BTW odors By ODOR
>>> in order to compute dissimilarity matrices OR compare WTH / BTW
"""
###############################################################################
st = study('Olfacto')
path_pow = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_odor_all_elecsFT/')
pow_path = join(path_pow, '{}_odor_{}_bipo_all_{}_6freqs.npz')
path2save = join(st.path, 'feature/TPSim_3groups_{}/by_odor_btw_v=1_elecs=all/')
tps_save = join(path2save, 'TPS_pears_{}_odor{}_btw_{}.npz')
###############################################################################
exp = 'Enc' #Ret, Enc
shortcut = ['E','R'] if exp == 'Enc_Ret' else [exp[0]]
if not exists(path2save.format(exp)):
    makedirs(path2save.format(exp))
###############################################################################
freqs = ['delta','theta', 'alpha', 'beta','low_gamma','high_gamma']
conds = ['high','low']
odors_su = {'CHAF': {5:12,7:68,8:36,9:96,1:6,2:2,3:68,4:8},
            'LEFC': {1:4,2:0,3:6,4:12,14:96,15:2,16:4,17:68},
            'PIRJ': {4:36,9:2,1:4,18:32,6:34,5:4,7:68}, #missing odor 15
            'VACJ': {14:6,15:64,16:68,17:8,10:6,11:4,12:4,13:40},
            'SEMC': {10:2,11:6,12:6,13:6,5:8,7:4,8:8,9:10},
            'FERJ': {16:6,17:6,5:8,7:6,12:8,13:8,2:6,1:10}}

def tpsim_btw_odors_by_odor(su,o1,o2,f,freq):
    """
    Compute tpsim for one odor with all other odors in list od 2
    Parameters
    ----------
    su : string (subject name)
    od1, od2 : list
        o1 of length 1 and o2 of length (n_odors - 1)
    freq : string

    Returns
    -------
    tpsim : array
        The Temporal Pattern Similarity between all odors BY odor
        (n_combinations of trials btw o1 and o2)
    """
    mat_o1 = np.load(pow_path.format(su,o1,shortcut[0]),allow_pickle=True)
    print(mat_o1.files)
    pow_o1 = mat_o1['xpow'][f,:,17:47,:] #nelecs,npts,ntrials
    pow_o2 = np.array([])
    for o in o2:
        pow_ = np.load(pow_path.format(su,o,shortcut[0],freq))['xpow'][f,:,17:47,:]
        pow_o2 = np.concatenate((pow_o2,pow_),axis=-1) if np.size(pow_o2) else pow_
    R_freq, p_freq = np.array([]), np.array([])
    for elec in range(pow_o2.shape[0]):
        pow1, pow2 = pow_o1[elec], pow_o2[elec]
        R_trials, p_trials = np.array([]), np.array([])
        for t0, t1 in product(range(pow1.shape[-1]),range(pow2.shape[-1])):
            R, p = stats.pearsonr(pow1[:,t0],pow2[:,t1])
            R_trials = np.vstack((R_trials,R)) if np.size(R_trials) else R
            p_trials = np.vstack((p_trials,p)) if np.size(p_trials) else p
        R_freq = np.vstack((R_freq,R_trials.T)) if np.size(R_freq) else R_trials.T
        p_freq = np.vstack((p_freq,p_trials.T)) if np.size(p_freq) else p_trials.T
        #print(R_freq.shape, p_freq.shape)
    R_freq = np.arctanh(R_freq)
    print(su,o1,freq,'R',R_freq.shape, p_freq.shape,
              'o1 data',pow_o1.shape, 'o2 data',pow_o2.shape)
    mat = {'tps':R_freq, 'pval':p_freq,'label':mat_o1['labels'],
           'channel':mat_o1['channels'], 'xyz':mat_o1['xyz']}
    np.savez(tps_save.format(exp,su,o1,freq),**mat)
    
for su in odors_su:
    for o1, freq in product(odors_su[su],freqs):
        f = [i for i,f in enumerate(freqs) if f == freq][0]
        o2 = [o for o in odors_su[su] if o != o1]
        tpsim_btw_odors_by_odor(su,o1,o2,f,freq)
# Out:
# -> Olfacto loaded
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 5 delta R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 5 theta R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 5 alpha R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 5 beta R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 5 low_gamma R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 5 high_gamma R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 7 delta R (61, 68) (61, 68) o1 data (61, 30, 4) o2 data (61, 30, 17)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 7 theta R (61, 68) (61, 68) o1 data (61, 30, 4) o2 data (61, 30, 17)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 7 alpha R (61, 68) (61, 68) o1 data (61, 30, 4) o2 data (61, 30, 17)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 7 beta R (61, 68) (61, 68) o1 data (61, 30, 4) o2 data (61, 30, 17)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 7 low_gamma R (61, 68) (61, 68) o1 data (61, 30, 4) o2 data (61, 30, 17)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 7 high_gamma R (61, 68) (61, 68) o1 data (61, 30, 4) o2 data (61, 30, 17)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 8 delta R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 8 theta R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 8 alpha R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 8 beta R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 8 low_gamma R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 8 high_gamma R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 9 delta R (61, 80) (61, 80) o1 data (61, 30, 5) o2 data (61, 30, 16)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 9 theta R (61, 80) (61, 80) o1 data (61, 30, 5) o2 data (61, 30, 16)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 9 alpha R (61, 80) (61, 80) o1 data (61, 30, 5) o2 data (61, 30, 16)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 9 beta R (61, 80) (61, 80) o1 data (61, 30, 5) o2 data (61, 30, 16)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 9 low_gamma R (61, 80) (61, 80) o1 data (61, 30, 5) o2 data (61, 30, 16)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 9 high_gamma R (61, 80) (61, 80) o1 data (61, 30, 5) o2 data (61, 30, 16)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 1 delta R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 1 theta R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 1 alpha R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 1 beta R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 1 low_gamma R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 1 high_gamma R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 2 delta R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 2 theta R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 2 alpha R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 2 beta R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 2 low_gamma R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 2 high_gamma R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 3 delta R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 3 theta R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 3 alpha R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 3 beta R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 3 low_gamma R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 3 high_gamma R (61, 54) (61, 54) o1 data (61, 30, 3) o2 data (61, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 4 delta R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 4 theta R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 4 alpha R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 4 beta R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 4 low_gamma R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# CHAF 4 high_gamma R (61, 20) (61, 20) o1 data (61, 30, 1) o2 data (61, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 1 delta R (27, 106) (27, 106) o1 data (27, 30, 2) o2 data (27, 30, 53)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 1 theta R (27, 106) (27, 106) o1 data (27, 30, 2) o2 data (27, 30, 53)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 1 alpha R (27, 106) (27, 106) o1 data (27, 30, 2) o2 data (27, 30, 53)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 1 beta R (27, 106) (27, 106) o1 data (27, 30, 2) o2 data (27, 30, 53)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 1 low_gamma R (27, 106) (27, 106) o1 data (27, 30, 2) o2 data (27, 30, 53)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 1 high_gamma R (27, 106) (27, 106) o1 data (27, 30, 2) o2 data (27, 30, 53)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 2 delta R (27, 250) (27, 250) o1 data (27, 30, 5) o2 data (27, 30, 50)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 2 theta R (27, 250) (27, 250) o1 data (27, 30, 5) o2 data (27, 30, 50)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 2 alpha R (27, 250) (27, 250) o1 data (27, 30, 5) o2 data (27, 30, 50)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 2 beta R (27, 250) (27, 250) o1 data (27, 30, 5) o2 data (27, 30, 50)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 2 low_gamma R (27, 250) (27, 250) o1 data (27, 30, 5) o2 data (27, 30, 50)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 2 high_gamma R (27, 250) (27, 250) o1 data (27, 30, 5) o2 data (27, 30, 50)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 3 delta R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 3 theta R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 3 alpha R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 3 beta R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 3 low_gamma R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 3 high_gamma R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 4 delta R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 4 theta R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 4 alpha R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 4 beta R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 4 low_gamma R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 4 high_gamma R (27, 204) (27, 204) o1 data (27, 30, 4) o2 data (27, 30, 51)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 14 delta R (27, 294) (27, 294) o1 data (27, 30, 6) o2 data (27, 30, 49)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 14 theta R (27, 294) (27, 294) o1 data (27, 30, 6) o2 data (27, 30, 49)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 14 alpha R (27, 294) (27, 294) o1 data (27, 30, 6) o2 data (27, 30, 49)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 14 beta R (27, 294) (27, 294) o1 data (27, 30, 6) o2 data (27, 30, 49)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 14 low_gamma R (27, 294) (27, 294) o1 data (27, 30, 6) o2 data (27, 30, 49)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 14 high_gamma R (27, 294) (27, 294) o1 data (27, 30, 6) o2 data (27, 30, 49)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 15 delta R (27, 484) (27, 484) o1 data (27, 30, 11) o2 data (27, 30, 44)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 15 theta R (27, 484) (27, 484) o1 data (27, 30, 11) o2 data (27, 30, 44)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 15 alpha R (27, 484) (27, 484) o1 data (27, 30, 11) o2 data (27, 30, 44)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 15 beta R (27, 484) (27, 484) o1 data (27, 30, 11) o2 data (27, 30, 44)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 15 low_gamma R (27, 484) (27, 484) o1 data (27, 30, 11) o2 data (27, 30, 44)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 15 high_gamma R (27, 484) (27, 484) o1 data (27, 30, 11) o2 data (27, 30, 44)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 16 delta R (27, 624) (27, 624) o1 data (27, 30, 16) o2 data (27, 30, 39)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 16 theta R (27, 624) (27, 624) o1 data (27, 30, 16) o2 data (27, 30, 39)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 16 alpha R (27, 624) (27, 624) o1 data (27, 30, 16) o2 data (27, 30, 39)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 16 beta R (27, 624) (27, 624) o1 data (27, 30, 16) o2 data (27, 30, 39)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 16 low_gamma R (27, 624) (27, 624) o1 data (27, 30, 16) o2 data (27, 30, 39)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 16 high_gamma R (27, 624) (27, 624) o1 data (27, 30, 16) o2 data (27, 30, 39)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 17 delta R (27, 336) (27, 336) o1 data (27, 30, 7) o2 data (27, 30, 48)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 17 theta R (27, 336) (27, 336) o1 data (27, 30, 7) o2 data (27, 30, 48)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 17 alpha R (27, 336) (27, 336) o1 data (27, 30, 7) o2 data (27, 30, 48)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 17 beta R (27, 336) (27, 336) o1 data (27, 30, 7) o2 data (27, 30, 48)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 17 low_gamma R (27, 336) (27, 336) o1 data (27, 30, 7) o2 data (27, 30, 48)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# LEFC 17 high_gamma R (27, 336) (27, 336) o1 data (27, 30, 7) o2 data (27, 30, 48)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 4 delta R (18, 132) (18, 132) o1 data (18, 30, 4) o2 data (18, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 4 theta R (18, 132) (18, 132) o1 data (18, 30, 4) o2 data (18, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 4 alpha R (18, 132) (18, 132) o1 data (18, 30, 4) o2 data (18, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 4 beta R (18, 132) (18, 132) o1 data (18, 30, 4) o2 data (18, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 4 low_gamma R (18, 132) (18, 132) o1 data (18, 30, 4) o2 data (18, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 4 high_gamma R (18, 132) (18, 132) o1 data (18, 30, 4) o2 data (18, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 9 delta R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 9 theta R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 9 alpha R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 9 beta R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 9 low_gamma R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 9 high_gamma R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 1 delta R (18, 210) (18, 210) o1 data (18, 30, 7) o2 data (18, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 1 theta R (18, 210) (18, 210) o1 data (18, 30, 7) o2 data (18, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 1 alpha R (18, 210) (18, 210) o1 data (18, 30, 7) o2 data (18, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 1 beta R (18, 210) (18, 210) o1 data (18, 30, 7) o2 data (18, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 1 low_gamma R (18, 210) (18, 210) o1 data (18, 30, 7) o2 data (18, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 1 high_gamma R (18, 210) (18, 210) o1 data (18, 30, 7) o2 data (18, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 18 delta R (18, 160) (18, 160) o1 data (18, 30, 5) o2 data (18, 30, 32)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 18 theta R (18, 160) (18, 160) o1 data (18, 30, 5) o2 data (18, 30, 32)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 18 alpha R (18, 160) (18, 160) o1 data (18, 30, 5) o2 data (18, 30, 32)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 18 beta R (18, 160) (18, 160) o1 data (18, 30, 5) o2 data (18, 30, 32)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 18 low_gamma R (18, 160) (18, 160) o1 data (18, 30, 5) o2 data (18, 30, 32)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 18 high_gamma R (18, 160) (18, 160) o1 data (18, 30, 5) o2 data (18, 30, 32)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 6 delta R (18, 232) (18, 232) o1 data (18, 30, 8) o2 data (18, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 6 theta R (18, 232) (18, 232) o1 data (18, 30, 8) o2 data (18, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 6 alpha R (18, 232) (18, 232) o1 data (18, 30, 8) o2 data (18, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 6 beta R (18, 232) (18, 232) o1 data (18, 30, 8) o2 data (18, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 6 low_gamma R (18, 232) (18, 232) o1 data (18, 30, 8) o2 data (18, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 6 high_gamma R (18, 232) (18, 232) o1 data (18, 30, 8) o2 data (18, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 5 delta R (18, 36) (18, 36) o1 data (18, 30, 1) o2 data (18, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 5 theta R (18, 36) (18, 36) o1 data (18, 30, 1) o2 data (18, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 5 alpha R (18, 36) (18, 36) o1 data (18, 30, 1) o2 data (18, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 5 beta R (18, 36) (18, 36) o1 data (18, 30, 1) o2 data (18, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 5 low_gamma R (18, 36) (18, 36) o1 data (18, 30, 1) o2 data (18, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 5 high_gamma R (18, 36) (18, 36) o1 data (18, 30, 1) o2 data (18, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 7 delta R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 7 theta R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 7 alpha R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 7 beta R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 7 low_gamma R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# PIRJ 7 high_gamma R (18, 186) (18, 186) o1 data (18, 30, 6) o2 data (18, 30, 31)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 14 delta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 14 theta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 14 alpha R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 14 beta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 14 low_gamma R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 14 high_gamma R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 15 delta R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 15 theta R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 15 alpha R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 15 beta R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 15 low_gamma R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 15 high_gamma R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 16 delta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 16 theta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 16 alpha R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 16 beta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 16 low_gamma R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 16 high_gamma R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 17 delta R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 17 theta R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 17 alpha R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 17 beta R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 17 low_gamma R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 17 high_gamma R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 10 delta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 10 theta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 10 alpha R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 10 beta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 10 low_gamma R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 10 high_gamma R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 11 delta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 11 theta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 11 alpha R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 11 beta R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 11 low_gamma R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 11 high_gamma R (39, 57) (39, 57) o1 data (39, 30, 3) o2 data (39, 30, 19)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 12 delta R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 12 theta R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 12 alpha R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 12 beta R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 12 low_gamma R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 12 high_gamma R (39, 40) (39, 40) o1 data (39, 30, 2) o2 data (39, 30, 20)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 13 delta R (39, 72) (39, 72) o1 data (39, 30, 4) o2 data (39, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 13 theta R (39, 72) (39, 72) o1 data (39, 30, 4) o2 data (39, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 13 alpha R (39, 72) (39, 72) o1 data (39, 30, 4) o2 data (39, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 13 beta R (39, 72) (39, 72) o1 data (39, 30, 4) o2 data (39, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 13 low_gamma R (39, 72) (39, 72) o1 data (39, 30, 4) o2 data (39, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# VACJ 13 high_gamma R (39, 72) (39, 72) o1 data (39, 30, 4) o2 data (39, 30, 18)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 10 delta R (53, 231) (53, 231) o1 data (53, 30, 7) o2 data (53, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 10 theta R (53, 231) (53, 231) o1 data (53, 30, 7) o2 data (53, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 10 alpha R (53, 231) (53, 231) o1 data (53, 30, 7) o2 data (53, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 10 beta R (53, 231) (53, 231) o1 data (53, 30, 7) o2 data (53, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 10 low_gamma R (53, 231) (53, 231) o1 data (53, 30, 7) o2 data (53, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 10 high_gamma R (53, 231) (53, 231) o1 data (53, 30, 7) o2 data (53, 30, 33)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 11 delta R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 11 theta R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 11 alpha R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 11 beta R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 11 low_gamma R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 11 high_gamma R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 12 delta R (53, 204) (53, 204) o1 data (53, 30, 6) o2 data (53, 30, 34)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 12 theta R (53, 204) (53, 204) o1 data (53, 30, 6) o2 data (53, 30, 34)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 12 alpha R (53, 204) (53, 204) o1 data (53, 30, 6) o2 data (53, 30, 34)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 12 beta R (53, 204) (53, 204) o1 data (53, 30, 6) o2 data (53, 30, 34)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 12 low_gamma R (53, 204) (53, 204) o1 data (53, 30, 6) o2 data (53, 30, 34)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 12 high_gamma R (53, 204) (53, 204) o1 data (53, 30, 6) o2 data (53, 30, 34)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 13 delta R (53, 300) (53, 300) o1 data (53, 30, 10) o2 data (53, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 13 theta R (53, 300) (53, 300) o1 data (53, 30, 10) o2 data (53, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 13 alpha R (53, 300) (53, 300) o1 data (53, 30, 10) o2 data (53, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 13 beta R (53, 300) (53, 300) o1 data (53, 30, 10) o2 data (53, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 13 low_gamma R (53, 300) (53, 300) o1 data (53, 30, 10) o2 data (53, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 13 high_gamma R (53, 300) (53, 300) o1 data (53, 30, 10) o2 data (53, 30, 30)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 5 delta R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 5 theta R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 5 alpha R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 5 beta R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 5 low_gamma R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 5 high_gamma R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 7 delta R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 7 theta R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 7 alpha R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 7 beta R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 7 low_gamma R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 7 high_gamma R (53, 144) (53, 144) o1 data (53, 30, 4) o2 data (53, 30, 36)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 8 delta R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 8 theta R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 8 alpha R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 8 beta R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 8 low_gamma R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 8 high_gamma R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 9 delta R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 9 theta R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 9 alpha R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 9 beta R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 9 low_gamma R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# SEMC 9 high_gamma R (53, 111) (53, 111) o1 data (53, 30, 3) o2 data (53, 30, 37)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 16 delta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 16 theta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 16 alpha R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 16 beta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 16 low_gamma R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 16 high_gamma R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 17 delta R (32, 198) (32, 198) o1 data (32, 30, 9) o2 data (32, 30, 22)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 17 theta R (32, 198) (32, 198) o1 data (32, 30, 9) o2 data (32, 30, 22)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 17 alpha R (32, 198) (32, 198) o1 data (32, 30, 9) o2 data (32, 30, 22)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 17 beta R (32, 198) (32, 198) o1 data (32, 30, 9) o2 data (32, 30, 22)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 17 low_gamma R (32, 198) (32, 198) o1 data (32, 30, 9) o2 data (32, 30, 22)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 17 high_gamma R (32, 198) (32, 198) o1 data (32, 30, 9) o2 data (32, 30, 22)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 5 delta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 5 theta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 5 alpha R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 5 beta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 5 low_gamma R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 5 high_gamma R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 7 delta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 7 theta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 7 alpha R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 7 beta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 7 low_gamma R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 7 high_gamma R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 12 delta R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 12 theta R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 12 alpha R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 12 beta R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 12 low_gamma R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 12 high_gamma R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 13 delta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 13 theta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 13 alpha R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 13 beta R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 13 low_gamma R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 13 high_gamma R (32, 84) (32, 84) o1 data (32, 30, 3) o2 data (32, 30, 28)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 2 delta R (32, 58) (32, 58) o1 data (32, 30, 2) o2 data (32, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 2 theta R (32, 58) (32, 58) o1 data (32, 30, 2) o2 data (32, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 2 alpha R (32, 58) (32, 58) o1 data (32, 30, 2) o2 data (32, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 2 beta R (32, 58) (32, 58) o1 data (32, 30, 2) o2 data (32, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 2 low_gamma R (32, 58) (32, 58) o1 data (32, 30, 2) o2 data (32, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 2 high_gamma R (32, 58) (32, 58) o1 data (32, 30, 2) o2 data (32, 30, 29)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 1 delta R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 1 theta R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 1 alpha R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 1 beta R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 1 low_gamma R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)
# ['f', 'split', 'width', 'step', 'time', 'fname', 'labels', 'channels', 'xyz', 'xpow', 'xpow_pval']
# FERJ 1 high_gamma R (32, 108) (32, 108) o1 data (32, 30, 4) o2 data (32, 30, 27)

# %%
"""
Compute TPSim BTW CONTEXT By ODOR
computing TPSim btw 2 lists of odors
"""
###############################################################################
st = study('Olfacto')
path_pow = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_odor/')
pow_path = join(path_pow, '{}_odor_{}_{}_6freqs.npz')
path2save = join(st.path,'feature/TPSim_3groups_{}/by_cont_{}/')
tps_save = join(path2save, 'TPS_pears_{}_odor{}_{}_{}.npz')
###############################################################################
exp = 'Enc' #Ret, Enc
methods = ['wth','btw']
shortcut = ['E','R'] if exp == 'Enc_Ret' else [exp[0],exp[0]]
###############################################################################
freqnames = ['delta','theta', 'alpha', 'beta','low_gamma','high_gamma']
freqs = ['alpha']
context_su = {'CHAF': {'M':[5,7,8,9],'F':[1,2,3,4]},
              'LEFC': {'M':[1,2,3,4],'F':[14,15,16,17]},
              'PIRJ': {'M':[4,9,1,18],'F':[6,5,7]}, #missing odor 15
              'VACJ': {'M':[14,15,16,17],'F':[10,11,12,13]},
              'SEMC': {'M':[10,11,12,13],'F':[5,7,8,9]},
              'FERJ': {'M':[16,17,5,7],'F':[12,13,2,1]},}

def tpsim_by_odor(su,o1,o2,f,freq,meth):
    """
    Compute tpsim for one odor with all other odors in list od 2
    Parameters
    ----------
    su : string (subject name)
    od1, od2 : list
        o1 of length 1 and o2 of length (n_odors - 1)
    freq : string

    Returns
    -------
    tpsim : array
        The Temporal Pattern Similarity between all odors BY odor
        (n_combinations of trials btw o1 and o2
    """
    mat_o1 = np.load(pow_path.format(su,o1,shortcut[0]),allow_pickle=True)
    pow_o1 = mat_o1['xpow'][f,:,17:47,:] #nelecs,npts,ntrials
    pow_o2 = np.array([])
    for o in o2:
        pow_ = np.load(pow_path.format(su,o,shortcut[1]))['xpow'][f,:,17:47,:]
        pow_o2 = np.concatenate((pow_o2,pow_),axis=-1) if np.size(pow_o2) else pow_
    R_freq, p_freq = np.array([]), np.array([])
    for elec in range(pow_o2.shape[0]):
        pow1, pow2 = pow_o1[elec], pow_o2[elec]
        R_trials, p_trials = np.array([]), np.array([])
        for t0, t1 in product(range(pow1.shape[-1]),range(pow2.shape[-1])):
            R, p = stats.pearsonr(pow1[:,t0],pow2[:,t1])
            R_trials = np.vstack((R_trials,R)) if np.size(R_trials) else R
            p_trials = np.vstack((p_trials,p)) if np.size(p_trials) else p
        R_freq = np.vstack((R_freq,R_trials.T)) if np.size(R_freq) else R_trials.T
        p_freq = np.vstack((p_freq,p_trials.T)) if np.size(p_freq) else p_trials.T
        #print(R_freq.shape, p_freq.shape)
    R_freq = np.arctanh(R_freq)
    print(su,o1,freq,'R',R_freq.shape, p_freq.shape,
              'o1 data',pow_o1.shape, 'o2 data',pow_o2.shape)
    mat = {'tps':R_freq, 'pval':p_freq,'label':mat_o1['labels'],
           'channel':mat_o1['channels'], 'xyz':mat_o1['xyz']}
    np.savez(tps_save.format(exp,meth,su,o1,meth,freq),**mat)

for meth in methods:
    if not exists(path2save.format(exp,meth)):
        makedirs(path2save.format(exp,meth))
    for su in context_su:
        for cont in context_su[su]:
            for o1, freq in product(context_su[su][cont],freqs):
                f = [i for i,f in enumerate(freqnames) if f == freq][0]
                if meth == 'wth':
                    o2 = [o for o in context_su[su][cont] if o != o1] #wth tps
                if meth == 'btw':
                    oth_cont = [c for c in context_su[su] if c!= cont][0]
                    o2 = context_su[su][oth_cont] #btw tps
                tpsim_by_odor(su,o1,o2,f,freq,meth)

# %%
"""
Compute TPSim BTW CONTEXT BTW SPACE
computing TPSim btw 2 lists of odors
Positions groups: (1odor by context, grouped by closest positions)
Gr1 1/5 Gr2 6/3 Gr3 7/2 Gr4 8/4
"""

###############################################################################
st = study('Olfacto')
path_pow = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_odor/')
pow_path = join(path_pow, '{}_odor_{}_{}_6freqs.npz')
path2save = join(st.path,'feature/TPSim_3groups_{}/by_pos_{}/')
tps_save = join(path2save, 'TPS_pears_{}_odor{}_{}_{}.npz')
###############################################################################
exp = 'Enc' #Ret, Enc
methods = ['wth','btw']
shortcut = ['E','R'] if exp == 'Enc_Ret' else [exp[0],exp[0]]
###############################################################################
freqnames = ['delta','theta', 'alpha', 'beta','low_gamma','high_gamma']
freqs = ['theta']
od_to_pos = {'CHAF': {'P1':[1,5],'P2':[7,3],'P3':[8,2], 'P4':[4,9]},
              'LEFC': {'P1':[14,1],'P2':[2,16],'P3':[3,15], 'P4':[4,17]},
              'PIRJ': {'P1':[6,4],'P2':[9],'P3':[1,5], 'P4':[18,7]}, #missing odor 15
              'VACJ': {'P1':[10,14],'P2':[15,12],'P3':[16,11], 'P4':[17,13]},
              'SEMC': {'P1':[5,10],'P2':[11,8],'P3':[12,7], 'P4':[13,9]},
              'FERJ': {'P1':[12,16],'P2':[17,2],'P3':[5,13], 'P4':[7,1]},}

def tpsim_by_odor(su,o1,o2,f,freq,meth):
    """
    Compute tpsim for one odor with all other odors in list od 2
    Parameters
    ----------
    su : string (subject name)
    od1, od2 : list
        o1 of length 1 and o2 of length (n_odors - 1)
    freq : string

    Returns
    -------
    tpsim : array
        The Temporal Pattern Similarity between all odors BY odor
        (n_combinations of trials btw o1 and o2
    """
    mat_o1 = np.load(pow_path.format(su,o1,shortcut[0]),allow_pickle=True)
    pow_o1 = mat_o1['xpow'][f,:,17:47,:] #nelecs,npts,ntrials
    pow_o2 = np.array([])
    for o in o2:
        pow_ = np.load(pow_path.format(su,o,shortcut[1]))['xpow'][f,:,17:47,:]
        pow_o2 = np.concatenate((pow_o2,pow_),axis=-1) if np.size(pow_o2) else pow_
    R_freq, p_freq = np.array([]), np.array([])
    for elec in range(pow_o2.shape[0]):
        pow1, pow2 = pow_o1[elec], pow_o2[elec]
        R_trials, p_trials = np.array([]), np.array([])
        for t0, t1 in product(range(pow1.shape[-1]),range(pow2.shape[-1])):
            R, p = stats.spearmanr(pow1[:,t0],pow2[:,t1])
            R_trials = np.vstack((R_trials,R)) if np.size(R_trials) else R
            p_trials = np.vstack((p_trials,p)) if np.size(p_trials) else p
        R_freq = np.vstack((R_freq,R_trials.T)) if np.size(R_freq) else R_trials.T
        p_freq = np.vstack((p_freq,p_trials.T)) if np.size(p_freq) else p_trials.T
        #print(R_freq.shape, p_freq.shape)
    R_freq = np.arctanh(R_freq)
    print(su,o1,freq,'R',R_freq.shape, p_freq.shape,
              'o1 data',pow_o1.shape, 'o2 data',pow_o2.shape)
    mat = {'tps':R_freq, 'pval':p_freq,'label':mat_o1['labels'],
           'channel':mat_o1['channels'], 'xyz':mat_o1['xyz']}
    np.savez(tps_save.format(exp,meth,su,o1,meth,freq),**mat)

for meth in methods:
    if not exists(path2save.format(exp,meth)):
        makedirs(path2save.format(exp,meth))
    for su in od_to_pos:
        for pos in od_to_pos[su]:
            for o1, freq in product(od_to_pos[su][pos],freqs):
                f = [i for i,f in enumerate(freqnames) if f == freq][0]
                if meth == 'wth':
                    o2 = [o for o in od_to_pos[su][pos] if o != o1] #wth tps
                if meth == 'btw':
                    oth_cont = [c for c in od_to_pos[su] if c!= pos]
                    o2 = np.ravel([od_to_pos[su][p] for p in oth_cont])
                tpsim_by_odor(su,o1,o2,f,freq,meth)

# %% [markdown]
# ### Distance between circles at encoding
# - Compute distances between circles
# - Create close and far-away groups for each position
# - Create link btw odors and position for each patient

# %%
from utils import pos_cirles
from itertools import combinations
from codes import num_odor_to_ref
import pandas as pd

#compute all distances between circles
p1_, p2_, dist_ = [], [], []
for p1, p2 in combinations(pos_cirles,2):
    p1_.append(p1), p2_.append(p2)
    coord1, coord2 = np.array(pos_cirles[p1]), np.array(pos_cirles[p2])
    dist = np.round(np.linalg.norm(coord1-coord2),2)
    dist_.append(dist)
data = np.concatenate((np.array(p1_)[:,np.newaxis],np.array(p2_)[:,np.newaxis],
                       np.array(dist_,dtype='float')[:,np.newaxis]),axis=1)
df = pd.DataFrame(data,columns=['Pos1','Pos2','dist'])
df = df.astype({'dist': 'float'})

#create a group of close and away circles for each place
dict_pos_dist = {}
for pos in pos_cirles:
    dict_inter = {}
    df_sel = df.loc[(df['Pos1']==pos) | (df['Pos2']==pos)].sort_values('dist',ascending=False)
    #print(df_sel)
    pos_sorted = df_sel[['Pos1']].values[:,0]+df_sel[['Pos2']].values[:,0]
    pos_sorted = [p[:2] if p[:2] != pos else p[-2:] for p in pos_sorted ]
    dict_inter['close'] = pos_sorted[-1:]
    dict_inter['far'] = pos_sorted[:1]
    dict_pos_dist[pos] = dict_inter
print(dict_pos_dist)

dict_pos_od = {}
for su in num_odor_to_ref:
    dict_pos_su = {}
    for od in num_odor_to_ref[su]:
        dict_pos_su['P'+str(num_odor_to_ref[su][od][1])] = str(od)
    dict_pos_od[su] = dict_pos_su
del dict_pos_od['MICP']
print(dict_pos_od)

# %%
"""
Compute TPSim BTW SPACE LOCATIONS
computing TPSim btw 2 lists of odors
Positions groups: (1odor by context, grouped by closest positions)
"""

###############################################################################
st = study('Olfacto')
path_pow = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_odor/')
pow_path = join(path_pow, '{}_odor_{}_{}_6freqs.npz')
path2save = join(st.path,'feature/TPSim_3groups_{}/by_pos_{}/')
tps_save = join(path2save, 'TPS_pears_{}_odor{}_{}_{}.npz')
###############################################################################
exp = 'Enc' #Ret, Enc
methods = ['wth','btw']
shortcut = ['E','R'] if exp == 'Enc_Ret' else [exp[0],exp[0]]
###############################################################################
freqnames = ['delta','theta', 'alpha', 'beta','low_gamma','high_gamma']
freq = 'alpha'
f = [i for i,f in enumerate(freqnames) if f == freq][0]

def tpsim_by_odor(su,o1,o2,f,freq,meth):
    """
    Compute tpsim for one odor with all other odors in list od 2
    Parameters
    ----------
    su : string (subject name)
    od1, od2 : list
        o1 of length 1 and o2 of length (n_odors - 1)
    freq : string

    Returns
    -------
    tpsim : array
        The Temporal Pattern Similarity between all odors BY odor
        (n_combinations of trials btw o1 and o2
    """
    mat_o1 = np.load(pow_path.format(su,o1,shortcut[0]),allow_pickle=True)
    pow_o1 = mat_o1['xpow'][f,:,17:47,:] #nelecs,npts,ntrials
    pow_o2 = np.array([])
    for o in o2:
        pow_ = np.load(pow_path.format(su,o,shortcut[1]))['xpow'][f,:,17:47,:]
        pow_o2 = np.concatenate((pow_o2,pow_),axis=-1) if np.size(pow_o2) else pow_
    R_freq, p_freq = np.array([]), np.array([])
    for elec in range(pow_o2.shape[0]):
        pow1, pow2 = pow_o1[elec], pow_o2[elec]
        R_trials, p_trials = np.array([]), np.array([])
        for t0, t1 in product(range(pow1.shape[-1]),range(pow2.shape[-1])):
            R, p = stats.spearmanr(pow1[:,t0],pow2[:,t1])
            R_trials = np.vstack((R_trials,R)) if np.size(R_trials) else R
            p_trials = np.vstack((p_trials,p)) if np.size(p_trials) else p
        R_freq = np.vstack((R_freq,R_trials.T)) if np.size(R_freq) else R_trials.T
        p_freq = np.vstack((p_freq,p_trials.T)) if np.size(p_freq) else p_trials.T
        #print(R_freq.shape, p_freq.shape)
    R_freq = np.arctanh(R_freq)
    print(su,o1,freq,'R',R_freq.shape, p_freq.shape,
              'o1 data',pow_o1.shape, 'o2 data',pow_o2.shape)
    mat = {'tps':R_freq, 'pval':p_freq,'label':mat_o1['labels'],
           'channel':mat_o1['channels'], 'xyz':mat_o1['xyz']}
    np.savez(tps_save.format(exp,meth,su,o1,meth,freq),**mat)

for meth in methods:
    if not exists(path2save.format(exp,meth)):
        makedirs(path2save.format(exp,meth))
    for su in dict_pos_od:
        for pos in dict_pos_dist:
            if su == 'PIRJ' and pos == 'P3':
                continue
            else:
                print(pos, su)
                o1 = dict_pos_od[su][pos]
                if meth == 'wth':
                    pos_list = dict_pos_dist[pos]['close']
                    if su == 'PIRJ':
                        pos_list = [p for p in pos_list if p != 'P3']
                    od_list = [dict_pos_od[su][p] for p in pos_list]
                    print(su,meth,pos,pos_list,od_list)
                if meth == 'btw':
                    pos_list = dict_pos_dist[pos]['far']
                    if su == 'PIRJ':
                        if pos not in ['P5','P6']:
                            pos_list = [p for p in pos_list if p != 'P3']
                        if pos == 'P5':
                            pos_list = ['P4']
                        if pos == 'P6':
                            pos_list = ['P2']
                    od_list = [dict_pos_od[su][p] for p in pos_list]
                    print(su,meth,pos,pos_list,od_list)
                tpsim_by_odor(su,o1,od_list,f,freq,meth)

# %%
"""
Combine TPSim files of each odor BY CONDITION
"""
from utils import odor_REC_first_3wgth as dict_
RT_type = 'RT_rec_first'#,'RT_epi_wght','RT_rec_first','RT_rec_wght','RT_epi_first
###############################################################################
st = study('Olfacto')
path_tps = join(st.path,'feature/TPSim_{}_By_Odor_By_Cond/TPS_by_odor/by_odor_wth/')
tps_file = join(path_tps, 'TPS_pears_{}_odor_{}_{}.npz')
path2save = join(st.path, 'feature/TPSim_3groups_{}_RT/TPS_wth_'+RT_type+'/')
save_file = join(path2save, 'TPS_pears_{}_{}_wth_RT_{}.npz')
###############################################################################
freqs = ['delta','theta','alpha','beta','low_gamma','high_gamma']
phases = ['Enc_Ret','Enc','Ret']
    
for su, phase in product(dict_,phases):
    if not exists(path2save.format(phase)):
        makedirs(path2save.format(phase))
    for cond in dict_[su]:
        for freq in freqs:
            concat = np.array([])
            for odor in dict_[su][cond]:
                if su == 'CHAF' and odor not in ['1','4','5'] and phase == 'Enc':
                    data = np.load(tps_file.format(phase,su,odor,freq))
                    tps = data['tps']
                    if len(tps) > 0:
                        concat = np.concatenate((concat,tps), axis=1) if np.size(concat) else tps
                if su == 'PIRJ' and odor not in ['5','6','7'] and phase == 'Enc':
                    data = np.load(tps_file.format(phase,su,odor,freq))
                    tps = data['tps']
                    if len(tps) > 0:
                        concat = np.concatenate((concat,tps), axis=1) if np.size(concat) else tps
                if su not in ['CHAF','PIRJ'] or phase != 'Enc':
                    data = np.load(tps_file.format(phase,su,odor,freq))
                    tps = data['tps']
                    if len(tps) > 0:
                        concat = np.concatenate((concat,tps), axis=1) if np.size(concat) else tps
            print(su, freq, cond, concat.shape)
            mat = {'tps':concat, 'label':data['label'],'channel':data['channel'],
                   'xyz':data['xyz']}
            np.savez(save_file.format(phase,su,cond,freq),**mat)

# %%
"""
Compute TPSim by combining all odors from each CONDITION
"""
exp, RT_type= 'Enc','RT_epi_wght' #Ret, Enc
###############################################################################
st = study('Olfacto')
path_data = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_cond_3groups_v=1_elecs=all/')
pow_file = join(path_data, '{}_odor_{}_'+exp[0]+'_6freqs.npz')
pathsave = join(st.path,'feature/TPSim_3groups_{}/TPS_btw_v=1_elecs=all/')#_'+RT_type+'/')
savename = join(pathsave,'TPS_pears_{}_{}_btw_{}.npz')
###############################################################################
if not exists(pathsave.format(exp)):
    makedirs(pathsave.format(exp))
#print('save path',path2save.format(exp))
#print('pow files',pow_file)
#############################################RT_type##################################
freqs = ['delta','theta', 'alpha', 'beta','low_gamma','high_gamma']
subjects = ['PIRJ']#,'CHAF','FERJ','VACJ','SEMC','LEFC']
conds = ['low','mid','high']
to_take = [17,47]

def tpsim_by_cond(su,cond):
    mat = np.load(pow_file.format(su,cond),allow_pickle=True)
    print(su,cond,mat['xpow'].shape)
    pow_data = mat['xpow'][:,:,to_take[0]:to_take[1],:] #3584 points 
    _,nelecs,npts,ntrials = pow_data.shape
    for f,freq in enumerate(freqs):
        data_freq = pow_data[f]
        R_freq, p_freq = np.array([]), np.array([])
        for elec in range(nelecs):
            pow0 = data_freq[elec,...]
            R_trials, p_trials = np.array([]), np.array([])
            for t0, t1 in combinations(np.arange(ntrials), 2):
                R, p = stats.pearsonr(pow0[:,t0],pow0[:,t1])
                D = 1 - R # <<<<<<< HERE TO CHANGE FOR DISTANCE COMPUTATIONS
                R_trials = np.vstack((R_trials,D)) if np.size(R_trials) else D
                p_trials = np.vstack((p_trials,p)) if np.size(p_trials) else p
            R_freq = np.vstack((R_freq,R_trials.T)) if np.size(R_freq) else R_trials.T
            p_freq = np.vstack((p_freq,p_trials.T)) if np.size(p_freq) else p_trials.T
        #R_freq = np.arctanh(R_freq)
        print(su,cond,freq,'TPSim',R_freq.shape, p_freq.shape,'initial data',pow_data.shape)
        dict_ = {'tps':R_freq, 'pval':p_freq,'label':mat['labels'],
                           'channel':mat['channels'], 'xyz':mat['xyz']}
        np.savez(savename.format(exp,su,cond,freq),**dict_)

for su,cond in product(subjects,conds):
    tpsim_by_cond(su,cond)
# Parallel(n_jobs=-1)(delayed(
#     tpsim_by_cond)(su,cond) for su,cond in product(subjects,conds))
# Out:
# -> Olfacto loaded
# PIRJ low (6, 18, 64, 14)
# PIRJ low delta TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)
# PIRJ low theta TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)
# PIRJ low alpha TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)
# PIRJ low beta TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)
# PIRJ low low_gamma TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)
# PIRJ low high_gamma TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)
# PIRJ mid (6, 18, 64, 9)
# PIRJ mid delta TPSim (18, 36) (18, 36) initial data (6, 18, 30, 9)
# PIRJ mid theta TPSim (18, 36) (18, 36) initial data (6, 18, 30, 9)
# PIRJ mid alpha TPSim (18, 36) (18, 36) initial data (6, 18, 30, 9)
# PIRJ mid beta TPSim (18, 36) (18, 36) initial data (6, 18, 30, 9)
# PIRJ mid low_gamma TPSim (18, 36) (18, 36) initial data (6, 18, 30, 9)
# PIRJ mid high_gamma TPSim (18, 36) (18, 36) initial data (6, 18, 30, 9)
# PIRJ high (6, 18, 64, 14)
# PIRJ high delta TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)
# PIRJ high theta TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)
# PIRJ high alpha TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)
# PIRJ high beta TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)
# PIRJ high low_gamma TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)
# PIRJ high high_gamma TPSim (18, 91) (18, 91) initial data (6, 18, 30, 14)

# %% [markdown]
# ### Compute similarity BTW odors through learning

# %%
from utils import odor_list_su, odor_groups_3wgth
"""
LEARNING effect
Compute TPSim for all ODORS whatever the memory perf group
ALL ODORS TOGETHER // EARLY MID LATE GROUPS OF TRIALS
"""
###############################################################################
st = study('Olfacto')
path_data = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_odor_all_elecsFT/')
pow_file = join(path_data, '{}_odor_{}_bipo_all_E_6freqs.npz')
pathsave = join(st.path,'feature/TPSim_3groups_Enc/TPS_btw_thgh_time_v=1_elecs=all/')
savename = join(pathsave,'TPS_pears_learn_{}_btw_{}_{}.npz')
###############################################################################
if not exists(pathsave.format(exp)):
    makedirs(pathsave.format(exp))
###############################################################################
freq = 'theta'
to_take = [17,47]

def tpsim_by_cond_learn(data):
    nelecs, npts, ntrials = data.shape
    ncomb = len([a for a,_ in combinations(np.arange(ntrials), 2)])
    tps_trials = np.empty((nelecs,ncomb))
    for e,elec in enumerate(range(nelecs)):
        pow0 = data[elec,...]
        c = 0
        for t0, t1 in combinations(np.arange(ntrials), 2):
            tps_trials[e,c], _ = stats.pearsonr(pow0[:,t0],pow0[:,t1])
            c += 1
    tps_trials = 1 - np.arctanh(tps_trials)
    return tps_trials

for su in odor_list_su('Enc'):
    early_t, mid_t, late_t = [], [], []
    for od in odor_list_su('Enc')[su]:
        mat = np.load(pow_file.format(su,od),allow_pickle=True)
        pow_ = mat['xpow'][1,:,to_take[0]:to_take[1],:]
        thr = int(pow_.shape[-1]/3)
        print(pow_.shape,thr)
        if thr == 0:
            if pow_.shape[-1] >= 1:
                early_t.append(pow_[...,:thr+1])
            if pow_.shape[-1] == 2:
                mid_t.append(pow_[...,thr+1:])
        if thr >= 1:
            #if pow_.shape[-1] == 4:
            #    early_t.append(pow_[...,:thr])
            #    mid_t.append(pow_[...,thr:3])
            #    late_t.append(pow_[...,3:])
            #if pow_.shape[-1] == 5:
            #    early_t.append(pow_[...,:2])
            #    mid_t.append(pow_[...,2:4])
            #    late_t.append(pow_[...,4:])
            #if (pow_.shape[-1] >= 6) or (pow_.shape[-1]==3):
            early_t.append(pow_[...,:thr])
            mid_t.append(pow_[...,thr:(2*thr)])
            late_t.append(pow_[...,(2*thr):])
    print('early odors list', [x.shape for x in early_t])
    print('mid odors list', [x.shape for x in mid_t])
    print('late odors list', [x.shape for x in late_t])

    concat_E = np.concatenate(early_t, axis=-1)
    concat_M = np.concatenate(mid_t, axis=-1)
    concat_L = np.concatenate(late_t, axis=-1)
    tps_E = tpsim_by_cond_learn(concat_E)
    tps_M = tpsim_by_cond_learn(concat_M)
    tps_L = tpsim_by_cond_learn(concat_L)
    
    dict_t = {}
    dict_t['tps_0'], dict_t['tps_1'], dict_t['tps_2'] = tps_E, tps_M, tps_L
    dict_t['label'], dict_t['channel'], dict_t['xyz'] = mat['labels'],mat['channels'], mat['xyz']
    np.savez(savename.format(su,freq,'3gr'),**dict_t)
# Out:
# -> Olfacto loaded
# (61, 30, 4) 1
# (61, 30, 3) 1
# (61, 30, 5) 1
# (61, 30, 3) 1
# (61, 30, 3) 1
# early odors list [(61, 30, 1), (61, 30, 1), (61, 30, 1), (61, 30, 1), (61, 30, 1)]
# mid odors list [(61, 30, 1), (61, 30, 1), (61, 30, 1), (61, 30, 1), (61, 30, 1)]
# late odors list [(61, 30, 2), (61, 30, 1), (61, 30, 3), (61, 30, 1), (61, 30, 1)]
# (27, 30, 2) 0
# (27, 30, 5) 1
# (27, 30, 4) 1
# (27, 30, 4) 1
# (27, 30, 6) 2
# (27, 30, 11) 3
# (27, 30, 16) 5
# (27, 30, 7) 2
# early odors list [(27, 30, 1), (27, 30, 1), (27, 30, 1), (27, 30, 1), (27, 30, 2), (27, 30, 3), (27, 30, 5), (27, 30, 2)]
# mid odors list [(27, 30, 1), (27, 30, 1), (27, 30, 1), (27, 30, 1), (27, 30, 2), (27, 30, 3), (27, 30, 5), (27, 30, 2)]
# late odors list [(27, 30, 3), (27, 30, 2), (27, 30, 2), (27, 30, 2), (27, 30, 5), (27, 30, 6), (27, 30, 3)]
# (18, 30, 4) 1
# (18, 30, 6) 2
# (18, 30, 7) 2
# (18, 30, 5) 1
# early odors list [(18, 30, 1), (18, 30, 2), (18, 30, 2), (18, 30, 1)]
# mid odors list [(18, 30, 1), (18, 30, 2), (18, 30, 2), (18, 30, 1)]
# late odors list [(18, 30, 2), (18, 30, 2), (18, 30, 3), (18, 30, 3)]
# (39, 30, 3) 1
# (39, 30, 2) 0
# (39, 30, 3) 1
# (39, 30, 2) 0
# (39, 30, 3) 1
# (39, 30, 3) 1
# (39, 30, 2) 0
# (39, 30, 4) 1
# early odors list [(39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1)]
# mid odors list [(39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1)]
# late odors list [(39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 2)]
# (53, 30, 7) 2
# (53, 30, 4) 1
# (53, 30, 6) 2
# (53, 30, 10) 3
# (53, 30, 3) 1
# (53, 30, 4) 1
# (53, 30, 3) 1
# (53, 30, 3) 1
# early odors list [(53, 30, 2), (53, 30, 1), (53, 30, 2), (53, 30, 3), (53, 30, 1), (53, 30, 1), (53, 30, 1), (53, 30, 1)]
# mid odors list [(53, 30, 2), (53, 30, 1), (53, 30, 2), (53, 30, 3), (53, 30, 1), (53, 30, 1), (53, 30, 1), (53, 30, 1)]
# late odors list [(53, 30, 3), (53, 30, 2), (53, 30, 2), (53, 30, 4), (53, 30, 1), (53, 30, 2), (53, 30, 1), (53, 30, 1)]
# (32, 30, 3) 1
# (32, 30, 9) 3
# (32, 30, 3) 1
# (32, 30, 3) 1
# (32, 30, 4) 1
# (32, 30, 3) 1
# (32, 30, 2) 0
# (32, 30, 4) 1
# early odors list [(32, 30, 1), (32, 30, 3), (32, 30, 1), (32, 30, 1), (32, 30, 1), (32, 30, 1), (32, 30, 1), (32, 30, 1)]
# mid odors list [(32, 30, 1), (32, 30, 3), (32, 30, 1), (32, 30, 1), (32, 30, 1), (32, 30, 1), (32, 30, 1), (32, 30, 1)]
# late odors list [(32, 30, 1), (32, 30, 3), (32, 30, 1), (32, 30, 1), (32, 30, 2), (32, 30, 1), (32, 30, 2)]

# %%
from utils import odor_list_su, odor_groups_3wgth
"""
LEARNING effect
Compute TPSim for all ODORS whatever the memory perf group
ALL ODORS TOGETHER // EARLY AND LATE GROUPS OF TRIALS
"""
###############################################################################
st = study('Olfacto')
conds = ['low','mid','high']
path_data = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_odor_all_elecsFT/')
pow_file = join(path_data, '{}_odor_{}_bipo_all_E_6freqs.npz')
pathsave = join(st.path,'feature/TPSim_3groups_Enc/TPS_btw_thgh_time_v=1_elecs=all/')
savename = join(pathsave,'TPS_pears_learn_{}_btw_{}_{}.npz')
###############################################################################
if not exists(pathsave.format(exp)):
    makedirs(pathsave.format(exp))
###############################################################################
freq = 'theta'
to_take = [17,47]

def tpsim_by_cond_learn(data):
    nelecs, npts, ntrials = data.shape
    ncomb = len([a for a,_ in combinations(np.arange(ntrials), 2)])
    tps_trials = np.empty((nelecs,ncomb))
    for e,elec in enumerate(range(nelecs)):
        pow0 = data[elec,...]
        c = 0
        for t0, t1 in combinations(np.arange(ntrials), 2):
            tps_trials[e,c], _ = stats.pearsonr(pow0[:,t0],pow0[:,t1])
            c += 1
    tps_trials = 1 - np.arctanh(tps_trials)
    return tps_trials

for su in odor_list_su('Enc'):
    early_t, late_t = [], []
    for od in odor_list_su('Enc')[su]:
        mat = np.load(pow_file.format(su,od),allow_pickle=True)
        pow_ = mat['xpow'][1,:,to_take[0]:to_take[1],:]
        thr = int(pow_.shape[-1]/2)
        if thr == 0:
            early_t.append(pow_[...,:thr+1])
        else:
            early_t.append(pow_[...,:thr]), late_t.append(pow_[...,thr:])
    print('early odors list', [x.shape for x in early_t])
    print('late odors list', [x.shape for x in late_t])

    concat_E = np.concatenate(early_t, axis=-1)
    concat_L = np.concatenate(late_t, axis=-1)
    tps_E = tpsim_by_cond_learn(concat_E)
    tps_L = tpsim_by_cond_learn(concat_L)
    
    dict_t = {}
    dict_t['tps_0'], dict_t['tps_1'] = tps_E, tps_L
    dict_t['label'], dict_t['channel'], dict_t['xyz'] = mat['labels'],mat['channels'], mat['xyz']
    np.savez(savename.format(su,freq,'2gr'),**dict_t)
# Out:
# -> Olfacto loaded
# early odors list [(61, 30, 2), (61, 30, 1), (61, 30, 2), (61, 30, 1), (61, 30, 1)]
# late odors list [(61, 30, 2), (61, 30, 2), (61, 30, 3), (61, 30, 2), (61, 30, 2)]
# early odors list [(27, 30, 1), (27, 30, 2), (27, 30, 2), (27, 30, 2), (27, 30, 3), (27, 30, 5), (27, 30, 8), (27, 30, 3)]
# late odors list [(27, 30, 1), (27, 30, 3), (27, 30, 2), (27, 30, 2), (27, 30, 3), (27, 30, 6), (27, 30, 8), (27, 30, 4)]
# early odors list [(18, 30, 2), (18, 30, 3), (18, 30, 3), (18, 30, 2)]
# late odors list [(18, 30, 2), (18, 30, 3), (18, 30, 4), (18, 30, 3)]
# early odors list [(39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 1), (39, 30, 2)]
# late odors list [(39, 30, 2), (39, 30, 1), (39, 30, 2), (39, 30, 1), (39, 30, 2), (39, 30, 2), (39, 30, 1), (39, 30, 2)]
# early odors list [(53, 30, 3), (53, 30, 2), (53, 30, 3), (53, 30, 5), (53, 30, 1), (53, 30, 2), (53, 30, 1), (53, 30, 1)]
# late odors list [(53, 30, 4), (53, 30, 2), (53, 30, 3), (53, 30, 5), (53, 30, 2), (53, 30, 2), (53, 30, 2), (53, 30, 2)]
# early odors list [(32, 30, 1), (32, 30, 4), (32, 30, 1), (32, 30, 1), (32, 30, 2), (32, 30, 1), (32, 30, 1), (32, 30, 2)]
# late odors list [(32, 30, 2), (32, 30, 5), (32, 30, 2), (32, 30, 2), (32, 30, 2), (32, 30, 2), (32, 30, 1), (32, 30, 2)]

# %%
from utils import odor_list_su, odor_groups_3wgth
"""
LEARNING effect for WITHIN COMPARISONS
Compute TPSim for all ODORS whatever the memory perf group 
ALL ODORS TOGETHER // EARLY AND LATE GROUPS OF TRIALS
"""
###############################################################################
st = study('Olfacto')
path_data = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_odor_all_elecsFT/')
pow_file = join(path_data, '{}_odor_{}_bipo_all_E_6freqs.npz')
pathsave = join(st.path,'feature/TPSim_3groups_Enc/by_odor_wth_thgh_time_v=1_elecs=all/')
savename = join(pathsave,'TPS_pears_learn_{}_wth_{}_{}.npz')
###############################################################################
f,freq = 1,'theta'
to_take = [17,47]
reps = ['Enc'] #Ret, Enc
for rep in reps:
    if not exists(pathsave.format(rep)):
        makedirs(pathsave.format(rep))

odors_su = {'CHAF': {5:12,7:68,8:36,9:96,1:6,2:2,3:68,4:8},
            'LEFC': {1:4,2:0,3:6,4:12,14:96,15:2,16:4,17:68},
            'PIRJ': {4:36,9:2,1:4,18:32,6:34,5:4,7:68}, #missing odor 15
            'VACJ': {14:6,15:64,16:68,17:8,10:6,11:4,12:4,13:40},
            'SEMC': {10:2,11:6,12:6,13:6,5:8,7:4,8:8,9:10},
            'FERJ': {16:6,17:6,5:8,7:6,12:8,13:8,2:6,1:10}}

def tpsim_by_odor(data):
    nelecs,npts,ntrials = data.shape
    tps_wth = np.array([])
    for elec in range(nelecs):
        pow0 = data[elec,:]
        tps_trials = np.array([])
        for t0, t1 in combinations(np.arange(ntrials), 2):
            R, _ = stats.pearsonr(pow0[:,t0],pow0[:,t1])
            tps_trials = np.vstack((tps_trials,R)) if np.size(tps_trials) else R
        tps_wth = np.vstack((tps_wth,tps_trials.T)) if np.size(tps_wth) else tps_trials.T
    #tps_wth = np.arctanh(tps_wth)
    print(su,odor,freq,'R',tps_wth.shape, 'initial data',data.shape)
    return tps_wth

def compute_save_tpsim_wth_step(exp,su,odor,f,freq):
    mat = np.load(pow_path.format(su,odor,rep[0]),allow_pickle=True)
    pow_data = mat['xpow'][f,:,to_take[0]:to_take[1],:]
    print(su,odor,pow_data.shape)
    
    #separate data in two groups
    thr = int(pow_data.shape[-1]/2)
    if thr != 0:
        tps_E = tpsim_by_odor(pow_data[...,:thr])
        tps_L = tpsim_by_odor(pow_data[...,thr:])
    
        dict_t = {}
        dict_t['tps_0'], dict_t['tps_1'] = tps_E, tps_L
        dict_t['label'], dict_t['channel'], dict_t['xyz'] = mat['labels'],mat['channels'], mat['xyz']
        np.savez(savename.format(su,freq,'2gr'),**dict_t)

for rep in reps:
    for su in odors_su:
        for odor in odors_su[su]:
            compute_save_tpsim_wth_step(rep,su,odor,f,freq)
# Out:
# -> Olfacto loaded
# CHAF 5 (61, 30, 1)
# CHAF 7 (61, 30, 4)
# CHAF 7 theta R (61, 1) initial data (61, 30, 2)
# CHAF 7 theta R (61, 1) initial data (61, 30, 2)
# CHAF 8 (61, 30, 3)
# CHAF 8 theta R (0,) initial data (61, 30, 1)
# CHAF 8 theta R (61, 1) initial data (61, 30, 2)
# CHAF 9 (61, 30, 5)
# CHAF 9 theta R (61, 1) initial data (61, 30, 2)
# CHAF 9 theta R (61, 3) initial data (61, 30, 3)
# CHAF 1 (61, 30, 1)
# CHAF 2 (61, 30, 3)
# CHAF 2 theta R (0,) initial data (61, 30, 1)
# CHAF 2 theta R (61, 1) initial data (61, 30, 2)
# CHAF 3 (61, 30, 3)
# CHAF 3 theta R (0,) initial data (61, 30, 1)
# CHAF 3 theta R (61, 1) initial data (61, 30, 2)
# CHAF 4 (61, 30, 1)
# LEFC 1 (27, 30, 2)
# LEFC 1 theta R (0,) initial data (27, 30, 1)
# LEFC 1 theta R (0,) initial data (27, 30, 1)
# LEFC 2 (27, 30, 5)
# LEFC 2 theta R (27, 1) initial data (27, 30, 2)
# LEFC 2 theta R (27, 3) initial data (27, 30, 3)
# LEFC 3 (27, 30, 4)
# LEFC 3 theta R (27, 1) initial data (27, 30, 2)
# LEFC 3 theta R (27, 1) initial data (27, 30, 2)
# LEFC 4 (27, 30, 4)
# LEFC 4 theta R (27, 1) initial data (27, 30, 2)
# LEFC 4 theta R (27, 1) initial data (27, 30, 2)
# LEFC 14 (27, 30, 6)
# LEFC 14 theta R (27, 3) initial data (27, 30, 3)
# LEFC 14 theta R (27, 3) initial data (27, 30, 3)
# LEFC 15 (27, 30, 11)
# LEFC 15 theta R (27, 10) initial data (27, 30, 5)
# LEFC 15 theta R (27, 15) initial data (27, 30, 6)
# LEFC 16 (27, 30, 16)
# LEFC 16 theta R (27, 28) initial data (27, 30, 8)
# LEFC 16 theta R (27, 28) initial data (27, 30, 8)
# LEFC 17 (27, 30, 7)
# LEFC 17 theta R (27, 3) initial data (27, 30, 3)
# LEFC 17 theta R (27, 6) initial data (27, 30, 4)
# PIRJ 4 (18, 30, 4)
# PIRJ 4 theta R (18, 1) initial data (18, 30, 2)
# PIRJ 4 theta R (18, 1) initial data (18, 30, 2)
# PIRJ 9 (18, 30, 6)
# PIRJ 9 theta R (18, 3) initial data (18, 30, 3)
# PIRJ 9 theta R (18, 3) initial data (18, 30, 3)
# PIRJ 1 (18, 30, 7)
# PIRJ 1 theta R (18, 3) initial data (18, 30, 3)
# PIRJ 1 theta R (18, 6) initial data (18, 30, 4)
# PIRJ 18 (18, 30, 5)
# PIRJ 18 theta R (18, 1) initial data (18, 30, 2)
# PIRJ 18 theta R (18, 3) initial data (18, 30, 3)
# PIRJ 6 (18, 30, 8)
# PIRJ 6 theta R (18, 6) initial data (18, 30, 4)
# PIRJ 6 theta R (18, 6) initial data (18, 30, 4)
# PIRJ 5 (18, 30, 1)
# PIRJ 7 (18, 30, 6)
# PIRJ 7 theta R (18, 3) initial data (18, 30, 3)
# PIRJ 7 theta R (18, 3) initial data (18, 30, 3)
# VACJ 14 (39, 30, 3)
# VACJ 14 theta R (0,) initial data (39, 30, 1)
# VACJ 14 theta R (39, 1) initial data (39, 30, 2)
# VACJ 15 (39, 30, 2)
# VACJ 15 theta R (0,) initial data (39, 30, 1)
# VACJ 15 theta R (0,) initial data (39, 30, 1)
# VACJ 16 (39, 30, 3)
# VACJ 16 theta R (0,) initial data (39, 30, 1)
# VACJ 16 theta R (39, 1) initial data (39, 30, 2)
# VACJ 17 (39, 30, 2)
# VACJ 17 theta R (0,) initial data (39, 30, 1)
# VACJ 17 theta R (0,) initial data (39, 30, 1)
# VACJ 10 (39, 30, 3)
# VACJ 10 theta R (0,) initial data (39, 30, 1)
# VACJ 10 theta R (39, 1) initial data (39, 30, 2)
# VACJ 11 (39, 30, 3)
# VACJ 11 theta R (0,) initial data (39, 30, 1)
# VACJ 11 theta R (39, 1) initial data (39, 30, 2)
# VACJ 12 (39, 30, 2)
# VACJ 12 theta R (0,) initial data (39, 30, 1)
# VACJ 12 theta R (0,) initial data (39, 30, 1)
# VACJ 13 (39, 30, 4)
# VACJ 13 theta R (39, 1) initial data (39, 30, 2)
# VACJ 13 theta R (39, 1) initial data (39, 30, 2)
# SEMC 10 (53, 30, 7)
# SEMC 10 theta R (53, 3) initial data (53, 30, 3)
# SEMC 10 theta R (53, 6) initial data (53, 30, 4)
# SEMC 11 (53, 30, 4)
# SEMC 11 theta R (53, 1) initial data (53, 30, 2)
# SEMC 11 theta R (53, 1) initial data (53, 30, 2)
# SEMC 12 (53, 30, 6)
# SEMC 12 theta R (53, 3) initial data (53, 30, 3)
# SEMC 12 theta R (53, 3) initial data (53, 30, 3)
# SEMC 13 (53, 30, 10)
# SEMC 13 theta R (53, 10) initial data (53, 30, 5)
# SEMC 13 theta R (53, 10) initial data (53, 30, 5)
# SEMC 5 (53, 30, 3)
# SEMC 5 theta R (0,) initial data (53, 30, 1)
# SEMC 5 theta R (53, 1) initial data (53, 30, 2)
# SEMC 7 (53, 30, 4)
# SEMC 7 theta R (53, 1) initial data (53, 30, 2)
# SEMC 7 theta R (53, 1) initial data (53, 30, 2)
# SEMC 8 (53, 30, 3)
# SEMC 8 theta R (0,) initial data (53, 30, 1)
# SEMC 8 theta R (53, 1) initial data (53, 30, 2)
# SEMC 9 (53, 30, 3)
# SEMC 9 theta R (0,) initial data (53, 30, 1)
# SEMC 9 theta R (53, 1) initial data (53, 30, 2)
# FERJ 16 (32, 30, 3)
# FERJ 16 theta R (0,) initial data (32, 30, 1)
# FERJ 16 theta R (32, 1) initial data (32, 30, 2)
# FERJ 17 (32, 30, 9)
# FERJ 17 theta R (32, 6) initial data (32, 30, 4)
# FERJ 17 theta R (32, 10) initial data (32, 30, 5)
# FERJ 5 (32, 30, 3)
# FERJ 5 theta R (0,) initial data (32, 30, 1)
# FERJ 5 theta R (32, 1) initial data (32, 30, 2)
# FERJ 7 (32, 30, 3)
# FERJ 7 theta R (0,) initial data (32, 30, 1)
# FERJ 7 theta R (32, 1) initial data (32, 30, 2)
# FERJ 12 (32, 30, 4)
# FERJ 12 theta R (32, 1) initial data (32, 30, 2)
# FERJ 12 theta R (32, 1) initial data (32, 30, 2)
# FERJ 13 (32, 30, 3)
# FERJ 13 theta R (0,) initial data (32, 30, 1)
# FERJ 13 theta R (32, 1) initial data (32, 30, 2)
# FERJ 2 (32, 30, 2)
# FERJ 2 theta R (0,) initial data (32, 30, 1)
# FERJ 2 theta R (0,) initial data (32, 30, 1)
# FERJ 1 (32, 30, 4)
# FERJ 1 theta R (32, 1) initial data (32, 30, 2)
# FERJ 1 theta R (32, 1) initial data (32, 30, 2)

# %%
from utils import odor_list_su, odor_groups_3wgth
"""
LEARNING effect for BETWEEN COMPARISONS
Compute TPSim for all ODORS whatever the memory perf group 
ALL ODORS TOGETHER // EARLY AND LATE GROUPS OF TRIALS
"""
###############################################################################
st = study('Olfacto')
path_data = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_odor_all_elecsFT/')
pow_file = join(path_data, '{}_odor_{}_bipo_all_E_6freqs.npz')
pathsave = join(st.path,'feature/TPSim_3groups_Enc/by_odor_btw_thgh_time_v=1_elecs=all/')
savename = join(pathsave,'TPS_pears_learn_{}_wth_{}_{}.npz')
###############################################################################
f,freq = 1,'theta'
to_take = [17,47]
reps = ['Enc'] #Ret, Enc
for rep in reps:
    if not exists(pathsave.format(rep)):
        makedirs(pathsave.format(rep))

odors_su = {'CHAF': {5:12,7:68,8:36,9:96,1:6,2:2,3:68,4:8},
            'LEFC': {1:4,2:0,3:6,4:12,14:96,15:2,16:4,17:68},
            'PIRJ': {4:36,9:2,1:4,18:32,6:34,5:4,7:68}, #missing odor 15
            'VACJ': {14:6,15:64,16:68,17:8,10:6,11:4,12:4,13:40},
            'SEMC': {10:2,11:6,12:6,13:6,5:8,7:4,8:8,9:10},
            'FERJ': {16:6,17:6,5:8,7:6,12:8,13:8,2:6,1:10}}

def tpsim_by_odor(data):
    nelecs,npts,ntrials = data.shape
    tps_wth = np.array([])
    for elec in range(nelecs):
        pow0 = data[elec,:]
        tps_trials = np.array([])
        for t0, t1 in combinations(np.arange(ntrials), 2):
            R, _ = stats.pearsonr(pow0[:,t0],pow0[:,t1])
            tps_trials = np.vstack((tps_trials,R)) if np.size(tps_trials) else R
        tps_wth = np.vstack((tps_wth,tps_trials.T)) if np.size(tps_wth) else tps_trials.T
    #tps_wth = np.arctanh(tps_wth)
    print(su,odor,freq,'R',tps_wth.shape, 'initial data',data.shape)
    return tps_wth

def separate_2gr(pow_data):
    thr = int(pow_data.shape[-1]/2)
    all_files = []
    if thr == 0:
        all_files.append(pow_data)
    if thr != 0:
        all_files.append(pow_data[...,:thr])
        all_files.append(pow_data[...,thr:])
    return all_files

for rep in reps:
    for su in odors_su:
        for o1 in odors_su[su]:
            o2 = [o for o in odors_su[su] if o != o1]
            mat_o1 = np.load(pow_path.format(su,o1,exp[0]),allow_pickle=True)
            pow_o1 = mat_o1['xpow'][f,:,17:47,:] #nelecs,npts,ntrials
            pow_o2 = np.array([])
            for o in o2:
                pow_ = np.load(pow_path.format(su,o,shortcut[0],freq))['xpow'][f,:,17:47,:]
                pow_o2 = np.concatenate((pow_o2,pow_),axis=-1) if np.size(pow_o2) else pow_
            tpsim_btw_odors_by_odor(su,o1,o2,f,freq)

# %%
def tpsim_btw_odors_by_odor(su,o1,o2,f,freq):
    """
    Compute tpsim for one odor with all other odors in list od 2
    Parameters
    ----------
    su : string (subject name)
    od1, od2 : list
        o1 of length 1 and o2 of length (n_odors - 1)
    freq : string

    Returns
    -------
    tpsim : array
        The Temporal Pattern Similarity between all odors BY odor
        (n_combinations of trials btw o1 and o2)
    """
    
    R_freq, p_freq = np.array([]), np.array([])
    for elec in range(pow_o2.shape[0]):
        pow1, pow2 = pow_o1[elec], pow_o2[elec]
        R_trials, p_trials = np.array([]), np.array([])
        for t0, t1 in product(range(pow1.shape[-1]),range(pow2.shape[-1])):
            R, p = stats.pearsonr(pow1[:,t0],pow2[:,t1])
            R_trials = np.vstack((R_trials,R)) if np.size(R_trials) else R
            p_trials = np.vstack((p_trials,p)) if np.size(p_trials) else p
        R_freq = np.vstack((R_freq,R_trials.T)) if np.size(R_freq) else R_trials.T
        p_freq = np.vstack((p_freq,p_trials.T)) if np.size(p_freq) else p_trials.T
        #print(R_freq.shape, p_freq.shape)
    R_freq = np.arctanh(R_freq)
    print(su,o1,freq,'R',R_freq.shape, p_freq.shape,
              'o1 data',pow_o1.shape, 'o2 data',pow_o2.shape)
    mat = {'tps':R_freq, 'pval':p_freq,'label':mat_o1['labels'],
           'channel':mat_o1['channels'], 'xyz':mat_o1['xyz']}
    np.savez(tps_save.format(exp,su,o1,freq),**mat)

# %%
from utils import odor_list_su, odor_groups_3wgth
"""
LEARNING effect
Compute TPSim for all ODORS BY memory perf group
EARLY AND LATE GROUPS OF TRIALS
"""
###############################################################################
st = study('Olfacto')
conds,exp = ['low','mid','high'],'Enc'
path_data = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_cond_3groups_v=1_elecs=all/')
pow_file = join(path_data, '{}_odor_{}_E_6freqs.npz')
pathsave = join(st.path,'feature/TPSim_3groups_Enc/TPS_btw_thgh_time_v=1_elecs=all/')
savename = join(pathsave,'TPS_pears_learn_{}_btw_{}_{}_{}.npz')
###############################################################################
if not exists(pathsave.format(exp)):
    makedirs(pathsave.format(exp))
###############################################################################
freq, meth = 'theta', '2gr' #groups here refer to time groups early late
to_take = [17,47]

def tpsim_by_cond_learn(data):
    nelecs, npts, ntrials = data.shape
    ncomb = len([a for a,_ in combinations(np.arange(ntrials), 2)])
    tps_trials = np.empty((nelecs,ncomb))
    for e,elec in enumerate(range(nelecs)):
        pow0 = data[elec,...]
        c = 0
        for t0, t1 in combinations(np.arange(ntrials), 2):
            tps_trials[e,c], _ = stats.pearsonr(pow0[:,t0],pow0[:,t1])
            c += 1
    tps_trials = 1 - tps_trials
    return tps_trials

for su in odor_list_su('Enc'):
    for cond in conds:
        mat = np.load(pow_file.format(su,cond),allow_pickle=True)
        pow_ = mat['xpow'][1,:,to_take[0]:to_take[1],:]
        if meth == '2gr':
            thr = int(pow_.shape[-1]/2)
            early_c, late_c = pow_[...,:thr], pow_[...,thr:]
            print('early ', early_c.shape)
            print('late ', late_c.shape)

            tps_E = tpsim_by_cond_learn(early_c)
            tps_L = tpsim_by_cond_learn(late_c)

            dict_t = {}
            dict_t['tps_0'], dict_t['tps_1'] = tps_E, tps_L
            dict_t['label'], dict_t['channel'], dict_t['xyz'] = mat['labels'],mat['channels'], mat['xyz']
            np.savez(savename.format(su,freq,cond,'2gr'),**dict_t)
        
        elif meth =='3gr':
            thr = int(pow_.shape[-1]/3)
            print(pow_.shape,thr)
            if thr == 0:
                if pow_.shape[-1] >= 1:
                    early_c = pow_[...,:thr+1]
                if pow_.shape[-1] == 2:
                    mid_c = pow_[...,thr+1:]
            if thr >= 1:
                early_c = pow_[...,:thr]
                mid_c = pow_[...,thr:(2*thr)]
                late_c = pow_[...,(2*thr):]
            print('early odors list', [x.shape for x in early_c])
            print('mid odors list', [x.shape for x in mid_c])
            print('late odors list', [x.shape for x in late_c])

            tps_E = tpsim_by_cond_learn(early_c)
            tps_M = tpsim_by_cond_learn(mid_c)
            tps_L = tpsim_by_cond_learn(late_c)
    
            dict_t = {}
            dict_t['tps_0'], dict_t['tps_1'], dict_t['tps_2'] = tps_E, tps_M, tps_L
            dict_t['label'], dict_t['channel'], dict_t['xyz'] = mat['labels'],mat['channels'], mat['xyz']
            np.savez(savename.format(su,freq,cond,'3gr'),**dict_t)
# Out:
# -> Olfacto loaded
# early  (61, 30, 2)
# late  (61, 30, 3)
# early  (61, 30, 2)
# late  (61, 30, 2)
# early  (61, 30, 6)
# late  (61, 30, 6)
# early  (27, 30, 11)
# late  (27, 30, 12)
# early  (27, 30, 7)
# late  (27, 30, 8)
# early  (27, 30, 8)
# late  (27, 30, 9)
# early  (18, 30, 7)
# late  (18, 30, 7)
# early  (18, 30, 4)
# late  (18, 30, 5)
# early  (18, 30, 7)
# late  (18, 30, 7)
# early  (39, 30, 4)
# late  (39, 30, 5)
# early  (39, 30, 2)
# late  (39, 30, 2)
# early  (39, 30, 4)
# late  (39, 30, 5)
# early  (53, 30, 10)
# late  (53, 30, 11)
# early  (53, 30, 5)
# late  (53, 30, 5)
# early  (53, 30, 4)
# late  (53, 30, 5)
# early  (32, 30, 8)
# late  (32, 30, 8)
# early  (32, 30, 3)
# late  (32, 30, 3)
# early  (32, 30, 4)
# late  (32, 30, 5)

# %%
from utils import odor_list_su, odor_groups_3wgth
"""
LEARNING effect
Compute TPSim for all ODORS whatever the memory perf group
ALL ODORS TOGETHER // ALL trials INDIVIDUALLY no groups
"""
###############################################################################
st = study('Olfacto')
path_data = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_cond_3groups_v=1_elecs=all/')
pow_file = join(path_data, '{}_odor_{}_E_6freqs.npz')
pathsave = join(st.path,'feature/TPSim_3groups_Enc/TPS_btw_thgh_time_v=1_elecs=all/')
savename = join(pathsave,'TPS_pears_learn_{}_btw_{}_{}.npz')
###############################################################################
if not exists(pathsave.format(exp)):
    makedirs(pathsave.format(exp))
###############################################################################
freq = 'theta'
to_take = [17,47]

def tpsim_by_cond_learn(data):
    nelecs, npts, ntrials = data.shape
    ncomb = len([a for a,_ in combinations(np.arange(ntrials), 2)])
    tps_trials = np.empty((nelecs,ncomb))
    for e,elec in enumerate(range(nelecs)):
        pow0 = data[elec,...]
        c = 0
        for t0, t1 in combinations(np.arange(ntrials), 2):
            tps_trials[e,c], _ = stats.pearsonr(pow0[:,t0],pow0[:,t1])
            c += 1
    tps_trials = 1 - np.arctanh(tps_trials)
    return tps_trials

for su in odor_list_su('Ret'):
    all_odors = []
    for od in odor_list_su('Ret')[su]:
        mat = np.load(pow_file.format(su,od))
        pow_ = mat['xpow'][1,:,to_take[0]:to_take[1],:]
        all_odors.append(pow_)
        
    max_trials = np.max([x.shape[-1] for x in all_odors])
    list_tpsim = []
    for t in range(max_trials):
        list_t = [x[:,:,t][np.newaxis] for x in all_odors if x.shape[-1] > t]
        if len(list_t) > 1 :
            concat_od = np.concatenate(list_t, axis=0).swapaxes(0,-1).swapaxes(0,1)
            tps_t = tpsim_by_cond_learn(concat_od)
            list_tpsim.append(tps_t)

    print(su,freq,max_trials,[x.shape for x in list_tpsim])
    dict_t = {}
    for n in range(len(list_tpsim)):
        dict_t['tps_'+str(n)] = list_tpsim[n]
    dict_t['label'], dict_t['channel'], dict_t['xyz'] = mat['labels'],mat['channels'], mat['xyz']
    np.savez(savename.format(su,freq,cond),**dict_t)

# %%
def tpsim_btw_odors(array1,array2):
    """
    Compute tpsim for one odor with all other odors in list od 2
    Parameters
    ----------
    array1, array2 : array
        shape nelecs, npts, ntrials (same shape of elecs and npts)

    Returns
    -------
    tpsim : array
        The Temporal Pattern Similarity between 2 two arrays
        (n_combinations of trials btw array1 and array2)
    """
    tpsim_btw = np.array([])
    for elec in range(array1.shape[0]):
        pow1, pow2 = array1[elec], array2[elec]
        R_trials = np.array([])
        for t0, t1 in product(range(pow1.shape[-1]),range(pow2.shape[-1])):
            R, p = stats.pearsonr(pow1[:,t0],pow2[:,t1])
            R_trials = np.vstack((R_trials,R)) if np.size(R_trials) else R
        tpsim_btw = np.vstack((tpsim_btw,R_trials.T)) if np.size(tpsim_btw) else R_trials.T
    tpsim_btw = 1 - np.arctanh(tpsim_btw)
    return tpsim_btw

# %%
from utils import odor_list_su, odor_groups_3wgth
"""
LEARNING effect
Compute TPSim for all ODORS whatever the memory perf group
SIMILARITY BTW ALL ODORS across trials
trial1 with trial2 / trial2 with trial3 / trial 3 with rest of trials
"""
###############################################################################
st = study('Olfacto')
path_data = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_odor_all_elecsFT/')
pow_file = join(path_data, '{}_odor_{}_bipo_all_E_6freqs.npz')
pathsave = join(st.path,'feature/TPSim_3groups_Enc/TPS_btw_thgh_time_v=1_elecs=all/')
savename = join(pathsave,'TPS_pears_learn_{}_btw_{}_{}.npz')
###############################################################################
if not exists(pathsave.format(exp)):
    makedirs(pathsave.format(exp))
###############################################################################
freq = 'theta'
to_take = [17,47]

for su in odor_list_su('Ret'):
    all_odors = []
    for od in odor_list_su('Ret')[su]:
        mat = np.load(pow_file.format(su,od),allow_pickle=True)
        pow_ = mat['xpow'][1,:,to_take[0]:to_take[1],:]
        all_odors.append(pow_)
    print([x.shape for x in all_odors])
    
    list_tpsim = []
    for t in range(3):
        list0 = [x[:,:,t][...,np.newaxis] for x in all_odors if x.shape[-1] > t]
        if t == 2 :
            list1 = [x[:,:,t+1:] for x in all_odors if x.shape[-1] > t+1]
        else :
            list1 = [x[:,:,t+1][...,np.newaxis] for x in all_odors if x.shape[-1] > t+1]
        concat_1 = np.concatenate(list0, axis=-1)
        concat_2 = np.concatenate(list1, axis=-1)
        tps_t = tpsim_btw_odors(concat_1,concat_2)
        list_tpsim.append(tps_t)
        
    print(su,freq,[x.shape for x in list_tpsim])
    dict_t = {}
    for n in range(len(list_tpsim)):
        dict_t['tps_'+str(n)] = list_tpsim[n]
    dict_t['label'], dict_t['channel'], dict_t['xyz'] = mat['labels'],mat['channels'], mat['xyz']
    np.savez(savename.format(su,freq,'btw_trials'),**dict_t)
