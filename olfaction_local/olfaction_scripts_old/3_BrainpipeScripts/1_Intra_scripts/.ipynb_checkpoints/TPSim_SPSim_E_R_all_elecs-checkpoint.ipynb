# %%
from os.path import isfile, join, exists
from os import listdir, makedirs
import numpy as np
import matplotlib.pyplot as plt
from brainpipe.system import study
from scipy import stats
from itertools import product
import pandas as pd

# %% [markdown]
# ### Take only electrodes present at encoding AND retrieval
# all common electrodes or only significant common electrodes

# %%
from os import listdir
import numpy as np
import pandas as pd

th = '0.01'
freqs = ['0_theta', '1_alpha','2_beta','3_gamma']
rois_to_keep = ['ACC','Amg','Amg-PirT','HC','IFG','Ins','MFG','OFC','PHG','SFG','pPirT']
nb_elecs = 120+55+55
###############################################################################
st = study('Olfacto')
path_enc = join(st.path, 'feature/0_Power_Encoding_EpiPerf_By_Odor/')
path_ret = join(st.path, 'feature/0_Power_Retrieval_EpiPerf_By_Odor/')
path_E = join(st.path, 'figure/0_Classif_Power_E_EpiPerf_LowHigh_1000perm_BBG/')
path_R = join(st.path, 'figure/0_Classif_Power_R_EpiPerf_LowHigh_1000perm_BBG/')
npz_form = 'All_subjects_sources_{}_odor_low_high_sel_physFT.npz'
mask_form = 'All_subjects_mask_stat_{}_minwin1.0_th'+th+'.npy'
path2save = join(st.path, 'feature/TPSim_Enc_Ret_By_Odor/')
###############################################################################

for freq in freqs:
    #select all electrodes from encoding (specific regions and subjects)
    mat_enc = np.load(path_E+npz_form.format(freq))
    idx_E = np.where([roi in rois_to_keep for roi in mat_enc['s_labels']])[0]
    id_su = np.where([su != 'S6' for su in mat_enc['su_codes'][idx_E]])[0]
    xyz0, labels0 = mat_enc['s_xyz'][idx_E][id_su], mat_enc['s_labels'][idx_E][id_su]
    mask0 = np.load(path_npz_enc+'masks_stat/'+mask_form.format(freq))[id_su]
    mask0 = np.asarray([not x for x in mask0])
        
    #select all electrodes from retrieval (specific regions, all subjects)
    mat_ret = np.load(path_R+npz_form.format(freq))
    idx_R = np.where([roi in rois_to_keep for roi in mat_ret['s_labels']])[0]
    mask1 = np.load(path_npz_ret+'masks_stat/'+mask_form.format(freq))
    mask1 = np.asarray([not x for x in mask1])
    xyz1, labels1 = mat_ret['s_xyz'][idx_R], mat_ret['s_labels'][idx_R]
    
    #select only electrodes present both during encoding and retrieval
    to_keep_enc = np.where((xyz0==xyz1[:,None]).all(-1))[1]
    to_keep_ret = np.where((xyz1==xyz0[:,None]).all(-1))[1]
    mask0_new, mask1_new = mask0[to_keep_enc], mask1[to_keep_ret]
    print(len(mask0_new),len(mask1_new))
    
    xyz_shared = xyz0[to_keep_enc]
    xyz0_sig = xyz0[to_keep_enc][mask0_new]
    xyz1_sig = xyz1[to_keep_ret][mask1_new]
    print(freq,xyz0_sig.shape,xyz1_sig.shape)
            
    #create an array of region labels for encoding and retrieval
    dict_regions ={ 'ACC':'Frontal','IFG':'Frontal','MFG':'Frontal','SFG':'Frontal',
                'Amg':'Olf','pPirT':'Olf','Amg-PirT':'Olf','Ins':'Olf','OFC':'Olf',
                'HC':'MTL','PHG':'MTL'}
    regions0 = np.vectorize(dict_regions.get)(labels0[to_keep_enc])
        
    #loop on all elecs and create a code indicating when it decodes
    codes_elecs, region_elecs = [], []
    for i, elec in enumerate(xyz_shared):
        in_1 = np.where(np.all(elec == xyz0_sig, 1))[0] #encoding
        in_2 = np.where(np.all(elec == xyz1_sig, 1))[0] #retrieval
        
        if in_1.size and in_2.size: #decode in both
            codes_elecs.append(2)
            region_elecs.append(regions0[i])
        elif in_1.size and not in_2.size: #decode only in encoding
            codes_elecs.append(0)
            region_elecs.append(regions0[i])
        elif not in_1.size and in_2.size: #decode only in retrieval
            codes_elecs.append(1)
            region_elecs.append(regions0[i])
    
    codes_elecs = np.asarray(codes_elecs)[np.newaxis]
    region_elecs = np.asarray(region_elecs)[np.newaxis]
    count = np.ones(shape=region_elecs.shape)
    #print(freq,'regions',region_elecs.shape,codes_elecs.shape, count.shape)
    concat = np.concatenate((codes_elecs,region_elecs,count),axis=0).swapaxes(0,1)
    df = pd.DataFrame(concat,columns=['codes_elecs','region_elecs','count'])
    df_gr = df[['codes_elecs','region_elecs']].groupby(['codes_elecs']).count()
    codes = df_gr.index.get_level_values(0).values
    rois = df_gr.columns.get_level_values(0).values
    print(df_gr, codes, rois)
# Out:
# -> Olfacto loaded
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-23b12d20e98d> in <module>()
#      24     id_su = np.where([su != 'S6' for su in mat_enc['su_codes'][idx_E]])[0]
#      25     xyz0, labels0 = mat_enc['s_xyz'][idx_E][id_su], mat_enc['s_labels'][idx_E][id_su]
# ---> 26     mask0 = np.load(path_npz_enc+'masks_stat/'+mask_form.format(freq))[id_su]
#      27     mask0 = np.asarray([not x for x in mask0])
#      28
#
# NameError: name 'path_npz_enc' is not defined

# %%
if not exists(path2save):
    makedirs(path2save)
###############################################################################
sel = 'signif' #'all'
freqs = ['2_theta', '3_alpha', '4_beta','5_gamma1','6_gamma2']
method = ['s_Mail_RL']
odors_su = {'CHAF': {5:12,7:68,8:36,9:96,1:6,2:2,3:68,4:8},
            'LEFC': {1:4,2:0,3:6,4:12,14:96,15:2,16:4,17:68},
            'PIRJ': {4:36,9:2,1:4,18:32,6:34,5:4,7:68}, #missing odor 15
            'VACJ': {14:6,15:64,16:68,17:8,10:6,11:4,12:4,13:40},
            'SEMC': {10:2,11:6,12:6,13:6,5:8,7:4,8:8,9:10},
            'FERJ': {16:6,17:6,5:8,7:6,12:8,13:8,2:6,1:10}}
rois_to_keep = ['ACC','Amg','Amg-PirT','HC','IFG','Ins','MFG','OFC','PHG',
                'SFG','pPirT']
th = 0.01
s_E, s_R = [0,1,2,4,5,6], range(6)

for s0, s1, su in zip(s_E,s_R,sorted(odors_su)):
    for odor in odors_su[su]:        
        if sel == 'signif': #select only significant electrodes at Encoding & Retrieval
            for f,freq in enumerate(freqs):
                mat0 = np.load(path_enc+su+'_odor_'+str(odor)+'_bipo_sel_physFT_pow.npz')
                mat1 = np.load(path_ret+su+'_odor_'+str(odor)+'_bipo_sel_physFT_pow.npz')
                data0, channels0 = mat0['xpow'], mat0['channels']
                data1, channels1 = mat1['xpow'], mat1['channels']
                #print(su,'num su',s0,s1, odor,freq,'data shape: ', data0.shape, data1.shape,'channels',channels0.shape,
                  #channels1.shape)

                #Select specific ROIs
                idx_roisE = np.where([roi in rois_to_keep for roi in mat0['Mai_RL']])[0]
                idx_roisR = np.where([roi in rois_to_keep for roi in mat1['Mai_RL']])[0]
                data0, channels0 = data0[:,idx_roisE,:,:], channels0[idx_roisE]
                data1, channels1 = data1[:,idx_roisR,:,:], channels1[idx_roisR]
                print('selec shape: ', data0.shape, data1.shape,'channels',channels0.shape,
                  channels1.shape)
                
                # Select one's subject ROIs
                df_E = pd.read_csv(path_maskE+'0_all_subjects_info_elecs.csv')
                df_R = pd.read_csv(path_maskR+'0_all_subjects_info_elecs.csv')
                                
                id_elecsE = np.where(df_E['subjects'] == 'S'+str(s0))[0]
                id_elecsR = np.where(df_R['subjects'] == 'S'+str(s1))[0]
                #print('elecs belonging to',su,id_elecsE.shape,id_elecsR.shape)
                maskE = np.load(path_maskE+'{}/All_subjects_mask_stat_{}_minwin1.0_th{}.npy'.format('masks_stat',freq,th))
                maskR = np.load(path_maskR+'{}/All_subjects_mask_stat_{}_minwin1.0_th{}.npy'.format('masks_stat',freq,th))
                #print('masks shapes', maskE.shape,maskR.shape)
                maskE,maskR = maskE[id_elecsE], maskR[id_elecsR]
                #print('mask for',su,maskE.shape,maskR.shape) #mask based on ROIs already
                channels0, channels1 = channels0[maskE], channels1[maskR]
                
                #create a list of electrodes to keep
                to_keep_enc = [idx for idx,elec in enumerate(channels0) if elec in channels1]
                to_keep_ret = [idx for idx,elec in enumerate(channels1) if elec in channels0]

                #select power files for to keep electrodes
                data0_new = data0[f,to_keep_enc,:,:]
                data1_new = data1[f,to_keep_ret,:,:]
                channels0_new = channels0[to_keep_enc]
                channels1_new = channels1[to_keep_ret]
                print('SIG elecs E/R for',su,freqs[f],channels0_new.shape, channels1_new.shape)
                labels0_new = mat0['Mai_RL'][idx_roisE][to_keep_enc]
                labels1_new = mat1['Mai_RL'][idx_roisR][to_keep_ret]
                xyz0_new = mat0['xyz'][idx_roisE][to_keep_enc]
                xyz1_new = mat1['xyz'][idx_roisR][to_keep_ret]

                #sorted all values from encoding and retrieval
                sorted_idx0 = np.argsort(channels0_new)
                data0_new = data0_new[sorted_idx0,:,:]
                channels0_new = channels0_new[sorted_idx0]
                labels0_new = labels0_new[sorted_idx0]
                xyz0_new = xyz0_new[sorted_idx0]
                sorted_idx1 = np.argsort(channels1_new)
                data1_new = data1_new[sorted_idx1,:,:]
                channels1_new = channels1_new[sorted_idx1]
                labels1_new = labels1_new[sorted_idx1]
                xyz1_new = xyz1_new[sorted_idx1]

                #Save all values from encoding and retrieval
                mat0_new = {'xpow':data0_new, 'label':labels0_new, 'channel':channels0_new,
                            'xyz':xyz0_new}
                mat1_new = {'xpow':data1_new, 'label':labels1_new, 'channel':channels1_new,
                            'xyz':xyz1_new}
                np.savez(path2save+su+'_odor'+str(odor)+'_E_pow{}.npz'.format(freq),**mat0_new)
                np.savez(path2save+su+'_odor'+str(odor)+'_R_pow{}.npz'.format(freq),**mat1_new)
        else:
            to_keep_enc = [idx for idx,elec in enumerate(channels0) if elec in channels1]
            to_keep_ret = [idx for idx,elec in enumerate(channels1) if elec in channels0]

            #select power files for to keep electrodes
            data0_new = data0[:,to_keep_enc,:,:]
            data1_new = data1[:,to_keep_ret,:,:]
            channels0_new = channels0[to_keep_enc]
            channels1_new = channels1[to_keep_ret]
            labels0_new = mat0['Mai_RL'][to_keep_enc]
            labels1_new = mat1['Mai_RL'][to_keep_ret]
            xyz0_new = mat0['xyz'][to_keep_enc]
            xyz1_new = mat1['xyz'][to_keep_ret]

            #sorted all values from encoding and retrieval
            sorted_idx0 = np.argsort(channels0_new)
            data0_new = data0_new[:,sorted_idx0,:,:]
            channels0_new = channels0_new[sorted_idx0]
            labels0_new = labels0_new[sorted_idx0]
            xyz0_new = xyz0_new[sorted_idx0]
            sorted_idx1 = np.argsort(channels1_new)
            data1_new = data1_new[:,sorted_idx1,:,:]
            channels1_new = channels1_new[sorted_idx1]
            labels1_new = labels1_new[sorted_idx1]
            xyz1_new = xyz1_new[sorted_idx1]

            #Save all values from encoding and retrieval
            mat0_new = {'xpow':data0_new, 'label':labels0_new, 'channel':channels0_new,
                        'xyz':xyz0_new}
            mat1_new = {'xpow':data1_new, 'label':labels1_new, 'channel':channels1_new,
                        'xyz':xyz1_new}
            np.savez(path2save+su+'_odor_'+str(odor)+'_E_pow.npz',**mat0_new)
            np.savez(path2save+su+'_odor_'+str(odor)+'_R_pow.npz',**mat1_new)
# Out:
# -> Olfacto loaded
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 2_theta (29,) (29,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 3_alpha (40,) (40,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 4_beta (35,) (35,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 5_gamma1 (21,) (21,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 6_gamma2 (13,) (13,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 2_theta (29,) (29,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 3_alpha (40,) (40,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 4_beta (35,) (35,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 5_gamma1 (21,) (21,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 6_gamma2 (13,) (13,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 2_theta (29,) (29,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 3_alpha (40,) (40,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 4_beta (35,) (35,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 5_gamma1 (21,) (21,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 6_gamma2 (13,) (13,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 2_theta (29,) (29,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 3_alpha (40,) (40,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 4_beta (35,) (35,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 5_gamma1 (21,) (21,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 6_gamma2 (13,) (13,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 2_theta (29,) (29,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 3_alpha (40,) (40,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 4_beta (35,) (35,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 5_gamma1 (21,) (21,)
# selec shape:  (7, 58, 64, 1) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 6_gamma2 (13,) (13,)
# selec shape:  (7, 58, 64, 4) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 2_theta (29,) (29,)
# selec shape:  (7, 58, 64, 4) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 3_alpha (40,) (40,)
# selec shape:  (7, 58, 64, 4) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 4_beta (35,) (35,)
# selec shape:  (7, 58, 64, 4) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 5_gamma1 (21,) (21,)
# selec shape:  (7, 58, 64, 4) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 6_gamma2 (13,) (13,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 2_theta (29,) (29,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 3_alpha (40,) (40,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 4_beta (35,) (35,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 5_gamma1 (21,) (21,)
# selec shape:  (7, 58, 64, 3) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 6_gamma2 (13,) (13,)
# selec shape:  (7, 58, 64, 5) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 2_theta (29,) (29,)
# selec shape:  (7, 58, 64, 5) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 3_alpha (40,) (40,)
# selec shape:  (7, 58, 64, 5) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 4_beta (35,) (35,)
# selec shape:  (7, 58, 64, 5) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 5_gamma1 (21,) (21,)
# selec shape:  (7, 58, 64, 5) (7, 60, 64, 3) channels (58,) (60,)
# SIG elecs E/R for CHAF 6_gamma2 (13,) (13,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 2_theta (12,) (12,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 3_alpha (11,) (11,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 4_beta (13,) (13,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 5_gamma1 (10,) (10,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 6_gamma2 (11,) (11,)
# selec shape:  (7, 46, 64, 9) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 2_theta (12,) (12,)
# selec shape:  (7, 46, 64, 9) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 3_alpha (11,) (11,)
# selec shape:  (7, 46, 64, 9) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 4_beta (13,) (13,)
# selec shape:  (7, 46, 64, 9) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 5_gamma1 (10,) (10,)
# selec shape:  (7, 46, 64, 9) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 6_gamma2 (11,) (11,)
# selec shape:  (7, 46, 64, 2) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 2_theta (12,) (12,)
# selec shape:  (7, 46, 64, 2) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 3_alpha (11,) (11,)
# selec shape:  (7, 46, 64, 2) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 4_beta (13,) (13,)
# selec shape:  (7, 46, 64, 2) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 5_gamma1 (10,) (10,)
# selec shape:  (7, 46, 64, 2) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 6_gamma2 (11,) (11,)
# selec shape:  (7, 46, 64, 4) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 2_theta (12,) (12,)
# selec shape:  (7, 46, 64, 4) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 3_alpha (11,) (11,)
# selec shape:  (7, 46, 64, 4) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 4_beta (13,) (13,)
# selec shape:  (7, 46, 64, 4) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 5_gamma1 (10,) (10,)
# selec shape:  (7, 46, 64, 4) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 6_gamma2 (11,) (11,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 2_theta (12,) (12,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 3_alpha (11,) (11,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 4_beta (13,) (13,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 5_gamma1 (10,) (10,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 6_gamma2 (11,) (11,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 2_theta (12,) (12,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 3_alpha (11,) (11,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 4_beta (13,) (13,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 5_gamma1 (10,) (10,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 6_gamma2 (11,) (11,)
# selec shape:  (7, 46, 64, 4) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 2_theta (12,) (12,)
# selec shape:  (7, 46, 64, 4) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 3_alpha (11,) (11,)
# selec shape:  (7, 46, 64, 4) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 4_beta (13,) (13,)
# selec shape:  (7, 46, 64, 4) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 5_gamma1 (10,) (10,)
# selec shape:  (7, 46, 64, 4) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 6_gamma2 (11,) (11,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 2_theta (12,) (12,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 3_alpha (11,) (11,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 4_beta (13,) (13,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 5_gamma1 (10,) (10,)
# selec shape:  (7, 46, 64, 3) (7, 45, 64, 3) channels (46,) (45,)
# SIG elecs E/R for FERJ 6_gamma2 (11,) (11,)
# selec shape:  (7, 36, 64, 16) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 2_theta (20,) (20,)
# selec shape:  (7, 36, 64, 16) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 3_alpha (24,) (24,)
# selec shape:  (7, 36, 64, 16) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 4_beta (23,) (23,)
# selec shape:  (7, 36, 64, 16) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 5_gamma1 (18,) (18,)
# selec shape:  (7, 36, 64, 16) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 6_gamma2 (19,) (19,)
# selec shape:  (7, 36, 64, 2) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 2_theta (20,) (20,)
# selec shape:  (7, 36, 64, 2) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 3_alpha (24,) (24,)
# selec shape:  (7, 36, 64, 2) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 4_beta (23,) (23,)
# selec shape:  (7, 36, 64, 2) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 5_gamma1 (18,) (18,)
# selec shape:  (7, 36, 64, 2) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 6_gamma2 (19,) (19,)
# selec shape:  (7, 36, 64, 5) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 2_theta (20,) (20,)
# selec shape:  (7, 36, 64, 5) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 3_alpha (24,) (24,)
# selec shape:  (7, 36, 64, 5) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 4_beta (23,) (23,)
# selec shape:  (7, 36, 64, 5) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 5_gamma1 (18,) (18,)
# selec shape:  (7, 36, 64, 5) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 6_gamma2 (19,) (19,)
# selec shape:  (7, 36, 64, 4) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 2_theta (20,) (20,)
# selec shape:  (7, 36, 64, 4) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 3_alpha (24,) (24,)
# selec shape:  (7, 36, 64, 4) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 4_beta (23,) (23,)
# selec shape:  (7, 36, 64, 4) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 5_gamma1 (18,) (18,)
# selec shape:  (7, 36, 64, 4) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 6_gamma2 (19,) (19,)
# selec shape:  (7, 36, 64, 4) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 2_theta (20,) (20,)
# selec shape:  (7, 36, 64, 4) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 3_alpha (24,) (24,)
# selec shape:  (7, 36, 64, 4) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 4_beta (23,) (23,)
# selec shape:  (7, 36, 64, 4) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 5_gamma1 (18,) (18,)
# selec shape:  (7, 36, 64, 4) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 6_gamma2 (19,) (19,)
# selec shape:  (7, 36, 64, 7) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 2_theta (20,) (20,)
# selec shape:  (7, 36, 64, 7) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 3_alpha (24,) (24,)
# selec shape:  (7, 36, 64, 7) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 4_beta (23,) (23,)
# selec shape:  (7, 36, 64, 7) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 5_gamma1 (18,) (18,)
# selec shape:  (7, 36, 64, 7) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 6_gamma2 (19,) (19,)
# selec shape:  (7, 36, 64, 6) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 2_theta (20,) (20,)
# selec shape:  (7, 36, 64, 6) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 3_alpha (24,) (24,)
# selec shape:  (7, 36, 64, 6) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 4_beta (23,) (23,)
# selec shape:  (7, 36, 64, 6) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 5_gamma1 (18,) (18,)
# selec shape:  (7, 36, 64, 6) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 6_gamma2 (19,) (19,)
# selec shape:  (7, 36, 64, 11) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 2_theta (20,) (20,)
# selec shape:  (7, 36, 64, 11) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 3_alpha (24,) (24,)
# selec shape:  (7, 36, 64, 11) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 4_beta (23,) (23,)
# selec shape:  (7, 36, 64, 11) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 5_gamma1 (18,) (18,)
# selec shape:  (7, 36, 64, 11) (7, 36, 64, 3) channels (36,) (36,)
# SIG elecs E/R for LEFC 6_gamma2 (19,) (19,)
# selec shape:  (7, 32, 64, 7) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 2_theta (20,) (20,)
# selec shape:  (7, 32, 64, 7) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 3_alpha (21,) (21,)
# selec shape:  (7, 32, 64, 7) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 4_beta (18,) (18,)
# selec shape:  (7, 32, 64, 7) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 5_gamma1 (17,) (17,)
# selec shape:  (7, 32, 64, 7) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 6_gamma2 (20,) (20,)
# selec shape:  (7, 32, 64, 5) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 2_theta (20,) (20,)
# selec shape:  (7, 32, 64, 5) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 3_alpha (21,) (21,)
# selec shape:  (7, 32, 64, 5) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 4_beta (18,) (18,)
# selec shape:  (7, 32, 64, 5) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 5_gamma1 (17,) (17,)
# selec shape:  (7, 32, 64, 5) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 6_gamma2 (20,) (20,)
# selec shape:  (7, 32, 64, 4) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 2_theta (20,) (20,)
# selec shape:  (7, 32, 64, 4) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 3_alpha (21,) (21,)
# selec shape:  (7, 32, 64, 4) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 4_beta (18,) (18,)
# selec shape:  (7, 32, 64, 4) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 5_gamma1 (17,) (17,)
# selec shape:  (7, 32, 64, 4) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 6_gamma2 (20,) (20,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 2_theta (20,) (20,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 3_alpha (21,) (21,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 4_beta (18,) (18,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 5_gamma1 (17,) (17,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 6_gamma2 (20,) (20,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 2_theta (20,) (20,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 3_alpha (21,) (21,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 4_beta (18,) (18,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 5_gamma1 (17,) (17,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 6_gamma2 (20,) (20,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 2_theta (20,) (20,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 3_alpha (21,) (21,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 4_beta (18,) (18,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 5_gamma1 (17,) (17,)
# selec shape:  (7, 32, 64, 1) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 6_gamma2 (20,) (20,)
# selec shape:  (7, 32, 64, 6) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 2_theta (20,) (20,)
# selec shape:  (7, 32, 64, 6) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 3_alpha (21,) (21,)
# selec shape:  (7, 32, 64, 6) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 4_beta (18,) (18,)
# selec shape:  (7, 32, 64, 6) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 5_gamma1 (17,) (17,)
# selec shape:  (7, 32, 64, 6) (7, 30, 64, 4) channels (32,) (30,)
# SIG elecs E/R for PIRJ 6_gamma2 (20,) (20,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 2_theta (42,) (42,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 3_alpha (43,) (43,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 4_beta (29,) (29,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 5_gamma1 (25,) (25,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 6_gamma2 (13,) (13,)
# selec shape:  (7, 62, 64, 4) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 2_theta (42,) (42,)
# selec shape:  (7, 62, 64, 4) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 3_alpha (43,) (43,)
# selec shape:  (7, 62, 64, 4) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 4_beta (29,) (29,)
# selec shape:  (7, 62, 64, 4) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 5_gamma1 (25,) (25,)
# selec shape:  (7, 62, 64, 4) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 6_gamma2 (13,) (13,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 2_theta (42,) (42,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 3_alpha (43,) (43,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 4_beta (29,) (29,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 5_gamma1 (25,) (25,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 6_gamma2 (13,) (13,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 2_theta (42,) (42,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 3_alpha (43,) (43,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 4_beta (29,) (29,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 5_gamma1 (25,) (25,)
# selec shape:  (7, 62, 64, 3) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 6_gamma2 (13,) (13,)
# selec shape:  (7, 62, 64, 7) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 2_theta (42,) (42,)
# selec shape:  (7, 62, 64, 7) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 3_alpha (43,) (43,)
# selec shape:  (7, 62, 64, 7) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 4_beta (29,) (29,)
# selec shape:  (7, 62, 64, 7) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 5_gamma1 (25,) (25,)
# selec shape:  (7, 62, 64, 7) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 6_gamma2 (13,) (13,)
# selec shape:  (7, 62, 64, 4) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 2_theta (42,) (42,)
# selec shape:  (7, 62, 64, 4) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 3_alpha (43,) (43,)
# selec shape:  (7, 62, 64, 4) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 4_beta (29,) (29,)
# selec shape:  (7, 62, 64, 4) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 5_gamma1 (25,) (25,)
# selec shape:  (7, 62, 64, 4) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 6_gamma2 (13,) (13,)
# selec shape:  (7, 62, 64, 6) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 2_theta (42,) (42,)
# selec shape:  (7, 62, 64, 6) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 3_alpha (43,) (43,)
# selec shape:  (7, 62, 64, 6) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 4_beta (29,) (29,)
# selec shape:  (7, 62, 64, 6) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 5_gamma1 (25,) (25,)
# selec shape:  (7, 62, 64, 6) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 6_gamma2 (13,) (13,)
# selec shape:  (7, 62, 64, 10) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 2_theta (42,) (42,)
# selec shape:  (7, 62, 64, 10) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 3_alpha (43,) (43,)
# selec shape:  (7, 62, 64, 10) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 4_beta (29,) (29,)
# selec shape:  (7, 62, 64, 10) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 5_gamma1 (25,) (25,)
# selec shape:  (7, 62, 64, 10) (7, 62, 64, 3) channels (62,) (62,)
# SIG elecs E/R for SEMC 6_gamma2 (13,) (13,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 2_theta (37,) (37,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 3_alpha (34,) (34,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 4_beta (30,) (30,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 5_gamma1 (36,) (36,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 6_gamma2 (39,) (39,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 2_theta (37,) (37,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 3_alpha (34,) (34,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 4_beta (30,) (30,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 5_gamma1 (36,) (36,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 6_gamma2 (39,) (39,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 2_theta (37,) (37,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 3_alpha (34,) (34,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 4_beta (30,) (30,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 5_gamma1 (36,) (36,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 6_gamma2 (39,) (39,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 2_theta (37,) (37,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 3_alpha (34,) (34,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 4_beta (30,) (30,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 5_gamma1 (36,) (36,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 6_gamma2 (39,) (39,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 2_theta (37,) (37,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 3_alpha (34,) (34,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 4_beta (30,) (30,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 5_gamma1 (36,) (36,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 6_gamma2 (39,) (39,)
# selec shape:  (7, 48, 64, 4) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 2_theta (37,) (37,)
# selec shape:  (7, 48, 64, 4) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 3_alpha (34,) (34,)
# selec shape:  (7, 48, 64, 4) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 4_beta (30,) (30,)
# selec shape:  (7, 48, 64, 4) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 5_gamma1 (36,) (36,)
# selec shape:  (7, 48, 64, 4) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 6_gamma2 (39,) (39,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 2_theta (37,) (37,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 3_alpha (34,) (34,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 4_beta (30,) (30,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 5_gamma1 (36,) (36,)
# selec shape:  (7, 48, 64, 3) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 6_gamma2 (39,) (39,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 2_theta (37,) (37,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 3_alpha (34,) (34,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 4_beta (30,) (30,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 5_gamma1 (36,) (36,)
# selec shape:  (7, 48, 64, 2) (7, 48, 64, 3) channels (48,) (48,)
# SIG elecs E/R for VACJ 6_gamma2 (39,) (39,)

# %% [markdown]
# ### Compute TPSim for common electrodes
# By odor (Similarity btw E and R by odor)

# %%
from numpy.random import permutation
from brainpipe.statistics import *

###############################################################################
st = study('Olfacto')
path_npz = join(st.path,'feature/TPSim_Enc_Ret_By_Odor_all/')
path2save = join(path_npz, 'TPS_R_p_by_odor/')
npz_enc = join(path_npz, '{}_odor{}_E_pow{}.npz')
npz_ret = join(path_npz, '{}_odor{}_R_pow{}.npz')
###############################################################################
if not exists(path2save):
    makedirs(path2save)
###############################################################################
th = '0.01'
freqs = ['2_theta', '3_alpha', '4_beta','5_gamma1','6_gamma2']
method = ['s_Mail_RL']
odors_su = {'CHAF': {5:12,7:68,8:36,9:96,1:6,2:2,3:68,4:8},
            'LEFC': {1:4,2:0,3:6,4:12,14:96,15:2,16:4,17:68},
            'PIRJ': {4:36,9:2,1:4,18:32,6:34,5:4,7:68}, #missing odor 15
            'VACJ': {14:6,15:64,16:68,17:8,10:6,11:4,12:4,13:40},
            'SEMC': {10:2,11:6,12:6,13:6,5:8,7:4,8:8,9:10},
            'FERJ': {16:6,17:6,5:8,7:6,12:8,13:8,2:6,1:10}}

for s,su in enumerate(sorted(odors_su)):
    for odor in sorted(odors_su[su]):
        for freq in freqs:
            mat_enc = np.load(npz_enc.format(su,odor,freq))
            mat_ret = np.load(npz_ret.format(su,odor,freq))
            pow_enc = mat_enc['xpow'][:,27:47,:]
            pow_ret = mat_ret['xpow'][:,27:47,:]
            print('enc',pow_enc.shape,'ret',pow_ret.shape)
            R_freq, p_freq = np.array([]), np.array([])
            for elec in range(pow_enc.shape[0]):
                pow0 = pow_enc[elec,:]
                pow1 = pow_ret[elec,:]
                R_trials, p_trials = np.array([]), np.array([])
                for t0, t1 in product(range(pow0.shape[1]),range(pow1.shape[1])):
                    R, p = stats.spearmanr(pow0[:,t0],pow1[:,t1])
                    R_trials = np.vstack((R_trials,R)) if np.size(R_trials) else R
                    p_trials = np.vstack((p_trials,p)) if np.size(p_trials) else p
                R_freq = np.vstack((R_freq,R_trials.T)) if np.size(R_freq) else R_trials.T
                p_freq = np.vstack((p_freq,p_trials.T)) if np.size(p_freq) else p_trials.T
                #print(R_freq.shape, p_freq.shape)
            print(su,odor,freq,'R',R_freq.shape, p_freq.shape)
            mat = {'tps':R_freq, 'pval':p_freq,'label':mat_enc['label'],
                   'channel':mat_enc['channel'], 'xyz':mat_enc['xyz']}
            np.savez(path2save+'TPS_spear_'+su+'_odor_'+str(odor)+'_'+freq+'.npz',**mat)
# Out:
# -> Olfacto loaded
# enc (29, 20, 1) ret (29, 20, 3)
# CHAF 1 2_theta R (29, 3) (29, 3)
# enc (40, 20, 1) ret (40, 20, 3)
# CHAF 1 3_alpha R (40, 3) (40, 3)
# enc (35, 20, 1) ret (35, 20, 3)
# CHAF 1 4_beta R (35, 3) (35, 3)
# enc (21, 20, 1) ret (21, 20, 3)
# CHAF 1 5_gamma1 R (21, 3) (21, 3)
# enc (13, 20, 1) ret (13, 20, 3)
# CHAF 1 6_gamma2 R (13, 3) (13, 3)
# enc (29, 20, 3) ret (29, 20, 3)
# CHAF 2 2_theta R (29, 9) (29, 9)
# enc (40, 20, 3) ret (40, 20, 3)
# CHAF 2 3_alpha R (40, 9) (40, 9)
# enc (35, 20, 3) ret (35, 20, 3)
# CHAF 2 4_beta R (35, 9) (35, 9)
# enc (21, 20, 3) ret (21, 20, 3)
# CHAF 2 5_gamma1 R (21, 9) (21, 9)
# enc (13, 20, 3) ret (13, 20, 3)
# CHAF 2 6_gamma2 R (13, 9) (13, 9)
# enc (29, 20, 3) ret (29, 20, 3)
# CHAF 3 2_theta R (29, 9) (29, 9)
# enc (40, 20, 3) ret (40, 20, 3)
# CHAF 3 3_alpha R (40, 9) (40, 9)
# enc (35, 20, 3) ret (35, 20, 3)
# CHAF 3 4_beta R (35, 9) (35, 9)
# enc (21, 20, 3) ret (21, 20, 3)
# CHAF 3 5_gamma1 R (21, 9) (21, 9)
# enc (13, 20, 3) ret (13, 20, 3)
# CHAF 3 6_gamma2 R (13, 9) (13, 9)
# enc (29, 20, 1) ret (29, 20, 3)
# CHAF 4 2_theta R (29, 3) (29, 3)
# enc (40, 20, 1) ret (40, 20, 3)
# CHAF 4 3_alpha R (40, 3) (40, 3)
# enc (35, 20, 1) ret (35, 20, 3)
# CHAF 4 4_beta R (35, 3) (35, 3)
# enc (21, 20, 1) ret (21, 20, 3)
# CHAF 4 5_gamma1 R (21, 3) (21, 3)
# enc (13, 20, 1) ret (13, 20, 3)
# CHAF 4 6_gamma2 R (13, 3) (13, 3)
# enc (29, 20, 1) ret (29, 20, 3)
# CHAF 5 2_theta R (29, 3) (29, 3)
# enc (40, 20, 1) ret (40, 20, 3)
# CHAF 5 3_alpha R (40, 3) (40, 3)
# enc (35, 20, 1) ret (35, 20, 3)
# CHAF 5 4_beta R (35, 3) (35, 3)
# enc (21, 20, 1) ret (21, 20, 3)
# CHAF 5 5_gamma1 R (21, 3) (21, 3)
# enc (13, 20, 1) ret (13, 20, 3)
# CHAF 5 6_gamma2 R (13, 3) (13, 3)
# enc (29, 20, 4) ret (29, 20, 3)
# CHAF 7 2_theta R (29, 12) (29, 12)
# enc (40, 20, 4) ret (40, 20, 3)
# CHAF 7 3_alpha R (40, 12) (40, 12)
# enc (35, 20, 4) ret (35, 20, 3)
# CHAF 7 4_beta R (35, 12) (35, 12)
# enc (21, 20, 4) ret (21, 20, 3)
# CHAF 7 5_gamma1 R (21, 12) (21, 12)
# enc (13, 20, 4) ret (13, 20, 3)
# CHAF 7 6_gamma2 R (13, 12) (13, 12)
# enc (29, 20, 3) ret (29, 20, 3)
# CHAF 8 2_theta R (29, 9) (29, 9)
# enc (40, 20, 3) ret (40, 20, 3)
# CHAF 8 3_alpha R (40, 9) (40, 9)
# enc (35, 20, 3) ret (35, 20, 3)
# CHAF 8 4_beta R (35, 9) (35, 9)
# enc (21, 20, 3) ret (21, 20, 3)
# CHAF 8 5_gamma1 R (21, 9) (21, 9)
# enc (13, 20, 3) ret (13, 20, 3)
# CHAF 8 6_gamma2 R (13, 9) (13, 9)
# enc (29, 20, 5) ret (29, 20, 3)
# CHAF 9 2_theta R (29, 15) (29, 15)
# enc (40, 20, 5) ret (40, 20, 3)
# CHAF 9 3_alpha R (40, 15) (40, 15)
# enc (35, 20, 5) ret (35, 20, 3)
# CHAF 9 4_beta R (35, 15) (35, 15)
# enc (21, 20, 5) ret (21, 20, 3)
# CHAF 9 5_gamma1 R (21, 15) (21, 15)
# enc (13, 20, 5) ret (13, 20, 3)
# CHAF 9 6_gamma2 R (13, 15) (13, 15)
# enc (12, 20, 4) ret (12, 20, 3)
# FERJ 1 2_theta R (12, 12) (12, 12)
# enc (11, 20, 4) ret (11, 20, 3)
# FERJ 1 3_alpha R (11, 12) (11, 12)
# enc (13, 20, 4) ret (13, 20, 3)
# FERJ 1 4_beta R (13, 12) (13, 12)
# enc (10, 20, 4) ret (10, 20, 3)
# FERJ 1 5_gamma1 R (10, 12) (10, 12)
# enc (11, 20, 4) ret (11, 20, 3)
# FERJ 1 6_gamma2 R (11, 12) (11, 12)
# enc (12, 20, 2) ret (12, 20, 3)
# FERJ 2 2_theta R (12, 6) (12, 6)
# enc (11, 20, 2) ret (11, 20, 3)
# FERJ 2 3_alpha R (11, 6) (11, 6)
# enc (13, 20, 2) ret (13, 20, 3)
# FERJ 2 4_beta R (13, 6) (13, 6)
# enc (10, 20, 2) ret (10, 20, 3)
# FERJ 2 5_gamma1 R (10, 6) (10, 6)
# enc (11, 20, 2) ret (11, 20, 3)
# FERJ 2 6_gamma2 R (11, 6) (11, 6)
# enc (12, 20, 3) ret (12, 20, 3)
# FERJ 5 2_theta R (12, 9) (12, 9)
# enc (11, 20, 3) ret (11, 20, 3)
# FERJ 5 3_alpha R (11, 9) (11, 9)
# enc (13, 20, 3) ret (13, 20, 3)
# FERJ 5 4_beta R (13, 9) (13, 9)
# enc (10, 20, 3) ret (10, 20, 3)
# FERJ 5 5_gamma1 R (10, 9) (10, 9)
# enc (11, 20, 3) ret (11, 20, 3)
# FERJ 5 6_gamma2 R (11, 9) (11, 9)
# enc (12, 20, 3) ret (12, 20, 3)
# FERJ 7 2_theta R (12, 9) (12, 9)
# enc (11, 20, 3) ret (11, 20, 3)
# FERJ 7 3_alpha R (11, 9) (11, 9)
# enc (13, 20, 3) ret (13, 20, 3)
# FERJ 7 4_beta R (13, 9) (13, 9)
# enc (10, 20, 3) ret (10, 20, 3)
# FERJ 7 5_gamma1 R (10, 9) (10, 9)
# enc (11, 20, 3) ret (11, 20, 3)
# FERJ 7 6_gamma2 R (11, 9) (11, 9)
# enc (12, 20, 4) ret (12, 20, 3)
# FERJ 12 2_theta R (12, 12) (12, 12)
# enc (11, 20, 4) ret (11, 20, 3)
# FERJ 12 3_alpha R (11, 12) (11, 12)
# enc (13, 20, 4) ret (13, 20, 3)
# FERJ 12 4_beta R (13, 12) (13, 12)
# enc (10, 20, 4) ret (10, 20, 3)
# FERJ 12 5_gamma1 R (10, 12) (10, 12)
# enc (11, 20, 4) ret (11, 20, 3)
# FERJ 12 6_gamma2 R (11, 12) (11, 12)
# enc (12, 20, 3) ret (12, 20, 3)
# FERJ 13 2_theta R (12, 9) (12, 9)
# enc (11, 20, 3) ret (11, 20, 3)
# FERJ 13 3_alpha R (11, 9) (11, 9)
# enc (13, 20, 3) ret (13, 20, 3)
# FERJ 13 4_beta R (13, 9) (13, 9)
# enc (10, 20, 3) ret (10, 20, 3)
# FERJ 13 5_gamma1 R (10, 9) (10, 9)
# enc (11, 20, 3) ret (11, 20, 3)
# FERJ 13 6_gamma2 R (11, 9) (11, 9)
# enc (12, 20, 3) ret (12, 20, 3)
# FERJ 16 2_theta R (12, 9) (12, 9)
# enc (11, 20, 3) ret (11, 20, 3)
# FERJ 16 3_alpha R (11, 9) (11, 9)
# enc (13, 20, 3) ret (13, 20, 3)
# FERJ 16 4_beta R (13, 9) (13, 9)
# enc (10, 20, 3) ret (10, 20, 3)
# FERJ 16 5_gamma1 R (10, 9) (10, 9)
# enc (11, 20, 3) ret (11, 20, 3)
# FERJ 16 6_gamma2 R (11, 9) (11, 9)
# enc (12, 20, 9) ret (12, 20, 3)
# FERJ 17 2_theta R (12, 27) (12, 27)
# enc (11, 20, 9) ret (11, 20, 3)
# FERJ 17 3_alpha R (11, 27) (11, 27)
# enc (13, 20, 9) ret (13, 20, 3)
# FERJ 17 4_beta R (13, 27) (13, 27)
# enc (10, 20, 9) ret (10, 20, 3)
# FERJ 17 5_gamma1 R (10, 27) (10, 27)
# enc (11, 20, 9) ret (11, 20, 3)
# FERJ 17 6_gamma2 R (11, 27) (11, 27)
# enc (20, 20, 2) ret (20, 20, 3)
# LEFC 1 2_theta R (20, 6) (20, 6)
# enc (24, 20, 2) ret (24, 20, 3)
# LEFC 1 3_alpha R (24, 6) (24, 6)
# enc (23, 20, 2) ret (23, 20, 3)
# LEFC 1 4_beta R (23, 6) (23, 6)
# enc (18, 20, 2) ret (18, 20, 3)
# LEFC 1 5_gamma1 R (18, 6) (18, 6)
# enc (19, 20, 2) ret (19, 20, 3)
# LEFC 1 6_gamma2 R (19, 6) (19, 6)
# enc (20, 20, 5) ret (20, 20, 3)
# LEFC 2 2_theta R (20, 15) (20, 15)
# enc (24, 20, 5) ret (24, 20, 3)
# LEFC 2 3_alpha R (24, 15) (24, 15)
# enc (23, 20, 5) ret (23, 20, 3)
# LEFC 2 4_beta R (23, 15) (23, 15)
# enc (18, 20, 5) ret (18, 20, 3)
# LEFC 2 5_gamma1 R (18, 15) (18, 15)
# enc (19, 20, 5) ret (19, 20, 3)
# LEFC 2 6_gamma2 R (19, 15) (19, 15)
# enc (20, 20, 4) ret (20, 20, 3)
# LEFC 3 2_theta R (20, 12) (20, 12)
# enc (24, 20, 4) ret (24, 20, 3)
# LEFC 3 3_alpha R (24, 12) (24, 12)
# enc (23, 20, 4) ret (23, 20, 3)
# LEFC 3 4_beta R (23, 12) (23, 12)
# enc (18, 20, 4) ret (18, 20, 3)
# LEFC 3 5_gamma1 R (18, 12) (18, 12)
# enc (19, 20, 4) ret (19, 20, 3)
# LEFC 3 6_gamma2 R (19, 12) (19, 12)
# enc (20, 20, 4) ret (20, 20, 3)
# LEFC 4 2_theta R (20, 12) (20, 12)
# enc (24, 20, 4) ret (24, 20, 3)
# LEFC 4 3_alpha R (24, 12) (24, 12)
# enc (23, 20, 4) ret (23, 20, 3)
# LEFC 4 4_beta R (23, 12) (23, 12)
# enc (18, 20, 4) ret (18, 20, 3)
# LEFC 4 5_gamma1 R (18, 12) (18, 12)
# enc (19, 20, 4) ret (19, 20, 3)
# LEFC 4 6_gamma2 R (19, 12) (19, 12)
# enc (20, 20, 6) ret (20, 20, 3)
# LEFC 14 2_theta R (20, 18) (20, 18)
# enc (24, 20, 6) ret (24, 20, 3)
# LEFC 14 3_alpha R (24, 18) (24, 18)
# enc (23, 20, 6) ret (23, 20, 3)
# LEFC 14 4_beta R (23, 18) (23, 18)
# enc (18, 20, 6) ret (18, 20, 3)
# LEFC 14 5_gamma1 R (18, 18) (18, 18)
# enc (19, 20, 6) ret (19, 20, 3)
# LEFC 14 6_gamma2 R (19, 18) (19, 18)
# enc (20, 20, 11) ret (20, 20, 3)
# LEFC 15 2_theta R (20, 33) (20, 33)
# enc (24, 20, 11) ret (24, 20, 3)
# LEFC 15 3_alpha R (24, 33) (24, 33)
# enc (23, 20, 11) ret (23, 20, 3)
# LEFC 15 4_beta R (23, 33) (23, 33)
# enc (18, 20, 11) ret (18, 20, 3)
# LEFC 15 5_gamma1 R (18, 33) (18, 33)
# enc (19, 20, 11) ret (19, 20, 3)
# LEFC 15 6_gamma2 R (19, 33) (19, 33)
# enc (20, 20, 16) ret (20, 20, 3)
# LEFC 16 2_theta R (20, 48) (20, 48)
# enc (24, 20, 16) ret (24, 20, 3)
# LEFC 16 3_alpha R (24, 48) (24, 48)
# enc (23, 20, 16) ret (23, 20, 3)
# LEFC 16 4_beta R (23, 48) (23, 48)
# enc (18, 20, 16) ret (18, 20, 3)
# LEFC 16 5_gamma1 R (18, 48) (18, 48)
# enc (19, 20, 16) ret (19, 20, 3)
# LEFC 16 6_gamma2 R (19, 48) (19, 48)
# enc (20, 20, 7) ret (20, 20, 3)
# LEFC 17 2_theta R (20, 21) (20, 21)
# enc (24, 20, 7) ret (24, 20, 3)
# LEFC 17 3_alpha R (24, 21) (24, 21)
# enc (23, 20, 7) ret (23, 20, 3)
# LEFC 17 4_beta R (23, 21) (23, 21)
# enc (18, 20, 7) ret (18, 20, 3)
# LEFC 17 5_gamma1 R (18, 21) (18, 21)
# enc (19, 20, 7) ret (19, 20, 3)
# LEFC 17 6_gamma2 R (19, 21) (19, 21)
# enc (20, 20, 7) ret (20, 20, 4)
# PIRJ 1 2_theta R (20, 28) (20, 28)
# enc (21, 20, 7) ret (21, 20, 4)
# PIRJ 1 3_alpha R (21, 28) (21, 28)
# enc (18, 20, 7) ret (18, 20, 4)
# PIRJ 1 4_beta R (18, 28) (18, 28)
# enc (17, 20, 7) ret (17, 20, 4)
# PIRJ 1 5_gamma1 R (17, 28) (17, 28)
# enc (20, 20, 7) ret (20, 20, 4)
# PIRJ 1 6_gamma2 R (20, 28) (20, 28)
# enc (20, 20, 4) ret (20, 20, 4)
# PIRJ 4 2_theta R (20, 16) (20, 16)
# enc (21, 20, 4) ret (21, 20, 4)
# PIRJ 4 3_alpha R (21, 16) (21, 16)
# enc (18, 20, 4) ret (18, 20, 4)
# PIRJ 4 4_beta R (18, 16) (18, 16)
# enc (17, 20, 4) ret (17, 20, 4)
# PIRJ 4 5_gamma1 R (17, 16) (17, 16)
# enc (20, 20, 4) ret (20, 20, 4)
# PIRJ 4 6_gamma2 R (20, 16) (20, 16)
# enc (20, 20, 1) ret (20, 20, 4)
# PIRJ 5 2_theta R (20, 4) (20, 4)
# enc (21, 20, 1) ret (21, 20, 4)
# PIRJ 5 3_alpha R (21, 4) (21, 4)
# enc (18, 20, 1) ret (18, 20, 4)
# PIRJ 5 4_beta R (18, 4) (18, 4)
# enc (17, 20, 1) ret (17, 20, 4)
# PIRJ 5 5_gamma1 R (17, 4) (17, 4)
# enc (20, 20, 1) ret (20, 20, 4)
# PIRJ 5 6_gamma2 R (20, 4) (20, 4)
# enc (20, 20, 1) ret (20, 20, 4)
# PIRJ 6 2_theta R (20, 4) (20, 4)
# enc (21, 20, 1) ret (21, 20, 4)
# PIRJ 6 3_alpha R (21, 4) (21, 4)
# enc (18, 20, 1) ret (18, 20, 4)
# PIRJ 6 4_beta R (18, 4) (18, 4)
# enc (17, 20, 1) ret (17, 20, 4)
# PIRJ 6 5_gamma1 R (17, 4) (17, 4)
# enc (20, 20, 1) ret (20, 20, 4)
# PIRJ 6 6_gamma2 R (20, 4) (20, 4)
# enc (20, 20, 1) ret (20, 20, 4)
# PIRJ 7 2_theta R (20, 4) (20, 4)
# enc (21, 20, 1) ret (21, 20, 4)
# PIRJ 7 3_alpha R (21, 4) (21, 4)
# enc (18, 20, 1) ret (18, 20, 4)
# PIRJ 7 4_beta R (18, 4) (18, 4)
# enc (17, 20, 1) ret (17, 20, 4)
# PIRJ 7 5_gamma1 R (17, 4) (17, 4)
# enc (20, 20, 1) ret (20, 20, 4)
# PIRJ 7 6_gamma2 R (20, 4) (20, 4)
# enc (20, 20, 6) ret (20, 20, 4)
# PIRJ 9 2_theta R (20, 24) (20, 24)
# enc (21, 20, 6) ret (21, 20, 4)
# PIRJ 9 3_alpha R (21, 24) (21, 24)
# enc (18, 20, 6) ret (18, 20, 4)
# PIRJ 9 4_beta R (18, 24) (18, 24)
# enc (17, 20, 6) ret (17, 20, 4)
# PIRJ 9 5_gamma1 R (17, 24) (17, 24)
# enc (20, 20, 6) ret (20, 20, 4)
# PIRJ 9 6_gamma2 R (20, 24) (20, 24)
# enc (20, 20, 5) ret (20, 20, 4)
# PIRJ 18 2_theta R (20, 20) (20, 20)
# enc (21, 20, 5) ret (21, 20, 4)
# PIRJ 18 3_alpha R (21, 20) (21, 20)
# enc (18, 20, 5) ret (18, 20, 4)
# PIRJ 18 4_beta R (18, 20) (18, 20)
# enc (17, 20, 5) ret (17, 20, 4)
# PIRJ 18 5_gamma1 R (17, 20) (17, 20)
# enc (20, 20, 5) ret (20, 20, 4)
# PIRJ 18 6_gamma2 R (20, 20) (20, 20)
# enc (42, 20, 3) ret (42, 20, 3)
# SEMC 5 2_theta R (42, 9) (42, 9)
# enc (43, 20, 3) ret (43, 20, 3)
# SEMC 5 3_alpha R (43, 9) (43, 9)
# enc (29, 20, 3) ret (29, 20, 3)
# SEMC 5 4_beta R (29, 9) (29, 9)
# enc (25, 20, 3) ret (25, 20, 3)
# SEMC 5 5_gamma1 R (25, 9) (25, 9)
# enc (13, 20, 3) ret (13, 20, 3)
# SEMC 5 6_gamma2 R (13, 9) (13, 9)
# enc (42, 20, 4) ret (42, 20, 3)
# SEMC 7 2_theta R (42, 12) (42, 12)
# enc (43, 20, 4) ret (43, 20, 3)
# SEMC 7 3_alpha R (43, 12) (43, 12)
# enc (29, 20, 4) ret (29, 20, 3)
# SEMC 7 4_beta R (29, 12) (29, 12)
# enc (25, 20, 4) ret (25, 20, 3)
# SEMC 7 5_gamma1 R (25, 12) (25, 12)
# enc (13, 20, 4) ret (13, 20, 3)
# SEMC 7 6_gamma2 R (13, 12) (13, 12)
# enc (42, 20, 3) ret (42, 20, 3)
# SEMC 8 2_theta R (42, 9) (42, 9)
# enc (43, 20, 3) ret (43, 20, 3)
# SEMC 8 3_alpha R (43, 9) (43, 9)
# enc (29, 20, 3) ret (29, 20, 3)
# SEMC 8 4_beta R (29, 9) (29, 9)
# enc (25, 20, 3) ret (25, 20, 3)
# SEMC 8 5_gamma1 R (25, 9) (25, 9)
# enc (13, 20, 3) ret (13, 20, 3)
# SEMC 8 6_gamma2 R (13, 9) (13, 9)
# enc (42, 20, 3) ret (42, 20, 3)
# SEMC 9 2_theta R (42, 9) (42, 9)
# enc (43, 20, 3) ret (43, 20, 3)
# SEMC 9 3_alpha R (43, 9) (43, 9)
# enc (29, 20, 3) ret (29, 20, 3)
# SEMC 9 4_beta R (29, 9) (29, 9)
# enc (25, 20, 3) ret (25, 20, 3)
# SEMC 9 5_gamma1 R (25, 9) (25, 9)
# enc (13, 20, 3) ret (13, 20, 3)
# SEMC 9 6_gamma2 R (13, 9) (13, 9)
# enc (42, 20, 7) ret (42, 20, 3)
# SEMC 10 2_theta R (42, 21) (42, 21)
# enc (43, 20, 7) ret (43, 20, 3)
# SEMC 10 3_alpha R (43, 21) (43, 21)
# enc (29, 20, 7) ret (29, 20, 3)
# SEMC 10 4_beta R (29, 21) (29, 21)
# enc (25, 20, 7) ret (25, 20, 3)
# SEMC 10 5_gamma1 R (25, 21) (25, 21)
# enc (13, 20, 7) ret (13, 20, 3)
# SEMC 10 6_gamma2 R (13, 21) (13, 21)
# enc (42, 20, 4) ret (42, 20, 3)
# SEMC 11 2_theta R (42, 12) (42, 12)
# enc (43, 20, 4) ret (43, 20, 3)
# SEMC 11 3_alpha R (43, 12) (43, 12)
# enc (29, 20, 4) ret (29, 20, 3)
# SEMC 11 4_beta R (29, 12) (29, 12)
# enc (25, 20, 4) ret (25, 20, 3)
# SEMC 11 5_gamma1 R (25, 12) (25, 12)
# enc (13, 20, 4) ret (13, 20, 3)
# SEMC 11 6_gamma2 R (13, 12) (13, 12)
# enc (42, 20, 6) ret (42, 20, 3)
# SEMC 12 2_theta R (42, 18) (42, 18)
# enc (43, 20, 6) ret (43, 20, 3)
# SEMC 12 3_alpha R (43, 18) (43, 18)
# enc (29, 20, 6) ret (29, 20, 3)
# SEMC 12 4_beta R (29, 18) (29, 18)
# enc (25, 20, 6) ret (25, 20, 3)
# SEMC 12 5_gamma1 R (25, 18) (25, 18)
# enc (13, 20, 6) ret (13, 20, 3)
# SEMC 12 6_gamma2 R (13, 18) (13, 18)
# enc (42, 20, 10) ret (42, 20, 3)
# SEMC 13 2_theta R (42, 30) (42, 30)
# enc (43, 20, 10) ret (43, 20, 3)
# SEMC 13 3_alpha R (43, 30) (43, 30)
# enc (29, 20, 10) ret (29, 20, 3)
# SEMC 13 4_beta R (29, 30) (29, 30)
# enc (25, 20, 10) ret (25, 20, 3)
# SEMC 13 5_gamma1 R (25, 30) (25, 30)
# enc (13, 20, 10) ret (13, 20, 3)
# SEMC 13 6_gamma2 R (13, 30) (13, 30)
# enc (37, 20, 3) ret (37, 20, 3)
# VACJ 10 2_theta R (37, 9) (37, 9)
# enc (34, 20, 3) ret (34, 20, 3)
# VACJ 10 3_alpha R (34, 9) (34, 9)
# enc (30, 20, 3) ret (30, 20, 3)
# VACJ 10 4_beta R (30, 9) (30, 9)
# enc (36, 20, 3) ret (36, 20, 3)
# VACJ 10 5_gamma1 R (36, 9) (36, 9)
# enc (39, 20, 3) ret (39, 20, 3)
# VACJ 10 6_gamma2 R (39, 9) (39, 9)
# enc (37, 20, 3) ret (37, 20, 3)
# VACJ 11 2_theta R (37, 9) (37, 9)
# enc (34, 20, 3) ret (34, 20, 3)
# VACJ 11 3_alpha R (34, 9) (34, 9)
# enc (30, 20, 3) ret (30, 20, 3)
# VACJ 11 4_beta R (30, 9) (30, 9)
# enc (36, 20, 3) ret (36, 20, 3)
# VACJ 11 5_gamma1 R (36, 9) (36, 9)
# enc (39, 20, 3) ret (39, 20, 3)
# VACJ 11 6_gamma2 R (39, 9) (39, 9)
# enc (37, 20, 2) ret (37, 20, 3)
# VACJ 12 2_theta R (37, 6) (37, 6)
# enc (34, 20, 2) ret (34, 20, 3)
# VACJ 12 3_alpha R (34, 6) (34, 6)
# enc (30, 20, 2) ret (30, 20, 3)
# VACJ 12 4_beta R (30, 6) (30, 6)
# enc (36, 20, 2) ret (36, 20, 3)
# VACJ 12 5_gamma1 R (36, 6) (36, 6)
# enc (39, 20, 2) ret (39, 20, 3)
# VACJ 12 6_gamma2 R (39, 6) (39, 6)
# enc (37, 20, 4) ret (37, 20, 3)
# VACJ 13 2_theta R (37, 12) (37, 12)
# enc (34, 20, 4) ret (34, 20, 3)
# VACJ 13 3_alpha R (34, 12) (34, 12)
# enc (30, 20, 4) ret (30, 20, 3)
# VACJ 13 4_beta R (30, 12) (30, 12)
# enc (36, 20, 4) ret (36, 20, 3)
# VACJ 13 5_gamma1 R (36, 12) (36, 12)
# enc (39, 20, 4) ret (39, 20, 3)
# VACJ 13 6_gamma2 R (39, 12) (39, 12)
# enc (37, 20, 3) ret (37, 20, 3)
# VACJ 14 2_theta R (37, 9) (37, 9)
# enc (34, 20, 3) ret (34, 20, 3)
# VACJ 14 3_alpha R (34, 9) (34, 9)
# enc (30, 20, 3) ret (30, 20, 3)
# VACJ 14 4_beta R (30, 9) (30, 9)
# enc (36, 20, 3) ret (36, 20, 3)
# VACJ 14 5_gamma1 R (36, 9) (36, 9)
# enc (39, 20, 3) ret (39, 20, 3)
# VACJ 14 6_gamma2 R (39, 9) (39, 9)
# enc (37, 20, 2) ret (37, 20, 3)
# VACJ 15 2_theta R (37, 6) (37, 6)
# enc (34, 20, 2) ret (34, 20, 3)
# VACJ 15 3_alpha R (34, 6) (34, 6)
# enc (30, 20, 2) ret (30, 20, 3)
# VACJ 15 4_beta R (30, 6) (30, 6)
# enc (36, 20, 2) ret (36, 20, 3)
# VACJ 15 5_gamma1 R (36, 6) (36, 6)
# enc (39, 20, 2) ret (39, 20, 3)
# VACJ 15 6_gamma2 R (39, 6) (39, 6)
# enc (37, 20, 3) ret (37, 20, 3)
# VACJ 16 2_theta R (37, 9) (37, 9)
# enc (34, 20, 3) ret (34, 20, 3)
# VACJ 16 3_alpha R (34, 9) (34, 9)
# enc (30, 20, 3) ret (30, 20, 3)
# VACJ 16 4_beta R (30, 9) (30, 9)
# enc (36, 20, 3) ret (36, 20, 3)
# VACJ 16 5_gamma1 R (36, 9) (36, 9)
# enc (39, 20, 3) ret (39, 20, 3)
# VACJ 16 6_gamma2 R (39, 9) (39, 9)
# enc (37, 20, 2) ret (37, 20, 3)
# VACJ 17 2_theta R (37, 6) (37, 6)
# enc (34, 20, 2) ret (34, 20, 3)
# VACJ 17 3_alpha R (34, 6) (34, 6)
# enc (30, 20, 2) ret (30, 20, 3)
# VACJ 17 4_beta R (30, 6) (30, 6)
# enc (36, 20, 2) ret (36, 20, 3)
# VACJ 17 5_gamma1 R (36, 6) (36, 6)
# enc (39, 20, 2) ret (39, 20, 3)
# VACJ 17 6_gamma2 R (39, 6) (39, 6)

# %% [markdown]
# ### Compute TPSim within low and high conditions
# 1 - create power npz files for common electrodes by subj and freq <br>
# 2 - compute the TPSim for Low and High conditions (all combinations) <br>

# %%
from numpy.random import permutation
from itertools import product
from brainpipe.statistics import *

###############################################################################
st = study('Olfacto')
path_files = join(st.path,'feature/TPSim_Enc_Ret_By_Odor_all/')
path2save = join(path_files, 'TPS_R_p_by_cond/')
###############################################################################
if not exists(path2save):
    makedirs(path2save)
###############################################################################
sessions = ['E','R']
su_codes = ['S0','S1','S2','S3','S4','S5']
freqs = ['0_theta', '1_alpha', '2_beta','3_gamma']
method = ['s_Mail_RL']
su_odor_groups = {'CHAF' : {'low':['1','2','4','5'],
                              'high':['3','8','7','9']},
                    'VACJ' : {'low':['11','14','12','10'],
                              'high':['15','17','16','13']},
                    'SEMC' : {'low':['7','10','11','12','13'],
                              'high':['5','8','9']},
                    'PIRJ' : {'low':['1','9','5'],
                              'high':['4','6','7','18']},
                    'LEFC' : {'low':['15','2','1','16'],
                              'high':['14','3','4','17']},
                    'FERJ' : {'low':['7','2','16','17'],
                              'high':['12','1','5','13']},}

for su in (sorted(su_odor_groups)):
    for sess in sessions:
        for cond in su_odor_groups[su]:
            big_concat = np.array([])
            for freq in freqs:
                concat = np.array([])
                for odor in su_odor_groups[su][cond]:
                    mat = np.load(path_files+su+'_odor'+str(odor)+'_'+sess+'_pow'+freq+'.npz',
                                 allow_pickle=True)
                    power = mat['xpow']
#                     print(su, freq, sess, cond, odor, mat.files)
                    concat = np.concatenate((concat,power), axis=2) if np.size(concat) else power
                #concat by freq
                big_concat = np.concatenate((big_concat,concat[np.newaxis]), axis=0) if np.size(big_concat) else concat[np.newaxis]
            #SAVE BIG_CONCAT FILE
            dico = {'xpow':big_concat, 'label':mat['label'],'channel':mat['channel'],'xyz':mat['xyz']}
            np.savez(path2save+'Pow_'+su+'_'+sess+'_'+cond+'_allfreqs.npz',**dico)
# Out:
# -> Olfacto loaded

# %%
from numpy.random import permutation
from brainpipe.statistics import *

###############################################################################
st = study('Olfacto')
path_files = join(st.path,'database/')
#path_npz = join(path_files,'TPSim_power_data/Power_all_elecs_E_R_by_cond/')
path2save = join(path_files,'TPSim_Enc_Ret_By_Odor_By_Cond/TPS_by_cond_raw/')
# npz_enc = join(path_npz, 'Pow_{}_E_{}_allfreqs.npz')
npz_enc = join(path_files, 'Encoding_EpiPerf_LowHigh/{}_odor_{}_common_renamed_OFC_HC.npz')
npz_ret = join(path_files, 'Retrieval_EpiPerf_LowHigh/{}_odor_{}_common_renamed_OFC_HC.npz')
# npz_ret = join(path_npz, 'Pow_{}_R_{}_allfreqs.npz')
savename = 'TPS_spear_{}_cond_{}_raw_3s.npz'
###############################################################################
if not exists(path2save):
    makedirs(path2save)
###############################################################################
#freqs = ['delta','theta', 'alpha', 'beta','low_gamma','high_gamma']
# freqs = ['0_theta', '1_alpha', '2_beta','3_gamma']
#method = ['s_Mail_RL']
conds = ['low','high']
subjects = ['CHAF','VACJ','SEMC','PIRJ','LEFC','FERJ']
to_take = [1024,2560]

for su in subjects:
    for cond in conds:
        #for f,freq in enumerate(freqs):
        mat_enc = np.load(npz_enc.format(su,cond),allow_pickle=True)
        mat_ret = np.load(npz_ret.format(su,cond),allow_pickle=True)
        pow_enc = mat_enc['x'][:,to_take[0]:to_take[1],:]
        pow_ret = mat_ret['x'][:,to_take[0]:to_take[1],:]
        print('enc',pow_enc.shape,'ret',pow_ret.shape)
        R_freq, p_freq = np.array([]), np.array([])
        for elec in range(pow_enc.shape[0]):
            pow0 = pow_enc[elec,...]
            pow1 = pow_ret[elec,...]
            R_trials, p_trials = np.array([]), np.array([])
            for t0, t1 in product(range(pow0.shape[1]),range(pow1.shape[1])):
#                     print(t0,t1,pow0[:,t0].shape,pow1[:,t1].shape)
                R, p = stats.pearsonr(pow0[:,t0],pow1[:,t1])
                D = R # <<<<<<< HERE TO CHANGE FOR DISTANCE COMPUTATIONS
                R_trials = np.vstack((R_trials,D)) if np.size(R_trials) else D
                p_trials = np.vstack((p_trials,p)) if np.size(p_trials) else p
#                     print(R_trials.shape,p_trials.shape)
            R_freq = np.vstack((R_freq,R_trials.T)) if np.size(R_freq) else R_trials.T
            p_freq = np.vstack((p_freq,p_trials.T)) if np.size(p_freq) else p_trials.T
#             print(R_freq.shape, p_freq.shape)
        print(su,cond,'R',R_freq.shape, p_freq.shape)
        mat = {'tps':R_freq, 'pval':p_freq,'label':mat_enc['labels'],
               'channel':mat_enc['channels'], 'xyz':mat_enc['xyz']}
        np.savez(path2save+savename.format(su,cond),**mat)
# Out:
# -> Olfacto loaded
# enc (57, 1536, 6) ret (57, 1536, 12)
# CHAF low R (57, 72) (57, 72)
# enc (57, 1536, 15) ret (57, 1536, 12)
# CHAF high R (57, 180) (57, 180)
# enc (48, 1536, 11) ret (48, 1536, 12)
# VACJ low R (48, 132) (48, 132)
# enc (48, 1536, 11) ret (48, 1536, 12)
# VACJ high R (48, 132) (48, 132)
# enc (62, 1536, 31) ret (62, 1536, 15)
# SEMC low R (62, 465) (62, 465)
# enc (62, 1536, 9) ret (62, 1536, 9)
# SEMC high R (62, 81) (62, 81)
# enc (30, 1536, 14) ret (30, 1536, 16)
# PIRJ low R (30, 224) (30, 224)
# enc (30, 1536, 11) ret (30, 1536, 16)
# PIRJ high R (30, 176) (30, 176)
# enc (36, 1536, 34) ret (36, 1536, 12)
# LEFC low R (36, 408) (36, 408)
# enc (36, 1536, 21) ret (36, 1536, 12)
# LEFC high R (36, 252) (36, 252)
# enc (45, 1536, 17) ret (45, 1536, 12)
# FERJ low R (45, 204) (45, 204)
# enc (45, 1536, 14) ret (45, 1536, 12)
# FERJ high R (45, 168) (45, 168)

# %% [markdown]
# ### Create the TPS files for each condition

# %%
from numpy.random import permutation
from itertools import product
from brainpipe.statistics import *

###############################################################################
st = study('Olfacto')
path_channels = join(st.path,'feature/TPSim_Enc_Ret_By_Odor/')
path_files = join(path_channels,'TPS_R_p_by_odor/')
path2save = join(path_channels, 'TPS_R_p_by_cond/')
###############################################################################
if not exists(path2save):
    makedirs(path2save)
###############################################################################

su_codes = ['S0','S1','S2','S3','S4','S5']
freqs = ['2_theta', '3_alpha', '4_beta','5_gamma1','6_gamma2']
method = ['s_Mail_RL']
su_odor_groups = {'CHAF' : {'low':['1','2','4','5'],
                              'high':['3','8','7','9']},
                    'VACJ' : {'low':['11','14','12','10'],
                              'high':['15','17','16','13']},
                    'SEMC' : {'low':['7','10','11','12','13'],
                              'high':['5','8','9']},
                    'PIRJ' : {'low':['1','9','5'],
                              'high':['4','6','7','18']},
                    'LEFC' : {'low':['15','2','1','16'],
                              'high':['14','3','4','17']},
                    'FERJ' : {'low':['7','2','16','17'],
                              'high':['12','1','5','13']},}

for su in (sorted(su_odor_groups)):
    for cond in su_odor_groups[su]:
        for freq in freqs:
            concat = np.array([])
            for odor in su_odor_groups[su][cond]:
                tps = np.load(path_files+'TPS_spear_'+su+'_odor_'+str(odor)+'_'+freq+'.npz')['tps']
                #print(su, freq, cond, odor, tps.shape)
                concat = np.concatenate((concat,tps), axis=1) if np.size(concat) else tps
            print(su, freq, cond, concat.shape)
            data = np.load(path_channels+su+'_odor'+str(odor)+'_E_pow'+freq+'.npz')
            mat = {'TPS':concat, 'label':data['label'],'channel':data['channel'],'xyz':data['xyz']}
            np.savez(path2save+'TPS_spear_'+su+'_odor_'+cond+'_'+freq+'.npz',**mat)
# Out:
# -> Olfacto loaded
# CHAF 2_theta high (29, 45)
# CHAF 3_alpha high (40, 45)
# CHAF 4_beta high (35, 45)
# CHAF 5_gamma1 high (21, 45)
# CHAF 6_gamma2 high (13, 45)
# CHAF 2_theta low (29, 18)
# CHAF 3_alpha low (40, 18)
# CHAF 4_beta low (35, 18)
# CHAF 5_gamma1 low (21, 18)
# CHAF 6_gamma2 low (13, 18)
# FERJ 2_theta high (12, 42)
# FERJ 3_alpha high (11, 42)
# FERJ 4_beta high (13, 42)
# FERJ 5_gamma1 high (10, 42)
# FERJ 6_gamma2 high (11, 42)
# FERJ 2_theta low (12, 51)
# FERJ 3_alpha low (11, 51)
# FERJ 4_beta low (13, 51)
# FERJ 5_gamma1 low (10, 51)
# FERJ 6_gamma2 low (11, 51)
# LEFC 2_theta high (20, 63)
# LEFC 3_alpha high (24, 63)
# LEFC 4_beta high (23, 63)
# LEFC 5_gamma1 high (18, 63)
# LEFC 6_gamma2 high (19, 63)
# LEFC 2_theta low (20, 102)
# LEFC 3_alpha low (24, 102)
# LEFC 4_beta low (23, 102)
# LEFC 5_gamma1 low (18, 102)
# LEFC 6_gamma2 low (19, 102)
# PIRJ 2_theta high (20, 44)
# PIRJ 3_alpha high (21, 44)
# PIRJ 4_beta high (18, 44)
# PIRJ 5_gamma1 high (17, 44)
# PIRJ 6_gamma2 high (20, 44)
# PIRJ 2_theta low (20, 56)
# PIRJ 3_alpha low (21, 56)
# PIRJ 4_beta low (18, 56)
# PIRJ 5_gamma1 low (17, 56)
# PIRJ 6_gamma2 low (20, 56)
# SEMC 2_theta high (42, 27)
# SEMC 3_alpha high (43, 27)
# SEMC 4_beta high (29, 27)
# SEMC 5_gamma1 high (25, 27)
# SEMC 6_gamma2 high (13, 27)
# SEMC 2_theta low (42, 93)
# SEMC 3_alpha low (43, 93)
# SEMC 4_beta low (29, 93)
# SEMC 5_gamma1 low (25, 93)
# SEMC 6_gamma2 low (13, 93)
# VACJ 2_theta high (37, 33)
# VACJ 3_alpha high (34, 33)
# VACJ 4_beta high (30, 33)
# VACJ 5_gamma1 high (36, 33)
# VACJ 6_gamma2 high (39, 33)
# VACJ 2_theta low (37, 33)
# VACJ 3_alpha low (34, 33)
# VACJ 4_beta low (30, 33)
# VACJ 5_gamma1 low (36, 33)
# VACJ 6_gamma2 low (39, 33)

# %% [markdown]
# ### Compute single-trial plots power to illustrate TPSim

# %%
from os.path import join, exists
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MaxNLocator
from brainpipe.visual import *

###############################################################################
st = study('Olfacto')
path_npz = join(st.path,'feature/TPSim_Enc_Ret_By_Odor_all/')
path2save = join(path_npz, 'plots/')
npz_enc = join(path_npz, '{}_odor{}_E_pow{}.npz')
npz_ret = join(path_npz, '{}_odor{}_R_pow{}.npz')
###############################################################################
if not exists(path2save):
    makedirs(path2save)
###############################################################################
th = '0.01'
method = ['s_Mail_RL']
freq = '0_theta'
odors_su = {'LEFC': {1:4,2:0,3:6,4:12,14:96,15:2,16:4,17:68},
            'PIRJ': {4:36,9:2,1:4,18:32,6:34,5:4,7:68}, #missing odor 15
            'FERJ': {16:6,17:6,5:8,7:6,12:8,13:8,2:6,1:10}}

for s,su in enumerate(sorted(odors_su)):
    for odor in sorted(odors_su[su]):
        mat_enc = np.load(npz_enc.format(su,odor,freq))
        mat_ret = np.load(npz_ret.format(su,odor,freq))
        pow_enc = mat_enc['xpow'][:,27:47,:]
        pow_ret = mat_ret['xpow'][:,27:47,:]
        label_E = mat_enc['label']
        label_R= mat_ret['label']
        time = np.arange(0,2,0.1)
        print('enc',pow_enc.shape,'ret',pow_ret.shape)
#         print('elecs names',label_E, label_R)
        if su == 'FERJ':
            elecs = [2] 
        elif su == 'LEFC':
            elecs = [8] 
        else:
            elecs = [3,10,12]
        for elec in elecs:
            for t0, t1 in product(range(pow_enc.shape[-1]),range(pow_ret.shape[-1])):
                pow0 = pow_enc[elec,:,t0]
                pow1 = pow_ret[elec,:,t1]
                max0, max1 = max(pow0), max(pow1)
                pow0, pow1 = pow0/max0, pow1/max1
                xfmt = ScalarFormatter(useMathText=True)
                rmaxis(plt.gca(), ['right', 'top'])
                xfmt.set_powerlimits((0,3))               
                rmaxis(plt.gca(), ['right', 'top'])
                plt.gca().yaxis.set_major_locator(MaxNLocator(3,integer=True))
                plt.plot(time, pow0, '-', color='purple', linewidth=2, label='Encoding')
                plt.plot(time, pow1, '-', color='orange', linewidth=2, label='Retrieval')
                plt.savefig(path2save+'plot_E_R_odor{}_{}_{}_trials{}_{}.png'.format(odor,su,elec,t0,t1))
                plt.savefig(path2save+'plot_E_R_odor{}_{}_{}_trials{}_{}.pdf'.format(odor,su,elec,t0,t1))
                plt.clf()
                plt.close()
            max0_2, max1_2 = np.max(pow_enc[elec]), np.max(pow_ret[elec])
            x = np.concatenate((pow_enc[elec]/max0_2,pow_ret[elec]/max1_2),axis=1)
            y = [0]*pow_enc.shape[-1] + [1]*pow_ret.shape[-1]
            BorderPlot(time, x, y=y, kind='sem', alpha=0.2, color=['purple','orange'],linewidth=2, 
                           ncol=1, xlabel='Time (s)',ylabel = r'Power', legend=['Encoding','Retrieval'])
            rmaxis(plt.gca(), ['right', 'top'])
            plt.legend(loc=0, handletextpad=0.1, frameon=False)
            plt.gca().yaxis.set_major_locator(MaxNLocator(3,integer=True))
            plt.savefig(path2save+'plot_E_R_odor{}_{}_{}_{}.pdf'.format(odor,su,elec,'mean'))            
            plt.savefig(path2save+'plot_E_R_odor{}_{}_{}_{}.png'.format(odor,su,elec,'mean'))
            plt.clf()
            plt.close()
# Out:
# -> Olfacto loaded
# enc (45, 20, 4) ret (45, 20, 3)
# enc (45, 20, 2) ret (45, 20, 3)
# enc (45, 20, 3) ret (45, 20, 3)
# enc (45, 20, 3) ret (45, 20, 3)
# enc (45, 20, 4) ret (45, 20, 3)
# enc (45, 20, 3) ret (45, 20, 3)
# enc (45, 20, 3) ret (45, 20, 3)
# enc (45, 20, 9) ret (45, 20, 3)
# enc (36, 20, 2) ret (36, 20, 3)
# enc (36, 20, 5) ret (36, 20, 3)
# enc (36, 20, 4) ret (36, 20, 3)
# enc (36, 20, 4) ret (36, 20, 3)
# enc (36, 20, 6) ret (36, 20, 3)
# enc (36, 20, 11) ret (36, 20, 3)
# enc (36, 20, 16) ret (36, 20, 3)
# enc (36, 20, 7) ret (36, 20, 3)
# enc (30, 20, 7) ret (30, 20, 4)
# enc (30, 20, 4) ret (30, 20, 4)
# enc (30, 20, 1) ret (30, 20, 4)
# enc (30, 20, 1) ret (30, 20, 4)
# enc (30, 20, 1) ret (30, 20, 4)
# enc (30, 20, 6) ret (30, 20, 4)
# enc (30, 20, 5) ret (30, 20, 4)
