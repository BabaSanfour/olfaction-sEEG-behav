# %% [markdown]
# ## Import Libraries

# %%
from os import path, makedirs
from itertools import product
import numpy as np
from brainpipe.system import study

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import StratifiedKFold as SKFold
from sklearn.model_selection import permutation_test_score
from sklearn.metrics import roc_auc_score

# %%
"""
Compute classification power in time for allfreqs and electrodes
"""

st = study('Ripples')
pow_path = path.join(st.path,'feature/')
reps = ['Encoding/', 'Retrieval_new_odors/', 'Retrieval_new_rec/']
conds = ['low','high']
freqs = ['ripple', 'low_freq','HFA']
subjects = ['LEFC','CHAF','VACJ','SEMC','FERJ','PIRJ']
nperm = 1000

for rep in reps:
    pow_name = path.join(pow_path+rep, '{}_cond={}_bipo_feat_norm.npz')
    path_save = path.join(st.path, 'classified/'+rep)
    if not path.exists(path_save):
        makedirs(path_save)
    clf_name = path.join(path_save, '{}_LDA_clf_{}_{}_{}.npz')    

    for su in subjects:
        mat0 = np.load(pow_name.format(su,conds[0]), allow_pickle=True)
        mat1 = np.load(pow_name.format(su,conds[1]), allow_pickle=True)
        if rep != 'Retrieval_new_rec/':
            to_take, time = [54, 100], mat0['time']-3
        else:
            to_take, time = [39, 120], mat0['time']-5

        for i,freq in enumerate(freqs):
            id_f = [i for i,f in enumerate(mat1['fname']) if f==freq][0]
            pow_list = []
            #=========================== Load Power files (nfreq, nelec, nwin, ntrial) =================================    
            pow_list.append(mat0['xpow'][id_f,:,to_take[0]:to_take[1],:])
            nelecs, npts, _ = mat0['xpow'][id_f,:,to_take[0]:to_take[1],:].shape
            pow_list.append(mat1['xpow'][id_f,:,to_take[0]:to_take[1],:])
            print (su,mat0.files, 'xpow shape: ', [pow.shape for pow in pow_list])
        
            #=========================== Create dict for all results =================================    
            name_classif = clf_name.format(su,freq,conds[0],conds[1])
            if not path.exists(name_classif):
                kwargs = {}
                kwargs['names'], kwargs['channels'] = mat0['new_labels'], mat0['channels']
                kwargs['xyz'], kwargs['time'] = mat0['xyz'], time

                # =========================== Select Power for 1 elec 1 freq =================================                 
                permut,auc = np.zeros((nelecs,npts,nperm)),np.zeros((nelecs,npts))
                for elec_num in range(nelecs):
                    print('--» processing',su, 'elec', elec_num,'/',nelecs, 'freq',freq)
                    pow_data_elec = [power[elec_num].swapaxes(0,1) for power in pow_list]

                    # create a data matrix, concatenate along the trial dimension
                    x = np.concatenate(pow_data_elec, axis=0)
                    print ('Size of the concatenated data: ', x.shape)
                    y = np.hstack([np.array([i]*len(power)) for i, power in enumerate(pow_data_elec)])
                    print ('Size of label for classif: ', len(y))

                    for t in range(npts):
                        X_t = x[:,t][:,np.newaxis]
                        clf = LDA()
                        cv = SKFold(5)
                        score, permutation_scores, pvalue = permutation_test_score(
                        clf, X_t, y, scoring="roc_auc", cv=cv, n_permutations=nperm, n_jobs=-1)
                        permut[elec_num,t] += permutation_scores
                        auc[elec_num,t] += score
    #                     print("clf score for %t %s (pvalue : %s)" % (t, score, pvalue))
                kwargs['perm'], kwargs['auc'] = permut, auc
                #Save plots
                np.savez(name_classif, **kwargs)
                del x, y, pow_data_elec, permutation_scores, score
            else:
                print(name_classif, 'already computed')
        del pow_list
# Out:
# -> Ripples loaded
# LEFC ['f', 'baseline', 'split', 'norm', 'width', 'step', 'time', 'xpow', 'pval_xpow', 'fname', 'new_labels', 'channels', 'labels', 'xyz'] xpow shape:  [(189, 46, 34), (189, 46, 21)]
# --» processing LEFC elec 0 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 1 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 2 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 3 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 4 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 5 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 6 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 7 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 8 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 9 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 10 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 11 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 12 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 13 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 14 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 15 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 16 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 17 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 18 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 19 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 20 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 21 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 22 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 23 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 24 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 25 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 26 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 27 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 28 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 29 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 30 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 31 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 32 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 33 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 34 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 35 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 36 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 37 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 38 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 39 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 40 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 41 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 42 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 43 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 44 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 45 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 46 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 47 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 48 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 49 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 50 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 51 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 52 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 53 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 54 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 55 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 56 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 57 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 58 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 59 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 60 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 61 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 62 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 63 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 64 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 65 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 66 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 67 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 68 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 69 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 70 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 71 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 72 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 73 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 74 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 75 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 76 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 77 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 78 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 79 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 80 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 81 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 82 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 83 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 84 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 85 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 86 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 87 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 88 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 89 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 90 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 91 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 92 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 93 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 94 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 95 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 96 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 97 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 98 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 99 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 100 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 101 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 102 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 103 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 104 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 105 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 106 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 107 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 108 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 109 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 110 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 111 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 112 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 113 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 114 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 115 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 116 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 117 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 118 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 119 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 120 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 121 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 122 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 123 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 124 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 125 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 126 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 127 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 128 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 129 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 130 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 131 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 132 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 133 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 134 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 135 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 136 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 137 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 138 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 139 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 140 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 141 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 142 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 143 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 144 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 145 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 146 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 147 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 148 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 149 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 150 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 151 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 152 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 153 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 154 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 155 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 156 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 157 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 158 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 159 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 160 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 161 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 162 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 163 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 164 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 165 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 166 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 167 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 168 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 169 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 170 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 171 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 172 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 173 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 174 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 175 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 176 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 177 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 178 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 179 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 180 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 181 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 182 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 183 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 184 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 185 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 186 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 187 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 188 / 189 freq ripple
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# LEFC ['f', 'baseline', 'split', 'norm', 'width', 'step', 'time', 'xpow', 'pval_xpow', 'fname', 'new_labels', 'channels', 'labels', 'xyz'] xpow shape:  [(189, 46, 34), (189, 46, 21)]
# --» processing LEFC elec 0 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 1 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 2 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 3 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 4 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 5 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 6 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 7 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 8 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 9 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 10 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 11 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 12 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 13 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 14 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 15 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 16 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 17 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 18 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 19 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 20 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 21 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 22 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 23 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 24 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 25 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 26 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 27 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 28 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 29 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 30 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 31 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 32 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 33 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 34 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 35 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 36 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 37 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 38 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 39 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 40 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 41 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 42 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 43 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 44 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 45 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 46 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 47 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 48 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 49 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 50 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 51 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 52 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 53 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 54 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 55 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 56 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 57 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 58 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 59 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 60 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 61 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 62 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 63 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 64 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 65 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 66 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 67 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 68 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 69 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 70 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 71 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 72 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 73 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 74 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 75 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 76 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 77 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 78 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 79 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 80 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 81 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 82 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 83 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 84 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 85 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 86 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 87 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 88 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 89 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 90 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 91 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 92 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 93 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 94 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 95 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 96 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 97 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 98 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 99 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 100 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 101 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 102 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 103 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 104 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 105 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 106 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 107 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 108 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 109 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 110 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 111 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 112 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 113 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 114 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 115 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 116 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 117 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 118 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 119 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 120 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 121 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 122 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 123 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 124 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 125 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 126 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 127 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 128 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 129 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 130 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 131 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 132 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 133 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 134 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 135 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 136 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 137 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 138 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 139 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 140 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 141 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 142 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 143 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 144 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 145 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 146 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 147 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 148 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 149 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 150 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 151 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 152 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 153 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 154 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 155 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 156 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 157 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 158 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 159 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 160 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 161 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 162 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 163 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 164 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 165 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 166 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 167 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 168 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 169 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 170 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 171 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 172 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 173 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 174 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 175 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 176 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 177 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 178 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 179 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 180 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 181 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 182 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 183 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 184 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 185 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 186 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 187 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 188 / 189 freq low_freq
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# LEFC ['f', 'baseline', 'split', 'norm', 'width', 'step', 'time', 'xpow', 'pval_xpow', 'fname', 'new_labels', 'channels', 'labels', 'xyz'] xpow shape:  [(189, 46, 34), (189, 46, 21)]
# --» processing LEFC elec 0 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 1 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 2 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 3 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 4 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 5 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 6 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 7 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 8 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 9 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 10 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 11 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 12 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 13 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 14 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 15 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 16 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 17 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 18 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# --» processing LEFC elec 19 / 189 freq HFA
# Size of the concatenated data:  (55, 46)
# Size of label for classif:  55
# ...
# exception calling callback for <Future at 0x7f8ef9ec02b0 state=finished raised WorkerInterrupt>
# Traceback (most recent call last):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# exception calling callback for <Future at 0x7f8efa122898 state=finished raised WorkerInterrupt>
# Traceback (most recent call last):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# exception calling callback for <Future at 0x7f8ef9ec9ac8 state=finished raised WorkerInterrupt>
# Traceback (most recent call last):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# exception calling callback for <Future at 0x7f8efa1f8e48 state=finished raised WorkerInterrupt>
# Traceback (most recent call last):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# exception calling callback for <Future at 0x7f8ef9dd4320 state=finished returned list>
# Traceback (most recent call last):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# exception calling callback for <Future at 0x7f8ef9d3c4a8 state=finished returned list>
# Traceback (most recent call last):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# exception calling callback for <Future at 0x7f8ef9d3c6d8 state=finished returned list>
# Traceback (most recent call last):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# exception calling callback for <Future at 0x7f8ef9fe9b00 state=finished returned list>
# Traceback (most recent call last):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# exception calling callback for <Future at 0x7f8ef9d57978 state=finished returned list>
# Traceback (most recent call last):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# exception calling callback for <Future at 0x7f8ef9e93cf8 state=finished returned list>
# Traceback (most recent call last):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# ----------------------------------------------------------
# KeyboardInterrupt        Traceback (most recent call last)
# <ipython-input-2-5fe41fe8a306> in <module>()
#      59                         cv = SKFold(5)
#      60                         score, permutation_scores, pvalue = permutation_test_score(
# ---> 61                         clf, X_t, y, scoring="roc_auc", cv=cv, n_permutations=nperm, n_jobs=-1)
#      62                         permut[elec_num,t] += permutation_scores
#      63                         auc[elec_num,t] += score
#
# ~/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in permutation_test_score(estimator, X, y, groups, cv, n_permutations, n_jobs, random_state, verbose, scoring)
#    1046             clone(estimator), X, _shuffle(y, groups, random_state),
#    1047             groups, cv, scorer)
# -> 1048         for _ in range(n_permutations))
#    1049     permutation_scores = np.array(permutation_scores)
#    1050     pvalue = (np.sum(permutation_scores >= score) + 1.0) / (n_permutations + 1)
#
# ~/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     826             # we empty it and Python list are not thread-safe by default hence
#     827             # the use of the lock
# --> 828             with self._lock:
#     829                 job = self._jobs.pop(0)
#     830
#
# KeyboardInterrupt:
# exception calling callback for <Future at 0x7f8efa22b320 state=finished returned list>
# Traceback (most recent call last):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
