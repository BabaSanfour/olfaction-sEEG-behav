# %% [markdown]
# ## Import Libraries

# %%
from os import path, makedirs
from itertools import product
import numpy as np
import scipy.io as sio

from brainpipe.system import study
from brainpipe.statistics import *
from utils import rename_elecs

# %% [markdown]
# ## Power Decoding - Partial//Detailed Encoding
# ### For ALL time points

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import StratifiedKFold as SKFold
from sklearn.model_selection import permutation_test_score
from sklearn.metrics import roc_auc_score
from numpy.random import permutation

st = study('Olfacto')
exp, meth = 'Ret', 'WITHIN'#'Enc'
conds, subjects = ['low','high'],['CHAF','VACJ','SEMC','LEFC','PIRJ','FERJ']
freqs = ['theta']
path_pow = path.join(st.path, 'feature/TPSim_'+exp+'_By_Odor_By_Cond/TPS_by_cond/6freqs/')
filename = path.join(path_pow, 'TPS_spear_{}_cond_{}_{}_6freqs_3s_dissim.npz')
save_path = path.join(st.path, 'classified/TPSim_clf_all_theta/')
#su, method(global,btw,wth),exp (E,R,ER),freq
name_classif = path.join(save_path, 
            '{}_LDA_clf_'+meth+'_'+exp[0]+'_'+conds[0]+'_'+conds[1]+'_{}_k=5.npz')
rois_to_keep = ['ACC','aHC','IFG','Ins_olf','MFG','OFC_olf','PHG','SFG','pPirT','Amg']

nperm = 1000

if not path.exists(save_path):
    makedirs(save_path)

for su,freq in product(subjects,freqs):
    #for freq in freqs:
    pow_list = []
    #=========================== Load Power files (nfreq, nelec, nwin, ntrial) =================================    
    mat0 = np.load(filename.format(su,conds[0],freq),allow_pickle=True)
    labels = mat0['label']
    x,y,z = mat0['xyz'][:,0], mat0['xyz'][:,1], mat0['xyz'][:,2]
    new_labels = rename_elecs(labels,x,y,z)
    idx_rois = np.isin(new_labels, rois_to_keep)
    
    pow_list.append(mat0['tps'][idx_rois])
    nelecs = mat0['tps'][idx_rois].shape[0]
    mat1 = np.load(filename.format(su,conds[1],freq),allow_pickle=True)
    pow_list.append(mat1['tps'][idx_rois])
    print (su,mat0.files, 'TPS shape: ', [pow.shape for pow in pow_list])

    #=========================== Create dict for all results =================================    
    if not path.exists(name_classif.format(su,freq)):
        kwargs = {}
        kwargs['names'], kwargs['channels'] = new_labels[idx_rois], mat0['channel'][idx_rois]
        kwargs['xyz'] = mat0['xyz'][idx_rois]

        # =========================== Select Power for 1 elec 1 freq =================================                 
        permut,auc = np.zeros((nelecs,nperm)),np.zeros((nelecs))
        for elec_num in range(nelecs):
            print('--» processing',su, 'elec', elec_num,'/',nelecs)
            pow_data_elec = [power[elec_num][:,np.newaxis] for power in pow_list]

            # create a data matrix, concatenate along the trial dimension
            x = np.concatenate(pow_data_elec, axis=0)
            print ('Size of the concatenated data: ', x.shape)
            y = np.hstack([np.array([i]*len(power)) for i, power in enumerate(pow_data_elec)])
            print ('Size of label for classif: ', len(y))

            clf = LDA()
            cv = SKFold(5)
            score, permutation_scores, pvalue = permutation_test_score(
            clf, x, y, scoring="roc_auc", cv=cv, n_permutations=nperm, n_jobs=-1)
            permut[elec_num] += permutation_scores
            auc[elec_num] += score
            print("Classification score %s (pvalue : %s)" % (score, pvalue))

        kwargs['perm'], kwargs['auc'] = permut, auc
        #Save plots
        np.savez(name_classif.format(su,freq), **kwargs)
        del x, y, pow_data_elec, permutation_scores, score
    else:
        print(name_classif, 'already computed')
    del pow_list
# Out:
# -> Olfacto loaded
# CHAF ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(57, 66), (57, 66)]
# --» processing CHAF elec 0 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5824598478444631 (pvalue : 0.1048951048951049)
# --» processing CHAF elec 1 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5763977780461297 (pvalue : 0.12687312687312688)
# --» processing CHAF elec 2 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.3734090085738438 (pvalue : 0.97002997002997)
# --» processing CHAF elec 3 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5972889747615022 (pvalue : 0.056943056943056944)
# --» processing CHAF elec 4 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4555911121845188 (pvalue : 0.6693306693306693)
# --» processing CHAF elec 5 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.698255041661635 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 6 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6065149136577708 (pvalue : 0.06393606393606394)
# --» processing CHAF elec 7 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6330032604757878 (pvalue : 0.01998001998001998)
# --» processing CHAF elec 8 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6247192368071489 (pvalue : 0.016983016983016984)
# --» processing CHAF elec 9 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.7888117377128365 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 10 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6900012075836253 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 11 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4530431107354184 (pvalue : 0.6843156843156843)
# --» processing CHAF elec 12 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6769049631686994 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 13 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5408948194662481 (pvalue : 0.3696303696303696)
# --» processing CHAF elec 14 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5860976935152759 (pvalue : 0.08491508491508491)
# --» processing CHAF elec 15 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5395483637241878 (pvalue : 0.4075924075924076)
# --» processing CHAF elec 16 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5721953870305517 (pvalue : 0.15384615384615385)
# --» processing CHAF elec 17 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6648351648351648 (pvalue : 0.003996003996003996)
# --» processing CHAF elec 18 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5240007245501752 (pvalue : 0.4925074925074925)
# --» processing CHAF elec 19 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6312824538099263 (pvalue : 0.016983016983016984)
# --» processing CHAF elec 20 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.3972467093346214 (pvalue : 0.8491508491508492)
# --» processing CHAF elec 21 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.627774423378819 (pvalue : 0.02097902097902098)
# --» processing CHAF elec 22 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4460874290544621 (pvalue : 0.7322677322677322)
# --» processing CHAF elec 23 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5419091897113876 (pvalue : 0.3936063936063936)
# --» processing CHAF elec 24 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.43110735418427726 (pvalue : 0.7622377622377622)
# --» processing CHAF elec 25 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5936541480497525 (pvalue : 0.07392607392607392)
# --» processing CHAF elec 26 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5834198768264702 (pvalue : 0.1018981018981019)
# --» processing CHAF elec 27 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.34627460451636277 (pvalue : 0.9820179820179821)
# --» processing CHAF elec 28 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5897113875135853 (pvalue : 0.07792207792207792)
# --» processing CHAF elec 29 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5696051201545707 (pvalue : 0.1878121878121878)
# --» processing CHAF elec 30 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.40934065934065933 (pvalue : 0.8391608391608392)
# --» processing CHAF elec 31 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6237954353338969 (pvalue : 0.02097902097902098)
# --» processing CHAF elec 32 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6635702209878034 (pvalue : 0.002997002997002997)
# --» processing CHAF elec 33 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5973372781065088 (pvalue : 0.07592407592407592)
# --» processing CHAF elec 34 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.3848387875860403 (pvalue : 0.9470529470529471)
# --» processing CHAF elec 35 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4512740007245502 (pvalue : 0.6403596403596403)
# --» processing CHAF elec 36 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5422835406351889 (pvalue : 0.38161838161838163)
# --» processing CHAF elec 37 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6514068349233184 (pvalue : 0.005994005994005994)
# --» processing CHAF elec 38 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.656013766453327 (pvalue : 0.006993006993006993)
# --» processing CHAF elec 39 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6356539065330273 (pvalue : 0.00999000999000999)
# --» processing CHAF elec 40 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.31329549571307813 (pvalue : 0.994005994005994)
# --» processing CHAF elec 41 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6843316024634707 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 42 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6279012196594614 (pvalue : 0.023976023976023976)
# --» processing CHAF elec 43 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5872962202632532 (pvalue : 0.08491508491508491)
# --» processing CHAF elec 44 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6175401521555368 (pvalue : 0.025974025974025976)
# --» processing CHAF elec 45 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.45960028982007 (pvalue : 0.5944055944055944)
# --» processing CHAF elec 46 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5998188624562251 (pvalue : 0.06593406593406594)
# --» processing CHAF elec 47 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.35557299843014134 (pvalue : 0.967032967032967)
# --» processing CHAF elec 48 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.698043714527231 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 49 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.537586040333293 (pvalue : 0.4015984015984016)
# --» processing CHAF elec 50 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.47718874532061345 (pvalue : 0.5484515484515484)
# --» processing CHAF elec 51 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.590683492331844 (pvalue : 0.08391608391608392)
# --» processing CHAF elec 52 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6921386306001691 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 53 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5862878879362394 (pvalue : 0.0999000999000999)
# --» processing CHAF elec 54 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4273215795193817 (pvalue : 0.8181818181818182)
# --» processing CHAF elec 55 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6042506943605844 (pvalue : 0.05194805194805195)
# --» processing CHAF elec 56 / 57
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5661997343316025 (pvalue : 0.18581418581418582)
# VACJ ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(37, 66), (37, 66)]
# --» processing VACJ elec 0 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5980678661997343 (pvalue : 0.055944055944055944)
# --» processing VACJ elec 1 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5675643038280402 (pvalue : 0.2047952047952048)
# --» processing VACJ elec 2 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5615867648834681 (pvalue : 0.23576423576423577)
# --» processing VACJ elec 3 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5798635430503563 (pvalue : 0.13586413586413587)
# --» processing VACJ elec 4 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.40385219176427967 (pvalue : 0.9240759240759241)
# --» processing VACJ elec 5 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.43540031397174256 (pvalue : 0.7552447552447552)
# --» processing VACJ elec 6 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5633015336312039 (pvalue : 0.21478521478521478)
# --» processing VACJ elec 7 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6161031276415891 (pvalue : 0.03296703296703297)
# --» processing VACJ elec 8 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.7422895785533148 (pvalue : 0.000999000999000999)
# --» processing VACJ elec 9 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5773759207825141 (pvalue : 0.13686313686313686)
# --» processing VACJ elec 10 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5728052167612607 (pvalue : 0.17182817182817184)
# --» processing VACJ elec 11 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6584711991305399 (pvalue : 0.003996003996003996)
# --» processing VACJ elec 12 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5867648834681802 (pvalue : 0.0999000999000999)
# --» processing VACJ elec 13 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.36937869822485203 (pvalue : 0.9280719280719281)
# --» processing VACJ elec 14 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.7051080787344524 (pvalue : 0.000999000999000999)
# --» processing VACJ elec 15 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.3877369882864388 (pvalue : 0.9340659340659341)
# --» processing VACJ elec 16 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5938232097572756 (pvalue : 0.07892107892107893)
# --» processing VACJ elec 17 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6520227025721531 (pvalue : 0.001998001998001998)
# --» processing VACJ elec 18 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6646661031276416 (pvalue : 0.002997002997002997)
# --» processing VACJ elec 19 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.7059654631083203 (pvalue : 0.001998001998001998)
# --» processing VACJ elec 20 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5693756792657891 (pvalue : 0.1958041958041958)
# --» processing VACJ elec 21 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.2961538461538461 (pvalue : 0.999000999000999)
# --» processing VACJ elec 22 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.45866441251056633 (pvalue : 0.5984015984015985)
# --» processing VACJ elec 23 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.41271585557299845 (pvalue : 0.8631368631368631)
# --» processing VACJ elec 24 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4325624924526023 (pvalue : 0.6403596403596403)
# --» processing VACJ elec 25 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5641468421688203 (pvalue : 0.2177822177822178)
# --» processing VACJ elec 26 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6744656442458641 (pvalue : 0.001998001998001998)
# --» processing VACJ elec 27 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.22636758845550053 (pvalue : 1.0)
# --» processing VACJ elec 28 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4399106388117377 (pvalue : 0.7242757242757243)
# --» processing VACJ elec 29 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5741577104214467 (pvalue : 0.16883116883116883)
# --» processing VACJ elec 30 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.57105422050477 (pvalue : 0.15984015984015984)
# --» processing VACJ elec 31 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6647506339814031 (pvalue : 0.000999000999000999)
# --» processing VACJ elec 32 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5873264098538824 (pvalue : 0.08691308691308691)
# --» processing VACJ elec 33 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5268264702330636 (pvalue : 0.4875124875124875)
# --» processing VACJ elec 34 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.453665016302379 (pvalue : 0.6483516483516484)
# --» processing VACJ elec 35 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5249969810409371 (pvalue : 0.4965034965034965)
# --» processing VACJ elec 36 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6751117014853278 (pvalue : 0.000999000999000999)
# SEMC ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(49, 105), (49, 36)]
# --» processing SEMC elec 0 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5358843537414966 (pvalue : 0.42957042957042957)
# --» processing SEMC elec 1 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5605442176870749 (pvalue : 0.29270729270729273)
# --» processing SEMC elec 2 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.4251700680272109 (pvalue : 0.7782217782217782)
# --» processing SEMC elec 3 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.46564625850340136 (pvalue : 0.6243756243756243)
# --» processing SEMC elec 4 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.7714285714285714 (pvalue : 0.000999000999000999)
# --» processing SEMC elec 5 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.3957482993197279 (pvalue : 0.8411588411588412)
# --» processing SEMC elec 6 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5255102040816326 (pvalue : 0.4745254745254745)
# --» processing SEMC elec 7 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.6073129251700681 (pvalue : 0.056943056943056944)
# --» processing SEMC elec 8 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.6812925170068027 (pvalue : 0.004995004995004995)
# --» processing SEMC elec 9 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.560374149659864 (pvalue : 0.3046953046953047)
# --» processing SEMC elec 10 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5717687074829931 (pvalue : 0.19880119880119881)
# --» processing SEMC elec 11 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.7450680272108843 (pvalue : 0.000999000999000999)
# --» processing SEMC elec 12 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.3824829931972789 (pvalue : 0.9230769230769231)
# --» processing SEMC elec 13 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5518707482993197 (pvalue : 0.35364635364635366)
# --» processing SEMC elec 14 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.6593537414965986 (pvalue : 0.006993006993006993)
# --» processing SEMC elec 15 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5784013605442176 (pvalue : 0.17482517482517482)
# --» processing SEMC elec 16 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.3792517006802721 (pvalue : 0.9440559440559441)
# --» processing SEMC elec 17 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.7676870748299319 (pvalue : 0.000999000999000999)
# --» processing SEMC elec 18 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.457482993197279 (pvalue : 0.6143856143856143)
# --» processing SEMC elec 19 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5855442176870748 (pvalue : 0.14485514485514486)
# --» processing SEMC elec 20 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5979591836734695 (pvalue : 0.09090909090909091)
# --» processing SEMC elec 21 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.3329931972789116 (pvalue : 0.985014985014985)
# --» processing SEMC elec 22 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.7562925170068027 (pvalue : 0.000999000999000999)
# --» processing SEMC elec 23 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5971088435374149 (pvalue : 0.09090909090909091)
# --» processing SEMC elec 24 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.3846938775510204 (pvalue : 0.8731268731268731)
# --» processing SEMC elec 25 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.4348639455782314 (pvalue : 0.7082917082917083)
# --» processing SEMC elec 26 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5855442176870748 (pvalue : 0.14285714285714285)
# --» processing SEMC elec 27 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.6445578231292517 (pvalue : 0.013986013986013986)
# --» processing SEMC elec 28 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5852040816326531 (pvalue : 0.13786213786213786)
# --» processing SEMC elec 29 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.37176870748299323 (pvalue : 0.9410589410589411)
# --» processing SEMC elec 30 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.6346938775510205 (pvalue : 0.023976023976023976)
# --» processing SEMC elec 31 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.43894557823129254 (pvalue : 0.6943056943056943)
# --» processing SEMC elec 32 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5197278911564626 (pvalue : 0.4885114885114885)
# --» processing SEMC elec 33 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.4804421768707483 (pvalue : 0.5564435564435565)
# --» processing SEMC elec 34 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5534013605442177 (pvalue : 0.33966033966033965)
# --» processing SEMC elec 35 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.40731292517006806 (pvalue : 0.6853146853146853)
# --» processing SEMC elec 36 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.6088435374149659 (pvalue : 0.061938061938061936)
# --» processing SEMC elec 37 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5588435374149661 (pvalue : 0.3166833166833167)
# --» processing SEMC elec 38 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5454081632653062 (pvalue : 0.3756243756243756)
# --» processing SEMC elec 39 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.4399659863945578 (pvalue : 0.7242757242757243)
# --» processing SEMC elec 40 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.35034013605442177 (pvalue : 0.978021978021978)
# --» processing SEMC elec 41 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5619047619047619 (pvalue : 0.26573426573426573)
# --» processing SEMC elec 42 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5775510204081632 (pvalue : 0.18581418581418582)
# --» processing SEMC elec 43 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.627891156462585 (pvalue : 0.025974025974025976)
# --» processing SEMC elec 44 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5957482993197278 (pvalue : 0.0919080919080919)
# --» processing SEMC elec 45 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5914965986394558 (pvalue : 0.11388611388611389)
# --» processing SEMC elec 46 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.5658163265306123 (pvalue : 0.24675324675324675)
# --» processing SEMC elec 47 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.7136054421768707 (pvalue : 0.000999000999000999)
# --» processing SEMC elec 48 / 49
# Size of the concatenated data:  (141, 1)
# Size of label for classif:  141
# Classification score 0.4012755102040816 (pvalue : 0.8561438561438561)
# LEFC ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(32, 66), (32, 66)]
# --» processing LEFC elec 0 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6039246467817897 (pvalue : 0.054945054945054944)
# --» processing LEFC elec 1 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5418306967757517 (pvalue : 0.3646353646353646)
# --» processing LEFC elec 2 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4416555971501027 (pvalue : 0.6993006993006993)
# --» processing LEFC elec 3 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.3697319164352132 (pvalue : 0.9560439560439561)
# --» processing LEFC elec 4 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.33739282695326656 (pvalue : 0.997002997002997)
# --» processing LEFC elec 5 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6205108078734451 (pvalue : 0.02197802197802198)
# --» processing LEFC elec 6 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.2772249728293684 (pvalue : 1.0)
# --» processing LEFC elec 7 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5847119913053979 (pvalue : 0.10589410589410589)
# --» processing LEFC elec 8 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6000181137543775 (pvalue : 0.057942057942057944)
# --» processing LEFC elec 9 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6985327858954232 (pvalue : 0.000999000999000999)
# --» processing LEFC elec 10 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5775389445719116 (pvalue : 0.11788211788211789)
# --» processing LEFC elec 11 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.3780461296944813 (pvalue : 0.936063936063936)
# --» processing LEFC elec 12 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.3551261924888298 (pvalue : 0.989010989010989)
# --» processing LEFC elec 13 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6033751962323392 (pvalue : 0.06293706293706294)
# --» processing LEFC elec 14 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4254800144910035 (pvalue : 0.8071928071928072)
# --» processing LEFC elec 15 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.44355150344161326 (pvalue : 0.5484515484515484)
# --» processing LEFC elec 16 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6424042989977056 (pvalue : 0.01098901098901099)
# --» processing LEFC elec 17 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.442669967395242 (pvalue : 0.6993006993006993)
# --» processing LEFC elec 18 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.39540514430624324 (pvalue : 0.8831168831168831)
# --» processing LEFC elec 19 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5637060741456346 (pvalue : 0.18581418581418582)
# --» processing LEFC elec 20 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5478746528197078 (pvalue : 0.31868131868131866)
# --» processing LEFC elec 21 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6659763313609467 (pvalue : 0.002997002997002997)
# --» processing LEFC elec 22 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6532061345248159 (pvalue : 0.004995004995004995)
# --» processing LEFC elec 23 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6491607293805096 (pvalue : 0.003996003996003996)
# --» processing LEFC elec 24 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6470776476270982 (pvalue : 0.007992007992007992)
# --» processing LEFC elec 25 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.43690375558507427 (pvalue : 0.6823176823176823)
# --» processing LEFC elec 26 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5867829972225576 (pvalue : 0.0979020979020979)
# --» processing LEFC elec 27 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6368011109769351 (pvalue : 0.01098901098901099)
# --» processing LEFC elec 28 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.7190435937688685 (pvalue : 0.000999000999000999)
# --» processing LEFC elec 29 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6236203357082478 (pvalue : 0.03396603396603397)
# --» processing LEFC elec 30 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4478021978021978 (pvalue : 0.6573426573426573)
# --» processing LEFC elec 31 / 32
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5937386789035141 (pvalue : 0.05194805194805195)
# PIRJ ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(20, 120), (20, 120)]
# --» processing PIRJ elec 0 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.45625 (pvalue : 0.7162837162837162)
# --» processing PIRJ elec 1 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.5717013888888889 (pvalue : 0.060939060939060936)
# --» processing PIRJ elec 2 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.6163194444444444 (pvalue : 0.001998001998001998)
# --» processing PIRJ elec 3 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.5434027777777778 (pvalue : 0.26173826173826176)
# --» processing PIRJ elec 4 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.3960069444444444 (pvalue : 0.975024975024975)
# --» processing PIRJ elec 5 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.40173611111111107 (pvalue : 0.972027972027972)
# --» processing PIRJ elec 6 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.5395833333333334 (pvalue : 0.30569430569430567)
# --» processing PIRJ elec 7 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.6401041666666666 (pvalue : 0.001998001998001998)
# --» processing PIRJ elec 8 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.4375000000000001 (pvalue : 0.7102897102897103)
# --» processing PIRJ elec 9 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.5932291666666668 (pvalue : 0.012987012987012988)
# --» processing PIRJ elec 10 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.35694444444444445 (pvalue : 1.0)
# --» processing PIRJ elec 11 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.5887152777777778 (pvalue : 0.01898101898101898)
# --» processing PIRJ elec 12 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.5921875 (pvalue : 0.008991008991008992)
# --» processing PIRJ elec 13 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.65625 (pvalue : 0.000999000999000999)
# --» processing PIRJ elec 14 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.5795138888888889 (pvalue : 0.029970029970029972)
# --» processing PIRJ elec 15 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.6739583333333333 (pvalue : 0.000999000999000999)
# --» processing PIRJ elec 16 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.6638888888888889 (pvalue : 0.000999000999000999)
# --» processing PIRJ elec 17 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.6107638888888889 (pvalue : 0.000999000999000999)
# --» processing PIRJ elec 18 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.5730902777777777 (pvalue : 0.07692307692307693)
# --» processing PIRJ elec 19 / 20
# Size of the concatenated data:  (240, 1)
# Size of label for classif:  240
# Classification score 0.5847222222222223 (pvalue : 0.022977022977022976)
# FERJ ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(37, 66), (37, 66)]
# --» processing FERJ elec 0 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.8052529887694723 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 1 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5637121120637604 (pvalue : 0.21078921078921078)
# --» processing FERJ elec 2 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5822304069556817 (pvalue : 0.11488511488511488)
# --» processing FERJ elec 3 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.414792899408284 (pvalue : 0.8691308691308691)
# --» processing FERJ elec 4 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5610131626615142 (pvalue : 0.24475524475524477)
# --» processing FERJ elec 5 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6275329066537857 (pvalue : 0.011988011988011988)
# --» processing FERJ elec 6 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.41456949643762825 (pvalue : 0.8431568431568431)
# --» processing FERJ elec 7 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.698043714527231 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 8 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.563295495713078 (pvalue : 0.20279720279720279)
# --» processing FERJ elec 9 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.3873445236082599 (pvalue : 0.948051948051948)
# --» processing FERJ elec 10 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.3276476270981765 (pvalue : 0.997002997002997)
# --» processing FERJ elec 11 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6215312160367106 (pvalue : 0.027972027972027972)
# --» processing FERJ elec 12 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4132773819587007 (pvalue : 0.8671328671328671)
# --» processing FERJ elec 13 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5308477237048665 (pvalue : 0.43156843156843155)
# --» processing FERJ elec 14 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5642796763675884 (pvalue : 0.1938061938061938)
# --» processing FERJ elec 15 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5739524212051685 (pvalue : 0.14485514485514486)
# --» processing FERJ elec 16 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4340840478203115 (pvalue : 0.7882117882117882)
# --» processing FERJ elec 17 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5711749788672866 (pvalue : 0.14485514485514486)
# --» processing FERJ elec 18 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.28836493177152517 (pvalue : 1.0)
# --» processing FERJ elec 19 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.7077224972829368 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 20 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5663929477116291 (pvalue : 0.2047952047952048)
# --» processing FERJ elec 21 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6374471682163989 (pvalue : 0.007992007992007992)
# --» processing FERJ elec 22 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.7579157106629634 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 23 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.438443424707161 (pvalue : 0.7032967032967034)
# --» processing FERJ elec 24 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.766036710542205 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 25 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.46293925854365414 (pvalue : 0.5844155844155844)
# --» processing FERJ elec 26 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5082628909551985 (pvalue : 0.5354645354645354)
# --» processing FERJ elec 27 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4209515758966308 (pvalue : 0.8501498501498501)
# --» processing FERJ elec 28 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5964164955923197 (pvalue : 0.059940059940059943)
# --» processing FERJ elec 29 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.4167914503079338 (pvalue : 0.8621378621378621)
# --» processing FERJ elec 30 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5776959304431832 (pvalue : 0.14585414585414586)
# --» processing FERJ elec 31 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5279797125950972 (pvalue : 0.46853146853146854)
# --» processing FERJ elec 32 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.7124199975848329 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 33 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.6450006037918126 (pvalue : 0.007992007992007992)
# --» processing FERJ elec 34 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5185605603188022 (pvalue : 0.4875124875124875)
# --» processing FERJ elec 35 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5378335949764521 (pvalue : 0.4245754245754246)
# --» processing FERJ elec 36 / 37
# Size of the concatenated data:  (132, 1)
# Size of label for classif:  132
# Classification score 0.5619611158072697 (pvalue : 0.23476523476523475)
