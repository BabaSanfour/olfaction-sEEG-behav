# %%
from os import path
import numpy as np
import matplotlib.pyplot as plt
from brainpipe.system import study
from itertools import product
from tensorpac import Pac
from brainpipe.feat.utils._feat import _manageWindow

plt.style.use('seaborn-poster')

# %% [markdown]
# ### Compute and Plot PAC values
#     Low frequency phases and large broad band gamma amplitude

# %%
st = study('Olfacto')
Test = False
if Test == True:
    subjects = ['FERJ']
    conds = {'subj':('GoodBad',['bad'])}
else:
    subjects = ['FERJ','MICP','VACJ','SEMC','LEFC','PIRJ','CHAF']
    conds = {'subj':('GoodBad',['bad', 'good']),'obj':('EpiPerf',['poor','partial','detailed'])}
# Out:
# -> Olfacto loaded

# %% [markdown]
# ### Compare different PAC methods and normalization

# %%
for su, cond in product(subjects[:], sorted(conds)):
    pathdata = path.join(st.path,'database/Encoding_'+conds[cond][0]+'_4500_expi_noart/')
    path2save = path.join(st.path,'feature/3_PAC_Encoding_'+conds[cond][0]+'_4500_expi_noart/')
    
    for c in conds[cond][1]:
        fi = su+'_odor_'+c+'_bipo_sel_phys.npz'
        loadname = pathdata+fi
        if path.isfile(loadname):
            data = np.load(loadname)
            data = data['x'][:,:2304,:].swapaxes(1,2)
            n_elec, n_trials, npts = data.shape
            sf, famp = 512., (60,120,5,2)
            fpha = (0.1,13,1,.2)
            print ('--> compute pac on : ', fi, 'data', data.shape, 'npts', npts, 'ntrials',n_trials, 'nelec', n_elec)              
            
            for elec in range(n_elec):
                data_elec = data[elec,:,:]
                print(data_elec.shape)
                p = Pac(fpha=fpha, famp=famp, filt='fir1', cycle=(3,6),dcomplex='hilbert')
                phases = p.filter(sf, data_elec, axis=1, ftype='phase')
                amplitudes = p.filter(sf, data_elec, axis=1, ftype='amplitude')
                print(phases.shape, amplitudes.shape)
                
                plt.figure(figsize=(22, 22))
                for i,k in enumerate(range(5)):
                    # Change the pac method :
                    p.idpac = (1, 1, k)
                    print('-> Normalization using ' + p.norm)
                    #print('-> PAC using ' + str(p))
                    # Compute only the PAC without filtering :
                    xpac = p.fit(phases, amplitudes, axis=2, nperm=100)
                    # Plot :
                    title = p.method + '\n' + p.surro + '\n' + p.norm
                    plt.subplot(4, 3, k+1)
                    p.comodulogram(xpac.mean(-1), title=title, cmap='Spectral_r')
                for i,j in enumerate(range(7,12,1)):
                    print(i,j)
                    plt.subplot(4,3,j)
                    p.idpac = (1, 1, i)
                    xpac_corr = p.filterfit(sf, data_elec, data_elec, axis=1)
                    title = p.method + '\n' + p.surro + '\n' + p.norm
                    p.comodulogram(xpac_corr.mean(-1), title=title, cmap='Spectral_r')
                plt.tight_layout()
                plt.show()
                0/0

# %% [markdown]
# ### Compute and plot comodulograms

# %%
for su, cond in product(subjects[:], sorted(conds)):
    pathdata = path.join(st.path,'database/Encoding_'+conds[cond][0]+'_4500_expi_noart/')
    path2save = path.join(st.path,'feature/3_PAC_Encoding_'+conds[cond][0]+'_4500_expi_noart/Comodulograms/')
    
    for c in conds[cond][1]:
        fi = su+'_odor_'+c+'_bipo_sel_phys.npz'
        loadname = pathdata+fi
        if path.isfile(loadname):
            data = np.load(loadname)
            data,labels = data['x'][:,:2304,:].swapaxes(1,2), data['labels']
            n_elec, n_trials, npts = data.shape
            sf, famp = 512., (60,120,5,2)
            fpha = (0.1,13,1,.2)
            print ('--> compute pac on : ', fi, 'data', data.shape, 'npts', npts, 'ntrials',n_trials, 'nelec', n_elec)              
            
            for elec in range(n_elec):
                data_elec = data[elec,:,:]
                print(data_elec.shape)
                p = Pac(idpac=(1, 1, 4),fpha=fpha, famp=famp, filt='fir1', cycle=(3,6),dcomplex='hilbert')
                               
                plt.figure(figsize=(12,9))
                xpac_corr = p.filterfit(sf, data_elec, data_elec, axis=1)
                title = 'PAC - '+c.capitalize()+ ' Memory - '+ labels[elec]
                p.comodulogram(xpac_corr.mean(-1), title=title, plotas='imshow', 
                               cmap='plasma', vmin=0, interp=(.1,.1), vmax=0.7)
                filename = su+'_'+c+'_PAC_'+str(elec)+'_'+labels[elec][:-4]+'.png'
                plt.tight_layout()
                plt.savefig(path2save+filename)
                plt.clf()
                plt.close()
# Out:
# --> compute pac on :  FERJ_odor_poor_bipo_sel_phys.npz data (88, 36, 2304) npts 2304 ntrials 36 nelec 88
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# (36, 2304)
# --> compute pac on :  FERJ_odor_partial_bipo_sel_phys.npz data (88, 20, 2304) npts 2304 ntrials 20 nelec 88
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# --> compute pac on :  FERJ_odor_bad_bipo_sel_phys.npz data (14, 26, 2304) npts 2304 ntrials 26 nelec 14
# (26, 2304)
# (26, 2304)
# (26, 2304)
# (26, 2304)
# (26, 2304)
# (26, 2304)
# (26, 2304)
# (26, 2304)
# (26, 2304)
# (26, 2304)
# (26, 2304)
# (26, 2304)
# (26, 2304)
# (26, 2304)
# --> compute pac on :  FERJ_odor_good_bipo_sel_phys.npz data (14, 30, 2304) npts 2304 ntrials 30 nelec 14
# (30, 2304)
# (30, 2304)
# (30, 2304)
# (30, 2304)
# (30, 2304)
# (30, 2304)
# (30, 2304)
# (30, 2304)
# (30, 2304)
# (30, 2304)
# (30, 2304)
# (30, 2304)
# (30, 2304)
# (30, 2304)
# --> compute pac on :  MICP_odor_poor_bipo_sel_phys.npz data (74, 24, 2304) npts 2304 ntrials 24 nelec 74
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# (24, 2304)
# --> compute pac on :  MICP_odor_partial_bipo_sel_phys.npz data (74, 33, 2304) npts 2304 ntrials 33 nelec 74
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# --> compute pac on :  MICP_odor_detailed_bipo_sel_phys.npz data (74, 21, 2304) npts 2304 ntrials 21 nelec 74
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# (21, 2304)
# --> compute pac on :  MICP_odor_bad_bipo_sel_phys.npz data (67, 45, 2304) npts 2304 ntrials 45 nelec 67
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# (45, 2304)
# --> compute pac on :  MICP_odor_good_bipo_sel_phys.npz data (67, 33, 2304) npts 2304 ntrials 33 nelec 67
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# --> compute pac on :  VACJ_odor_poor_bipo_sel_phys.npz data (80, 14, 2304) npts 2304 ntrials 14 nelec 80
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# --> compute pac on :  VACJ_odor_partial_bipo_sel_phys.npz data (80, 7, 2304) npts 2304 ntrials 7 nelec 80
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# --> compute pac on :  VACJ_odor_detailed_bipo_sel_phys.npz data (80, 8, 2304) npts 2304 ntrials 8 nelec 80
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# (8, 2304)
# --> compute pac on :  VACJ_odor_bad_bipo_sel_phys.npz data (73, 15, 2304) npts 2304 ntrials 15 nelec 73
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# (15, 2304)
# --> compute pac on :  VACJ_odor_good_bipo_sel_phys.npz data (73, 14, 2304) npts 2304 ntrials 14 nelec 73
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# --> compute pac on :  SEMC_odor_poor_bipo_sel_phys.npz data (66, 32, 2304) npts 2304 ntrials 32 nelec 66
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# (32, 2304)
# --> compute pac on :  SEMC_odor_partial_bipo_sel_phys.npz data (66, 9, 2304) npts 2304 ntrials 9 nelec 66
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# (9, 2304)
# --> compute pac on :  SEMC_odor_bad_bipo_sel_phys.npz data (64, 18, 2304) npts 2304 ntrials 18 nelec 64
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# (18, 2304)
# --> compute pac on :  SEMC_odor_good_bipo_sel_phys.npz data (64, 23, 2304) npts 2304 ntrials 23 nelec 64
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# --> compute pac on :  LEFC_odor_poor_bipo_sel_phys.npz data (148, 23, 2304) npts 2304 ntrials 23 nelec 148
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# --> compute pac on :  LEFC_odor_partial_bipo_sel_phys.npz data (148, 20, 2304) npts 2304 ntrials 20 nelec 148
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# (20, 2304)
# --> compute pac on :  LEFC_odor_detailed_bipo_sel_phys.npz data (148, 14, 2304) npts 2304 ntrials 14 nelec 148
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# (14, 2304)
# --> compute pac on :  LEFC_odor_bad_bipo_sel_phys.npz data (139, 23, 2304) npts 2304 ntrials 23 nelec 139
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# (23, 2304)
# --> compute pac on :  LEFC_odor_good_bipo_sel_phys.npz data (139, 35, 2304) npts 2304 ntrials 35 nelec 139
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# --> compute pac on :  PIRJ_odor_poor_bipo_sel_phys.npz data (58, 19, 2304) npts 2304 ntrials 19 nelec 58
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# (19, 2304)
# --> compute pac on :  PIRJ_odor_partial_bipo_sel_phys.npz data (58, 48, 2304) npts 2304 ntrials 48 nelec 58
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# (48, 2304)
# --> compute pac on :  PIRJ_odor_detailed_bipo_sel_phys.npz data (58, 7, 2304) npts 2304 ntrials 7 nelec 58
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# (7, 2304)
# --> compute pac on :  PIRJ_odor_bad_bipo_sel_phys.npz data (48, 35, 2304) npts 2304 ntrials 35 nelec 48
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# (35, 2304)
# --> compute pac on :  PIRJ_odor_good_bipo_sel_phys.npz data (48, 39, 2304) npts 2304 ntrials 39 nelec 48
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# (39, 2304)
# --> compute pac on :  CHAF_odor_poor_bipo_sel_phys.npz data (93, 16, 2304) npts 2304 ntrials 16 nelec 93
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# (16, 2304)
# --> compute pac on :  CHAF_odor_partial_bipo_sel_phys.npz data (93, 25, 2304) npts 2304 ntrials 25 nelec 93
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# --> compute pac on :  CHAF_odor_detailed_bipo_sel_phys.npz data (93, 25, 2304) npts 2304 ntrials 25 nelec 93
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# (25, 2304)
# --> compute pac on :  CHAF_odor_bad_bipo_sel_phys.npz data (94, 33, 2304) npts 2304 ntrials 33 nelec 94
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# --> compute pac on :  CHAF_odor_good_bipo_sel_phys.npz data (94, 33, 2304) npts 2304 ntrials 33 nelec 94
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
# (33, 2304)
