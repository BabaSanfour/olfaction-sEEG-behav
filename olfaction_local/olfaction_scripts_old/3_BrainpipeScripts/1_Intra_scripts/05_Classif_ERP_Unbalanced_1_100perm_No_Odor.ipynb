# %% [markdown]
# ## Import Libraries

# %%
from os import path
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MaxNLocator
import scipy.io as sio

from brainpipe.classification import *
from brainpipe.system import study
from brainpipe.feature import power, amplitude, sigfilt
from brainpipe.visual import *
from brainpipe.statistics import *
from scipy.stats import *

# %% [markdown]
# ## Power Decoding - Partial//Detailed Encoding
# ### For ALL time points

# %%
time = (np.arange(0,2000))/512
print(time.shape)
print(auc.shape)
print(x.shape)
print(y.shape)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import StratifiedKFold as SKFold
from sklearn.metrics import roc_auc_score
from numpy.random import permutation

conds, subjects = ['odor','no_odor'],['LEFC']#,'PIRJ','SEMC','CHAF','FERJ','VACJ','MICP']#'MICP','VACJ','CHAF','SEMC','LEFC','PIRJ'
color_codes = ['darkorange','blue']
st = study('Olfacto')
nperm = 1000
step = 'Encoding'

path_data = path.join(st.path, 'database/'+step+'_No_Odor/')
path_feat = path.join(st.path, 'feature/ERP_Odor_No_Odor/'+step+'_no_ds/')
save_path = path.join(st.path, 'classified/0_Classif_ERP_'+step+'_Odor_Inspi_100perm_no_ds/')

for su in subjects:
    feat_list = []
    #=========================== Load ERPs files =================================    
    mat = np.load(path_data+su+'_odor_'+conds[1]+'_bipo_sel_phys.npz')
    labels,channels = mat['Mai_RL'],mat['channels']
    erp0 = np.load(path.join(path_feat, su+'_'+conds[0]+'_bipo_sel_phys.npy'))[:,2:-1]
    feat_list.append(erp0)
    time = (np.arange(erp0.shape[1]))
    nelecs = erp0.shape[0]
    erp1 = np.load(path.join(path_feat, su+'_'+conds[1]+'_bipo_sel_phys.npy'))[:,2:-1]
    feat_list.append(erp1)
    print (su, 'power shape: ', [feat.shape for feat in feat_list])

    # =========================== Select ERP for 1 elec =================================                 
    iterator = range(nelecs)
    for elec_num in iterator:
        elec, elec_label = channels[elec_num], labels[elec_num]
        print ('elec ', elec, 'elec_label ', elec_label)
        #Filenames to save
        name_auc = (save_path+'/auc/'+su +'_auc_'+conds[0]+'_'+conds[1]+'_'+str(elec_label)+'_('+str(elec_num)+').npy')
        name_perm = (save_path+'/auc/'+su +'_perm_'+str(elec_label)+'_('+str(elec_num)+').npy')
        plot_name = (save_path+'/fig/'+su +'_ERP_'+conds[0]+'_'+conds[1]+'_'+str(elec)+'_'+str(elec_label)+'_('+str(elec_num)+').png')            
        
#         perm_old = np.load(name_perm)
#         print(perm_old.shape)
        
#         if perm_old.shape[0] == 200:
        if path.exists(name_auc):
            print(su,elec_num,'already computed')
        else:
            print('--» processing',su, 'elec', elec_num,'/',nelecs)
            data_elec = []
            for i,erp in enumerate(feat_list):
                data_elec.append(erp[elec_num].swapaxes(0,1))

    # =============================  Classification Computation ============================================================           
            # create a data matrix, concatenate along the trial dimension
            x = np.concatenate(data_elec, axis=0)
            print ('Size of the concatenated data: ', x.shape, 'Number time windows : ', x.shape[1])
            y = np.hstack([np.array([i]*len(erp)) for i, erp in enumerate(data_elec)])
            print ('Size of label for classif: ', len(y))

            auc = np.array([])
            for t in range(x.shape[1]):
                X = x[:,t]
                X = X.reshape(-1, 1)
                score_rep = []
                for i in range(10):
                    k = 10
                    skf = SKFold(n_splits=k, random_state=None, shuffle=True)
                    skf.get_n_splits(X, y)
                    score_cv = []
                    for train_index, test_index in skf.split(X, y):
                        clf = LDA()
                        X_train, X_test = X[train_index], X[test_index]
                        y_train, y_test = y[train_index], y[test_index]
                        clf.fit(X=X_train, y=y_train)
                        y_pred = clf.predict(X_test)
                        score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                    score_rep.append(np.mean(score_cv))
                score_rep = np.asarray(score_rep).reshape(1,len(score_rep))
                auc = np.vstack((auc, score_rep)) if np.size(auc) else score_rep
            auc = np.swapaxes(auc,0,1)

            perm_scores = np.array([])
            for t in range(x.shape[1]):
                X = x[:,t]
                X = X.reshape(-1, 1)
                perm_rep = []
                for perm in range(nperm):
                    y_perm = y[permutation(len(y))]
                    score_cv = []
                    for train_index, test_index in skf.split(X, y_perm):
                        clf = LDA()
                        X_train, X_test = X[train_index], X[test_index]
                        y_train, y_test = y_perm[train_index], y_perm[test_index]
                        clf.fit(X=X_train, y=y_train)
                        y_pred = clf.predict(X_test)
                        score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                    perm_rep.append(np.mean(score_cv))
                perm_rep = np.asarray(perm_rep).reshape(1,len(perm_rep))
                perm_scores = np.vstack((perm_scores, perm_rep)) if np.size(perm_scores) else perm_rep
            perm_scores = np.swapaxes(perm_scores,0,1)           
            th_0_01_perm = perm_pvalue2level(perm_scores, p=0.01, maxst=True)
            th_0_001_perm = perm_pvalue2level(perm_scores, p=0.001, maxst=True)
            print('th_perm 01: ', th_0_01_perm[0], '001',th_0_001_perm[0], 'auc_max', np.max(auc))

    # ============================== PLOT POWER ANALYSIS + STATS & DECODING ACCURACY ===================================================
            # plot and figure parameters
            xfmt = ScalarFormatter(useMathText=True)
            xfmt.set_powerlimits((0,3))
            fig = plt.figure(1,figsize=(7,7))
            title = 'ERP-Stats-DA for '+su+' '+conds[0]+' vs '+conds[1]+' '+str(elec)+' '+str(elec_label)+' ('+str(elec_num)+')'
            fig.suptitle(title, fontsize=12)

            # Plot the POW + STATS
            plt.subplot(211)        
            BorderPlot(time, x, y=y, kind='sem', alpha=0.2, color=color_codes,linewidth=2, 
                       ncol=1, xlabel='Time (s)',ylabel = r'Power', legend=['No Odor','Odor'])
            rmaxis(plt.gca(), ['right', 'top'])
            addLines(plt.gca(), vLines=[0], vColor=['darkgray'], vWidth=[2])
            plt.legend(loc=0, handletextpad=0.1, frameon=False)
            plt.gca().yaxis.set_major_locator(MaxNLocator(3,integer=True))

            # Plot DA for the POW
            plt.subplot(212)
            BorderPlot(time, auc, color='b', kind='sd',xlabel='Time (s)', ylim=[0.4,1.], ylabel='Decoding accuracy (%)',linewidth=2, alpha=0.3)
            rmaxis(plt.gca(), ['right', 'top'])
            addLines(plt.gca(), vLines=[0], vColor=['darkgray'], vWidth=[2])
            plt.gca().yaxis.set_major_locator(MaxNLocator(3,integer=True))
            plt.plot(time, th_0_01_perm*np.ones(len(time)), '--', color='r', linewidth=2)
            #plt.plot(times_plot, th_0_01_perm*np.ones(len(times_plot)), '--', color='orange', linewidth=2)

            #Save plots
            np.save(name_auc, auc)
            np.save(name_perm, perm_scores)
            plt.savefig(plot_name, dpi=300, bbox_inches='tight')
            plt.clf()
            plt.close() 
            del X, auc, 
    del feat_list
# Out:
# -> Olfacto loaded
# LEFC power shape:  [(148, 1149, 55), (148, 1149, 252)]
# elec  a2-a1 elec_label  Amg-PirT
# LEFC 0 already computed
# elec  a6-a5 elec_label  Ins
# LEFC 1 already computed
# elec  a7-a6 elec_label  Ins
# LEFC 2 already computed
# elec  a8-a7 elec_label  STG
# LEFC 3 already computed
# elec  a9-a8 elec_label  MTG
# LEFC 4 already computed
# elec  a10-a9 elec_label  MTG
# LEFC 5 already computed
# elec  a11-a10 elec_label  MTG
# LEFC 6 already computed
# elec  b2-b1 elec_label  HC
# LEFC 7 already computed
# elec  b3-b2 elec_label  HC
# LEFC 8 already computed
# elec  b4-b3 elec_label  HC
# LEFC 9 already computed
# elec  b9-b8 elec_label  MTG
# LEFC 10 already computed
# elec  b10-b9 elec_label  MTG
# LEFC 11 already computed
# elec  b11-b10 elec_label  MTG
# LEFC 12 already computed
# elec  d2-d1 elec_label  HC
# LEFC 13 already computed
# elec  d3-d2 elec_label  HC
# LEFC 14 already computed
# elec  d4-d3 elec_label  HC
# LEFC 15 already computed
# elec  d5-d4 elec_label  HC
# LEFC 16 already computed
# elec  d6-d5 elec_label  HC
# LEFC 17 already computed
# elec  d7-d6 elec_label  FuG
# LEFC 18 already computed
# elec  d8-d7 elec_label  FuG
# LEFC 19 already computed
# elec  d9-d8 elec_label  ITG
# LEFC 20 already computed
# elec  d10-d9 elec_label  ITG
# LEFC 21 already computed
# elec  d11-d10 elec_label  ITG
# LEFC 22 already computed
# elec  g2-g1 elec_label  RSC
# LEFC 23 already computed
# elec  g3-g2 elec_label  RSC
# LEFC 24 already computed
# elec  g4-g3 elec_label  RSC
# LEFC 25 already computed
# elec  g5-g4 elec_label  RSC
# LEFC 26 already computed
# elec  g6-g5 elec_label  RSC
# LEFC 27 already computed
# elec  g7-g6 elec_label  SMG
# LEFC 28 already computed
# elec  g8-g7 elec_label  SMG
# LEFC 29 already computed
# elec  g9-g8 elec_label  SMG
# LEFC 30 already computed
# elec  g10-g9 elec_label  SMG
# LEFC 31 already computed
# elec  g11-g10 elec_label  STG
# LEFC 32 already computed
# elec  g12-g11 elec_label  STG
# LEFC 33 already computed
# elec  g13-g12 elec_label  STG
# LEFC 34 already computed
# elec  g14-g13 elec_label  STG
# LEFC 35 already computed
# elec  k2-k1 elec_label  ACC
# LEFC 36 already computed
# elec  k3-k2 elec_label  ACC
# LEFC 37 already computed
# elec  k4-k3 elec_label  ACC
# LEFC 38 already computed
# elec  k8-k7 elec_label  MFG
# LEFC 39 already computed
# elec  k9-k8 elec_label  MFG
# LEFC 40 already computed
# elec  k10-k9 elec_label  MFG
# LEFC 41 already computed
# elec  k11-k10 elec_label  MFG
# LEFC 42 already computed
# elec  k12-k11 elec_label  MFG
# LEFC 43 already computed
# elec  l2-l1 elec_label  FuG
# LEFC 44 already computed
# elec  l3-l2 elec_label  FuG
# LEFC 45 already computed
# elec  l4-l3 elec_label  FuG
# LEFC 46 already computed
# elec  l5-l4 elec_label  ITG
# LEFC 47 already computed
# elec  l6-l5 elec_label  ITG
# LEFC 48 already computed
# elec  l7-l6 elec_label  ITG
# LEFC 49 already computed
# elec  l8-l7 elec_label  ITG
# LEFC 50 already computed
# elec  l9-l8 elec_label  ITG
# LEFC 51 already computed
# elec  l10-l9 elec_label  ITG
# LEFC 52 already computed
# elec  l11-l10 elec_label  ITG
# LEFC 53 already computed
# elec  m2-m1 elec_label  MCC
# LEFC 54 already computed
# elec  m3-m2 elec_label  MCC
# LEFC 55 already computed
# elec  m10-m9 elec_label  SMG
# LEFC 56 already computed
# elec  m11-m10 elec_label  SMG
# LEFC 57 already computed
# elec  m12-m11 elec_label  SMG
# LEFC 58 already computed
# elec  m13-m12 elec_label  SMG
# LEFC 59 already computed
# elec  m14-m13 elec_label  SMG
# LEFC 60 already computed
# elec  o2-o1 elec_label  OFC
# LEFC 61 already computed
# elec  o3-o2 elec_label  OFC
# LEFC 62 already computed
# elec  o4-o3 elec_label  OFC
# LEFC 63 already computed
# elec  o5-o4 elec_label  OFC
# LEFC 64 already computed
# elec  o6-o5 elec_label  OFC
# LEFC 65 already computed
# elec  o7-o6 elec_label  OFC
# LEFC 66 already computed
# elec  o8-o7 elec_label  OFC
# LEFC 67 already computed
# elec  o9-o8 elec_label  IFG
# LEFC 68 already computed
# elec  o10-o9 elec_label  IFG
# LEFC 69 already computed
# elec  o11-o10 elec_label  IFG
# LEFC 70 already computed
# elec  q2-q1 elec_label  PoG
# LEFC 71 already computed
# elec  q3-q2 elec_label  PoG
# LEFC 72 already computed
# elec  q4-q3 elec_label  PoG
# LEFC 73 already computed
# elec  q5-q4 elec_label  PoG
# LEFC 74 already computed
# elec  q6-q5 elec_label  PoG
# LEFC 75 already computed
# elec  q7-q6 elec_label  PoG
# LEFC 76 already computed
# elec  q8-q7 elec_label  PoG
# LEFC 77 already computed
# elec  q9-q8 elec_label  PoG
# LEFC 78 already computed
# elec  q10-q9 elec_label  SMG
# LEFC 79 already computed
# elec  q11-q10 elec_label  SMG
# LEFC 80 already computed
# elec  r2-r1 elec_label  MCC
# LEFC 81 already computed
# elec  r8-r7 elec_label  PoG
# LEFC 82 already computed
# elec  r9-r8 elec_label  PoG
# LEFC 83 already computed
# elec  r10-r9 elec_label  PoG
# LEFC 84 already computed
# elec  r11-r10 elec_label  SMG
# LEFC 85 already computed
# elec  r12-r11 elec_label  SMG
# LEFC 86 already computed
# elec  r13-r12 elec_label  SMG
# LEFC 87 already computed
# elec  r14-r13 elec_label  SMG
# LEFC 88 already computed
# elec  s2-s1 elec_label  SFG
# --» processing LEFC elec 89 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.5 001 0.53 auc_max 0.51
# not legend
# elec  s3-s2 elec_label  SFG
# --» processing LEFC elec 90 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.508333333333 001 0.53 auc_max 0.5
# not legend
# elec  s4-s3 elec_label  SFG
# --» processing LEFC elec 91 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.508333333333 001 0.544666666667 auc_max 0.5
# not legend
# elec  s5-s4 elec_label  SFG
# --» processing LEFC elec 92 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.508333333333 001 0.545 auc_max 0.5
# not legend
# elec  s6-s5 elec_label  SFG
# --» processing LEFC elec 93 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.51 001 0.536666666667 auc_max 0.51
# not legend
# elec  s7-s6 elec_label  SFG
# --» processing LEFC elec 94 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.51 001 0.536333333333 auc_max 0.5
# not legend
# elec  s8-s7 elec_label  PrG
# --» processing LEFC elec 95 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.508333333333 001 0.564666666667 auc_max 0.5
# not legend
# elec  s9-s8 elec_label  PrG
# --» processing LEFC elec 96 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.51 001 0.546 auc_max 0.51
# not legend
# elec  s10-s9 elec_label  PrG
# --» processing LEFC elec 97 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.5 001 0.550743589744 auc_max 0.5
# not legend
# elec  s11-s10 elec_label  PrG
# --» processing LEFC elec 98 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.5 001 0.531 auc_max 0.5
# not legend
# elec  t2-t1 elec_label  Ins
# --» processing LEFC elec 99 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.5 001 0.53 auc_max 0.51
# not legend
# elec  t3-t2 elec_label  TTG
# --» processing LEFC elec 100 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.5 001 0.541 auc_max 0.5
# not legend
# elec  t4-t3 elec_label  TTG
# --» processing LEFC elec 101 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.51 001 0.545 auc_max 0.51
# not legend
# elec  t5-t4 elec_label  TTG
# --» processing LEFC elec 102 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.508333333333 001 0.532666666667 auc_max 0.51
# not legend
# elec  t6-t5 elec_label  STG
# --» processing LEFC elec 103 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
# th_perm 01:  0.508333333333 001 0.533333333333 auc_max 0.5
# not legend
# elec  t7-t6 elec_label  STG
# --» processing LEFC elec 104 / 148
# Size of the concatenated data:  (307, 1149) Number time windows :  1149
# Size of label for classif:  307
