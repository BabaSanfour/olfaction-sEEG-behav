# %% [markdown]
# ## Import Libraries

# %%
from os import path
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MaxNLocator
import scipy.io as sio

from brainpipe.classification import *
from brainpipe.system import study
from brainpipe.feature import power, amplitude, sigfilt
from brainpipe.visual import *
from brainpipe.statistics import *
from scipy.stats import *

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import StratifiedKFold as SKFold
from sklearn.metrics import roc_auc_score
from numpy.random import permutation

conds,phases, subjects = ['low','high'],['odor'],['FERJ','LEFC']#,'MICP','VACJ','SEMC','LEFC','PIRJ']
color_codes = ['darkorange','blue']
#bsls = ['bsl1','bsl2']
bsl = ''
st = study('Olfacto')
freqs = 5
nperm = 1000

for su,phase in product(subjects,phases):
    path_pow = path.join(st.path, 'feature/0_Power_Encoding_EpiPerf_LowHigh/')
    save_path = path.join(st.path, 'classified/LDA_Power_E_EpiPerf_LowHigh'+bsl+'/')

    pow_list = []
    #=========================== Load Power files (nfreq, nelec, nwin, ntrial) =================================    
    mat0 = np.load(path.join(path_pow, su+'_'+phase+'_'+conds[0]+'_bipo_sel_physFT_pow'+bsl+'.npz'),
                  allow_pickle=True)
    names, channels, freq_names, time = mat0['Mai_RL'], mat0['channels'],mat0['fname'], mat0['time']
    time = time[20:47]-3
    #print(mat0['xpow'].shape,time.shape,time[17:42])
    pow_list.append(mat0['xpow'][:,:,20:47,:]) #17:52
    nelecs = mat0['xpow'].shape[1]
    mat1 = np.load(path.join(path_pow, su+'_'+phase+'_'+conds[1]+'_bipo_sel_physFT_pow'+bsl+'.npz'),
                   allow_pickle=True)
    pow_list.append(mat1['xpow'][:,:,20:47,:]) #17:52
    print (su, 'power shape: ', [pow.shape for pow in pow_list])
    # =========================== Select Power for 1 elec 1 freq =================================                 
    iterator = range(nelecs)
    for elec_num in iterator:#iterator
        for freq in range(4,freqs):#range(2,freqs):
            elec, elec_label, freq_name = channels[elec_num], names[elec_num], freq_names[freq]
            print ('elec ', elec, 'elec_label ', elec_label)
            #Filenames to save
            name_auc = (save_path+str(freq)+'_'+freq_name+'/auc/'+su +'_auc_'+conds[0]+'_'+conds[1]+'_'+str(elec_label)+'_('+str(elec_num)+').npy')
            name_perm = (save_path+str(freq)+'_'+freq_name+'/auc/'+su +'_perm_'+str(elec_label)+'_('+str(elec_num)+').npy')
            plot_name = (save_path+str(freq)+'_'+freq_name+'/fig/'+su +'_Power_'+conds[0]+'_'+conds[1]+'_'+str(elec)+'_'+str(elec_label)+'_('+str(elec_num)+').png')            
            
            if path.exists(name_auc):
                print(su,bsl,phase,elec_num,freq,'already computed')
            else:
                print('--» processing',su, 'elec', elec_num,'/',nelecs, 'freq',freq)
                pow_data_elec = []
                for i,power in enumerate(pow_list):
                    pow_data_elec.append(power[freq,elec_num].swapaxes(0,1))
                nwin = power.shape[1]

        # =============================  Classification Computation ============================================================           
                # create a data matrix, concatenate along the trial dimension
                x = np.concatenate(pow_data_elec, axis=0)
                print ('Size of the concatenated data: ', x.shape, 'Number time windows : ', x.shape[1])
                y = np.hstack([np.array([i]*len(power)) for i, power in enumerate(pow_data_elec)])
                print ('Size of label for classif: ', len(y))

                auc = np.array([])
                for t in range(x.shape[1]):
                    X = x[:,t]
                    X = X.reshape(-1, 1)
                    score_rep = []
                    for i in range(10):
                        k = 5
                        skf = SKFold(n_splits=k, random_state=None, shuffle=True)
                        skf.get_n_splits(X, y)
                        score_cv = []
                        for train_index, test_index in skf.split(X, y):
                            clf = LDA()
                            X_train, X_test = X[train_index], X[test_index]
                            y_train, y_test = y[train_index], y[test_index]
                            clf.fit(X=X_train, y=y_train)
                            y_pred = clf.predict(X_test)
                            score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                        score_rep.append(np.mean(score_cv))
                    score_rep = np.asarray(score_rep).reshape(1,len(score_rep))
                    auc = np.vstack((auc, score_rep)) if np.size(auc) else score_rep
                auc = np.swapaxes(auc,0,1)

                perm_scores = np.array([])
                for t in range(x.shape[1]):
                    X = x[:,t]
                    X = X.reshape(-1, 1)
                    perm_rep = []
                    for perm in range(nperm):
                        y_perm = y[permutation(len(y))]
                        score_cv = []
                        for train_index, test_index in skf.split(X, y_perm):
                            clf = LDA()
                            X_train, X_test = X[train_index], X[test_index]
                            y_train, y_test = y_perm[train_index], y_perm[test_index]
                            clf.fit(X=X_train, y=y_train)
                            y_pred = clf.predict(X_test)
                            score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                        perm_rep.append(np.mean(score_cv))
                    perm_rep = np.asarray(perm_rep).reshape(1,len(perm_rep))
                    perm_scores = np.vstack((perm_scores, perm_rep)) if np.size(perm_scores) else perm_rep
                perm_scores = np.swapaxes(perm_scores,0,1)           
                th_0_05_perm = perm_pvalue2level(perm_scores, p=0.005, maxst=True)
                th_0_01_perm = perm_pvalue2level(perm_scores, p=0.001, maxst=True)
                print('th_perm 005: ', th_0_05_perm[0], '001',th_0_01_perm[0], 'auc_max', np.max(auc))

        # ============================== PLOT POWER ANALYSIS + STATS & DECODING ACCURACY ===================================================
                #plot and figure parameters
                xfmt = ScalarFormatter(useMathText=True)
                xfmt.set_powerlimits((0,3))
                fig = plt.figure(1,figsize=(7,7))
                title = 'Power-Stats-DA for '+su+' '+conds[0]+' vs '+conds[1]+' '+str(elec)+' '+str(elec_label)+' ('+str(elec_num)+')'
                fig.suptitle(title, fontsize=12)

                # Plot the POW + STATS
                plt.subplot(211)        
                BorderPlot(time, x, y=y, kind='sem', alpha=0.2, color=color_codes,linewidth=2, 
                          ncol=1, xlabel='Time (s)',ylabel = r'Power', legend=conds)
                rmaxis(plt.gca(), ['right', 'top'])
                addLines(plt.gca(), vLines=[0], vColor=['darkgray'], vWidth=[2])
                plt.legend(loc=0, handletextpad=0.1, frameon=False)
                plt.gca().yaxis.set_major_locator(MaxNLocator(3,integer=True))

                # Plot DA for the POW
                plt.subplot(212)
                BorderPlot(time, auc, color='b', kind='sd',xlabel='Time (s)', ylim=[0.4,1.], ylabel='Decoding accuracy (%)',linewidth=2, alpha=0.3)
                rmaxis(plt.gca(), ['right', 'top'])
                addLines(plt.gca(), vLines=[0], vColor=['darkgray'], vWidth=[2])
                plt.gca().yaxis.set_major_locator(MaxNLocator(3,integer=True))
                plt.plot(time, th_0_05_perm*np.ones(len(time)), '--', color='r', linewidth=2)
                plt.plot(time, th_0_01_perm*np.ones(len(time)), '--', color='orange', linewidth=2)

                #Save plots
                np.save(name_auc, auc)
                np.save(name_perm, perm_scores)
                plt.savefig(plot_name, dpi=300, bbox_inches='tight')
                plt.clf()
                plt.close() 
                del X, auc, pow_data_elec
    del pow_list
# Out:
# -> Olfacto loaded
# FERJ power shape:  [(5, 85, 27, 17), (5, 85, 27, 14)]
# elec  a2-a1 elec_label  Amg
# --» processing FERJ elec 0 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.85 auc_max 0.8666666666666668
# elec  a3-a2 elec_label  Amg
# --» processing FERJ elec 1 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8666666666666666 auc_max 0.9666666666666666
# elec  a8-a7 elec_label  MTG
# --» processing FERJ elec 2 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8666666666666666 auc_max 0.8916666666666668
# elec  a9-a8 elec_label  MTG
# --» processing FERJ elec 3 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.875 auc_max 0.7499999999999999
# elec  a10-a9 elec_label  MTG
# --» processing FERJ elec 4 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7749999999999999 001 0.8416666666666666 auc_max 0.9083333333333332
# elec  b2-b1 elec_label  HC
# --» processing FERJ elec 5 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7583333333333335 001 0.8416666666666666 auc_max 0.9083333333333332
# elec  b3-b2 elec_label  HC
# --» processing FERJ elec 6 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333334 001 0.8833333333333332 auc_max 0.8166666666666667
# elec  b4-b3 elec_label  HC
# --» processing FERJ elec 7 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7749999999999999 001 0.85 auc_max 0.9333333333333332
# elec  b5-b4 elec_label  HC
# --» processing FERJ elec 8 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7750000000000001 001 0.8833333333333332 auc_max 0.875
# elec  b6-b5 elec_label  HC
# --» processing FERJ elec 9 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8666666666666668 auc_max 0.75
# elec  b7-b6 elec_label  MTG
# --» processing FERJ elec 10 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333333 001 0.8333333333333333 auc_max 0.95
# elec  b8-b7 elec_label  MTG
# --» processing FERJ elec 11 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7750000000000001 001 0.8666666666666666 auc_max 0.875
# elec  b9-b8 elec_label  MTG
# --» processing FERJ elec 12 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333334 001 0.85 auc_max 0.725
# elec  b10-b9 elec_label  MTG
# --» processing FERJ elec 13 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8666666666666668 auc_max 0.8833333333333334
# elec  b'2-b'1 elec_label  HC
# --» processing FERJ elec 14 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8416666666666668 auc_max 0.7166666666666667
# elec  b'3-b'2 elec_label  HC
# --» processing FERJ elec 15 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666668 001 0.85 auc_max 0.85
# elec  b'4-b'3 elec_label  HC
# --» processing FERJ elec 16 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7916666666666666 001 0.875 auc_max 0.9
# elec  b'5-b'4 elec_label  HC
# --» processing FERJ elec 17 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666666 001 0.8666666666666668 auc_max 0.7833333333333333
# elec  b'6-b'5 elec_label  HC
# --» processing FERJ elec 18 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333333 001 0.875 auc_max 0.7416666666666667
# elec  b'11-b'10 elec_label  MTG
# --» processing FERJ elec 19 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7750000000000001 001 0.8833333333333332 auc_max 0.8333333333333334
# elec  d2-d1 elec_label  PHG
# --» processing FERJ elec 20 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.85 auc_max 0.7666666666666666
# elec  d3-d2 elec_label  PHG
# --» processing FERJ elec 21 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333333 001 0.9083333333333334 auc_max 0.8166666666666667
# elec  d4-d3 elec_label  PHG
# --» processing FERJ elec 22 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8666666666666668 auc_max 0.7833333333333334
# elec  d5-d4 elec_label  FuG
# --» processing FERJ elec 23 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.8083333333333332 001 0.8666666666666668 auc_max 0.85
# elec  d6-d5 elec_label  FuG
# --» processing FERJ elec 24 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7749999999999999 001 0.8583333333333332 auc_max 0.8666666666666666
# elec  d7-d6 elec_label  FuG
# --» processing FERJ elec 25 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333334 001 0.8416666666666668 auc_max 0.9333333333333332
# elec  d8-d7 elec_label  ITG
# --» processing FERJ elec 26 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333334 001 0.875 auc_max 0.9166666666666666
# elec  d9-d8 elec_label  ITG
# --» processing FERJ elec 27 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.875 auc_max 0.8666666666666666
# elec  d10-d9 elec_label  ITG
# --» processing FERJ elec 28 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333333 001 0.8666666666666666 auc_max 0.7499999999999999
# elec  d11-d10 elec_label  ITG
# --» processing FERJ elec 29 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8666666666666666 auc_max 0.7666666666666667
# elec  d'2-d'1 elec_label  PHG
# --» processing FERJ elec 30 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7583333333333333 001 0.8166666666666668 auc_max 0.7416666666666668
# elec  d'3-d'2 elec_label  PHG
# --» processing FERJ elec 31 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.75 001 0.8333333333333333 auc_max 0.8333333333333333
# elec  d'4-d'3 elec_label  PHG
# --» processing FERJ elec 32 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666667 001 0.8416666666666668 auc_max 0.7833333333333333
# elec  d'5-d'4 elec_label  PHG
# --» processing FERJ elec 33 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.9 auc_max 0.8333333333333333
# elec  d'6-d'5 elec_label  FuG
# --» processing FERJ elec 34 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7750000000000001 001 0.875 auc_max 0.875
# elec  d'7-d'6 elec_label  FuG
# --» processing FERJ elec 35 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666667 001 0.8916666666666666 auc_max 0.675
# elec  d'8-d'7 elec_label  FuG
# --» processing FERJ elec 36 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333334 001 0.85 auc_max 0.8416666666666668
# elec  d'9-d'8 elec_label  FuG
# --» processing FERJ elec 37 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333334 001 0.9 auc_max 0.85
# elec  d'10-d'9 elec_label  ITG
# --» processing FERJ elec 38 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8416666666666668 auc_max 0.8083333333333332
# elec  d'11-d'10 elec_label  ITG
# --» processing FERJ elec 39 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7750000000000001 001 0.9333333333333333 auc_max 0.8583333333333332
# elec  e2-e1 elec_label  HC
# --» processing FERJ elec 40 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666667 001 0.8333333333333334 auc_max 0.7416666666666667
# elec  e3-e2 elec_label  HC
# --» processing FERJ elec 41 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333334 001 0.8333333333333334 auc_max 0.6916666666666667
# elec  e7-e6 elec_label  MTG
# --» processing FERJ elec 42 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666667 001 0.9083333333333332 auc_max 0.8083333333333332
# elec  e8-e7 elec_label  MTG
# --» processing FERJ elec 43 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666666 001 0.8416666666666668 auc_max 0.725
# elec  e9-e8 elec_label  MTG
# --» processing FERJ elec 44 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666666 001 0.8416666666666666 auc_max 0.8833333333333334
# elec  e10-e9 elec_label  MTG
# --» processing FERJ elec 45 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666667 001 0.85 auc_max 0.8916666666666666
# elec  e11-e10 elec_label  MTG
# --» processing FERJ elec 46 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.85 auc_max 0.7666666666666667
# elec  h2-h1 elec_label  Ins
# --» processing FERJ elec 47 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333334 001 0.85 auc_max 0.9166666666666667
# elec  h3-h2 elec_label  Ins
# --» processing FERJ elec 48 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7916666666666666 001 0.85 auc_max 0.8833333333333334
# elec  h4-h3 elec_label  Ins
# --» processing FERJ elec 49 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7583333333333334 001 0.8333333333333334 auc_max 0.8666666666666666
# elec  h8-h7 elec_label  STG
# --» processing FERJ elec 50 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666666 001 0.9083333333333332 auc_max 0.9
# elec  j2-j1 elec_label  pPirT
# --» processing FERJ elec 51 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7750000000000001 001 0.875 auc_max 0.8833333333333334
# elec  j3-j2 elec_label  ITG
# --» processing FERJ elec 52 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.85 auc_max 0.6416666666666667
# elec  j4-j3 elec_label  MTG
# --» processing FERJ elec 53 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.9333333333333333 auc_max 0.8
# elec  j5-j4 elec_label  MTG
# --» processing FERJ elec 54 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666666 001 0.8416666666666668 auc_max 0.8833333333333332
# elec  j6-j5 elec_label  MTG
# --» processing FERJ elec 55 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666668 001 0.9166666666666666 auc_max 0.7083333333333333
# elec  j'2-j'1 elec_label  pPirT
# --» processing FERJ elec 56 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7916666666666666 001 0.875 auc_max 0.8333333333333333
# elec  j'3-j'2 elec_label  pPirT
# --» processing FERJ elec 57 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7916666666666666 001 0.9 auc_max 0.8166666666666667
# elec  j'4-j'3 elec_label  pPirT
# --» processing FERJ elec 58 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7750000000000001 001 0.85 auc_max 0.7666666666666667
# elec  l2-l1 elec_label  PHG
# --» processing FERJ elec 59 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.85 auc_max 0.6833333333333333
# elec  l3-l2 elec_label  PHG
# --» processing FERJ elec 60 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.9333333333333332 auc_max 0.6833333333333333
# elec  l4-l3 elec_label  PHG
# --» processing FERJ elec 61 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7749999999999999 001 0.8416666666666668 auc_max 0.8
# elec  l5-l4 elec_label  PHG
# --» processing FERJ elec 62 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333332 001 0.8916666666666668 auc_max 0.8166666666666668
# elec  l6-l5 elec_label  PHG
# --» processing FERJ elec 63 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666666 001 0.875 auc_max 0.8416666666666666
# elec  l7-l6 elec_label  FuG
# --» processing FERJ elec 64 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.8 001 0.8833333333333334 auc_max 0.85
# elec  l8-l7 elec_label  ITG
# --» processing FERJ elec 65 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7749999999999999 001 0.875 auc_max 0.85
# elec  l9-l8 elec_label  MTG
# --» processing FERJ elec 66 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7749999999999999 001 0.875 auc_max 0.8666666666666666
# elec  l10-l9 elec_label  MTG
# --» processing FERJ elec 67 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7583333333333334 001 0.8416666666666666 auc_max 0.7833333333333334
# elec  l11-l10 elec_label  MTG
# --» processing FERJ elec 68 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8416666666666668 auc_max 0.825
# elec  o2-o1 elec_label  OFC
# --» processing FERJ elec 69 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.875 auc_max 0.8666666666666666
# elec  o3-o2 elec_label  OFC
# --» processing FERJ elec 70 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.875 auc_max 0.875
# elec  o4-o3 elec_label  OFC
# --» processing FERJ elec 71 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333334 001 0.9 auc_max 0.875
# elec  o5-o4 elec_label  OFC
# --» processing FERJ elec 72 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8499999999999999 auc_max 0.9333333333333332
# elec  o6-o5 elec_label  OFC
# --» processing FERJ elec 73 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333333 001 0.9 auc_max 0.8416666666666666
# elec  o7-o6 elec_label  OFC
# --» processing FERJ elec 74 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.875 auc_max 0.85
# elec  o8-o7 elec_label  IFG
# --» processing FERJ elec 75 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333333 001 0.8666666666666666 auc_max 0.875
# elec  o9-o8 elec_label  IFG
# --» processing FERJ elec 76 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7583333333333334 001 0.8333333333333334 auc_max 0.9
# elec  o10-o9 elec_label  IFG
# --» processing FERJ elec 77 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7583333333333332 001 0.8416666666666668 auc_max 0.9
# elec  o11-o10 elec_label  IFG
# --» processing FERJ elec 78 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666666 001 0.8416666666666666 auc_max 0.8333333333333334
# elec  t2-t1 elec_label  Ins
# --» processing FERJ elec 79 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7666666666666667 001 0.8833333333333332 auc_max 0.725
# elec  t3-t2 elec_label  Ins
# --» processing FERJ elec 80 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7833333333333334 001 0.8333333333333334 auc_max 0.8083333333333332
# elec  t4-t3 elec_label  Ins
# --» processing FERJ elec 81 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8666666666666666 auc_max 0.9333333333333333
# elec  t5-t4 elec_label  STG
# --» processing FERJ elec 82 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.85 auc_max 0.9083333333333334
# elec  t6-t5 elec_label  STG
# --» processing FERJ elec 83 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.775 001 0.8416666666666666 auc_max 1.0
# elec  t7-t6 elec_label  STG
# --» processing FERJ elec 84 / 85 freq 4
# Size of the concatenated data:  (31, 27) Number time windows :  27
# Size of label for classif:  31
# th_perm 005:  0.7583333333333334 001 0.85 auc_max 1.0
# LEFC power shape:  [(5, 60, 27, 34), (5, 60, 27, 21)]
# elec  a2-a1 elec_label  Amg-PirT
# --» processing LEFC elec 0 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6771428571428572 001 0.7447619047619047 auc_max 0.7611904761904762
# elec  a6-a5 elec_label  Ins
# --» processing LEFC elec 1 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6961904761904762 001 0.7604761904761904 auc_max 0.6269047619047619
# elec  a7-a6 elec_label  Ins
# --» processing LEFC elec 2 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6897619047619049 001 0.7621428571428572 auc_max 0.7278571428571429
# elec  a8-a7 elec_label  STG
# --» processing LEFC elec 3 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6826190476190475 001 0.7447619047619047 auc_max 0.7421428571428572
# elec  a9-a8 elec_label  MTG
# --» processing LEFC elec 4 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6864285714285714 001 0.7864285714285714 auc_max 0.6414285714285715
# elec  a10-a9 elec_label  MTG
# --» processing LEFC elec 5 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6954761904761905 001 0.7754761904761904 auc_max 0.6297619047619047
# elec  a11-a10 elec_label  MTG
# --» processing LEFC elec 6 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6780952380952382 001 0.7554761904761905 auc_max 0.6714285714285715
# elec  b2-b1 elec_label  HC
# --» processing LEFC elec 7 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6804761904761906 001 0.7597619047619049 auc_max 0.7411904761904763
# elec  b3-b2 elec_label  HC
# --» processing LEFC elec 8 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6969047619047619 001 0.7835714285714286 auc_max 0.5964285714285715
# elec  b4-b3 elec_label  HC
# --» processing LEFC elec 9 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6992857142857143 001 0.7554761904761905 auc_max 0.5864285714285715
# elec  b9-b8 elec_label  MTG
# --» processing LEFC elec 10 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6771428571428572 001 0.7871428571428571 auc_max 0.7421428571428572
# elec  b10-b9 elec_label  MTG
# --» processing LEFC elec 11 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6992857142857143 001 0.7704761904761905 auc_max 0.7864285714285714
# elec  b11-b10 elec_label  MTG
# --» processing LEFC elec 12 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6804761904761906 001 0.7445238095238096 auc_max 0.7004761904761906
# elec  d2-d1 elec_label  HC
# --» processing LEFC elec 13 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6854761904761905 001 0.7671428571428571 auc_max 0.6185714285714285
# elec  d3-d2 elec_label  HC
# --» processing LEFC elec 14 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6695238095238095 001 0.7578571428571429 auc_max 0.6247619047619047
# elec  d4-d3 elec_label  HC
# --» processing LEFC elec 15 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6830952380952382 001 0.7778571428571428 auc_max 0.7885714285714286
# elec  d5-d4 elec_label  HC
# --» processing LEFC elec 16 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6721428571428572 001 0.7495238095238095 auc_max 0.6
# elec  d6-d5 elec_label  HC
# --» processing LEFC elec 17 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6745238095238096 001 0.7533333333333333 auc_max 0.8114285714285714
# elec  d7-d6 elec_label  FuG
# --» processing LEFC elec 18 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6761904761904762 001 0.7485714285714286 auc_max 0.6797619047619048
# elec  d8-d7 elec_label  FuG
# --» processing LEFC elec 19 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6778571428571429 001 0.7654761904761905 auc_max 0.5571428571428572
# elec  d9-d8 elec_label  ITG
# --» processing LEFC elec 20 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6804761904761905 001 0.7561904761904763 auc_max 0.7054761904761906
# elec  d10-d9 elec_label  ITG
# --» processing LEFC elec 21 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6935714285714286 001 0.7611904761904762 auc_max 0.6757142857142857
# elec  d11-d10 elec_label  ITG
# --» processing LEFC elec 22 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6876190476190477 001 0.7578571428571428 auc_max 0.7769047619047621
# elec  k2-k1 elec_label  ACC
# --» processing LEFC elec 23 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6985714285714286 001 0.7671428571428571 auc_max 0.6900000000000001
# elec  k3-k2 elec_label  ACC
# --» processing LEFC elec 24 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6828571428571428 001 0.7447619047619047 auc_max 0.6528571428571428
# elec  k4-k3 elec_label  ACC
# --» processing LEFC elec 25 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6885714285714286 001 0.7635714285714286 auc_max 0.5523809523809524
# elec  k8-k7 elec_label  MFG
# --» processing LEFC elec 26 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6628571428571428 001 0.7535714285714287 auc_max 0.6078571428571429
# elec  k9-k8 elec_label  MFG
# --» processing LEFC elec 27 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.687857142857143 001 0.7647619047619049 auc_max 0.7411904761904762
# elec  k10-k9 elec_label  MFG
# --» processing LEFC elec 28 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6828571428571429 001 0.7535714285714287 auc_max 0.7564285714285715
# elec  k11-k10 elec_label  MFG
# --» processing LEFC elec 29 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6826190476190476 001 0.7485714285714286 auc_max 0.7114285714285715
# elec  k12-k11 elec_label  MFG
# --» processing LEFC elec 30 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6745238095238096 001 0.7576190476190476 auc_max 0.7264285714285714
# elec  l2-l1 elec_label  FuG
# --» processing LEFC elec 31 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6852380952380953 001 0.7614285714285713 auc_max 0.5857142857142857
# elec  l3-l2 elec_label  FuG
# --» processing LEFC elec 32 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6719047619047618 001 0.7728571428571429 auc_max 0.6411904761904761
# elec  l4-l3 elec_label  FuG
# --» processing LEFC elec 33 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.696904761904762 001 0.7604761904761905 auc_max 0.6878571428571428
# elec  l5-l4 elec_label  ITG
# --» processing LEFC elec 34 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6697619047619048 001 0.7971428571428572 auc_max 0.702857142857143
# elec  l6-l5 elec_label  ITG
# --» processing LEFC elec 35 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6771428571428573 001 0.7671428571428571 auc_max 0.6364285714285715
# elec  l7-l6 elec_label  ITG
# --» processing LEFC elec 36 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6854761904761905 001 0.7578571428571429 auc_max 0.6438095238095238
# elec  l8-l7 elec_label  ITG
# --» processing LEFC elec 37 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6735714285714286 001 0.7597619047619047 auc_max 0.5435714285714286
# elec  l9-l8 elec_label  ITG
# --» processing LEFC elec 38 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.685 001 0.7885714285714286 auc_max 0.6054761904761905
# elec  l10-l9 elec_label  ITG
# --» processing LEFC elec 39 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6911904761904762 001 0.7528571428571429 auc_max 0.6640476190476191
# elec  l11-l10 elec_label  ITG
# --» processing LEFC elec 40 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.7011904761904763 001 0.7361904761904762 auc_max 0.6992857142857144
# elec  o2-o1 elec_label  OFC
# --» processing LEFC elec 41 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6711904761904762 001 0.7635714285714286 auc_max 0.9040476190476191
# elec  o3-o2 elec_label  OFC
# --» processing LEFC elec 42 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6871428571428572 001 0.7578571428571429 auc_max 0.6
# elec  o4-o3 elec_label  OFC
# --» processing LEFC elec 43 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6854761904761905 001 0.7661904761904763 auc_max 0.6521428571428571
# elec  o5-o4 elec_label  OFC
# --» processing LEFC elec 44 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6795238095238095 001 0.7647619047619048 auc_max 0.747857142857143
# elec  o6-o5 elec_label  OFC
# --» processing LEFC elec 45 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6935714285714286 001 0.8054761904761906 auc_max 0.6945238095238098
# elec  o7-o6 elec_label  OFC
# --» processing LEFC elec 46 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6928571428571428 001 0.7811904761904762 auc_max 0.645
# elec  o8-o7 elec_label  OFC
# --» processing LEFC elec 47 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6828571428571429 001 0.7373809523809525 auc_max 0.6461904761904762
# elec  o9-o8 elec_label  IFG
# --» processing LEFC elec 48 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6945238095238095 001 0.7861904761904762 auc_max 0.7992857142857144
# elec  o10-o9 elec_label  IFG
# --» processing LEFC elec 49 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6804761904761906 001 0.7354761904761904 auc_max 0.6604761904761905
# elec  o11-o10 elec_label  IFG
# --» processing LEFC elec 50 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6769047619047619 001 0.7528571428571429 auc_max 0.7076190476190476
# elec  s2-s1 elec_label  SFG
# --» processing LEFC elec 51 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6804761904761905 001 0.7364285714285714 auc_max 0.589047619047619
# elec  s3-s2 elec_label  SFG
# --» processing LEFC elec 52 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6778571428571428 001 0.8028571428571428 auc_max 0.6771428571428572
# elec  s4-s3 elec_label  SFG
# --» processing LEFC elec 53 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6754761904761903 001 0.7697619047619046 auc_max 0.6721428571428572
# elec  s5-s4 elec_label  SFG
# --» processing LEFC elec 54 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6778571428571428 001 0.7871428571428571 auc_max 0.7421428571428572
# elec  s6-s5 elec_label  SFG
# --» processing LEFC elec 55 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6735714285714286 001 0.7521428571428572 auc_max 0.6935714285714286
# elec  s7-s6 elec_label  SFG
# --» processing LEFC elec 56 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6885714285714286 001 0.7604761904761905 auc_max 0.6328571428571428
# elec  t2-t1 elec_label  Ins
# --» processing LEFC elec 57 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6804761904761905 001 0.7847619047619048 auc_max 0.7147619047619047
# elec  t6-t5 elec_label  STG
# --» processing LEFC elec 58 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6778571428571428 001 0.7611904761904762 auc_max 0.7054761904761906
# elec  t7-t6 elec_label  STG
# --» processing LEFC elec 59 / 60 freq 4
# Size of the concatenated data:  (55, 27) Number time windows :  27
# Size of label for classif:  55
# th_perm 005:  0.6771428571428572 001 0.7611904761904762 auc_max 0.7028571428571428
