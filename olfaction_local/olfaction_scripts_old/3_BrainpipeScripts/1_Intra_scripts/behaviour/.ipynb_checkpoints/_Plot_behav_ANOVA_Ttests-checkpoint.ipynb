# %%
from os import path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MaxNLocator
from matplotlib.offsetbox import AnchoredText
from brainpipe.visual import *
from scipy.stats import sem
import seaborn as sns

# %%
def plot_jitter_behav(df,subjects,df_stats,stat_meth,
                            factor,plot_name,data_ind=False):
    conds = df.columns
    if factor.split('_')[-1] in ['volume','max']:
        df = abs(df)
    means = df.mean().values 
    err = df.sem().values 
    id_subj = [i for i,_ in enumerate(subjects)]
    print(means,err)
    
    #Convert df in order to plot Violin distribution
    df2 = df_stat.stack()
    df3 = df2.reset_index(inplace=False,drop=False,name=factor)
    df3.rename(columns={'level_0':'subjects', 'level_1':'conds'},inplace=True)
    
    #Plot BAR PLOTS // data from all subjects
    ind = np.arange(len(conds))  # the x locations for the groups
    width = 0.8      # the width of the bars
    fig, ax = plt.subplots(figsize=(3,4))
    
    ax = sns.violinplot(x='conds',y=factor,data=df3,color='grey',linewidth=0.5,
                        bw=0.5,scale='width')
    ax = sns.pointplot(x="conds", y=factor, data=df3,ci=None,color='black',linewidth=0.5)
    #ax.bar(ind, means, width, color='grey', yerr=err,zorder=-1)
    #ax.errorbar(ind, means, yerr=err, fmt='o', color='black',
    #         ecolor='lightgray', elinewidth=3, capsize=0)
    #ax.plot(ind, means)
    #ax.set_ylabel(factor+' by memory richness', fontsize=14)
    #ax.set_xticks(ind)
    #ax.set_xticklabels(conds,fontsize=11)

    # Add all values for each patient
    if data_ind == True:
        x0 = np.random.normal(ind[0], 0.1, size=df.shape[0]) #to not have all values on the same x
        x1 = np.random.normal(ind[1], 0.1, size=df.shape[0])
        x2 = np.random.normal(ind[2], 0.1, size=df.shape[0])

        colormap = np.array(["darkblue", "deepskyblue", "mediumspringgreen",
                             "yellow", "darkorange","red"])
        ax.scatter(x0,df[[conds[0]]].values, marker='o',alpha=1.,
                                           c=colormap[id_subj],zorder=1,s=50)
        ax.scatter(x1,df[[conds[1]]].values,marker='o',alpha=1.,
                                           c=colormap[id_subj],zorder=1,s=50)
        ax.scatter(x2,df[[conds[2]]].values,marker='o',alpha=1.,
                                           c=colormap[id_subj],zorder=1,s=50)
        rmaxis(plt.gca(), ['right', 'top'])
        ax.legend(loc=0, handletextpad=0.1, frameon=False)
        ax.yaxis.set_major_locator(MaxNLocator(4,integer=True))
    
    #plot the stats
    if stat_meth == 'ANOVA':
        anchored_text = AnchoredText('t = %s \np = %s' \
             % (np.round(stats['F'].values[0],2), np.round(stats['p-unc'].values[0],2)),loc=2)
    elif stat_meth == 'LinearReg':
        anchored_text = AnchoredText('t = %s \np = %s' \
             % (stats[0], stats[1]),loc=2)
    ax.add_artist(anchored_text)
    plt.tight_layout()
    fignames = [plot_name, plot_name.replace('.png','.pdf')]
    for name in fignames:
        plt.savefig(name, dpi=600)

# %% [markdown]
# #### ANOVA for Memory Richness effect on breathing and ITI/Count at E
# - Global effect of Memory Richness
# - Plot data averaged and singl-subject with colors and stats

# %%
from utils import odor_groups_3wgth
import pingouin as pg

PATH = '/media/karim/Datas4To/1_Analyses_Intra_EM_Odor/1bis_OE_BaseSam/JPlailly201306_seeg_ALS/behavior/'
df_name = path.join(PATH,'Repiration features individual total {}.xls')
path_save = path.join(PATH, 'plots/Plot_{}_{}_stat.png')
exps = ['R']
conds = ['low','mid','high']
sel_cols = ['delta_time_next_trial','total_encodage_mean_exp_duration',
           'total_encodage_mean_exp_volume', 'total_encodage_mean_exp_max',
           'total_encodage_mean_insp_duration','total_encodage_mean_insp_volume',
           'total_encodage_mean_insp_max','trial_index']

for exp in exps:
    if exp == 'R':
        sel_cols = [x.replace('encodage_','') for x in sel_cols[1:-1]]
    for col in sel_cols:
        data = np.zeros((len([x for x in odor_groups_3wgth]),len(conds)))
        subjects = [su for su in odor_groups_3wgth]
        for s,su in enumerate(odor_groups_3wgth):
            df = pd.read_excel(df_name.format(exp), sheet_name=su)
            df_sel = df[['odor_num',col]]
            for c,cond in enumerate(conds):
                od_data = []
                for od in odor_groups_3wgth[su][cond]:
                    val = df_sel.loc[df_sel['odor_num']==int(od)][col].values[0]
                    od_data.append(np.round(val,3))                    
                data[s,c] += np.mean(od_data)
        df_stat = pd.DataFrame(data,columns=conds)
        stats = pg.rm_anova(df_stat)
        print(exp,col)
        print(stats,'\n')
        col_name = col.split('_')[-2]+'_'+col.split('_')[-1]
        print(col_name)
        plot_jitter_behav(df_stat,subjects,stats,col_name,path_save.format(exp,col_name))
        del df_stat, stats, data
# Out:
# R total_mean_exp_duration
#    Source  ddof1  ddof2      F    p-unc    np2    eps
# 0  Within      2     10  0.046  0.95499  0.009  0.804
#
# exp_duration
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-172adc6ad836> in <module>()
#      33         col_name = col.split('_')[-2]+'_'+col.split('_')[-1]
#      34         print(col_name)
# ---> 35         plot_jitter_behav(df_stat,subjects,stats,col_name,path_save.format(exp,col_name))
#      36         del df_stat, stats, data
#
# TypeError: plot_jitter_behav() missing 1 required positional argument: 'plot_name'

# %% [markdown]
# #### Linear Regression for Memory Richness effect on breathing and ITI/Count at E
# - Regression effect of Memory Richness (one analysis with AVERAGED data by SUBJ)
# - Plot data averaged and singl-subject with colors and stats

# %%
from utils import odor_groups_3wgth
import statsmodels.api as sm

PATH = '/media/karim/Datas4To/1_Analyses_Intra_EM_Odor/1bis_OE_BaseSam/JPlailly201306_seeg_ALS/behavior/'
df_name = path.join(PATH,'Repiration features individual total {}.xls')
path_save = path.join(PATH, 'plots/Plot_{}_{}_{}_stat.png')
exps = ['E','R']
stat_meth = 'LinearReg'
conds = ['low','mid','high']
dict_perf = {'low':1, 'mid':2, 'high':3}

sel_cols = ['delta_time_next_trial','total_encodage_mean_exp_duration',
           'total_encodage_mean_exp_volume', 'total_encodage_mean_exp_max',
           'total_encodage_mean_insp_duration','total_encodage_mean_insp_volume',
           'total_encodage_mean_insp_max','trial_index']

for exp in exps:
    if exp == 'R':
        sel_cols = [x.replace('encodage_','') for x in sel_cols[1:-1]]
    for col in sel_cols:
        data_stat = np.zeros((len([x for x in odor_groups_3wgth]),len(conds)))
        data, score = [], []
        for s,su in enumerate(odor_groups_3wgth):
            df = pd.read_excel(df_name.format(exp), sheet_name=su)
            df_sel = df[['odor_num',col]]
            for c,cond in enumerate(conds):
                od_data = []
                for od in odor_groups_3wgth[su][cond]:
                    val = df_sel.loc[df_sel['odor_num']==int(od)][col].values[0]
                    od_data.append(np.round(val,3))    
                data_stat[s,c] += np.mean(od_data)
                data.append(np.mean(od_data))
                score.append(dict_perf[cond])
        df_stat = pd.DataFrame(data_stat,columns=conds)
        Y, X = np.array(data), sm.add_constant(score)
        model_ols = sm.OLS(Y,X).fit()
        stats = np.round(model_ols.tvalues[1],3),np.round(model_ols.pvalues[1],3)
        print('\n',exp,col.upper())
        print(model_ols.summary())
        #print(stats,'\n')
        col_name = col.split('_')[-2]+'_'+col.split('_')[-1]
        #plot_jitter_behav(df_stat,subjects,stats,stat_meth,
                                  #col_name,path_save.format(exp,stat_meth,col_name))
        del stats, data
# Out:
#  E DELTA_TIME_NEXT_TRIAL
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.109
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     1.956
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.181
# Time:                        14:52:12   Log-Likelihood:                -67.102
# No. Observations:                  18   AIC:                             138.2
# Df Residuals:                      16   BIC:                             140.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         33.2772      6.657      4.999      0.000      19.166      47.389
# x1            -4.3091      3.081     -1.398      0.181     -10.841       2.223
# ==============================================================================
# Omnibus:                        5.263   Durbin-Watson:                   0.936
# Prob(Omnibus):                  0.072   Jarque-Bera (JB):                3.510
# Skew:                           1.078   Prob(JB):                        0.173
# Kurtosis:                       3.178   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  E TOTAL_ENCODAGE_MEAN_EXP_DURATION
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                 -0.037
# Method:                 Least Squares   F-statistic:                    0.3993
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.536
# Time:                        14:52:13   Log-Likelihood:                -25.195
# No. Observations:                  18   AIC:                             54.39
# Df Residuals:                      16   BIC:                             56.17
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3688      0.649      3.651      0.002       0.993       3.744
# x1             0.1898      0.300      0.632      0.536      -0.447       0.827
# ==============================================================================
# Omnibus:                        8.870   Durbin-Watson:                   0.661
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                6.321
# Skew:                           1.406   Prob(JB):                       0.0424
# Kurtosis:                       3.721   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  E TOTAL_ENCODAGE_MEAN_EXP_VOLUME
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.061
# Method:                 Least Squares   F-statistic:                   0.02109
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.886
# Time:                        14:52:13   Log-Likelihood:                -26.563
# No. Observations:                  18   AIC:                             57.13
# Df Residuals:                      16   BIC:                             58.91
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.3579      0.700      4.796      0.000       1.874       4.842
# x1             0.0471      0.324      0.145      0.886      -0.640       0.734
# ==============================================================================
# Omnibus:                        0.286   Durbin-Watson:                   0.642
# Prob(Omnibus):                  0.867   Jarque-Bera (JB):                0.381
# Skew:                           0.246   Prob(JB):                        0.827
# Kurtosis:                       2.485   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/scipy/stats/stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
#  E TOTAL_ENCODAGE_MEAN_EXP_MAX
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.062
# Method:                 Least Squares   F-statistic:                 8.347e-05
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.993
# Time:                        14:52:13   Log-Likelihood:                -14.977
# No. Observations:                  18   AIC:                             33.95
# Df Residuals:                      16   BIC:                             35.74
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9662      0.368      8.065      0.000       2.186       3.746
# x1             0.0016      0.170      0.009      0.993      -0.359       0.362
# ==============================================================================
# Omnibus:                        5.652   Durbin-Watson:                   0.794
# Prob(Omnibus):                  0.059   Jarque-Bera (JB):                1.671
# Skew:                          -0.214   Prob(JB):                        0.434
# Kurtosis:                       1.570   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  E TOTAL_ENCODAGE_MEAN_INSP_DURATION
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.059
# Method:                 Least Squares   F-statistic:                   0.04961
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.827
# Time:                        14:52:13   Log-Likelihood:                -2.9668
# No. Observations:                  18   AIC:                             9.934
# Df Residuals:                      16   BIC:                             11.71
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5891      0.189      8.420      0.000       1.189       1.989
# x1            -0.0195      0.087     -0.223      0.827      -0.205       0.166
# ==============================================================================
# Omnibus:                       10.489   Durbin-Watson:                   0.506
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):                7.476
# Skew:                           1.416   Prob(JB):                       0.0238
# Kurtosis:                       4.397   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  E TOTAL_ENCODAGE_MEAN_INSP_VOLUME
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.061
# Method:                 Least Squares   F-statistic:                   0.02151
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.885
# Time:                        14:52:13   Log-Likelihood:                -29.739
# No. Observations:                  18   AIC:                             63.48
# Df Residuals:                      16   BIC:                             65.26
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7917      0.835     -4.540      0.000      -5.562      -2.021
# x1            -0.0567      0.387     -0.147      0.885      -0.876       0.763
# ==============================================================================
# Omnibus:                        2.195   Durbin-Watson:                   0.384
# Prob(Omnibus):                  0.334   Jarque-Bera (JB):                1.142
# Skew:                          -0.228   Prob(JB):                        0.565
# Kurtosis:                       1.853   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  E TOTAL_ENCODAGE_MEAN_INSP_MAX
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.056
# Method:                 Least Squares   F-statistic:                   0.09375
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.763
# Time:                        14:52:13   Log-Likelihood:                -20.559
# No. Observations:                  18   AIC:                             45.12
# Df Residuals:                      16   BIC:                             46.90
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.5625      0.502     -7.104      0.000      -4.626      -2.499
# x1            -0.0711      0.232     -0.306      0.763      -0.563       0.421
# ==============================================================================
# Omnibus:                        1.038   Durbin-Watson:                   0.462
# Prob(Omnibus):                  0.595   Jarque-Bera (JB):                0.750
# Skew:                          -0.010   Prob(JB):                        0.687
# Kurtosis:                       2.000   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  E TRIAL_INDEX
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.087
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     1.516
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.236
# Time:                        14:52:13   Log-Likelihood:                -40.411
# No. Observations:                  18   AIC:                             84.82
# Df Residuals:                      16   BIC:                             86.60
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.6111      1.511      5.699      0.000       5.408      11.814
# x1            -0.8611      0.699     -1.231      0.236      -2.344       0.622
# ==============================================================================
# Omnibus:                        1.172   Durbin-Watson:                   1.323
# Prob(Omnibus):                  0.556   Jarque-Bera (JB):                0.850
# Skew:                          -0.193   Prob(JB):                        0.654
# Kurtosis:                       2.008   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  R TOTAL_MEAN_EXP_DURATION
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.062
# Method:                 Least Squares   F-statistic:                  0.005829
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.940
# Time:                        14:52:13   Log-Likelihood:                -26.759
# No. Observations:                  18   AIC:                             57.52
# Df Residuals:                      16   BIC:                             59.30
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9414      0.708      4.156      0.001       1.441       4.442
# x1             0.0250      0.328      0.076      0.940      -0.670       0.720
# ==============================================================================
# Omnibus:                        5.119   Durbin-Watson:                   0.951
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                2.379
# Skew:                           0.607   Prob(JB):                        0.304
# Kurtosis:                       1.698   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  R TOTAL_MEAN_EXP_VOLUME
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.050
# Method:                 Least Squares   F-statistic:                    0.1978
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.662
# Time:                        14:52:13   Log-Likelihood:                -35.101
# No. Observations:                  18   AIC:                             74.20
# Df Residuals:                      16   BIC:                             75.98
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.1075      1.125      3.651      0.002       1.723       6.492
# x1            -0.2316      0.521     -0.445      0.662      -1.336       0.872
# ==============================================================================
# Omnibus:                        2.847   Durbin-Watson:                   0.380
# Prob(Omnibus):                  0.241   Jarque-Bera (JB):                2.017
# Skew:                          -0.654   Prob(JB):                        0.365
# Kurtosis:                       2.012   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  R TOTAL_MEAN_EXP_MAX
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.061
# Method:                 Least Squares   F-statistic:                   0.02410
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.879
# Time:                        14:52:13   Log-Likelihood:                -28.466
# No. Observations:                  18   AIC:                             60.93
# Df Residuals:                      16   BIC:                             62.71
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.1335      0.778      4.027      0.001       1.484       4.783
# x1            -0.0559      0.360     -0.155      0.879      -0.820       0.708
# ==============================================================================
# Omnibus:                        2.279   Durbin-Watson:                   0.275
# Prob(Omnibus):                  0.320   Jarque-Bera (JB):                1.685
# Skew:                          -0.584   Prob(JB):                        0.431
# Kurtosis:                       2.060   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  R TOTAL_MEAN_INSP_DURATION
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.042
# Method:                 Least Squares   F-statistic:                    0.3090
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.586
# Time:                        14:52:13   Log-Likelihood:                -13.381
# No. Observations:                  18   AIC:                             30.76
# Df Residuals:                      16   BIC:                             32.54
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8747      0.337      5.570      0.000       1.161       2.588
# x1            -0.0866      0.156     -0.556      0.586      -0.417       0.244
# ==============================================================================
# Omnibus:                        7.594   Durbin-Watson:                   1.172
# Prob(Omnibus):                  0.022   Jarque-Bera (JB):                5.350
# Skew:                           1.316   Prob(JB):                       0.0689
# Kurtosis:                       3.458   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  R TOTAL_MEAN_INSP_VOLUME
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.062
# Method:                 Least Squares   F-statistic:                  0.009581
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.923
# Time:                        14:52:14   Log-Likelihood:                -33.851
# No. Observations:                  18   AIC:                             71.70
# Df Residuals:                      16   BIC:                             73.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -4.1929      1.050     -3.995      0.001      -6.418      -1.968
# x1             0.0476      0.486      0.098      0.923      -0.982       1.078
# ==============================================================================
# Omnibus:                        3.513   Durbin-Watson:                   0.563
# Prob(Omnibus):                  0.173   Jarque-Bera (JB):                1.276
# Skew:                           0.025   Prob(JB):                        0.528
# Kurtosis:                       1.697   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  R TOTAL_MEAN_INSP_MAX
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.062
# Method:                 Least Squares   F-statistic:                   0.01427
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):              0.906
# Time:                        14:52:14   Log-Likelihood:                -26.066
# No. Observations:                  18   AIC:                             56.13
# Df Residuals:                      16   BIC:                             57.91
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.8129      0.681     -5.599      0.000      -5.257      -2.369
# x1             0.0377      0.315      0.119      0.906      -0.631       0.706
# ==============================================================================
# Omnibus:                        5.582   Durbin-Watson:                   0.409
# Prob(Omnibus):                  0.061   Jarque-Bera (JB):                1.936
# Skew:                           0.396   Prob(JB):                        0.380
# Kurtosis:                       1.603   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Stats for Memory richness perf
# - different df (no breathing recordings there)

# %%
from os import path
import numpy as np
import pandas as pd
from utils import odor_groups_3wgth
import statsmodels.api as sm

PATH = '/media/karim/Datas4To/1_Analyses_Intra_EM_Odor/1bis_OE_BaseSam/JPlailly201306_seeg_ALS/behavior/'
df_name = path.join(PATH,'episodic_all_su_all_trials_old_odors.csv')
path_save = path.join(PATH, 'plots/Plot_{}_{}_{}_stat.png')
stat_meth, exp = 'LinearReg', 'R'
subjects = [su for su in odor_groups_3wgth]
conds = ['low','mid','high']
#features = ['epi_chance_wght','odor_recognition_rt','episodic_rt']
features = ['rec_RT_wght','epi_RT_wght']
dict_perf = {'low':1, 'mid':2, 'high':3}


df = pd.read_csv(df_name)
print(df.columns)

for feat in features:
    data_stat = np.zeros((len([x for x in odor_groups_3wgth]),len(conds)))
    data, score = [], []
    for s,su in enumerate(odor_groups_3wgth):
        df_sel = df.loc[df['subject_name']==su]
        df_sel = df_sel[['odor_num',feat]]
        df_sel_gr = df_sel.groupby('odor_num').mean()
        print(su,df_sel_gr)
        for c,cond in enumerate(conds):
            od_data = []
            for od in odor_groups_3wgth[su][cond]:
                idx = [i for i,j in enumerate(df_sel_gr.index) if j==int(od)]
                val = df_sel_gr.iloc[idx,0].values[0]
                print(su,od,val,idx)
                od_data.append(np.round(val,3))    
            data_stat[s,c] += np.mean(od_data)
            data.append(np.mean(od_data))
            score.append(dict_perf[cond])
    df_stat = pd.DataFrame(data_stat,columns=conds)
    Y, X = np.array(data), sm.add_constant(score)
    model_ols = sm.OLS(Y,X).fit()
    stats = np.round(model_ols.tvalues[1],3),np.round(model_ols.pvalues[1],3)
    print(feat)
    print(model_ols.summary(),'\n')
    plot_jitter_behav(df_stat,subjects,stats,stat_meth,
                              feat,path_save.format(exp,stat_meth,feat))
    del stats, data
# Out:
# Index(['subject_name', 'run_index', 'trial_index', 'odor_num', 'image_context',
#        'repetition_of_target', 'context_day', 'score_episodic_strict',
#        'odor_recognition_rt', 'episodic_rt', 'epi_chance', 'weights',
#        'epi_chance_wght', 'rec_RT_wght', 'epi_RT_wght'],
#       dtype='object')
# CHAF           rec_RT_wght
# odor_num
# 1            2.365838
# 2            3.589650
# 3            2.849920
# 4            3.135074
# 5            3.439464
# 7            2.923069
# 8            3.138984
# 9            3.376566
# CHAF 1 2.365838446001015 [0]
# CHAF 2 3.589650448632551 [1]
# CHAF 4 3.1350740540996846 [3]
# CHAF 5 3.4394635702083076 [4]
# CHAF 8 3.1389835706535703 [6]
# CHAF 3 2.8499200444631456 [2]
# CHAF 7 2.9230693903606597 [5]
# CHAF 9 3.3765658139631682 [7]
# VACJ           rec_RT_wght
# odor_num
# 10           4.585343
# 11           6.215703
# 12           6.262798
# 13           2.786887
# 14           4.771417
# 15           3.643402
# 16           3.701849
# 17           5.653827
# VACJ 10 4.585343308284508 [0]
# VACJ 11 6.2157032086809165 [1]
# VACJ 14 4.771416864866585 [4]
# VACJ 12 6.262798338244322 [2]
# VACJ 17 5.653827196715718 [7]
# VACJ 16 3.7018489045100686 [6]
# VACJ 13 2.786887088970197 [3]
# VACJ 15 3.6434019530055592 [5]
# SEMC           rec_RT_wght
# odor_num
# 5            5.446192
# 7            4.060671
# 8            5.433319
# 9            4.288672
# 10           5.744495
# 11           7.546853
# 12           5.185836
# 13           2.405773
# SEMC 10 5.744494692662156 [4]
# SEMC 7 4.060671438017166 [1]
# SEMC 13 2.405773227307691 [7]
# SEMC 11 7.546852905195794 [5]
# SEMC 12 5.185835810379101 [6]
# SEMC 5 5.446191552370877 [0]
# SEMC 9 4.288671825228316 [3]
# SEMC 8 5.4333191995059416 [2]
# PIRJ           rec_RT_wght
# odor_num
# 1            2.789369
# 4            2.981233
# 5            4.473703
# 6            2.764719
# 7            2.070626
# 9            3.522992
# 15           4.633033
# 18           3.228799
# PIRJ 9 3.522992410496782 [5]
# PIRJ 1 2.789368605103431 [0]
# PIRJ 18 3.228799101336962 [7]
# PIRJ 5 4.4737028329502095 [2]
# PIRJ 4 2.981232651540979 [1]
# PIRJ 6 2.764719265734725 [3]
# PIRJ 7 2.070626142851578 [4]
# LEFC           rec_RT_wght
# odor_num
# 1            1.707225
# 2            6.028060
# 3            4.619557
# 4            3.480704
# 14           2.932699
# 15           2.877972
# 16           3.131173
# 17           3.669942
# LEFC 2 6.028060011702884 [1]
# LEFC 1 1.7072251872875206 [0]
# LEFC 16 3.1311733626831573 [6]
# LEFC 15 2.8779721619142093 [5]
# LEFC 3 4.619556621946828 [2]
# LEFC 4 3.48070351624786 [3]
# LEFC 17 3.669941602372052 [7]
# LEFC 14 2.932698693994914 [4]
# FERJ           rec_RT_wght
# odor_num
# 1            1.326376
# 2            2.382843
# 5            1.806474
# 7            1.881388
# 12           2.076199
# 13           2.128688
# 16           2.606801
# 17           2.477943
# FERJ 16 2.6068007793464174 [6]
# FERJ 17 2.4779427017725846 [7]
# FERJ 12 2.0761985922428576 [4]
# FERJ 7 1.8813883606963964 [3]
# FERJ 13 2.1286876420503362 [5]
# FERJ 5 1.806473616141741 [2]
# FERJ 2 2.3828432396526034 [1]
# FERJ 1 1.326375744504452 [0]
# rec_RT_wght
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                 -0.047
# Method:                 Least Squares   F-statistic:                    0.2334
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):              0.636
# Time:                        10:28:34   Log-Likelihood:                -29.137
# No. Observations:                  18   AIC:                             62.27
# Df Residuals:                      16   BIC:                             64.05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.0260      0.808      4.984      0.000       2.314       5.738
# x1            -0.1806      0.374     -0.483      0.636      -0.973       0.612
# ==============================================================================
# Omnibus:                        2.479   Durbin-Watson:                   1.004
# Prob(Omnibus):                  0.290   Jarque-Bera (JB):                1.687
# Skew:                           0.741   Prob(JB):                        0.430
# Kurtosis:                       2.776   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# [3.57605556 4.20325    3.21477778] [0.39755515 0.67721932 0.43706481]
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/scipy/stats/stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# CHAF           epi_RT_wght
# odor_num
# 1            3.095894
# 2           -4.740905
# 3            3.712031
# 4            4.344518
# 5            4.678130
# 7            3.671125
# 8            4.202428
# 9            4.375677
# CHAF 1 3.0958940015565712 [0]
# CHAF 2 -4.740905106923005 [1]
# CHAF 4 4.3445184985441285 [3]
# CHAF 5 4.678130236874975 [4]
# CHAF 8 4.202428015098014 [6]
# CHAF 3 3.712031155574257 [2]
# CHAF 7 3.6711249459162154 [5]
# CHAF 9 4.37567692507428 [7]
# VACJ           epi_RT_wght
# odor_num
# 10           8.559288
# 11           2.548425
# 12           6.904021
# 13           6.218609
# 14           8.860917
# 15           2.173291
# 16           5.064904
# 17           6.662938
# VACJ 10 8.559287752728954 [0]
# VACJ 11 2.5484254309031407 [1]
# VACJ 14 8.860916864866587 [4]
# VACJ 12 6.904020560466545 [2]
# VACJ 17 6.6629383078268285 [7]
# VACJ 16 5.064904460065624 [6]
# VACJ 13 6.218609311192419 [3]
# VACJ 15 2.1732908418944477 [5]
# SEMC           epi_RT_wght
# odor_num
# 5            5.971358
# 7            2.202283
# 8            6.088041
# 9            5.000894
# 10          -1.219839
# 11           7.205520
# 12           4.032169
# 13           3.312829
# SEMC 10 -1.2198386406711788 [4]
# SEMC 7 2.2022825491282765 [1]
# SEMC 13 3.312828782863246 [7]
# SEMC 11 7.205519571862461 [5]
# SEMC 12 4.032169143712435 [6]
# SEMC 5 5.971358219037543 [0]
# SEMC 9 5.0008940474505374 [3]
# SEMC 8 6.088041421728164 [2]
# PIRJ           epi_RT_wght
# odor_num
# 1           -0.874194
# 4            0.198753
# 5            0.437911
# 6            0.784448
# 7           -0.132457
# 9           -3.175487
# 15          -2.307717
# 18          -2.066680
# PIRJ 9 -3.1754867561698843 [5]
# PIRJ 1 -0.8741938948965695 [0]
# PIRJ 18 -2.066680065329704 [7]
# PIRJ 5 0.437911166283543 [2]
# PIRJ 4 0.19875348487431221 [1]
# PIRJ 6 0.7844484324013917 [3]
# PIRJ 7 -0.13245719048175558 [4]
# LEFC           epi_RT_wght
# odor_num
# 1           -1.307719
# 2           -3.640551
# 3            6.005057
# 4            6.443648
# 14           3.717976
# 15           2.555639
# 16          -0.785160
# 17           4.430219
# LEFC 2 -3.640551099408226 [1]
# LEFC 1 -1.307719257156924 [0]
# LEFC 16 -0.7851599706501758 [6]
# LEFC 15 2.5556388285808755 [5]
# LEFC 3 6.005056621946826 [2]
# LEFC 4 6.443647960692303 [3]
# LEFC 17 4.43021938014983 [7]
# LEFC 14 3.717976471772692 [4]
# FERJ           epi_RT_wght
# odor_num
# 1            2.721376
# 2            2.212621
# 5            2.942474
# 7            3.332722
# 12          -0.915801
# 13           4.718577
# 16          -0.345477
# 17          -0.891002
# FERJ 16 -0.3454769984313608 [6]
# FERJ 17 -0.8910017426718594 [7]
# FERJ 12 -0.9158014077571422 [4]
# FERJ 7 3.332721694029729 [3]
# FERJ 13 4.718576530939225 [5]
# FERJ 5 2.9424736161417404 [2]
# FERJ 2 2.2126210174303806 [1]
# FERJ 1 2.7213757445044515 [0]
# epi_RT_wght
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     3.446
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):             0.0819
# Time:                        10:28:35   Log-Likelihood:                -42.532
# No. Observations:                  18   AIC:                             89.06
# Df Residuals:                      16   BIC:                             90.84
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1143      1.700     -0.067      0.947      -3.718       3.489
# x1             1.4609      0.787      1.856      0.082      -0.207       3.129
# ==============================================================================
# Omnibus:                        0.258   Durbin-Watson:                   1.164
# Prob(Omnibus):                  0.879   Jarque-Bera (JB):                0.435
# Skew:                           0.164   Prob(JB):                        0.805
# Kurtosis:                       2.313   Cond. No.                         6.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# [0.72241667 4.05575    3.64416667] [1.32031629 1.06148876 0.79109215]
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/scipy/stats/stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))

# %%
"""Plot RT and perf counts barplots and Stats"""
from os import path
import numpy as np
import pandas as pd
from utils import odor_groups_3wgth
import statsmodels.api as sm

PATH = '/media/karim/Datas4To/1_Analyses_Intra_EM_Odor/1bis_OE_BaseSam/JPlailly201306_seeg_ALS/behavior/'
df_name = path.join(PATH,'episodic_all_su_all_trials_old_odors.csv')
path_save = path.join(PATH, 'plots/Plot_bars_{}_{}_{}_stat.png')
dict_conds = {'WWhere-S1':'WWhich-S1'}

df = pd.read_csv(df_name)
df2 = df['score_episodic_strict'].map(dict_conds)
print(df2['score_episodic_strict'])
print(df.columns)
df_gr = df.groupby(['subject_name','score_episodic_strict']).mean().unstack(1)
df_gr_na = df_gr.fillna(0) #in order for the mean to be accurate
df_gr_na['odor_recognition_rt'].mean().plot.bar()
#plot.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-8d0592471b20> in <module>()
#      12
#      13 df = pd.read_csv(df_name)
# ---> 14 df = df[['score_episodic_strict']].map(dict_conds)
#      15 print(df.columns)
#      16 df_gr = df.groupby(['subject_name','score_episodic_strict']).mean().unstack(1)
#
# ~/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
(8+5+9+5)/4
# Out:
# 6.75

# %%
for feat in features:
    data_stat = np.zeros((len([x for x in odor_groups_3wgth]),len(conds)))
    data, score = [], []
    for s,su in enumerate(odor_groups_3wgth):
        df_sel = df.loc[df['subject_name']==su]
        df_sel = df_sel[['odor_num',feat]]
        df_sel_gr = df_sel.groupby('odor_num').mean()
        print(su,df_sel_gr)
        for c,cond in enumerate(conds):
            od_data = []
            for od in odor_groups_3wgth[su][cond]:
                idx = [i for i,j in enumerate(df_sel_gr.index) if j==int(od)]
                val = df_sel_gr.iloc[idx,0].values[0]
                print(su,od,val,idx)
                od_data.append(np.round(val,3))    
            data_stat[s,c] += np.mean(od_data)
            data.append(np.mean(od_data))
            score.append(dict_perf[cond])
    df_stat = pd.DataFrame(data_stat,columns=conds)
    Y, X = np.array(data), sm.add_constant(score)
    model_ols = sm.OLS(Y,X).fit()
    stats = np.round(model_ols.tvalues[1],3),np.round(model_ols.pvalues[1],3)
    print(feat)dict_perf
    print(model_ols.summary(),'\n')
    plot_jitter_behav(df_stat,subjects,stats,stat_meth,
                              feat,path_save.format(exp,stat_meth,feat))
    del stats, data
