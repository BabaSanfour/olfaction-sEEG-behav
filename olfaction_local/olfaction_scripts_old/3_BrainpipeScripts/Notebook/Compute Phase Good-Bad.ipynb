# %% [markdown]
# ## Compute Phase Encoding

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
#%matplotlib notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from brainpipe.system import study
from brainpipe.feature import power, amplitude, sigfilt, phase, PLF
from brainpipe.visual import *

from brainpipe.statistics import *
from os import path

# %% [markdown]
# ### Check all files dimensions

# %%
st = study('Olfacto')

files = st.search('_bipo_sel.npz', folder='database/TS_E_all_by_odor_th40_art400_30_250_Good_Bad_EpiScore_Expi/')
for fi in files:
    loadname = path.join(st.path, 'database/TS_E_all_by_odor_th40_art400_30_250_Good_Bad_EpiScore_Expi/', fi)
    mat = np.load(loadname)
    x = np.load(loadname)['x']
    print (fi, x.shape, mat.files)
# Out:
# -> Olfacto loaded
# CHAF_odor_bad_bipo_sel.npz (94, 2816, 33) ['channel', 'label', 'xyz', 'x', 'sf']
# CHAF_odor_good_bipo_sel.npz (94, 2816, 33) ['channel', 'label', 'xyz', 'x', 'sf']
# FERJ_odor_bad_bipo_sel.npz (14, 2816, 26) ['channel', 'label', 'xyz', 'x', 'sf']
# FERJ_odor_good_bipo_sel.npz (14, 2816, 30) ['channel', 'label', 'xyz', 'x', 'sf']
# LEFC_odor_bad_bipo_sel.npz (139, 2816, 23) ['channel', 'label', 'xyz', 'x', 'sf']
# LEFC_odor_good_bipo_sel.npz (139, 2816, 35) ['channel', 'label', 'xyz', 'x', 'sf']
# MICP_odor_bad_bipo_sel.npz (67, 2816, 45) ['channel', 'label', 'xyz', 'x', 'sf']
# MICP_odor_good_bipo_sel.npz (67, 2816, 33) ['channel', 'label', 'xyz', 'x', 'sf']
# PIRJ_odor_bad_bipo_sel.npz (48, 2816, 35) ['channel', 'x', 'label', 'sf', 'xyz']
# PIRJ_odor_good_bipo_sel.npz (48, 2816, 39) ['channel', 'x', 'label', 'sf', 'xyz']
# SEMC_odor_bad_bipo_sel.npz (64, 2816, 18) ['channel', 'x', 'label', 'sf', 'xyz']
# SEMC_odor_good_bipo_sel.npz (64, 2816, 23) ['channel', 'x', 'label', 'sf', 'xyz']
# VACJ_odor_bad_bipo_sel.npz (73, 2816, 15) ['channel', 'x', 'label', 'sf', 'xyz']
# VACJ_odor_good_bipo_sel.npz (73, 2816, 14) ['channel', 'x', 'label', 'sf', 'xyz']

# %% [markdown]
# ## Compute phase
# Instantaneous phase computation

# %%
st = study('Olfacto')
subjects = ['FERJ','MICP','VACJ','SEMC','LEFC','PIRJ','CHAF']
conds = ['bad', 'good']

for su in subjects:
    for cond in conds:
        # Define phase settings 
        f = [[0.1,1.5],[2,4],[4, 8], [8, 13]]
        fname = ['VLFC','delta','theta', 'alpha']
        
        # Load file :
        fi = su+'_odor_'+cond+'_bipo_sel.npz'
        loadname = path.join(st.path, 'database/TS_E_all_by_odor_th40_art400_30_250_Good_Bad_EpiScore_Expi/', fi)
        mat = np.load(loadname)
        x = mat['x']
        n_elec, npts, n_trials = x.shape
        sf = 512.
        print ('--> compute phase on : ', fi, 'data', x.shape, 'npts', npts, 'ntrials',n_trials, 'nelec', n_elec)              

        # Define and save power objects :
        phase0bj = phase(sf, npts=npts, f=f, method='hilbert', width=358, step=51)
        kwargs = {}
        kwargs['f'], kwargs['fname'] = f, fname
        kwargs['labels'], kwargs['channels'], kwargs['xyz'] = mat['label'], mat['channel'], mat['xyz']
        kwargs['phase'],  kwargs['phase_pval']= phase0bj.get(x,n_jobs=5)
        
        save_phase = path.join(st.path, 'feature/7_Phase_E1E2_Odor_Good_Bad_EpiScore_Expi/', fi.replace('.npz', '_phase.npz'))
        np.savez(save_phase, **kwargs)
        del kwargs['phase'],  kwargs['phase_pval'], kwargs['fname']
        del kwargs, x, sf, n_elec, n_trials
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7e59687a2952> in <module>()
# ----> 1 st = study('Olfacto')
#       2 subjects = ['FERJ','MICP','VACJ','SEMC','LEFC','PIRJ','CHAF']
#       3 conds = ['bad', 'good']
#       4
#       5 for su in subjects:
#
# NameError: name 'study' is not defined

# %% [markdown]
# ### Check all phase files dimensions

# %%
st = study('Olfacto')
files = st.search('_sel_phase.npz', folder='feature/7_Phase_E1E2_Odor_Good_Bad_EpiScore_Expi/')
for fi in files:
    loadname = path.join(st.path, 'feature/7_Phase_E1E2_Odor_Good_Bad_EpiScore_Expi/', fi)
    mat = np.load(loadname)
    x = np.load(loadname)['phase']
    # nfreq, nelec, nwin, ntrials
    print (fi, x.shape)
    print(mat.files)
# Out:
# -> Olfacto loaded
# MICP_odor_good_bipo_sel_phase.npz (67, 4, 49, 33)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# CHAF_odor_bad_bipo_sel_phase.npz (94, 4, 49, 33)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# CHAF_odor_good_bipo_sel_phase.npz (94, 4, 49, 33)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# FERJ_odor_bad_bipo_sel_phase.npz (14, 4, 49, 26)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# FERJ_odor_good_bipo_sel_phase.npz (14, 4, 49, 30)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# LEFC_odor_bad_bipo_sel_phase.npz (139, 4, 49, 23)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# LEFC_odor_good_bipo_sel_phase.npz (139, 4, 49, 35)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# MICP_odor_bad_bipo_sel_phase.npz (67, 4, 49, 45)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# PIRJ_odor_bad_bipo_sel_phase.npz (48, 4, 49, 35)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# PIRJ_odor_good_bipo_sel_phase.npz (48, 4, 49, 39)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# SEMC_odor_bad_bipo_sel_phase.npz (64, 4, 49, 18)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# SEMC_odor_good_bipo_sel_phase.npz (64, 4, 49, 23)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# VACJ_odor_bad_bipo_sel_phase.npz (73, 4, 49, 15)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']
# VACJ_odor_good_bipo_sel_phase.npz (73, 4, 49, 14)
# ['labels', 'f', 'xyz', 'channels', 'fname', 'phase', 'phase_pval']

# %% [markdown]
# ### Plot phases for each electrodes

# %%
#%matplotlib notebook
st = study('Olfacto')
path_phase = path.join(st.path, 'feature/7_Phase_E1E2_Odor_Good_Bad_EpiScore_Expi/')
path_save = path.join(path_phase, 'figures_phase/')
subjects = ['FERJ','MICP','VACJ','SEMC','LEFC','PIRJ','CHAF']

for su in subjects:
    mat_good = np.load(path_phase+su+'_odor_good_bipo_sel_phase.npz')
    good_phase = mat_good['phase']
    nelecs, nfreq = good_phase.shape[0], good_phase.shape[1]
    bad_phase = np.load(path_phase+su+'_odor_bad_bipo_sel_phase.npz')['phase']
    freq_names, channels, labels = mat_good['fname'], mat_good['channels'], mat_good['labels']
    for freq in range(nfreq):
        for elec in range(nelecs):
            #phase files - nelecs, nphases,npts, ntrials
            print('plotting --> ', su, freq_names[freq],'elec', elec,'/',nelecs)
            elec_good_phase = good_phase[elec,freq,:,:]
            elec_bad_phase = bad_phase[elec,freq,:,:]
            freq_name, label, channel = freq_names[freq], labels[elec], channels[elec]
            #print('good shape', elec_good_phase.shape, 'bad shape', elec_bad_phase.shape)
            bad_good = np.concatenate((elec_good_phase,elec_bad_phase), axis = 1)
            y = [1]*elec_good_phase.shape[1] + [0]*elec_bad_phase.shape[1]
            #print('concat', bad_good.shape, 'label', len(y))

            # create the figure
            fig = plt.figure(1,figsize=(6,4))
            step = 5500/ bad_good.shape[0]
            time = np.arange(0, 5500, step)
            title = 'Phase '+str(freq_name)+' '+su+' '+str(label)+' '+str(channel)+' ('+str(elec)+')'
            fig.suptitle(title, fontsize=14)

            BorderPlot(time, bad_good, y=y, xlabel='Time (ms)',ylabel = r'Phase modulation',
                       alpha=0.3,linewidth=2,color=['m','b'],kind='sem',legend=['good','bad'])
            rmaxis(plt.gca(), ['right', 'top'])
            addLines(plt.gca(),hColor= ['dimgrey'], hLines=[0], hWidth=[1], hShape=['-'],vLines=[975,4000],
                     vWidth=[1.5]*2,vShape=['--']*2)
            #Save the figure
            fname = (path_save+su+'_Phase_'+str(freq_name)+'_elec_'+str(channel)+'_'+str(label)+'_('+str(elec)+')_Bad-Good.png')
            fig.savefig(fname, dpi=300, bbox_inches='tight')
            plt.close()
            #plt.show()
# Out:
# -> Olfacto loaded
# plotting -->  FERJ VLFC elec 0 / 14
# plotting -->  FERJ VLFC elec 1 / 14
# plotting -->  FERJ VLFC elec 2 / 14
# plotting -->  FERJ VLFC elec 3 / 14
# plotting -->  FERJ VLFC elec 4 / 14
# plotting -->  FERJ VLFC elec 5 / 14
# plotting -->  FERJ VLFC elec 6 / 14
# plotting -->  FERJ VLFC elec 7 / 14
# plotting -->  FERJ VLFC elec 8 / 14
# plotting -->  FERJ VLFC elec 9 / 14
# plotting -->  FERJ VLFC elec 10 / 14
# plotting -->  FERJ VLFC elec 11 / 14
# plotting -->  FERJ VLFC elec 12 / 14
# plotting -->  FERJ VLFC elec 13 / 14
# plotting -->  FERJ delta elec 0 / 14
# plotting -->  FERJ delta elec 1 / 14
# plotting -->  FERJ delta elec 2 / 14
# plotting -->  FERJ delta elec 3 / 14
# plotting -->  FERJ delta elec 4 / 14
# plotting -->  FERJ delta elec 5 / 14
# plotting -->  FERJ delta elec 6 / 14
# plotting -->  FERJ delta elec 7 / 14
# plotting -->  FERJ delta elec 8 / 14
# plotting -->  FERJ delta elec 9 / 14
# plotting -->  FERJ delta elec 10 / 14
# plotting -->  FERJ delta elec 11 / 14
# plotting -->  FERJ delta elec 12 / 14
# plotting -->  FERJ delta elec 13 / 14
# plotting -->  FERJ theta elec 0 / 14
# plotting -->  FERJ theta elec 1 / 14
# plotting -->  FERJ theta elec 2 / 14
# plotting -->  FERJ theta elec 3 / 14
# plotting -->  FERJ theta elec 4 / 14
# plotting -->  FERJ theta elec 5 / 14
# plotting -->  FERJ theta elec 6 / 14
# plotting -->  FERJ theta elec 7 / 14
# plotting -->  FERJ theta elec 8 / 14
# plotting -->  FERJ theta elec 9 / 14
# plotting -->  FERJ theta elec 10 / 14
# plotting -->  FERJ theta elec 11 / 14
# plotting -->  FERJ theta elec 12 / 14
# plotting -->  FERJ theta elec 13 / 14
# plotting -->  FERJ alpha elec 0 / 14
# plotting -->  FERJ alpha elec 1 / 14
# plotting -->  FERJ alpha elec 2 / 14
# plotting -->  FERJ alpha elec 3 / 14
# plotting -->  FERJ alpha elec 4 / 14
# plotting -->  FERJ alpha elec 5 / 14
# plotting -->  FERJ alpha elec 6 / 14
# plotting -->  FERJ alpha elec 7 / 14
# plotting -->  FERJ alpha elec 8 / 14
# plotting -->  FERJ alpha elec 9 / 14
# plotting -->  FERJ alpha elec 10 / 14
# plotting -->  FERJ alpha elec 11 / 14
# plotting -->  FERJ alpha elec 12 / 14
# plotting -->  FERJ alpha elec 13 / 14
# plotting -->  MICP VLFC elec 0 / 67
# plotting -->  MICP VLFC elec 1 / 67
# plotting -->  MICP VLFC elec 2 / 67
# plotting -->  MICP VLFC elec 3 / 67
# plotting -->  MICP VLFC elec 4 / 67
# plotting -->  MICP VLFC elec 5 / 67
# plotting -->  MICP VLFC elec 6 / 67
# plotting -->  MICP VLFC elec 7 / 67
# plotting -->  MICP VLFC elec 8 / 67
# plotting -->  MICP VLFC elec 9 / 67
# plotting -->  MICP VLFC elec 10 / 67
# plotting -->  MICP VLFC elec 11 / 67
# plotting -->  MICP VLFC elec 12 / 67
# plotting -->  MICP VLFC elec 13 / 67
# plotting -->  MICP VLFC elec 14 / 67
# plotting -->  MICP VLFC elec 15 / 67
# plotting -->  MICP VLFC elec 16 / 67
# plotting -->  MICP VLFC elec 17 / 67
# plotting -->  MICP VLFC elec 18 / 67
# plotting -->  MICP VLFC elec 19 / 67
# plotting -->  MICP VLFC elec 20 / 67
# plotting -->  MICP VLFC elec 21 / 67
# plotting -->  MICP VLFC elec 22 / 67
# plotting -->  MICP VLFC elec 23 / 67
# plotting -->  MICP VLFC elec 24 / 67
# plotting -->  MICP VLFC elec 25 / 67
# plotting -->  MICP VLFC elec 26 / 67
# plotting -->  MICP VLFC elec 27 / 67
# plotting -->  MICP VLFC elec 28 / 67
# plotting -->  MICP VLFC elec 29 / 67
# plotting -->  MICP VLFC elec 30 / 67
# plotting -->  MICP VLFC elec 31 / 67
# plotting -->  MICP VLFC elec 32 / 67
# plotting -->  MICP VLFC elec 33 / 67
# plotting -->  MICP VLFC elec 34 / 67
# plotting -->  MICP VLFC elec 35 / 67
# plotting -->  MICP VLFC elec 36 / 67
# plotting -->  MICP VLFC elec 37 / 67
# plotting -->  MICP VLFC elec 38 / 67
# plotting -->  MICP VLFC elec 39 / 67
# plotting -->  MICP VLFC elec 40 / 67
# plotting -->  MICP VLFC elec 41 / 67
# plotting -->  MICP VLFC elec 42 / 67
# plotting -->  MICP VLFC elec 43 / 67
# plotting -->  MICP VLFC elec 44 / 67
# plotting -->  MICP VLFC elec 45 / 67
# plotting -->  MICP VLFC elec 46 / 67
# plotting -->  MICP VLFC elec 47 / 67
# plotting -->  MICP VLFC elec 48 / 67
# plotting -->  MICP VLFC elec 49 / 67
# plotting -->  MICP VLFC elec 50 / 67
# plotting -->  MICP VLFC elec 51 / 67
# plotting -->  MICP VLFC elec 52 / 67
# plotting -->  MICP VLFC elec 53 / 67
# plotting -->  MICP VLFC elec 54 / 67
# plotting -->  MICP VLFC elec 55 / 67
# plotting -->  MICP VLFC elec 56 / 67
# plotting -->  MICP VLFC elec 57 / 67
# plotting -->  MICP VLFC elec 58 / 67
# plotting -->  MICP VLFC elec 59 / 67
# plotting -->  MICP VLFC elec 60 / 67
# plotting -->  MICP VLFC elec 61 / 67
# plotting -->  MICP VLFC elec 62 / 67
# plotting -->  MICP VLFC elec 63 / 67
# plotting -->  MICP VLFC elec 64 / 67
# plotting -->  MICP VLFC elec 65 / 67
# plotting -->  MICP VLFC elec 66 / 67
# plotting -->  MICP delta elec 0 / 67
# plotting -->  MICP delta elec 1 / 67
# plotting -->  MICP delta elec 2 / 67
# plotting -->  MICP delta elec 3 / 67
# plotting -->  MICP delta elec 4 / 67
# plotting -->  MICP delta elec 5 / 67
# plotting -->  MICP delta elec 6 / 67
# plotting -->  MICP delta elec 7 / 67
# plotting -->  MICP delta elec 8 / 67
# plotting -->  MICP delta elec 9 / 67
# plotting -->  MICP delta elec 10 / 67
# plotting -->  MICP delta elec 11 / 67
# plotting -->  MICP delta elec 12 / 67
# plotting -->  MICP delta elec 13 / 67
# plotting -->  MICP delta elec 14 / 67
# plotting -->  MICP delta elec 15 / 67
# plotting -->  MICP delta elec 16 / 67
# plotting -->  MICP delta elec 17 / 67
# plotting -->  MICP delta elec 18 / 67
# plotting -->  MICP delta elec 19 / 67
# plotting -->  MICP delta elec 20 / 67
# plotting -->  MICP delta elec 21 / 67
# plotting -->  MICP delta elec 22 / 67
# plotting -->  MICP delta elec 23 / 67
# plotting -->  MICP delta elec 24 / 67
# plotting -->  MICP delta elec 25 / 67
# plotting -->  MICP delta elec 26 / 67
# plotting -->  MICP delta elec 27 / 67
# plotting -->  MICP delta elec 28 / 67
# plotting -->  MICP delta elec 29 / 67
# plotting -->  MICP delta elec 30 / 67
# plotting -->  MICP delta elec 31 / 67
# plotting -->  MICP delta elec 32 / 67
# plotting -->  MICP delta elec 33 / 67
# plotting -->  MICP delta elec 34 / 67
# plotting -->  MICP delta elec 35 / 67
# plotting -->  MICP delta elec 36 / 67
# plotting -->  MICP delta elec 37 / 67
# plotting -->  MICP delta elec 38 / 67
# plotting -->  MICP delta elec 39 / 67
# plotting -->  MICP delta elec 40 / 67
# plotting -->  MICP delta elec 41 / 67
# plotting -->  MICP delta elec 42 / 67
# plotting -->  MICP delta elec 43 / 67
# plotting -->  MICP delta elec 44 / 67
# plotting -->  MICP delta elec 45 / 67
# plotting -->  MICP delta elec 46 / 67
# plotting -->  MICP delta elec 47 / 67
# plotting -->  MICP delta elec 48 / 67
# plotting -->  MICP delta elec 49 / 67
# plotting -->  MICP delta elec 50 / 67
# plotting -->  MICP delta elec 51 / 67
# plotting -->  MICP delta elec 52 / 67
# plotting -->  MICP delta elec 53 / 67
# plotting -->  MICP delta elec 54 / 67
# plotting -->  MICP delta elec 55 / 67
# plotting -->  MICP delta elec 56 / 67
# plotting -->  MICP delta elec 57 / 67
# plotting -->  MICP delta elec 58 / 67
# plotting -->  MICP delta elec 59 / 67
# plotting -->  MICP delta elec 60 / 67
# plotting -->  MICP delta elec 61 / 67
# plotting -->  MICP delta elec 62 / 67
# plotting -->  MICP delta elec 63 / 67
# plotting -->  MICP delta elec 64 / 67
# plotting -->  MICP delta elec 65 / 67
# plotting -->  MICP delta elec 66 / 67
# plotting -->  MICP theta elec 0 / 67
# plotting -->  MICP theta elec 1 / 67
# plotting -->  MICP theta elec 2 / 67
# plotting -->  MICP theta elec 3 / 67
# plotting -->  MICP theta elec 4 / 67
# plotting -->  MICP theta elec 5 / 67
# plotting -->  MICP theta elec 6 / 67
# plotting -->  MICP theta elec 7 / 67
# plotting -->  MICP theta elec 8 / 67
# plotting -->  MICP theta elec 9 / 67
# plotting -->  MICP theta elec 10 / 67
# plotting -->  MICP theta elec 11 / 67
# plotting -->  MICP theta elec 12 / 67
# plotting -->  MICP theta elec 13 / 67
# plotting -->  MICP theta elec 14 / 67
# plotting -->  MICP theta elec 15 / 67
# plotting -->  MICP theta elec 16 / 67
# plotting -->  MICP theta elec 17 / 67
# plotting -->  MICP theta elec 18 / 67
# plotting -->  MICP theta elec 19 / 67
# plotting -->  MICP theta elec 20 / 67
# plotting -->  MICP theta elec 21 / 67
# plotting -->  MICP theta elec 22 / 67
# plotting -->  MICP theta elec 23 / 67
# plotting -->  MICP theta elec 24 / 67
# plotting -->  MICP theta elec 25 / 67
# plotting -->  MICP theta elec 26 / 67
# plotting -->  MICP theta elec 27 / 67
# plotting -->  MICP theta elec 28 / 67
# plotting -->  MICP theta elec 29 / 67
# plotting -->  MICP theta elec 30 / 67
# plotting -->  MICP theta elec 31 / 67
# plotting -->  MICP theta elec 32 / 67
# plotting -->  MICP theta elec 33 / 67
# plotting -->  MICP theta elec 34 / 67
# plotting -->  MICP theta elec 35 / 67
# plotting -->  MICP theta elec 36 / 67
# plotting -->  MICP theta elec 37 / 67
# plotting -->  MICP theta elec 38 / 67
# plotting -->  MICP theta elec 39 / 67
# plotting -->  MICP theta elec 40 / 67
# plotting -->  MICP theta elec 41 / 67
# plotting -->  MICP theta elec 42 / 67
# plotting -->  MICP theta elec 43 / 67
# plotting -->  MICP theta elec 44 / 67
# plotting -->  MICP theta elec 45 / 67
# plotting -->  MICP theta elec 46 / 67
# plotting -->  MICP theta elec 47 / 67
# plotting -->  MICP theta elec 48 / 67
# plotting -->  MICP theta elec 49 / 67
# plotting -->  MICP theta elec 50 / 67
# plotting -->  MICP theta elec 51 / 67
# plotting -->  MICP theta elec 52 / 67
# plotting -->  MICP theta elec 53 / 67
# plotting -->  MICP theta elec 54 / 67
# plotting -->  MICP theta elec 55 / 67
# plotting -->  MICP theta elec 56 / 67
# plotting -->  MICP theta elec 57 / 67
# plotting -->  MICP theta elec 58 / 67
# plotting -->  MICP theta elec 59 / 67
# plotting -->  MICP theta elec 60 / 67
# plotting -->  MICP theta elec 61 / 67
# plotting -->  MICP theta elec 62 / 67
# plotting -->  MICP theta elec 63 / 67
# plotting -->  MICP theta elec 64 / 67
# plotting -->  MICP theta elec 65 / 67
# plotting -->  MICP theta elec 66 / 67
# plotting -->  MICP alpha elec 0 / 67
# plotting -->  MICP alpha elec 1 / 67
# plotting -->  MICP alpha elec 2 / 67
# plotting -->  MICP alpha elec 3 / 67
# plotting -->  MICP alpha elec 4 / 67
# plotting -->  MICP alpha elec 5 / 67
# plotting -->  MICP alpha elec 6 / 67
# plotting -->  MICP alpha elec 7 / 67
# plotting -->  MICP alpha elec 8 / 67
# plotting -->  MICP alpha elec 9 / 67
# plotting -->  MICP alpha elec 10 / 67
# plotting -->  MICP alpha elec 11 / 67
# plotting -->  MICP alpha elec 12 / 67
# plotting -->  MICP alpha elec 13 / 67
# plotting -->  MICP alpha elec 14 / 67
# plotting -->  MICP alpha elec 15 / 67
# plotting -->  MICP alpha elec 16 / 67
# plotting -->  MICP alpha elec 17 / 67
# plotting -->  MICP alpha elec 18 / 67
# plotting -->  MICP alpha elec 19 / 67
# plotting -->  MICP alpha elec 20 / 67
# plotting -->  MICP alpha elec 21 / 67
# plotting -->  MICP alpha elec 22 / 67
# plotting -->  MICP alpha elec 23 / 67
# plotting -->  MICP alpha elec 24 / 67
# plotting -->  MICP alpha elec 25 / 67
# plotting -->  MICP alpha elec 26 / 67
# plotting -->  MICP alpha elec 27 / 67
# plotting -->  MICP alpha elec 28 / 67
# plotting -->  MICP alpha elec 29 / 67
# plotting -->  MICP alpha elec 30 / 67
# plotting -->  MICP alpha elec 31 / 67
# plotting -->  MICP alpha elec 32 / 67
# plotting -->  MICP alpha elec 33 / 67
# plotting -->  MICP alpha elec 34 / 67
# plotting -->  MICP alpha elec 35 / 67
# plotting -->  MICP alpha elec 36 / 67
# plotting -->  MICP alpha elec 37 / 67
# plotting -->  MICP alpha elec 38 / 67
# plotting -->  MICP alpha elec 39 / 67
# plotting -->  MICP alpha elec 40 / 67
# plotting -->  MICP alpha elec 41 / 67
# plotting -->  MICP alpha elec 42 / 67
# plotting -->  MICP alpha elec 43 / 67
# plotting -->  MICP alpha elec 44 / 67
# plotting -->  MICP alpha elec 45 / 67
# plotting -->  MICP alpha elec 46 / 67
# plotting -->  MICP alpha elec 47 / 67
# plotting -->  MICP alpha elec 48 / 67
# plotting -->  MICP alpha elec 49 / 67
# plotting -->  MICP alpha elec 50 / 67
# plotting -->  MICP alpha elec 51 / 67
# plotting -->  MICP alpha elec 52 / 67
# plotting -->  MICP alpha elec 53 / 67
# plotting -->  MICP alpha elec 54 / 67
# plotting -->  MICP alpha elec 55 / 67
# plotting -->  MICP alpha elec 56 / 67
# plotting -->  MICP alpha elec 57 / 67
# plotting -->  MICP alpha elec 58 / 67
# plotting -->  MICP alpha elec 59 / 67
# plotting -->  MICP alpha elec 60 / 67
# plotting -->  MICP alpha elec 61 / 67
# plotting -->  MICP alpha elec 62 / 67
# plotting -->  MICP alpha elec 63 / 67
# plotting -->  MICP alpha elec 64 / 67
# plotting -->  MICP alpha elec 65 / 67
# plotting -->  MICP alpha elec 66 / 67
# plotting -->  VACJ VLFC elec 0 / 73
# plotting -->  VACJ VLFC elec 1 / 73
# plotting -->  VACJ VLFC elec 2 / 73
# plotting -->  VACJ VLFC elec 3 / 73
# plotting -->  VACJ VLFC elec 4 / 73
# plotting -->  VACJ VLFC elec 5 / 73
# plotting -->  VACJ VLFC elec 6 / 73
# plotting -->  VACJ VLFC elec 7 / 73
# plotting -->  VACJ VLFC elec 8 / 73
# plotting -->  VACJ VLFC elec 9 / 73
# plotting -->  VACJ VLFC elec 10 / 73
# plotting -->  VACJ VLFC elec 11 / 73
# plotting -->  VACJ VLFC elec 12 / 73
# plotting -->  VACJ VLFC elec 13 / 73
# plotting -->  VACJ VLFC elec 14 / 73
# plotting -->  VACJ VLFC elec 15 / 73
# plotting -->  VACJ VLFC elec 16 / 73
# plotting -->  VACJ VLFC elec 17 / 73
# plotting -->  VACJ VLFC elec 18 / 73
# plotting -->  VACJ VLFC elec 19 / 73
# plotting -->  VACJ VLFC elec 20 / 73
# plotting -->  VACJ VLFC elec 21 / 73
# plotting -->  VACJ VLFC elec 22 / 73
# plotting -->  VACJ VLFC elec 23 / 73
# plotting -->  VACJ VLFC elec 24 / 73
# plotting -->  VACJ VLFC elec 25 / 73
# plotting -->  VACJ VLFC elec 26 / 73
# plotting -->  VACJ VLFC elec 27 / 73
# plotting -->  VACJ VLFC elec 28 / 73
# plotting -->  VACJ VLFC elec 29 / 73
# plotting -->  VACJ VLFC elec 30 / 73
# plotting -->  VACJ VLFC elec 31 / 73
# plotting -->  VACJ VLFC elec 32 / 73
# plotting -->  VACJ VLFC elec 33 / 73
# plotting -->  VACJ VLFC elec 34 / 73
# plotting -->  VACJ VLFC elec 35 / 73
# plotting -->  VACJ VLFC elec 36 / 73
# plotting -->  VACJ VLFC elec 37 / 73
# plotting -->  VACJ VLFC elec 38 / 73
# plotting -->  VACJ VLFC elec 39 / 73
# plotting -->  VACJ VLFC elec 40 / 73
# plotting -->  VACJ VLFC elec 41 / 73
# plotting -->  VACJ VLFC elec 42 / 73
# plotting -->  VACJ VLFC elec 43 / 73
# plotting -->  VACJ VLFC elec 44 / 73
# plotting -->  VACJ VLFC elec 45 / 73
# plotting -->  VACJ VLFC elec 46 / 73
# plotting -->  VACJ VLFC elec 47 / 73
# plotting -->  VACJ VLFC elec 48 / 73
# plotting -->  VACJ VLFC elec 49 / 73
# plotting -->  VACJ VLFC elec 50 / 73
# plotting -->  VACJ VLFC elec 51 / 73
# plotting -->  VACJ VLFC elec 52 / 73
# plotting -->  VACJ VLFC elec 53 / 73
# plotting -->  VACJ VLFC elec 54 / 73
# plotting -->  VACJ VLFC elec 55 / 73
# plotting -->  VACJ VLFC elec 56 / 73
# plotting -->  VACJ VLFC elec 57 / 73
# plotting -->  VACJ VLFC elec 58 / 73
# plotting -->  VACJ VLFC elec 59 / 73
# plotting -->  VACJ VLFC elec 60 / 73
# plotting -->  VACJ VLFC elec 61 / 73
# plotting -->  VACJ VLFC elec 62 / 73
# plotting -->  VACJ VLFC elec 63 / 73
# plotting -->  VACJ VLFC elec 64 / 73
# plotting -->  VACJ VLFC elec 65 / 73
# plotting -->  VACJ VLFC elec 66 / 73
# plotting -->  VACJ VLFC elec 67 / 73
# plotting -->  VACJ VLFC elec 68 / 73
# plotting -->  VACJ VLFC elec 69 / 73
# plotting -->  VACJ VLFC elec 70 / 73
# plotting -->  VACJ VLFC elec 71 / 73
# plotting -->  VACJ VLFC elec 72 / 73
# plotting -->  VACJ delta elec 0 / 73
# plotting -->  VACJ delta elec 1 / 73
# plotting -->  VACJ delta elec 2 / 73
# plotting -->  VACJ delta elec 3 / 73
# plotting -->  VACJ delta elec 4 / 73
# plotting -->  VACJ delta elec 5 / 73
# plotting -->  VACJ delta elec 6 / 73
# plotting -->  VACJ delta elec 7 / 73
# plotting -->  VACJ delta elec 8 / 73
# plotting -->  VACJ delta elec 9 / 73
# plotting -->  VACJ delta elec 10 / 73
# plotting -->  VACJ delta elec 11 / 73
# plotting -->  VACJ delta elec 12 / 73
# plotting -->  VACJ delta elec 13 / 73
# plotting -->  VACJ delta elec 14 / 73
# plotting -->  VACJ delta elec 15 / 73
# plotting -->  VACJ delta elec 16 / 73
# plotting -->  VACJ delta elec 17 / 73
# plotting -->  VACJ delta elec 18 / 73
# plotting -->  VACJ delta elec 19 / 73
# plotting -->  VACJ delta elec 20 / 73
# plotting -->  VACJ delta elec 21 / 73
# plotting -->  VACJ delta elec 22 / 73
# plotting -->  VACJ delta elec 23 / 73
# plotting -->  VACJ delta elec 24 / 73
# plotting -->  VACJ delta elec 25 / 73
# plotting -->  VACJ delta elec 26 / 73
# plotting -->  VACJ delta elec 27 / 73
# plotting -->  VACJ delta elec 28 / 73
# plotting -->  VACJ delta elec 29 / 73
# plotting -->  VACJ delta elec 30 / 73
# plotting -->  VACJ delta elec 31 / 73
# plotting -->  VACJ delta elec 32 / 73
# plotting -->  VACJ delta elec 33 / 73
# plotting -->  VACJ delta elec 34 / 73
# plotting -->  VACJ delta elec 35 / 73
# plotting -->  VACJ delta elec 36 / 73
# plotting -->  VACJ delta elec 37 / 73
# plotting -->  VACJ delta elec 38 / 73
# plotting -->  VACJ delta elec 39 / 73
# plotting -->  VACJ delta elec 40 / 73
# plotting -->  VACJ delta elec 41 / 73
# plotting -->  VACJ delta elec 42 / 73
# plotting -->  VACJ delta elec 43 / 73
# plotting -->  VACJ delta elec 44 / 73
# plotting -->  VACJ delta elec 45 / 73
# plotting -->  VACJ delta elec 46 / 73
# plotting -->  VACJ delta elec 47 / 73
# plotting -->  VACJ delta elec 48 / 73
# plotting -->  VACJ delta elec 49 / 73
# plotting -->  VACJ delta elec 50 / 73
# plotting -->  VACJ delta elec 51 / 73
# plotting -->  VACJ delta elec 52 / 73
# plotting -->  VACJ delta elec 53 / 73
# plotting -->  VACJ delta elec 54 / 73
# plotting -->  VACJ delta elec 55 / 73
# plotting -->  VACJ delta elec 56 / 73
# plotting -->  VACJ delta elec 57 / 73
# plotting -->  VACJ delta elec 58 / 73
# plotting -->  VACJ delta elec 59 / 73
# plotting -->  VACJ delta elec 60 / 73
# plotting -->  VACJ delta elec 61 / 73
# plotting -->  VACJ delta elec 62 / 73
# plotting -->  VACJ delta elec 63 / 73
# plotting -->  VACJ delta elec 64 / 73
# plotting -->  VACJ delta elec 65 / 73
# plotting -->  VACJ delta elec 66 / 73
# plotting -->  VACJ delta elec 67 / 73
# plotting -->  VACJ delta elec 68 / 73
# plotting -->  VACJ delta elec 69 / 73
# plotting -->  VACJ delta elec 70 / 73
# plotting -->  VACJ delta elec 71 / 73
# plotting -->  VACJ delta elec 72 / 73
# plotting -->  VACJ theta elec 0 / 73
# plotting -->  VACJ theta elec 1 / 73
# plotting -->  VACJ theta elec 2 / 73
# plotting -->  VACJ theta elec 3 / 73
# plotting -->  VACJ theta elec 4 / 73
# plotting -->  VACJ theta elec 5 / 73
# plotting -->  VACJ theta elec 6 / 73
# plotting -->  VACJ theta elec 7 / 73
# plotting -->  VACJ theta elec 8 / 73
# plotting -->  VACJ theta elec 9 / 73
# plotting -->  VACJ theta elec 10 / 73
# plotting -->  VACJ theta elec 11 / 73
# plotting -->  VACJ theta elec 12 / 73
# plotting -->  VACJ theta elec 13 / 73
# plotting -->  VACJ theta elec 14 / 73
# plotting -->  VACJ theta elec 15 / 73
# plotting -->  VACJ theta elec 16 / 73
# plotting -->  VACJ theta elec 17 / 73
# plotting -->  VACJ theta elec 18 / 73
# plotting -->  VACJ theta elec 19 / 73
# plotting -->  VACJ theta elec 20 / 73
# plotting -->  VACJ theta elec 21 / 73
# plotting -->  VACJ theta elec 22 / 73
# plotting -->  VACJ theta elec 23 / 73
# plotting -->  VACJ theta elec 24 / 73
# plotting -->  VACJ theta elec 25 / 73
# plotting -->  VACJ theta elec 26 / 73
# plotting -->  VACJ theta elec 27 / 73
# plotting -->  VACJ theta elec 28 / 73
# plotting -->  VACJ theta elec 29 / 73
# plotting -->  VACJ theta elec 30 / 73
# plotting -->  VACJ theta elec 31 / 73
# plotting -->  VACJ theta elec 32 / 73
# plotting -->  VACJ theta elec 33 / 73
# plotting -->  VACJ theta elec 34 / 73
# plotting -->  VACJ theta elec 35 / 73
# plotting -->  VACJ theta elec 36 / 73
# plotting -->  VACJ theta elec 37 / 73
# plotting -->  VACJ theta elec 38 / 73
# plotting -->  VACJ theta elec 39 / 73
# plotting -->  VACJ theta elec 40 / 73
# plotting -->  VACJ theta elec 41 / 73
# plotting -->  VACJ theta elec 42 / 73
# plotting -->  VACJ theta elec 43 / 73
# plotting -->  VACJ theta elec 44 / 73
# plotting -->  VACJ theta elec 45 / 73
# plotting -->  VACJ theta elec 46 / 73
# plotting -->  VACJ theta elec 47 / 73
# plotting -->  VACJ theta elec 48 / 73
# plotting -->  VACJ theta elec 49 / 73
# plotting -->  VACJ theta elec 50 / 73
# plotting -->  VACJ theta elec 51 / 73
# plotting -->  VACJ theta elec 52 / 73
# plotting -->  VACJ theta elec 53 / 73
# plotting -->  VACJ theta elec 54 / 73
# plotting -->  VACJ theta elec 55 / 73
# plotting -->  VACJ theta elec 56 / 73
# plotting -->  VACJ theta elec 57 / 73
# plotting -->  VACJ theta elec 58 / 73
# plotting -->  VACJ theta elec 59 / 73
# plotting -->  VACJ theta elec 60 / 73
# plotting -->  VACJ theta elec 61 / 73
# plotting -->  VACJ theta elec 62 / 73
# plotting -->  VACJ theta elec 63 / 73
# plotting -->  VACJ theta elec 64 / 73
# plotting -->  VACJ theta elec 65 / 73
# plotting -->  VACJ theta elec 66 / 73
# plotting -->  VACJ theta elec 67 / 73
# plotting -->  VACJ theta elec 68 / 73
# plotting -->  VACJ theta elec 69 / 73
# plotting -->  VACJ theta elec 70 / 73
# plotting -->  VACJ theta elec 71 / 73
# plotting -->  VACJ theta elec 72 / 73
# plotting -->  VACJ alpha elec 0 / 73
# plotting -->  VACJ alpha elec 1 / 73
# plotting -->  VACJ alpha elec 2 / 73
# plotting -->  VACJ alpha elec 3 / 73
# plotting -->  VACJ alpha elec 4 / 73
# plotting -->  VACJ alpha elec 5 / 73
# plotting -->  VACJ alpha elec 6 / 73
# plotting -->  VACJ alpha elec 7 / 73
# plotting -->  VACJ alpha elec 8 / 73
# plotting -->  VACJ alpha elec 9 / 73
# plotting -->  VACJ alpha elec 10 / 73
# plotting -->  VACJ alpha elec 11 / 73
# plotting -->  VACJ alpha elec 12 / 73
# plotting -->  VACJ alpha elec 13 / 73
# plotting -->  VACJ alpha elec 14 / 73
# plotting -->  VACJ alpha elec 15 / 73
# plotting -->  VACJ alpha elec 16 / 73
# plotting -->  VACJ alpha elec 17 / 73
# plotting -->  VACJ alpha elec 18 / 73
# plotting -->  VACJ alpha elec 19 / 73
# plotting -->  VACJ alpha elec 20 / 73
# plotting -->  VACJ alpha elec 21 / 73
# plotting -->  VACJ alpha elec 22 / 73
# plotting -->  VACJ alpha elec 23 / 73
# plotting -->  VACJ alpha elec 24 / 73
# plotting -->  VACJ alpha elec 25 / 73
# plotting -->  VACJ alpha elec 26 / 73
# plotting -->  VACJ alpha elec 27 / 73
# plotting -->  VACJ alpha elec 28 / 73
# plotting -->  VACJ alpha elec 29 / 73
# plotting -->  VACJ alpha elec 30 / 73
# plotting -->  VACJ alpha elec 31 / 73
# plotting -->  VACJ alpha elec 32 / 73
# plotting -->  VACJ alpha elec 33 / 73
# plotting -->  VACJ alpha elec 34 / 73
# plotting -->  VACJ alpha elec 35 / 73
# plotting -->  VACJ alpha elec 36 / 73
# plotting -->  VACJ alpha elec 37 / 73
# plotting -->  VACJ alpha elec 38 / 73
# plotting -->  VACJ alpha elec 39 / 73
# plotting -->  VACJ alpha elec 40 / 73
# plotting -->  VACJ alpha elec 41 / 73
# plotting -->  VACJ alpha elec 42 / 73
# plotting -->  VACJ alpha elec 43 / 73
# plotting -->  VACJ alpha elec 44 / 73
# plotting -->  VACJ alpha elec 45 / 73
# plotting -->  VACJ alpha elec 46 / 73
# plotting -->  VACJ alpha elec 47 / 73
# plotting -->  VACJ alpha elec 48 / 73
# plotting -->  VACJ alpha elec 49 / 73
# plotting -->  VACJ alpha elec 50 / 73
# plotting -->  VACJ alpha elec 51 / 73
# plotting -->  VACJ alpha elec 52 / 73
# plotting -->  VACJ alpha elec 53 / 73
# plotting -->  VACJ alpha elec 54 / 73
# plotting -->  VACJ alpha elec 55 / 73
# plotting -->  VACJ alpha elec 56 / 73
# plotting -->  VACJ alpha elec 57 / 73
# plotting -->  VACJ alpha elec 58 / 73
# plotting -->  VACJ alpha elec 59 / 73
# plotting -->  VACJ alpha elec 60 / 73
# plotting -->  VACJ alpha elec 61 / 73
# plotting -->  VACJ alpha elec 62 / 73
# plotting -->  VACJ alpha elec 63 / 73
# plotting -->  VACJ alpha elec 64 / 73
# plotting -->  VACJ alpha elec 65 / 73
# plotting -->  VACJ alpha elec 66 / 73
# plotting -->  VACJ alpha elec 67 / 73
# plotting -->  VACJ alpha elec 68 / 73
# plotting -->  VACJ alpha elec 69 / 73
# plotting -->  VACJ alpha elec 70 / 73
# plotting -->  VACJ alpha elec 71 / 73
# plotting -->  VACJ alpha elec 72 / 73
# plotting -->  SEMC VLFC elec 0 / 64
# plotting -->  SEMC VLFC elec 1 / 64
# plotting -->  SEMC VLFC elec 2 / 64
# plotting -->  SEMC VLFC elec 3 / 64
# plotting -->  SEMC VLFC elec 4 / 64
# plotting -->  SEMC VLFC elec 5 / 64
# plotting -->  SEMC VLFC elec 6 / 64
# plotting -->  SEMC VLFC elec 7 / 64
# plotting -->  SEMC VLFC elec 8 / 64
# plotting -->  SEMC VLFC elec 9 / 64
# plotting -->  SEMC VLFC elec 10 / 64
# plotting -->  SEMC VLFC elec 11 / 64
# plotting -->  SEMC VLFC elec 12 / 64
# plotting -->  SEMC VLFC elec 13 / 64
# plotting -->  SEMC VLFC elec 14 / 64
# plotting -->  SEMC VLFC elec 15 / 64
# plotting -->  SEMC VLFC elec 16 / 64
# plotting -->  SEMC VLFC elec 17 / 64
# plotting -->  SEMC VLFC elec 18 / 64
# plotting -->  SEMC VLFC elec 19 / 64
# plotting -->  SEMC VLFC elec 20 / 64
# plotting -->  SEMC VLFC elec 21 / 64
# plotting -->  SEMC VLFC elec 22 / 64
# plotting -->  SEMC VLFC elec 23 / 64
# plotting -->  SEMC VLFC elec 24 / 64
# plotting -->  SEMC VLFC elec 25 / 64
# plotting -->  SEMC VLFC elec 26 / 64
# plotting -->  SEMC VLFC elec 27 / 64
# plotting -->  SEMC VLFC elec 28 / 64
# plotting -->  SEMC VLFC elec 29 / 64
# plotting -->  SEMC VLFC elec 30 / 64
# plotting -->  SEMC VLFC elec 31 / 64
# plotting -->  SEMC VLFC elec 32 / 64
# plotting -->  SEMC VLFC elec 33 / 64
# plotting -->  SEMC VLFC elec 34 / 64
# plotting -->  SEMC VLFC elec 35 / 64
# plotting -->  SEMC VLFC elec 36 / 64
# plotting -->  SEMC VLFC elec 37 / 64
# plotting -->  SEMC VLFC elec 38 / 64
# plotting -->  SEMC VLFC elec 39 / 64
# plotting -->  SEMC VLFC elec 40 / 64
# plotting -->  SEMC VLFC elec 41 / 64
# plotting -->  SEMC VLFC elec 42 / 64
# plotting -->  SEMC VLFC elec 43 / 64
# plotting -->  SEMC VLFC elec 44 / 64
# plotting -->  SEMC VLFC elec 45 / 64
# plotting -->  SEMC VLFC elec 46 / 64
# plotting -->  SEMC VLFC elec 47 / 64
# plotting -->  SEMC VLFC elec 48 / 64
# plotting -->  SEMC VLFC elec 49 / 64
# plotting -->  SEMC VLFC elec 50 / 64
# plotting -->  SEMC VLFC elec 51 / 64
# plotting -->  SEMC VLFC elec 52 / 64
# plotting -->  SEMC VLFC elec 53 / 64
# plotting -->  SEMC VLFC elec 54 / 64
# plotting -->  SEMC VLFC elec 55 / 64
# plotting -->  SEMC VLFC elec 56 / 64
# plotting -->  SEMC VLFC elec 57 / 64
# plotting -->  SEMC VLFC elec 58 / 64
# plotting -->  SEMC VLFC elec 59 / 64
# plotting -->  SEMC VLFC elec 60 / 64
# plotting -->  SEMC VLFC elec 61 / 64
# plotting -->  SEMC VLFC elec 62 / 64
# plotting -->  SEMC VLFC elec 63 / 64
# plotting -->  SEMC delta elec 0 / 64
# plotting -->  SEMC delta elec 1 / 64
# plotting -->  SEMC delta elec 2 / 64
# plotting -->  SEMC delta elec 3 / 64
# plotting -->  SEMC delta elec 4 / 64
# plotting -->  SEMC delta elec 5 / 64
# plotting -->  SEMC delta elec 6 / 64
# plotting -->  SEMC delta elec 7 / 64
# plotting -->  SEMC delta elec 8 / 64
# plotting -->  SEMC delta elec 9 / 64
# plotting -->  SEMC delta elec 10 / 64
# plotting -->  SEMC delta elec 11 / 64
# plotting -->  SEMC delta elec 12 / 64
# plotting -->  SEMC delta elec 13 / 64
# plotting -->  SEMC delta elec 14 / 64
# plotting -->  SEMC delta elec 15 / 64
# plotting -->  SEMC delta elec 16 / 64
# plotting -->  SEMC delta elec 17 / 64
# plotting -->  SEMC delta elec 18 / 64
# plotting -->  SEMC delta elec 19 / 64
# plotting -->  SEMC delta elec 20 / 64
# plotting -->  SEMC delta elec 21 / 64
# plotting -->  SEMC delta elec 22 / 64
# plotting -->  SEMC delta elec 23 / 64
# plotting -->  SEMC delta elec 24 / 64
# plotting -->  SEMC delta elec 25 / 64
# plotting -->  SEMC delta elec 26 / 64
# plotting -->  SEMC delta elec 27 / 64
# plotting -->  SEMC delta elec 28 / 64
# plotting -->  SEMC delta elec 29 / 64
# plotting -->  SEMC delta elec 30 / 64
# plotting -->  SEMC delta elec 31 / 64
# plotting -->  SEMC delta elec 32 / 64
# plotting -->  SEMC delta elec 33 / 64
# plotting -->  SEMC delta elec 34 / 64
# plotting -->  SEMC delta elec 35 / 64
# plotting -->  SEMC delta elec 36 / 64
# plotting -->  SEMC delta elec 37 / 64
# plotting -->  SEMC delta elec 38 / 64
# plotting -->  SEMC delta elec 39 / 64
# plotting -->  SEMC delta elec 40 / 64
# plotting -->  SEMC delta elec 41 / 64
# plotting -->  SEMC delta elec 42 / 64
# plotting -->  SEMC delta elec 43 / 64
# plotting -->  SEMC delta elec 44 / 64
# plotting -->  SEMC delta elec 45 / 64
# plotting -->  SEMC delta elec 46 / 64
# plotting -->  SEMC delta elec 47 / 64
# plotting -->  SEMC delta elec 48 / 64
# plotting -->  SEMC delta elec 49 / 64
# plotting -->  SEMC delta elec 50 / 64
# plotting -->  SEMC delta elec 51 / 64
# plotting -->  SEMC delta elec 52 / 64
# plotting -->  SEMC delta elec 53 / 64
# plotting -->  SEMC delta elec 54 / 64
# plotting -->  SEMC delta elec 55 / 64
# plotting -->  SEMC delta elec 56 / 64
# plotting -->  SEMC delta elec 57 / 64
# plotting -->  SEMC delta elec 58 / 64
# plotting -->  SEMC delta elec 59 / 64
# plotting -->  SEMC delta elec 60 / 64
# plotting -->  SEMC delta elec 61 / 64
# plotting -->  SEMC delta elec 62 / 64
# plotting -->  SEMC delta elec 63 / 64
# plotting -->  SEMC theta elec 0 / 64
# plotting -->  SEMC theta elec 1 / 64
# plotting -->  SEMC theta elec 2 / 64
# plotting -->  SEMC theta elec 3 / 64
# plotting -->  SEMC theta elec 4 / 64
# plotting -->  SEMC theta elec 5 / 64
# plotting -->  SEMC theta elec 6 / 64
# plotting -->  SEMC theta elec 7 / 64
# plotting -->  SEMC theta elec 8 / 64
# plotting -->  SEMC theta elec 9 / 64
# plotting -->  SEMC theta elec 10 / 64
# plotting -->  SEMC theta elec 11 / 64
# plotting -->  SEMC theta elec 12 / 64
# plotting -->  SEMC theta elec 13 / 64
# plotting -->  SEMC theta elec 14 / 64
# plotting -->  SEMC theta elec 15 / 64
# plotting -->  SEMC theta elec 16 / 64
# plotting -->  SEMC theta elec 17 / 64
# plotting -->  SEMC theta elec 18 / 64
# plotting -->  SEMC theta elec 19 / 64
# plotting -->  SEMC theta elec 20 / 64
# plotting -->  SEMC theta elec 21 / 64
# plotting -->  SEMC theta elec 22 / 64
# plotting -->  SEMC theta elec 23 / 64
# plotting -->  SEMC theta elec 24 / 64
# plotting -->  SEMC theta elec 25 / 64
# plotting -->  SEMC theta elec 26 / 64
# plotting -->  SEMC theta elec 27 / 64
# plotting -->  SEMC theta elec 28 / 64
# plotting -->  SEMC theta elec 29 / 64
# plotting -->  SEMC theta elec 30 / 64
# plotting -->  SEMC theta elec 31 / 64
# plotting -->  SEMC theta elec 32 / 64
# plotting -->  SEMC theta elec 33 / 64
# plotting -->  SEMC theta elec 34 / 64
# plotting -->  SEMC theta elec 35 / 64
# plotting -->  SEMC theta elec 36 / 64
# plotting -->  SEMC theta elec 37 / 64
# plotting -->  SEMC theta elec 38 / 64
# plotting -->  SEMC theta elec 39 / 64
# plotting -->  SEMC theta elec 40 / 64
# plotting -->  SEMC theta elec 41 / 64
# plotting -->  SEMC theta elec 42 / 64
# plotting -->  SEMC theta elec 43 / 64
# plotting -->  SEMC theta elec 44 / 64
# plotting -->  SEMC theta elec 45 / 64
# plotting -->  SEMC theta elec 46 / 64
# plotting -->  SEMC theta elec 47 / 64
# plotting -->  SEMC theta elec 48 / 64
# plotting -->  SEMC theta elec 49 / 64
# plotting -->  SEMC theta elec 50 / 64
# plotting -->  SEMC theta elec 51 / 64
# plotting -->  SEMC theta elec 52 / 64
# plotting -->  SEMC theta elec 53 / 64
# plotting -->  SEMC theta elec 54 / 64
# plotting -->  SEMC theta elec 55 / 64
# plotting -->  SEMC theta elec 56 / 64
# plotting -->  SEMC theta elec 57 / 64
# plotting -->  SEMC theta elec 58 / 64
# plotting -->  SEMC theta elec 59 / 64
# plotting -->  SEMC theta elec 60 / 64
# plotting -->  SEMC theta elec 61 / 64
# plotting -->  SEMC theta elec 62 / 64
# plotting -->  SEMC theta elec 63 / 64
# plotting -->  SEMC alpha elec 0 / 64
# plotting -->  SEMC alpha elec 1 / 64
# plotting -->  SEMC alpha elec 2 / 64
# plotting -->  SEMC alpha elec 3 / 64
# plotting -->  SEMC alpha elec 4 / 64
# plotting -->  SEMC alpha elec 5 / 64
# plotting -->  SEMC alpha elec 6 / 64
# plotting -->  SEMC alpha elec 7 / 64
# plotting -->  SEMC alpha elec 8 / 64
# plotting -->  SEMC alpha elec 9 / 64
# plotting -->  SEMC alpha elec 10 / 64
# plotting -->  SEMC alpha elec 11 / 64
# plotting -->  SEMC alpha elec 12 / 64
# plotting -->  SEMC alpha elec 13 / 64
# plotting -->  SEMC alpha elec 14 / 64
# plotting -->  SEMC alpha elec 15 / 64
# plotting -->  SEMC alpha elec 16 / 64
# plotting -->  SEMC alpha elec 17 / 64
# plotting -->  SEMC alpha elec 18 / 64
# plotting -->  SEMC alpha elec 19 / 64
# plotting -->  SEMC alpha elec 20 / 64
# plotting -->  SEMC alpha elec 21 / 64
# plotting -->  SEMC alpha elec 22 / 64
# plotting -->  SEMC alpha elec 23 / 64
# plotting -->  SEMC alpha elec 24 / 64
# plotting -->  SEMC alpha elec 25 / 64
# plotting -->  SEMC alpha elec 26 / 64
# plotting -->  SEMC alpha elec 27 / 64
# plotting -->  SEMC alpha elec 28 / 64
# plotting -->  SEMC alpha elec 29 / 64
# plotting -->  SEMC alpha elec 30 / 64
# plotting -->  SEMC alpha elec 31 / 64
# plotting -->  SEMC alpha elec 32 / 64
# plotting -->  SEMC alpha elec 33 / 64
# plotting -->  SEMC alpha elec 34 / 64
# plotting -->  SEMC alpha elec 35 / 64
# plotting -->  SEMC alpha elec 36 / 64
# plotting -->  SEMC alpha elec 37 / 64
# plotting -->  SEMC alpha elec 38 / 64
# plotting -->  SEMC alpha elec 39 / 64
# plotting -->  SEMC alpha elec 40 / 64
# plotting -->  SEMC alpha elec 41 / 64
# plotting -->  SEMC alpha elec 42 / 64
# plotting -->  SEMC alpha elec 43 / 64
# plotting -->  SEMC alpha elec 44 / 64
# plotting -->  SEMC alpha elec 45 / 64
# plotting -->  SEMC alpha elec 46 / 64
# plotting -->  SEMC alpha elec 47 / 64
# plotting -->  SEMC alpha elec 48 / 64
# plotting -->  SEMC alpha elec 49 / 64
# plotting -->  SEMC alpha elec 50 / 64
# plotting -->  SEMC alpha elec 51 / 64
# plotting -->  SEMC alpha elec 52 / 64
# plotting -->  SEMC alpha elec 53 / 64
# plotting -->  SEMC alpha elec 54 / 64
# plotting -->  SEMC alpha elec 55 / 64
# plotting -->  SEMC alpha elec 56 / 64
# plotting -->  SEMC alpha elec 57 / 64
# plotting -->  SEMC alpha elec 58 / 64
# plotting -->  SEMC alpha elec 59 / 64
# plotting -->  SEMC alpha elec 60 / 64
# plotting -->  SEMC alpha elec 61 / 64
# plotting -->  SEMC alpha elec 62 / 64
# plotting -->  SEMC alpha elec 63 / 64
# plotting -->  LEFC VLFC elec 0 / 139
# plotting -->  LEFC VLFC elec 1 / 139
# plotting -->  LEFC VLFC elec 2 / 139
# plotting -->  LEFC VLFC elec 3 / 139
# plotting -->  LEFC VLFC elec 4 / 139
# plotting -->  LEFC VLFC elec 5 / 139
# plotting -->  LEFC VLFC elec 6 / 139
# plotting -->  LEFC VLFC elec 7 / 139
# plotting -->  LEFC VLFC elec 8 / 139
# plotting -->  LEFC VLFC elec 9 / 139
# plotting -->  LEFC VLFC elec 10 / 139
# plotting -->  LEFC VLFC elec 11 / 139
# plotting -->  LEFC VLFC elec 12 / 139
# plotting -->  LEFC VLFC elec 13 / 139
# plotting -->  LEFC VLFC elec 14 / 139
# plotting -->  LEFC VLFC elec 15 / 139
# plotting -->  LEFC VLFC elec 16 / 139
# plotting -->  LEFC VLFC elec 17 / 139
# plotting -->  LEFC VLFC elec 18 / 139
# plotting -->  LEFC VLFC elec 19 / 139
# plotting -->  LEFC VLFC elec 20 / 139
# plotting -->  LEFC VLFC elec 21 / 139
# plotting -->  LEFC VLFC elec 22 / 139
# plotting -->  LEFC VLFC elec 23 / 139
# plotting -->  LEFC VLFC elec 24 / 139
# plotting -->  LEFC VLFC elec 25 / 139
# plotting -->  LEFC VLFC elec 26 / 139
# plotting -->  LEFC VLFC elec 27 / 139
# plotting -->  LEFC VLFC elec 28 / 139
# plotting -->  LEFC VLFC elec 29 / 139
# plotting -->  LEFC VLFC elec 30 / 139
# plotting -->  LEFC VLFC elec 31 / 139
# plotting -->  LEFC VLFC elec 32 / 139
# plotting -->  LEFC VLFC elec 33 / 139
# plotting -->  LEFC VLFC elec 34 / 139
# plotting -->  LEFC VLFC elec 35 / 139
# plotting -->  LEFC VLFC elec 36 / 139
# plotting -->  LEFC VLFC elec 37 / 139
# plotting -->  LEFC VLFC elec 38 / 139
# plotting -->  LEFC VLFC elec 39 / 139
# plotting -->  LEFC VLFC elec 40 / 139
# plotting -->  LEFC VLFC elec 41 / 139
# plotting -->  LEFC VLFC elec 42 / 139
# plotting -->  LEFC VLFC elec 43 / 139
# plotting -->  LEFC VLFC elec 44 / 139
# plotting -->  LEFC VLFC elec 45 / 139
# plotting -->  LEFC VLFC elec 46 / 139
# plotting -->  LEFC VLFC elec 47 / 139
# plotting -->  LEFC VLFC elec 48 / 139
# plotting -->  LEFC VLFC elec 49 / 139
# plotting -->  LEFC VLFC elec 50 / 139
# plotting -->  LEFC VLFC elec 51 / 139
# plotting -->  LEFC VLFC elec 52 / 139
# plotting -->  LEFC VLFC elec 53 / 139
# plotting -->  LEFC VLFC elec 54 / 139
# plotting -->  LEFC VLFC elec 55 / 139
# plotting -->  LEFC VLFC elec 56 / 139
# plotting -->  LEFC VLFC elec 57 / 139
# plotting -->  LEFC VLFC elec 58 / 139
# plotting -->  LEFC VLFC elec 59 / 139
# plotting -->  LEFC VLFC elec 60 / 139
# plotting -->  LEFC VLFC elec 61 / 139
# plotting -->  LEFC VLFC elec 62 / 139
# plotting -->  LEFC VLFC elec 63 / 139
# plotting -->  LEFC VLFC elec 64 / 139
# plotting -->  LEFC VLFC elec 65 / 139
# plotting -->  LEFC VLFC elec 66 / 139
# plotting -->  LEFC VLFC elec 67 / 139
# plotting -->  LEFC VLFC elec 68 / 139
# plotting -->  LEFC VLFC elec 69 / 139
# plotting -->  LEFC VLFC elec 70 / 139
# plotting -->  LEFC VLFC elec 71 / 139
# plotting -->  LEFC VLFC elec 72 / 139
# plotting -->  LEFC VLFC elec 73 / 139
# plotting -->  LEFC VLFC elec 74 / 139
# plotting -->  LEFC VLFC elec 75 / 139
# plotting -->  LEFC VLFC elec 76 / 139
# plotting -->  LEFC VLFC elec 77 / 139
# plotting -->  LEFC VLFC elec 78 / 139
# plotting -->  LEFC VLFC elec 79 / 139
# plotting -->  LEFC VLFC elec 80 / 139
# plotting -->  LEFC VLFC elec 81 / 139
# plotting -->  LEFC VLFC elec 82 / 139
# plotting -->  LEFC VLFC elec 83 / 139
# plotting -->  LEFC VLFC elec 84 / 139
# plotting -->  LEFC VLFC elec 85 / 139
# plotting -->  LEFC VLFC elec 86 / 139
# plotting -->  LEFC VLFC elec 87 / 139
# plotting -->  LEFC VLFC elec 88 / 139
# plotting -->  LEFC VLFC elec 89 / 139
# plotting -->  LEFC VLFC elec 90 / 139
# plotting -->  LEFC VLFC elec 91 / 139
# plotting -->  LEFC VLFC elec 92 / 139
# plotting -->  LEFC VLFC elec 93 / 139
# plotting -->  LEFC VLFC elec 94 / 139
# plotting -->  LEFC VLFC elec 95 / 139
# plotting -->  LEFC VLFC elec 96 / 139
# plotting -->  LEFC VLFC elec 97 / 139
# plotting -->  LEFC VLFC elec 98 / 139
# plotting -->  LEFC VLFC elec 99 / 139
# plotting -->  LEFC VLFC elec 100 / 139
# plotting -->  LEFC VLFC elec 101 / 139
# plotting -->  LEFC VLFC elec 102 / 139
# plotting -->  LEFC VLFC elec 103 / 139
# plotting -->  LEFC VLFC elec 104 / 139
# plotting -->  LEFC VLFC elec 105 / 139
# plotting -->  LEFC VLFC elec 106 / 139
# plotting -->  LEFC VLFC elec 107 / 139
# plotting -->  LEFC VLFC elec 108 / 139
# plotting -->  LEFC VLFC elec 109 / 139
# plotting -->  LEFC VLFC elec 110 / 139
# plotting -->  LEFC VLFC elec 111 / 139
# plotting -->  LEFC VLFC elec 112 / 139
# plotting -->  LEFC VLFC elec 113 / 139
# plotting -->  LEFC VLFC elec 114 / 139
# plotting -->  LEFC VLFC elec 115 / 139
# plotting -->  LEFC VLFC elec 116 / 139
# plotting -->  LEFC VLFC elec 117 / 139
# plotting -->  LEFC VLFC elec 118 / 139
# plotting -->  LEFC VLFC elec 119 / 139
# plotting -->  LEFC VLFC elec 120 / 139
# plotting -->  LEFC VLFC elec 121 / 139
# plotting -->  LEFC VLFC elec 122 / 139
# plotting -->  LEFC VLFC elec 123 / 139
# plotting -->  LEFC VLFC elec 124 / 139
# plotting -->  LEFC VLFC elec 125 / 139
# plotting -->  LEFC VLFC elec 126 / 139
# plotting -->  LEFC VLFC elec 127 / 139
# plotting -->  LEFC VLFC elec 128 / 139
# plotting -->  LEFC VLFC elec 129 / 139
# plotting -->  LEFC VLFC elec 130 / 139
# plotting -->  LEFC VLFC elec 131 / 139
# plotting -->  LEFC VLFC elec 132 / 139
# plotting -->  LEFC VLFC elec 133 / 139
# plotting -->  LEFC VLFC elec 134 / 139
# plotting -->  LEFC VLFC elec 135 / 139
# plotting -->  LEFC VLFC elec 136 / 139
# plotting -->  LEFC VLFC elec 137 / 139
# plotting -->  LEFC VLFC elec 138 / 139
# plotting -->  LEFC delta elec 0 / 139
# plotting -->  LEFC delta elec 1 / 139
# plotting -->  LEFC delta elec 2 / 139
# plotting -->  LEFC delta elec 3 / 139
# plotting -->  LEFC delta elec 4 / 139
# plotting -->  LEFC delta elec 5 / 139
# plotting -->  LEFC delta elec 6 / 139
# plotting -->  LEFC delta elec 7 / 139
# plotting -->  LEFC delta elec 8 / 139
# plotting -->  LEFC delta elec 9 / 139
# plotting -->  LEFC delta elec 10 / 139
# plotting -->  LEFC delta elec 11 / 139
# plotting -->  LEFC delta elec 12 / 139
# plotting -->  LEFC delta elec 13 / 139
# plotting -->  LEFC delta elec 14 / 139
# plotting -->  LEFC delta elec 15 / 139
# plotting -->  LEFC delta elec 16 / 139
# plotting -->  LEFC delta elec 17 / 139
# plotting -->  LEFC delta elec 18 / 139
# plotting -->  LEFC delta elec 19 / 139
# plotting -->  LEFC delta elec 20 / 139
# plotting -->  LEFC delta elec 21 / 139
# plotting -->  LEFC delta elec 22 / 139
# plotting -->  LEFC delta elec 23 / 139
# plotting -->  LEFC delta elec 24 / 139
# plotting -->  LEFC delta elec 25 / 139
# plotting -->  LEFC delta elec 26 / 139
# plotting -->  LEFC delta elec 27 / 139
# plotting -->  LEFC delta elec 28 / 139
# plotting -->  LEFC delta elec 29 / 139
# plotting -->  LEFC delta elec 30 / 139
# plotting -->  LEFC delta elec 31 / 139
# plotting -->  LEFC delta elec 32 / 139
# plotting -->  LEFC delta elec 33 / 139
# plotting -->  LEFC delta elec 34 / 139
# plotting -->  LEFC delta elec 35 / 139
# plotting -->  LEFC delta elec 36 / 139
# plotting -->  LEFC delta elec 37 / 139
# plotting -->  LEFC delta elec 38 / 139
# plotting -->  LEFC delta elec 39 / 139
# plotting -->  LEFC delta elec 40 / 139
# plotting -->  LEFC delta elec 41 / 139
# plotting -->  LEFC delta elec 42 / 139
# plotting -->  LEFC delta elec 43 / 139
# plotting -->  LEFC delta elec 44 / 139
# plotting -->  LEFC delta elec 45 / 139
# plotting -->  LEFC delta elec 46 / 139
# plotting -->  LEFC delta elec 47 / 139
# plotting -->  LEFC delta elec 48 / 139
# plotting -->  LEFC delta elec 49 / 139
# plotting -->  LEFC delta elec 50 / 139
# plotting -->  LEFC delta elec 51 / 139
# plotting -->  LEFC delta elec 52 / 139
# plotting -->  LEFC delta elec 53 / 139
# plotting -->  LEFC delta elec 54 / 139
# plotting -->  LEFC delta elec 55 / 139
# plotting -->  LEFC delta elec 56 / 139
# plotting -->  LEFC delta elec 57 / 139
# plotting -->  LEFC delta elec 58 / 139
# plotting -->  LEFC delta elec 59 / 139
# plotting -->  LEFC delta elec 60 / 139
# plotting -->  LEFC delta elec 61 / 139
# plotting -->  LEFC delta elec 62 / 139
# plotting -->  LEFC delta elec 63 / 139
# plotting -->  LEFC delta elec 64 / 139
# plotting -->  LEFC delta elec 65 / 139
# plotting -->  LEFC delta elec 66 / 139
# plotting -->  LEFC delta elec 67 / 139
# plotting -->  LEFC delta elec 68 / 139
# plotting -->  LEFC delta elec 69 / 139
# plotting -->  LEFC delta elec 70 / 139
# plotting -->  LEFC delta elec 71 / 139
# plotting -->  LEFC delta elec 72 / 139
# plotting -->  LEFC delta elec 73 / 139
# plotting -->  LEFC delta elec 74 / 139
# plotting -->  LEFC delta elec 75 / 139
# plotting -->  LEFC delta elec 76 / 139
# plotting -->  LEFC delta elec 77 / 139
# plotting -->  LEFC delta elec 78 / 139
# plotting -->  LEFC delta elec 79 / 139
# plotting -->  LEFC delta elec 80 / 139
# plotting -->  LEFC delta elec 81 / 139
# plotting -->  LEFC delta elec 82 / 139
# plotting -->  LEFC delta elec 83 / 139
# plotting -->  LEFC delta elec 84 / 139
# plotting -->  LEFC delta elec 85 / 139
# plotting -->  LEFC delta elec 86 / 139
# plotting -->  LEFC delta elec 87 / 139
# plotting -->  LEFC delta elec 88 / 139
# plotting -->  LEFC delta elec 89 / 139
# plotting -->  LEFC delta elec 90 / 139
# plotting -->  LEFC delta elec 91 / 139
# plotting -->  LEFC delta elec 92 / 139
# plotting -->  LEFC delta elec 93 / 139
# plotting -->  LEFC delta elec 94 / 139
# plotting -->  LEFC delta elec 95 / 139
# plotting -->  LEFC delta elec 96 / 139
# plotting -->  LEFC delta elec 97 / 139
# plotting -->  LEFC delta elec 98 / 139
# plotting -->  LEFC delta elec 99 / 139
# plotting -->  LEFC delta elec 100 / 139
# plotting -->  LEFC delta elec 101 / 139
# plotting -->  LEFC delta elec 102 / 139
# plotting -->  LEFC delta elec 103 / 139
# plotting -->  LEFC delta elec 104 / 139
# plotting -->  LEFC delta elec 105 / 139
# plotting -->  LEFC delta elec 106 / 139
# plotting -->  LEFC delta elec 107 / 139
# plotting -->  LEFC delta elec 108 / 139
# plotting -->  LEFC delta elec 109 / 139
# plotting -->  LEFC delta elec 110 / 139
# plotting -->  LEFC delta elec 111 / 139
# plotting -->  LEFC delta elec 112 / 139
# plotting -->  LEFC delta elec 113 / 139
# plotting -->  LEFC delta elec 114 / 139
# plotting -->  LEFC delta elec 115 / 139
# plotting -->  LEFC delta elec 116 / 139
# plotting -->  LEFC delta elec 117 / 139
# plotting -->  LEFC delta elec 118 / 139
# plotting -->  LEFC delta elec 119 / 139
# plotting -->  LEFC delta elec 120 / 139
# plotting -->  LEFC delta elec 121 / 139
# plotting -->  LEFC delta elec 122 / 139
# plotting -->  LEFC delta elec 123 / 139
# plotting -->  LEFC delta elec 124 / 139
# plotting -->  LEFC delta elec 125 / 139
# plotting -->  LEFC delta elec 126 / 139
# plotting -->  LEFC delta elec 127 / 139
# plotting -->  LEFC delta elec 128 / 139
# plotting -->  LEFC delta elec 129 / 139
# plotting -->  LEFC delta elec 130 / 139
# plotting -->  LEFC delta elec 131 / 139
# plotting -->  LEFC delta elec 132 / 139
# plotting -->  LEFC delta elec 133 / 139
# plotting -->  LEFC delta elec 134 / 139
# plotting -->  LEFC delta elec 135 / 139
# plotting -->  LEFC delta elec 136 / 139
# plotting -->  LEFC delta elec 137 / 139
# plotting -->  LEFC delta elec 138 / 139
# plotting -->  LEFC theta elec 0 / 139
# plotting -->  LEFC theta elec 1 / 139
# plotting -->  LEFC theta elec 2 / 139
# plotting -->  LEFC theta elec 3 / 139
# plotting -->  LEFC theta elec 4 / 139
# plotting -->  LEFC theta elec 5 / 139
# plotting -->  LEFC theta elec 6 / 139
# plotting -->  LEFC theta elec 7 / 139
# plotting -->  LEFC theta elec 8 / 139
# plotting -->  LEFC theta elec 9 / 139
# plotting -->  LEFC theta elec 10 / 139
# plotting -->  LEFC theta elec 11 / 139
# plotting -->  LEFC theta elec 12 / 139
# plotting -->  LEFC theta elec 13 / 139
# plotting -->  LEFC theta elec 14 / 139
# plotting -->  LEFC theta elec 15 / 139
# plotting -->  LEFC theta elec 16 / 139
# plotting -->  LEFC theta elec 17 / 139
# plotting -->  LEFC theta elec 18 / 139
# plotting -->  LEFC theta elec 19 / 139
# plotting -->  LEFC theta elec 20 / 139
# plotting -->  LEFC theta elec 21 / 139
# plotting -->  LEFC theta elec 22 / 139
# plotting -->  LEFC theta elec 23 / 139
# plotting -->  LEFC theta elec 24 / 139
# plotting -->  LEFC theta elec 25 / 139
# plotting -->  LEFC theta elec 26 / 139
# plotting -->  LEFC theta elec 27 / 139
# plotting -->  LEFC theta elec 28 / 139
# plotting -->  LEFC theta elec 29 / 139
# plotting -->  LEFC theta elec 30 / 139
# plotting -->  LEFC theta elec 31 / 139
# plotting -->  LEFC theta elec 32 / 139
# plotting -->  LEFC theta elec 33 / 139
# plotting -->  LEFC theta elec 34 / 139
# plotting -->  LEFC theta elec 35 / 139
# plotting -->  LEFC theta elec 36 / 139
# plotting -->  LEFC theta elec 37 / 139
# plotting -->  LEFC theta elec 38 / 139
# plotting -->  LEFC theta elec 39 / 139
# plotting -->  LEFC theta elec 40 / 139
# plotting -->  LEFC theta elec 41 / 139
# plotting -->  LEFC theta elec 42 / 139
# plotting -->  LEFC theta elec 43 / 139
# plotting -->  LEFC theta elec 44 / 139
# plotting -->  LEFC theta elec 45 / 139
# plotting -->  LEFC theta elec 46 / 139
# plotting -->  LEFC theta elec 47 / 139
# plotting -->  LEFC theta elec 48 / 139
# plotting -->  LEFC theta elec 49 / 139
# plotting -->  LEFC theta elec 50 / 139
# plotting -->  LEFC theta elec 51 / 139
# plotting -->  LEFC theta elec 52 / 139
# plotting -->  LEFC theta elec 53 / 139
# plotting -->  LEFC theta elec 54 / 139
# plotting -->  LEFC theta elec 55 / 139
# plotting -->  LEFC theta elec 56 / 139
# plotting -->  LEFC theta elec 57 / 139
# plotting -->  LEFC theta elec 58 / 139
# plotting -->  LEFC theta elec 59 / 139
# plotting -->  LEFC theta elec 60 / 139
# plotting -->  LEFC theta elec 61 / 139
# plotting -->  LEFC theta elec 62 / 139
# plotting -->  LEFC theta elec 63 / 139
# plotting -->  LEFC theta elec 64 / 139
# plotting -->  LEFC theta elec 65 / 139
# plotting -->  LEFC theta elec 66 / 139
# plotting -->  LEFC theta elec 67 / 139
# plotting -->  LEFC theta elec 68 / 139
# plotting -->  LEFC theta elec 69 / 139
# plotting -->  LEFC theta elec 70 / 139
# plotting -->  LEFC theta elec 71 / 139
# plotting -->  LEFC theta elec 72 / 139
# plotting -->  LEFC theta elec 73 / 139
# plotting -->  LEFC theta elec 74 / 139
# plotting -->  LEFC theta elec 75 / 139
# plotting -->  LEFC theta elec 76 / 139
# plotting -->  LEFC theta elec 77 / 139
# plotting -->  LEFC theta elec 78 / 139
# plotting -->  LEFC theta elec 79 / 139
# plotting -->  LEFC theta elec 80 / 139
# plotting -->  LEFC theta elec 81 / 139
# plotting -->  LEFC theta elec 82 / 139
# plotting -->  LEFC theta elec 83 / 139
# plotting -->  LEFC theta elec 84 / 139
# plotting -->  LEFC theta elec 85 / 139
# plotting -->  LEFC theta elec 86 / 139
# plotting -->  LEFC theta elec 87 / 139
# plotting -->  LEFC theta elec 88 / 139
# plotting -->  LEFC theta elec 89 / 139
# plotting -->  LEFC theta elec 90 / 139
# plotting -->  LEFC theta elec 91 / 139
# plotting -->  LEFC theta elec 92 / 139
# plotting -->  LEFC theta elec 93 / 139
# plotting -->  LEFC theta elec 94 / 139
# plotting -->  LEFC theta elec 95 / 139
# plotting -->  LEFC theta elec 96 / 139
# plotting -->  LEFC theta elec 97 / 139
# plotting -->  LEFC theta elec 98 / 139
# plotting -->  LEFC theta elec 99 / 139
# plotting -->  LEFC theta elec 100 / 139
# plotting -->  LEFC theta elec 101 / 139
# plotting -->  LEFC theta elec 102 / 139
# plotting -->  LEFC theta elec 103 / 139
# plotting -->  LEFC theta elec 104 / 139
# plotting -->  LEFC theta elec 105 / 139
# plotting -->  LEFC theta elec 106 / 139
# plotting -->  LEFC theta elec 107 / 139
# plotting -->  LEFC theta elec 108 / 139
# plotting -->  LEFC theta elec 109 / 139
# plotting -->  LEFC theta elec 110 / 139
# plotting -->  LEFC theta elec 111 / 139
# plotting -->  LEFC theta elec 112 / 139
# plotting -->  LEFC theta elec 113 / 139
# ...
# plotting -->  PIRJ alpha elec 0 / 48
# plotting -->  PIRJ alpha elec 1 / 48
# plotting -->  PIRJ alpha elec 2 / 48
# plotting -->  PIRJ alpha elec 3 / 48
# plotting -->  PIRJ alpha elec 4 / 48
# plotting -->  PIRJ alpha elec 5 / 48
# plotting -->  PIRJ alpha elec 6 / 48
# plotting -->  PIRJ alpha elec 7 / 48
# plotting -->  PIRJ alpha elec 8 / 48
# plotting -->  PIRJ alpha elec 9 / 48
# plotting -->  PIRJ alpha elec 10 / 48
# plotting -->  PIRJ alpha elec 11 / 48
# plotting -->  PIRJ alpha elec 12 / 48
# plotting -->  PIRJ alpha elec 13 / 48
# plotting -->  PIRJ alpha elec 14 / 48
# plotting -->  PIRJ alpha elec 15 / 48
# plotting -->  PIRJ alpha elec 16 / 48
# plotting -->  PIRJ alpha elec 17 / 48
# plotting -->  PIRJ alpha elec 18 / 48
# plotting -->  PIRJ alpha elec 19 / 48
# plotting -->  PIRJ alpha elec 20 / 48
# plotting -->  PIRJ alpha elec 21 / 48
# plotting -->  PIRJ alpha elec 22 / 48
# plotting -->  PIRJ alpha elec 23 / 48
# plotting -->  PIRJ alpha elec 24 / 48
# plotting -->  PIRJ alpha elec 25 / 48
# plotting -->  PIRJ alpha elec 26 / 48
# plotting -->  PIRJ alpha elec 27 / 48
# plotting -->  PIRJ alpha elec 28 / 48
# plotting -->  PIRJ alpha elec 29 / 48
# plotting -->  PIRJ alpha elec 30 / 48
# plotting -->  PIRJ alpha elec 31 / 48
# plotting -->  PIRJ alpha elec 32 / 48
# plotting -->  PIRJ alpha elec 33 / 48
# plotting -->  PIRJ alpha elec 34 / 48
# plotting -->  PIRJ alpha elec 35 / 48
# plotting -->  PIRJ alpha elec 36 / 48
# plotting -->  PIRJ alpha elec 37 / 48
# plotting -->  PIRJ alpha elec 38 / 48
# plotting -->  PIRJ alpha elec 39 / 48
# plotting -->  PIRJ alpha elec 40 / 48
# plotting -->  PIRJ alpha elec 41 / 48
# plotting -->  PIRJ alpha elec 42 / 48
# plotting -->  PIRJ alpha elec 43 / 48
# plotting -->  PIRJ alpha elec 44 / 48
# plotting -->  PIRJ alpha elec 45 / 48
# plotting -->  PIRJ alpha elec 46 / 48
# plotting -->  PIRJ alpha elec 47 / 48
# plotting -->  CHAF VLFC elec 0 / 94
# plotting -->  CHAF VLFC elec 1 / 94
# plotting -->  CHAF VLFC elec 2 / 94
# plotting -->  CHAF VLFC elec 3 / 94
# plotting -->  CHAF VLFC elec 4 / 94
# plotting -->  CHAF VLFC elec 5 / 94
# plotting -->  CHAF VLFC elec 6 / 94
# plotting -->  CHAF VLFC elec 7 / 94
# plotting -->  CHAF VLFC elec 8 / 94
# plotting -->  CHAF VLFC elec 9 / 94
# plotting -->  CHAF VLFC elec 10 / 94
# plotting -->  CHAF VLFC elec 11 / 94
# plotting -->  CHAF VLFC elec 12 / 94
# plotting -->  CHAF VLFC elec 13 / 94
# plotting -->  CHAF VLFC elec 14 / 94
# plotting -->  CHAF VLFC elec 15 / 94
# plotting -->  CHAF VLFC elec 16 / 94
# plotting -->  CHAF VLFC elec 17 / 94
# plotting -->  CHAF VLFC elec 18 / 94
# plotting -->  CHAF VLFC elec 19 / 94
# plotting -->  CHAF VLFC elec 20 / 94
# plotting -->  CHAF VLFC elec 21 / 94
# plotting -->  CHAF VLFC elec 22 / 94
# plotting -->  CHAF VLFC elec 23 / 94
# plotting -->  CHAF VLFC elec 24 / 94
# plotting -->  CHAF VLFC elec 25 / 94
# plotting -->  CHAF VLFC elec 26 / 94
# plotting -->  CHAF VLFC elec 27 / 94
# plotting -->  CHAF VLFC elec 28 / 94
# plotting -->  CHAF VLFC elec 29 / 94
# plotting -->  CHAF VLFC elec 30 / 94
# plotting -->  CHAF VLFC elec 31 / 94
# plotting -->  CHAF VLFC elec 32 / 94
# plotting -->  CHAF VLFC elec 33 / 94
# plotting -->  CHAF VLFC elec 34 / 94
# plotting -->  CHAF VLFC elec 35 / 94
# plotting -->  CHAF VLFC elec 36 / 94
# plotting -->  CHAF VLFC elec 37 / 94
# plotting -->  CHAF VLFC elec 38 / 94
# plotting -->  CHAF VLFC elec 39 / 94
# plotting -->  CHAF VLFC elec 40 / 94
# plotting -->  CHAF VLFC elec 41 / 94
# plotting -->  CHAF VLFC elec 42 / 94
# plotting -->  CHAF VLFC elec 43 / 94
# plotting -->  CHAF VLFC elec 44 / 94
# plotting -->  CHAF VLFC elec 45 / 94
# plotting -->  CHAF VLFC elec 46 / 94
# plotting -->  CHAF VLFC elec 47 / 94
# plotting -->  CHAF VLFC elec 48 / 94
# plotting -->  CHAF VLFC elec 49 / 94
# plotting -->  CHAF VLFC elec 50 / 94
# plotting -->  CHAF VLFC elec 51 / 94
# plotting -->  CHAF VLFC elec 52 / 94
# plotting -->  CHAF VLFC elec 53 / 94
# plotting -->  CHAF VLFC elec 54 / 94
# plotting -->  CHAF VLFC elec 55 / 94
# plotting -->  CHAF VLFC elec 56 / 94
# plotting -->  CHAF VLFC elec 57 / 94
# plotting -->  CHAF VLFC elec 58 / 94
# plotting -->  CHAF VLFC elec 59 / 94
# plotting -->  CHAF VLFC elec 60 / 94
# plotting -->  CHAF VLFC elec 61 / 94
# plotting -->  CHAF VLFC elec 62 / 94
# plotting -->  CHAF VLFC elec 63 / 94
# plotting -->  CHAF VLFC elec 64 / 94
# plotting -->  CHAF VLFC elec 65 / 94
# plotting -->  CHAF VLFC elec 66 / 94
# plotting -->  CHAF VLFC elec 67 / 94
# plotting -->  CHAF VLFC elec 68 / 94
# plotting -->  CHAF VLFC elec 69 / 94
# plotting -->  CHAF VLFC elec 70 / 94
# plotting -->  CHAF VLFC elec 71 / 94
# plotting -->  CHAF VLFC elec 72 / 94
# plotting -->  CHAF VLFC elec 73 / 94
# plotting -->  CHAF VLFC elec 74 / 94
# plotting -->  CHAF VLFC elec 75 / 94
# plotting -->  CHAF VLFC elec 76 / 94
# plotting -->  CHAF VLFC elec 77 / 94
# plotting -->  CHAF VLFC elec 78 / 94
# plotting -->  CHAF VLFC elec 79 / 94
# plotting -->  CHAF VLFC elec 80 / 94
# plotting -->  CHAF VLFC elec 81 / 94
# plotting -->  CHAF VLFC elec 82 / 94
# plotting -->  CHAF VLFC elec 83 / 94
# plotting -->  CHAF VLFC elec 84 / 94
# plotting -->  CHAF VLFC elec 85 / 94
# plotting -->  CHAF VLFC elec 86 / 94
# plotting -->  CHAF VLFC elec 87 / 94
# plotting -->  CHAF VLFC elec 88 / 94
# plotting -->  CHAF VLFC elec 89 / 94
# plotting -->  CHAF VLFC elec 90 / 94
# plotting -->  CHAF VLFC elec 91 / 94
# plotting -->  CHAF VLFC elec 92 / 94
# plotting -->  CHAF VLFC elec 93 / 94
# plotting -->  CHAF delta elec 0 / 94
# plotting -->  CHAF delta elec 1 / 94
# plotting -->  CHAF delta elec 2 / 94
# plotting -->  CHAF delta elec 3 / 94
# plotting -->  CHAF delta elec 4 / 94
# plotting -->  CHAF delta elec 5 / 94
# plotting -->  CHAF delta elec 6 / 94
# plotting -->  CHAF delta elec 7 / 94
# plotting -->  CHAF delta elec 8 / 94
# plotting -->  CHAF delta elec 9 / 94
# plotting -->  CHAF delta elec 10 / 94
# plotting -->  CHAF delta elec 11 / 94
# plotting -->  CHAF delta elec 12 / 94
# plotting -->  CHAF delta elec 13 / 94
# plotting -->  CHAF delta elec 14 / 94
# plotting -->  CHAF delta elec 15 / 94
# plotting -->  CHAF delta elec 16 / 94
# plotting -->  CHAF delta elec 17 / 94
# plotting -->  CHAF delta elec 18 / 94
# plotting -->  CHAF delta elec 19 / 94
# plotting -->  CHAF delta elec 20 / 94
# plotting -->  CHAF delta elec 21 / 94
# plotting -->  CHAF delta elec 22 / 94
# plotting -->  CHAF delta elec 23 / 94
# plotting -->  CHAF delta elec 24 / 94
# plotting -->  CHAF delta elec 25 / 94
# plotting -->  CHAF delta elec 26 / 94
# plotting -->  CHAF delta elec 27 / 94
# plotting -->  CHAF delta elec 28 / 94
# plotting -->  CHAF delta elec 29 / 94
# plotting -->  CHAF delta elec 30 / 94
# plotting -->  CHAF delta elec 31 / 94
# plotting -->  CHAF delta elec 32 / 94
# plotting -->  CHAF delta elec 33 / 94
# plotting -->  CHAF delta elec 34 / 94
# plotting -->  CHAF delta elec 35 / 94
# plotting -->  CHAF delta elec 36 / 94
# plotting -->  CHAF delta elec 37 / 94
# plotting -->  CHAF delta elec 38 / 94
# plotting -->  CHAF delta elec 39 / 94
# plotting -->  CHAF delta elec 40 / 94
# plotting -->  CHAF delta elec 41 / 94
# plotting -->  CHAF delta elec 42 / 94
# plotting -->  CHAF delta elec 43 / 94
# plotting -->  CHAF delta elec 44 / 94
# plotting -->  CHAF delta elec 45 / 94
# plotting -->  CHAF delta elec 46 / 94
# plotting -->  CHAF delta elec 47 / 94
# plotting -->  CHAF delta elec 48 / 94
# plotting -->  CHAF delta elec 49 / 94
# plotting -->  CHAF delta elec 50 / 94
# plotting -->  CHAF delta elec 51 / 94
# plotting -->  CHAF delta elec 52 / 94
# plotting -->  CHAF delta elec 53 / 94
# plotting -->  CHAF delta elec 54 / 94
# plotting -->  CHAF delta elec 55 / 94
# plotting -->  CHAF delta elec 56 / 94
# plotting -->  CHAF delta elec 57 / 94
# plotting -->  CHAF delta elec 58 / 94
# plotting -->  CHAF delta elec 59 / 94
# plotting -->  CHAF delta elec 60 / 94
# plotting -->  CHAF delta elec 61 / 94
# plotting -->  CHAF delta elec 62 / 94
# plotting -->  CHAF delta elec 63 / 94
# plotting -->  CHAF delta elec 64 / 94
# plotting -->  CHAF delta elec 65 / 94
# plotting -->  CHAF delta elec 66 / 94
# plotting -->  CHAF delta elec 67 / 94
# plotting -->  CHAF delta elec 68 / 94
# plotting -->  CHAF delta elec 69 / 94
# plotting -->  CHAF delta elec 70 / 94
# plotting -->  CHAF delta elec 71 / 94
# plotting -->  CHAF delta elec 72 / 94
# plotting -->  CHAF delta elec 73 / 94
# plotting -->  CHAF delta elec 74 / 94
# plotting -->  CHAF delta elec 75 / 94
# plotting -->  CHAF delta elec 76 / 94
# plotting -->  CHAF delta elec 77 / 94
# plotting -->  CHAF delta elec 78 / 94
# plotting -->  CHAF delta elec 79 / 94
# plotting -->  CHAF delta elec 80 / 94
# plotting -->  CHAF delta elec 81 / 94
# plotting -->  CHAF delta elec 82 / 94
# plotting -->  CHAF delta elec 83 / 94
# plotting -->  CHAF delta elec 84 / 94
# plotting -->  CHAF delta elec 85 / 94
# plotting -->  CHAF delta elec 86 / 94
# plotting -->  CHAF delta elec 87 / 94
# plotting -->  CHAF delta elec 88 / 94
# plotting -->  CHAF delta elec 89 / 94
# plotting -->  CHAF delta elec 90 / 94
# plotting -->  CHAF delta elec 91 / 94
# plotting -->  CHAF delta elec 92 / 94
# plotting -->  CHAF delta elec 93 / 94
# plotting -->  CHAF theta elec 0 / 94
# plotting -->  CHAF theta elec 1 / 94
# plotting -->  CHAF theta elec 2 / 94
# plotting -->  CHAF theta elec 3 / 94
# plotting -->  CHAF theta elec 4 / 94
# plotting -->  CHAF theta elec 5 / 94
# plotting -->  CHAF theta elec 6 / 94
# plotting -->  CHAF theta elec 7 / 94
# plotting -->  CHAF theta elec 8 / 94
# plotting -->  CHAF theta elec 9 / 94
# plotting -->  CHAF theta elec 10 / 94
# plotting -->  CHAF theta elec 11 / 94
# plotting -->  CHAF theta elec 12 / 94
# plotting -->  CHAF theta elec 13 / 94
# plotting -->  CHAF theta elec 14 / 94
# plotting -->  CHAF theta elec 15 / 94
# plotting -->  CHAF theta elec 16 / 94
# plotting -->  CHAF theta elec 17 / 94
# plotting -->  CHAF theta elec 18 / 94
# plotting -->  CHAF theta elec 19 / 94
# plotting -->  CHAF theta elec 20 / 94
# plotting -->  CHAF theta elec 21 / 94
# plotting -->  CHAF theta elec 22 / 94
# plotting -->  CHAF theta elec 23 / 94
# plotting -->  CHAF theta elec 24 / 94
# plotting -->  CHAF theta elec 25 / 94
# plotting -->  CHAF theta elec 26 / 94
# plotting -->  CHAF theta elec 27 / 94
# plotting -->  CHAF theta elec 28 / 94
# plotting -->  CHAF theta elec 29 / 94
# plotting -->  CHAF theta elec 30 / 94
# plotting -->  CHAF theta elec 31 / 94
# plotting -->  CHAF theta elec 32 / 94
# plotting -->  CHAF theta elec 33 / 94
# plotting -->  CHAF theta elec 34 / 94
# plotting -->  CHAF theta elec 35 / 94
# plotting -->  CHAF theta elec 36 / 94
# plotting -->  CHAF theta elec 37 / 94
# plotting -->  CHAF theta elec 38 / 94
# plotting -->  CHAF theta elec 39 / 94
# plotting -->  CHAF theta elec 40 / 94
# plotting -->  CHAF theta elec 41 / 94
# plotting -->  CHAF theta elec 42 / 94
# plotting -->  CHAF theta elec 43 / 94
# plotting -->  CHAF theta elec 44 / 94
# plotting -->  CHAF theta elec 45 / 94
# plotting -->  CHAF theta elec 46 / 94
# plotting -->  CHAF theta elec 47 / 94
# plotting -->  CHAF theta elec 48 / 94
# plotting -->  CHAF theta elec 49 / 94
# plotting -->  CHAF theta elec 50 / 94
# plotting -->  CHAF theta elec 51 / 94
# plotting -->  CHAF theta elec 52 / 94
# plotting -->  CHAF theta elec 53 / 94
# plotting -->  CHAF theta elec 54 / 94
# plotting -->  CHAF theta elec 55 / 94
# plotting -->  CHAF theta elec 56 / 94
# plotting -->  CHAF theta elec 57 / 94
# plotting -->  CHAF theta elec 58 / 94
# plotting -->  CHAF theta elec 59 / 94
# plotting -->  CHAF theta elec 60 / 94
# plotting -->  CHAF theta elec 61 / 94
# plotting -->  CHAF theta elec 62 / 94
# plotting -->  CHAF theta elec 63 / 94
# plotting -->  CHAF theta elec 64 / 94
# plotting -->  CHAF theta elec 65 / 94
# plotting -->  CHAF theta elec 66 / 94
# plotting -->  CHAF theta elec 67 / 94
# plotting -->  CHAF theta elec 68 / 94
# plotting -->  CHAF theta elec 69 / 94
# plotting -->  CHAF theta elec 70 / 94
# plotting -->  CHAF theta elec 71 / 94
# plotting -->  CHAF theta elec 72 / 94
# plotting -->  CHAF theta elec 73 / 94
# plotting -->  CHAF theta elec 74 / 94
# plotting -->  CHAF theta elec 75 / 94
# plotting -->  CHAF theta elec 76 / 94
# plotting -->  CHAF theta elec 77 / 94
# plotting -->  CHAF theta elec 78 / 94
# plotting -->  CHAF theta elec 79 / 94
# plotting -->  CHAF theta elec 80 / 94
# plotting -->  CHAF theta elec 81 / 94
# plotting -->  CHAF theta elec 82 / 94
# plotting -->  CHAF theta elec 83 / 94
# plotting -->  CHAF theta elec 84 / 94
# plotting -->  CHAF theta elec 85 / 94
# plotting -->  CHAF theta elec 86 / 94
# plotting -->  CHAF theta elec 87 / 94
# plotting -->  CHAF theta elec 88 / 94
# plotting -->  CHAF theta elec 89 / 94
# plotting -->  CHAF theta elec 90 / 94
# plotting -->  CHAF theta elec 91 / 94
# plotting -->  CHAF theta elec 92 / 94
# plotting -->  CHAF theta elec 93 / 94
# plotting -->  CHAF alpha elec 0 / 94
# plotting -->  CHAF alpha elec 1 / 94
# plotting -->  CHAF alpha elec 2 / 94
# plotting -->  CHAF alpha elec 3 / 94
# plotting -->  CHAF alpha elec 4 / 94
# plotting -->  CHAF alpha elec 5 / 94
# plotting -->  CHAF alpha elec 6 / 94
# plotting -->  CHAF alpha elec 7 / 94
# plotting -->  CHAF alpha elec 8 / 94
# plotting -->  CHAF alpha elec 9 / 94
# plotting -->  CHAF alpha elec 10 / 94
# plotting -->  CHAF alpha elec 11 / 94
# plotting -->  CHAF alpha elec 12 / 94
# plotting -->  CHAF alpha elec 13 / 94
# plotting -->  CHAF alpha elec 14 / 94
# plotting -->  CHAF alpha elec 15 / 94
# plotting -->  CHAF alpha elec 16 / 94
# plotting -->  CHAF alpha elec 17 / 94
# plotting -->  CHAF alpha elec 18 / 94
# plotting -->  CHAF alpha elec 19 / 94
# plotting -->  CHAF alpha elec 20 / 94
# plotting -->  CHAF alpha elec 21 / 94
# plotting -->  CHAF alpha elec 22 / 94
# plotting -->  CHAF alpha elec 23 / 94
# plotting -->  CHAF alpha elec 24 / 94
# plotting -->  CHAF alpha elec 25 / 94
# plotting -->  CHAF alpha elec 26 / 94
# plotting -->  CHAF alpha elec 27 / 94
# plotting -->  CHAF alpha elec 28 / 94
# plotting -->  CHAF alpha elec 29 / 94
# plotting -->  CHAF alpha elec 30 / 94
# plotting -->  CHAF alpha elec 31 / 94
# plotting -->  CHAF alpha elec 32 / 94
# plotting -->  CHAF alpha elec 33 / 94
# plotting -->  CHAF alpha elec 34 / 94
# plotting -->  CHAF alpha elec 35 / 94
# plotting -->  CHAF alpha elec 36 / 94
# plotting -->  CHAF alpha elec 37 / 94
# plotting -->  CHAF alpha elec 38 / 94
# plotting -->  CHAF alpha elec 39 / 94
# plotting -->  CHAF alpha elec 40 / 94
# plotting -->  CHAF alpha elec 41 / 94
# plotting -->  CHAF alpha elec 42 / 94
# plotting -->  CHAF alpha elec 43 / 94
# plotting -->  CHAF alpha elec 44 / 94
# plotting -->  CHAF alpha elec 45 / 94
# plotting -->  CHAF alpha elec 46 / 94
# plotting -->  CHAF alpha elec 47 / 94
# plotting -->  CHAF alpha elec 48 / 94
# plotting -->  CHAF alpha elec 49 / 94
# plotting -->  CHAF alpha elec 50 / 94
# plotting -->  CHAF alpha elec 51 / 94
# plotting -->  CHAF alpha elec 52 / 94
# plotting -->  CHAF alpha elec 53 / 94
# plotting -->  CHAF alpha elec 54 / 94
# plotting -->  CHAF alpha elec 55 / 94
# plotting -->  CHAF alpha elec 56 / 94
# plotting -->  CHAF alpha elec 57 / 94
# plotting -->  CHAF alpha elec 58 / 94
# plotting -->  CHAF alpha elec 59 / 94
# plotting -->  CHAF alpha elec 60 / 94
# plotting -->  CHAF alpha elec 61 / 94
# plotting -->  CHAF alpha elec 62 / 94
# plotting -->  CHAF alpha elec 63 / 94
# plotting -->  CHAF alpha elec 64 / 94
# plotting -->  CHAF alpha elec 65 / 94
# plotting -->  CHAF alpha elec 66 / 94
# plotting -->  CHAF alpha elec 67 / 94
# plotting -->  CHAF alpha elec 68 / 94
# plotting -->  CHAF alpha elec 69 / 94
# plotting -->  CHAF alpha elec 70 / 94
# plotting -->  CHAF alpha elec 71 / 94
# plotting -->  CHAF alpha elec 72 / 94
# plotting -->  CHAF alpha elec 73 / 94
# plotting -->  CHAF alpha elec 74 / 94
# plotting -->  CHAF alpha elec 75 / 94
# plotting -->  CHAF alpha elec 76 / 94
# plotting -->  CHAF alpha elec 77 / 94
# plotting -->  CHAF alpha elec 78 / 94
# plotting -->  CHAF alpha elec 79 / 94
# plotting -->  CHAF alpha elec 80 / 94
# plotting -->  CHAF alpha elec 81 / 94
# plotting -->  CHAF alpha elec 82 / 94
# plotting -->  CHAF alpha elec 83 / 94
# plotting -->  CHAF alpha elec 84 / 94
# plotting -->  CHAF alpha elec 85 / 94
# plotting -->  CHAF alpha elec 86 / 94
# plotting -->  CHAF alpha elec 87 / 94
# plotting -->  CHAF alpha elec 88 / 94
# plotting -->  CHAF alpha elec 89 / 94
# plotting -->  CHAF alpha elec 90 / 94
# plotting -->  CHAF alpha elec 91 / 94
# plotting -->  CHAF alpha elec 92 / 94
# plotting -->  CHAF alpha elec 93 / 94
