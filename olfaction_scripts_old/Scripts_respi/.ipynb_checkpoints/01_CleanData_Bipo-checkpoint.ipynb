# %% [markdown]
# ### Create all info file

# %%
import numpy as np
from brainpipe.system import study
import pandas as pd

st = study('respi')
subjects = ['CHAF', 'LEFC', 'PIRJ', 'VACJ', 'SEMC', 'FERJ','MICP']
path_data = st.path+'/raw_data/'

for su in subjects:
    path_files = path.join(path_data,su)
    x = np.loadtxt(path_files + '/' + 'channel_names.txt', dtype=str)
    names_frame = pd.DataFrame(x)
    y = np.loadtxt(path_files + '/' +'channel_coords.txt', dtype=str)
    coord_frame = pd.DataFrame(y)
    z = np.loadtxt(path_files + '/' +'channel_descriptions.txt', dtype=str)
    descr_frame = pd.DataFrame(z)
    all_df = [names_frame,coord_frame,descr_frame ]
    all_info = pd.concat(all_df, axis=1)
    all_info.to_csv(path_files+'/'+su+"_all_info.txt", header=False, index=False)
# Out:
# -> respi loaded

# %% [markdown]
# ### Create mat files with all electrodes information

# %%
import numpy as np
from os import path
import pandas as pd
from scipy.io import savemat

st = study('respi') # Load the study
subjects = ['CHAF', 'LEFC', 'PIRJ', 'VACJ', 'SEMC', 'FERJ','MICP']
sessions =  ['E1', 'E2']

for su in subjects:
    path_data = path.join(st.path,('raw_data/'+su+'/'))
    for sess in sessions:
        print ('-> Computing on : ', su , 'sess', sess)
        dataname = path.join(path_data,(su+'_'+sess+'_sigs.npy'))
        if path.isfile(dataname) == True:
            data = np.load(dataname)
            print ('data shape', data.shape)
            data = data[:,:]
            print ('data shape2', data.shape)
            #Sampling frequency
            sf = 512.

            ## Coordinates of electrodes included in Data
            elec_info = path.join(path_data,(su+'_all_info.txt'))
            loadfile = np.loadtxt(elec_info, dtype=str, delimiter=',')
            chanmonop = pd.DataFrame(loadfile,)
            coord = (np.array(chanmonop.iloc[:,0]), 
                     np.array(chanmonop.iloc[:,1]), 
                     np.array(chanmonop.iloc[:,2]), 
                     np.array(chanmonop.iloc[:,3]),
                     np.array(chanmonop.iloc[:,4]),)
            chanmonop_final = np.array(coord, dtype=object)

            ## Create and save the structure of np array (sig, sf, coord)
            mat = ('_mat_files/'+su+'_'+sess+'_sigs.mat')
            savemat(path.join(st.path,('raw_data/'+mat)),{'x': data, 'chanmonop': chanmonop_final, 'sf': sf})
# Out:
# -> respi loaded
# -> Computing on :  CHAF sess E1
# data shape (121, 529888)
# data shape2 (121, 529888)
# -> Computing on :  CHAF sess E2
# data shape (121, 336192)
# data shape2 (121, 336192)
# -> Computing on :  LEFC sess E1
# data shape (210, 338608)
# data shape2 (210, 338608)
# -> Computing on :  LEFC sess E2
# data shape (210, 381680)
# data shape2 (210, 381680)
# -> Computing on :  PIRJ sess E1
# data shape (120, 522528)
# data shape2 (120, 522528)
# -> Computing on :  PIRJ sess E2
# data shape (120, 445024)
# data shape2 (120, 445024)
# -> Computing on :  VACJ sess E1
# data shape (152, 348288)
# data shape2 (152, 348288)
# -> Computing on :  VACJ sess E2
# data shape (152, 308816)
# data shape2 (152, 308816)
# -> Computing on :  SEMC sess E1
# data shape (118, 424560)
# data shape2 (118, 424560)
# -> Computing on :  SEMC sess E2
# data shape (118, 324272)
# data shape2 (118, 324272)
# -> Computing on :  FERJ sess E1
# data shape (126, 359360)
# data shape2 (126, 359360)
# -> Computing on :  FERJ sess E2
# data shape (126, 331360)
# data shape2 (126, 331360)
# -> Computing on :  MICP sess E1
# data shape (125, 543344)
# data shape2 (125, 543344)
# -> Computing on :  MICP sess E2
# data shape (125, 437568)
# data shape2 (125, 437568)

# %%
"""This script will clean your data/channels/coordinates,adapt it from matlab format and save 
in a convenient numpy format"""

import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat, savemat
from os import path
from brainpipe.system import study

def _cleanData(pathdata, suj, sess):
    """The function to clean your data. This is convenient because you can loop on your 
    subject/trigger and clean everything in one script"""

    # Import file :
    file = '{suj}_{sess}_sigs.mat'
    loadname = file.format(suj=suj, sess=sess)
    print('-> Processing '+loadname)
    fname = path.join(pathdata, loadname)
    print(fname)
    if path.isfile(fname) == True:
        mat = loadmat(fname)
        mat2 = mat['x']
        print (mat2.shape)

        # Make a clean version of channel name / xyz :
        chan_xy = mat['chanmonop'][1:4]
        print (chan_xy.shape)
        chan_names = mat['chanmonop'][0]
        chan_label = mat['chanmonop'][4]
        # channel = [k[0][0] for k in chan[0]]  # Clean channel name
        xyz = np.zeros([len(chan_names), 3], dtype=float)
        for k in range(len(chan_names)):
            xyz[k, 0] = float(chan_xy[0,k][0])
            xyz[k, 1] = float(chan_xy[1,k][0])
            xyz[k, 2] = float(chan_xy[2,k][0])
        xyz = xyz.round(decimals=1, out=None)

        # Clean matrix of data (remove unecessary channels)
        x = mat['x']
        print ('shape of the data', x.shape)
        if x.ndim == 2:  # This test is in case of x being a 2D matrix (make it 3D)
            x = x[..., np.newaxis]
        #x = x.swapaxes(0, 1).swapaxes(1,2)
        print (x.shape)

        # Update variable inside the loaded file :
        dico = dict(mat)
        dico['x'] = x[0:len(chan_names), ...]
        dico['xyz'] = (xyz)
        dico['channel'] = chan_names
        dico['label'] = chan_label
        dico['sf'] = dico['sf'][0][0]
        del dico['chanmonop']
        del dico['__header__']
        del dico['__globals__']
        del dico['__version__']
        return dico, loadname.split('.mat')[0]
    else:
        return 0,0
    
if __name__ == '__main__':
    # Filesettings :
    st = study('respi') # Load the study
    pathdata = path.join(st.path,('raw_data/_mat_files/'))
    suj = ['CHAF', 'VACJ', 'SEMC', 'PIRJ', 'LEFC','FERJ','MICP']
    sessions = ['E1','E2']

    for su in suj:
        for sess in sessions:
            dico, shortname = _cleanData(pathdata, su, sess)
            if dico !=0:
                path2save = path.join(st.path, 'database/', shortname+'.npz') # make sure it's windows compatible
                np.savez(path2save, **dico)
                print('-> Save as : '+path2save+'\n')
# Out:
# -> respi loaded
# -> Processing CHAF_E1_sigs.mat
# /media/karim/Datas4To/1_Analyses_Intra_EM_Odor/respi/raw_data/_mat_files/CHAF_E1_sigs.mat
# (121, 529888)
# (3, 121)
# shape of the data (121, 529888)
# (121, 529888, 1)
# -> Save as : /media/karim/Datas4To/1_Analyses_Intra_EM_Odor/respi/database/CHAF_E1_sigs.npz
#
# -> Processing CHAF_E2_sigs.mat
# /media/karim/Datas4To/1_Analyses_Intra_EM_Odor/respi/raw_data/_mat_files/CHAF_E2_sigs.mat
# (121, 336192)
# (3, 121)
# shape of the data (121, 336192)
# (121, 336192, 1)
# -> Save as : /media/karim/Datas4To/1_Analyses_Intra_EM_Odor/respi/database/CHAF_E2_sigs.npz
#
# -> Processing VACJ_E1_sigs.mat
# /media/karim/Datas4To/1_Analyses_Intra_EM_Odor/respi/raw_data/_mat_files/VACJ_E1_sigs.mat
# (152, 348288)
# (3, 152)
# shape of the data (152, 348288)
# (152, 348288, 1)
# -> Save as : /media/karim/Datas4To/1_Analyses_Intra_EM_Odor/respi/database/VACJ_E1_sigs.npz
#
# -> Processing VACJ_E2_sigs.mat
# /media/karim/Datas4To/1_Analyses_Intra_EM_Odor/respi/raw_data/_mat_files/VACJ_E2_sigs.mat
# (152, 308816)
# (3, 152)
# shape of the data (152, 308816)
# (152, 308816, 1)
# -> Save as : /media/karim/Datas4To/1_Analyses_Intra_EM_Odor/respi/database/VACJ_E2_sigs.npz
#
# -> Processing SEMC_E1_sigs.mat
# /media/karim/Datas4To/1_Analyses_Intra_EM_Odor/respi/raw_data/_mat_files/SEMC_E1_sigs.mat
# (118, 424560)
# (3, 118)
# shape of the data (118, 424560)
# (118, 424560, 1)
# -> Save as : /media/karim/Datas4To/1_Analyses_Intra_EM_Odor/respi/database/SEMC_E1_sigs.npz
#
# -> Processing SEMC_E2_sigs.mat
# /media/karim/Datas4To/1_Analyses_Intra_EM_Odor/respi/raw_data/_mat_files/SEMC_E2_sigs.mat
# (118, 324272)
# (3, 118)
# shape of the data (118, 324272)
# (118, 324272, 1)

# %%
from brainpipe.system import study
from brainpipe.preprocessing import bipolarization
import numpy as np
from os import path

st = study('respi')
files = [k for k in st.search('_sigs', folder=('database/')) if not k.find('_bipo')+1]
for f in files:
    print('--> Bipolarize: '+f)
    mat = np.load(path.join(st.path,'database/'+f))
    print(mat.files, mat['x'].shape)

    # Bipolarize data :
    x_bip, chan_bip, label_bip, xyz_bip = bipolarization(mat['x'], [mat['channel'][i][0] for i in range(len(mat['channel']))], [mat['label'][i][0] for i in range(len(mat['label']))], xyz=mat['xyz'],)
    mat = dict(mat)
    mat['x'], mat['channel'], mat['xyz'], mat['label'] = x_bip, chan_bip, xyz_bip, label_bip
    savename = f.replace('.npz', '_bipo.npz')
    np.savez(path.join(st.path,('database/'+savename)), **mat)
# Out:
# -> respi loaded
# --> Bipolarize: CHAF_E1_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (121, 1, 121)
# 1 a' PCC-PCL
# 2 a' PCC-PCL
# 0
# 3 a' PCL
# 1
# 4 a' PrG-PoG
# 2
# 5 a' PrG-PoG
# 3
# 6 a' PrG-PoG
# 4
# 7 a' PrG-PoG
# 5
# 8 a' PrG-PoG
# 6
# 9 a' PrG-PoG
# 7
# 10 a' PoG
# 8
# 11 a' PoG
# 9
# 12 a' out
# 10
# 1 b' MCC-PCL
# 2 b' PCL
# 12
# 3 b' PrG
# 13
# 4 b' PrG
# 14
# 5 b' PrG
# 15
# 6 b' PrG
# 16
# 7 b' PrG
# 17
# 8 b' PrG
# 18
# 9 b' PrG
# 19
# 10 b' out
# 20
# 1 c' MCC-SFGM
# 2 c' MCC-SFGM
# 22
# 3 c' SFGM
# 23
# 4 c' SFGM-SFGL
# 24
# 5 c' SFGL
# 25
# 6 c' SFGL
# 26
# 7 c' SFGL
# 27
# 8 c' SFGL
# 28
# 9 c' out
# 29
# 10 c' out
# 30
# 1 d' ACC-SFGM
# 2 d' ACC-SFGM
# 32
# 3 d' SFGM-SFGL
# 33
# 4 d' SFGM-SFGL
# 34
# 5 d' SFGM-SFGL
# 35
# 6 d' SFGL-SFGM
# 36
# 7 d' SFGL-SFGM
# 37
# 8 d' SFGM
# 38
# 9 d' SFGM
# 39
# 10 d' SFGM
# 40
# 1 e' ACC
# 2 e' ACC
# 42
# 3 e' ACC-SFGM
# 43
# 4 e' SFGM
# 44
# 5 e' SFGM
# 45
# 6 e' SFGM
# 46
# 7 e' SFGM
# 47
# 8 e' SFGL
# 48
# 9 e' SFGL
# 49
# 10 e' SFGL
# 50
# 11 e' SFGL
# 51
# 12 e' SFGL
# 52
# 1 f' ACC
# 2 f' ACC
# 54
# 3 f' ACC
# 55
# 4 f' SFGM
# 56
# 5 f' SFGM
# 57
# 6 f' SFGL
# 58
# 7 f' SFGL
# 59
# 8 f' SFGL
# 60
# 9 f' SFGL
# 61
# 10 f' SFGL
# 62
# 11 f' SFGL
# 63
# 12 f' SFGL
# 64
# 13 f' SFGL
# 65
# 14 f' SFGL
# 66
# 15 f' out
# 67
# 1 g' out
# 2 g' MFG-PrG
# 69
# 3 g' MFG-PrG
# 70
# 4 g' MFG-PrG
# 71
# 5 g' MFG-PrG
# 72
# 6 g' MFG-PrG
# 73
# 7 g' MFG-PrG
# 74
# 8 g' MFG
# 75
# 9 g' MFG
# 76
# 10 g' MFG
# 77
# 11 g' MFG
# 78
# 12 g' MFG
# 79
# 1 h' out
# 2 h' out
# 81
# 3 h' MFG
# 82
# 4 h' MFG
# 83
# 5 h' MFG
# 84
# 6 h' MFG
# 85
# 7 h' MFG
# 86
# 8 h' MFG
# 87
# 9 h' MFG
# 88
# 10 h' MFG
# 89
# 1 i' OrG
# 2 i' OrG
# 91
# 3 i' OrG
# 92
# 4 i' OrG
# 93
# 5 i' OrG
# 94
# 6 i' out
# 95
# 7 i' MFG
# 96
# 8 i' MFG-SFGL
# 97
# 9 i' SFGL
# 98
# 10 i' SFGL
# 99
# 11 i' SFGL
# 100
# 12 i' SFGL
# 101
# 13 i' SFGL
# 102
# 14 i' SFGL
# 103
# 15 i' SFGL
# 104
# 1 j' Cd
# 2 j' Cd
# 106
# 3 j' Cd
# 107
# 4 j' Cd
# 108
# 5 j' Cd
# 109
# 6 j' Cd
# 110
# 7 j' PrG
# 111
# 8 j' PrG
# 112
# 9 j' PrG
# 113
# 10 j' PrG
# 114
# 11 j' MFG-IFGOp
# 115
# 12 j' MFG-IFGOp
# 116
# 13 j' MFG
# 117
# 14 j' MFG
# 118
# 15 j' MFG
# 119
# --> Bipolarize: CHAF_E2_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (121, 1, 121)
# 1 a' PCC-PCL
# 2 a' PCC-PCL
# 0
# 3 a' PCL
# 1
# 4 a' PrG-PoG
# 2
# 5 a' PrG-PoG
# 3
# 6 a' PrG-PoG
# 4
# 7 a' PrG-PoG
# 5
# 8 a' PrG-PoG
# 6
# 9 a' PrG-PoG
# 7
# 10 a' PoG
# 8
# 11 a' PoG
# 9
# 12 a' out
# 10
# 1 b' MCC-PCL
# 2 b' PCL
# 12
# 3 b' PrG
# 13
# 4 b' PrG
# 14
# 5 b' PrG
# 15
# 6 b' PrG
# 16
# 7 b' PrG
# 17
# 8 b' PrG
# 18
# 9 b' PrG
# 19
# 10 b' out
# 20
# 1 c' MCC-SFGM
# 2 c' MCC-SFGM
# 22
# 3 c' SFGM
# 23
# 4 c' SFGM-SFGL
# 24
# 5 c' SFGL
# 25
# 6 c' SFGL
# 26
# 7 c' SFGL
# 27
# 8 c' SFGL
# 28
# 9 c' out
# 29
# 10 c' out
# 30
# 1 d' ACC-SFGM
# 2 d' ACC-SFGM
# 32
# 3 d' SFGM-SFGL
# 33
# 4 d' SFGM-SFGL
# 34
# 5 d' SFGM-SFGL
# 35
# 6 d' SFGL-SFGM
# 36
# 7 d' SFGL-SFGM
# 37
# 8 d' SFGM
# 38
# 9 d' SFGM
# 39
# 10 d' SFGM
# 40
# 1 e' ACC
# 2 e' ACC
# 42
# 3 e' ACC-SFGM
# 43
# 4 e' SFGM
# 44
# 5 e' SFGM
# 45
# 6 e' SFGM
# 46
# 7 e' SFGM
# 47
# 8 e' SFGL
# 48
# 9 e' SFGL
# 49
# 10 e' SFGL
# 50
# 11 e' SFGL
# 51
# 12 e' SFGL
# 52
# 1 f' ACC
# 2 f' ACC
# 54
# 3 f' ACC
# 55
# 4 f' SFGM
# 56
# 5 f' SFGM
# 57
# 6 f' SFGL
# 58
# 7 f' SFGL
# 59
# 8 f' SFGL
# 60
# 9 f' SFGL
# 61
# 10 f' SFGL
# 62
# 11 f' SFGL
# 63
# 12 f' SFGL
# 64
# 13 f' SFGL
# 65
# 14 f' SFGL
# 66
# 15 f' out
# 67
# 1 g' out
# 2 g' MFG-PrG
# 69
# 3 g' MFG-PrG
# 70
# 4 g' MFG-PrG
# 71
# 5 g' MFG-PrG
# 72
# 6 g' MFG-PrG
# 73
# 7 g' MFG-PrG
# 74
# 8 g' MFG
# 75
# 9 g' MFG
# 76
# 10 g' MFG
# 77
# 11 g' MFG
# 78
# 12 g' MFG
# 79
# 1 h' out
# 2 h' out
# 81
# 3 h' MFG
# 82
# 4 h' MFG
# 83
# 5 h' MFG
# 84
# 6 h' MFG
# 85
# 7 h' MFG
# 86
# 8 h' MFG
# 87
# 9 h' MFG
# 88
# 10 h' MFG
# 89
# 1 i' OrG
# 2 i' OrG
# 91
# 3 i' OrG
# 92
# 4 i' OrG
# 93
# 5 i' OrG
# 94
# 6 i' out
# 95
# 7 i' MFG
# 96
# 8 i' MFG-SFGL
# 97
# 9 i' SFGL
# 98
# 10 i' SFGL
# 99
# 11 i' SFGL
# 100
# 12 i' SFGL
# 101
# 13 i' SFGL
# 102
# 14 i' SFGL
# 103
# 15 i' SFGL
# 104
# 1 j' Cd
# 2 j' Cd
# 106
# 3 j' Cd
# 107
# 4 j' Cd
# 108
# 5 j' Cd
# 109
# 6 j' Cd
# 110
# 7 j' PrG
# 111
# 8 j' PrG
# 112
# 9 j' PrG
# 113
# 10 j' PrG
# 114
# 11 j' MFG-IFGOp
# 115
# 12 j' MFG-IFGOp
# 116
# 13 j' MFG
# 117
# 14 j' MFG
# 118
# 15 j' MFG
# 119
# --> Bipolarize: FERJ_E1_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (126, 1, 126)
# 1 a Amg
# 2 a Amg
# 0
# 3 a Amg
# 1
# 4 a WM-Amg
# 2
# 5 a WM-Ins
# 3
# 6 a WM-Ins
# 4
# 7 a STG-MTG
# 5
# 8 a STG-MTG
# 6
# 9 a STG-MTG
# 7
# 10 a STG-MTG
# 8
# 11 a LCR-STG-MTG
# 9
# 12 a LCR-skull
# 10
# 1 b aHC-Ent
# 2 b aHC-aPHG
# 12
# 3 b aHC-aPHG
# 13
# 4 b aHC-aPHG
# 14
# 5 b aHC-aPHG
# 15
# 6 b FuG
# 16
# 7 b ITG-MTG
# 17
# 8 b MTG
# 18
# 9 b MTG
# 19
# 10 b MTG
# 20
# 11 b LCR-MTG
# 21
# 12 b LCR-skull
# 22
# 1 b' aHC
# 2 b' aHC
# 24
# 3 b' aHC
# 25
# 4 b' aHC
# 26
# 5 b' aHC-aPHG-FuG
# 27
# 6 b' aHC-aPHG-FuG
# 28
# 7 b' WM-FuG-MTG
# 29
# 8 b' WM-MTG
# 30
# 9 b' WM-MTG
# 31
# 10 b' MTG
# 32
# 11 b' MTG
# 33
# 1 d mHC-Ent-PHG
# 2 d mHC-Ent-PHG
# 35
# 3 d mHC-PHG
# 36
# 4 d mHC-PHG-FuG
# 37
# 5 d mHC-PHG-FuG
# 38
# 6 d FuG-ITG
# 39
# 7 d FuG-ITG
# 40
# 8 d ITG-MTG
# 41
# 9 d MTG
# 42
# 10 d MTG
# 43
# 11 d MTG
# 44
# 12 d LCR-MTG
# 45
# 1 d' pHC-PHG
# 2 d' pHC-PHG
# 47
# 3 d' pHC-PHG
# 48
# 4 d' pHC-PHG-FuG
# 49
# 5 d' pHC-PHG-FuG
# 50
# 6 d' pHC-PHG-FuG
# 51
# 7 d' FuG-pITG
# 52
# 8 d' FuG-pITG
# 53
# 9 d' pITG
# 54
# 10 d' pITG
# 55
# 11 d' pITG
# 56
# 1 e pHC
# 2 e pHC
# 58
# 3 e pHC
# 59
# 4 e WM-pHC
# 60
# 5 e WM-MTG
# 61
# 6 e MTG
# 62
# 7 e MTG
# 63
# 8 e MTG
# 64
# 9 e MTG
# 65
# 10 e MTG
# 66
# 11 e MTG
# 67
# 12 e LCR-MTG
# 68
# 1 h Ins
# 2 h Ins
# 70
# 3 h Ins
# 71
# 4 h TTG1
# 72
# 5 h TTG1
# 73
# 6 h TTG1
# 74
# 7 h TTG4-STG
# 75
# 8 h STG
# 76
# 9 h LCR-STG
# 77
# 1 j Ent-pPirT
# 2 j FuG-aITG
# 79
# 3 j aITG-MTG
# 80
# 4 j MTG
# 81
# 5 j MTG
# 82
# 6 j MTG
# 83
# 7 j LCR-MTG
# 84
# 8 j LCR-skull
# 85
# 1 j' Ent-pPirT-PRC
# 2 j' Ent-pPirT-PRC
# 87
# 3 j' pPirT-aITG
# 88
# 4 j' pPirT-aITG
# 89
# 5 j' WM-aITG-Ppo
# 90
# 6 j' WM-aITG-Ppo
# 91
# 7 j' MTG
# 92
# 1 l pHC-pPHG
# 2 l pHC-pPHG
# 94
# 3 l pHC-pPHG
# 95
# 4 l pHC-pPHG
# 96
# 5 l pPHG-FuG
# 97
# 6 l FuG-pITG
# 98
# 7 l FuG-pITG
# 99
# 8 l pITG-MTG
# 100
# 9 l MTG
# 101
# 10 l MTG
# 102
# 11 l MTG
# 103
# 1 o IRoG
# 2 o IRoG
# 105
# 3 o IRoG-MOrG
# 106
# 4 o IRoG-MOrG
# 107
# 5 o LOrG
# 108
# 6 o LOrG
# 109
# 7 o LOrG
# 110
# 8 o LOrG-IFGOr
# 111
# 9 o IFGOr
# 112
# 10 o IFGOr
# 113
# 11 o IFGOr
# 114
# 1 t Ins-Pu
# 2 t Ins
# 116
# 3 t Ins
# 117
# 4 t PPo-STG
# 118
# 5 t PPo-STG
# 119
# 6 t STG
# 120
# 7 t STG
# 121
# 8 t LCR-STG
# 122
# 9 t LCR-skull
# 123
# 10 t skull
# 124
# --> Bipolarize: FERJ_E2_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (126, 1, 126)
# 1 a Amg
# 2 a Amg
# 0
# 3 a Amg
# 1
# 4 a WM-Amg
# 2
# 5 a WM-Ins
# 3
# 6 a WM-Ins
# 4
# 7 a STG-MTG
# 5
# 8 a STG-MTG
# 6
# 9 a STG-MTG
# 7
# 10 a STG-MTG
# 8
# 11 a LCR-STG-MTG
# 9
# 12 a LCR-skull
# 10
# 1 b aHC-Ent
# 2 b aHC-aPHG
# 12
# 3 b aHC-aPHG
# 13
# 4 b aHC-aPHG
# 14
# 5 b aHC-aPHG
# 15
# 6 b FuG
# 16
# 7 b ITG-MTG
# 17
# 8 b MTG
# 18
# 9 b MTG
# 19
# 10 b MTG
# 20
# 11 b LCR-MTG
# 21
# 12 b LCR-skull
# 22
# 1 b' aHC
# 2 b' aHC
# 24
# 3 b' aHC
# 25
# 4 b' aHC
# 26
# 5 b' aHC-aPHG-FuG
# 27
# 6 b' aHC-aPHG-FuG
# 28
# 7 b' WM-FuG-MTG
# 29
# 8 b' WM-MTG
# 30
# 9 b' WM-MTG
# 31
# 10 b' MTG
# 32
# 11 b' MTG
# 33
# 1 d mHC-Ent-PHG
# 2 d mHC-Ent-PHG
# 35
# 3 d mHC-PHG
# 36
# 4 d mHC-PHG-FuG
# 37
# 5 d mHC-PHG-FuG
# 38
# 6 d FuG-ITG
# 39
# 7 d FuG-ITG
# 40
# 8 d ITG-MTG
# 41
# 9 d MTG
# 42
# 10 d MTG
# 43
# 11 d MTG
# 44
# 12 d LCR-MTG
# 45
# 1 d' pHC-PHG
# 2 d' pHC-PHG
# 47
# 3 d' pHC-PHG
# 48
# 4 d' pHC-PHG-FuG
# 49
# 5 d' pHC-PHG-FuG
# 50
# 6 d' pHC-PHG-FuG
# 51
# 7 d' FuG-pITG
# 52
# 8 d' FuG-pITG
# 53
# 9 d' pITG
# 54
# 10 d' pITG
# 55
# 11 d' pITG
# 56
# 1 e pHC
# 2 e pHC
# 58
# 3 e pHC
# 59
# 4 e WM-pHC
# 60
# 5 e WM-MTG
# 61
# 6 e MTG
# 62
# 7 e MTG
# 63
# 8 e MTG
# 64
# 9 e MTG
# 65
# 10 e MTG
# 66
# 11 e MTG
# 67
# 12 e LCR-MTG
# 68
# 1 h Ins
# 2 h Ins
# 70
# 3 h Ins
# 71
# 4 h TTG1
# 72
# 5 h TTG1
# 73
# 6 h TTG1
# 74
# 7 h TTG4-STG
# 75
# 8 h STG
# 76
# 9 h LCR-STG
# 77
# 1 j Ent-pPirT
# 2 j FuG-aITG
# 79
# 3 j aITG-MTG
# 80
# 4 j MTG
# 81
# 5 j MTG
# 82
# 6 j MTG
# 83
# 7 j LCR-MTG
# 84
# 8 j LCR-skull
# 85
# 1 j' Ent-pPirT-PRC
# 2 j' Ent-pPirT-PRC
# 87
# 3 j' pPirT-aITG
# 88
# 4 j' pPirT-aITG
# 89
# 5 j' WM-aITG-Ppo
# 90
# 6 j' WM-aITG-Ppo
# 91
# 7 j' MTG
# 92
# 1 l pHC-pPHG
# 2 l pHC-pPHG
# 94
# 3 l pHC-pPHG
# 95
# 4 l pHC-pPHG
# 96
# 5 l pPHG-FuG
# 97
# 6 l FuG-pITG
# 98
# 7 l FuG-pITG
# 99
# 8 l pITG-MTG
# 100
# 9 l MTG
# 101
# 10 l MTG
# 102
# 11 l MTG
# 103
# 1 o IRoG
# 2 o IRoG
# 105
# 3 o IRoG-MOrG
# 106
# 4 o IRoG-MOrG
# 107
# 5 o LOrG
# 108
# 6 o LOrG
# 109
# 7 o LOrG
# 110
# 8 o LOrG-IFGOr
# 111
# 9 o IFGOr
# 112
# 10 o IFGOr
# 113
# 11 o IFGOr
# 114
# 1 t Ins-Pu
# 2 t Ins
# 116
# 3 t Ins
# 117
# 4 t PPo-STG
# 118
# 5 t PPo-STG
# 119
# 6 t STG
# 120
# 7 t STG
# 121
# 8 t LCR-STG
# 122
# 9 t LCR-skull
# 123
# 10 t skull
# 124
# --> Bipolarize: LEFC_E1_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (210, 1, 210)
# 1 a Amg-pPirT
# 2 a Amg-pPirT
# 0
# 3 a WM-Ins
# 1
# 4 a WM-Ins
# 2
# 5 a Ins-Ppo
# 3
# 6 a Ins-Ppo
# 4
# 7 a Ins-Ppo
# 5
# 8 a aSTG-aMTG
# 6
# 9 a aSTG-aMTG
# 7
# 10 a aSTG-aMTG
# 8
# 11 a aSTG-aMTG
# 9
# 12 a LCR-aSTG-aMTG
# 10
# 1 b mHC
# 2 b mHC
# 12
# 3 b mHC
# 13
# 4 b mHC
# 14
# 5 b WM-MTG
# 15
# 6 b WM-MTG
# 16
# 7 b WM-MTG
# 17
# 8 b MTG
# 18
# 9 b MTG
# 19
# 10 b MTG
# 20
# 11 b MTG
# 21
# 12 b LCR-MTG
# 22
# 1 d EC-aHC
# 2 d EC-aHC
# 24
# 3 d EC-aPHG-aHC
# 25
# 4 d aPHG-aHC
# 26
# 5 d aPHG-aHC-FuG
# 27
# 6 d aPHG-aHC-FuG
# 28
# 7 d FuG-aITG
# 29
# 8 d FuG-aITG
# 30
# 9 d aITG-aMTG
# 31
# 10 d aITG-aMTG
# 32
# 11 d aITG-aMTG
# 33
# 12 d LCR-aMTG
# 34
# 1 g RSC
# 2 g RSC
# 36
# 3 g RSC
# 37
# 4 g RSC
# 38
# 5 g RSC
# 39
# 6 g SMG
# 40
# 7 g SMG
# 41
# 8 g SMG
# 42
# 9 g SMG
# 43
# 10 g SMG-STG
# 44
# 11 g STG
# 45
# 12 g STG
# 46
# 13 g STG
# 47
# 14 g STG
# 48
# 15 g skull-LCR
# 49
# 1 j aMTG-aITG
# 2 j aMTG-aITG
# 51
# 3 j aMTG-aITG
# 52
# 4 j LCR-skull
# 53
# 5 j LCR-skull
# 54
# 1 k ACC-SFGM
# 2 k ACC-SFGM
# 56
# 3 k ACC-SFGM
# 57
# 4 k ACC-SFGM
# 58
# 5 k WM-MFPG
# 59
# 6 k WM-MFPG
# 60
# 7 k MFPG-MFG
# 61
# 8 k MFG
# 62
# 9 k MFG
# 63
# 10 k MFG
# 64
# 11 k MFG
# 65
# 12 k MFG
# 66
# 1 l LgG-FuG
# 2 l LgG-FuG
# 68
# 3 l FuG-ITG
# 69
# 4 l FuG-ITG
# 70
# 5 l FuG-ITG
# 71
# 6 l ITG
# 72
# 7 l ITG
# 73
# 8 l MTG-ITG
# 74
# 9 l MTG-ITG
# 75
# 10 l MTG-ITG
# 76
# 11 l MTG-ITG
# 77
# 12 l skull-LCR
# 78
# 1 m MCC
# 2 m MCC
# 80
# 3 m MCC
# 81
# 4 m WM-PoG-PrG
# 82
# 5 m WM-PoG-PrG
# 83
# 6 m WM-PoG-PrG
# 84
# 7 m WM-PoG-PrG
# 85
# 8 m WM-PoG-PrG
# 86
# 9 m PoG-SMG
# 87
# 10 m PoG-SMG
# 88
# 11 m PoG-SMG
# 89
# 12 m PoG-SMG
# 90
# 13 m PoG-SMG
# 91
# 14 m PoG-SMG
# 92
# 15 m LCR-PoG-SMG
# 93
# 1 o IRoG-SG
# 2 o IRoG-SG-MOrG
# 95
# 3 o SG-MOrG
# 96
# 4 o MOrG
# 97
# 5 o MorG-IorG
# 98
# 6 o MorG-IorG
# 99
# 7 o IOrG-LOrG
# 100
# 8 o LOrG
# 101
# 9 o IFGOr-LOrG
# 102
# 10 o IFGOr
# 103
# 11 o IFGOr
# 104
# 12 o LCR-IFGOr
# 105
# 1 q PCL-PoG
# 2 q PCL-PoG
# 107
# 3 q PCL-PoG
# 108
# 4 q PoG
# 109
# 5 q PoG
# 110
# 6 q PoG
# 111
# 7 q PoG-SMG
# 112
# 8 q PoG-SMG
# 113
# 9 q PoG-SMG
# 114
# 10 q SMG
# 115
# 11 q SMG
# 116
# 12 q skull-LCR
# 117
# 1 r PCC-PCL
# 2 r PCC-PCL
# 119
# 3 r WM-PCL-PoG
# 120
# 4 r WM-PCL-PoG
# 121
# 5 r WM-PCL-PoG
# 122
# 6 r WM-PCL-PoG
# 123
# 7 r PoG-SMG
# 124
# 8 r PoG-SMG
# 125
# 9 r PoG-SMG
# 126
# 10 r PoG-SMG
# 127
# 11 r SMG
# 128
# 12 r SMG
# 129
# 13 r SMG
# 130
# 14 r SMG
# 131
# 15 r skull-LCR
# 132
# 1 s PCL-SFGL
# 2 s PCL-SFGL
# 134
# 3 s PCL-SFGL
# 135
# 4 s PrG-SFGL
# 136
# 5 s PrG-SFGL
# 137
# 6 s PrG-SFGL
# 138
# 7 s PrG
# 139
# 8 s PrG
# 140
# 9 s PrG
# 141
# 10 s PrG
# 142
# 11 s PrG
# 143
# 12 s LCR-PrG
# 144
# 1 t Ins-TTG
# 2 t Ins-TTG
# 146
# 3 t TTG-aSTG
# 147
# 4 t TTG-aSTG
# 148
# 5 t TTG-aSTG
# 149
# 6 t TTG-aSTG
# 150
# 7 t TTG-aSTG
# 151
# 8 t aSTG
# 152
# 9 t aSTG
# 153
# 10 t LCR-aSTG
# 154
# 1 v 17
# 2 v 17
# 156
# 3 v 17
# 157
# 4 v 17-POTZ-AngG
# 158
# 5 v POTZ-AngG
# 159
# 6 v POTZ-AngG
# 160
# 7 v Ang-OcG
# 161
# 8 v OcG
# 162
# 9 v OcG
# 163
# 10 v OcG
# 164
# 11 v OcG
# 165
# 12 v Skull-OcG
# 166
# 1 w PCun
# 2 w PCun
# 168
# 3 w PCun
# 169
# 4 w PCun
# 170
# 5 w POTZ-AngG
# 171
# 6 w POTZ-AngG
# 172
# 7 w AngG
# 173
# 8 w AngG-OcG
# 174
# 9 w AngG-OcG
# 175
# 10 w AngG-OcG
# 176
# 11 w AngG-OcG
# 177
# 12 w AngG-OcG
# 178
# 1 x PCun
# 2 x PCun
# 180
# 3 x PCun
# 181
# 4 x PCun-SPL-SMG
# 182
# 5 x SPL-SMG
# 183
# 6 x SPL-SMG
# 184
# 7 x SPL-SMG
# 185
# 8 x SMG
# 186
# 9 x SMG
# 187
# 10 x SMG
# 188
# 11 x SMG
# 189
# 12 x SMG
# 190
# 13 x SMG
# 191
# 14 x SMG
# 192
# 15 x skull-LCR
# 193
# 1 y PCun
# 2 y PCun
# 195
# 3 y PCun-OcG
# 196
# 4 y PCun-OcG
# 197
# 5 y PCun-OcG
# 198
# 6 y WM-PCun-OcG
# 199
# 7 y WM
# 200
# 8 y WM
# 201
# 9 y WM
# 202
# 10 y WM-AngG-STG
# 203
# 11 y AngG-STG
# 204
# 12 y AngG-STG
# 205
# 13 y STG
# 206
# 14 y STG
# 207
# 15 y STG
# 208
# --> Bipolarize: LEFC_E2_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (210, 1, 210)
# 1 a Amg-pPirT
# 2 a Amg-pPirT
# 0
# 3 a WM-Ins
# 1
# 4 a WM-Ins
# 2
# 5 a Ins-Ppo
# 3
# 6 a Ins-Ppo
# 4
# 7 a Ins-Ppo
# 5
# 8 a aSTG-aMTG
# 6
# 9 a aSTG-aMTG
# 7
# 10 a aSTG-aMTG
# 8
# 11 a aSTG-aMTG
# 9
# 12 a LCR-aSTG-aMTG
# 10
# 1 b mHC
# 2 b mHC
# 12
# 3 b mHC
# 13
# 4 b mHC
# 14
# 5 b WM-MTG
# 15
# 6 b WM-MTG
# 16
# 7 b WM-MTG
# 17
# 8 b MTG
# 18
# 9 b MTG
# 19
# 10 b MTG
# 20
# 11 b MTG
# 21
# 12 b LCR-MTG
# 22
# 1 d EC-aHC
# 2 d EC-aHC
# 24
# 3 d EC-aPHG-aHC
# 25
# 4 d aPHG-aHC
# 26
# 5 d aPHG-aHC-FuG
# 27
# 6 d aPHG-aHC-FuG
# 28
# 7 d FuG-aITG
# 29
# 8 d FuG-aITG
# 30
# 9 d aITG-aMTG
# 31
# 10 d aITG-aMTG
# 32
# 11 d aITG-aMTG
# 33
# 12 d LCR-aMTG
# 34
# 1 g RSC
# 2 g RSC
# 36
# 3 g RSC
# 37
# 4 g RSC
# 38
# 5 g RSC
# 39
# 6 g SMG
# 40
# 7 g SMG
# 41
# 8 g SMG
# 42
# 9 g SMG
# 43
# 10 g SMG-STG
# 44
# 11 g STG
# 45
# 12 g STG
# 46
# 13 g STG
# 47
# 14 g STG
# 48
# 15 g skull-LCR
# 49
# 1 j aMTG-aITG
# 2 j aMTG-aITG
# 51
# 3 j aMTG-aITG
# 52
# 4 j LCR-skull
# 53
# 5 j LCR-skull
# 54
# 1 k ACC-SFGM
# 2 k ACC-SFGM
# 56
# 3 k ACC-SFGM
# 57
# 4 k ACC-SFGM
# 58
# 5 k WM-MFPG
# 59
# 6 k WM-MFPG
# 60
# 7 k MFPG-MFG
# 61
# 8 k MFG
# 62
# 9 k MFG
# 63
# 10 k MFG
# 64
# 11 k MFG
# 65
# 12 k MFG
# 66
# 1 l LgG-FuG
# 2 l LgG-FuG
# 68
# 3 l FuG-ITG
# 69
# 4 l FuG-ITG
# 70
# 5 l FuG-ITG
# 71
# 6 l ITG
# 72
# 7 l ITG
# 73
# 8 l MTG-ITG
# 74
# 9 l MTG-ITG
# 75
# 10 l MTG-ITG
# 76
# 11 l MTG-ITG
# 77
# 12 l skull-LCR
# 78
# 1 m MCC
# 2 m MCC
# 80
# 3 m MCC
# 81
# 4 m WM-PoG-PrG
# 82
# 5 m WM-PoG-PrG
# 83
# 6 m WM-PoG-PrG
# 84
# 7 m WM-PoG-PrG
# 85
# 8 m WM-PoG-PrG
# 86
# 9 m PoG-SMG
# 87
# 10 m PoG-SMG
# 88
# 11 m PoG-SMG
# 89
# 12 m PoG-SMG
# 90
# 13 m PoG-SMG
# 91
# 14 m PoG-SMG
# 92
# 15 m LCR-PoG-SMG
# 93
# 1 o IRoG-SG
# 2 o IRoG-SG-MOrG
# 95
# 3 o SG-MOrG
# 96
# 4 o MOrG
# 97
# 5 o MorG-IorG
# 98
# 6 o MorG-IorG
# 99
# 7 o IOrG-LOrG
# 100
# 8 o LOrG
# 101
# 9 o IFGOr-LOrG
# 102
# 10 o IFGOr
# 103
# 11 o IFGOr
# 104
# 12 o LCR-IFGOr
# 105
# 1 q PCL-PoG
# 2 q PCL-PoG
# 107
# 3 q PCL-PoG
# 108
# 4 q PoG
# 109
# 5 q PoG
# 110
# 6 q PoG
# 111
# 7 q PoG-SMG
# 112
# 8 q PoG-SMG
# 113
# 9 q PoG-SMG
# 114
# 10 q SMG
# 115
# 11 q SMG
# 116
# 12 q skull-LCR
# 117
# 1 r PCC-PCL
# 2 r PCC-PCL
# 119
# 3 r WM-PCL-PoG
# 120
# 4 r WM-PCL-PoG
# 121
# 5 r WM-PCL-PoG
# 122
# 6 r WM-PCL-PoG
# 123
# 7 r PoG-SMG
# 124
# 8 r PoG-SMG
# 125
# 9 r PoG-SMG
# 126
# 10 r PoG-SMG
# 127
# 11 r SMG
# 128
# 12 r SMG
# 129
# 13 r SMG
# 130
# 14 r SMG
# 131
# 15 r skull-LCR
# 132
# 1 s PCL-SFGL
# 2 s PCL-SFGL
# 134
# 3 s PCL-SFGL
# 135
# 4 s PrG-SFGL
# 136
# 5 s PrG-SFGL
# 137
# 6 s PrG-SFGL
# 138
# 7 s PrG
# 139
# 8 s PrG
# 140
# 9 s PrG
# 141
# 10 s PrG
# 142
# 11 s PrG
# 143
# 12 s LCR-PrG
# 144
# 1 t Ins-TTG
# 2 t Ins-TTG
# 146
# 3 t TTG-aSTG
# 147
# 4 t TTG-aSTG
# 148
# 5 t TTG-aSTG
# 149
# 6 t TTG-aSTG
# 150
# 7 t TTG-aSTG
# 151
# 8 t aSTG
# 152
# 9 t aSTG
# 153
# 10 t LCR-aSTG
# 154
# 1 v 17
# 2 v 17
# 156
# 3 v 17
# 157
# 4 v 17-POTZ-AngG
# 158
# 5 v POTZ-AngG
# 159
# 6 v POTZ-AngG
# 160
# 7 v Ang-OcG
# 161
# 8 v OcG
# 162
# 9 v OcG
# 163
# 10 v OcG
# 164
# 11 v OcG
# 165
# 12 v Skull-OcG
# 166
# 1 w PCun
# 2 w PCun
# 168
# 3 w PCun
# 169
# 4 w PCun
# 170
# 5 w POTZ-AngG
# 171
# 6 w POTZ-AngG
# 172
# 7 w AngG
# 173
# 8 w AngG-OcG
# 174
# 9 w AngG-OcG
# 175
# 10 w AngG-OcG
# 176
# 11 w AngG-OcG
# 177
# 12 w AngG-OcG
# 178
# 1 x PCun
# 2 x PCun
# 180
# 3 x PCun
# 181
# 4 x PCun-SPL-SMG
# 182
# 5 x SPL-SMG
# 183
# 6 x SPL-SMG
# 184
# 7 x SPL-SMG
# 185
# 8 x SMG
# 186
# 9 x SMG
# 187
# 10 x SMG
# 188
# 11 x SMG
# 189
# 12 x SMG
# 190
# 13 x SMG
# 191
# 14 x SMG
# 192
# 15 x skull-LCR
# 193
# 1 y PCun
# 2 y PCun
# 195
# 3 y PCun-OcG
# 196
# 4 y PCun-OcG
# 197
# 5 y PCun-OcG
# 198
# 6 y WM-PCun-OcG
# 199
# 7 y WM
# 200
# 8 y WM
# 201
# 9 y WM
# 202
# 10 y WM-AngG-STG
# 203
# 11 y AngG-STG
# 204
# 12 y AngG-STG
# 205
# 13 y STG
# 206
# 14 y STG
# 207
# 15 y STG
# 208
# --> Bipolarize: MICP_E1_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (125, 1, 125)
# 1 a' Amg-pPirT
# 2 a' Amg
# 0
# 3 a' Amg
# 1
# 4 a' WM-Amg
# 2
# 5 a' WM-Ins
# 3
# 6 a' WM-MTG
# 4
# 7 a' MTG-STG
# 5
# 8 a' MTG
# 6
# 9 a' MTG
# 7
# 10 a' LCR-MTG
# 8
# 1 b aHC-pAmg
# 2 b aHC
# 10
# 3 b aHC
# 11
# 4 b aHC
# 12
# 5 b aHC
# 13
# 7 b WM-FuG
# 8 b WM-MTG
# 15
# 9 b MTG
# 16
# 10 b MTG
# 17
# 11 b MTG
# 18
# 12 b MTG
# 19
# 13 b None
# 20
# 14 b None
# 21
# 15 b None
# 22
# 1 b' aHC-pAmg
# 2 b' aHC
# 24
# 3 b' aHC
# 25
# 4 b' aHC
# 26
# 5 b' aHC
# 27
# 6 b' WM-aHC
# 28
# 7 b' WM-MTG
# 29
# 8 b' MTG
# 30
# 9 b' MTG
# 31
# 10 b' MTG
# 32
# 11 b' MTG
# 33
# 12 b' MTG
# 34
# 1 c' pHC
# 2 c' pHC
# 36
# 3 c' pHC
# 37
# 4 c' pHC
# 38
# 5 c' WM-pHC
# 39
# 6 c' WM-MTG
# 40
# 7 c' MTG
# 41
# 8 c' MTG
# 42
# 9 c' MTG
# 43
# 10 c' MTG
# 44
# 11 c' MTG
# 45
# 12 c' MTG
# 46
# 1 d' aHC-Ent
# 2 d' aHC-Ent
# 48
# 3 d' aHC-PRC
# 49
# 4 d' aHC-aPHG
# 50
# 5 d' aHC-aPHG
# 51
# 6 d' aPHG-FuG
# 52
# 8 d' WM-MTG
# 9 d' WM-MTG
# 54
# 10 d' WM-MTG
# 55
# 11 d' MTG
# 56
# 12 d' MTG
# 57
# 1 h Pu-Ins
# 2 h Ins
# 59
# 3 h Ins
# 60
# 4 h Ins-TTG
# 61
# 5 h TTG
# 62
# 6 h TTG
# 63
# 7 h TTG
# 64
# 8 h STG-Pte
# 65
# 9 h STG-Pte
# 66
# 10 h STG-Pte
# 67
# 1 h' TTG-pSTG
# 2 h' TTG-pSTG
# 69
# 3 h' TTG-pSTG
# 70
# 4 h' TTG-pSTG
# 71
# 5 h' TTG-pSTG
# 72
# 6 h' TTG-pSTG
# 73
# 7 h' TTG-pSTG
# 74
# 8 h' LCR-pSTG
# 75
# 1 j aMTG
# 2 j aMTG
# 77
# 3 j aMTG
# 78
# 4 j aMTG
# 79
# 5 j aMTG
# 80
# 1 j' aITG-aMTG
# 2 j' aMTG
# 82
# 3 j' aMTG
# 83
# 4 j' aMTG
# 84
# 5 j' aMTG
# 85
# 1 l' FuG
# 2 l' FuG
# 87
# 3 l' WM-FuG
# 88
# 4 l' WM-pITG
# 89
# 5 l' WM-pITG
# 90
# 7 l' WM-pITG
# 8 l' WM-pITG
# 92
# 9 l' pITG-pMTG
# 93
# 10 l' pITG-pMTG
# 94
# 1 o' IRoG
# 2 o' IRoG
# 96
# 3 o' WM-IRoG
# 97
# 4 o' IOrG
# 98
# 5 o' IOrG
# 99
# 7 o' IOrG
# 8 o' IOrG
# 101
# 9 o' IOrG
# 102
# 10 o' IOrG
# 103
# 11 o' IOrG
# 104
# 12 o' IOrG
# 105
# 1 t' Pu-Ins
# 2 t' Ins
# 107
# 3 t' Ins
# 108
# 4 t' Ins-TTG
# 109
# 5 t' WM-STG
# 110
# 6 t' mSTG
# 111
# 7 t' mSTG
# 112
# 8 t' mSTG
# 113
# 9 t' mSTG
# 114
# 10 t' LCR-mSTG
# 115
# 1 y' pMTG-pSTG
# 2 y' pMTG-pSTG
# 117
# 3 y' pMTG-pSTG
# 118
# 4 y' pMTG-pSTG
# 119
# 5 y' pMTG-pSTG
# 120
# 6 y' pMTG-pSTG
# 121
# 7 y' LCR-pMTG-pSTG
# 122
# 8 y' LCR
# 123
# --> Bipolarize: MICP_E2_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (125, 1, 125)
# 1 a' Amg-pPirT
# 2 a' Amg
# 0
# 3 a' Amg
# 1
# 4 a' WM-Amg
# 2
# 5 a' WM-Ins
# 3
# 6 a' WM-MTG
# 4
# 7 a' MTG-STG
# 5
# 8 a' MTG
# 6
# 9 a' MTG
# 7
# 10 a' LCR-MTG
# 8
# 1 b aHC-pAmg
# 2 b aHC
# 10
# 3 b aHC
# 11
# 4 b aHC
# 12
# 5 b aHC
# 13
# 7 b WM-FuG
# 8 b WM-MTG
# 15
# 9 b MTG
# 16
# 10 b MTG
# 17
# 11 b MTG
# 18
# 12 b MTG
# 19
# 13 b None
# 20
# 14 b None
# 21
# 15 b None
# 22
# 1 b' aHC-pAmg
# 2 b' aHC
# 24
# 3 b' aHC
# 25
# 4 b' aHC
# 26
# 5 b' aHC
# 27
# 6 b' WM-aHC
# 28
# 7 b' WM-MTG
# 29
# 8 b' MTG
# 30
# 9 b' MTG
# 31
# 10 b' MTG
# 32
# 11 b' MTG
# 33
# 12 b' MTG
# 34
# 1 c' pHC
# 2 c' pHC
# 36
# 3 c' pHC
# 37
# 4 c' pHC
# 38
# 5 c' WM-pHC
# 39
# 6 c' WM-MTG
# 40
# 7 c' MTG
# 41
# 8 c' MTG
# 42
# 9 c' MTG
# 43
# 10 c' MTG
# 44
# 11 c' MTG
# 45
# 12 c' MTG
# 46
# 1 d' aHC-Ent
# 2 d' aHC-Ent
# 48
# 3 d' aHC-PRC
# 49
# 4 d' aHC-aPHG
# 50
# 5 d' aHC-aPHG
# 51
# 6 d' aPHG-FuG
# 52
# 8 d' WM-MTG
# 9 d' WM-MTG
# 54
# 10 d' WM-MTG
# 55
# 11 d' MTG
# 56
# 12 d' MTG
# 57
# 1 h Pu-Ins
# 2 h Ins
# 59
# 3 h Ins
# 60
# 4 h Ins-TTG
# 61
# 5 h TTG
# 62
# 6 h TTG
# 63
# 7 h TTG
# 64
# 8 h STG-Pte
# 65
# 9 h STG-Pte
# 66
# 10 h STG-Pte
# 67
# 1 h' TTG-pSTG
# 2 h' TTG-pSTG
# 69
# 3 h' TTG-pSTG
# 70
# 4 h' TTG-pSTG
# 71
# 5 h' TTG-pSTG
# 72
# 6 h' TTG-pSTG
# 73
# 7 h' TTG-pSTG
# 74
# 8 h' LCR-pSTG
# 75
# 1 j aMTG
# 2 j aMTG
# 77
# 3 j aMTG
# 78
# 4 j aMTG
# 79
# 5 j aMTG
# 80
# 1 j' aITG-aMTG
# 2 j' aMTG
# 82
# 3 j' aMTG
# 83
# 4 j' aMTG
# 84
# 5 j' aMTG
# 85
# 1 l' FuG
# 2 l' FuG
# 87
# 3 l' WM-FuG
# 88
# 4 l' WM-pITG
# 89
# 5 l' WM-pITG
# 90
# 7 l' WM-pITG
# 8 l' WM-pITG
# 92
# 9 l' pITG-pMTG
# 93
# 10 l' pITG-pMTG
# 94
# 1 o' IRoG
# 2 o' IRoG
# 96
# 3 o' WM-IRoG
# 97
# 4 o' IOrG
# 98
# 5 o' IOrG
# 99
# 7 o' IOrG
# 8 o' IOrG
# 101
# 9 o' IOrG
# 102
# 10 o' IOrG
# 103
# 11 o' IOrG
# 104
# 12 o' IOrG
# 105
# 1 t' Pu-Ins
# 2 t' Ins
# 107
# 3 t' Ins
# 108
# 4 t' Ins-TTG
# 109
# 5 t' WM-STG
# 110
# 6 t' mSTG
# 111
# 7 t' mSTG
# 112
# 8 t' mSTG
# 113
# 9 t' mSTG
# 114
# 10 t' LCR-mSTG
# 115
# 1 y' pMTG-pSTG
# 2 y' pMTG-pSTG
# 117
# 3 y' pMTG-pSTG
# 118
# 4 y' pMTG-pSTG
# 119
# 5 y' pMTG-pSTG
# 120
# 6 y' pMTG-pSTG
# 121
# 7 y' LCR-pMTG-pSTG
# 122
# 8 y' LCR
# 123
# --> Bipolarize: PIRJ_E1_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (120, 1, 120)
# 1 b aHC
# 2 b aHC
# 0
# 3 b aHC
# 1
# 4 b aHC
# 2
# 5 b WM-aHC
# 3
# 6 b WM-MTG
# 4
# 7 b pMTG
# 5
# 8 b pMTG
# 6
# 9 b pMTG
# 7
# 10 b pMTG
# 8
# 11 b pMTG
# 9
# 12 b pMTG
# 10
# 1 b' aHC
# 2 b' aHC
# 12
# 3 b' aHC
# 13
# 4 b' aHC
# 14
# 5 b' aHC
# 15
# 6 b' WM-aHC
# 16
# 7 b' WM-pMTG
# 17
# 8 b' pMTG
# 18
# 9 b' pMTG
# 19
# 10 b' pMTG
# 20
# 11 b' pMTG
# 21
# 12 b' pMTG
# 22
# 1 c pHC
# 2 c pHC
# 24
# 3 c pHC
# 25
# 4 c pHC
# 26
# 5 c WM-pHC
# 27
# 6 c WM-pMTG
# 28
# 7 c WM-pMTG
# 29
# 8 c WM-pMTG
# 30
# 9 c pMTG
# 31
# 10 c pMTG
# 32
# 11 c pMTG
# 33
# 12 c pMTG
# 34
# 1 c' pHC
# 2 c' pHC
# 36
# 3 c' pHC
# 37
# 4 c' pHC
# 38
# 5 c' pHC
# 39
# 6 c' WM-pHC
# 40
# 7 c' WM-pMTG
# 41
# 8 c' pMTG
# 42
# 9 c' pMTG
# 43
# 10 c' pMTG
# 44
# 11 c' pMTG
# 45
# 12 c' pMTG
# 46
# 1 d PRC-aPHG
# 2 d PRC-aPHG
# 48
# 3 d PRC-aPHG
# 49
# 4 d aPHG
# 50
# 5 d aPHG
# 51
# 6 d FuG
# 52
# 7 d FuG-ITG
# 53
# 8 d ITG-aMTG
# 54
# 9 d aMTG
# 55
# 10 d aMTG
# 56
# 1 g PCC-Pcun
# 2 g PCC-Pcun
# 58
# 3 g PCC-Pcun
# 59
# 4 g PCC-Pcun
# 60
# 5 g WM
# 61
# 6 g WM-SMG
# 62
# 7 g WM-SMG
# 63
# 8 g WM-SMG
# 64
# 9 g WM-SMG
# 65
# 10 g WM-SMG
# 66
# 11 g SMG-pSTG
# 67
# 12 g SMG-pSTG
# 68
# 13 g SMG-pSTG
# 69
# 14 g SMG-pSTG
# 70
# 15 g LCR
# 71
# 1 g' PCC
# 2 g' PCC
# 73
# 3 g' PCC
# 74
# 4 g' WM-PCC
# 75
# 5 g' WM-PCC
# 76
# 6 g' WM-Ang
# 77
# 7 g' WM-Ang
# 78
# 8 g' WM-Ang
# 79
# 9 g' WM-Ang
# 80
# 10 g' WM-Ang
# 81
# 11 g' pSTG
# 82
# 12 g' pSTG
# 83
# 13 g' pSTG
# 84
# 14 g' pSTG
# 85
# 15 g' LCR
# 86
# 1 j POrG-LOrG
# 2 j POrG-LOrG
# 88
# 3 j POrG-LOrG
# 89
# 4 j PPo
# 90
# 5 j PPo
# 91
# 6 j PPo
# 92
# 7 j Ppo-ITP
# 93
# 8 j Ppo-ITP
# 94
# 9 j LCR-ITP
# 95
# 10 j LCR
# 96
# 1 o IRoG
# 2 o IROG-SG
# 98
# 3 o WM-MOrG
# 99
# 4 o MOrG
# 100
# 5 o MOrG
# 101
# 6 o MOrG-LOrG
# 102
# 7 o MOrG-LOrG
# 103
# 8 o LOrG
# 104
# 9 o LOrG-IFGOr
# 105
# 10 o LOrG-IFGOr
# 106
# 11 o IFGOr
# 107
# 12 o IFGOr
# 108
# 1 t pIns
# 2 t pIns
# 110
# 3 t PIns-TTG
# 111
# 4 t pSTG
# 112
# 5 t pSTG
# 113
# 6 t pSTG
# 114
# 7 t pSTG
# 115
# 8 t pSTG
# 116
# 9 t pSTG-pMTG
# 117
# 10 t pSTG-pMTG
# 118
# --> Bipolarize: PIRJ_E2_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (120, 1, 120)
# 1 b aHC
# 2 b aHC
# 0
# 3 b aHC
# 1
# 4 b aHC
# 2
# 5 b WM-aHC
# 3
# 6 b WM-MTG
# 4
# 7 b pMTG
# 5
# 8 b pMTG
# 6
# 9 b pMTG
# 7
# 10 b pMTG
# 8
# 11 b pMTG
# 9
# 12 b pMTG
# 10
# 1 b' aHC
# 2 b' aHC
# 12
# 3 b' aHC
# 13
# 4 b' aHC
# 14
# 5 b' aHC
# 15
# 6 b' WM-aHC
# 16
# 7 b' WM-pMTG
# 17
# 8 b' pMTG
# 18
# 9 b' pMTG
# 19
# 10 b' pMTG
# 20
# 11 b' pMTG
# 21
# 12 b' pMTG
# 22
# 1 c pHC
# 2 c pHC
# 24
# 3 c pHC
# 25
# 4 c pHC
# 26
# 5 c WM-pHC
# 27
# 6 c WM-pMTG
# 28
# 7 c WM-pMTG
# 29
# 8 c WM-pMTG
# 30
# 9 c pMTG
# 31
# 10 c pMTG
# 32
# 11 c pMTG
# 33
# 12 c pMTG
# 34
# 1 c' pHC
# 2 c' pHC
# 36
# 3 c' pHC
# 37
# 4 c' pHC
# 38
# 5 c' pHC
# 39
# 6 c' WM-pHC
# 40
# 7 c' WM-pMTG
# 41
# 8 c' pMTG
# 42
# 9 c' pMTG
# 43
# 10 c' pMTG
# 44
# 11 c' pMTG
# 45
# 12 c' pMTG
# 46
# 1 d PRC-aPHG
# 2 d PRC-aPHG
# 48
# 3 d PRC-aPHG
# 49
# 4 d aPHG
# 50
# 5 d aPHG
# 51
# 6 d FuG
# 52
# 7 d FuG-ITG
# 53
# 8 d ITG-aMTG
# 54
# 9 d aMTG
# 55
# 10 d aMTG
# 56
# 1 g PCC-Pcun
# 2 g PCC-Pcun
# 58
# 3 g PCC-Pcun
# 59
# 4 g PCC-Pcun
# 60
# 5 g WM
# 61
# 6 g WM-SMG
# 62
# 7 g WM-SMG
# 63
# 8 g WM-SMG
# 64
# 9 g WM-SMG
# 65
# 10 g WM-SMG
# 66
# 11 g SMG-pSTG
# 67
# 12 g SMG-pSTG
# 68
# 13 g SMG-pSTG
# 69
# 14 g SMG-pSTG
# 70
# 15 g LCR
# 71
# 1 g' PCC
# 2 g' PCC
# 73
# 3 g' PCC
# 74
# 4 g' WM-PCC
# 75
# 5 g' WM-PCC
# 76
# 6 g' WM-Ang
# 77
# 7 g' WM-Ang
# 78
# 8 g' WM-Ang
# 79
# 9 g' WM-Ang
# 80
# 10 g' WM-Ang
# 81
# 11 g' pSTG
# 82
# 12 g' pSTG
# 83
# 13 g' pSTG
# 84
# 14 g' pSTG
# 85
# 15 g' LCR
# 86
# 1 j POrG-LOrG
# 2 j POrG-LOrG
# 88
# 3 j POrG-LOrG
# 89
# 4 j PPo
# 90
# 5 j PPo
# 91
# 6 j PPo
# 92
# 7 j Ppo-ITP
# 93
# 8 j Ppo-ITP
# 94
# 9 j LCR-ITP
# 95
# 10 j LCR
# 96
# 1 o IRoG
# 2 o IROG-SG
# 98
# 3 o WM-MOrG
# 99
# 4 o MOrG
# 100
# 5 o MOrG
# 101
# 6 o MOrG-LOrG
# 102
# 7 o MOrG-LOrG
# 103
# 8 o LOrG
# 104
# 9 o LOrG-IFGOr
# 105
# 10 o LOrG-IFGOr
# 106
# 11 o IFGOr
# 107
# 12 o IFGOr
# 108
# 1 t pIns
# 2 t pIns
# 110
# 3 t PIns-TTG
# 111
# 4 t pSTG
# 112
# 5 t pSTG
# 113
# 6 t pSTG
# 114
# 7 t pSTG
# 115
# 8 t pSTG
# 116
# 9 t pSTG-pMTG
# 117
# 10 t pSTG-pMTG
# 118
# --> Bipolarize: SEMC_E1_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (118, 1, 118)
# 1 b aHC-Ent
# 2 b aHC
# 0
# 3 b aHC
# 1
# 4 b aHC
# 2
# 5 b aHC-PHG
# 3
# 6 b PHG-FuG
# 4
# 7 b WM-FuG
# 5
# 8 b WM-FuG
# 6
# 9 b WM-FuG
# 7
# 10 b WM-MTG
# 8
# 11 b MTG
# 9
# 12 b MTG
# 10
# 1 e FOp-IG
# 2 e FOp-IG
# 12
# 3 e FOp-IG
# 13
# 4 e FOp
# 14
# 5 e WM-FOp
# 15
# 6 e IFGOp
# 16
# 7 e IFGOp
# 17
# 8 e IFGOp
# 18
# 9 e LCR-IFGOp
# 19
# 10 e LCR
# 20
# 1 f SRoG
# 2 f SRoG-IFPG
# 22
# 3 f SRoG-IFPG
# 23
# 4 f IFPG
# 24
# 5 f IFPG
# 25
# 6 f MFG
# 26
# 7 f MFG
# 27
# 8 f MFG
# 28
# 9 f LCR-MFG
# 29
# 10 f LCR
# 30
# 1 j POrG
# 2 j PORG-IFGOr
# 32
# 3 j IFGOr
# 33
# 4 j PPo
# 34
# 5 j PPo
# 35
# 6 j PPo
# 36
# 7 j LCR
# 37
# 8 j LCR
# 38
# 9 j skull
# 39
# 10 j skull
# 40
# 1 k pgACC
# 2 k pgACC
# 42
# 3 k WM-pgACC
# 43
# 4 k WM-MFG
# 44
# 5 k WM-MFG
# 45
# 6 k WM-MFG
# 46
# 7 k WM-MFG
# 47
# 8 k MFG
# 48
# 9 k MFG
# 49
# 10 k MFG
# 50
# 11 k MFG
# 51
# 12 k MFG
# 52
# 1 m WM-PoG
# 2 m WM-PoG
# 54
# 3 m WM-PoG
# 55
# 4 m PoG
# 56
# 5 m PoG
# 57
# 1 o sgACC
# 2 o sgACC-SG
# 59
# 3 o WM-MOrG
# 60
# 4 o MOrG-POrG
# 61
# 5 o MOrG
# 62
# 6 o MOrG
# 63
# 7 o MOrG
# 64
# 8 o MOrG
# 65
# 9 o MOrG
# 66
# 10 o MOrG-IFGOr
# 67
# 11 o IFGOr-IFGTr
# 68
# 12 o IFGOr-IFGTr
# 69
# 13 o IFGOr-IFGTr
# 70
# 14 o IFGTr-LCR
# 71
# 15 o LCR-skull
# 72
# 1 u IRoG-sgACC
# 2 u IRoG-sgACC
# 74
# 3 u WM-MOrG
# 75
# 4 u MOrG
# 76
# 5 u MOrG
# 77
# 6 u MOrG-LOrG
# 78
# 7 u MOrG-LOrG
# 79
# 8 u IFGOr
# 80
# 9 u IFGOr
# 81
# 10 u IFGOr
# 82
# 11 u IFGOr
# 83
# 12 u IFGOr
# 84
# 1 x adACC
# 2 x adACC
# 86
# 3 x WM-adACC
# 87
# 4 x WM-MFG
# 88
# 5 x WM-MFG
# 89
# 6 x WM-MFG
# 90
# 7 x MFG
# 91
# 8 x MFG
# 92
# 9 x MFG
# 93
# 10 x MFG
# 94
# 11 x MFG
# 95
# 12 x LCR-MFG
# 96
# 1 y SFGM-SFGL
# 2 y SFGM-SFGL
# 98
# 3 y SFGL
# 99
# 4 y SFGL
# 100
# 5 y SFGL-MFG
# 101
# 6 y SFGL-MFG
# 102
# 7 y SFGL-MFG
# 103
# 8 y SFGL-MFG
# 104
# 9 y LCR-MFG
# 105
# 10 y LCR
# 106
# 1 z SFGM
# 2 z SFGM-SFGL
# 108
# 3 z SFGL
# 109
# 4 z SFGL-MFG
# 110
# 5 z MFG
# 111
# 6 z MFG
# 112
# 7 z MFG
# 113
# 8 z LCR-MFG
# 114
# 9 z LCR
# 115
# 10 z LCR-skull
# 116
# --> Bipolarize: SEMC_E2_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (118, 1, 118)
# 1 b aHC-Ent
# 2 b aHC
# 0
# 3 b aHC
# 1
# 4 b aHC
# 2
# 5 b aHC-PHG
# 3
# 6 b PHG-FuG
# 4
# 7 b WM-FuG
# 5
# 8 b WM-FuG
# 6
# 9 b WM-FuG
# 7
# 10 b WM-MTG
# 8
# 11 b MTG
# 9
# 12 b MTG
# 10
# 1 e FOp-IG
# 2 e FOp-IG
# 12
# 3 e FOp-IG
# 13
# 4 e FOp
# 14
# 5 e WM-FOp
# 15
# 6 e IFGOp
# 16
# 7 e IFGOp
# 17
# 8 e IFGOp
# 18
# 9 e LCR-IFGOp
# 19
# 10 e LCR
# 20
# 1 f SRoG
# 2 f SRoG-IFPG
# 22
# 3 f SRoG-IFPG
# 23
# 4 f IFPG
# 24
# 5 f IFPG
# 25
# 6 f MFG
# 26
# 7 f MFG
# 27
# 8 f MFG
# 28
# 9 f LCR-MFG
# 29
# 10 f LCR
# 30
# 1 j POrG
# 2 j PORG-IFGOr
# 32
# 3 j IFGOr
# 33
# 4 j PPo
# 34
# 5 j PPo
# 35
# 6 j PPo
# 36
# 7 j LCR
# 37
# 8 j LCR
# 38
# 9 j skull
# 39
# 10 j skull
# 40
# 1 k pgACC
# 2 k pgACC
# 42
# 3 k WM-pgACC
# 43
# 4 k WM-MFG
# 44
# 5 k WM-MFG
# 45
# 6 k WM-MFG
# 46
# 7 k WM-MFG
# 47
# 8 k MFG
# 48
# 9 k MFG
# 49
# 10 k MFG
# 50
# 11 k MFG
# 51
# 12 k MFG
# 52
# 1 m WM-PoG
# 2 m WM-PoG
# 54
# 3 m WM-PoG
# 55
# 4 m PoG
# 56
# 5 m PoG
# 57
# 1 o sgACC
# 2 o sgACC-SG
# 59
# 3 o WM-MOrG
# 60
# 4 o MOrG-POrG
# 61
# 5 o MOrG
# 62
# 6 o MOrG
# 63
# 7 o MOrG
# 64
# 8 o MOrG
# 65
# 9 o MOrG
# 66
# 10 o MOrG-IFGOr
# 67
# 11 o IFGOr-IFGTr
# 68
# 12 o IFGOr-IFGTr
# 69
# 13 o IFGOr-IFGTr
# 70
# 14 o IFGTr-LCR
# 71
# 15 o LCR-skull
# 72
# 1 u IRoG-sgACC
# 2 u IRoG-sgACC
# 74
# 3 u WM-MOrG
# 75
# 4 u MOrG
# 76
# 5 u MOrG
# 77
# 6 u MOrG-LOrG
# 78
# 7 u MOrG-LOrG
# 79
# 8 u IFGOr
# 80
# 9 u IFGOr
# 81
# 10 u IFGOr
# 82
# 11 u IFGOr
# 83
# 12 u IFGOr
# 84
# 1 x adACC
# 2 x adACC
# 86
# 3 x WM-adACC
# 87
# 4 x WM-MFG
# 88
# 5 x WM-MFG
# 89
# 6 x WM-MFG
# 90
# 7 x MFG
# 91
# 8 x MFG
# 92
# 9 x MFG
# 93
# 10 x MFG
# 94
# 11 x MFG
# 95
# 12 x LCR-MFG
# 96
# 1 y SFGM-SFGL
# 2 y SFGM-SFGL
# 98
# 3 y SFGL
# 99
# 4 y SFGL
# 100
# 5 y SFGL-MFG
# 101
# 6 y SFGL-MFG
# 102
# 7 y SFGL-MFG
# 103
# 8 y SFGL-MFG
# 104
# 9 y LCR-MFG
# 105
# 10 y LCR
# 106
# 1 z SFGM
# 2 z SFGM-SFGL
# 108
# 3 z SFGL
# 109
# 4 z SFGL-MFG
# 110
# 5 z MFG
# 111
# 6 z MFG
# 112
# 7 z MFG
# 113
# 8 z LCR-MFG
# 114
# 9 z LCR
# 115
# 10 z LCR-skull
# 116
# --> Bipolarize: VACJ_E1_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (152, 1, 152)
# 1 b mHC-Ent
# 2 b mHC-Ent
# 0
# 3 b mHC-PHG
# 1
# 4 b mHC-PHG-FuG
# 2
# 5 b WM-FuG
# 3
# 6 b MTG
# 4
# 7 b MTG
# 5
# 8 b MTG
# 6
# 9 b MTG
# 7
# 10 b MTG
# 8
# 11 b MTG
# 9
# 12 b MTG
# 10
# 1 b' mHC
# 2 b' mHC
# 12
# 3 b' mHC
# 13
# 4 b' mHC
# 14
# 5 b' mHC
# 15
# 6 b' mHC
# 16
# 7 b' WM-mHC
# 17
# 8 b' WM-MTG
# 18
# 9 b' WM-MTG
# 19
# 10 b' MTG
# 20
# 11 b' MTG
# 21
# 12 b' MTG
# 22
# 1 d' Amg
# 2 d' Amg-PRC
# 24
# 3 d' Amg-PRC
# 25
# 4 d' PRC
# 26
# 5 d' WM-PRC
# 27
# 6 d' WM-Ppo
# 28
# 7 d' WM-Ppo
# 29
# 8 d' MTG
# 30
# 9 d' MTG
# 31
# 10 d' MTG
# 32
# 11 d' MTG
# 33
# 12 d' MTG
# 34
# 1 e' IFGOp-IG
# 2 e' IFGOp-IG
# 36
# 3 e' IFGOp-IFGTr
# 37
# 4 e' IFGOp-IFGTr
# 38
# 5 e' IFGOp-IFGTr
# 39
# 6 e' WM-IFGOp
# 40
# 7 e' WM-IFGOp
# 41
# 8 e' IFGOp-IFGTr
# 42
# 9 e' IFGOp-IFGTr
# 43
# 10 e' LCR
# 44
# 1 f SRoG
# 2 f SRoG
# 46
# 3 f WM-SRoG
# 47
# 4 f WM-IFPG
# 48
# 5 f WM-IFPG
# 49
# 6 f WM-IFPG
# 50
# 7 f WM-IFPG
# 51
# 8 f WM-MFG
# 52
# 9 f MFG
# 53
# 10 f MFG
# 54
# 11 f MFG
# 55
# 12 f MFG-LCR
# 56
# 1 j WM-PPo
# 2 j WM-ITG-MTG
# 58
# 3 j MTG
# 59
# 4 j MTG
# 60
# 5 j LCR-MTG
# 61
# 6 j LCR
# 62
# 7 j LCR-skull
# 63
# 8 j skull
# 64
# 1 j' pPirT-Ent
# 2 j' pPirtT
# 66
# 3 j' WM-pPirT
# 67
# 4 j' WM-ITG
# 68
# 5 j' WM-MTG
# 69
# 6 j' WM-MTG
# 70
# 7 j' MTG
# 71
# 8 j' MTG
# 72
# 9 j' MTG
# 73
# 10 j' LCR-MTG
# 74
# 1 k pgACC
# 2 k pgACC
# 76
# 3 k WM-pgACC
# 77
# 4 k WM-pgACC
# 78
# 5 k WM
# 79
# 6 k WM
# 80
# 7 k MFG
# 81
# 8 k MFG
# 82
# 9 k MFG
# 83
# 10 k MFG
# 84
# 11 k MFG
# 85
# 12 k MFG
# 86
# 13 k MFG
# 87
# 14 k LCR-MFG
# 88
# 15 k LCR
# 89
# 1 k' pgACC
# 2 k' pgACC
# 91
# 3 k' WM
# 92
# 4 k' WM
# 93
# 5 k' WM
# 94
# 6 k' WM
# 95
# 7 k' WM
# 96
# 8 k' WM
# 97
# 9 k' WM
# 98
# 10 k' WM-IFGTr
# 99
# 11 k' IFGTr
# 100
# 12 k' IFGTr
# 101
# 13 k' IFGTr
# 102
# 14 k' IFGTr
# 103
# 15 k' LCR-IFGTr
# 104
# 1 l LgG-FuG
# 2 l LgG-FuG
# 106
# 3 l FuG
# 107
# 4 l FuG
# 108
# 5 l FuG-pITG
# 109
# 6 l FuG-pITG
# 110
# 7 l pITG
# 111
# 8 l pITG
# 112
# 9 l pITG
# 113
# 10 l pITG
# 114
# 11 l pITG
# 115
# 12 l LCR
# 116
# 1 o SG-MOrG
# 2 o SG-MOrG
# 118
# 3 o MOrG
# 119
# 4 o MOrG
# 120
# 5 o MOrG-IOrG
# 121
# 6 o MOrG-IOrG
# 122
# 7 o IOrG
# 123
# 8 o IOrG
# 124
# 9 o IOrG-IFGOr
# 125
# 10 o IFGOr
# 126
# 11 o IFGOr
# 127
# 12 o LCR-IFGOr
# 128
# 1 o' IRoG
# 2 o' IRoG
# 130
# 3 o' IRoG-SG
# 131
# 4 o' WM-MOrG
# 132
# 5 o' MOrG
# 133
# 6 o' Iorg
# 134
# 7 o' Iorg
# 135
# 8 o' Iorg
# 136
# 9 o' Iorg
# 137
# 10 o' Iorg
# 138
# 11 o' IFGOr
# 139
# 12 o' IFGOr
# 140
# 1 t Ins-TTG
# 2 t Ins-TTG
# 142
# 3 t TTG
# 143
# 4 t TTG
# 144
# 5 t TTG
# 145
# 6 t STG-TTG
# 146
# 7 t STG
# 147
# 8 t STG
# 148
# 9 t STG
# 149
# 10 t STG
# 150
# --> Bipolarize: VACJ_E2_sigs.npz
# ['x', 'channel', 'sf', 'xyz', 'label'] (152, 1, 152)
# 1 b mHC-Ent
# 2 b mHC-Ent
# 0
# 3 b mHC-PHG
# 1
# 4 b mHC-PHG-FuG
# 2
# 5 b WM-FuG
# 3
# 6 b MTG
# 4
# 7 b MTG
# 5
# 8 b MTG
# 6
# 9 b MTG
# 7
# 10 b MTG
# 8
# 11 b MTG
# 9
# 12 b MTG
# 10
# 1 b' mHC
# 2 b' mHC
# 12
# 3 b' mHC
# 13
# 4 b' mHC
# 14
# 5 b' mHC
# 15
# 6 b' mHC
# 16
# 7 b' WM-mHC
# 17
# 8 b' WM-MTG
# 18
# 9 b' WM-MTG
# 19
# 10 b' MTG
# 20
# 11 b' MTG
# 21
# 12 b' MTG
# 22
# 1 d' Amg
# 2 d' Amg-PRC
# 24
# 3 d' Amg-PRC
# 25
# 4 d' PRC
# 26
# 5 d' WM-PRC
# 27
# 6 d' WM-Ppo
# 28
# 7 d' WM-Ppo
# 29
# 8 d' MTG
# 30
# 9 d' MTG
# 31
# 10 d' MTG
# 32
# 11 d' MTG
# 33
# 12 d' MTG
# 34
# 1 e' IFGOp-IG
# 2 e' IFGOp-IG
# 36
# 3 e' IFGOp-IFGTr
# 37
# 4 e' IFGOp-IFGTr
# 38
# 5 e' IFGOp-IFGTr
# 39
# 6 e' WM-IFGOp
# 40
# 7 e' WM-IFGOp
# 41
# 8 e' IFGOp-IFGTr
# 42
# 9 e' IFGOp-IFGTr
# 43
# 10 e' LCR
# 44
# 1 f SRoG
# 2 f SRoG
# 46
# 3 f WM-SRoG
# 47
# 4 f WM-IFPG
# 48
# 5 f WM-IFPG
# 49
# 6 f WM-IFPG
# 50
# 7 f WM-IFPG
# 51
# 8 f WM-MFG
# 52
# 9 f MFG
# 53
# 10 f MFG
# 54
# 11 f MFG
# 55
# 12 f MFG-LCR
# 56
# 1 j WM-PPo
# 2 j WM-ITG-MTG
# 58
# 3 j MTG
# 59
# 4 j MTG
# 60
# 5 j LCR-MTG
# 61
# 6 j LCR
# 62
# 7 j LCR-skull
# 63
# 8 j skull
# 64
# 1 j' pPirT-Ent
# 2 j' pPirtT
# 66
# 3 j' WM-pPirT
# 67
# 4 j' WM-ITG
# 68
# 5 j' WM-MTG
# 69
# 6 j' WM-MTG
# 70
# 7 j' MTG
# 71
# 8 j' MTG
# 72
# 9 j' MTG
# 73
# 10 j' LCR-MTG
# 74
# 1 k pgACC
# 2 k pgACC
# 76
# 3 k WM-pgACC
# 77
# 4 k WM-pgACC
# 78
# 5 k WM
# 79
# 6 k WM
# 80
# 7 k MFG
# 81
# 8 k MFG
# 82
# 9 k MFG
# 83
# 10 k MFG
# 84
# 11 k MFG
# 85
# 12 k MFG
# 86
# 13 k MFG
# 87
# 14 k LCR-MFG
# 88
# 15 k LCR
# 89
# 1 k' pgACC
# 2 k' pgACC
# 91
# 3 k' WM
# 92
# 4 k' WM
# 93
# 5 k' WM
# 94
# 6 k' WM
# 95
# 7 k' WM
# 96
# 8 k' WM
# 97
# 9 k' WM
# 98
# 10 k' WM-IFGTr
# 99
# 11 k' IFGTr
# 100
# 12 k' IFGTr
# 101
# 13 k' IFGTr
# 102
# 14 k' IFGTr
# 103
# 15 k' LCR-IFGTr
# 104
# 1 l LgG-FuG
# 2 l LgG-FuG
# 106
# 3 l FuG
# 107
# 4 l FuG
# 108
# 5 l FuG-pITG
# 109
# 6 l FuG-pITG
# 110
# 7 l pITG
# 111
# 8 l pITG
# 112
# 9 l pITG
# 113
# 10 l pITG
# 114
# 11 l pITG
# 115
# 12 l LCR
# 116
# 1 o SG-MOrG
# 2 o SG-MOrG
# 118
# 3 o MOrG
# 119
# 4 o MOrG
# 120
# 5 o MOrG-IOrG
# 121
# 6 o MOrG-IOrG
# 122
# 7 o IOrG
# 123
# 8 o IOrG
# 124
# 9 o IOrG-IFGOr
# 125
# 10 o IFGOr
# 126
# 11 o IFGOr
# 127
# 12 o LCR-IFGOr
# 128
# 1 o' IRoG
# 2 o' IRoG
# 130
# 3 o' IRoG-SG
# 131
# 4 o' WM-MOrG
# 132
# 5 o' MOrG
# 133
# 6 o' Iorg
# 134
# 7 o' Iorg
# 135
# 8 o' Iorg
# 136
# 9 o' Iorg
# 137
# 10 o' Iorg
# 138
# 11 o' IFGOr
# 139
# 12 o' IFGOr
# 140
# 1 t Ins-TTG
# 2 t Ins-TTG
# 142
# 3 t TTG
# 143
# 4 t TTG
# 144
# 5 t TTG
# 145
# 6 t STG-TTG
# 146
# 7 t STG
# 147
# 8 t STG
# 148
# 9 t STG
# 149
# 10 t STG
# 150
