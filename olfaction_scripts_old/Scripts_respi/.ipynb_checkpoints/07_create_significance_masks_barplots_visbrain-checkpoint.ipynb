# %% [markdown]
# ### 1- Create stats masks - Electrodes to be plotted
#     Elec that reach the threshold in time (min sig)

# %%
from brainpipe.system import study
from os import listdir, makedirs
from os.path import isfile, join, exists
from brainpipe.statistics import *
import numpy as np
from itertools import product

phase = '_reshape'
conds = ['no_odor','odorall']
###############################################################################
st = study('Olfacto')
path_npz = join(st.path, 'figure/0_Classif_Power_Odor_NoOdor_Reshaped_1000perm/')
path_to_save = join(path_npz, 'masks_stat/')
All_subjects_sources_'+freq+phase+'_'+conds[0]+'_'+conds[1]+'_sel_physFT.npz'
f_form = '{}_sources_{}_odor_'+conds[0]+'_'+conds[1]+'_sel_physFT.npz'
f_form = join(path_npz, f_form)
f_save = '{}_mask_stat_{}_minwin{}_th{}.npy'
f_save = join(path_to_save,f_save)
###############################################################################
if not exists(path_to_save):
    makedirs(path_to_save)
###############################################################################  
freqs = ['0_VLFC','1_delta','2_theta', '3_alpha','4_beta','5_gamma1','6_gamma2']
min_win = 1
th = 0.001

#Find the permutation threshold by frequency band
perm_max = np.array([])
for freq in freqs:
    mat = np.load(f_form.format('All_subjects',freq))
    s_perm = mat['s_perm']
    print(s_perm.shape)
    for elec in range(s_perm.shape[0]):
        perm = s_perm[elec][:,np.newaxis]
        th_perm = perm_pvalue2level(perm, p=th, maxst=True)
        perm_max = np.hstack((perm_max,th_perm[0])) if np.size(perm_max) else th_perm[0]
    print(freq, max(perm_max))
print('perm max size',perm_max.shape)
thresh = max(perm_max) #find the max of perm thr across time and subjects

# Create masks for a specific perm threshold
for freq in freqs:
    mat = np.load(f_form.format('All_subjects',freq))
    s_da = mat['s_da']
    print('da',s_da.shape,np.max(s_da))
    mask = np.array([])
    for elec in range(s_da.shape[0]):
        da_elec = s_da[elec]
        pvals = np.array([])
        for win in range(da_elec.shape[0]):
            if da_elec[win] > thresh:
                pval = 1
            if da_elec[win] <= thresh:
                pval = 0
            pvals = np.hstack((pvals,pval)) if np.size(pvals) else pval
        #criteria for an elec to be significant
        pvals = np.ravel(pvals)
        underp = np.where(pvals == 1)[0]
        pvsplit = np.split(underp, np.where(np.diff(underp) != 1)[0]+1)
        signif = [True for k in pvsplit if len(k) >= min_win]
        if len(signif) >=1:
            remove = False
        else:
            remove = True
        mask = np.hstack((mask, remove)) if np.size(mask) else remove
    print(freq, len(mask),len(np.where(mask == False)[0]))
    np.save(f_save.format('All_subjects',freq,min_win,th,'freqs'),mask)
# Out:
# -> Olfacto loaded
# (607, 1000, 20)
# 0_VLFC 0.679807692308
# (607, 1000, 20)
# 1_delta 0.679807692308
# (607, 1000, 20)
# 2_theta 0.679807692308
# (607, 1000, 20)
# 3_alpha 0.679807692308
# (607, 1000, 20)
# 4_beta 0.696794871795
# (607, 1000, 20)
# 5_gamma1 0.696794871795
# (607, 1000, 20)
# 6_gamma2 0.696794871795
# perm max size (84980,)
# da (607, 20) 0.676684782609
# 0_VLFC 607 0
# da (607, 20) 0.742684659091
# 1_delta 607 1
# da (607, 20) 0.714758522727
# 2_theta 607 1
# da (607, 20) 0.713641098485
# 3_alpha 607 2
# da (607, 20) 0.755199275362
# 4_beta 607 2
# da (607, 20) 0.805416666667
# 5_gamma1 607 1
# da (607, 20) 0.888623188406
# 6_gamma2 607 6

# %% [markdown]
# ### Create masks for rest with one point in time

# %%
from brainpipe.system import study
from os import listdir, makedirs
from os.path import isfile, join, exists
from brainpipe.statistics import *
import numpy as np
from itertools import product

conds = ['low','high']
###############################################################################
st = study('Olfacto')
path_npz = join(st.path, 'figure/2_Classif_Rest_E_R_1000perm/0_Classif_Power_R_Rest_LowHigh_1000perm/')
path_to_save = join(path_npz, 'masks_stat/')
f_form = '{}_sources_{}_odor_'+conds[0]+'_'+conds[1]+'_sel_physFT.npz'
f_form = join(path_npz, f_form)
f_save = '{}_mask_stat_{}_minwin{}_th{}.npy'
f_save = join(path_to_save,f_save)
###############################################################################
if not exists(path_to_save):
    makedirs(path_to_save)
###############################################################################  
freqs = ['2_theta', '3_alpha','4_beta','5_gamma1','6_gamma2']
th = 0.001

#Find the permutation threshold by frequency band
perm_max = np.array([])
for freq in freqs:
    mat = np.load(f_form.format('All_subjects',freq))
    s_perm = mat['s_perm'][:,:,np.newaxis]
    print(s_perm.shape)
    for elec in range(s_perm.shape[0]):
        perm = s_perm[elec]
        th_perm = perm_pvalue2level(perm, p=th, maxst=True)
        perm_max = np.hstack((perm_max,th_perm[0])) if np.size(perm_max) else th_perm[0]
    print(freq, max(perm_max))
print('perm max size',perm_max.shape)
thresh = max(perm_max) #find the max of perm thr across time and subjects
print('perm corrected across freq', thresh)

# Create masks for a specific perm threshold
for freq in freqs:
    mat = np.load(f_form.format('All_subjects',freq))
    s_da = mat['s_da']
    print('da',s_da.shape)
    mask = np.array([])
    for elec in range(s_da.shape[0]):
        da_elec = s_da[elec]
        pvals = np.array([])
        if da_elec > thresh:
            pval = 1
            remove = False
        if da_elec <= thresh:
            pval = 0
            remove = True
        pvals = np.hstack((pvals,pval)) if np.size(pvals) else pval
        mask = np.hstack((mask, remove)) if np.size(mask) else remove
    print(freq, len(mask),len(np.where(mask == False)[0]))
    np.save(f_save.format('All_subjects',freq,min_win,th,'freqs'),mask)
# Out:
# -> Olfacto loaded
# (405, 1000, 1)
# 2_theta 0.916666666667
# (405, 1000, 1)
# 3_alpha 0.95
# (405, 1000, 1)
# 4_beta 0.95
# (405, 1000, 1)
# 5_gamma1 0.95
# (405, 1000, 1)
# 6_gamma2 0.966666666667
# perm max size (2025,)
# perm corrected across freq 0.966666666667
# da (405,)
# 2_theta 405 0
# da (405,)
# 3_alpha 405 0
# da (405,)
# 4_beta 405 0
# da (405,)
# 5_gamma1 405 0
# da (405,)
# 6_gamma2 405 0

# %% [markdown]
# ### Create mask for ERPs

# %%
from brainpipe.system import study
from os import listdir, makedirs
from os.path import isfile, join, exists
from brainpipe.statistics import *
import numpy as np
from itertools import product

conds, step = ['no_odor','odor'], 'Encoding'
###############################################################################
st = study('Olfacto')
path_npz = join(st.path, 'figure/0_Classif_ERP_'+step+'_Odor_Inspi_1000perm/')
path_to_save = join(path_npz, 'masks_stat/')
f_form = '{}_sources_ERP_'+conds[0]+'_'+conds[1]+'_sel_phys.npz'
f_form = join(path_npz, f_form)
f_save = '{}_mask_stat_ERP_minwin{}_th{}.npy'
f_save = join(path_to_save,f_save)
###############################################################################
if not exists(path_to_save):
    makedirs(path_to_save)
###############################################################################  

min_win = 1
th = 0.05

#Find the permutation threshold by frequency band
perm_max = np.array([])
mat = np.load(f_form.format('All_subjects'))
s_perm = mat['s_perm']
print(s_perm.shape)
for elec in range(s_perm.shape[0]):
    perm = s_perm[elec][:,np.newaxis]
    th_perm = perm_pvalue2level(perm, p=th, maxst=True)
    perm_max = np.hstack((perm_max,th_perm[0])) if np.size(perm_max) else th_perm[0]
print(max(perm_max))
print('perm max size',perm_max.shape)
thresh = max(perm_max) #find the max of perm thr across time and subjects

# Create masks for a specific perm threshold

mat = np.load(f_form.format('All_subjects'))
s_da = mat['s_da']
su_codes, channels = mat['su_codes'], mat['s_channels']
print('da',s_da.shape,np.max(s_da))
mask = np.array([])
for elec in range(s_da.shape[0]):
    da_elec = s_da[elec]
    pvals = np.array([])
    for win in range(da_elec.shape[0]):
        if da_elec[win] > thresh:
            pval = 1
            print(elec,su_codes[elec],channels[elec])
        if da_elec[win] <= thresh:
            pval = 0
        pvals = np.hstack((pvals,pval)) if np.size(pvals) else pval
    #criteria for an elec to be significant
    pvals = np.ravel(pvals)
    underp = np.where(pvals == 1)[0]
    pvsplit = np.split(underp, np.where(np.diff(underp) != 1)[0]+1)
    signif = [True for k in pvsplit if len(k) >= min_win]
    if len(signif) >=1:
        remove = False
    else:
        remove = True
    mask = np.hstack((mask, remove)) if np.size(mask) else remove
print(len(mask),len(np.where(mask == False)[0]))
np.save(f_save.format('All_subjects',min_win,th),mask)

# %% [markdown]
# ### 2- Create masks - min patients

# %%
from brainpipe.system import study
from os import listdir, makedirs
from os.path import isfile, join, exists
import numpy as np
from itertools import product
from PIL import Image

score = 'Epi'
conds = ['low','high','no_odor']
th, corr = '0.01', False
###############################################################################
st = study('Olfacto')
path_classif = join(st.path, 'classified/0_Classif_Power_Encoding_Odor_Inspi_1000perm/')
path_npz = join(st.path, 'figure/0_Classif_Power_E_Odor_Inspi_1000perm/')
if corr == True:
    path_rois, path_stats = join(path_npz,'Signif_ROIs'+th+'/'), join(path_npz, 'masks_stat_corr/')
else :
    path_rois, path_stats = join(path_npz,'Signif_ROIs'+th+'/'), join(path_npz, 'masks_stat/')
path_to_save = join(path_npz, 'masks_visbrain'+th+'/')
path_save_fig = join(path_npz, 'Signif_timecourse'+th+'_corr/') if corr == True else join(path_npz, 'Signif_timecourse'+th+'/')
npz_form = join(path_npz, '{}_sources_{}_odor_'+conds[0]+'_'+conds[1]+'_sel_physFT.npz')
rois_form = join(path_rois, '{}_signif_min_{}_{}_min_win{}_th_{}_corr.npy') if corr == True else join(path_rois, '{}_signif_min_{}_{}_min_win{}_th_{}.npy')
stat_form = join(path_stats,'{}_mask_stat_{}_minwin{}_th{}.npy')
mask_vis_form = join(path_to_save,'{}_mask_min{}_{}_minwin{}_th{}_corr.npy') if corr == True else join(path_to_save,'{}_mask_min{}_{}_minwin{}_th{}.npy')
###############################################################################
if not exists(path_to_save):
    makedirs(path_to_save)
if not exists(path_save_fig):
    makedirs(path_save_fig)
############################################################################### 

freqs = ['0_VLFC','1_delta','2_theta', '3_alpha', '4_beta','5_gamma1','6_gamma2']
su_codes = {'S0':'CHAF','S1':'FERJ','S2':'LEFC','S3':'MICP','S4':'PIRJ','S5':'SEMC','S6':'VACJ'} #'S6':'MICP'
min_wins = ['1']#,'2','3','4','5']
methods = ['MAI_RL'] #,'aal_RL','BA','aal',
min_sigs = [1]#1,2,3,4,

for freq,min_win,min_sig,method in product(freqs,min_wins,min_sigs,methods):
    # Load the electrodes labels, electrodes significant (bool), rois significant (names)
    npz_mat = np.load(npz_form.format('All_subjects',freq))
    print(npz_mat.files) #, npz_mat['su_codes'], npz_mat['su_names'])
    labels0, labels = npz_mat['s_labels'],npz_mat['s_'+method]
    subjects, names = npz_mat['su_codes'], npz_mat['su_names']
    elecs, channels = npz_mat['s_elec'],npz_mat['s_channels']
    stats = np.load(stat_form.format('All_subjects',freq,min_win,th))
    filename_rois = rois_form.format('s_Mai_RL',min_sig,freq[2:],min_win,th)
    if exists(filename_rois):
        rois = np.load(filename_rois)
        mask_vis = []
        i=0
        for e in range(labels.shape[0]):
            if stats[e]==0 and labels[e] in rois:
                mask_vis.append(False)
                i=i+1
                print(subjects[e], names[e],labels[e],channels[e],elecs[e],'number of elecs',i)
                #path_file = path_classif+su_codes[subjects[e]]+'/'+freq+'/fig/'
                path_file_time = path_classif+freq+'/fig/'
                filename = su_codes[subjects[e]]+'_Power_'+conds[2]+'_'+channels[e]+'_'+labels[e]+'_('+elecs[e]+').png'
                img = Image.open(path_file_time+filename)
                path_save_fig2 = path_save_fig+freq+'/'+labels[e]+'/'
                if not exists(path_save_fig2):
                    makedirs(path_save_fig2)
                img.save(path_save_fig2+'/min_patient'+str(min_sig)+'_minwin_'+str(min_win)+'_'+filename,'png')
            else :
                mask_vis.append(True)
            #print(stats[e],labels[e], mask_vis[e])
        np.save(mask_vis_form.format(method,min_sig,freq,min_win,th),mask_vis)
# Out:
# -> Olfacto loaded
# ['s_elec', 's_perm', 's_xyz', 's_labels', 'su_names', 's_aal', 's_MAI', 's_da', 's_elec_pow1', 's_channels', 's_elec_pow0', 's_time', 's_aal_RL', 'su_codes', 's_MAI_RL', 's_BA']
# S1 S1_FERJ MTG b'11-b'10 19 number of elecs 1
# S1 S1_FERJ Ins t2-t1 82 number of elecs 2
# S2 S2_LEFC MFG k11-k10 42 number of elecs 3
# S2 S2_LEFC OFC o4-o3 63 number of elecs 4
# S2 S2_LEFC SMG x11-x10 136 number of elecs 5
# S5 S5_VACJ Ins e3-e2 7 number of elecs 6
# S5 S5_VACJ OFC o5-o4 30 number of elecs 7
# S5 S5_VACJ OFC o7-o6 32 number of elecs 8
# S5 S5_VACJ OFC o10-o9 35 number of elecs 9
# S5 S5_VACJ OFC u5-u4 40 number of elecs 10
# S6 S6_MICP ACC k'2-k'1 39 number of elecs 11
# S6 S6_MICP IFG k'12-k'11 40 number of elecs 12
# ['s_elec', 's_perm', 's_xyz', 's_labels', 'su_names', 's_aal', 's_MAI', 's_da', 's_elec_pow1', 's_channels', 's_elec_pow0', 's_time', 's_aal_RL', 'su_codes', 's_MAI_RL', 's_BA']
# S2 S2_LEFC Amg-PirT a2-a1 0 number of elecs 1
# S2 S2_LEFC Ins a7-a6 2 number of elecs 2
# S2 S2_LEFC MTG a10-a9 5 number of elecs 3
# S2 S2_LEFC MTG b10-b9 11 number of elecs 4
# S2 S2_LEFC SMG x11-x10 136 number of elecs 5
# S3 S3_SEMC TTG h'4-h'3 43 number of elecs 6
# S5 S5_VACJ MFG k9-k8 24 number of elecs 7
# S5 S5_VACJ OFC o7-o6 32 number of elecs 8
# S6 S6_MICP MTG b9-b8 4 number of elecs 9
# S6 S6_MICP MTG b10-b9 5 number of elecs 10
# S6 S6_MICP MTG b11-b10 6 number of elecs 11
# S6 S6_MICP MTG b'11-b'10 13 number of elecs 12
# S6 S6_MICP IFG e'3-e'2 23 number of elecs 13
# S6 S6_MICP OFC o7-o6 58 number of elecs 14
# ['s_aal_RL', 's_channels', 's_perm', 'su_codes', 's_MAI', 's_MAI_RL', 's_xyz', 's_da', 'su_names', 's_time', 's_elec', 's_labels', 's_aal', 's_elec_pow0', 's_elec_pow1', 's_BA']
# S0 S0_CHAF MCC b'2-b'1 10 number of elecs 1
# S0 S0_CHAF PrG b'3-b'2 11 number of elecs 2
# S0 S0_CHAF PrG b'8-b'7 16 number of elecs 3
# S0 S0_CHAF SFG d'9-d'8 30 number of elecs 4
# S0 S0_CHAF SFG d'10-d'9 31 number of elecs 5
# S0 S0_CHAF SFG f'6-f'5 47 number of elecs 6
# S2 S2_LEFC PoG q6-q5 75 number of elecs 7
# S2 S2_LEFC PoG q7-q6 76 number of elecs 8
# S2 S2_LEFC SMG q10-q9 79 number of elecs 9
# S3 S3_SEMC MTG c'11-c'10 24 number of elecs 10
# S6 S6_MICP MTG b9-b8 4 number of elecs 11
# S6 S6_MICP MTG b10-b9 5 number of elecs 12
# S6 S6_MICP MTG d'10-d'9 19 number of elecs 13
# S6 S6_MICP MTG d'11-d'10 20 number of elecs 14
# S6 S6_MICP SFG f2-f1 27 number of elecs 15
# ['s_aal_RL', 's_channels', 's_perm', 'su_codes', 's_MAI', 's_MAI_RL', 's_xyz', 's_da', 'su_names', 's_time', 's_elec', 's_labels', 's_aal', 's_elec_pow0', 's_elec_pow1', 's_BA']
# S0 S0_CHAF PrG a'9-a'8 7 number of elecs 1
# S5 S5_VACJ OFC o5-o4 30 number of elecs 2
# S5 S5_VACJ OFC o6-o5 31 number of elecs 3
# S5 S5_VACJ OFC o7-o6 32 number of elecs 4
# S6 S6_MICP MTG b9-b8 4 number of elecs 5
# S6 S6_MICP MTG b10-b9 5 number of elecs 6
# S6 S6_MICP MTG b11-b10 6 number of elecs 7
# S6 S6_MICP MTG d'10-d'9 19 number of elecs 8
# S6 S6_MICP MTG j4-j3 30 number of elecs 9
# S6 S6_MICP TTG t5-t4 74 number of elecs 10
# S6 S6_MICP TTG t6-t5 75 number of elecs 11
# S6 S6_MICP STG t9-t8 78 number of elecs 12
# ['s_aal_RL', 's_channels', 's_perm', 'su_codes', 's_MAI', 's_MAI_RL', 's_xyz', 's_da', 'su_names', 's_time', 's_elec', 's_labels', 's_aal', 's_elec_pow0', 's_elec_pow1', 's_BA']
# S0 S0_CHAF MFG j'14-j'13 91 number of elecs 1
# S1 S1_FERJ FuG d'8-d'7 36 number of elecs 2
# S2 S2_LEFC OFC o5-o4 64 number of elecs 3
# S2 S2_LEFC SFG s5-s4 92 number of elecs 4
# S2 S2_LEFC SFG s6-s5 93 number of elecs 5
# S3 S3_SEMC MTG b'12-b'11 17 number of elecs 6
# S5 S5_VACJ OFC o5-o4 30 number of elecs 7
# S5 S5_VACJ OFC o6-o5 31 number of elecs 8
# S5 S5_VACJ OFC o7-o6 32 number of elecs 9
# S5 S5_VACJ IFG u8-u7 43 number of elecs 10
# S6 S6_MICP MTG b10-b9 5 number of elecs 11
# S6 S6_MICP MTG b11-b10 6 number of elecs 12
# S6 S6_MICP Ins e'2-e'1 22 number of elecs 13
# S6 S6_MICP MFG f10-f9 28 number of elecs 14
# S6 S6_MICP MFG f11-f10 29 number of elecs 15
# S6 S6_MICP FuG l5-l4 46 number of elecs 16
# ['s_aal_RL', 's_channels', 's_perm', 'su_codes', 's_MAI', 's_MAI_RL', 's_xyz', 's_da', 'su_names', 's_time', 's_elec', 's_labels', 's_aal', 's_elec_pow0', 's_elec_pow1', 's_BA']
# S0 S0_CHAF PrG a'8-a'7 6 number of elecs 1
# S0 S0_CHAF SFG e'5-e'4 35 number of elecs 2
# S0 S0_CHAF ACC f'3-f'2 44 number of elecs 3
# S0 S0_CHAF PrG g'7-g'6 60 number of elecs 4
# S0 S0_CHAF OrG i'3-i'2 72 number of elecs 5
# S1 S1_FERJ IFG o8-o7 78 number of elecs 6
# S2 S2_LEFC STG g13-g12 34 number of elecs 7
# S2 S2_LEFC OFC o4-o3 63 number of elecs 8
# S2 S2_LEFC OFC o5-o4 64 number of elecs 9
# S5 S5_VACJ HC b2-b1 0 number of elecs 10
# S5 S5_VACJ Ins e2-e1 6 number of elecs 11
# S5 S5_VACJ Ins e3-e2 7 number of elecs 12
# S5 S5_VACJ MFG k9-k8 24 number of elecs 13
# S5 S5_VACJ MFG k10-k9 25 number of elecs 14
# S5 S5_VACJ OFC o5-o4 30 number of elecs 15
# S5 S5_VACJ OFC o6-o5 31 number of elecs 16
# S5 S5_VACJ OFC o7-o6 32 number of elecs 17
# S5 S5_VACJ MFG x9-x8 50 number of elecs 18
# S6 S6_MICP Ins e'2-e'1 22 number of elecs 19
# ['s_aal_RL', 's_channels', 's_perm', 'su_codes', 's_MAI', 's_MAI_RL', 's_xyz', 's_da', 'su_names', 's_time', 's_elec', 's_labels', 's_aal', 's_elec_pow0', 's_elec_pow1', 's_BA']
# S0 S0_CHAF SFG e'4-e'3 34 number of elecs 1
# S0 S0_CHAF ACC f'2-f'1 43 number of elecs 2
# S0 S0_CHAF SFG f'5-f'4 46 number of elecs 3
# S0 S0_CHAF SFG f'6-f'5 47 number of elecs 4
# S0 S0_CHAF MFG h'9-h'8 69 number of elecs 5
# S0 S0_CHAF OrG i'2-i'1 71 number of elecs 6
# S1 S1_FERJ PHG d'2-d'1 30 number of elecs 7
# S1 S1_FERJ OFC o7-o6 77 number of elecs 8
# S1 S1_FERJ IFG o8-o7 78 number of elecs 9
# S1 S1_FERJ IFG o9-o8 79 number of elecs 10
# S2 S2_LEFC STG g13-g12 34 number of elecs 11
# S2 S2_LEFC ITG l10-l9 52 number of elecs 12
# S2 S2_LEFC OFC o4-o3 63 number of elecs 13
# S2 S2_LEFC OFC o5-o4 64 number of elecs 14
# S2 S2_LEFC OFC o6-o5 65 number of elecs 15
# S2 S2_LEFC SMG x11-x10 136 number of elecs 16
# S2 S2_LEFC SMG x12-x11 137 number of elecs 17
# S3 S3_SEMC TTG h'3-h'2 42 number of elecs 18
# S3 S3_SEMC TTG h'4-h'3 43 number of elecs 19
# S3 S3_SEMC TTG h'6-h'5 45 number of elecs 20
# S3 S3_SEMC TTG h'7-h'6 46 number of elecs 21
# S5 S5_VACJ Ins e3-e2 7 number of elecs 22
# S5 S5_VACJ MFG k9-k8 24 number of elecs 23
# S5 S5_VACJ MFG k10-k9 25 number of elecs 24
# S5 S5_VACJ OFC o5-o4 30 number of elecs 25
# S5 S5_VACJ OFC o6-o5 31 number of elecs 26
# S5 S5_VACJ OFC o7-o6 32 number of elecs 27
# S5 S5_VACJ OFC u7-u6 42 number of elecs 28
# S5 S5_VACJ IFG u8-u7 43 number of elecs 29
# S5 S5_VACJ MFG x9-x8 50 number of elecs 30
# S6 S6_MICP Ins e'2-e'1 22 number of elecs 31
# S6 S6_MICP IFG e'4-e'3 24 number of elecs 32
# S6 S6_MICP MFG k10-k9 35 number of elecs 33
# S6 S6_MICP OFC o'10-o'9 69 number of elecs 34
