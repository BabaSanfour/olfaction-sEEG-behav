# %%
#Importing files and modules

import numpy as np
import matplotlib.pyplot as plt
from os import path
# %matplotlib notebook
from brainpipe.system import study
from brainpipe.visual import *
from brainpipe.statistics import *
from mne.baseline import rescale
from mne.filter import filter_data
import pandas as pd
from pandas import ExcelWriter

from detect_peaks import detect_peaks

# %%
low_pass_filter = 10.
sf = 512.
norm_mode = 'mean' #'ratio' 'mean' 'percent' 
baseline = [640 , 768] #-250ms à 0ms
data_to_use = [768, 1536]
n_perm = 200

# %%
st = study('Olfacto')
path_data = path.join (st.path, 'database/TS_E_all_cond_by_block_trigs_th40_art400_30_250_5s_concatOK/')

subjects = ['CHAF','VACJ','SEMC','PIRJ','LEFC','MICP',]

conds = ['all']

n_elec = {
    'CHAF' : 107,
    'VACJ' : 139, 
    'SEMC' : 107,
    'PIRJ' : 106,
    'LEFC' : 193,
    'MICP' : 105,
}

for su in subjects:
    for elec in range(0, n_elec[su],1):
        for cond in conds:
            filename = su+'_E1E2_concat_all_bipo_new.npz'
            print (filename)
            data_all = np.load(path.join(path_data, filename))
            data, channel, label = data_all['x'], data_all['channel'], data_all['label']

            # Select data for one elec + name :
            data_elec = data[elec,:,:]
            ntrials = len(data_elec[1])
            print ('\nOriginal data : ', data.shape, 'Channel : ', channel[elec], 'Label : ', label[elec], 'N_trials :', ntrials, 'One elec shape : ', data_elec.shape)

            #Normalize the non-averaged data (all trials)
            times = np.arange(data_elec.shape[0])
            print ('time points : ', times.shape)
            data_to_norm = np.swapaxes(data_elec, 0, 1)
            norm_data = rescale(data_to_norm, times=times, baseline=baseline, mode=norm_mode)
            norm_data = np.swapaxes(norm_data, 0, 1)
            print ('Size norm & filtered data : ', norm_data.shape,)



# =======================================SELECT DATA FOR STATISTICS=====================================
            # Define a range vector for the baseline and data :
            baseline_range = range(baseline[0], baseline[1])
            data_range = range(data_to_use[0], data_to_use[1])
            
            #Get the baseline and data from the RAW data :
            baseline_tr = data_elec[baseline_range, :]
            data_elec_tr = data_elec[data_range, :]

            # Mean the baseline across time (increase consistency) :
            baseline_tr = baseline_tr.mean(0)[np.newaxis, ...]
            print('-> Shape of the baseline : ', baseline_tr.shape,' and the selected data :', data_elec_tr.shape)
            
            # Repeat the baseline by the nb of temporal time points (for swap function)
            baseline_tr_rep = np.tile(baseline_tr, (data_elec_tr.shape[0], 1))
            print('-> Shape of repeated baseline :', baseline_tr_rep.shape)
            
            # Swap RAW data and baseline across trials (dim 1) :
            perm_data = perm_swap(baseline_tr_rep, data_elec_tr, axis=1, n_perm=n_perm)[0]
            print('-> Shape of permuted data / baseline : ', perm_data.shape)

            # Take the mean across time :
            perm_data_mean = perm_data.mean(2)
            print('-> Shape of meaned permuted data / baseline : ', perm_data_mean.shape)

            # Get p-values from the permuted data :
            p_vals = perm_2pvalue(data_elec_tr.mean(1), perm_data_mean, n_perm=n_perm, threshold=None, tail=2)
            print('-> Shape of non-corrected p-values : ', p_vals.shape)

            # Correct across time :
            perm_corr = maxstat(perm_data, axis=2)[..., 0]
            print('-> Shape of maxstat perm : ', perm_corr.shape)

            # Get p-values from the permuted data :
            p_vals_corr = perm_2pvalue(data_elec_tr.mean(1), perm_corr, n_perm=n_perm, threshold=None, tail=2)
            print('-> Shape of corrected p-values : ', p_vals_corr.shape)

            # Test if there's significant p-values after multiplt comparison :
            print('-> Significant p-values after mutiple comparison? ', p_vals_corr.min() <= 0.05)

# =======================PREPARE DATA TO PLOT AND PLOT THE ERPs=====================================
            # Data to plot :
            #data_to_plot = norm_data[range(baseline[0], data_to_use[1])]
            #print('-> Shape of data to plot : ', data_to_plot.shape)
            data_to_plot = norm_data[range(baseline[0], data_to_use[1])]
            print('-> Shape of data to plot : ', data_to_plot.shape)

            # Time vector :
            times_plot = 1000 * np.arange((baseline[0] - baseline[1]), data_to_plot.shape[0]-baseline[1] + baseline[0],) / sf
            #times_plot = 1000 * np.arange(-baseline[1], filtered_data_to_plot.shape[0]-baseline[1],) / sf
            print('-> Shape of time vector : ', times_plot.shape)

            # P-values to plot :
            p_vals_to_plot = np.insert(p_vals, 0, 10 * np.ones((data_to_use[0] - baseline[0],)))
            p_vals_corr_to_plot = np.insert(p_vals_corr, 0, 10 * np.ones((data_to_use[0] - baseline[0],)))
            print('-> Shape of p-values to plot :', p_vals_to_plot.shape, p_vals_corr_to_plot.shape)

            #Prepare the plot
            fig = plt.figure(0, figsize=(12, 7))
            ax = fig.add_subplot(111)
            fig.subplots_adjust(top=0.85)
            ax.set_xlabel('Times (ms)', fontsize=12)
            ax.set_ylabel('Potential', fontsize=12)

            #Plot the Data
            #plt.plot(times_plot, data_to_plot, '#808080', linewidth=1, label='data')
            #plt.plot(times_plot, filtered_data_to_plot, 'g-', linewidth=2, label='filtered data < '+str(low_pass_filter)+'Hz')
            BorderPlot(times_plot, data_to_plot, kind='sem', color='', alpha=0.2, linewidth=2, ncol=1, 
                      title=su+'_ERP_Odor_bipo_'+norm_mode+'_'+channel[elec]+'_'+label[elec]+' elec_num: '+str(elec)+'_ntrials:'+str(ntrials),) #legend= roi+'_filter < '+str(low_pass_filter)+'Hz'
            plt.gca()
            lines = [0] #time vector is in ms
            addPval(plt.gca(), p_vals_to_plot, p=0.05, x=times_plot, y=0.5, color='darkred', lw=3)
            addPval(plt.gca(), p_vals_to_plot, p=0.01, x=times_plot, y=1, color='darkblue', lw=4)
            addPval(plt.gca(), p_vals_corr_to_plot, p=0.05, x=times_plot, y=2, color='red', lw=3)
            addPval(plt.gca(), p_vals_corr_to_plot, p=0.01, x=times_plot, y=3, color='dodgerblue', lw=4)
            addLines(plt.gca(), vLines=lines, vColor=['firebrick']*2, vWidth=[2]*2, hLines=[0], hColor=['#000000'], hWidth=[2])
            plt.grid()
            #plt.legend(fontsize='small')
            #plt.show()         
                 
# =========================SAVE PLOTS of ERPs=================================================
            rep = path.join(st.path, 'feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/',su)
            fname = (rep + '_E1E2_ERP_concat_all_bipo_' + channel [elec] +'_'+str(elec)+'_'+label[elec]+'.png')
            print (fname)
            plt.savefig(fname, dpi=300, bbox_inches='tight')
            plt.close()
del x, channel, n_elec, n_trials, label
# Out:
# -> Olfacto loaded
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  a'2-a'1 Label :  PCC-PCL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_a'2-a'1_0_PCC-PCL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  a'3-a'2 Label :  PCL&PCC-PCL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_a'3-a'2_1_PCL&PCC-PCL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  a'4-a'3 Label :  WM-PrG-PoG&PCL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_a'4-a'3_2_WM-PrG-PoG&PCL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  a'5-a'4 Label :  WM-PrG-PoG N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo
png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  e'5-e'4 Label :  SFGM-SFGL&SFGM N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_e'5-e'4_39_SFGM-SFGL&SFGM.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  e'6-e'5 Label :  SFGM-SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_e'6-e'5_40_SFGM-SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  e'7-e'6 Label :  SFGM-SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_e'7-e'6_41_SFGM-SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  e'8-e'7 Label :  SFGL&SFGM-SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_e'8-e'7_42_SFGL&SFGM-SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  e'9-e'8 Label :  SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_e'9-e'8_43_SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  e'10-e'9 Label :  SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_e'10-e'9_44_SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  e'11-e'10 Label :  LCR-SFGL&SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_e'11-e'10_45_LCR-SFGL&SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  e'12-e'11 Label :  LCR-SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_e'12-e'11_46_LCR-SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  f'2-f'1 Label :  pgACC N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_f'2-f'1_47_pgACC.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  f'3-f'2 Label :  pgACC-SFGM&pgACC N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# ...
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_i'10-i'9_87_SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  i'11-i'10 Label :  SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_i'11-i'10_88_SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  i'12-i'11 Label :  SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_i'12-i'11_89_SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  i'13-i'12 Label :  SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_i'13-i'12_90_SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  i'14-i'13 Label :  SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_i'14-i'13_91_SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  i'15-i'14 Label :  SFGL N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_i'15-i'14_92_SFGL.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  j'2-j'1 Label :  Cd N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_j'2-j'1_93_Cd.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  j'3-j'2 Label :  Cd N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_j'3-j'2_94_Cd.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  j'4-j'3 Label :  WM-Cd&Cd N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_j'4-j'3_95_WM-Cd&Cd.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  j'5-j'4 Label :  WM-Cd N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_j'5-j'4_96_WM-Cd.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  j'6-j'5 Label :  WM-Cd N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_j'6-j'5_97_WM-Cd.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  j'8-j'7 Label :  WM-PrG N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_j'8-j'7_98_WM-PrG.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  j'9-j'8 Label :  WM-PrG N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_j'9-j'8_99_WM-PrG.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  j'10-j'9 Label :  WM-PrG N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_j'10-j'9_100_WM-PrG.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  j'14-j'13 Label :  MFG N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_j'14-j'13_101_MFG.png
# CHAF_E1E2_concat_all_bipo_new.npz
#
# Original data :  (103, 2560, 40) Channel :  j'15-j'14 Label :  MFPG&MFG N_trials : 40 One elec shape :  (2560, 40)
# time points :  (2560,)
# Applying baseline correction (mode: mean)
# Size norm & filtered data :  (2560, 40)
# -> Shape of the baseline :  (1, 40)  and the selected data : (768, 40)
# -> Shape of repeated baseline : (768, 40)
# -> Shape of permuted data / baseline :  (200, 768, 40)
# -> Shape of meaned permuted data / baseline :  (200, 768)
# -> Shape of non-corrected p-values :  (768,)
# -> Shape of maxstat perm :  (200, 768)
# -> Shape of corrected p-values :  (768,)
# -> Significant p-values after mutiple comparison?  False
# -> Shape of data to plot :  (896, 40)
# -> Shape of time vector :  (896,)
# -> Shape of p-values to plot : (896,) (896,)
# <img src="data:image/png;base64,...">
# /media/karim/Datas4To/Analyses_Intra_EM_Odor/Olfacto/feature/ERP_Encoding_all_bipo_250ms_mean_thr40_art400_30_250_RAW/CHAF_E1E2_ERP_concat_all_bipo_j'15-j'14_102_MFPG&MFG.png
# CHAF_E1E2_concat_all_bipo_new.npz
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-23169b352e85> in <module>()
#      24
#      25             # Select data for one elec + name :
# ---> 26             data_elec = data[elec,:,:]
#      27             ntrials = len(data_elec[1])
#      28             print ('\nOriginal data : ', data.shape, 'Channel : ', channel[elec], 'Label : ', label[elec], 'N_trials :', ntrials, 'One elec shape : ', data_elec.shape)
#
# IndexError: index 103 is out of bounds for axis 0 with size 103
