# %% [markdown]
# # Import librabys :

# %%
# %reload_ext autoreload
# %autoreload 2
import numpy as n
import brainpipe.bpold.braindata as bdt
from brainpipe.feature import power
import brainpipe.classification as ct
# from brainpipe.system.tools import binarize
from brainpipe.visual import *
import matplotlib.pyplot as plt
# import brainpipe.statistic.stat_tools as cs
from brainpipe.classification import *
plt.style.use('seaborn-poster')
# %matplotlib notebook

# %% [markdown]
# ---
# ### Define variables :
# For Paper 3 figures :
# - elec 22: clf = svm rbf, fc=(65,75), width=700, step=50, norm=0

# %%
sujet = 'C_rev'
main = 'RH'
elec = 73
event,condition = [1,2,3,4], ['Up', 'Right', 'Down', 'Left']

# path = '/home/etienne/Database/Sujets/'
path = '/media/etienne/E438C4AE38C480D2/Users/Etienne Combrisson/Documents/MATLAB/Sujets/'
x, channel, sf, y = bdt.seeg_data(sujet, main, event, path=path)
x = x[elec, :, :]
N = x.shape[0]
# Out:
# Loading : bipolarised_C_rev_mouse_RH_1.mat
# Loading : bipolarised_C_rev_mouse_RH_2.mat
# Loading : bipolarised_C_rev_mouse_RH_3.mat
# Loading : bipolarised_C_rev_mouse_RH_4.mat

# %%
# bad_L_jac = [1,4,8,9,11,18,27,28,30,33,43,69,82,83,84,86,88,90,92,93,94,96,97,98,100,102,104,107,117]
# x = n.delete(x, bad_L_jac, axis=1)
# y = n.delete(y, bad_L_jac, axis=0)
x.shape
# Out:
# (4001, 160)

# %% [markdown]
# ### Compute the power :

# %%
fc = (8,13)
baseline, norm = (250,750), 0
width, step = 700, 50#700, 50
split = None
fcname = str(fc[0])+'-'+str(fc[1])

powObj = power(sf, 4001, f=fc, baseline=baseline, width=width, step=step, split=split,
               method='hilbert1', norm=norm, time=n.arange(4001)-1000)
# time = n.array(powObj.xvec).astype(int)-1000


n.array(powObj._window[5]).mean()
xPower = powObj.get(x, n_jobs=-1)[0]
# time = powObj.xvec

# %%
x_m =  n.tile(n.mean(xPower.T, 0), (xPower.T.shape[0], 1))
x_m.shape
xPower = n.squeeze(xPower)

# %% [markdown]
# ### Classify each time point :

# %%
clfObj = classify(y, clf='svm', cvtype='sss', cvArg={'rep':10}, clfArg={'kern':'rbf'})
# da = clfObj.fit(xPower, n_jobs=-1)
da = clfObj.fit(xPower, n_jobs=-1, center=True)[0]#, n_perm=20, method='label_rnd') , pvalue, daperm

# %%
da.max(), da.mean(1).argmax(), powObj._window[da.mean(1).argmax()], da.mean(0).max()
# Out:
# (50.625, 6, (300, 1000), 47.4375)

# %%
clf = defClf(y, clf='svm', kern='linear')
clf.shStr
# Out:
# 'SVM-linear'

# %% [markdown]
# ---
# ### Border Plot :

# %%
from matplotlib.ticker import ScalarFormatter, MaxNLocator
# xPower[:,83], xPower[:,93] = xPower[:,82], xPower[:,92]
# xPower = n.delete(xPower,(83,91,92,93,94),axis=1)
# y = n.delete(n.array(y),(83,91,92,93,94),axis=0)

titre=sujet#+'-'+main+', elec:'+channel[0][elec][0]+'('+str(elec)+'), f='+str(fc)+', clf='+clfObj.clf.shStr

xfmt = ScalarFormatter(useMathText=True)
xfmt.set_powerlimits((0,3))

fig = plt.figure(1,figsize=(10,8))
titre='Gamma power directions decoding (BA6 - S6)'

# Plot the phase features :
plt.subplot(211)
BorderPlot(powObj.xvec,xPower,y=y, xlabel='',title=titre,legend=['Up','Right','Down','Left'],
           alpha=0.3,linewidth=4,color=['b','g','r','darkorange'],xticks=[0,1500],ylabel=r'$\mu$V² / hz',
           kind='sem')
rmaxis(plt.gca(), ['right', 'top'])
addLines(plt.gca(),vLines=[0,1500],vWidth=[1,1],vShape=['-','-'])
# plt.gca().yaxis.set_major_locator(MaxNLocator(3,integer=True))
plt.gca().yaxis.set_major_formatter(xfmt)

plt.legend(loc=0, handletextpad=0.1, frameon=False)

plt.subplot(212)
BorderPlot(powObj.xvec,da,color='darkslateblue',kind='std',ylim=[20,50],xlabel='Time (ms)',
           ylabel='Decoding accuracy (%)',xticks=[0,1500],linewidth=4,alpha=0.3)
rmaxis(plt.gca(), ['right', 'top'])
addLines(plt.gca(),vLines=[0,1500],vWidth=[1,1],hLines=[25],vShape=['-','-'],hWidth=[2])
plt.plot(powObj.xvec, 39.8*n.ones((len(powObj.xvec),1)), '--', color='dimgrey', linewidth=2, label='p<.05')
# plt.plot(time, daperm.max()*n.ones((len(time),1)), '--', color='dimgrey', linewidth=2, label='p<.05')
plt.legend(loc=2, handletextpad=0.1, frameon=False)

fig.savefig('C_rev-RH_elec73_power_alpha.png', dpi=300, bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ---
# ### Save the figure :

# %%
# from matplotlib.pylab import mpl

# mpl.rc("savefig", dpi=300)
# saveName=sujet+'-'+main+'_elec'+str(elec)+'_'+fcname+'_clf-'+clfObj.clf.shStr
# fig = plt.gcf()
# # fig.savefig(saveName+'.tif',bbox_inches='tight')

# # plt.show()

# %%
# da = timegeneralization(time, y, xPower.T, clf=0, cvtype='sss', clfArg={'kern':'rbf'})

# %%
# from brainpipe.vizualisation.classification_plot import timegeneralizationMap

# p1, p01, p001 = cs.binostat(y,(10e-3)/4489), cs.binostat(y,10e-4), cs.binostat(y,10e-5)


# cue = [(0,'Cue 1','w',1),(1500,'Cue 2','w',1)]
# pvalue=[(p1,'$p<10^{-6}$','lightsage')]#,(p01,'$p<10^{-4}$','darkorange'),(p001,'$p<10^{-5}$','r')]

# F = timegeneralizationMap(da[6::2,6::2],time=time[6::2],cmap='inferno',vmin=25,vmax=70,cue=cue,
#                           ticksize=27, figsize=(13,10), labelsize=30, 
#                           blurred=(p1,0.9), pvalue=pvalue)#,interp=(0.1,0.1))
# ax = plt.gca()
# ax.legend('')
# plt.show()

# %%
# saveName='TG_'+sujet+'-'+main+'_elec'+str(elec)+'_'+fcname+'_clf-'+clfObj.clf.shStr+'_'+str(width)+'r'+str(step)
# saveName = 'elec'+str(elec)+'_GT'
# F=plt.gcf()
# plt.savefig(saveName,bbox_inches='tight')
# F.savefig(saveName+'.png',bbox_inches='tight')
