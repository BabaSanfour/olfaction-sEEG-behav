# %% [markdown]
# ## Import Libraries

# %%
from os import path, makedirs
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MaxNLocator
import scipy.io as sio

from brainpipe.classification import *
from brainpipe.system import study
from brainpipe.feature import power, amplitude, sigfilt
from brainpipe.visual import *
from brainpipe.statistics import *
from scipy.stats import *

# %% [markdown]
# ## Power Decoding - Partial//Detailed Encoding
# ### For ALL time points

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import StratifiedKFold as SKFold
from sklearn.model_selection import permutation_test_score
from sklearn.metrics import roc_auc_score
from numpy.random import permutation

st = study('Olfacto')
exp = 'Enc'#'Enc'
conds, subjects = ['low','high'],['CHAF','VACJ','SEMC','LEFC','PIRJ','FERJ']
freqs = ['0_theta','1_alpha','2_beta','3_gamma']
path_pow = path.join(st.path, 'feature/TPSim_'+exp+'_By_Odor_By_Cond/TPS_by_odor/')
#path_pow = path.join(st.path, 'feature/TPSim_Enc_Ret_By_Odor_all/TPS_R_p_by_cond/TPS_R_p_by_cond/')
save_path = path.join(st.path, 'classified/Classif_TPSim_'+exp[0]+'_by_cond/')
#save_path = path.join(st.path, 'classified/Classif_TPSim_Enc_Ret_by_cond/')
nperm = 1000

for su in subjects:
    for freq in freqs:
        pow_list = []
        #=========================== Load Power files (nfreq, nelec, nwin, ntrial) =================================    
        mat0 = np.load(path.join(path_pow, 'TPS_spear_'+su+'_'+conds[0]+'_'+freq+'.npz'),
                       allow_pickle=True)
        pow_list.append(mat0['tps'])
        nelecs = mat0['tps'].shape[0]
        mat1 = np.load(path.join(path_pow, 'TPS_spear_'+su+'_'+conds[1]+'_'+freq+'.npz'),
                       allow_pickle=True)
        pow_list.append(mat1['tps'])
        print (su,mat0.files, 'TPS shape: ', [pow.shape for pow in pow_list])
        
        #=========================== Create dict for all results =================================    
        name_classif = (save_path+'/'+su +'_LDA_classif_'+freq+'_'+conds[0]+'_'+conds[1]+'.npz')
        if not path.exists(name_classif):
            kwargs = {}
            kwargs['names'], kwargs['channels'] = mat0['label'], mat0['channel']
            kwargs['xyz'] = mat0['xyz']

            # =========================== Select Power for 1 elec 1 freq =================================                 
            permut,auc = np.zeros((nelecs,nperm)),np.zeros((nelecs))
            for elec_num in range(nelecs):
                print('--» processing',su, 'elec', elec_num,'/',nelecs, 'freq',freq)
                pow_data_elec = [power[elec_num][:,np.newaxis] for power in pow_list]

                # create a data matrix, concatenate along the trial dimension
                x = np.concatenate(pow_data_elec, axis=0)
                print ('Size of the concatenated data: ', x.shape)
                y = np.hstack([np.array([i]*len(power)) for i, power in enumerate(pow_data_elec)])
                print ('Size of label for classif: ', len(y))

                clf = LDA()
                cv = SKFold(5)
                score, permutation_scores, pvalue = permutation_test_score(
                clf, x, y, scoring="roc_auc", cv=cv, n_permutations=nperm, n_jobs=-1)
                permut[elec_num] += permutation_scores
                auc[elec_num] += score
                print("Classification score %s (pvalue : %s)" % (score, pvalue))

            kwargs['perm'], kwargs['auc'] = permut, auc
            #Save plots
            np.savez(name_classif, **kwargs)
            del x, y, pow_data_elec, permutation_scores, score
        else:
            print(name_classif, 'already computed')
    del pow_list
# Out:
# -> Olfacto loaded
# CHAF ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(57, 72), (57, 180)]
# --» processing CHAF elec 0 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6773280423280423 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 1 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.529431216931217 (pvalue : 0.4355644355644356)
# --» processing CHAF elec 2 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5407936507936508 (pvalue : 0.3076923076923077)
# --» processing CHAF elec 3 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5253306878306878 (pvalue : 0.43956043956043955)
# --» processing CHAF elec 4 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6344179894179893 (pvalue : 0.002997002997002997)
# --» processing CHAF elec 5 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.48161375661375666 (pvalue : 0.5374625374625375)
# --» processing CHAF elec 6 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.2803174603174603 (pvalue : 1.0)
# --» processing CHAF elec 7 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6602513227513228 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 8 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6058730158730159 (pvalue : 0.01898101898101898)
# --» processing CHAF elec 9 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6359391534391534 (pvalue : 0.002997002997002997)
# --» processing CHAF elec 10 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.533994708994709 (pvalue : 0.33966033966033965)
# --» processing CHAF elec 11 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4167195767195767 (pvalue : 0.8871128871128872)
# --» processing CHAF elec 12 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4524074074074075 (pvalue : 0.7492507492507493)
# --» processing CHAF elec 13 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5435185185185185 (pvalue : 0.3196803196803197)
# --» processing CHAF elec 14 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6200396825396824 (pvalue : 0.005994005994005994)
# --» processing CHAF elec 15 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5886904761904763 (pvalue : 0.03996003996003996)
# --» processing CHAF elec 16 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4386772486772486 (pvalue : 0.8351648351648352)
# --» processing CHAF elec 17 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5781481481481482 (pvalue : 0.04295704295704296)
# --» processing CHAF elec 18 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4636507936507936 (pvalue : 0.6463536463536463)
# --» processing CHAF elec 19 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5430291005291006 (pvalue : 0.2937062937062937)
# --» processing CHAF elec 20 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.41542328042328036 (pvalue : 0.9140859140859141)
# --» processing CHAF elec 21 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4307010582010582 (pvalue : 0.8661338661338661)
# --» processing CHAF elec 22 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5451851851851852 (pvalue : 0.26373626373626374)
# --» processing CHAF elec 23 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5674735449735449 (pvalue : 0.11288711288711288)
# --» processing CHAF elec 24 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4511640211640212 (pvalue : 0.7312687312687313)
# --» processing CHAF elec 25 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.7029232804232803 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 26 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4093253968253968 (pvalue : 0.9470529470529471)
# --» processing CHAF elec 27 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.3666798941798942 (pvalue : 0.997002997002997)
# --» processing CHAF elec 28 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5636507936507937 (pvalue : 0.12987012987012986)
# --» processing CHAF elec 29 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4709126984126984 (pvalue : 0.6043956043956044)
# --» processing CHAF elec 30 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5732010582010582 (pvalue : 0.06893106893106893)
# --» processing CHAF elec 31 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5314550264550265 (pvalue : 0.42157842157842157)
# --» processing CHAF elec 32 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6111640211640212 (pvalue : 0.00999000999000999)
# --» processing CHAF elec 33 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5736904761904762 (pvalue : 0.07492507492507493)
# --» processing CHAF elec 34 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6296825396825396 (pvalue : 0.003996003996003996)
# --» processing CHAF elec 35 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6377777777777778 (pvalue : 0.001998001998001998)
# --» processing CHAF elec 36 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.36973544973544975 (pvalue : 0.991008991008991)
# --» processing CHAF elec 37 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5890211640211641 (pvalue : 0.03496503496503497)
# --» processing CHAF elec 38 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5791666666666667 (pvalue : 0.058941058941058944)
# --» processing CHAF elec 39 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4488756613756614 (pvalue : 0.6623376623376623)
# --» processing CHAF elec 40 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5492063492063493 (pvalue : 0.22077922077922077)
# --» processing CHAF elec 41 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4681878306878307 (pvalue : 0.5564435564435565)
# --» processing CHAF elec 42 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.371931216931217 (pvalue : 0.998001998001998)
# --» processing CHAF elec 43 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4412301587301587 (pvalue : 0.7902097902097902)
# --» processing CHAF elec 44 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5332142857142858 (pvalue : 0.4045954045954046)
# --» processing CHAF elec 45 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.34408730158730155 (pvalue : 0.9920079920079921)
# --» processing CHAF elec 46 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6094047619047618 (pvalue : 0.005994005994005994)
# --» processing CHAF elec 47 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.38912698412698415 (pvalue : 0.984015984015984)
# --» processing CHAF elec 48 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5920370370370371 (pvalue : 0.01998001998001998)
# --» processing CHAF elec 49 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5554100529100529 (pvalue : 0.18281718281718282)
# --» processing CHAF elec 50 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.40136243386243386 (pvalue : 0.9230769230769231)
# --» processing CHAF elec 51 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5406349206349206 (pvalue : 0.3116883116883117)
# --» processing CHAF elec 52 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5751851851851851 (pvalue : 0.06893106893106893)
# --» processing CHAF elec 53 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.3370899470899471 (pvalue : 0.995004995004995)
# --» processing CHAF elec 54 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5958068783068783 (pvalue : 0.015984015984015984)
# --» processing CHAF elec 55 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4358465608465609 (pvalue : 0.8291708291708292)
# --» processing CHAF elec 56 / 57 freq 0_theta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.43735449735449733 (pvalue : 0.7932067932067932)
# CHAF ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(57, 72), (57, 180)]
# --» processing CHAF elec 0 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4673809523809524 (pvalue : 0.5614385614385614)
# --» processing CHAF elec 1 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.574484126984127 (pvalue : 0.06593406593406594)
# --» processing CHAF elec 2 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5450132275132276 (pvalue : 0.2647352647352647)
# --» processing CHAF elec 3 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.3909391534391534 (pvalue : 0.983016983016983)
# --» processing CHAF elec 4 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.42558201058201056 (pvalue : 0.8761238761238761)
# --» processing CHAF elec 5 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5782142857142858 (pvalue : 0.06393606393606394)
# --» processing CHAF elec 6 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5726719576719577 (pvalue : 0.06993006993006994)
# --» processing CHAF elec 7 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4310449735449735 (pvalue : 0.8451548451548452)
# --» processing CHAF elec 8 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.642037037037037 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 9 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5852380952380953 (pvalue : 0.03196803196803197)
# --» processing CHAF elec 10 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6192328042328041 (pvalue : 0.007992007992007992)
# --» processing CHAF elec 11 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4693650793650794 (pvalue : 0.6113886113886113)
# --» processing CHAF elec 12 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4460449735449735 (pvalue : 0.7182817182817183)
# --» processing CHAF elec 13 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4530026455026455 (pvalue : 0.6943056943056943)
# --» processing CHAF elec 14 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4301719576719577 (pvalue : 0.8821178821178821)
# --» processing CHAF elec 15 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.3977116402116402 (pvalue : 0.9500499500499501)
# --» processing CHAF elec 16 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4332804232804233 (pvalue : 0.8531468531468531)
# --» processing CHAF elec 17 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6188095238095238 (pvalue : 0.001998001998001998)
# --» processing CHAF elec 18 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.37875661375661374 (pvalue : 0.988011988011988)
# --» processing CHAF elec 19 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.41839947089947094 (pvalue : 0.8721278721278721)
# --» processing CHAF elec 20 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4330026455026455 (pvalue : 0.8611388611388612)
# --» processing CHAF elec 21 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4428306878306879 (pvalue : 0.7892107892107892)
# --» processing CHAF elec 22 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4626719576719577 (pvalue : 0.6483516483516484)
# --» processing CHAF elec 23 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.41420634920634924 (pvalue : 0.9410589410589411)
# --» processing CHAF elec 24 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5608730158730159 (pvalue : 0.1258741258741259)
# --» processing CHAF elec 25 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5378174603174602 (pvalue : 0.34765234765234765)
# --» processing CHAF elec 26 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4376851851851852 (pvalue : 0.8531468531468531)
# --» processing CHAF elec 27 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6314550264550264 (pvalue : 0.002997002997002997)
# --» processing CHAF elec 28 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.39417989417989424 (pvalue : 0.971028971028971)
# --» processing CHAF elec 29 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.46994708994708995 (pvalue : 0.6173826173826173)
# --» processing CHAF elec 30 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6363624338624339 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 31 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.468558201058201 (pvalue : 0.6143856143856143)
# --» processing CHAF elec 32 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.35298941798941796 (pvalue : 0.999000999000999)
# --» processing CHAF elec 33 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.41575396825396826 (pvalue : 0.9170829170829171)
# --» processing CHAF elec 34 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.447420634920635 (pvalue : 0.8121878121878122)
# --» processing CHAF elec 35 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5800793650793651 (pvalue : 0.052947052947052944)
# --» processing CHAF elec 36 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5817724867724868 (pvalue : 0.03596403596403597)
# --» processing CHAF elec 37 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.46302910052910046 (pvalue : 0.6753246753246753)
# --» processing CHAF elec 38 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5911243386243387 (pvalue : 0.025974025974025976)
# --» processing CHAF elec 39 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5833465608465608 (pvalue : 0.03496503496503497)
# --» processing CHAF elec 40 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5892989417989417 (pvalue : 0.026973026973026972)
# --» processing CHAF elec 41 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4339814814814814 (pvalue : 0.8551448551448552)
# --» processing CHAF elec 42 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4 (pvalue : 0.9090909090909091)
# --» processing CHAF elec 43 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.36187830687830685 (pvalue : 0.973026973026973)
# --» processing CHAF elec 44 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4098544973544974 (pvalue : 0.9370629370629371)
# --» processing CHAF elec 45 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5367724867724868 (pvalue : 0.35764235764235763)
# --» processing CHAF elec 46 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6196693121693121 (pvalue : 0.007992007992007992)
# --» processing CHAF elec 47 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.3748015873015873 (pvalue : 0.989010989010989)
# --» processing CHAF elec 48 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.45194444444444437 (pvalue : 0.7342657342657343)
# --» processing CHAF elec 49 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4565740740740741 (pvalue : 0.7552447552447552)
# --» processing CHAF elec 50 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5621825396825397 (pvalue : 0.12987012987012986)
# --» processing CHAF elec 51 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5892328042328042 (pvalue : 0.03896103896103896)
# --» processing CHAF elec 52 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6337962962962963 (pvalue : 0.001998001998001998)
# --» processing CHAF elec 53 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.26252645502645505 (pvalue : 1.0)
# --» processing CHAF elec 54 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5852380952380952 (pvalue : 0.04195804195804196)
# --» processing CHAF elec 55 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.45591269841269844 (pvalue : 0.6653346653346653)
# --» processing CHAF elec 56 / 57 freq 1_alpha
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.641468253968254 (pvalue : 0.002997002997002997)
# CHAF ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(57, 72), (57, 180)]
# --» processing CHAF elec 0 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.541058201058201 (pvalue : 0.2997002997002997)
# --» processing CHAF elec 1 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5880291005291006 (pvalue : 0.026973026973026972)
# --» processing CHAF elec 2 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5777645502645503 (pvalue : 0.06693306693306693)
# --» processing CHAF elec 3 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4420238095238095 (pvalue : 0.7922077922077922)
# --» processing CHAF elec 4 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.46264550264550264 (pvalue : 0.6633366633366633)
# --» processing CHAF elec 5 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.728452380952381 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 6 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5716534391534391 (pvalue : 0.11188811188811189)
# --» processing CHAF elec 7 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6480687830687831 (pvalue : 0.002997002997002997)
# --» processing CHAF elec 8 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4178439153439154 (pvalue : 0.8641358641358642)
# --» processing CHAF elec 9 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6032936507936508 (pvalue : 0.013986013986013986)
# --» processing CHAF elec 10 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5272619047619047 (pvalue : 0.43656343656343655)
# --» processing CHAF elec 11 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5999603174603175 (pvalue : 0.014985014985014986)
# --» processing CHAF elec 12 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4943253968253968 (pvalue : 0.5204795204795205)
# --» processing CHAF elec 13 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.44078042328042333 (pvalue : 0.7972027972027972)
# --» processing CHAF elec 14 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.3878439153439153 (pvalue : 0.971028971028971)
# --» processing CHAF elec 15 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5676455026455027 (pvalue : 0.0989010989010989)
# --» processing CHAF elec 16 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6863359788359787 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 17 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6098280423280423 (pvalue : 0.00999000999000999)
# --» processing CHAF elec 18 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4446296296296296 (pvalue : 0.7562437562437563)
# --» processing CHAF elec 19 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.7444973544973544 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 20 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5226322751322752 (pvalue : 0.4805194805194805)
# --» processing CHAF elec 21 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5868783068783069 (pvalue : 0.04295704295704296)
# --» processing CHAF elec 22 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5401719576719577 (pvalue : 0.32667332667332666)
# --» processing CHAF elec 23 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5520238095238096 (pvalue : 0.1918081918081918)
# --» processing CHAF elec 24 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.43169312169312174 (pvalue : 0.8531468531468531)
# --» processing CHAF elec 25 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6147089947089948 (pvalue : 0.006993006993006993)
# --» processing CHAF elec 26 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4348015873015873 (pvalue : 0.8331668331668332)
# --» processing CHAF elec 27 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5230687830687831 (pvalue : 0.43956043956043955)
# --» processing CHAF elec 28 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.36538359788359787 (pvalue : 0.998001998001998)
# --» processing CHAF elec 29 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5935978835978837 (pvalue : 0.03196803196803197)
# --» processing CHAF elec 30 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5643121693121694 (pvalue : 0.11788211788211789)
# --» processing CHAF elec 31 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.553941798941799 (pvalue : 0.22577422577422576)
# --» processing CHAF elec 32 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5652645502645502 (pvalue : 0.11788211788211789)
# --» processing CHAF elec 33 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.538968253968254 (pvalue : 0.3036963036963037)
# --» processing CHAF elec 34 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5262566137566138 (pvalue : 0.42157842157842157)
# --» processing CHAF elec 35 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.550026455026455 (pvalue : 0.22077922077922077)
# --» processing CHAF elec 36 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5549867724867724 (pvalue : 0.16383616383616384)
# --» processing CHAF elec 37 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.32636243386243385 (pvalue : 1.0)
# --» processing CHAF elec 38 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5796560846560845 (pvalue : 0.07092907092907093)
# --» processing CHAF elec 39 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6284656084656085 (pvalue : 0.006993006993006993)
# --» processing CHAF elec 40 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.38849206349206356 (pvalue : 0.9630369630369631)
# --» processing CHAF elec 41 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5736640211640213 (pvalue : 0.1028971028971029)
# --» processing CHAF elec 42 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5485449735449736 (pvalue : 0.25074925074925075)
# --» processing CHAF elec 43 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5533333333333333 (pvalue : 0.22877122877122877)
# --» processing CHAF elec 44 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5273941798941799 (pvalue : 0.4745254745254745)
# --» processing CHAF elec 45 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5449074074074074 (pvalue : 0.2757242757242757)
# --» processing CHAF elec 46 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.668068783068783 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 47 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5384656084656084 (pvalue : 0.3246753246753247)
# --» processing CHAF elec 48 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4419444444444444 (pvalue : 0.7832167832167832)
# --» processing CHAF elec 49 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5771693121693122 (pvalue : 0.06493506493506493)
# --» processing CHAF elec 50 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5496164021164021 (pvalue : 0.20279720279720279)
# --» processing CHAF elec 51 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.563042328042328 (pvalue : 0.13086913086913088)
# --» processing CHAF elec 52 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6102910052910053 (pvalue : 0.011988011988011988)
# --» processing CHAF elec 53 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.2958862433862434 (pvalue : 1.0)
# --» processing CHAF elec 54 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.481468253968254 (pvalue : 0.5534465534465535)
# --» processing CHAF elec 55 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5398148148148149 (pvalue : 0.32367632367632365)
# --» processing CHAF elec 56 / 57 freq 2_beta
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.47239417989417987 (pvalue : 0.5464535464535465)
# CHAF ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(57, 72), (57, 180)]
# --» processing CHAF elec 0 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5533730158730158 (pvalue : 0.1928071928071928)
# --» processing CHAF elec 1 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4095502645502645 (pvalue : 0.9470529470529471)
# --» processing CHAF elec 2 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.30437830687830686 (pvalue : 1.0)
# --» processing CHAF elec 3 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5774074074074074 (pvalue : 0.06493506493506493)
# --» processing CHAF elec 4 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5902910052910053 (pvalue : 0.030969030969030968)
# --» processing CHAF elec 5 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.40484126984126984 (pvalue : 0.971028971028971)
# --» processing CHAF elec 6 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.3882936507936508 (pvalue : 0.988011988011988)
# --» processing CHAF elec 7 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6337433862433862 (pvalue : 0.001998001998001998)
# --» processing CHAF elec 8 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5853703703703703 (pvalue : 0.055944055944055944)
# --» processing CHAF elec 9 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6542592592592593 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 10 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5605158730158729 (pvalue : 0.17682317682317683)
# --» processing CHAF elec 11 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6427116402116402 (pvalue : 0.002997002997002997)
# --» processing CHAF elec 12 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6201984126984128 (pvalue : 0.003996003996003996)
# --» processing CHAF elec 13 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.3603306878306879 (pvalue : 0.999000999000999)
# --» processing CHAF elec 14 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.35952380952380947 (pvalue : 0.996003996003996)
# --» processing CHAF elec 15 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.448478835978836 (pvalue : 0.7592407592407593)
# --» processing CHAF elec 16 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5498412698412698 (pvalue : 0.2047952047952048)
# --» processing CHAF elec 17 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.38621693121693124 (pvalue : 0.973026973026973)
# --» processing CHAF elec 18 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5800661375661376 (pvalue : 0.057942057942057944)
# --» processing CHAF elec 19 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5930952380952381 (pvalue : 0.02197802197802198)
# --» processing CHAF elec 20 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5806216931216931 (pvalue : 0.059940059940059943)
# --» processing CHAF elec 21 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.41111111111111115 (pvalue : 0.9330669330669331)
# --» processing CHAF elec 22 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.2430026455026455 (pvalue : 1.0)
# --» processing CHAF elec 23 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6182142857142857 (pvalue : 0.003996003996003996)
# --» processing CHAF elec 24 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4137698412698413 (pvalue : 0.8601398601398601)
# --» processing CHAF elec 25 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5276719576719577 (pvalue : 0.4225774225774226)
# --» processing CHAF elec 26 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4148015873015873 (pvalue : 0.939060939060939)
# --» processing CHAF elec 27 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.3292328042328042 (pvalue : 1.0)
# --» processing CHAF elec 28 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5646031746031746 (pvalue : 0.12087912087912088)
# --» processing CHAF elec 29 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5348148148148149 (pvalue : 0.37662337662337664)
# --» processing CHAF elec 30 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5790079365079365 (pvalue : 0.06593406593406594)
# --» processing CHAF elec 31 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6066269841269841 (pvalue : 0.00999000999000999)
# --» processing CHAF elec 32 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5278306878306879 (pvalue : 0.42957042957042957)
# --» processing CHAF elec 33 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4609259259259259 (pvalue : 0.6493506493506493)
# --» processing CHAF elec 34 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.7015873015873016 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 35 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6016534391534392 (pvalue : 0.016983016983016984)
# --» processing CHAF elec 36 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.7074999999999999 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 37 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6192857142857143 (pvalue : 0.004995004995004995)
# --» processing CHAF elec 38 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5931613756613757 (pvalue : 0.02097902097902098)
# --» processing CHAF elec 39 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5555291005291005 (pvalue : 0.1938061938061938)
# --» processing CHAF elec 40 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.3444179894179894 (pvalue : 0.999000999000999)
# --» processing CHAF elec 41 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5496825396825397 (pvalue : 0.21578421578421578)
# --» processing CHAF elec 42 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5565740740740741 (pvalue : 0.15184815184815184)
# --» processing CHAF elec 43 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.576058201058201 (pvalue : 0.059940059940059943)
# --» processing CHAF elec 44 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.3933730158730159 (pvalue : 0.942057942057942)
# --» processing CHAF elec 45 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.6003306878306878 (pvalue : 0.012987012987012988)
# --» processing CHAF elec 46 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5830952380952381 (pvalue : 0.04495504495504495)
# --» processing CHAF elec 47 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4435449735449735 (pvalue : 0.8331668331668332)
# --» processing CHAF elec 48 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4450793650793651 (pvalue : 0.7812187812187812)
# --» processing CHAF elec 49 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.39055555555555554 (pvalue : 0.965034965034965)
# --» processing CHAF elec 50 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.4470502645502645 (pvalue : 0.6843156843156843)
# --» processing CHAF elec 51 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.27022486772486765 (pvalue : 1.0)
# --» processing CHAF elec 52 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5941402116402117 (pvalue : 0.028971028971028972)
# --» processing CHAF elec 53 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5676984126984126 (pvalue : 0.08191808191808192)
# --» processing CHAF elec 54 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.5442195767195768 (pvalue : 0.2937062937062937)
# --» processing CHAF elec 55 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.8372222222222222 (pvalue : 0.000999000999000999)
# --» processing CHAF elec 56 / 57 freq 3_gamma
# Size of the concatenated data:  (252, 1)
# Size of label for classif:  252
# Classification score 0.674021164021164 (pvalue : 0.000999000999000999)
# VACJ ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(48, 132), (48, 132)]
# --» processing VACJ elec 0 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.38130352026363423 (pvalue : 0.995004995004995)
# --» processing VACJ elec 1 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.6036048814538842 (pvalue : 0.003996003996003996)
# --» processing VACJ elec 2 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.4381760294153456 (pvalue : 0.8411588411588412)
# --» processing VACJ elec 3 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.423746966339559 (pvalue : 0.7952047952047953)
# --» processing VACJ elec 4 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.40434026509525084 (pvalue : 0.997002997002997)
# --» processing VACJ elec 5 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.6214969846023977 (pvalue : 0.000999000999000999)
# --» processing VACJ elec 6 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.5907017800180194 (pvalue : 0.028971028971028972)
# --» processing VACJ elec 7 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.5536742802412318 (pvalue : 0.12687312687312688)
# --» processing VACJ elec 8 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.5729032231881235 (pvalue : 0.07792207792207792)
# --» processing VACJ elec 9 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.6284441684726586 (pvalue : 0.000999000999000999)
# --» processing VACJ elec 10 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.47080340256978437 (pvalue : 0.6323676323676324)
# --» processing VACJ elec 11 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.5629471351693573 (pvalue : 0.08791208791208792)
# --» processing VACJ elec 12 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.5687652697624207 (pvalue : 0.056943056943056944)
# --» processing VACJ elec 13 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.4341040251296661 (pvalue : 0.8741258741258742)
# --» processing VACJ elec 14 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.337956469509176 (pvalue : 1.0)
# --» processing VACJ elec 15 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.5884164901258918 (pvalue : 0.028971028971028972)
# --» processing VACJ elec 16 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.38029196191589354 (pvalue : 0.99000999000999)
# --» processing VACJ elec 17 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.4103590879944156 (pvalue : 0.936063936063936)
# --» processing VACJ elec 18 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.7520208845707421 (pvalue : 0.000999000999000999)
# --» processing VACJ elec 19 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.4880019236856844 (pvalue : 0.5444555444555444)
# --» processing VACJ elec 20 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.5523325703525133 (pvalue : 0.15984015984015984)
# --» processing VACJ elec 21 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.29571675554581534 (pvalue : 1.0)
# --» processing VACJ elec 22 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.6193105169600897 (pvalue : 0.003996003996003996)
# --» processing VACJ elec 23 / 48 freq 0_theta
# Size of the concatenated data:  (264, 1)
# Size of label for classif:  264
# Classification score 0.4454101427748151 (pvalue : 0.8311688311688312)
# ...
# Size of label for classif:  372
# Classification score 0.5351386896221904 (pvalue : 0.21478521478521478)
# --» processing FERJ elec 6 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.4545564323290292 (pvalue : 0.7562437562437563)
# --» processing FERJ elec 7 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.4319718707882266 (pvalue : 0.9230769230769231)
# --» processing FERJ elec 8 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6361661449502196 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 9 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.44915123255510625 (pvalue : 0.8511488511488512)
# --» processing FERJ elec 10 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5901631450806487 (pvalue : 0.002997002997002997)
# --» processing FERJ elec 11 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6788077692274249 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 12 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.575963979826964 (pvalue : 0.012987012987012988)
# --» processing FERJ elec 13 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.4056091039520021 (pvalue : 0.988011988011988)
# --» processing FERJ elec 14 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.43923731576887964 (pvalue : 0.903096903096903)
# --» processing FERJ elec 15 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6264555888874397 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 16 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.3822004478066171 (pvalue : 1.0)
# --» processing FERJ elec 17 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5355513890700405 (pvalue : 0.22877122877122877)
# --» processing FERJ elec 18 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.44776977087952696 (pvalue : 0.8081918081918081)
# --» processing FERJ elec 19 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5735988652667274 (pvalue : 0.014985014985014986)
# --» processing FERJ elec 20 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5504534585452807 (pvalue : 0.08891108891108891)
# --» processing FERJ elec 21 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5506813834181122 (pvalue : 0.09490509490509491)
# --» processing FERJ elec 22 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.4558581148645711 (pvalue : 0.7732267732267732)
# --» processing FERJ elec 23 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.39329496543628545 (pvalue : 0.955044955044955)
# --» processing FERJ elec 24 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5967466631885571 (pvalue : 0.002997002997002997)
# --» processing FERJ elec 25 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.45405982348593543 (pvalue : 0.6893106893106893)
# --» processing FERJ elec 26 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5357906177992261 (pvalue : 0.2547452547452547)
# --» processing FERJ elec 27 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6520999086996216 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 28 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5816493848093562 (pvalue : 0.008991008991008992)
# --» processing FERJ elec 29 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6117653580279118 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 30 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5860381070388243 (pvalue : 0.003996003996003996)
# --» processing FERJ elec 31 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.4355871483848528 (pvalue : 0.929070929070929)
# --» processing FERJ elec 32 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5469287204904135 (pvalue : 0.12387612387612387)
# --» processing FERJ elec 33 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5553436807095343 (pvalue : 0.07592407592407592)
# --» processing FERJ elec 34 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.36159406112777703 (pvalue : 1.0)
# --» processing FERJ elec 35 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5713435285422372 (pvalue : 0.022977022977022976)
# --» processing FERJ elec 36 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6088448328333551 (pvalue : 0.001998001998001998)
# --» processing FERJ elec 37 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6120506717099257 (pvalue : 0.001998001998001998)
# --» processing FERJ elec 38 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6999617407938785 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 39 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5493894830659537 (pvalue : 0.08891108891108891)
# --» processing FERJ elec 40 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.568247032737707 (pvalue : 0.024975024975024976)
# --» processing FERJ elec 41 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.42726457545324115 (pvalue : 0.9600399600399601)
# --» processing FERJ elec 42 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5397214251554281 (pvalue : 0.1878121878121878)
# --» processing FERJ elec 43 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.39412699447850097 (pvalue : 0.999000999000999)
# --» processing FERJ elec 44 / 45 freq 2_beta
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6155282379026998 (pvalue : 0.000999000999000999)
# FERJ ['tps', 'pval', 'label', 'channel', 'xyz'] TPS shape:  [(45, 204), (45, 168)]
# --» processing FERJ elec 0 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.3521933828963958 (pvalue : 1.0)
# --» processing FERJ elec 1 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.4365998217468806 (pvalue : 0.906093906093906)
# --» processing FERJ elec 2 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.2791300378244424 (pvalue : 1.0)
# --» processing FERJ elec 3 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5911845137167949 (pvalue : 0.004995004995004995)
# --» processing FERJ elec 4 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.34772825094561105 (pvalue : 1.0)
# --» processing FERJ elec 5 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5201831442111213 (pvalue : 0.43356643356643354)
# --» processing FERJ elec 6 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.40952578148776136 (pvalue : 0.989010989010989)
# --» processing FERJ elec 7 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5796572975088039 (pvalue : 0.00999000999000999)
# --» processing FERJ elec 8 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5631734489804792 (pvalue : 0.028971028971028972)
# --» processing FERJ elec 9 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5799455458458328 (pvalue : 0.00999000999000999)
# --» processing FERJ elec 10 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5232493152471632 (pvalue : 0.4165834165834166)
# --» processing FERJ elec 11 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.4375524977174905 (pvalue : 0.8951048951048951)
# --» processing FERJ elec 12 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.3749698926133646 (pvalue : 0.998001998001998)
# --» processing FERJ elec 13 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.369738815703665 (pvalue : 0.999000999000999)
# --» processing FERJ elec 14 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.44300139124385896 (pvalue : 0.9010989010989011)
# --» processing FERJ elec 15 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6429184600669535 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 16 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5450779313942873 (pvalue : 0.13186813186813187)
# --» processing FERJ elec 17 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6244944785009348 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 18 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.41499000043476375 (pvalue : 0.991008991008991)
# --» processing FERJ elec 19 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5702530324768488 (pvalue : 0.028971028971028972)
# --» processing FERJ elec 20 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5413112473370723 (pvalue : 0.17582417582417584)
# --» processing FERJ elec 21 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.4069750228250946 (pvalue : 0.972027972027972)
# --» processing FERJ elec 22 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.33854854136776663 (pvalue : 1.0)
# --» processing FERJ elec 23 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6370579540019999 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 24 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5522493587235338 (pvalue : 0.11788211788211789)
# --» processing FERJ elec 25 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5802239033085518 (pvalue : 0.006993006993006993)
# --» processing FERJ elec 26 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5405553019433937 (pvalue : 0.16583416583416583)
# --» processing FERJ elec 27 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.7239384157210557 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 28 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5519615451502109 (pvalue : 0.0939060939060939)
# --» processing FERJ elec 29 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5290189556975784 (pvalue : 0.3036963036963037)
# --» processing FERJ elec 30 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.3965673231598626 (pvalue : 0.995004995004995)
# --» processing FERJ elec 31 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6359623494630668 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 32 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5887388591800357 (pvalue : 0.003996003996003996)
# --» processing FERJ elec 33 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.424929785661493 (pvalue : 0.971028971028971)
# --» processing FERJ elec 34 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5604948697882701 (pvalue : 0.04195804195804196)
# --» processing FERJ elec 35 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.4486382113821138 (pvalue : 0.8581418581418582)
# --» processing FERJ elec 36 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.4786315812355985 (pvalue : 0.5804195804195804)
# --» processing FERJ elec 37 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.3736978827007521 (pvalue : 1.0)
# --» processing FERJ elec 38 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5352527064040693 (pvalue : 0.24075924075924077)
# --» processing FERJ elec 39 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5910699534802835 (pvalue : 0.003996003996003996)
# --» processing FERJ elec 40 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.5619665449328289 (pvalue : 0.04595404595404595)
# --» processing FERJ elec 41 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.40402004260684315 (pvalue : 0.955044955044955)
# --» processing FERJ elec 42 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.4942136211469067 (pvalue : 0.5734265734265734)
# --» processing FERJ elec 43 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.6980541063432024 (pvalue : 0.000999000999000999)
# --» processing FERJ elec 44 / 45 freq 3_gamma
# Size of the concatenated data:  (372, 1)
# Size of label for classif:  372
# Classification score 0.569281661666884 (pvalue : 0.025974025974025976)
