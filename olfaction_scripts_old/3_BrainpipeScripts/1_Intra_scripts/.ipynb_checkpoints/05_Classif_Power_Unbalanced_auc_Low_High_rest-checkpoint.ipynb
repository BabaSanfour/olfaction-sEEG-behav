# %% [markdown]
# ## Import Libraries

# %%
from os import path
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MaxNLocator
import scipy.io as sio

from brainpipe.classification import *
from brainpipe.system import study
from brainpipe.feature import power, amplitude, sigfilt
from brainpipe.visual import *
from brainpipe.statistics import *
from scipy.stats import *

# %% [markdown]
# ## Power Decoding - Partial//Detailed Encoding
# ### For ALL time points

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import StratifiedKFold as SKFold
from sklearn.metrics import roc_auc_score
from numpy.random import permutation

conds,phases, subjects = ['low','high'],['odor'],['SEMC','VACJ','FERJ','LEFC','PIRJ','CHAF']#,'MICP','VACJ','SEMC','LEFC','PIRJ']
color_codes = ['darkorange','blue']
st = study('Olfacto')
freqs = 7
nperm = 1000

for su,phase in product(subjects,phases):
    path_pow = path.join(st.path, 'feature/TPSim_Enc_Ret_By_Odor/TPS_R_p_by_cond/')
    save_path = path.join(st.path, 'classified/Classif_TPSim_Encoding_Retrieval_Odor_1000perm/')

    pow_list = []
    #=========================== Load Power files (nfreq, nelec, nwin, ntrial) =================================    
    mat0 = np.load(path.join(path_pow, su+'_'+phase+'_'+conds[0]+'_bipo_sel_physFT_pow'+bsl+'.npz'))
    names, channels, freq_names, time = mat0['Mai_RL'], mat0['channels'],mat0['fname'], mat0['time']
    #print(mat0['xpow'].shape,time.shape,time[17:42])
    pow_list.append(mat0['xpow'][:,:,18,:][:,:,np.newaxis,:])
    nelecs = mat0['xpow'].shape[1]
    mat1 = np.load(path.join(path_pow, su+'_'+phase+'_'+conds[1]+'_bipo_sel_physFT_pow'+bsl+'.npz'))
    pow_list.append(mat1['xpow'][:,:,18,:][:,:,np.newaxis,:])
    print (su, 'power shape: ', [pow.shape for pow in pow_list])
    # =========================== Select Power for 1 elec 1 freq =================================                 
    iterator = range(nelecs)
    for elec_num in iterator:
        for freq in range(2,freqs):
            elec, elec_label, freq_name = channels[elec_num], names[elec_num], freq_names[freq]
            print ('elec ', elec, 'elec_label ', elec_label)
            #Filenames to save
            name_auc = (save_path+str(freq)+'_'+freq_name+'/auc/'+su +'_auc_'+conds[0]+'_'+conds[1]+'_'+str(elec_label)+'_('+str(elec_num)+').npy')
            name_perm = (save_path+str(freq)+'_'+freq_name+'/auc/'+su +'_perm_'+str(elec_label)+'_('+str(elec_num)+').npy')
                        
            if path.exists(name_auc):
                print(su,bsl,phase,elec_num,freq,'already computed')
            else:
                print('--» processing',su, 'elec', elec_num,'/',nelecs, 'freq',freq)
                pow_data_elec = []
                for i,power in enumerate(pow_list):
                    pow_data_elec.append(power[freq,elec_num].swapaxes(0,1))
                nwin = power.shape[1]

        # =============================  Classification Computation ============================================================           
                # create a data matrix, concatenate along the trial dimension
                x = np.concatenate(pow_data_elec, axis=0)
                print ('Size of the concatenated data: ', x.shape, 'Number time windows : ', x.shape[1])
                y = np.hstack([np.array([i]*len(power)) for i, power in enumerate(pow_data_elec)])
                print ('Size of label for classif: ', len(y))

                auc = np.array([])
                for t in range(x.shape[1]):
                    X = x[:,t]
                    X = X.reshape(-1, 1)
                    score_rep = []
                    for i in range(10):
                        k = 5
                        skf = SKFold(n_splits=k, random_state=None, shuffle=True)
                        skf.get_n_splits(X, y)
                        score_cv = []
                        for train_index, test_index in skf.split(X, y):
                            clf = LDA()
                            X_train, X_test = X[train_index], X[test_index]
                            y_train, y_test = y[train_index], y[test_index]
                            clf.fit(X=X_train, y=y_train)
                            y_pred = clf.predict(X_test)
                            score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                        score_rep.append(np.mean(score_cv))
                    score_rep = np.asarray(score_rep).reshape(1,len(score_rep))
                    auc = np.vstack((auc, score_rep)) if np.size(auc) else score_rep
                auc = np.swapaxes(auc,0,1)

                perm_scores = np.array([])
                for t in range(x.shape[1]):
                    X = x[:,t]
                    X = X.reshape(-1, 1)
                    perm_rep = []
                    for perm in range(nperm):
                        y_perm = y[permutation(len(y))]
                        score_cv = []
                        for train_index, test_index in skf.split(X, y_perm):
                            clf = LDA()
                            X_train, X_test = X[train_index], X[test_index]
                            y_train, y_test = y_perm[train_index], y_perm[test_index]
                            clf.fit(X=X_train, y=y_train)
                            y_pred = clf.predict(X_test)
                            score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                        perm_rep.append(np.mean(score_cv))
                    perm_rep = np.asarray(perm_rep).reshape(1,len(perm_rep))
                    perm_scores = np.vstack((perm_scores, perm_rep)) if np.size(perm_scores) else perm_rep
                perm_scores = np.swapaxes(perm_scores,0,1)           
                th_0_05_perm = perm_pvalue2level(perm_scores, p=0.01, maxst=True)
                th_0_01_perm = perm_pvalue2level(perm_scores, p=0.001, maxst=True)
                print('th_perm 005: ', th_0_05_perm[0], '001',th_0_01_perm[0], 'auc_max', np.max(auc))

        # ============================== PLOT POWER ANALYSIS + STATS & DECODING ACCURACY ===================================================
#                 # plot and figure parameters
#                 xfmt = ScalarFormatter(useMathText=True)
#                 xfmt.set_powerlimits((0,3))
#                 fig = plt.figure(1,figsize=(7,7))
#                 title = 'Power-Stats-DA for '+su+' '+conds[0]+' vs '+conds[1]+' '+str(elec)+' '+str(elec_label)+' ('+str(elec_num)+')'
#                 fig.suptitle(title, fontsize=12)

#                 # Plot the POW + STATS
#                 plt.subplot(211)        
#                 BorderPlot(time, x, y=y, kind='sem', alpha=0.2, color=color_codes,linewidth=2, 
#                            ncol=1, xlabel='Time (s)',ylabel = r'Power', legend=conds)
#                 rmaxis(plt.gca(), ['right', 'top'])
#                 addLines(plt.gca(), vLines=[0], vColor=['darkgray'], vWidth=[2])
#                 plt.legend(loc=0, handletextpad=0.1, frameon=False)
#                 plt.gca().yaxis.set_major_locator(MaxNLocator(3,integer=True))

#                 # Plot DA for the POW
#                 plt.subplot(212)
#                 BorderPlot(time, auc, color='b', kind='sd',xlabel='Time (s)', ylim=[0.4,1.], ylabel='Decoding accuracy (%)',linewidth=2, alpha=0.3)
#                 rmaxis(plt.gca(), ['right', 'top'])
#                 addLines(plt.gca(), vLines=[0], vColor=['darkgray'], vWidth=[2])
#                 plt.gca().yaxis.set_major_locator(MaxNLocator(3,integer=True))
#                 plt.plot(time, th_0_05_perm*np.ones(len(time)), '--', color='r', linewidth=2)
#                 #plt.plot(times_plot, th_0_01_perm*np.ones(len(times_plot)), '--', color='orange', linewidth=2)

                #Save plots
                np.save(name_auc, auc)
                np.save(name_perm, perm_scores)
#                 plt.savefig(plot_name, dpi=300, bbox_inches='tight')
#                 plt.clf()
#                 plt.close() 
                del X, auc, pow_data_elec
    del pow_list
# Out:
# -> Olfacto loaded
# SEMC power shape:  [(7, 65, 1, 32), (7, 65, 1, 9)]
# elec  b2-b1 elec_label  HC
# --» processing SEMC elec 0 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.652380952381 auc_max 0.5
# elec  b2-b1 elec_label  HC
# --» processing SEMC elec 0 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.7 auc_max 0.5
# elec  b2-b1 elec_label  HC
# --» processing SEMC elec 0 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.719047619048 auc_max 0.5
# elec  b2-b1 elec_label  HC
# --» processing SEMC elec 0 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.716666666667 auc_max 0.571428571429
# elec  b2-b1 elec_label  HC
# --» processing SEMC elec 0 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.821428571429 auc_max 0.704761904762
# elec  b3-b2 elec_label  HC
# --» processing SEMC elec 1 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.783333333333 auc_max 0.5
# elec  b3-b2 elec_label  HC
# --» processing SEMC elec 1 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.604761904762 001 0.685714285714 auc_max 0.5
# elec  b3-b2 elec_label  HC
# --» processing SEMC elec 1 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.635714285714 001 0.735714285714 auc_max 0.683333333333
# elec  b3-b2 elec_label  HC
# --» processing SEMC elec 1 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.783333333333 auc_max 0.5
# elec  b3-b2 elec_label  HC
# --» processing SEMC elec 1 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.685714285714 auc_max 0.5
# elec  b4-b3 elec_label  HC
# --» processing SEMC elec 2 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.783333333333 auc_max 0.5
# elec  b4-b3 elec_label  HC
# --» processing SEMC elec 2 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.769047619048 auc_max 0.5
# elec  b4-b3 elec_label  HC
# --» processing SEMC elec 2 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.769047619048 auc_max 0.685714285714
# elec  b4-b3 elec_label  HC
# --» processing SEMC elec 2 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.590476190476 001 0.766666666667 auc_max 0.6
# elec  b4-b3 elec_label  HC
# --» processing SEMC elec 2 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.733333333333 auc_max 0.5
# elec  b5-b4 elec_label  HC
# --» processing SEMC elec 3 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.685714285714 auc_max 0.5
# elec  b5-b4 elec_label  HC
# --» processing SEMC elec 3 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.75 auc_max 0.5
# elec  b5-b4 elec_label  HC
# --» processing SEMC elec 3 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.75 auc_max 0.5
# elec  b5-b4 elec_label  HC
# --» processing SEMC elec 3 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.685714285714 auc_max 0.583333333333
# elec  b5-b4 elec_label  HC
# --» processing SEMC elec 3 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.716666666667 auc_max 0.485714285714
# elec  b6-b5 elec_label  PHG
# --» processing SEMC elec 4 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.621428571429 001 0.7 auc_max 0.5
# elec  b6-b5 elec_label  PHG
# --» processing SEMC elec 4 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.735714285714 auc_max 0.5
# elec  b6-b5 elec_label  PHG
# --» processing SEMC elec 4 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.685714285714 auc_max 0.5
# elec  b6-b5 elec_label  PHG
# --» processing SEMC elec 4 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.604761904762 001 0.683333333333 auc_max 0.5
# elec  b6-b5 elec_label  PHG
# --» processing SEMC elec 4 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.721428571429 auc_max 0.635714285714
# elec  b12-b11 elec_label  MTG
# --» processing SEMC elec 5 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.65 auc_max 0.5
# elec  b12-b11 elec_label  MTG
# --» processing SEMC elec 5 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.7 auc_max 0.5
# elec  b12-b11 elec_label  MTG
# --» processing SEMC elec 5 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.783333333333 auc_max 0.5
# elec  b12-b11 elec_label  MTG
# --» processing SEMC elec 5 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.669047619048 001 0.735714285714 auc_max 0.55
# elec  b12-b11 elec_label  MTG
# --» processing SEMC elec 5 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.683333333333 auc_max 0.55
# elec  e2-e1 elec_label  Ins
# --» processing SEMC elec 6 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.785714285714 auc_max 0.55
# elec  e2-e1 elec_label  Ins
# --» processing SEMC elec 6 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.552380952381 001 0.669047619048 auc_max 0.5
# elec  e2-e1 elec_label  Ins
# --» processing SEMC elec 6 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.621428571429 001 0.7 auc_max 0.5
# elec  e2-e1 elec_label  Ins
# --» processing SEMC elec 6 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.704761904762 auc_max 0.5
# elec  e2-e1 elec_label  Ins
# --» processing SEMC elec 6 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.7 auc_max 0.65
# elec  e3-e2 elec_label  Ins
# --» processing SEMC elec 7 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.735714285714 auc_max 0.535714285714
# elec  e3-e2 elec_label  Ins
# --» processing SEMC elec 7 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.7 auc_max 0.521428571429
# elec  e3-e2 elec_label  Ins
# --» processing SEMC elec 7 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.733333333333 auc_max 0.635714285714
# elec  e3-e2 elec_label  Ins
# --» processing SEMC elec 7 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.735714285714 auc_max 0.666666666667
# elec  e3-e2 elec_label  Ins
# --» processing SEMC elec 7 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.7 auc_max 0.5
# elec  e4-e3 elec_label  IFG
# --» processing SEMC elec 8 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.571428571429 001 0.690476190476 auc_max 0.5
# elec  e4-e3 elec_label  IFG
# --» processing SEMC elec 8 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.602380952381 001 0.75 auc_max 0.6
# elec  e4-e3 elec_label  IFG
# --» processing SEMC elec 8 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.569047619048 001 0.816666666667 auc_max 0.7
# elec  e4-e3 elec_label  IFG
# --» processing SEMC elec 8 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.733333333333 auc_max 0.5
# elec  e4-e3 elec_label  IFG
# --» processing SEMC elec 8 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.8 auc_max 0.5
# elec  e7-e6 elec_label  IFG
# --» processing SEMC elec 9 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.783333333333 auc_max 0.5
# elec  e7-e6 elec_label  IFG
# --» processing SEMC elec 9 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.55 001 0.583333333333 auc_max 0.5
# elec  e7-e6 elec_label  IFG
# --» processing SEMC elec 9 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.752380952381 auc_max 0.5
# elec  e7-e6 elec_label  IFG
# --» processing SEMC elec 9 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.7 auc_max 0.835714285714
# elec  e7-e6 elec_label  IFG
# --» processing SEMC elec 9 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.735714285714 auc_max 0.65
# elec  e8-e7 elec_label  IFG
# --» processing SEMC elec 10 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.571428571429 001 0.702380952381 auc_max 0.5
# elec  e8-e7 elec_label  IFG
# --» processing SEMC elec 10 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.590476190476 001 0.783333333333 auc_max 0.535714285714
# elec  e8-e7 elec_label  IFG
# --» processing SEMC elec 10 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.683333333333 auc_max 0.769047619048
# elec  e8-e7 elec_label  IFG
# --» processing SEMC elec 10 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.602380952381 001 0.8 auc_max 0.985714285714
# elec  e8-e7 elec_label  IFG
# --» processing SEMC elec 10 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.669047619048 auc_max 0.707142857143
# elec  f2-f1 elec_label  OFC
# --» processing SEMC elec 11 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.733333333333 auc_max 0.669047619048
# elec  f2-f1 elec_label  OFC
# --» processing SEMC elec 11 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.685714285714 auc_max 0.5
# elec  f2-f1 elec_label  OFC
# --» processing SEMC elec 11 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.735714285714 auc_max 0.5
# elec  f2-f1 elec_label  OFC
# --» processing SEMC elec 11 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.769047619048 auc_max 0.535714285714
# elec  f2-f1 elec_label  OFC
# --» processing SEMC elec 11 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.75 auc_max 0.5
# elec  f3-f2 elec_label  OFC
# --» processing SEMC elec 12 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.566666666667 001 0.619047619048 auc_max 0.5
# elec  f3-f2 elec_label  OFC
# --» processing SEMC elec 12 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.635714285714 001 0.733333333333 auc_max 0.485714285714
# elec  f3-f2 elec_label  OFC
# --» processing SEMC elec 12 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.669047619048 auc_max 0.5
# elec  f3-f2 elec_label  OFC
# --» processing SEMC elec 12 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.816666666667 auc_max 0.5
# elec  f3-f2 elec_label  OFC
# --» processing SEMC elec 12 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.783333333333 auc_max 0.619047619048
# elec  f4-f3 elec_label  OFC
# --» processing SEMC elec 13 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.716666666667 auc_max 0.669047619048
# elec  f4-f3 elec_label  OFC
# --» processing SEMC elec 13 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.783333333333 auc_max 0.5
# elec  f4-f3 elec_label  OFC
# --» processing SEMC elec 13 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.75 auc_max 0.55
# elec  f4-f3 elec_label  OFC
# --» processing SEMC elec 13 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.719047619048 auc_max 0.835714285714
# elec  f4-f3 elec_label  OFC
# --» processing SEMC elec 13 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.652380952381 auc_max 0.769047619048
# elec  f5-f4 elec_label  OFC
# --» processing SEMC elec 14 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.554761904762 001 0.65 auc_max 0.583333333333
# elec  f5-f4 elec_label  OFC
# --» processing SEMC elec 14 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.65 001 0.719047619048 auc_max 0.721428571429
# elec  f5-f4 elec_label  OFC
# --» processing SEMC elec 14 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.735714285714 auc_max 0.5
# elec  f5-f4 elec_label  OFC
# --» processing SEMC elec 14 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.65 001 0.719047619048 auc_max 0.5
# elec  f5-f4 elec_label  OFC
# --» processing SEMC elec 14 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.621428571429 001 0.7 auc_max 0.75
# elec  f6-f5 elec_label  OFC
# --» processing SEMC elec 15 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.702380952381 auc_max 0.5
# elec  f6-f5 elec_label  OFC
# --» processing SEMC elec 15 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.716666666667 auc_max 0.5
# elec  f6-f5 elec_label  OFC
# --» processing SEMC elec 15 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.65 auc_max 0.65
# elec  f6-f5 elec_label  OFC
# --» processing SEMC elec 15 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.683333333333 auc_max 0.5
# elec  f6-f5 elec_label  OFC
# --» processing SEMC elec 15 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.683333333333 auc_max 0.485714285714
# elec  f7-f6 elec_label  MFG
# --» processing SEMC elec 16 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.571428571429 001 0.702380952381 auc_max 0.535714285714
# elec  f7-f6 elec_label  MFG
# --» processing SEMC elec 16 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.685714285714 auc_max 0.5
# elec  f7-f6 elec_label  MFG
# --» processing SEMC elec 16 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.719047619048 auc_max 0.5
# elec  f7-f6 elec_label  MFG
# --» processing SEMC elec 16 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.75 auc_max 0.5
# elec  f7-f6 elec_label  MFG
# --» processing SEMC elec 16 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.566666666667 001 0.702380952381 auc_max 0.5
# elec  f8-f7 elec_label  MFG
# --» processing SEMC elec 17 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.602380952381 001 0.804761904762 auc_max 0.5
# elec  f8-f7 elec_label  MFG
# --» processing SEMC elec 17 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.7 auc_max 0.5
# elec  f8-f7 elec_label  MFG
# --» processing SEMC elec 17 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.602380952381 001 0.685714285714 auc_max 0.685714285714
# elec  f8-f7 elec_label  MFG
# --» processing SEMC elec 17 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.602380952381 001 0.7 auc_max 0.5
# elec  f8-f7 elec_label  MFG
# --» processing SEMC elec 17 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.754761904762 auc_max 0.5
# elec  j2-j1 elec_label  IFG
# --» processing SEMC elec 18 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.683333333333 auc_max 0.5
# elec  j2-j1 elec_label  IFG
# --» processing SEMC elec 18 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.819047619048 auc_max 0.5
# elec  j2-j1 elec_label  IFG
# --» processing SEMC elec 18 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.807142857143 auc_max 0.5
# elec  j2-j1 elec_label  IFG
# --» processing SEMC elec 18 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.685714285714 auc_max 0.5
# elec  j2-j1 elec_label  IFG
# --» processing SEMC elec 18 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.635714285714 001 0.75 auc_max 0.5
# elec  j3-j2 elec_label  IFG
# --» processing SEMC elec 19 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.721428571429 auc_max 0.55
# elec  j3-j2 elec_label  IFG
# --» processing SEMC elec 19 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.685714285714 auc_max 0.5
# elec  j3-j2 elec_label  IFG
# --» processing SEMC elec 19 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.735714285714 auc_max 0.5
# elec  j3-j2 elec_label  IFG
# --» processing SEMC elec 19 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.652380952381 auc_max 0.55
# elec  j3-j2 elec_label  IFG
# --» processing SEMC elec 19 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.635714285714 001 0.735714285714 auc_max 0.5
# elec  j4-j3 elec_label  IFG
# --» processing SEMC elec 20 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.685714285714 auc_max 0.5
# elec  j4-j3 elec_label  IFG
# --» processing SEMC elec 20 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.683333333333 auc_max 0.485714285714
# elec  j4-j3 elec_label  IFG
# --» processing SEMC elec 20 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.65 001 0.769047619048 auc_max 0.5
# elec  j4-j3 elec_label  IFG
# --» processing SEMC elec 20 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.685714285714 auc_max 0.5
# elec  j4-j3 elec_label  IFG
# --» processing SEMC elec 20 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.607142857143 001 0.75 auc_max 0.5
# elec  j5-j4 elec_label  STG
# --» processing SEMC elec 21 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.685714285714 auc_max 0.5
# elec  j5-j4 elec_label  STG
# --» processing SEMC elec 21 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.621428571429 001 0.769047619048 auc_max 0.5
# elec  j5-j4 elec_label  STG
# --» processing SEMC elec 21 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.735714285714 auc_max 0.719047619048
# elec  j5-j4 elec_label  STG
# --» processing SEMC elec 21 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.783333333333 auc_max 0.685714285714
# elec  j5-j4 elec_label  STG
# --» processing SEMC elec 21 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.7 auc_max 0.55
# elec  j6-j5 elec_label  STG
# --» processing SEMC elec 22 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.569047619048 001 0.783333333333 auc_max 0.557142857143
# elec  j6-j5 elec_label  STG
# --» processing SEMC elec 22 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.721428571429 auc_max 0.5
# elec  j6-j5 elec_label  STG
# --» processing SEMC elec 22 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.604761904762 001 0.721428571429 auc_max 0.652380952381
# elec  j6-j5 elec_label  STG
# --» processing SEMC elec 22 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.733333333333 auc_max 0.55
# elec  j6-j5 elec_label  STG
# --» processing SEMC elec 22 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.719047619048 auc_max 0.5
# elec  k2-k1 elec_label  ACC
# --» processing SEMC elec 23 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.7 auc_max 0.5
# elec  k2-k1 elec_label  ACC
# --» processing SEMC elec 23 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.735714285714 auc_max 0.55
# elec  k2-k1 elec_label  ACC
# --» processing SEMC elec 23 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.669047619048 auc_max 0.5
# elec  k2-k1 elec_label  ACC
# --» processing SEMC elec 23 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.735714285714 auc_max 0.733333333333
# elec  k2-k1 elec_label  ACC
# --» processing SEMC elec 23 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.816666666667 auc_max 0.6
# elec  k9-k8 elec_label  MFG
# --» processing SEMC elec 24 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.569047619048 001 0.65 auc_max 0.5
# elec  k9-k8 elec_label  MFG
# --» processing SEMC elec 24 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.766666666667 auc_max 0.5
# elec  k9-k8 elec_label  MFG
# --» processing SEMC elec 24 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.65 auc_max 0.5
# elec  k9-k8 elec_label  MFG
# --» processing SEMC elec 24 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.590476190476 001 0.733333333333 auc_max 0.65
# elec  k9-k8 elec_label  MFG
# --» processing SEMC elec 24 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.683333333333 auc_max 0.5
# elec  k10-k9 elec_label  MFG
# --» processing SEMC elec 25 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.65 auc_max 0.5
# elec  k10-k9 elec_label  MFG
# --» processing SEMC elec 25 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.685714285714 auc_max 0.485714285714
# elec  k10-k9 elec_label  MFG
# --» processing SEMC elec 25 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.735714285714 auc_max 0.5
# elec  k10-k9 elec_label  MFG
# --» processing SEMC elec 25 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.733333333333 auc_max 0.716666666667
# elec  k10-k9 elec_label  MFG
# --» processing SEMC elec 25 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.683333333333 auc_max 0.669047619048
# elec  k11-k10 elec_label  MFG
# --» processing SEMC elec 26 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.621428571429 001 0.719047619048 auc_max 0.5
# elec  k11-k10 elec_label  MFG
# --» processing SEMC elec 26 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.7 auc_max 0.5
# elec  k11-k10 elec_label  MFG
# --» processing SEMC elec 26 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.7 auc_max 0.685714285714
# elec  k11-k10 elec_label  MFG
# --» processing SEMC elec 26 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.7 auc_max 0.5
# elec  k11-k10 elec_label  MFG
# --» processing SEMC elec 26 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.719047619048 auc_max 0.604761904762
# elec  k12-k11 elec_label  MFG
# --» processing SEMC elec 27 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.721428571429 auc_max 0.5
# elec  k12-k11 elec_label  MFG
# --» processing SEMC elec 27 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.671428571429 auc_max 0.5
# elec  k12-k11 elec_label  MFG
# --» processing SEMC elec 27 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.721428571429 auc_max 0.65
# elec  k12-k11 elec_label  MFG
# --» processing SEMC elec 27 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.685714285714 auc_max 0.5
# elec  k12-k11 elec_label  MFG
# --» processing SEMC elec 27 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.666666666667 auc_max 0.55
# elec  o2-o1 elec_label  ACC
# --» processing SEMC elec 28 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.685714285714 auc_max 0.535714285714
# elec  o2-o1 elec_label  ACC
# --» processing SEMC elec 28 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.588095238095 001 0.65 auc_max 0.5
# elec  o2-o1 elec_label  ACC
# --» processing SEMC elec 28 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.704761904762 auc_max 0.5
# elec  o2-o1 elec_label  ACC
# --» processing SEMC elec 28 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.685714285714 auc_max 0.5
# elec  o2-o1 elec_label  ACC
# --» processing SEMC elec 28 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.607142857143 001 0.683333333333 auc_max 0.5
# elec  o5-o4 elec_label  OFC
# --» processing SEMC elec 29 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.633333333333 auc_max 0.5
# elec  o5-o4 elec_label  OFC
# --» processing SEMC elec 29 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.685714285714 auc_max 0.5
# elec  o5-o4 elec_label  OFC
# --» processing SEMC elec 29 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.621428571429 001 0.7 auc_max 0.5
# elec  o5-o4 elec_label  OFC
# --» processing SEMC elec 29 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.635714285714 auc_max 0.5
# elec  o5-o4 elec_label  OFC
# --» processing SEMC elec 29 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.716666666667 auc_max 0.5
# elec  o6-o5 elec_label  OFC
# --» processing SEMC elec 30 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.735714285714 auc_max 0.685714285714
# elec  o6-o5 elec_label  OFC
# --» processing SEMC elec 30 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.7 auc_max 0.5
# elec  o6-o5 elec_label  OFC
# --» processing SEMC elec 30 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.669047619048 auc_max 0.55
# elec  o6-o5 elec_label  OFC
# --» processing SEMC elec 30 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.685714285714 auc_max 0.483333333333
# elec  o6-o5 elec_label  OFC
# --» processing SEMC elec 30 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.671428571429 auc_max 0.65
# elec  o7-o6 elec_label  OFC
# --» processing SEMC elec 31 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.735714285714 auc_max 0.5
# elec  o7-o6 elec_label  OFC
# --» processing SEMC elec 31 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.65 auc_max 0.5
# elec  o7-o6 elec_label  OFC
# --» processing SEMC elec 31 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.685714285714 auc_max 0.5
# elec  o7-o6 elec_label  OFC
# --» processing SEMC elec 31 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.769047619048 auc_max 0.769047619048
# elec  o7-o6 elec_label  OFC
# --» processing SEMC elec 31 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.735714285714 auc_max 0.585714285714
# elec  o8-o7 elec_label  OFC
# --» processing SEMC elec 32 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.721428571429 auc_max 0.5
# elec  o8-o7 elec_label  OFC
# --» processing SEMC elec 32 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.719047619048 auc_max 0.5
# elec  o8-o7 elec_label  OFC
# --» processing SEMC elec 32 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.7 auc_max 0.583333333333
# elec  o8-o7 elec_label  OFC
# --» processing SEMC elec 32 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.7 auc_max 0.5
# elec  o8-o7 elec_label  OFC
# --» processing SEMC elec 32 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.733333333333 auc_max 0.569047619048
# elec  o9-o8 elec_label  OFC
# --» processing SEMC elec 33 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.7 auc_max 0.5
# elec  o9-o8 elec_label  OFC
# --» processing SEMC elec 33 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.683333333333 auc_max 0.5
# elec  o9-o8 elec_label  OFC
# --» processing SEMC elec 33 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.766666666667 auc_max 0.6
# elec  o9-o8 elec_label  OFC
# --» processing SEMC elec 33 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.621428571429 001 0.7 auc_max 0.5
# elec  o9-o8 elec_label  OFC
# --» processing SEMC elec 33 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.685714285714 auc_max 0.6
# elec  o10-o9 elec_label  OFC
# --» processing SEMC elec 34 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.602380952381 001 0.666666666667 auc_max 0.569047619048
# elec  o10-o9 elec_label  OFC
# --» processing SEMC elec 34 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.754761904762 auc_max 0.5
# elec  o10-o9 elec_label  OFC
# --» processing SEMC elec 34 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.666666666667 auc_max 0.5
# elec  o10-o9 elec_label  OFC
# --» processing SEMC elec 34 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.766666666667 auc_max 0.5
# elec  o10-o9 elec_label  OFC
# --» processing SEMC elec 34 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.821428571429 auc_max 0.5
# elec  o11-o10 elec_label  IFG
# --» processing SEMC elec 35 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.733333333333 auc_max 0.716666666667
# elec  o11-o10 elec_label  IFG
# --» processing SEMC elec 35 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.716666666667 auc_max 0.5
# elec  o11-o10 elec_label  IFG
# --» processing SEMC elec 35 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.685714285714 auc_max 0.5
# elec  o11-o10 elec_label  IFG
# --» processing SEMC elec 35 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.602380952381 001 0.766666666667 auc_max 0.583333333333
# elec  o11-o10 elec_label  IFG
# --» processing SEMC elec 35 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.716666666667 auc_max 0.521428571429
# elec  o12-o11 elec_label  IFG
# --» processing SEMC elec 36 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.602380952381 001 0.785714285714 auc_max 0.5
# elec  o12-o11 elec_label  IFG
# --» processing SEMC elec 36 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.7 auc_max 0.55
# elec  o12-o11 elec_label  IFG
# --» processing SEMC elec 36 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.783333333333 auc_max 0.5
# elec  o12-o11 elec_label  IFG
# --» processing SEMC elec 36 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.669047619048 auc_max 0.5
# elec  o12-o11 elec_label  IFG
# --» processing SEMC elec 36 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.65 001 0.75 auc_max 0.5
# elec  o13-o12 elec_label  IFG
# --» processing SEMC elec 37 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.735714285714 auc_max 0.671428571429
# elec  o13-o12 elec_label  IFG
# --» processing SEMC elec 37 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.719047619048 auc_max 0.583333333333
# elec  o13-o12 elec_label  IFG
# --» processing SEMC elec 37 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.735714285714 auc_max 0.5
# elec  o13-o12 elec_label  IFG
# --» processing SEMC elec 37 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.685714285714 auc_max 0.5
# elec  o13-o12 elec_label  IFG
# --» processing SEMC elec 37 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.652380952381 auc_max 0.5
# elec  u2-u1 elec_label  ACC
# --» processing SEMC elec 38 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.733333333333 auc_max 0.5
# elec  u2-u1 elec_label  ACC
# --» processing SEMC elec 38 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.607142857143 001 0.785714285714 auc_max 0.5
# elec  u2-u1 elec_label  ACC
# --» processing SEMC elec 38 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.569047619048 001 0.735714285714 auc_max 0.55
# elec  u2-u1 elec_label  ACC
# --» processing SEMC elec 38 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.607142857143 001 0.766666666667 auc_max 0.5
# elec  u2-u1 elec_label  ACC
# --» processing SEMC elec 38 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.685714285714 auc_max 0.5
# elec  u5-u4 elec_label  OFC
# --» processing SEMC elec 39 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.735714285714 auc_max 0.5
# elec  u5-u4 elec_label  OFC
# --» processing SEMC elec 39 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.602380952381 001 0.721428571429 auc_max 0.5
# elec  u5-u4 elec_label  OFC
# --» processing SEMC elec 39 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.7 auc_max 0.766666666667
# elec  u5-u4 elec_label  OFC
# --» processing SEMC elec 39 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.733333333333 auc_max 0.8
# elec  u5-u4 elec_label  OFC
# --» processing SEMC elec 39 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.65 auc_max 0.6
# elec  u6-u5 elec_label  OFC
# --» processing SEMC elec 40 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.716666666667 auc_max 0.55
# elec  u6-u5 elec_label  OFC
# --» processing SEMC elec 40 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.7 auc_max 0.5
# elec  u6-u5 elec_label  OFC
# --» processing SEMC elec 40 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.604761904762 001 0.785714285714 auc_max 0.721428571429
# elec  u6-u5 elec_label  OFC
# --» processing SEMC elec 40 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.766666666667 auc_max 0.55
# elec  u6-u5 elec_label  OFC
# --» processing SEMC elec 40 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.719047619048 auc_max 0.683333333333
# elec  u7-u6 elec_label  OFC
# --» processing SEMC elec 41 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.75 auc_max 0.5
# elec  u7-u6 elec_label  OFC
# --» processing SEMC elec 41 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.619047619048 001 0.685714285714 auc_max 0.55
# elec  u7-u6 elec_label  OFC
# --» processing SEMC elec 41 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.583333333333 001 0.666666666667 auc_max 0.5
# elec  u7-u6 elec_label  OFC
# --» processing SEMC elec 41 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.65 auc_max 0.5
# elec  u7-u6 elec_label  OFC
# --» processing SEMC elec 41 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.635714285714 001 0.75 auc_max 0.5
# elec  u8-u7 elec_label  IFG
# --» processing SEMC elec 42 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.616666666667 001 0.7 auc_max 0.583333333333
# elec  u8-u7 elec_label  IFG
# --» processing SEMC elec 42 / 65 freq 3
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.6 001 0.719047619048 auc_max 0.635714285714
# elec  u8-u7 elec_label  IFG
# --» processing SEMC elec 42 / 65 freq 4
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.633333333333 001 0.7 auc_max 0.5
# elec  u8-u7 elec_label  IFG
# --» processing SEMC elec 42 / 65 freq 5
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.569047619048 001 0.671428571429 auc_max 0.571428571429
# elec  u8-u7 elec_label  IFG
# --» processing SEMC elec 42 / 65 freq 6
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.654761904762 001 0.75 auc_max 0.666666666667
# elec  u9-u8 elec_label  IFG
# --» processing SEMC elec 43 / 65 freq 2
# Size of the concatenated data:  (41, 1) Number time windows :  1
# Size of label for classif:  41
# th_perm 005:  0.585714285714 001 0.7 auc_max 0.633333333333
# elec  u9-u8 elec_label  IFG
# --» processing SEMC elec 43 / 65 freq 3
# ...
# elec  h'7-h'6 elec_label  MFG
# --» processing CHAF elec 44 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.655357142857 001 0.692857142857 auc_max 0.596428571429
# elec  h'7-h'6 elec_label  MFG
# --» processing CHAF elec 44 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.644642857143 001 0.696428571429 auc_max 0.580357142857
# elec  h'7-h'6 elec_label  MFG
# --» processing CHAF elec 44 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.648214285714 001 0.726785714286 auc_max 0.732142857143
# elec  h'8-h'7 elec_label  MFG
# --» processing CHAF elec 45 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.651785714286 001 0.696428571429 auc_max 0.664285714286
# elec  h'8-h'7 elec_label  MFG
# --» processing CHAF elec 45 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.639285714286 001 0.683928571429 auc_max 0.551785714286
# elec  h'8-h'7 elec_label  MFG
# --» processing CHAF elec 45 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.635714285714 001 0.6875 auc_max 0.623214285714
# elec  h'8-h'7 elec_label  MFG
# --» processing CHAF elec 45 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.646428571429 001 0.683928571429 auc_max 0.701785714286
# elec  h'8-h'7 elec_label  MFG
# --» processing CHAF elec 45 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.644642857143 001 0.6875 auc_max 0.739285714286
# elec  h'9-h'8 elec_label  MFG
# --» processing CHAF elec 46 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.658928571429 001 0.717857142857 auc_max 0.530357142857
# elec  h'9-h'8 elec_label  MFG
# --» processing CHAF elec 46 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.630357142857 001 0.683928571429 auc_max 0.498214285714
# elec  h'9-h'8 elec_label  MFG
# --» processing CHAF elec 46 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.642857142857 001 0.696428571429 auc_max 0.523214285714
# elec  h'9-h'8 elec_label  MFG
# --» processing CHAF elec 46 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.642857142857 001 0.698214285714 auc_max 0.617857142857
# elec  h'9-h'8 elec_label  MFG
# --» processing CHAF elec 46 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.648214285714 001 0.701785714286 auc_max 0.710714285714
# elec  h'10-h'9 elec_label  MFG
# --» processing CHAF elec 47 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.646428571429 001 0.714285714286 auc_max 0.508928571429
# elec  h'10-h'9 elec_label  MFG
# --» processing CHAF elec 47 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.644642857143 001 0.669642857143 auc_max 0.589285714286
# elec  h'10-h'9 elec_label  MFG
# --» processing CHAF elec 47 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.641071428571 001 0.683928571429 auc_max 0.483928571429
# elec  h'10-h'9 elec_label  MFG
# --» processing CHAF elec 47 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.6375 001 0.698214285714 auc_max 0.701785714286
# elec  h'10-h'9 elec_label  MFG
# --» processing CHAF elec 47 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.630357142857 001 0.678571428571 auc_max 0.775
# elec  i'8-i'7 elec_label  SFG
# --» processing CHAF elec 48 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.642857142857 001 0.698214285714 auc_max 0.482142857143
# elec  i'8-i'7 elec_label  SFG
# --» processing CHAF elec 48 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.65 001 0.694642857143 auc_max 0.507142857143
# elec  i'8-i'7 elec_label  SFG
# --» processing CHAF elec 48 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.646428571429 001 0.730357142857 auc_max 0.464285714286
# elec  i'8-i'7 elec_label  SFG
# --» processing CHAF elec 48 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.646428571429 001 0.698214285714 auc_max 0.767857142857
# elec  i'8-i'7 elec_label  SFG
# --» processing CHAF elec 48 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.619642857143 001 0.667857142857 auc_max 0.680357142857
# elec  i'9-i'8 elec_label  SFG
# --» processing CHAF elec 49 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.658928571429 001 0.680357142857 auc_max 0.491071428571
# elec  i'9-i'8 elec_label  SFG
# --» processing CHAF elec 49 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.648214285714 001 0.691071428571 auc_max 0.564285714286
# elec  i'9-i'8 elec_label  SFG
# --» processing CHAF elec 49 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.664285714286 001 0.698214285714 auc_max 0.539285714286
# elec  i'9-i'8 elec_label  SFG
# --» processing CHAF elec 49 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.655357142857 001 0.728571428571 auc_max 0.635714285714
# elec  i'9-i'8 elec_label  SFG
# --» processing CHAF elec 49 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.653571428571 001 0.683928571429 auc_max 0.573214285714
# elec  i'10-i'9 elec_label  SFG
# --» processing CHAF elec 50 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.65 001 0.675 auc_max 0.564285714286
# elec  i'10-i'9 elec_label  SFG
# --» processing CHAF elec 50 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.644642857143 001 0.7 auc_max 0.4375
# elec  i'10-i'9 elec_label  SFG
# --» processing CHAF elec 50 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.6375 001 0.6875 auc_max 0.492857142857
# elec  i'10-i'9 elec_label  SFG
# --» processing CHAF elec 50 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.655357142857 001 0.698214285714 auc_max 0.719642857143
# elec  i'10-i'9 elec_label  SFG
# --» processing CHAF elec 50 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.653571428571 001 0.716071428571 auc_max 0.658928571429
# elec  i'11-i'10 elec_label  SFG
# --» processing CHAF elec 51 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.658928571429 001 0.694642857143 auc_max 0.480357142857
# elec  i'11-i'10 elec_label  SFG
# --» processing CHAF elec 51 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.657142857143 001 0.707142857143 auc_max 0.632142857143
# elec  i'11-i'10 elec_label  SFG
# --» processing CHAF elec 51 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.657142857143 001 0.7 auc_max 0.592857142857
# elec  i'11-i'10 elec_label  SFG
# --» processing CHAF elec 51 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.660714285714 001 0.703571428571 auc_max 0.567857142857
# elec  i'11-i'10 elec_label  SFG
# --» processing CHAF elec 51 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.648214285714 001 0.676785714286 auc_max 0.642857142857
# elec  i'12-i'11 elec_label  SFG
# --» processing CHAF elec 52 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.644642857143 001 0.667857142857 auc_max 0.558928571429
# elec  i'12-i'11 elec_label  SFG
# --» processing CHAF elec 52 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.635714285714 001 0.710714285714 auc_max 0.532142857143
# elec  i'12-i'11 elec_label  SFG
# --» processing CHAF elec 52 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.655357142857 001 0.6875 auc_max 0.521428571429
# elec  i'12-i'11 elec_label  SFG
# --» processing CHAF elec 52 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.641071428571 001 0.6875 auc_max 0.730357142857
# elec  i'12-i'11 elec_label  SFG
# --» processing CHAF elec 52 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.633928571429 001 0.685714285714 auc_max 0.633928571429
# elec  i'13-i'12 elec_label  SFG
# --» processing CHAF elec 53 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.646428571429 001 0.739285714286 auc_max 0.596428571429
# elec  i'13-i'12 elec_label  SFG
# --» processing CHAF elec 53 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.648214285714 001 0.669642857143 auc_max 0.596428571429
# elec  i'13-i'12 elec_label  SFG
# --» processing CHAF elec 53 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.648214285714 001 0.6875 auc_max 0.494642857143
# elec  i'13-i'12 elec_label  SFG
# --» processing CHAF elec 53 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.646428571429 001 0.7 auc_max 0.660714285714
# elec  i'13-i'12 elec_label  SFG
# --» processing CHAF elec 53 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.658928571429 001 0.710714285714 auc_max 0.6
# elec  i'14-i'13 elec_label  SFG
# --» processing CHAF elec 54 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.660714285714 001 0.698214285714 auc_max 0.6875
# elec  i'14-i'13 elec_label  SFG
# --» processing CHAF elec 54 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.642857142857 001 0.701785714286 auc_max 0.491071428571
# elec  i'14-i'13 elec_label  SFG
# --» processing CHAF elec 54 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.648214285714 001 0.696428571429 auc_max 0.453571428571
# elec  i'14-i'13 elec_label  SFG
# --» processing CHAF elec 54 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.65 001 0.669642857143 auc_max 0.532142857143
# elec  i'14-i'13 elec_label  SFG
# --» processing CHAF elec 54 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.639285714286 001 0.710714285714 auc_max 0.551785714286
# elec  i'15-i'14 elec_label  SFG
# --» processing CHAF elec 55 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.632142857143 001 0.680357142857 auc_max 0.558928571429
# elec  i'15-i'14 elec_label  SFG
# --» processing CHAF elec 55 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.648214285714 001 0.703571428571 auc_max 0.542857142857
# elec  i'15-i'14 elec_label  SFG
# --» processing CHAF elec 55 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.648214285714 001 0.689285714286 auc_max 0.55
# elec  i'15-i'14 elec_label  SFG
# --» processing CHAF elec 55 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.658928571429 001 0.726785714286 auc_max 0.607142857143
# elec  i'15-i'14 elec_label  SFG
# --» processing CHAF elec 55 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.644642857143 001 0.6875 auc_max 0.705357142857
# elec  j'14-j'13 elec_label  MFG
# --» processing CHAF elec 56 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.653571428571 001 0.716071428571 auc_max 0.671428571429
# elec  j'14-j'13 elec_label  MFG
# --» processing CHAF elec 56 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.648214285714 001 0.694642857143 auc_max 0.575
# elec  j'14-j'13 elec_label  MFG
# --» processing CHAF elec 56 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.641071428571 001 0.676785714286 auc_max 0.475
# elec  j'14-j'13 elec_label  MFG
# --» processing CHAF elec 56 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.651785714286 001 0.6875 auc_max 0.773214285714
# elec  j'14-j'13 elec_label  MFG
# --» processing CHAF elec 56 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.633928571429 001 0.682142857143 auc_max 0.673214285714
# elec  j'15-j'14 elec_label  MFG
# --» processing CHAF elec 57 / 58 freq 2
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.642857142857 001 0.669642857143 auc_max 0.673214285714
# elec  j'15-j'14 elec_label  MFG
# --» processing CHAF elec 57 / 58 freq 3
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.644642857143 001 0.682142857143 auc_max 0.564285714286
# elec  j'15-j'14 elec_label  MFG
# --» processing CHAF elec 57 / 58 freq 4
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.644642857143 001 0.708928571429 auc_max 0.614285714286
# elec  j'15-j'14 elec_label  MFG
# --» processing CHAF elec 57 / 58 freq 5
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.6375 001 0.7 auc_max 0.551785714286
# elec  j'15-j'14 elec_label  MFG
# --» processing CHAF elec 57 / 58 freq 6
# Size of the concatenated data:  (73, 1) Number time windows :  1
# Size of label for classif:  73
# th_perm 005:  0.616071428571 001 0.651785714286 auc_max 0.666071428571

# %% [markdown]
# #### ML for the TPSim - ST analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import StratifiedKFold as SKFold
from sklearn.metrics import roc_auc_score
from numpy.random import permutation

conds,phases, subjects = ['low','high'],['odor'],['SEMC','VACJ','FERJ','LEFC','PIRJ','CHAF']#,'MICP','VACJ','SEMC','LEFC','PIRJ']
freq_names = ['2_theta','3_alpha','4_beta','5_gamma1','6_gamma2']
color_codes = ['darkorange','blue']
st = study('Olfacto')
freqs = 7
nperm = 1000

for su,phase in product(subjects,phases):
    path_pow = path.join(st.path, 'feature/TPSim_Enc_Ret_By_Odor/TPS_R_p_by_cond/')
    save_path = path.join(st.path, 'classified/Classif_TPSim_Encoding_Retrieval_Odor_1000perm/')

    pow_list = []
    #=========================== Load Power files (nfreq, nelec, nwin, ntrial) =================================    
    mat0 = np.load(path.join(path_pow, 'TPS_spear_'+su+'_'+phase+'_'+conds[0]+'.npz'))
    names, channels = mat0['Mai_RL'], mat0['channels'],mat0['fname'], mat0['time']
    #print(mat0['xpow'].shape,time.shape,time[17:42])
    pow_list.append(mat0['xpow'][:,:,18,:][:,:,np.newaxis,:])
    nelecs = mat0['xpow'].shape[1]
    mat1 = np.load(path.join(path_pow, su+'_'+phase+'_'+conds[1]+'_bipo_sel_physFT_pow'+bsl+'.npz'))
    pow_list.append(mat1['xpow'][:,:,18,:][:,:,np.newaxis,:])
    print (su, 'power shape: ', [pow.shape for pow in pow_list])
    # =========================== Select Power for 1 elec 1 freq =================================                 
    iterator = range(nelecs)
    for elec_num in iterator:
        for freq in range(2,freqs):
            elec, elec_label, freq_name = channels[elec_num], names[elec_num], freq_names[freq]
            print ('elec ', elec, 'elec_label ', elec_label)
            #Filenames to save
            name_auc = (save_path+str(freq)+'_'+freq_name+'/auc/'+su +'_auc_'+conds[0]+'_'+conds[1]+'_'+str(elec_label)+'_('+str(elec_num)+').npy')
            name_perm = (save_path+str(freq)+'_'+freq_name+'/auc/'+su +'_perm_'+str(elec_label)+'_('+str(elec_num)+').npy')
                        
            if path.exists(name_auc):
                print(su,bsl,phase,elec_num,freq,'already computed')
            else:
                print('--» processing',su, 'elec', elec_num,'/',nelecs, 'freq',freq)
                pow_data_elec = []
                for i,power in enumerate(pow_list):
                    pow_data_elec.append(power[freq,elec_num].swapaxes(0,1))
                nwin = power.shape[1]

        # =============================  Classification Computation ============================================================           
                # create a data matrix, concatenate along the trial dimension
                x = np.concatenate(pow_data_elec, axis=0)
                print ('Size of the concatenated data: ', x.shape, 'Number time windows : ', x.shape[1])
                y = np.hstack([np.array([i]*len(power)) for i, power in enumerate(pow_data_elec)])
                print ('Size of label for classif: ', len(y))

                auc = np.array([])
                for t in range(x.shape[1]):
                    X = x[:,t]
                    X = X.reshape(-1, 1)
                    score_rep = []
                    for i in range(10):
                        k = 5
                        skf = SKFold(n_splits=k, random_state=None, shuffle=True)
                        skf.get_n_splits(X, y)
                        score_cv = []
                        for train_index, test_index in skf.split(X, y):
                            clf = LDA()
                            X_train, X_test = X[train_index], X[test_index]
                            y_train, y_test = y[train_index], y[test_index]
                            clf.fit(X=X_train, y=y_train)
                            y_pred = clf.predict(X_test)
                            score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                        score_rep.append(np.mean(score_cv))
                    score_rep = np.asarray(score_rep).reshape(1,len(score_rep))
                    auc = np.vstack((auc, score_rep)) if np.size(auc) else score_rep
                auc = np.swapaxes(auc,0,1)

                perm_scores = np.array([])
                for t in range(x.shape[1]):
                    X = x[:,t]
                    X = X.reshape(-1, 1)
                    perm_rep = []
                    for perm in range(nperm):
                        y_perm = y[permutation(len(y))]
                        score_cv = []
                        for train_index, test_index in skf.split(X, y_perm):
                            clf = LDA()
                            X_train, X_test = X[train_index], X[test_index]
                            y_train, y_test = y_perm[train_index], y_perm[test_index]
                            clf.fit(X=X_train, y=y_train)
                            y_pred = clf.predict(X_test)
                            score_cv.append(roc_auc_score(y_test,y_pred,average='weighted'))
                        perm_rep.append(np.mean(score_cv))
                    perm_rep = np.asarray(perm_rep).reshape(1,len(perm_rep))
                    perm_scores = np.vstack((perm_scores, perm_rep)) if np.size(perm_scores) else perm_rep
                perm_scores = np.swapaxes(perm_scores,0,1)           
                th_0_05_perm = perm_pvalue2level(perm_scores, p=0.01, maxst=True)
                th_0_01_perm = perm_pvalue2level(perm_scores, p=0.001, maxst=True)
                print('th_perm 005: ', th_0_05_perm[0], '001',th_0_01_perm[0], 'auc_max', np.max(auc))

                np.save(name_auc, auc)
                np.save(name_perm, perm_scores)
                del X, auc, pow_data_elec
    del pow_list
