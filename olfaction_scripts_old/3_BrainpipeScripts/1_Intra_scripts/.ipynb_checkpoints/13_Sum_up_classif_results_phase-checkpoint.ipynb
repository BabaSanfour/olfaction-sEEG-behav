# %% [markdown]
# ### Create a df to sum up all results from all classif
#     0-Good/Bad 1-Poor/Partial 2-Partial/Detailed 3-Poor/Detailed

# %%
from os import listdir, makedirs
from os.path import isfile, join, exists
import pandas as pd
import numpy as np
from itertools import product

conds = {'0':['good','bad'],'1':['poor','partial'],'2':['partial','detailed'],
         '3':['poor','detailed']}

for cond in conds:
    ###############################################################################
    path = r'/media/karim/Datas4To/1_Analyses_Intra_EM_Odor/Olfacto/'
    path_npz = join(path, 'figures_npz/1_'+conds[cond][0]+'_'+conds[cond][1]+'_4500_expi_noart/')
    path_mask = join(path_npz, 'masks_visbrain/')
    path_to_save = join(path, 'Bilan_classif/0_all_elecs_phase/')
    npz_form = join(path_npz,'{}_sources_phase_{}_odor_'+conds[cond][0]+'_'+conds[cond][1]+'_Expi_sel_phys_{}.npz')
    masks_vis_form = join(path_mask, '{}_mask_min{}_{}_minwin{}_th{}.npy')
    ###############################################################################
    if not exists(path_to_save):
        makedirs(path_to_save)
    ###############################################################################

    freqs = ['0_VLFC','1_delta','2_theta', '3_alpha','4_beta','5_gamma1','6_gamma2']

    for freq in freqs:
        #Load all data for one classif one freq
        arch_sig = np.load(npz_form.format('All_subjects',freq, 'None'))
        print(arch_sig.files)
        #Create a df with all electrodes info
        features = ['su_codes','s_elec','s_channels','s_labels','s_aal_RL','s_BA']
        df_elec = np.array([])
        for f in features:
            data = arch_sig[f]
            df_elec = np.vstack((df_elec,data)) if np.size(df_elec) else data
        xyz = arch_sig['s_xyz']
        x,y,z = xyz[:,0],xyz[:,1],xyz[:,2]
        df_elec = np.vstack((df_elec,x,y,z))
        df0 = pd.DataFrame(data=df_elec.T, columns=features+['x','y','z'])
        #Select max values for power and AUC scores and create Time array
        da = arch_sig['s_da'][:,:39]
        pow0_max, pow1_max, idx_max, da_max, time_max = np.array([]), np.array([]), np.array([]), np.array([]),np.array([])
        for elec in range(da.shape[0]):
            #print('shape da',da.shape)
            idx = [i for i,j in enumerate(da[elec]) if j == max(da[elec])]
            if len(idx) != 1:
                idx = [idx[0]]
            #print('index',idx)
            pow0, pow1 = arch_sig['s_elec_p0'][elec][idx], arch_sig['s_elec_p1'][elec][idx]
            time = arch_sig['s_time'][idx]
            da_elec = da[elec][idx]
            pow0_max = np.hstack((pow0_max,pow0)) if np.size(pow0_max) else pow0
            pow1_max = np.hstack((pow1_max,pow1)) if np.size(pow1_max) else pow1
            time_max = np.hstack((time_max,time)) if np.size(time_max) else time
            idx_max = np.hstack((idx_max,idx)) if np.size(idx_max) else idx
            da_max = np.hstack((da_max, da_elec)) if np.size(da_max) else da_elec
        df_data = np.concatenate((pow0_max[:,np.newaxis],pow1_max[:,np.newaxis],
                da_max[:,np.newaxis],idx_max[:,np.newaxis], time_max[:,np.newaxis]),axis=1)
        df1 = pd.DataFrame(data=df_data, columns=['p0','p1','da','idx','time'])
        df_all = pd.concat((df0,df1),axis=1)
        df_name = cond+'_Classif_'+conds[cond][0]+'_'+conds[cond][1]+'_'+freq+'_all_elecs.csv'
        df_all.to_csv(path_to_save+df_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-6b8a77c20fef> in <module>()
#      25     for freq in freqs:
#      26         #Load all data for one classif one freq
# ---> 27         arch_sig = np.load(npz_form.format('All_subjects',freq, 'None'))
#      28         print(arch_sig.files)
#      29         #Create a df with all electrodes info
#
# /home/karim/anaconda3/lib/python3.5/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     368     own_fid = False
#     369     if isinstance(file, basestring):
# --> 370         fid = open(file, "rb")
#     371         own_fid = True
#     372     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/karim/Datas4To/1_Analyses_Intra_EM_Odor/Olfacto/figures_npz/1_poor_partial_4500_expi_noart/All_subjects_sources_phase_0_VLFC_odor_poor_partial_Expi_sel_phys_None.npz'

# %% [markdown]
# ### Mask significant results as function of time of the effect (wins)
#     statistics p < 0.05 corrected over electrodes and time

# %%
from os import listdir, makedirs
from os.path import isfile, join, exists
import pandas as pd
import numpy as np
from itertools import product
###############################################################################################
path = r'/media/karim/Datas4To/1_Analyses_Intra_EM_Odor/Olfacto/'
path_df = join(path, 'Bilan_classif/0_all_elecs/')
path2save = join(path,'Bilan_classif/1_signif_elecs_wins/')
###############################################################################################
if not exists(path2save):
    makedirs(path2save)
##############################################################################################
conds = {'0':['good','bad'],'1':['poor','partial'],'2':['partial','detailed'],
         '3':['poor','detailed']}
freqs = ['0_VLFC','1_delta','2_theta', '3_alpha','4_beta','5_gamma1','6_gamma2']
bsls,wins,ths = ['None'], [3,4,5], ['05']

for cond, freq, bsl, th in product(conds, freqs,bsls,ths):
    df = pd.read_csv(path_df+cond+'_Classif_'+conds[cond][0]+'_'+conds[cond][1]+'_'+freq+'_all_elecs.csv')
    path_mask = join(path,'figures_npz/'+'0_'+conds[cond][0]+'_'+conds[cond][1]+'_4500_expi_noart/masks_stat/')
    for i,win in enumerate(wins):
        #load data to plot and mask
        mask = np.load(path_mask+'All_subjects_mask_stat_'+freq+'_minwin'+str(win)+'_th'+th+'.npy')[:,np.newaxis]
        mask = np.repeat(mask,df.shape[1],axis=1)
        if mask.dtype == bool:
            df_sel = df.mask(mask).dropna()
            df_name = cond+'_Classif_'+conds[cond][0]+'_'+conds[cond][1]+'_'+freq+'_win'+str(win)+'.csv'
            df_sel.to_csv(path2save+df_name)

# %% [markdown]
# ### Mask significant results as function of time and nb of patients
#     statistics p < 0.05 corrected over electrodes and time

# %%
from os import listdir, makedirs
from os.path import isfile, join, exists
import pandas as pd
import numpy as np
from itertools import product
###############################################################################################
path = r'/media/karim/Datas4To/1_Analyses_Intra_EM_Odor/Olfacto/'
path_df = join(path, 'Bilan_classif/1_signif_elecs_wins/')
path2save = join(path,'Bilan_classif/2_signif_elecs_patients/')
###############################################################################################
if not exists(path2save):
    makedirs(path2save)
##############################################################################################
conds = {'0':['good','bad'],'1':['poor','partial'],'2':['partial','detailed'],
         '3':['poor','detailed']}
freqs = ['0_VLFC','1_delta','2_theta', '3_alpha','4_beta','5_gamma1','6_gamma2']
bsls,wins,ths = ['None'], [3,4,5], ['05']

df3, df4, df5 = None, None, None
for cond, freq, bsl, th, win in product(conds, freqs,bsls,ths,wins):
    print('processing on', conds[cond], win, freq)
    df = pd.read_csv(path_df+cond+'_Classif_'+conds[cond][0]+'_'+conds[cond][1]+'_'+freq+'_win'+str(win)+'.csv')
    df = df.drop(['Unnamed: 0.1'], axis=1)
    df = df.rename(index=str,columns={'Unnamed: 0':'old_idx'})
    print(df.shape)
    
    #count and select regions with enough patients
    count = df.groupby(['s_aal_RL']).nunique()
    count = count['su_codes']
    rois_sig3, rois_sig4, rois_sig5 = [], [], []
    for i,row in count.iteritems():
        #print('how many patients',row, 'for roi', i)
        if row >=3:
            rois_sig3.append(i)
        if row >=4:
            rois_sig4.append(i)
        if row >=5:
            rois_sig5.append(i)
    print(rois_sig3,rois_sig4,rois_sig5)
    
    # select data only in selected regions 
    df3 = df[df['s_aal_RL'].isin(rois_sig3)] if rois_sig3 else print('No rois3')
    df4 = df[df['s_aal_RL'].isin(rois_sig4)] if rois_sig4 else print('No rois4')
    df5 = df[df['s_aal_RL'].isin(rois_sig5)] if rois_sig5 else print('No rois5')
    # save data for selected regions
    df3_name = cond+'_Classif_'+conds[cond][0]+'_'+conds[cond][1]+'_'+freq+'_win'+str(win)+'_patients3.csv'
    df4_name = cond+'_Classif_'+conds[cond][0]+'_'+conds[cond][1]+'_'+freq+'_win'+str(win)+'_patients4.csv'
    df5_name = cond+'_Classif_'+conds[cond][0]+'_'+conds[cond][1]+'_'+freq+'_win'+str(win)+'_patients5.csv'
    df3.to_csv(path2save+df3_name) if df3 is not None else print('no df3 saved')
    df4.to_csv(path2save+df4_name) if df4 is not None else print('no df4 saved')
    df5.to_csv(path2save+df5_name) if df5 is not None else print('no df5 saved')
# Out:
# processing on ['good', 'bad'] 3 0_VLFC
# (87, 15)
# ['Cingulum Mid', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb'] [] []
# No rois4
# No rois5
# no df4 saved
# no df5 saved
# processing on ['good', 'bad'] 4 0_VLFC
# (57, 15)
# ['Cingulum Mid', 'Frontal Inf Orb', 'Frontal Mid Orb'] [] []
# No rois4
# No rois5
# no df4 saved
# no df5 saved
# processing on ['good', 'bad'] 5 0_VLFC
# (38, 15)
# ['Frontal Mid Orb'] [] []
# No rois4
# No rois5
# no df4 saved
# no df5 saved
# processing on ['good', 'bad'] 3 1_delta
# (100, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid']
# processing on ['good', 'bad'] 4 1_delta
# (68, 15)
# ['Frontal Mid', 'Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['good', 'bad'] 5 1_delta
# (47, 15)
# ['Frontal Mid', 'Temporal Mid'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['good', 'bad'] 3 2_theta
# (103, 15)
# ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Not f', 'Temporal Inf', 'Temporal Mid'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['good', 'bad'] 4 2_theta
# (72, 15)
# ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Mid'] ['Frontal Mid Orb'] []
# No rois5
# no df5 saved
# processing on ['good', 'bad'] 5 2_theta
# (45, 15)
# ['Frontal Inf Orb', 'Temporal Mid'] [] []
# No rois4
# No rois5
# no df4 saved
# no df5 saved
# processing on ['good', 'bad'] 3 3_alpha
# (134, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup', 'Heschl', 'Insula', 'Not f', 'Temporal Inf', 'Temporal Mid'] ['Frontal Mid Orb', 'Temporal Mid'] ['Frontal Mid Orb', 'Temporal Mid']
# processing on ['good', 'bad'] 4 3_alpha
# (85, 15)
# ['Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup', 'Temporal Mid'] ['Frontal Mid Orb', 'Temporal Mid'] ['Frontal Mid Orb', 'Temporal Mid']
# processing on ['good', 'bad'] 5 3_alpha
# (52, 15)
# ['Frontal Mid', 'Frontal Mid Orb', 'Temporal Mid'] ['Frontal Mid Orb', 'Temporal Mid'] ['Temporal Mid']
# processing on ['good', 'bad'] 3 4_beta
# (117, 15)
# ['Cingulum Ant', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup Orb', 'Postcentral', 'Temporal Inf', 'Temporal Mid'] ['Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup Orb', 'Temporal Inf', 'Temporal Mid'] ['Temporal Inf']
# processing on ['good', 'bad'] 4 4_beta
# (69, 15)
# ['Frontal Mid', 'Frontal Sup Orb', 'Postcentral', 'Temporal Inf', 'Temporal Mid'] ['Frontal Sup Orb', 'Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['good', 'bad'] 5 4_beta
# (44, 15)
# ['Frontal Sup Orb', 'Postcentral', 'Temporal Inf'] [] []
# No rois4
# No rois5
# no df4 saved
# no df5 saved
# processing on ['good', 'bad'] 3 5_gamma1
# (112, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Sup Orb', 'Postcentral', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Temporal Mid'] ['Frontal Inf Orb']
# processing on ['good', 'bad'] 4 5_gamma1
# (83, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Sup Orb', 'Temporal Mid'] ['Frontal Inf Orb'] []
# No rois5
# no df5 saved
# processing on ['good', 'bad'] 5 5_gamma1
# (56, 15)
# ['Frontal Mid'] [] []
# No rois4
# No rois5
# no df4 saved
# no df5 saved
# processing on ['good', 'bad'] 3 6_gamma2
# (172, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup', 'Hippocampus', 'Postcentral', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb'] ['Frontal Inf Orb', 'Frontal Mid Orb']
# processing on ['good', 'bad'] 4 6_gamma2
# (126, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup', 'Postcentral', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb'] ['Frontal Inf Orb']
# processing on ['good', 'bad'] 5 6_gamma2
# (96, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Postcentral', 'Temporal Sup'] ['Frontal Mid Orb'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 3 0_VLFC
# (82, 15)
# ['Cingulum Ant', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 4 0_VLFC
# (61, 15)
# ['Cingulum Ant', 'Temporal Mid'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 5 0_VLFC
# (42, 15)
# ['Temporal Mid'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 3 1_delta
# (145, 15)
# ['Cingulum Mid', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Fusiform', 'Not f', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Fusiform', 'Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 4 1_delta
# (112, 15)
# ['Frontal Mid', 'Frontal Mid Orb', 'Fusiform', 'Not f', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 5 1_delta
# (84, 15)
# ['Frontal Mid Orb', 'Fusiform', 'Not f', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 3 2_theta
# (143, 15)
# ['Frontal Inf Orb', 'Frontal Mid Orb', 'Fusiform', 'Heschl', 'Hippocampus', 'Not f', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb']
# processing on ['poor', 'detailed'] 4 2_theta
# (104, 15)
# ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Not f', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 5 2_theta
# (80, 15)
# ['Frontal Mid Orb', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid', 'Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 3 3_alpha
# (124, 15)
# ['Frontal Mid Orb', 'Fusiform', 'Hippocampus', 'Not f', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 4 3_alpha
# (81, 15)
# ['Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 5 3_alpha
# (52, 15)
# ['Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 3 4_beta
# (107, 15)
# ['Frontal Inf Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid', 'Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 4 4_beta
# (76, 15)
# ['Frontal Inf Orb', 'Temporal Mid', 'Temporal Sup'] ['Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 5 4_beta
# (46, 15)
# ['Temporal Mid', 'Temporal Sup'] ['Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 3 5_gamma1
# (151, 15)
# ['Cingulum Mid', 'Frontal Inf Orb', 'Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid', 'Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 4 5_gamma1
# (112, 15)
# ['Cingulum Mid', 'Frontal Inf Orb', 'Temporal Mid', 'Temporal Sup'] ['Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 5 5_gamma1
# (88, 15)
# ['Cingulum Mid', 'Temporal Mid', 'Temporal Sup'] ['Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 3 6_gamma2
# (179, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Not f', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 4 6_gamma2
# (141, 15)
# ['Frontal Mid Orb', 'Not f', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid', 'Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['poor', 'detailed'] 5 6_gamma2
# (120, 15)
# ['Temporal Mid', 'Temporal Sup'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['poor', 'partial'] 3 0_VLFC
# (147, 15)
# ['Cingulum Ant', 'Cingulum Mid', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup', 'Frontal Sup Orb', 'Hippocampus', 'Not f', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid', 'Hippocampus', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Hippocampus', 'Temporal Sup']
# processing on ['poor', 'partial'] 4 0_VLFC
# (117, 15)
# ['Cingulum Ant', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Sup Orb', 'Hippocampus', 'Not f', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Hippocampus', 'Temporal Sup']
# processing on ['poor', 'partial'] 5 0_VLFC
# (78, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Hippocampus', 'Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['poor', 'partial'] 3 1_delta
# (176, 15)
# ['Cingulum Ant', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup', 'Frontal Sup Orb', 'Fusiform', 'Hippocampus', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Frontal Sup Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup']
# processing on ['poor', 'partial'] 4 1_delta
# (129, 15)
# ['Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup', 'Frontal Sup Orb', 'Fusiform', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid']
# processing on ['poor', 'partial'] 5 1_delta
# (101, 15)
# ['Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup Orb', 'Fusiform', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid', 'Temporal Sup'] ['Temporal Mid']
# processing on ['poor', 'partial'] 3 2_theta
# (184, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup', 'Frontal Sup Orb', 'Fusiform', 'Hippocampus', 'Insula', 'Postcentral', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Fusiform', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup']
# processing on ['poor', 'partial'] 4 2_theta
# (134, 15)
# ['Frontal Inf Orb', 'Frontal Mid Orb', 'Frontal Sup', 'Fusiform', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Fusiform', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup']
# processing on ['poor', 'partial'] 5 2_theta
# (94, 15)
# ['Frontal Inf Orb', 'Fusiform', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Fusiform', 'Hippocampus', 'Temporal Mid'] ['Frontal Inf Orb', 'Hippocampus', 'Temporal Mid']
# processing on ['poor', 'partial'] 3 3_alpha
# (180, 15)
# ['Cingulum Ant', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup', 'Hippocampus', 'ParaHippocampal', 'Postcentral', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup']
# processing on ['poor', 'partial'] 4 3_alpha
# (116, 15)
# ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup']
# processing on ['poor', 'partial'] 5 3_alpha
# (81, 15)
# ['Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Temporal Sup']
# processing on ['poor', 'partial'] 3 4_beta
# (189, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup Orb', 'Heschl', 'Hippocampus', 'Insula', 'Not f', 'Postcentral', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid', 'Hippocampus', 'Insula', 'Not f', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Hippocampus', 'Temporal Mid']
# processing on ['poor', 'partial'] 4 4_beta
# (123, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Hippocampus', 'Insula', 'Postcentral', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Hippocampus', 'Temporal Mid'] ['Frontal Inf Orb', 'Hippocampus', 'Temporal Mid']
# processing on ['poor', 'partial'] 5 4_beta
# (88, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Hippocampus', 'Postcentral', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Hippocampus', 'Temporal Mid'] ['Frontal Inf Orb']
# processing on ['poor', 'partial'] 3 5_gamma1
# (245, 15)
# ['Cingulum Mid', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup', 'Frontal Sup Orb', 'Fusiform', 'Hippocampus', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup']
# processing on ['poor', 'partial'] 4 5_gamma1
# (200, 15)
# ['Cingulum Mid', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Fusiform', 'Hippocampus', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Temporal Mid', 'Temporal Sup']
# processing on ['poor', 'partial'] 5 5_gamma1
# (166, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Fusiform', 'Hippocampus', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid', 'Temporal Sup']
# processing on ['poor', 'partial'] 3 6_gamma2
# (293, 15)
# ['Cingulum Ant', 'Cingulum Mid', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup Medial', 'Frontal Sup Orb', 'Fusiform', 'Heschl', 'Hippocampus', 'Not f', 'Postcentral', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Hippocampus', 'Not f', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup']
# processing on ['poor', 'partial'] 4 6_gamma2
# (253, 15)
# ['Cingulum Ant', 'Cingulum Mid', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup Medial', 'Frontal Sup Orb', 'Fusiform', 'Hippocampus', 'Not f', 'Postcentral', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid', 'Temporal Sup']
# processing on ['poor', 'partial'] 5 6_gamma2
# (221, 15)
# ['Cingulum Ant', 'Cingulum Mid', 'Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Frontal Sup Orb', 'Fusiform', 'Hippocampus', 'Not f', 'Postcentral', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Inf Orb', 'Frontal Mid Orb', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid', 'Temporal Sup']
# processing on ['partial', 'detailed'] 3 0_VLFC
# (70, 15)
# ['Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 4 0_VLFC
# (53, 15)
# ['Frontal Mid Orb', 'Temporal Mid'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 5 0_VLFC
# (35, 15)
# ['Temporal Mid'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 3 1_delta
# (102, 15)
# ['Temporal Mid'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 4 1_delta
# (71, 15)
# ['Temporal Mid'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 5 1_delta
# (47, 15)
# ['Temporal Mid'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 3 2_theta
# (102, 15)
# ['Frontal Mid', 'Frontal Mid Orb', 'Fusiform', 'Hippocampus', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Fusiform', 'Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 4 2_theta
# (73, 15)
# ['Frontal Mid Orb', 'Hippocampus', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb', 'Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 5 2_theta
# (52, 15)
# ['Frontal Mid Orb', 'Temporal Inf', 'Temporal Mid', 'Temporal Sup'] ['Frontal Mid Orb'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 3 3_alpha
# (89, 15)
# ['Frontal Mid Orb', 'Fusiform', 'Hippocampus', 'Not f', 'Temporal Inf', 'Temporal Mid'] ['Hippocampus', 'Temporal Inf', 'Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 4 3_alpha
# (51, 15)
# ['Hippocampus', 'Temporal Mid'] ['Temporal Mid'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 5 3_alpha
# (29, 15)
# ['Temporal Mid'] [] []
# No rois4
# No rois5
# no df4 saved
# no df5 saved
# processing on ['partial', 'detailed'] 3 4_beta
# (85, 15)
# ['Frontal Inf Orb', 'Frontal Mid Orb', 'Hippocampus', 'Temporal Mid'] [] []
# No rois4
# No rois5
# no df4 saved
# no df5 saved
# processing on ['partial', 'detailed'] 4 4_beta
# (54, 15)
# ['Hippocampus', 'Temporal Mid'] [] []
# No rois4
# No rois5
# no df4 saved
# no df5 saved
# processing on ['partial', 'detailed'] 5 4_beta
# (33, 15)
# [] [] []
# No rois3
# No rois4
# No rois5
# no df3 saved
# no df4 saved
# no df5 saved
# processing on ['partial', 'detailed'] 3 5_gamma1
# (98, 15)
# ['Frontal Mid Orb', 'Fusiform', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Hippocampus', 'Temporal Mid', 'Temporal Sup'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 4 5_gamma1
# (62, 15)
# ['Frontal Mid Orb', 'Hippocampus', 'Temporal Mid', 'Temporal Sup'] ['Hippocampus'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 5 5_gamma1
# (38, 15)
# [] [] []
# No rois3
# No rois4
# No rois5
# no df3 saved
# no df4 saved
# no df5 saved
# processing on ['partial', 'detailed'] 3 6_gamma2
# (89, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Hippocampus', 'Not f', 'Temporal Mid'] ['Frontal Inf Orb'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 4 6_gamma2
# (52, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb', 'Hippocampus', 'Not f'] ['Frontal Inf Orb'] []
# No rois5
# no df5 saved
# processing on ['partial', 'detailed'] 5 6_gamma2
# (33, 15)
# ['Frontal Inf Orb', 'Frontal Mid', 'Frontal Mid Orb'] [] []
# No rois4
# No rois5
# no df4 saved
# no df5 saved
