# %%
import numpy as np
from os import path, listdir, makedirs
from itertools import product
from brainpipe.system import study
from brainpipe.feat.utils._feat import _manageWindow
from brainpipe.feature import power
from mne.filter import resample

# %% [markdown]
# #### Compute all power files for all configurations
# theta freqs, smoothing and downsampling parameters

# %%
st = study('Olfacto')
reps = ['Encoding_By_Odor']

for rep in reps:
    path2save = path.join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_odor_all_elecsFT/')
    code = 'E' if rep.startswith('Encoding') else 'R'
    ###############################################################################
    if not path.exists(path2save):
        makedirs(path2save)
    ###############################################################################  
    files = [k for k in st.search('bipo_all_noWM_physFT.npz', folder=('database/'+rep+'/'))]
    for fi in files:
        # Dict with all power features
        kwargs = {} # Define an empty dictionnary to save all power parameters
        kwargs['f'] = [[3,7],[4,7],[3,8],[4,8]] # Frequency vector
        kwargs['split'] = [None,None,None,None]

        # Load file :
        loadname = path.join(st.path, 'database/'+rep+'/', fi)
        mat = np.load(loadname,allow_pickle=True)
        print('all files in archive', mat.files)
        x, sf = mat['x'], 512
        n_elec, n_pts, n_trials = x.shape
        print ('--> compute power on : ', rep +'/'+ fi,'shape', x.shape)

        # Compute and save power objects :
        powObj_x = power(sf, n_pts,**kwargs, width=None, step=None, method='hilbert')
        powObj_x1 = power(sf, n_pts,**kwargs, width=6, step=6, method='hilbert')
        win_all, time = _manageWindow(x.shape[1], width=None, step=None)
        win_all, time_ds = _manageWindow(x.shape[1], width=6, step=6)
        xpow = powObj_x.get(x,n_jobs=-1)[0]
        xpow_1 = powObj_x1.get(x,n_jobs=-1)[0]
        xpow_down = resample(xpow,down=6,axis=-2)
        print('xpow None', xpow.shape, 'xpow_ds', xpow_down.shape, 'xpow_smooth',xpow_1.shape)
        print('time',np.array(time).shape,'time ds', np.array(time_ds).shape)
        
        kwargs['labels'], kwargs['channels']= mat['Mai_RL'], mat['channels']
        kwargs['xyz'] = mat['xyz']
        
        kwargs['time'], kwargs['time_ds'] = np.array(time) / sf, np.array(time_ds) / sf 
        kwargs['xpow_None'], kwargs['xpow_ds'] = xpow, xpow_down
        kwargs['xpow_smooth'] = xpow_1
        save_x = path2save+ fi.replace('bipo_all_noWM_physFT.npz', 'bipo_all_'+code+'_4theta.npz')
        np.savez(save_x, **kwargs)
        del kwargs['xpow_ds'],  kwargs['xpow_None'], kwargs['xpow_smooth']
        del kwargs, x, sf, n_elec, n_trials
# Out:
# -> Olfacto loaded
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/CHAF_odor_1_bipo_all_noWM_physFT.npz shape (61, 3584, 1)
# xpow None (4, 61, 3584, 1) xpow_ds (4, 61, 597, 1) xpow_smooth (4, 61, 597, 1)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/CHAF_odor_2_bipo_all_noWM_physFT.npz shape (61, 3584, 3)
# xpow None (4, 61, 3584, 3) xpow_ds (4, 61, 597, 3) xpow_smooth (4, 61, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/LEFC_odor_14_bipo_all_noWM_physFT.npz shape (27, 3584, 6)
# xpow None (4, 27, 3584, 6) xpow_ds (4, 27, 597, 6) xpow_smooth (4, 27, 597, 6)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/LEFC_odor_15_bipo_all_noWM_physFT.npz shape (27, 3584, 11)
# xpow None (4, 27, 3584, 11) xpow_ds (4, 27, 597, 11) xpow_smooth (4, 27, 597, 11)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/SEMC_odor_10_bipo_all_noWM_physFT.npz shape (53, 3584, 7)
# xpow None (4, 53, 3584, 7) xpow_ds (4, 53, 597, 7) xpow_smooth (4, 53, 597, 7)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/FERJ_odor_12_bipo_all_noWM_physFT.npz shape (32, 3584, 4)
# xpow None (4, 32, 3584, 4) xpow_ds (4, 32, 597, 4) xpow_smooth (4, 32, 597, 4)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/FERJ_odor_13_bipo_all_noWM_physFT.npz shape (32, 3584, 3)
# xpow None (4, 32, 3584, 3) xpow_ds (4, 32, 597, 3) xpow_smooth (4, 32, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/SEMC_odor_9_bipo_all_noWM_physFT.npz shape (53, 3584, 3)
# xpow None (4, 53, 3584, 3) xpow_ds (4, 53, 597, 3) xpow_smooth (4, 53, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/VACJ_odor_10_bipo_all_noWM_physFT.npz shape (39, 3584, 3)
# xpow None (4, 39, 3584, 3) xpow_ds (4, 39, 597, 3) xpow_smooth (4, 39, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/PIRJ_odor_18_bipo_all_noWM_physFT.npz shape (18, 3584, 5)
# xpow None (4, 18, 3584, 5) xpow_ds (4, 18, 597, 5) xpow_smooth (4, 18, 597, 5)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/PIRJ_odor_1_bipo_all_noWM_physFT.npz shape (18, 3584, 7)
# xpow None (4, 18, 3584, 7) xpow_ds (4, 18, 597, 7) xpow_smooth (4, 18, 597, 7)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/CHAF_odor_5_bipo_all_noWM_physFT.npz shape (61, 3584, 1)
# xpow None (4, 61, 3584, 1) xpow_ds (4, 61, 597, 1) xpow_smooth (4, 61, 597, 1)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/CHAF_odor_7_bipo_all_noWM_physFT.npz shape (61, 3584, 4)
# xpow None (4, 61, 3584, 4) xpow_ds (4, 61, 597, 4) xpow_smooth (4, 61, 597, 4)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/LEFC_odor_1_bipo_all_noWM_physFT.npz shape (27, 3584, 2)
# xpow None (4, 27, 3584, 2) xpow_ds (4, 27, 597, 2) xpow_smooth (4, 27, 597, 2)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/SEMC_odor_13_bipo_all_noWM_physFT.npz shape (53, 3584, 10)
# xpow None (4, 53, 3584, 10) xpow_ds (4, 53, 597, 10) xpow_smooth (4, 53, 597, 10)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/SEMC_odor_5_bipo_all_noWM_physFT.npz shape (53, 3584, 3)
# xpow None (4, 53, 3584, 3) xpow_ds (4, 53, 597, 3) xpow_smooth (4, 53, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/FERJ_odor_1_bipo_all_noWM_physFT.npz shape (32, 3584, 4)
# xpow None (4, 32, 3584, 4) xpow_ds (4, 32, 597, 4) xpow_smooth (4, 32, 597, 4)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/FERJ_odor_2_bipo_all_noWM_physFT.npz shape (32, 3584, 2)
# xpow None (4, 32, 3584, 2) xpow_ds (4, 32, 597, 2) xpow_smooth (4, 32, 597, 2)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/VACJ_odor_13_bipo_all_noWM_physFT.npz shape (39, 3584, 4)
# xpow None (4, 39, 3584, 4) xpow_ds (4, 39, 597, 4) xpow_smooth (4, 39, 597, 4)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/PIRJ_odor_4_bipo_all_noWM_physFT.npz shape (18, 3584, 4)
# xpow None (4, 18, 3584, 4) xpow_ds (4, 18, 597, 4) xpow_smooth (4, 18, 597, 4)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/PIRJ_odor_5_bipo_all_noWM_physFT.npz shape (18, 3584, 1)
# xpow None (4, 18, 3584, 1) xpow_ds (4, 18, 597, 1) xpow_smooth (4, 18, 597, 1)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/PIRJ_odor_6_bipo_all_noWM_physFT.npz shape (18, 3584, 10)
# xpow None (4, 18, 3584, 10) xpow_ds (4, 18, 597, 10) xpow_smooth (4, 18, 597, 10)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/PIRJ_odor_7_bipo_all_noWM_physFT.npz shape (18, 3584, 10)
# xpow None (4, 18, 3584, 10) xpow_ds (4, 18, 597, 10) xpow_smooth (4, 18, 597, 10)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/PIRJ_odor_9_bipo_all_noWM_physFT.npz shape (18, 3584, 6)
# xpow None (4, 18, 3584, 6) xpow_ds (4, 18, 597, 6) xpow_smooth (4, 18, 597, 6)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/VACJ_odor_16_bipo_all_noWM_physFT.npz shape (39, 3584, 3)
# xpow None (4, 39, 3584, 3) xpow_ds (4, 39, 597, 3) xpow_smooth (4, 39, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/VACJ_odor_17_bipo_all_noWM_physFT.npz shape (39, 3584, 2)
# xpow None (4, 39, 3584, 2) xpow_ds (4, 39, 597, 2) xpow_smooth (4, 39, 597, 2)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/LEFC_odor_4_bipo_all_noWM_physFT.npz shape (27, 3584, 4)
# xpow None (4, 27, 3584, 4) xpow_ds (4, 27, 597, 4) xpow_smooth (4, 27, 597, 4)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/CHAF_odor_8_bipo_all_noWM_physFT.npz shape (61, 3584, 3)
# xpow None (4, 61, 3584, 3) xpow_ds (4, 61, 597, 3) xpow_smooth (4, 61, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/CHAF_odor_9_bipo_all_noWM_physFT.npz shape (61, 3584, 5)
# xpow None (4, 61, 3584, 5) xpow_ds (4, 61, 597, 5) xpow_smooth (4, 61, 597, 5)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/FERJ_odor_5_bipo_all_noWM_physFT.npz shape (32, 3584, 3)
# xpow None (4, 32, 3584, 3) xpow_ds (4, 32, 597, 3) xpow_smooth (4, 32, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/FERJ_odor_7_bipo_all_noWM_physFT.npz shape (32, 3584, 3)
# xpow None (4, 32, 3584, 3) xpow_ds (4, 32, 597, 3) xpow_smooth (4, 32, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/LEFC_odor_16_bipo_all_noWM_physFT.npz shape (27, 3584, 16)
# xpow None (4, 27, 3584, 16) xpow_ds (4, 27, 597, 16) xpow_smooth (4, 27, 597, 16)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/LEFC_odor_17_bipo_all_noWM_physFT.npz shape (27, 3584, 7)
# xpow None (4, 27, 3584, 7) xpow_ds (4, 27, 597, 7) xpow_smooth (4, 27, 597, 7)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/SEMC_odor_11_bipo_all_noWM_physFT.npz shape (53, 3584, 4)
# xpow None (4, 53, 3584, 4) xpow_ds (4, 53, 597, 4) xpow_smooth (4, 53, 597, 4)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/SEMC_odor_12_bipo_all_noWM_physFT.npz shape (53, 3584, 6)
# xpow None (4, 53, 3584, 6) xpow_ds (4, 53, 597, 6) xpow_smooth (4, 53, 597, 6)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/VACJ_odor_11_bipo_all_noWM_physFT.npz shape (39, 3584, 3)
# xpow None (4, 39, 3584, 3) xpow_ds (4, 39, 597, 3) xpow_smooth (4, 39, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/VACJ_odor_12_bipo_all_noWM_physFT.npz shape (39, 3584, 2)
# xpow None (4, 39, 3584, 2) xpow_ds (4, 39, 597, 2) xpow_smooth (4, 39, 597, 2)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/SEMC_odor_7_bipo_all_noWM_physFT.npz shape (53, 3584, 4)
# xpow None (4, 53, 3584, 4) xpow_ds (4, 53, 597, 4) xpow_smooth (4, 53, 597, 4)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/SEMC_odor_8_bipo_all_noWM_physFT.npz shape (53, 3584, 3)
# xpow None (4, 53, 3584, 3) xpow_ds (4, 53, 597, 3) xpow_smooth (4, 53, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/CHAF_odor_3_bipo_all_noWM_physFT.npz shape (61, 3584, 3)
# xpow None (4, 61, 3584, 3) xpow_ds (4, 61, 597, 3) xpow_smooth (4, 61, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/CHAF_odor_4_bipo_all_noWM_physFT.npz shape (61, 3584, 1)
# xpow None (4, 61, 3584, 1) xpow_ds (4, 61, 597, 1) xpow_smooth (4, 61, 597, 1)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/FERJ_odor_16_bipo_all_noWM_physFT.npz shape (32, 3584, 3)
# xpow None (4, 32, 3584, 3) xpow_ds (4, 32, 597, 3) xpow_smooth (4, 32, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/FERJ_odor_17_bipo_all_noWM_physFT.npz shape (32, 3584, 9)
# xpow None (4, 32, 3584, 9) xpow_ds (4, 32, 597, 9) xpow_smooth (4, 32, 597, 9)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/LEFC_odor_2_bipo_all_noWM_physFT.npz shape (27, 3584, 5)
# xpow None (4, 27, 3584, 5) xpow_ds (4, 27, 597, 5) xpow_smooth (4, 27, 597, 5)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/LEFC_odor_3_bipo_all_noWM_physFT.npz shape (27, 3584, 4)
# xpow None (4, 27, 3584, 4) xpow_ds (4, 27, 597, 4) xpow_smooth (4, 27, 597, 4)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/VACJ_odor_14_bipo_all_noWM_physFT.npz shape (39, 3584, 3)
# xpow None (4, 39, 3584, 3) xpow_ds (4, 39, 597, 3) xpow_smooth (4, 39, 597, 3)
# time (3584,) time ds (597,)
# all files in archive ['labels', 'x', 'aal', 'xyz', 'channels', 'sf', 'Mai', 'BA', 'Mai_RL']
# --> compute power on :  Encoding_By_Odor/VACJ_odor_15_bipo_all_noWM_physFT.npz shape (39, 3584, 2)
# xpow None (4, 39, 3584, 2) xpow_ds (4, 39, 597, 2) xpow_smooth (4, 39, 597, 2)
# time (3584,) time ds (597,)

# %% [markdown]
# #### Concatenate power by cond (ds, smooth, None)

# %%
import numpy as np
from brainpipe.system import study
from utils import odor_groups_3wgth as dict_
from os.path import join, exists
from os import makedirs
from itertools import product

st = study('Olfacto')
PATH = join(st.path, 'feature/TPSim_power_data/')
PATH_OD = join(PATH, 'Power_all_elecs_E_R_by_odor_all_elecsFT/')
od_name = join(PATH_OD, '{}_odor_{}_bipo_all_E_4theta.npz')
PATH_COND = join(PATH, 'Power_all_elecs_E_R_by_cond_3groups_v=1_elecs=all/')
save_name = join(PATH_COND, '{}_odor_{}_E_4theta.npz')
data_concat = ['xpow_ds','xpow_None','xpow_smooth']

for su in dict_:
    for cond in dict_[su]:
        print('>>> processing:', su, cond)
        all_pow = []
        for data_c in data_concat:
            pow_data = np.array([])
            for od in dict_[su][cond]:
                mat = np.load(od_name.format(su,od),allow_pickle=True)
                pow_data = np.concatenate((pow_data, mat[data_c]),axis=-1) \
                                                if np.size(pow_data) else mat[data_c]
            all_pow.append(pow_data)
            print(data_c, su, od, cond, pow_data.shape)
        dict_pow = {}
        for file in mat.files:
            dict_pow[file] = mat[file]
        for i,data_c in enumerate(data_concat):
            dict_pow[data_c] = all_pow[i]
        np.savez(save_name.format(su,cond),**dict_pow)
# Out:
# -> Olfacto loaded
# >>> processing: CHAF low
# xpow_ds CHAF 4 low (4, 61, 597, 5)
# xpow_None CHAF 4 low (4, 61, 3584, 5)
# xpow_smooth CHAF 4 low (4, 61, 597, 5)
# >>> processing: CHAF mid
# xpow_ds CHAF 8 mid (4, 61, 597, 4)
# xpow_None CHAF 8 mid (4, 61, 3584, 4)
# xpow_smooth CHAF 8 mid (4, 61, 597, 4)
# >>> processing: CHAF high
# xpow_ds CHAF 9 high (4, 61, 597, 12)
# xpow_None CHAF 9 high (4, 61, 3584, 12)
# xpow_smooth CHAF 9 high (4, 61, 597, 12)
# >>> processing: VACJ low
# xpow_ds VACJ 14 low (4, 39, 597, 9)
# xpow_None VACJ 14 low (4, 39, 3584, 9)
# xpow_smooth VACJ 14 low (4, 39, 597, 9)
# >>> processing: VACJ mid
# xpow_ds VACJ 17 mid (4, 39, 597, 4)
# xpow_None VACJ 17 mid (4, 39, 3584, 4)
# xpow_smooth VACJ 17 mid (4, 39, 597, 4)
# >>> processing: VACJ high
# xpow_ds VACJ 15 high (4, 39, 597, 9)
# xpow_None VACJ 15 high (4, 39, 3584, 9)
# xpow_smooth VACJ 15 high (4, 39, 597, 9)
# >>> processing: SEMC low
# xpow_ds SEMC 13 low (4, 53, 597, 21)
# xpow_None SEMC 13 low (4, 53, 3584, 21)
# xpow_smooth SEMC 13 low (4, 53, 597, 21)
# >>> processing: SEMC mid
# xpow_ds SEMC 12 mid (4, 53, 597, 10)
# xpow_None SEMC 12 mid (4, 53, 3584, 10)
# xpow_smooth SEMC 12 mid (4, 53, 597, 10)
# >>> processing: SEMC high
# xpow_ds SEMC 8 high (4, 53, 597, 9)
# xpow_None SEMC 8 high (4, 53, 3584, 9)
# xpow_smooth SEMC 8 high (4, 53, 597, 9)
# >>> processing: PIRJ low
# xpow_ds PIRJ 5 low (4, 18, 597, 14)
# xpow_None PIRJ 5 low (4, 18, 3584, 14)
# xpow_smooth PIRJ 5 low (4, 18, 597, 14)
# >>> processing: PIRJ mid
# xpow_ds PIRJ 4 mid (4, 18, 597, 9)
# xpow_None PIRJ 4 mid (4, 18, 3584, 9)
# xpow_smooth PIRJ 4 mid (4, 18, 597, 9)
# >>> processing: PIRJ high
# xpow_ds PIRJ 7 high (4, 18, 597, 20)
# xpow_None PIRJ 7 high (4, 18, 3584, 20)
# xpow_smooth PIRJ 7 high (4, 18, 597, 20)
# >>> processing: LEFC low
# xpow_ds LEFC 16 low (4, 27, 597, 23)
# xpow_None LEFC 16 low (4, 27, 3584, 23)
# xpow_smooth LEFC 16 low (4, 27, 597, 23)
# >>> processing: LEFC mid
# xpow_ds LEFC 3 mid (4, 27, 597, 15)
# xpow_None LEFC 3 mid (4, 27, 3584, 15)
# xpow_smooth LEFC 3 mid (4, 27, 597, 15)
# >>> processing: LEFC high
# xpow_ds LEFC 14 high (4, 27, 597, 17)
# xpow_None LEFC 14 high (4, 27, 3584, 17)
# xpow_smooth LEFC 14 high (4, 27, 597, 17)
# >>> processing: FERJ low
# xpow_ds FERJ 12 low (4, 32, 597, 16)
# xpow_None FERJ 12 low (4, 32, 3584, 16)
# xpow_smooth FERJ 12 low (4, 32, 597, 16)
# >>> processing: FERJ mid
# xpow_ds FERJ 13 mid (4, 32, 597, 6)
# xpow_None FERJ 13 mid (4, 32, 3584, 6)
# xpow_smooth FERJ 13 mid (4, 32, 597, 6)
# >>> processing: FERJ high
# xpow_ds FERJ 1 high (4, 32, 597, 9)
# xpow_None FERJ 1 high (4, 32, 3584, 9)
# xpow_smooth FERJ 1 high (4, 32, 597, 9)

# %% [markdown]
# #### Compute between-TPD by cond

# %%
from itertools import product,combinations
from scipy import stats
"""
Compute TPSim by combining all odors from each CONDITION
"""
###############################################################################
st = study('Olfacto')
path_data = join(st.path, 'feature/TPSim_power_data/Power_all_elecs_E_R_by_cond_3groups_v=1_elecs=all/')
pow_file = join(path_data, '{}_odor_{}_E_4theta.npz')
pathsave = join(st.path,'feature/TPSim_3groups_Enc/TPS_btw_v=1_elecs=all_ds_sm/')#_'+RT_type+'/')
savename = join(pathsave,'TPS_pears_{}_{}_btw_theta{}_data={}_win={}.npz')
###############################################################################
subjects = ['PIRJ','CHAF','FERJ','VACJ','SEMC','LEFC']
conds = ['low','mid','high']
data_concat = ['xpow_ds','xpow_None','xpow_smooth']
wins = {'3s': [-1,2], '2s':[0,2]}

def tpsim_by_cond(su,cond,data_type,win_type):
    print(su,cond,data_type,win_type)
    mat = np.load(pow_file.format(su,cond),allow_pickle=True)
    time = mat['time_ds']-3 if data_type in ['xpow_ds','xpow_smooth'] else mat['time']-3
    lims = wins[win_type]
    nsel = [i for i,t in enumerate(time) if lims[0]<=t<=lims[1]]
    print(nsel[0],nsel[-1],len(nsel))
    pow_data = mat[data_type][:,:,nsel,:] #3584 points
    _,nelecs,npts,ntrials = pow_data.shape
    for f in range(len(mat['f'])):
        data_freq = pow_data[f]
        R_freq, p_freq = np.array([]), np.array([])
        for elec in range(nelecs):
            pow0 = data_freq[elec,...]
            R_trials, p_trials = np.array([]), np.array([])
            for t0, t1 in combinations(np.arange(ntrials), 2):
                R, p = stats.pearsonr(pow0[:,t0],pow0[:,t1])
                D = 1 - R # <<<<<<< HERE TO CHANGE FOR DISTANCE COMPUTATIONS
                R_trials = np.vstack((R_trials,D)) if np.size(R_trials) else D
                p_trials = np.vstack((p_trials,p)) if np.size(p_trials) else p
            R_freq = np.vstack((R_freq,R_trials.T)) if np.size(R_freq) else R_trials.T
            p_freq = np.vstack((p_freq,p_trials.T)) if np.size(p_freq) else p_trials.T
        #R_freq = np.arctanh(R_freq)
        print(su,cond,'theta',f,'TPSim',R_freq.shape, p_freq.shape,'initial data',pow_data.shape)
        dict_ = {'tps':R_freq, 'pval':p_freq,'label':mat['labels'],
                           'channel':mat['channels'], 'xyz':mat['xyz']}
        np.savez(savename.format(su,cond,str(f),data_type,win_type),**dict_)

for su,cond,data_type,win in product(subjects,conds,data_concat,wins):
    tpsim_by_cond(su,cond,data_type,win)
# Parallel(n_jobs=-1)(delayed(
#     tpsim_by_cond)(su,cond) for su,cond in product(subjects,conds))
# Out:
# -> Olfacto loaded
# PIRJ low xpow_ds 3s
# 171 426 256
# PIRJ low theta 0 TPSim (18, 91) (18, 91) initial data (4, 18, 256, 14)
# PIRJ low theta 1 TPSim (18, 91) (18, 91) initial data (4, 18, 256, 14)
# PIRJ low theta 2 TPSim (18, 91) (18, 91) initial data (4, 18, 256, 14)
# PIRJ low theta 3 TPSim (18, 91) (18, 91) initial data (4, 18, 256, 14)
# PIRJ low xpow_ds 2s
# 256 426 171
# PIRJ low theta 0 TPSim (18, 91) (18, 91) initial data (4, 18, 171, 14)
# PIRJ low theta 1 TPSim (18, 91) (18, 91) initial data (4, 18, 171, 14)
# PIRJ low theta 2 TPSim (18, 91) (18, 91) initial data (4, 18, 171, 14)
# PIRJ low theta 3 TPSim (18, 91) (18, 91) initial data (4, 18, 171, 14)
# PIRJ low xpow_None 3s
# 1024 2560 1537
# PIRJ low theta 0 TPSim (18, 91) (18, 91) initial data (4, 18, 1537, 14)
# PIRJ low theta 1 TPSim (18, 91) (18, 91) initial data (4, 18, 1537, 14)
# PIRJ low theta 2 TPSim (18, 91) (18, 91) initial data (4, 18, 1537, 14)
# PIRJ low theta 3 TPSim (18, 91) (18, 91) initial data (4, 18, 1537, 14)
# PIRJ low xpow_None 2s
# 1536 2560 1025
# PIRJ low theta 0 TPSim (18, 91) (18, 91) initial data (4, 18, 1025, 14)
# PIRJ low theta 1 TPSim (18, 91) (18, 91) initial data (4, 18, 1025, 14)
# PIRJ low theta 2 TPSim (18, 91) (18, 91) initial data (4, 18, 1025, 14)
# PIRJ low theta 3 TPSim (18, 91) (18, 91) initial data (4, 18, 1025, 14)
# PIRJ low xpow_smooth 3s
# 171 426 256
# PIRJ low theta 0 TPSim (18, 91) (18, 91) initial data (4, 18, 256, 14)
# PIRJ low theta 1 TPSim (18, 91) (18, 91) initial data (4, 18, 256, 14)
# PIRJ low theta 2 TPSim (18, 91) (18, 91) initial data (4, 18, 256, 14)
# PIRJ low theta 3 TPSim (18, 91) (18, 91) initial data (4, 18, 256, 14)
# PIRJ low xpow_smooth 2s
# 256 426 171
# PIRJ low theta 0 TPSim (18, 91) (18, 91) initial data (4, 18, 171, 14)
# PIRJ low theta 1 TPSim (18, 91) (18, 91) initial data (4, 18, 171, 14)
# PIRJ low theta 2 TPSim (18, 91) (18, 91) initial data (4, 18, 171, 14)
# PIRJ low theta 3 TPSim (18, 91) (18, 91) initial data (4, 18, 171, 14)
# PIRJ mid xpow_ds 3s
# 171 426 256
# PIRJ mid theta 0 TPSim (18, 36) (18, 36) initial data (4, 18, 256, 9)
# PIRJ mid theta 1 TPSim (18, 36) (18, 36) initial data (4, 18, 256, 9)
# PIRJ mid theta 2 TPSim (18, 36) (18, 36) initial data (4, 18, 256, 9)
# PIRJ mid theta 3 TPSim (18, 36) (18, 36) initial data (4, 18, 256, 9)
# PIRJ mid xpow_ds 2s
# 256 426 171
# PIRJ mid theta 0 TPSim (18, 36) (18, 36) initial data (4, 18, 171, 9)
# PIRJ mid theta 1 TPSim (18, 36) (18, 36) initial data (4, 18, 171, 9)
# PIRJ mid theta 2 TPSim (18, 36) (18, 36) initial data (4, 18, 171, 9)
# PIRJ mid theta 3 TPSim (18, 36) (18, 36) initial data (4, 18, 171, 9)
# PIRJ mid xpow_None 3s
# 1024 2560 1537
# PIRJ mid theta 0 TPSim (18, 36) (18, 36) initial data (4, 18, 1537, 9)
# PIRJ mid theta 1 TPSim (18, 36) (18, 36) initial data (4, 18, 1537, 9)
# PIRJ mid theta 2 TPSim (18, 36) (18, 36) initial data (4, 18, 1537, 9)
# PIRJ mid theta 3 TPSim (18, 36) (18, 36) initial data (4, 18, 1537, 9)
# PIRJ mid xpow_None 2s
# 1536 2560 1025
# PIRJ mid theta 0 TPSim (18, 36) (18, 36) initial data (4, 18, 1025, 9)
# PIRJ mid theta 1 TPSim (18, 36) (18, 36) initial data (4, 18, 1025, 9)
# PIRJ mid theta 2 TPSim (18, 36) (18, 36) initial data (4, 18, 1025, 9)
# PIRJ mid theta 3 TPSim (18, 36) (18, 36) initial data (4, 18, 1025, 9)
# PIRJ mid xpow_smooth 3s
# 171 426 256
# PIRJ mid theta 0 TPSim (18, 36) (18, 36) initial data (4, 18, 256, 9)
# PIRJ mid theta 1 TPSim (18, 36) (18, 36) initial data (4, 18, 256, 9)
# PIRJ mid theta 2 TPSim (18, 36) (18, 36) initial data (4, 18, 256, 9)
# PIRJ mid theta 3 TPSim (18, 36) (18, 36) initial data (4, 18, 256, 9)
# PIRJ mid xpow_smooth 2s
# 256 426 171
# PIRJ mid theta 0 TPSim (18, 36) (18, 36) initial data (4, 18, 171, 9)
# PIRJ mid theta 1 TPSim (18, 36) (18, 36) initial data (4, 18, 171, 9)
# PIRJ mid theta 2 TPSim (18, 36) (18, 36) initial data (4, 18, 171, 9)
# PIRJ mid theta 3 TPSim (18, 36) (18, 36) initial data (4, 18, 171, 9)
# PIRJ high xpow_ds 3s
# 171 426 256
# PIRJ high theta 0 TPSim (18, 190) (18, 190) initial data (4, 18, 256, 20)
# PIRJ high theta 1 TPSim (18, 190) (18, 190) initial data (4, 18, 256, 20)
# PIRJ high theta 2 TPSim (18, 190) (18, 190) initial data (4, 18, 256, 20)
# PIRJ high theta 3 TPSim (18, 190) (18, 190) initial data (4, 18, 256, 20)
# PIRJ high xpow_ds 2s
# 256 426 171
# PIRJ high theta 0 TPSim (18, 190) (18, 190) initial data (4, 18, 171, 20)
# PIRJ high theta 1 TPSim (18, 190) (18, 190) initial data (4, 18, 171, 20)
# PIRJ high theta 2 TPSim (18, 190) (18, 190) initial data (4, 18, 171, 20)
# PIRJ high theta 3 TPSim (18, 190) (18, 190) initial data (4, 18, 171, 20)
# PIRJ high xpow_None 3s
# 1024 2560 1537
# PIRJ high theta 0 TPSim (18, 190) (18, 190) initial data (4, 18, 1537, 20)
# PIRJ high theta 1 TPSim (18, 190) (18, 190) initial data (4, 18, 1537, 20)
# PIRJ high theta 2 TPSim (18, 190) (18, 190) initial data (4, 18, 1537, 20)
# PIRJ high theta 3 TPSim (18, 190) (18, 190) initial data (4, 18, 1537, 20)
# PIRJ high xpow_None 2s
# 1536 2560 1025
# PIRJ high theta 0 TPSim (18, 190) (18, 190) initial data (4, 18, 1025, 20)
# PIRJ high theta 1 TPSim (18, 190) (18, 190) initial data (4, 18, 1025, 20)
# PIRJ high theta 2 TPSim (18, 190) (18, 190) initial data (4, 18, 1025, 20)
# PIRJ high theta 3 TPSim (18, 190) (18, 190) initial data (4, 18, 1025, 20)
# PIRJ high xpow_smooth 3s
# 171 426 256
# PIRJ high theta 0 TPSim (18, 190) (18, 190) initial data (4, 18, 256, 20)
# PIRJ high theta 1 TPSim (18, 190) (18, 190) initial data (4, 18, 256, 20)
# PIRJ high theta 2 TPSim (18, 190) (18, 190) initial data (4, 18, 256, 20)
# PIRJ high theta 3 TPSim (18, 190) (18, 190) initial data (4, 18, 256, 20)
# PIRJ high xpow_smooth 2s
# 256 426 171
# PIRJ high theta 0 TPSim (18, 190) (18, 190) initial data (4, 18, 171, 20)
# PIRJ high theta 1 TPSim (18, 190) (18, 190) initial data (4, 18, 171, 20)
# PIRJ high theta 2 TPSim (18, 190) (18, 190) initial data (4, 18, 171, 20)
# PIRJ high theta 3 TPSim (18, 190) (18, 190) initial data (4, 18, 171, 20)
# CHAF low xpow_ds 3s
# 171 426 256
# CHAF low theta 0 TPSim (61, 10) (61, 10) initial data (4, 61, 256, 5)
# CHAF low theta 1 TPSim (61, 10) (61, 10) initial data (4, 61, 256, 5)
# CHAF low theta 2 TPSim (61, 10) (61, 10) initial data (4, 61, 256, 5)
# CHAF low theta 3 TPSim (61, 10) (61, 10) initial data (4, 61, 256, 5)
# CHAF low xpow_ds 2s
# 256 426 171
# CHAF low theta 0 TPSim (61, 10) (61, 10) initial data (4, 61, 171, 5)
# CHAF low theta 1 TPSim (61, 10) (61, 10) initial data (4, 61, 171, 5)
# CHAF low theta 2 TPSim (61, 10) (61, 10) initial data (4, 61, 171, 5)
# CHAF low theta 3 TPSim (61, 10) (61, 10) initial data (4, 61, 171, 5)
# CHAF low xpow_None 3s
# 1024 2560 1537
# CHAF low theta 0 TPSim (61, 10) (61, 10) initial data (4, 61, 1537, 5)
# CHAF low theta 1 TPSim (61, 10) (61, 10) initial data (4, 61, 1537, 5)
# CHAF low theta 2 TPSim (61, 10) (61, 10) initial data (4, 61, 1537, 5)
# CHAF low theta 3 TPSim (61, 10) (61, 10) initial data (4, 61, 1537, 5)
# CHAF low xpow_None 2s
# 1536 2560 1025
# CHAF low theta 0 TPSim (61, 10) (61, 10) initial data (4, 61, 1025, 5)
# CHAF low theta 1 TPSim (61, 10) (61, 10) initial data (4, 61, 1025, 5)
# CHAF low theta 2 TPSim (61, 10) (61, 10) initial data (4, 61, 1025, 5)
# CHAF low theta 3 TPSim (61, 10) (61, 10) initial data (4, 61, 1025, 5)
# CHAF low xpow_smooth 3s
# 171 426 256
# CHAF low theta 0 TPSim (61, 10) (61, 10) initial data (4, 61, 256, 5)
# CHAF low theta 1 TPSim (61, 10) (61, 10) initial data (4, 61, 256, 5)
# CHAF low theta 2 TPSim (61, 10) (61, 10) initial data (4, 61, 256, 5)
# CHAF low theta 3 TPSim (61, 10) (61, 10) initial data (4, 61, 256, 5)
# CHAF low xpow_smooth 2s
# 256 426 171
# CHAF low theta 0 TPSim (61, 10) (61, 10) initial data (4, 61, 171, 5)
# CHAF low theta 1 TPSim (61, 10) (61, 10) initial data (4, 61, 171, 5)
# CHAF low theta 2 TPSim (61, 10) (61, 10) initial data (4, 61, 171, 5)
# CHAF low theta 3 TPSim (61, 10) (61, 10) initial data (4, 61, 171, 5)
# CHAF mid xpow_ds 3s
# 171 426 256
# CHAF mid theta 0 TPSim (61, 6) (61, 6) initial data (4, 61, 256, 4)
# CHAF mid theta 1 TPSim (61, 6) (61, 6) initial data (4, 61, 256, 4)
# CHAF mid theta 2 TPSim (61, 6) (61, 6) initial data (4, 61, 256, 4)
# CHAF mid theta 3 TPSim (61, 6) (61, 6) initial data (4, 61, 256, 4)
# CHAF mid xpow_ds 2s
# 256 426 171
# CHAF mid theta 0 TPSim (61, 6) (61, 6) initial data (4, 61, 171, 4)
# CHAF mid theta 1 TPSim (61, 6) (61, 6) initial data (4, 61, 171, 4)
# CHAF mid theta 2 TPSim (61, 6) (61, 6) initial data (4, 61, 171, 4)
# CHAF mid theta 3 TPSim (61, 6) (61, 6) initial data (4, 61, 171, 4)
# CHAF mid xpow_None 3s
# 1024 2560 1537
# CHAF mid theta 0 TPSim (61, 6) (61, 6) initial data (4, 61, 1537, 4)
# CHAF mid theta 1 TPSim (61, 6) (61, 6) initial data (4, 61, 1537, 4)
# CHAF mid theta 2 TPSim (61, 6) (61, 6) initial data (4, 61, 1537, 4)
# CHAF mid theta 3 TPSim (61, 6) (61, 6) initial data (4, 61, 1537, 4)
# CHAF mid xpow_None 2s
# 1536 2560 1025
# CHAF mid theta 0 TPSim (61, 6) (61, 6) initial data (4, 61, 1025, 4)
# CHAF mid theta 1 TPSim (61, 6) (61, 6) initial data (4, 61, 1025, 4)
# CHAF mid theta 2 TPSim (61, 6) (61, 6) initial data (4, 61, 1025, 4)
# CHAF mid theta 3 TPSim (61, 6) (61, 6) initial data (4, 61, 1025, 4)
# CHAF mid xpow_smooth 3s
# 171 426 256
# CHAF mid theta 0 TPSim (61, 6) (61, 6) initial data (4, 61, 256, 4)
# CHAF mid theta 1 TPSim (61, 6) (61, 6) initial data (4, 61, 256, 4)
# CHAF mid theta 2 TPSim (61, 6) (61, 6) initial data (4, 61, 256, 4)
# CHAF mid theta 3 TPSim (61, 6) (61, 6) initial data (4, 61, 256, 4)
# CHAF mid xpow_smooth 2s
# 256 426 171
# CHAF mid theta 0 TPSim (61, 6) (61, 6) initial data (4, 61, 171, 4)
# CHAF mid theta 1 TPSim (61, 6) (61, 6) initial data (4, 61, 171, 4)
# CHAF mid theta 2 TPSim (61, 6) (61, 6) initial data (4, 61, 171, 4)
# CHAF mid theta 3 TPSim (61, 6) (61, 6) initial data (4, 61, 171, 4)
# CHAF high xpow_ds 3s
# 171 426 256
# CHAF high theta 0 TPSim (61, 66) (61, 66) initial data (4, 61, 256, 12)
# CHAF high theta 1 TPSim (61, 66) (61, 66) initial data (4, 61, 256, 12)
# CHAF high theta 2 TPSim (61, 66) (61, 66) initial data (4, 61, 256, 12)
# CHAF high theta 3 TPSim (61, 66) (61, 66) initial data (4, 61, 256, 12)
# CHAF high xpow_ds 2s
# 256 426 171
# CHAF high theta 0 TPSim (61, 66) (61, 66) initial data (4, 61, 171, 12)
# CHAF high theta 1 TPSim (61, 66) (61, 66) initial data (4, 61, 171, 12)
# CHAF high theta 2 TPSim (61, 66) (61, 66) initial data (4, 61, 171, 12)
# CHAF high theta 3 TPSim (61, 66) (61, 66) initial data (4, 61, 171, 12)
# CHAF high xpow_None 3s
# 1024 2560 1537
# CHAF high theta 0 TPSim (61, 66) (61, 66) initial data (4, 61, 1537, 12)
# CHAF high theta 1 TPSim (61, 66) (61, 66) initial data (4, 61, 1537, 12)
# CHAF high theta 2 TPSim (61, 66) (61, 66) initial data (4, 61, 1537, 12)
# CHAF high theta 3 TPSim (61, 66) (61, 66) initial data (4, 61, 1537, 12)
# CHAF high xpow_None 2s
# 1536 2560 1025
# CHAF high theta 0 TPSim (61, 66) (61, 66) initial data (4, 61, 1025, 12)
# CHAF high theta 1 TPSim (61, 66) (61, 66) initial data (4, 61, 1025, 12)
# CHAF high theta 2 TPSim (61, 66) (61, 66) initial data (4, 61, 1025, 12)
# CHAF high theta 3 TPSim (61, 66) (61, 66) initial data (4, 61, 1025, 12)
# CHAF high xpow_smooth 3s
# 171 426 256
# CHAF high theta 0 TPSim (61, 66) (61, 66) initial data (4, 61, 256, 12)
# CHAF high theta 1 TPSim (61, 66) (61, 66) initial data (4, 61, 256, 12)
# CHAF high theta 2 TPSim (61, 66) (61, 66) initial data (4, 61, 256, 12)
# CHAF high theta 3 TPSim (61, 66) (61, 66) initial data (4, 61, 256, 12)
# CHAF high xpow_smooth 2s
# 256 426 171
# CHAF high theta 0 TPSim (61, 66) (61, 66) initial data (4, 61, 171, 12)
# CHAF high theta 1 TPSim (61, 66) (61, 66) initial data (4, 61, 171, 12)
# CHAF high theta 2 TPSim (61, 66) (61, 66) initial data (4, 61, 171, 12)
# CHAF high theta 3 TPSim (61, 66) (61, 66) initial data (4, 61, 171, 12)
# FERJ low xpow_ds 3s
# 171 426 256
# FERJ low theta 0 TPSim (32, 120) (32, 120) initial data (4, 32, 256, 16)
# FERJ low theta 1 TPSim (32, 120) (32, 120) initial data (4, 32, 256, 16)
# FERJ low theta 2 TPSim (32, 120) (32, 120) initial data (4, 32, 256, 16)
# FERJ low theta 3 TPSim (32, 120) (32, 120) initial data (4, 32, 256, 16)
# FERJ low xpow_ds 2s
# 256 426 171
# FERJ low theta 0 TPSim (32, 120) (32, 120) initial data (4, 32, 171, 16)
# FERJ low theta 1 TPSim (32, 120) (32, 120) initial data (4, 32, 171, 16)
# FERJ low theta 2 TPSim (32, 120) (32, 120) initial data (4, 32, 171, 16)
# FERJ low theta 3 TPSim (32, 120) (32, 120) initial data (4, 32, 171, 16)
# FERJ low xpow_None 3s
# 1024 2560 1537
# FERJ low theta 0 TPSim (32, 120) (32, 120) initial data (4, 32, 1537, 16)
# FERJ low theta 1 TPSim (32, 120) (32, 120) initial data (4, 32, 1537, 16)
# FERJ low theta 2 TPSim (32, 120) (32, 120) initial data (4, 32, 1537, 16)
# FERJ low theta 3 TPSim (32, 120) (32, 120) initial data (4, 32, 1537, 16)
# FERJ low xpow_None 2s
# 1536 2560 1025
# FERJ low theta 0 TPSim (32, 120) (32, 120) initial data (4, 32, 1025, 16)
# FERJ low theta 1 TPSim (32, 120) (32, 120) initial data (4, 32, 1025, 16)
# FERJ low theta 2 TPSim (32, 120) (32, 120) initial data (4, 32, 1025, 16)
# FERJ low theta 3 TPSim (32, 120) (32, 120) initial data (4, 32, 1025, 16)
# FERJ low xpow_smooth 3s
# 171 426 256
# FERJ low theta 0 TPSim (32, 120) (32, 120) initial data (4, 32, 256, 16)
# FERJ low theta 1 TPSim (32, 120) (32, 120) initial data (4, 32, 256, 16)
# FERJ low theta 2 TPSim (32, 120) (32, 120) initial data (4, 32, 256, 16)
# FERJ low theta 3 TPSim (32, 120) (32, 120) initial data (4, 32, 256, 16)
# FERJ low xpow_smooth 2s
# 256 426 171
# FERJ low theta 0 TPSim (32, 120) (32, 120) initial data (4, 32, 171, 16)
# FERJ low theta 1 TPSim (32, 120) (32, 120) initial data (4, 32, 171, 16)
# FERJ low theta 2 TPSim (32, 120) (32, 120) initial data (4, 32, 171, 16)
# FERJ low theta 3 TPSim (32, 120) (32, 120) initial data (4, 32, 171, 16)
# FERJ mid xpow_ds 3s
# 171 426 256
# FERJ mid theta 0 TPSim (32, 15) (32, 15) initial data (4, 32, 256, 6)
# FERJ mid theta 1 TPSim (32, 15) (32, 15) initial data (4, 32, 256, 6)
# FERJ mid theta 2 TPSim (32, 15) (32, 15) initial data (4, 32, 256, 6)
# FERJ mid theta 3 TPSim (32, 15) (32, 15) initial data (4, 32, 256, 6)
# FERJ mid xpow_ds 2s
# 256 426 171
# FERJ mid theta 0 TPSim (32, 15) (32, 15) initial data (4, 32, 171, 6)
# FERJ mid theta 1 TPSim (32, 15) (32, 15) initial data (4, 32, 171, 6)
# FERJ mid theta 2 TPSim (32, 15) (32, 15) initial data (4, 32, 171, 6)
# FERJ mid theta 3 TPSim (32, 15) (32, 15) initial data (4, 32, 171, 6)
# FERJ mid xpow_None 3s
# 1024 2560 1537
# FERJ mid theta 0 TPSim (32, 15) (32, 15) initial data (4, 32, 1537, 6)
# FERJ mid theta 1 TPSim (32, 15) (32, 15) initial data (4, 32, 1537, 6)
# FERJ mid theta 2 TPSim (32, 15) (32, 15) initial data (4, 32, 1537, 6)
# FERJ mid theta 3 TPSim (32, 15) (32, 15) initial data (4, 32, 1537, 6)
# FERJ mid xpow_None 2s
# 1536 2560 1025
# FERJ mid theta 0 TPSim (32, 15) (32, 15) initial data (4, 32, 1025, 6)
# FERJ mid theta 1 TPSim (32, 15) (32, 15) initial data (4, 32, 1025, 6)
# FERJ mid theta 2 TPSim (32, 15) (32, 15) initial data (4, 32, 1025, 6)
# FERJ mid theta 3 TPSim (32, 15) (32, 15) initial data (4, 32, 1025, 6)
# FERJ mid xpow_smooth 3s
# 171 426 256
# FERJ mid theta 0 TPSim (32, 15) (32, 15) initial data (4, 32, 256, 6)
# FERJ mid theta 1 TPSim (32, 15) (32, 15) initial data (4, 32, 256, 6)
# FERJ mid theta 2 TPSim (32, 15) (32, 15) initial data (4, 32, 256, 6)
# FERJ mid theta 3 TPSim (32, 15) (32, 15) initial data (4, 32, 256, 6)
# FERJ mid xpow_smooth 2s
# 256 426 171
# FERJ mid theta 0 TPSim (32, 15) (32, 15) initial data (4, 32, 171, 6)
# FERJ mid theta 1 TPSim (32, 15) (32, 15) initial data (4, 32, 171, 6)
# FERJ mid theta 2 TPSim (32, 15) (32, 15) initial data (4, 32, 171, 6)
# FERJ mid theta 3 TPSim (32, 15) (32, 15) initial data (4, 32, 171, 6)
# FERJ high xpow_ds 3s
# 171 426 256
# FERJ high theta 0 TPSim (32, 36) (32, 36) initial data (4, 32, 256, 9)
# FERJ high theta 1 TPSim (32, 36) (32, 36) initial data (4, 32, 256, 9)
# FERJ high theta 2 TPSim (32, 36) (32, 36) initial data (4, 32, 256, 9)
# FERJ high theta 3 TPSim (32, 36) (32, 36) initial data (4, 32, 256, 9)
# FERJ high xpow_ds 2s
# 256 426 171
# FERJ high theta 0 TPSim (32, 36) (32, 36) initial data (4, 32, 171, 9)
# FERJ high theta 1 TPSim (32, 36) (32, 36) initial data (4, 32, 171, 9)
# FERJ high theta 2 TPSim (32, 36) (32, 36) initial data (4, 32, 171, 9)
# FERJ high theta 3 TPSim (32, 36) (32, 36) initial data (4, 32, 171, 9)
# FERJ high xpow_None 3s
# 1024 2560 1537
# FERJ high theta 0 TPSim (32, 36) (32, 36) initial data (4, 32, 1537, 9)
# FERJ high theta 1 TPSim (32, 36) (32, 36) initial data (4, 32, 1537, 9)
# FERJ high theta 2 TPSim (32, 36) (32, 36) initial data (4, 32, 1537, 9)
# FERJ high theta 3 TPSim (32, 36) (32, 36) initial data (4, 32, 1537, 9)
# FERJ high xpow_None 2s
# 1536 2560 1025
# FERJ high theta 0 TPSim (32, 36) (32, 36) initial data (4, 32, 1025, 9)
# FERJ high theta 1 TPSim (32, 36) (32, 36) initial data (4, 32, 1025, 9)
# FERJ high theta 2 TPSim (32, 36) (32, 36) initial data (4, 32, 1025, 9)
# FERJ high theta 3 TPSim (32, 36) (32, 36) initial data (4, 32, 1025, 9)
# FERJ high xpow_smooth 3s
# 171 426 256
# FERJ high theta 0 TPSim (32, 36) (32, 36) initial data (4, 32, 256, 9)
# FERJ high theta 1 TPSim (32, 36) (32, 36) initial data (4, 32, 256, 9)
# FERJ high theta 2 TPSim (32, 36) (32, 36) initial data (4, 32, 256, 9)
# FERJ high theta 3 TPSim (32, 36) (32, 36) initial data (4, 32, 256, 9)
# FERJ high xpow_smooth 2s
# 256 426 171
# FERJ high theta 0 TPSim (32, 36) (32, 36) initial data (4, 32, 171, 9)
# FERJ high theta 1 TPSim (32, 36) (32, 36) initial data (4, 32, 171, 9)
# FERJ high theta 2 TPSim (32, 36) (32, 36) initial data (4, 32, 171, 9)
# FERJ high theta 3 TPSim (32, 36) (32, 36) initial data (4, 32, 171, 9)
# VACJ low xpow_ds 3s
# 171 426 256
# VACJ low theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ low theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ low theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ low theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ low xpow_ds 2s
# 256 426 171
# VACJ low theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ low theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ low theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ low theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ low xpow_None 3s
# 1024 2560 1537
# VACJ low theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 1537, 9)
# VACJ low theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 1537, 9)
# VACJ low theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 1537, 9)
# VACJ low theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 1537, 9)
# VACJ low xpow_None 2s
# 1536 2560 1025
# VACJ low theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 1025, 9)
# VACJ low theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 1025, 9)
# VACJ low theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 1025, 9)
# VACJ low theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 1025, 9)
# VACJ low xpow_smooth 3s
# 171 426 256
# VACJ low theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ low theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ low theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ low theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ low xpow_smooth 2s
# 256 426 171
# VACJ low theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ low theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ low theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ low theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ mid xpow_ds 3s
# 171 426 256
# VACJ mid theta 0 TPSim (39, 6) (39, 6) initial data (4, 39, 256, 4)
# VACJ mid theta 1 TPSim (39, 6) (39, 6) initial data (4, 39, 256, 4)
# VACJ mid theta 2 TPSim (39, 6) (39, 6) initial data (4, 39, 256, 4)
# VACJ mid theta 3 TPSim (39, 6) (39, 6) initial data (4, 39, 256, 4)
# VACJ mid xpow_ds 2s
# 256 426 171
# VACJ mid theta 0 TPSim (39, 6) (39, 6) initial data (4, 39, 171, 4)
# VACJ mid theta 1 TPSim (39, 6) (39, 6) initial data (4, 39, 171, 4)
# VACJ mid theta 2 TPSim (39, 6) (39, 6) initial data (4, 39, 171, 4)
# VACJ mid theta 3 TPSim (39, 6) (39, 6) initial data (4, 39, 171, 4)
# VACJ mid xpow_None 3s
# 1024 2560 1537
# VACJ mid theta 0 TPSim (39, 6) (39, 6) initial data (4, 39, 1537, 4)
# VACJ mid theta 1 TPSim (39, 6) (39, 6) initial data (4, 39, 1537, 4)
# VACJ mid theta 2 TPSim (39, 6) (39, 6) initial data (4, 39, 1537, 4)
# VACJ mid theta 3 TPSim (39, 6) (39, 6) initial data (4, 39, 1537, 4)
# VACJ mid xpow_None 2s
# 1536 2560 1025
# VACJ mid theta 0 TPSim (39, 6) (39, 6) initial data (4, 39, 1025, 4)
# VACJ mid theta 1 TPSim (39, 6) (39, 6) initial data (4, 39, 1025, 4)
# VACJ mid theta 2 TPSim (39, 6) (39, 6) initial data (4, 39, 1025, 4)
# VACJ mid theta 3 TPSim (39, 6) (39, 6) initial data (4, 39, 1025, 4)
# VACJ mid xpow_smooth 3s
# 171 426 256
# VACJ mid theta 0 TPSim (39, 6) (39, 6) initial data (4, 39, 256, 4)
# VACJ mid theta 1 TPSim (39, 6) (39, 6) initial data (4, 39, 256, 4)
# VACJ mid theta 2 TPSim (39, 6) (39, 6) initial data (4, 39, 256, 4)
# VACJ mid theta 3 TPSim (39, 6) (39, 6) initial data (4, 39, 256, 4)
# VACJ mid xpow_smooth 2s
# 256 426 171
# VACJ mid theta 0 TPSim (39, 6) (39, 6) initial data (4, 39, 171, 4)
# VACJ mid theta 1 TPSim (39, 6) (39, 6) initial data (4, 39, 171, 4)
# VACJ mid theta 2 TPSim (39, 6) (39, 6) initial data (4, 39, 171, 4)
# VACJ mid theta 3 TPSim (39, 6) (39, 6) initial data (4, 39, 171, 4)
# VACJ high xpow_ds 3s
# 171 426 256
# VACJ high theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ high theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ high theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ high theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ high xpow_ds 2s
# 256 426 171
# VACJ high theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ high theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ high theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ high theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ high xpow_None 3s
# 1024 2560 1537
# VACJ high theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 1537, 9)
# VACJ high theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 1537, 9)
# VACJ high theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 1537, 9)
# VACJ high theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 1537, 9)
# VACJ high xpow_None 2s
# 1536 2560 1025
# VACJ high theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 1025, 9)
# VACJ high theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 1025, 9)
# VACJ high theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 1025, 9)
# VACJ high theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 1025, 9)
# VACJ high xpow_smooth 3s
# 171 426 256
# VACJ high theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ high theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ high theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ high theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 256, 9)
# VACJ high xpow_smooth 2s
# 256 426 171
# VACJ high theta 0 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ high theta 1 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ high theta 2 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# VACJ high theta 3 TPSim (39, 36) (39, 36) initial data (4, 39, 171, 9)
# SEMC low xpow_ds 3s
# 171 426 256
# SEMC low theta 0 TPSim (53, 210) (53, 210) initial data (4, 53, 256, 21)
# SEMC low theta 1 TPSim (53, 210) (53, 210) initial data (4, 53, 256, 21)
# SEMC low theta 2 TPSim (53, 210) (53, 210) initial data (4, 53, 256, 21)
# SEMC low theta 3 TPSim (53, 210) (53, 210) initial data (4, 53, 256, 21)
# SEMC low xpow_ds 2s
# 256 426 171
# SEMC low theta 0 TPSim (53, 210) (53, 210) initial data (4, 53, 171, 21)
# SEMC low theta 1 TPSim (53, 210) (53, 210) initial data (4, 53, 171, 21)
# SEMC low theta 2 TPSim (53, 210) (53, 210) initial data (4, 53, 171, 21)
# SEMC low theta 3 TPSim (53, 210) (53, 210) initial data (4, 53, 171, 21)
# SEMC low xpow_None 3s
# 1024 2560 1537
# SEMC low theta 0 TPSim (53, 210) (53, 210) initial data (4, 53, 1537, 21)
# SEMC low theta 1 TPSim (53, 210) (53, 210) initial data (4, 53, 1537, 21)
# SEMC low theta 2 TPSim (53, 210) (53, 210) initial data (4, 53, 1537, 21)
# SEMC low theta 3 TPSim (53, 210) (53, 210) initial data (4, 53, 1537, 21)
# SEMC low xpow_None 2s
# 1536 2560 1025
# SEMC low theta 0 TPSim (53, 210) (53, 210) initial data (4, 53, 1025, 21)
# SEMC low theta 1 TPSim (53, 210) (53, 210) initial data (4, 53, 1025, 21)
# SEMC low theta 2 TPSim (53, 210) (53, 210) initial data (4, 53, 1025, 21)
# SEMC low theta 3 TPSim (53, 210) (53, 210) initial data (4, 53, 1025, 21)
# SEMC low xpow_smooth 3s
# 171 426 256
# SEMC low theta 0 TPSim (53, 210) (53, 210) initial data (4, 53, 256, 21)
# SEMC low theta 1 TPSim (53, 210) (53, 210) initial data (4, 53, 256, 21)
# SEMC low theta 2 TPSim (53, 210) (53, 210) initial data (4, 53, 256, 21)
# SEMC low theta 3 TPSim (53, 210) (53, 210) initial data (4, 53, 256, 21)
# SEMC low xpow_smooth 2s
# 256 426 171
# SEMC low theta 0 TPSim (53, 210) (53, 210) initial data (4, 53, 171, 21)
# SEMC low theta 1 TPSim (53, 210) (53, 210) initial data (4, 53, 171, 21)
# SEMC low theta 2 TPSim (53, 210) (53, 210) initial data (4, 53, 171, 21)
# SEMC low theta 3 TPSim (53, 210) (53, 210) initial data (4, 53, 171, 21)
# SEMC mid xpow_ds 3s
# 171 426 256
# SEMC mid theta 0 TPSim (53, 45) (53, 45) initial data (4, 53, 256, 10)
# SEMC mid theta 1 TPSim (53, 45) (53, 45) initial data (4, 53, 256, 10)
# SEMC mid theta 2 TPSim (53, 45) (53, 45) initial data (4, 53, 256, 10)
# SEMC mid theta 3 TPSim (53, 45) (53, 45) initial data (4, 53, 256, 10)
# SEMC mid xpow_ds 2s
# 256 426 171
# SEMC mid theta 0 TPSim (53, 45) (53, 45) initial data (4, 53, 171, 10)
# SEMC mid theta 1 TPSim (53, 45) (53, 45) initial data (4, 53, 171, 10)
# SEMC mid theta 2 TPSim (53, 45) (53, 45) initial data (4, 53, 171, 10)
# SEMC mid theta 3 TPSim (53, 45) (53, 45) initial data (4, 53, 171, 10)
# SEMC mid xpow_None 3s
# 1024 2560 1537
# SEMC mid theta 0 TPSim (53, 45) (53, 45) initial data (4, 53, 1537, 10)
# SEMC mid theta 1 TPSim (53, 45) (53, 45) initial data (4, 53, 1537, 10)
# SEMC mid theta 2 TPSim (53, 45) (53, 45) initial data (4, 53, 1537, 10)
# SEMC mid theta 3 TPSim (53, 45) (53, 45) initial data (4, 53, 1537, 10)
# SEMC mid xpow_None 2s
# 1536 2560 1025
# SEMC mid theta 0 TPSim (53, 45) (53, 45) initial data (4, 53, 1025, 10)
# SEMC mid theta 1 TPSim (53, 45) (53, 45) initial data (4, 53, 1025, 10)
# SEMC mid theta 2 TPSim (53, 45) (53, 45) initial data (4, 53, 1025, 10)
# SEMC mid theta 3 TPSim (53, 45) (53, 45) initial data (4, 53, 1025, 10)
# SEMC mid xpow_smooth 3s
# 171 426 256
# SEMC mid theta 0 TPSim (53, 45) (53, 45) initial data (4, 53, 256, 10)
# SEMC mid theta 1 TPSim (53, 45) (53, 45) initial data (4, 53, 256, 10)
# SEMC mid theta 2 TPSim (53, 45) (53, 45) initial data (4, 53, 256, 10)
# SEMC mid theta 3 TPSim (53, 45) (53, 45) initial data (4, 53, 256, 10)
# SEMC mid xpow_smooth 2s
# 256 426 171
# SEMC mid theta 0 TPSim (53, 45) (53, 45) initial data (4, 53, 171, 10)
# SEMC mid theta 1 TPSim (53, 45) (53, 45) initial data (4, 53, 171, 10)
# SEMC mid theta 2 TPSim (53, 45) (53, 45) initial data (4, 53, 171, 10)
# SEMC mid theta 3 TPSim (53, 45) (53, 45) initial data (4, 53, 171, 10)
# SEMC high xpow_ds 3s
# 171 426 256
# SEMC high theta 0 TPSim (53, 36) (53, 36) initial data (4, 53, 256, 9)
# SEMC high theta 1 TPSim (53, 36) (53, 36) initial data (4, 53, 256, 9)
# SEMC high theta 2 TPSim (53, 36) (53, 36) initial data (4, 53, 256, 9)
# SEMC high theta 3 TPSim (53, 36) (53, 36) initial data (4, 53, 256, 9)
# SEMC high xpow_ds 2s
# 256 426 171
# SEMC high theta 0 TPSim (53, 36) (53, 36) initial data (4, 53, 171, 9)
# SEMC high theta 1 TPSim (53, 36) (53, 36) initial data (4, 53, 171, 9)
# SEMC high theta 2 TPSim (53, 36) (53, 36) initial data (4, 53, 171, 9)
# SEMC high theta 3 TPSim (53, 36) (53, 36) initial data (4, 53, 171, 9)
# SEMC high xpow_None 3s
# 1024 2560 1537
# SEMC high theta 0 TPSim (53, 36) (53, 36) initial data (4, 53, 1537, 9)
# SEMC high theta 1 TPSim (53, 36) (53, 36) initial data (4, 53, 1537, 9)
# SEMC high theta 2 TPSim (53, 36) (53, 36) initial data (4, 53, 1537, 9)
# SEMC high theta 3 TPSim (53, 36) (53, 36) initial data (4, 53, 1537, 9)
# SEMC high xpow_None 2s
# 1536 2560 1025
# SEMC high theta 0 TPSim (53, 36) (53, 36) initial data (4, 53, 1025, 9)
# SEMC high theta 1 TPSim (53, 36) (53, 36) initial data (4, 53, 1025, 9)
# SEMC high theta 2 TPSim (53, 36) (53, 36) initial data (4, 53, 1025, 9)
# SEMC high theta 3 TPSim (53, 36) (53, 36) initial data (4, 53, 1025, 9)
# SEMC high xpow_smooth 3s
# 171 426 256
# SEMC high theta 0 TPSim (53, 36) (53, 36) initial data (4, 53, 256, 9)
# SEMC high theta 1 TPSim (53, 36) (53, 36) initial data (4, 53, 256, 9)
# SEMC high theta 2 TPSim (53, 36) (53, 36) initial data (4, 53, 256, 9)
# SEMC high theta 3 TPSim (53, 36) (53, 36) initial data (4, 53, 256, 9)
# SEMC high xpow_smooth 2s
# 256 426 171
# SEMC high theta 0 TPSim (53, 36) (53, 36) initial data (4, 53, 171, 9)
# SEMC high theta 1 TPSim (53, 36) (53, 36) initial data (4, 53, 171, 9)
# SEMC high theta 2 TPSim (53, 36) (53, 36) initial data (4, 53, 171, 9)
# SEMC high theta 3 TPSim (53, 36) (53, 36) initial data (4, 53, 171, 9)
# LEFC low xpow_ds 3s
# 171 426 256
# LEFC low theta 0 TPSim (27, 253) (27, 253) initial data (4, 27, 256, 23)
# LEFC low theta 1 TPSim (27, 253) (27, 253) initial data (4, 27, 256, 23)
# LEFC low theta 2 TPSim (27, 253) (27, 253) initial data (4, 27, 256, 23)
# LEFC low theta 3 TPSim (27, 253) (27, 253) initial data (4, 27, 256, 23)
# LEFC low xpow_ds 2s
# 256 426 171
# LEFC low theta 0 TPSim (27, 253) (27, 253) initial data (4, 27, 171, 23)
# LEFC low theta 1 TPSim (27, 253) (27, 253) initial data (4, 27, 171, 23)
# LEFC low theta 2 TPSim (27, 253) (27, 253) initial data (4, 27, 171, 23)
# LEFC low theta 3 TPSim (27, 253) (27, 253) initial data (4, 27, 171, 23)
# LEFC low xpow_None 3s
# 1024 2560 1537
# LEFC low theta 0 TPSim (27, 253) (27, 253) initial data (4, 27, 1537, 23)
# LEFC low theta 1 TPSim (27, 253) (27, 253) initial data (4, 27, 1537, 23)
# LEFC low theta 2 TPSim (27, 253) (27, 253) initial data (4, 27, 1537, 23)
# LEFC low theta 3 TPSim (27, 253) (27, 253) initial data (4, 27, 1537, 23)
# LEFC low xpow_None 2s
# 1536 2560 1025
# LEFC low theta 0 TPSim (27, 253) (27, 253) initial data (4, 27, 1025, 23)
# LEFC low theta 1 TPSim (27, 253) (27, 253) initial data (4, 27, 1025, 23)
# LEFC low theta 2 TPSim (27, 253) (27, 253) initial data (4, 27, 1025, 23)
# LEFC low theta 3 TPSim (27, 253) (27, 253) initial data (4, 27, 1025, 23)
# LEFC low xpow_smooth 3s
# 171 426 256
# LEFC low theta 0 TPSim (27, 253) (27, 253) initial data (4, 27, 256, 23)
# LEFC low theta 1 TPSim (27, 253) (27, 253) initial data (4, 27, 256, 23)
# LEFC low theta 2 TPSim (27, 253) (27, 253) initial data (4, 27, 256, 23)
# LEFC low theta 3 TPSim (27, 253) (27, 253) initial data (4, 27, 256, 23)
# LEFC low xpow_smooth 2s
# 256 426 171
# LEFC low theta 0 TPSim (27, 253) (27, 253) initial data (4, 27, 171, 23)
# LEFC low theta 1 TPSim (27, 253) (27, 253) initial data (4, 27, 171, 23)
# LEFC low theta 2 TPSim (27, 253) (27, 253) initial data (4, 27, 171, 23)
# LEFC low theta 3 TPSim (27, 253) (27, 253) initial data (4, 27, 171, 23)
# LEFC mid xpow_ds 3s
# 171 426 256
# LEFC mid theta 0 TPSim (27, 105) (27, 105) initial data (4, 27, 256, 15)
# LEFC mid theta 1 TPSim (27, 105) (27, 105) initial data (4, 27, 256, 15)
# LEFC mid theta 2 TPSim (27, 105) (27, 105) initial data (4, 27, 256, 15)
# LEFC mid theta 3 TPSim (27, 105) (27, 105) initial data (4, 27, 256, 15)
# LEFC mid xpow_ds 2s
# 256 426 171
# LEFC mid theta 0 TPSim (27, 105) (27, 105) initial data (4, 27, 171, 15)
# LEFC mid theta 1 TPSim (27, 105) (27, 105) initial data (4, 27, 171, 15)
# LEFC mid theta 2 TPSim (27, 105) (27, 105) initial data (4, 27, 171, 15)
# LEFC mid theta 3 TPSim (27, 105) (27, 105) initial data (4, 27, 171, 15)
# LEFC mid xpow_None 3s
# 1024 2560 1537
# LEFC mid theta 0 TPSim (27, 105) (27, 105) initial data (4, 27, 1537, 15)
# LEFC mid theta 1 TPSim (27, 105) (27, 105) initial data (4, 27, 1537, 15)
# LEFC mid theta 2 TPSim (27, 105) (27, 105) initial data (4, 27, 1537, 15)
# LEFC mid theta 3 TPSim (27, 105) (27, 105) initial data (4, 27, 1537, 15)
# LEFC mid xpow_None 2s
# 1536 2560 1025
# LEFC mid theta 0 TPSim (27, 105) (27, 105) initial data (4, 27, 1025, 15)
# LEFC mid theta 1 TPSim (27, 105) (27, 105) initial data (4, 27, 1025, 15)
# LEFC mid theta 2 TPSim (27, 105) (27, 105) initial data (4, 27, 1025, 15)
# LEFC mid theta 3 TPSim (27, 105) (27, 105) initial data (4, 27, 1025, 15)
# LEFC mid xpow_smooth 3s
# 171 426 256
# LEFC mid theta 0 TPSim (27, 105) (27, 105) initial data (4, 27, 256, 15)
# LEFC mid theta 1 TPSim (27, 105) (27, 105) initial data (4, 27, 256, 15)
# LEFC mid theta 2 TPSim (27, 105) (27, 105) initial data (4, 27, 256, 15)
# LEFC mid theta 3 TPSim (27, 105) (27, 105) initial data (4, 27, 256, 15)
# LEFC mid xpow_smooth 2s
# 256 426 171
# LEFC mid theta 0 TPSim (27, 105) (27, 105) initial data (4, 27, 171, 15)
# LEFC mid theta 1 TPSim (27, 105) (27, 105) initial data (4, 27, 171, 15)
# LEFC mid theta 2 TPSim (27, 105) (27, 105) initial data (4, 27, 171, 15)
# LEFC mid theta 3 TPSim (27, 105) (27, 105) initial data (4, 27, 171, 15)
# LEFC high xpow_ds 3s
# 171 426 256
# LEFC high theta 0 TPSim (27, 136) (27, 136) initial data (4, 27, 256, 17)
# LEFC high theta 1 TPSim (27, 136) (27, 136) initial data (4, 27, 256, 17)
# LEFC high theta 2 TPSim (27, 136) (27, 136) initial data (4, 27, 256, 17)
# LEFC high theta 3 TPSim (27, 136) (27, 136) initial data (4, 27, 256, 17)
# LEFC high xpow_ds 2s
# 256 426 171
# LEFC high theta 0 TPSim (27, 136) (27, 136) initial data (4, 27, 171, 17)
# LEFC high theta 1 TPSim (27, 136) (27, 136) initial data (4, 27, 171, 17)
# LEFC high theta 2 TPSim (27, 136) (27, 136) initial data (4, 27, 171, 17)
# LEFC high theta 3 TPSim (27, 136) (27, 136) initial data (4, 27, 171, 17)
# LEFC high xpow_None 3s
# 1024 2560 1537
# LEFC high theta 0 TPSim (27, 136) (27, 136) initial data (4, 27, 1537, 17)
# LEFC high theta 1 TPSim (27, 136) (27, 136) initial data (4, 27, 1537, 17)
# LEFC high theta 2 TPSim (27, 136) (27, 136) initial data (4, 27, 1537, 17)
# LEFC high theta 3 TPSim (27, 136) (27, 136) initial data (4, 27, 1537, 17)
# LEFC high xpow_None 2s
# 1536 2560 1025
# LEFC high theta 0 TPSim (27, 136) (27, 136) initial data (4, 27, 1025, 17)
# LEFC high theta 1 TPSim (27, 136) (27, 136) initial data (4, 27, 1025, 17)
# LEFC high theta 2 TPSim (27, 136) (27, 136) initial data (4, 27, 1025, 17)
# LEFC high theta 3 TPSim (27, 136) (27, 136) initial data (4, 27, 1025, 17)
# LEFC high xpow_smooth 3s
# 171 426 256
# LEFC high theta 0 TPSim (27, 136) (27, 136) initial data (4, 27, 256, 17)
# LEFC high theta 1 TPSim (27, 136) (27, 136) initial data (4, 27, 256, 17)
# LEFC high theta 2 TPSim (27, 136) (27, 136) initial data (4, 27, 256, 17)
# LEFC high theta 3 TPSim (27, 136) (27, 136) initial data (4, 27, 256, 17)
# LEFC high xpow_smooth 2s
# 256 426 171
# LEFC high theta 0 TPSim (27, 136) (27, 136) initial data (4, 27, 171, 17)
# LEFC high theta 1 TPSim (27, 136) (27, 136) initial data (4, 27, 171, 17)
# LEFC high theta 2 TPSim (27, 136) (27, 136) initial data (4, 27, 171, 17)
# LEFC high theta 3 TPSim (27, 136) (27, 136) initial data (4, 27, 171, 17)

# %% [markdown]
# #### Compute linear regression by elec for all combinations

# %%
from utils import rename_elecs
import statsmodels.api as sm
from mne.stats import bonferroni_correction, fdr_correction
import pandas as pd

st = study('Olfacto')
path_tps = join(st.path, 'feature/TPSim_3groups_Enc/')
tps_form = join(path_tps, 'TPS_{}_v=1_elecs=all_ds_sm/'+\
            'TPS_pears_{}_{}_{}_theta{}_data={}_win={}.npz') #su,cond,meth, freq
df_path = join(path_tps, 'LinReg_stats_theta_v=1_elecs=all_ds_sm/')
df_name = join(df_path, 'df_{}_theta{}_data={}_win={}.csv') #meth,f,data_c,win
    
nfreqs, wins, data_types = 4, ['2s', '3s'], ['xpow_None','xpow_ds','xpow_smooth']
meth, conds, stat = 'btw', ['low','mid','high'], 'LinReg'
subjects = ['CHAF','VACJ','PIRJ','SEMC','FERJ','LEFC']
rois_sel = ['aHC','MFG','IFG','Amg','pPirT','PHG','Ins_olf','OFC_olf']
dict_perf = {'low':1, 'mid':2, 'high':3}

for f,win,data_c in product(range(nfreqs),wins,data_types):
    print('>>> processing theta', f, win, data_c)
    subjects_c, elecs_c, labels_c = np.array([]), np.array([]), np.array([])
    channels_c, x_c, y_c, z_c = np.array([]), np.array([]), np.array([]), np.array([])
    tps_scores, T_vals_c, p_vals_c = np.array([]), np.array([]), np.array([])
    p_fdr_c, p_bf_c = np.array([]), np.array([])

    for su in subjects:
        #load all elec info,rename and select electrodes id
        mat = np.load(tps_form.format(meth,su,conds[0],meth,f,data_c,win),allow_pickle=True)
        labels, channels = mat['label'], mat['channel']
        print(su,labels.shape, mat['tps'].shape,np.unique(labels))
        x, y, z = mat['xyz'][:,0], mat['xyz'][:,1], mat['xyz'][:,2]
        labels_new = rename_elecs(labels,x,y,z)
        idx_sel = [i for i,lab in enumerate(labels_new) if lab in rois_sel]
        labels, channels = labels_new[idx_sel], channels[idx_sel]
        x, y, z = x[idx_sel], y[idx_sel], z[idx_sel]
            
        if stat == 'LinReg':
            tps_su = np.zeros((len(idx_sel),len(conds)))
            all_tps, all_scores = [], []
            for c,cond in enumerate(conds):
                mat = np.load(tps_form.format(meth,su,cond,meth,f,data_c,win))
                tps = mat['tps'][idx_sel]
                nelecs, ntrials = tps.shape
                score_ = np.array([dict_perf[cond]]*ntrials)
                tps_su[:,c] += np.mean(tps,axis=1)
                #fill tps and score vectors
                all_tps.append(tps)
                all_scores.append(score_)

            #compute stats Ttests-unpaired
            all_tps = np.concatenate(all_tps,axis=1)
            all_scores = np.concatenate(all_scores,axis=0)
            T, unc_p = [], []
            for elec in range(nelecs):
                #Tval,pval = stats.kendalltau(all_tps[elec],all_scores)
                Y, X = np.array(all_tps[elec]), sm.add_constant(np.array(all_scores))
                model_ols = sm.OLS(Y,X).fit()
                Tval, pval = np.round(model_ols.tvalues[1],3),model_ols.pvalues[1]
                T.append(Tval), unc_p.append(pval)
        if stat == 'Ttest':
            tps0 = np.load(tps_form.format(su,conds[0],freq,width,step))['tps'][idx_sel]
            nelecs = len(idx_sel)
            tps1 = np.load(tps_form.format(su,conds[1],freq,width,step))['tps'][idx_sel]
            mean0, mean1 = np.mean(tps0,axis=1)[:,np.newaxis], np.mean(tps1,axis=1)[:,np.newaxis]
            tps_su = np.concatenate((mean0,mean1),axis=1)
            #compute stats Ttests-unpaired
            tps0, tps1 = tps0.swapaxes(0,1), tps1.swapaxes(0,1) #ntrials x nelecs
            T, unc_p = ttest_ind(tps0, tps1, equal_var=False)
            print(T.shape, unc_p.shape)
        _, p_fdr = fdr_correction(unc_p)
        _, p_bf = bonferroni_correction(unc_p)

        #fill all df data
        subjects_c = np.hstack((subjects_c,np.array([su]*nelecs))) if np.size(subjects_c) else np.array([su]*nelecs)
        elecs_c = np.hstack((elecs_c,np.arange(nelecs))) if np.size(elecs_c) else np.arange(nelecs)
        labels_c = np.hstack((labels_c,labels)) if np.size(labels_c) else labels
        channels_c = np.hstack((channels_c,channels)) if np.size(channels_c) else channels
        tps_scores = np.concatenate((tps_scores,tps_su),axis=0) if np.size(tps_scores) else tps_su
        x_c = np.hstack((x_c,x)) if np.size(x_c) else x
        y_c = np.hstack((y_c,y)) if np.size(y_c) else y
        z_c = np.hstack((z_c,z)) if np.size(z_c) else z
        T_vals_c = np.hstack((T_vals_c,T)) if np.size(T_vals_c) else T
        p_vals_c = np.hstack((p_vals_c,unc_p)) if np.size(p_vals_c) else unc_p
        p_fdr_c = np.hstack((p_fdr_c,p_fdr)) if np.size(p_fdr_c) else p_fdr
        p_bf_c = np.hstack((p_bf_c,p_bf)) if np.size(p_bf_c) else p_bf

    data = np.concatenate((subjects_c[:,np.newaxis],labels_c[:,np.newaxis],
                channels_c[:,np.newaxis],x_c[:,np.newaxis],y_c[:,np.newaxis],
                z_c[:,np.newaxis],elecs_c[:,np.newaxis],tps_scores,T_vals_c[:,np.newaxis],
                p_vals_c[:,np.newaxis],p_fdr_c[:,np.newaxis],p_bf_c[:,np.newaxis]),
                axis=1)
    df = pd.DataFrame(data, columns=['subjects','labels','channels','x','y','z',
                            'elecs_num', 'tps_'+conds[0], 'tps_'+conds[1],'tps_'+conds[2],
                                    'Tvals', 'unc_p','fdr_p', 'bonf_p'])
    #df = pd.DataFrame(data, columns=['subjects','labels','channels','x','y','z',
    #                        'elecs_num', 'tps_'+conds[0], 'tps_'+conds[1],
    #                                'Tvals', 'unc_p','fdr_p', 'bonf_p'])
    print(df.shape)
    df.to_csv(df_name.format(meth,f,data_c,win),index=False)
# Out:
# -> Olfacto loaded
# >>> processing theta 0 2s xpow_None
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 0 2s xpow_ds
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 0 2s xpow_smooth
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 0 3s xpow_None
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 0 3s xpow_ds
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 0 3s xpow_smooth
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 1 2s xpow_None
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 1 2s xpow_ds
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 1 2s xpow_smooth
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 1 3s xpow_None
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 1 3s xpow_ds
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 1 3s xpow_smooth
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 2 2s xpow_None
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 2 2s xpow_ds
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 2 2s xpow_smooth
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 2 3s xpow_None
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 2 3s xpow_ds
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 2 3s xpow_smooth
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 3 2s xpow_None
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 3 2s xpow_ds
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 3 2s xpow_smooth
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 3 3s xpow_None
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 3 3s xpow_ds
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)
# >>> processing theta 3 3s xpow_smooth
# CHAF (61,) (61, 10) ['ACC' 'MFG' 'OFC_olf' 'SFG']
# VACJ (39,) (39, 36) ['ACC' 'Amg' 'IFG' 'MFG' 'OFC_olf' 'aHC' 'pPirT']
# PIRJ (18,) (18, 91) ['IFG' 'Ins_olf' 'OFC_olf' 'PHG' 'aHC']
# SEMC (53,) (53, 210) ['ACC' 'IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC']
# FERJ (32,) (32, 120) ['Amg' 'IFG' 'Ins_olf' 'aHC' 'pPirT']
# LEFC (27,) (27, 253) ['IFG' 'MFG' 'OFC_olf' 'SFG' 'aHC' 'pPirT']
# (164, 14)

# %% [markdown]
# #### Sum up signif elecs for all combinations of data

# %%
from collections import Counter

st = study('Olfacto')
stat = 'LinReg'#'Enc'
meth = 'btw'
olf_regions = ['Amg','pPirT','OFC_olf']
nfreqs, wins, data_types = 4, ['3s', '2s'], ['xpow_None']#,'xpow_ds','xpow_smooth']
thrs = [0.05]
corrections = ['unc_p']#['fdr_p'] unc_p

##################################################################################
path_pow = join(st.path, 'feature/TPSim_3groups_Enc/LinReg_stats_theta_v=1_elecs=all_ds_sm/')
df_name = join(path_pow, 'df_{}_theta{}_data={}_win={}.csv')
df_sig = join(path_pow, 'df_sig_{}_theta{}_roi={}_sign={}_stat={}_data={}_win={}.csv')
##################################################################################

for f,data_c,win in product(range(nfreqs),data_types,wins):
    print('')
    print('processing >>>', 'theta'+str(f),data_c,win)
    df = pd.read_csv(df_name.format(meth,str(f),data_c,win))
    df['labels'] = ['pPirT' if lab == 'Amg' else lab for lab in df['labels']]
    print(df[df['labels']=='OFC_olf'].mean())

    for th, corr in product(thrs,corrections):
        df_sel = df.loc[df[corr]<th] #
        df_sel['sign'] = ['separation' if t > 0 else 'completion' for t in df_sel['Tvals']]
        #print(df_sel.groupby(['subjects','labels',]).sum()['Tvals'])
        
        rois = np.unique(df_sel['labels'])
        for roi in rois:
            df_roi = df_sel.loc[df_sel['labels']==roi]
            df_inc = df_roi.loc[df_roi['sign']=='completion'].groupby(['subjects']).count()
            df_dec = df_roi.loc[df_roi['sign']=='separation'].groupby(['subjects']).count()
            
            if (df_inc.shape[0] >= 3) or (df_inc.shape[0] >=2 and roi in olf_regions):
                print(roi, 'NB of subjects with completion',df_inc.shape[0],' subjects')
                df_plot = df_roi.loc[df_roi['sign']=='completion']
                print('#electrodes in total >>> ',df_plot.shape[0])
                df_plot.to_csv(df_sig.format(meth,str(f),roi,'compl',corr,data_c,win))

            if (df_dec.shape[0] >= 3) or (df_dec.shape[0] >=2 and roi in olf_regions):
                print(roi, 'NB of subjects with separation',df_dec.shape[0],' subjects')
                df_plot = df_roi.loc[df_roi['sign']=='separation']
                print('#electrodes in total >>> ',df_plot.shape[0])
                df_plot.to_csv(df_sig.format(meth,str(f),roi,'sep',corr,data_c,win))
# Out:
# -> Olfacto loaded
#
# processing >>> theta0 xpow_None 3s
# x             6.110526
# y            36.526316
# z           -11.186842
# elecs_num    17.684211
# tps_low       0.983003
# tps_mid       1.003671
# tps_high      1.017444
# Tvals         0.803526
# unc_p         0.434798
# fdr_p         0.721719
# bonf_p       11.903694
# dtype: float64
# OFC_olf NB of subjects with separation 2  subjects
# #electrodes in total >>>  3
# pPirT NB of subjects with separation 2  subjects
# #electrodes in total >>>  2
#
# processing >>> theta0 xpow_None 2s
# x             6.110526
# y            36.526316
# z           -11.186842
# elecs_num    17.684211
# tps_low       0.973856
# tps_mid       0.987691
# tps_high      1.007975
# Tvals         0.782211
# unc_p         0.457584
# fdr_p         0.702957
# bonf_p       11.786645
# dtype: float64
# aHC NB of subjects with separation 3  subjects
# #electrodes in total >>>  3
#
# processing >>> theta1 xpow_None 3s
# x             6.110526
# y            36.526316
# z           -11.186842
# elecs_num    17.684211
# tps_low       0.978765
# tps_mid       1.019488
# tps_high      1.022691
# Tvals         1.014842
# unc_p         0.442661
# fdr_p         0.765554
# bonf_p       11.546797
# dtype: float64
#
# processing >>> theta1 xpow_None 2s
# x             6.110526
# y            36.526316
# z           -11.186842
# elecs_num    17.684211
# tps_low       0.968899
# tps_mid       1.020836
# tps_high      1.014324
# Tvals         0.926579
# unc_p         0.481755
# fdr_p         0.762226
# bonf_p       12.843052
# dtype: float64
#
# processing >>> theta2 xpow_None 3s
# x             6.110526
# y            36.526316
# z           -11.186842
# elecs_num    17.684211
# tps_low       0.982566
# tps_mid       0.996200
# tps_high      1.009569
# Tvals         0.677263
# unc_p         0.498761
# fdr_p         0.842960
# bonf_p       13.772757
# dtype: float64
#
# processing >>> theta2 xpow_None 2s
# x             6.110526
# y            36.526316
# z           -11.186842
# elecs_num    17.684211
# tps_low       0.976199
# tps_mid       0.986484
# tps_high      1.001527
# Tvals         0.639579
# unc_p         0.502718
# fdr_p         0.760836
# bonf_p       14.122879
# dtype: float64
#
# processing >>> theta3 xpow_None 3s
# x             6.110526
# y            36.526316
# z           -11.186842
# elecs_num    17.684211
# tps_low       0.988133
# tps_mid       1.000438
# tps_high      1.012648
# Tvals         0.688579
# unc_p         0.433637
# fdr_p         0.765380
# bonf_p       11.759942
# dtype: float64
#
# processing >>> theta3 xpow_None 2s
# x             6.110526
# y            36.526316
# z           -11.186842
# elecs_num    17.684211
# tps_low       0.981537
# tps_mid       1.010275
# tps_high      1.007949
# Tvals         0.640842
# unc_p         0.446682
# fdr_p         0.733708
# bonf_p       12.591816
# dtype: float64

# %% [markdown]
# ### Mixed models

# %%
import numpy as np
from scipy.stats import wilcoxon
from os.path import join
from utils import subjects
import pandas as pd
from brainpipe.system import study

import statsmodels.api as sm
import statsmodels.formula.api as smf

###############################################################################
st = study('Olfacto')
rep_study = join(st.path, 'feature/TPSim_3groups_Enc/')
data_rep = join(rep_study, 'LinReg_stats_theta_v=1_elecs=all_ds_sm/')
csv_file = join(data_rep, 'df_btw_theta{}_data={}_win={}.csv')
###############################################################################
conds = ['low','mid','high']
var_con = {'low':1,'mid':2,'high':3}
rois = ['aHC']#,'aHC','pPirT']
data_types = ['xpow_None']

for f,data_c,win in product(range(4),data_types,wins):
    df = pd.read_csv(csv_file.format(str(f),data_c,win))
    df['labels'] = ['pPirT' if lab =='Amg' else lab for lab in df['labels']]
    df['labels_RL'] = [x+'_R' if df['x'][i] > 0 else x+'_L' for i,x in enumerate(df['labels'])]

    pvals, rois_sel = [], []
    for roi in rois:
        df_roi = df.loc[df['labels']==roi]
        rois_sel.append(roi)

        df_take = df_roi
        data = np.concatenate([df_take['tps_'+cond] for cond in conds])
        richness = np.concatenate([[var_con[cond]]*len(df_take['tps_'+cond]) for cond in conds])
        subjs = np.concatenate([df_take['subjects']]*len(conds))
        all_df = np.concatenate((subjs[:,np.newaxis],richness[:,np.newaxis],
                                 data[:,np.newaxis]),axis=-1)
        df_stats = pd.DataFrame(all_df, columns=['subjs','richness','tps'])
        df_stats['richness'] = df_stats['richness'].astype('float')
        df_stats['tps'] = df_stats['tps'].astype('float')

        print(">>> processing ", f, data_c, win, roi)
        print(df_take[['tps_low','tps_mid','tps_high']].mean().values)
        md = smf.mixedlm("tps ~ richness", df_stats, groups = df_stats['subjs'])
        mdf = md.fit()
        pvals.append(mdf.pvalues[1])
        print(mdf.pvalues[1])
# Out:
# -> Olfacto loaded
# >>> processing  0 xpow_None 3s aHC
# [0.99967368 1.0006289  0.99357571]
# 0.5764018199463217
# >>> processing  0 xpow_None 2s aHC
# [1.0011941  0.99616791 1.00031929]
# 0.9549517344810617
# >>> processing  1 xpow_None 3s aHC
# [1.0008457  1.0090461  0.98461301]
# 0.14097805772918437
# >>> processing  1 xpow_None 2s aHC
# [1.00096634 1.0206415  0.99893258]
# 0.8878682668836626
# >>> processing  2 xpow_None 3s aHC
# [0.99887545 1.00120903 0.99599653]
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2059: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2059: ConvergenceWarning: Retrying MixedLM optimization with cg
#   ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2063: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2075: ConvergenceWarning: Gradient optimization failed, |grad| = 1.026551
#   warnings.warn(msg, ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 0.7608633223154275
# >>> processing  2 xpow_None 2s aHC
# [1.00438607 1.00418398 1.00334663]
# 0.9351682934068505
# >>> processing  3 xpow_None 3s aHC
# [0.99849925 1.01447249 0.99255427]
# 0.5651660220700354
# >>> processing  3 xpow_None 2s aHC
# [0.99943747 1.02311083 1.00399126]
# 0.72520624606335
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/karim/anaconda3/envs/mne_coreg/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
