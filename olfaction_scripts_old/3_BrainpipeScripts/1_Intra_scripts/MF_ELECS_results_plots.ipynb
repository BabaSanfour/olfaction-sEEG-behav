# %%
import numpy as np
from brainpipe.system import study
from os.path import join
from itertools import product
import pandas as pd

st = study('Olfacto')
phase = 'Encoding'#'Encoding'
PATH_F = join(st.path, 'feature/0_Power_{}_EpiPerf_LowHigh/'.format(phase))
PATH_MF = join(st.path,'MF_results{}/'.format(phase[0]))
PATH_EL = join(st.path, 'database/{}_EpiPerf_LowHigh/All_elecs_infos_npz/'.format(phase))

if phase == 'Encoding':
    subjects = ['FERJ','MICP','VACJ','SEMC','LEFC','PIRJ','CHAF']
elif phase == 'Retrieval':
    subjects = ['FERJ','VACJ','SEMC','LEFC','PIRJ','CHAF']
# Out:
# -> Olfacto loaded

# %% [markdown]
# ### Create global MF results files

# %%
df_info = pd.read_csv(PATH_EL+'0_all_subjects_info_elecsFT.csv')

for su in subjects:
    mat_low = np.load(join(PATH_F,su+'_odor_low_bipo_sel_physFT_pow.npz'))
    mat_high = np.load(join(PATH_F,su+'_odor_high_bipo_sel_physFT_pow.npz'))
    elecs_names = mat_low['Mai_RL']
    y = [0]*mat_low['xpow'].shape[0]+[1]*mat_high['xpow'].shape[0]
        
    su_scores, su_sels = np.array([]), np.array([])
    for freq in range(2,7):
        scores, sels = np.array([]), np.array([])
        for ti in range(35):
            x = np.load(PATH_MF+'{}_{}_{}_MVPA_scores.npz'.format(su,ti,freq))
            score, feat = x['score'], x['id_sel']
            feat = [[f] for f in feat]
            print(su,feat)
            scores = np.vstack((scores,score)) if np.size(scores) else score
            sels =  np.vstack((sels,feat)) if np.size(sels) else feat
        scores, sels = scores[np.newaxis], sels[np.newaxis]
        su_scores = np.vstack((su_scores,scores)) if np.size(su_scores) else scores
        su_sels = np.vstack((su_sels,sels)) if np.size(su_sels) else sels
    
    #Save and add names
    regions = df_info['region'].loc[df_info['subjects'] == su].values
    np.savez(PATH_MF+'npz/{}_Pow_Elecs_MF_scores.npz'.format(su),score=su_scores, 
             sel=su_sels, y=y, regions=regions)
    print(su, su_scores.shape, su_sels.shape)
# Out:
# FERJ [[array([0])], [array([18])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([6])], [array([15])], [array([19])], [array([11])], [array([12])]]
# FERJ [[array([0])], [array([0])], [array([1])], [array([12])], [array([7])]]
# FERJ [[array([0])], [array([17])], [array([18])], [array([1])], [array([8])]]
# FERJ [[array([23])], [array([8])], [array([6])], [array([17])], [array([17])]]
# FERJ [[array([33])], [array([5])], [array([15])], [array([16])], [array([19])]]
# FERJ [[array([14])], [array([19])], [array([7])], [array([5])], [array([13])]]
# FERJ [[array([5])], [array([5])], [array([3])], [array([19])], [array([10])]]
# FERJ [[array([13])], [array([9])], [array([5])], [array([1])], [array([5])]]
# FERJ [[array([2])], [array([4])], [array([0])], [array([44])], [array([1])]]
# FERJ [[array([1])], [array([5])], [array([18])], [array([4])], [array([1])]]
# FERJ [[array([5])], [array([5])], [array([0])], [array([0])], [array([6])]]
# FERJ [[array([6])], [array([7])], [array([8])], [array([0])], [array([6])]]
# FERJ [[array([1])], [array([5])], [array([2])], [array([6])], [array([5])]]
# FERJ [[array([4])], [array([6])], [array([2])], [array([2])], [array([20])]]
# FERJ [[array([3])], [array([1])], [array([0])], [array([5])], [array([1])]]
# FERJ [[array([3])], [array([3])], [array([2])], [array([4])], [array([2])]]
# FERJ [[array([3])], [array([7])], [array([0])], [array([4])], [array([5])]]
# FERJ [[array([6])], [array([4])], [array([0])], [array([2])], [array([3])]]
# FERJ [[array([0])], [array([0])], [array([1])], [array([0])], [array([3])]]
# FERJ [[array([0])], [array([16])], [array([4])], [array([1])], [array([1])]]
# FERJ [[array([5])], [array([0])], [array([16])], [array([1])], [array([5])]]
# FERJ [[array([0])], [array([5])], [array([3])], [array([0])], [array([5])]]
# FERJ [[array([16])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([5])], [array([0])], [array([0])], [array([0])], [array([13])]]
# FERJ [[array([5])], [array([5])], [array([8])], [array([5])], [array([17])]]
# FERJ [[array([0])], [array([17])], [array([1])], [array([0])], [array([17])]]
# FERJ [[array([4])], [array([0])], [array([37])], [array([17])], [array([0])]]
# FERJ [[array([7])], [array([16])], [array([0])], [array([7])], [array([9])]]
# FERJ [[array([7])], [array([9])], [array([32])], [array([7])], [array([9])]]
# FERJ [[array([0])], [array([32])], [array([7])], [array([10])], [array([0])]]
# FERJ [[array([4])], [array([7])], [array([7])], [array([7])], [array([9])]]
# FERJ [[array([1])], [array([1])], [array([7])], [array([1])], [array([23])]]
# FERJ [[array([6])], [array([6])], [array([1])], [array([6])], [array([6])]]
# FERJ [[array([1])], [array([5])], [array([1])], [array([0])], [array([1])]]
# FERJ [[array([18])], [array([19])], [array([13])], [array([12])], [array([2])]]
# FERJ [[array([11])], [array([13])], [array([15])], [array([11])], [array([0])]]
# FERJ [[array([10])], [array([4])], [array([2])], [array([19])], [array([10])]]
# FERJ [[array([10])], [array([10])], [array([11])], [array([5])], [array([10])]]
# FERJ [[array([3])], [array([10])], [array([3])], [array([10])], [array([0])]]
# FERJ [[array([6])], [array([0])], [array([3])], [array([3])], [array([3])]]
# FERJ [[array([7])], [array([0])], [array([7])], [array([6])], [array([0])]]
# FERJ [[array([3])], [array([8])], [array([7])], [array([15])], [array([4])]]
# FERJ [[array([4])], [array([4])], [array([4])], [array([4])], [array([3])]]
# FERJ [[array([4])], [array([0])], [array([6])], [array([7])], [array([0])]]
# FERJ [[array([3])], [array([4])], [array([7])], [array([1])], [array([4])]]
# FERJ [[array([5])], [array([3])], [array([0])], [array([7])], [array([6])]]
# FERJ [[array([3])], [array([6])], [array([6])], [array([0])], [array([8])]]
# FERJ [[array([6])], [array([3])], [array([0])], [array([0])], [array([1])]]
# FERJ [[array([1])], [array([0])], [array([1])], [array([0])], [array([1])]]
# FERJ [[array([0])], [array([1])], [array([0])], [array([0])], [array([1])]]
# FERJ [[array([19])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([3])], [array([5])], [array([0])], [array([3])], [array([3])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([9])]]
# FERJ [[array([0])], [array([3])], [array([3])], [array([0])], [array([0])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([4])], [array([0])], [array([6])], [array([0])], [array([0])]]
# FERJ [[array([0])], [array([3])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([4])], [array([4])], [array([1])], [array([51])], [array([1])]]
# FERJ [[array([0])], [array([1])], [array([4])], [array([0])], [array([0])]]
# FERJ [[array([10])], [array([0])], [array([1])], [array([1])], [array([1])]]
# FERJ [[array([0])], [array([1])], [array([10])], [array([0])], [array([0])]]
# FERJ [[array([0])], [array([51])], [array([39])], [array([0])], [array([25])]]
# FERJ [[array([0])], [array([0])], [array([1])], [array([3])], [array([23])]]
# FERJ [[array([1])], [array([2])], [array([1])], [array([3])], [array([8])]]
# FERJ [[array([26])], [array([0])], [array([3])], [array([2])], [array([14])]]
# FERJ [[array([26])], [array([3])], [array([3])], [array([37])], [array([0])]]
# FERJ [[array([12])], [array([22])], [array([1])], [array([19])], [array([4])]]
# FERJ [[array([30])], [array([11])], [array([8])], [array([19])], [array([36])]]
# FERJ [[array([23])], [array([10])], [array([19])], [array([1])], [array([31])]]
# FERJ [[array([21])], [array([10])], [array([2])], [array([10])], [array([5])]]
# FERJ [[array([12])], [array([13])], [array([10])], [array([13])], [array([12])]]
# FERJ [[array([3])], [array([13])], [array([2])], [array([3])], [array([1])]]
# FERJ [[array([11])], [array([12])], [array([4])], [array([14])], [array([10])]]
# FERJ [[array([4])], [array([12])], [array([4])], [array([12])], [array([4])]]
# FERJ [[array([12])], [array([1])], [array([0])], [array([0])], [array([13])]]
# FERJ [[array([10])], [array([22])], [array([9])], [array([4])], [array([0])]]
# FERJ [[array([9])], [array([3])], [array([0])], [array([0])], [array([6])]]
# FERJ [[array([6])], [array([1])], [array([0])], [array([1])], [array([1])]]
# FERJ [[array([0])], [array([0])], [array([4])], [array([1])], [array([0])]]
# FERJ [[array([1])], [array([0])], [array([0])], [array([1])], [array([0])]]
# FERJ [[array([0])], [array([3])], [array([0])], [array([1])], [array([0])]]
# FERJ [[array([0])], [array([3])], [array([1])], [array([1])], [array([1])]]
# FERJ [[array([2])], [array([2])], [array([1])], [array([2])], [array([1])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([1])]]
# FERJ [[array([1])], [array([0])], [array([1])], [array([0])], [array([5])]]
# FERJ [[array([0])], [array([0])], [array([1])], [array([0])], [array([0])]]
# FERJ [[array([1])], [array([2])], [array([0])], [array([0])], [array([2])]]
# FERJ [[array([2])], [array([0])], [array([3])], [array([2])], [array([1])]]
# FERJ [[array([1])], [array([0])], [array([0])], [array([1])], [array([6])]]
# FERJ [[array([5])], [array([5])], [array([5])], [array([0])], [array([0])]]
# FERJ [[array([6])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([11])], [array([4])], [array([5])], [array([0])], [array([0])]]
# FERJ [[array([6])], [array([7])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([20])], [array([1])], [array([1])], [array([1])], [array([1])]]
# FERJ [[array([0])], [array([1])], [array([1])], [array([46])], [array([1])]]
# FERJ [[array([1])], [array([46])], [array([15])], [array([0])], [array([45])]]
# FERJ [[array([1])], [array([42])], [array([1])], [array([47])], [array([42])]]
# FERJ [[array([8])], [array([3])], [array([4])], [array([48])], [array([10])]]
# FERJ [[array([3])], [array([46])], [array([13])], [array([48])], [array([13])]]
# FERJ [[array([1])], [array([14])], [array([3])], [array([14])], [array([9])]]
# FERJ [[array([3])], [array([10])], [array([0])], [array([13])], [array([3])]]
# FERJ [[array([11])], [array([8])], [array([3])], [array([3])], [array([17])]]
# FERJ [[array([11])], [array([11])], [array([9])], [array([9])], [array([0])]]
# FERJ [[array([8])], [array([3])], [array([4])], [array([3])], [array([27])]]
# FERJ [[array([3])], [array([3])], [array([3])], [array([0])], [array([3])]]
# FERJ [[array([8])], [array([0])], [array([3])], [array([10])], [array([8])]]
# FERJ [[array([13])], [array([8])], [array([2])], [array([2])], [array([11])]]
# FERJ [[array([15])], [array([0])], [array([11])], [array([0])], [array([0])]]
# FERJ [[array([12])], [array([8])], [array([13])], [array([17])], [array([7])]]
# FERJ [[array([22])], [array([8])], [array([22])], [array([10])], [array([8])]]
# FERJ [[array([4])], [array([7])], [array([1])], [array([1])], [array([25])]]
# FERJ [[array([1])], [array([1])], [array([1])], [array([1])], [array([27])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([1])]]
# FERJ [[array([1])], [array([0])], [array([1])], [array([1])], [array([0])]]
# FERJ [[array([0])], [array([4])], [array([2])], [array([2])], [array([1])]]
# FERJ [[array([1])], [array([1])], [array([5])], [array([0])], [array([2])]]
# FERJ [[array([2])], [array([5])], [array([25])], [array([2])], [array([2])]]
# FERJ [[array([2])], [array([2])], [array([2])], [array([0])], [array([1])]]
# FERJ [[array([2])], [array([0])], [array([2])], [array([2])], [array([0])]]
# FERJ [[array([2])], [array([0])], [array([0])], [array([2])], [array([0])]]
# FERJ [[array([2])], [array([2])], [array([0])], [array([2])], [array([2])]]
# FERJ [[array([2])], [array([1])], [array([2])], [array([5])], [array([2])]]
# FERJ [[array([2])], [array([1])], [array([2])], [array([1])], [array([2])]]
# FERJ [[array([1])], [array([1])], [array([1])], [array([0])], [array([1])]]
# FERJ [[array([0])], [array([0])], [array([1])], [array([0])], [array([1])]]
# FERJ [[array([1])], [array([1])], [array([0])], [array([0])], [array([1])]]
# FERJ [[array([1])], [array([0])], [array([1])], [array([0])], [array([1])]]
# FERJ [[array([1])], [array([0])], [array([1])], [array([1])], [array([0])]]
# FERJ [[array([1])], [array([1])], [array([1])], [array([1])], [array([1])]]
# FERJ [[array([6])], [array([16])], [array([1])], [array([1])], [array([3])]]
# FERJ [[array([1])], [array([1])], [array([2])], [array([1])], [array([8])]]
# FERJ [[array([1])], [array([0])], [array([1])], [array([1])], [array([0])]]
# FERJ [[array([0])], [array([1])], [array([1])], [array([11])], [array([8])]]
# FERJ [[array([1])], [array([16])], [array([16])], [array([1])], [array([8])]]
# FERJ [[array([33])], [array([1])], [array([1])], [array([3])], [array([9])]]
# FERJ [[array([1])], [array([17])], [array([0])], [array([8])], [array([1])]]
# FERJ [[array([8])], [array([8])], [array([1])], [array([7])], [array([8])]]
# FERJ [[array([8])], [array([8])], [array([9])], [array([8])], [array([8])]]
# FERJ [[array([9])], [array([8])], [array([11])], [array([12])], [array([8])]]
# FERJ [[array([3])], [array([7])], [array([8])], [array([10])], [array([10])]]
# FERJ [[array([8])], [array([8])], [array([8])], [array([8])], [array([13])]]
# FERJ [[array([2])], [array([2])], [array([1])], [array([7])], [array([4])]]
# FERJ [[array([8])], [array([8])], [array([0])], [array([1])], [array([22])]]
# FERJ [[array([0])], [array([13])], [array([2])], [array([12])], [array([2])]]
# FERJ [[array([0])], [array([4])], [array([1])], [array([0])], [array([13])]]
# FERJ [[array([2])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array([0])], [array([0])], [array([0])], [array([4])], [array([1])]]
# FERJ [[array([0])], [array([1])], [array([0])], [array([0])], [array([0])]]
# FERJ [[array
], [array([0])], [array([0])], [array([0])]]
# VACJ [[array([0])], [array([0])], [array([0])], [array([1])], [array([0])]]
# VACJ [[array([5])], [array([0])], [array([0])], [array([2])], [array([0])]]
# VACJ [[array([1])], [array([0])], [array([1])], [array([3])], [array([3])]]
# VACJ [[array([10])], [array([9])], [array([14])], [array([0])], [array([18])]]
# VACJ [[array([1])], [array([0])], [array([1])], [array([2])], [array([1])]]
# VACJ [[array([6])], [array([8])], [array([1])], [array([1])], [array([18])]]
# VACJ [[array([9])], [array([1])], [array([2])], [array([17])], [array([1])]]
# VACJ [[array([10])], [array([17])], [array([1])], [array([0])], [array([1])]]
# VACJ [[array([0])], [array([20])], [array([4])], [array([4])], [array([0])]]
# VACJ [[array([4])], [array([5])], [array([0])], [array([4])], [array([0])]]
# VACJ [[array([17])], [array([8])], [array([17])], [array([10])], [array([0])]]
# VACJ [[array([5])], [array([17])], [array([1])], [array([18])], [array([5])]]
# VACJ [[array([1])], [array([12])], [array([4])], [array([0])], [array([4])]]
# VACJ [[array([12])], [array([0])], [array([3])], [array([2])], [array([3])]]
# VACJ [[array([11])], [array([2])], [array([8])], [array([2])], [array([3])]]
# VACJ [[array([2])], [array([2])], [array([3])], [array([2])], [array([2])]]
# VACJ [[array([3])], [array([2])], [array([2])], [array([12])], [array([2])]]
# VACJ [[array([2])], [array([2])], [array([5])], [array([2])], [array([1])]]
# VACJ [[array([8])], [array([2])], [array([2])], [array([1])], [array([1])]]
# VACJ [[array([3])], [array([9])], [array([2])], [array([10])], [array([2])]]
# VACJ [[array([1])], [array([1])], [array([5])], [array([1])], [array([1])]]
# VACJ [[array([3])], [array([3])], [array([3])], [array([17])], [array([17])]]
# VACJ [[array([14])], [array([1])], [array([0])], [array([1])], [array([1])]]
# VACJ [[array([6])], [array([0])], [array([0])], [array([2])], [array([1])]]
# VACJ [[array([0])], [array([3])], [array([14])], [array([1])], [array([12])]]
# VACJ [[array([3])], [array([2])], [array([9])], [array([10])], [array([0])]]
# VACJ [[array([14])], [array([0])], [array([3])], [array([3])], [array([9])]]
# VACJ [[array([3])], [array([3])], [array([2])], [array([7])], [array([0])]]
# VACJ [[array([7])], [array([7])], [array([8])], [array([0])], [array([2])]]
# VACJ [[array([0])], [array([0])], [array([5])], [array([0])], [array([0])]]
# VACJ [[array([4])], [array([0])], [array([4])], [array([5])], [array([0])]]
# VACJ [[array([0])], [array([0])], [array([1])], [array([1])], [array([4])]]
# VACJ [[array([1])], [array([0])], [array([1])], [array([0])], [array([0])]]
# VACJ [[array([0])], [array([0])], [array([0])], [array([2])], [array([0])]]
# VACJ [[array([2])], [array([0])], [array([1])], [array([1])], [array([4])]]
# VACJ [[array([2])], [array([2])], [array([0])], [array([2])], [array([2])]]
# VACJ [[array([0])], [array([7])], [array([0])], [array([0])], [array([1])]]
# VACJ [[array([0])], [array([13])], [array([7])], [array([1])], [array([2])]]
# VACJ [[array([0])], [array([5])], [array([2])], [array([1])], [array([29])]]
# VACJ [[array([4])], [array([12])], [array([5])], [array([1])], [array([5])]]
# VACJ [[array([0])], [array([3])], [array([1])], [array([0])], [array([3])]]
# VACJ [[array([2])], [array([3])], [array([0])], [array([0])], [array([1])]]
# VACJ [[array([5])], [array([4])], [array([9])], [array([5])], [array([5])]]
# VACJ [[array([16])], [array([4])], [array([5])], [array([1])], [array([5])]]
# VACJ [[array([5])], [array([0])], [array([4])], [array([5])], [array([1])]]
# VACJ [[array([0])], [array([2])], [array([1])], [array([15])], [array([0])]]
# VACJ [[array([19])], [array([7])], [array([0])], [array([1])], [array([9])]]
# VACJ [[array([16])], [array([7])], [array([1])], [array([28])], [array([6])]]
# VACJ [[array([3])], [array([3])], [array([13])], [array([3])], [array([1])]]
# VACJ [[array([3])], [array([19])], [array([1])], [array([2])], [array([0])]]
# VACJ [[array([1])], [array([1])], [array([6])], [array([1])], [array([8])]]
# VACJ [[array([5])], [array([6])], [array([12])], [array([6])], [array([11])]]
# VACJ [[array([1])], [array([2])], [array([6])], [array([5])], [array([6])]]
# VACJ [[array([6])], [array([11])], [array([6])], [array([11])], [array([3])]]
# VACJ [[array([6])], [array([6])], [array([5])], [array([4])], [array([6])]]
# VACJ [[array([4])], [array([1])], [array([1])], [array([1])], [array([5])]]
# VACJ [[array([5])], [array([5])], [array([3])], [array([4])], [array([4])]]
# VACJ [[array([1])], [array([1])], [array([1])], [array([5])], [array([4])]]
# VACJ [[array([18])], [array([1])], [array([10])], [array([12])], [array([1])]]
# VACJ [[array([1])], [array([1])], [array([8])], [array([0])], [array([1])]]
# VACJ [[array([3])], [array([15])], [array([1])], [array([0])], [array([4])]]
# VACJ [[array([5])], [array([3])], [array([3])], [array([9])], [array([3])]]
# VACJ [[array([1])], [array([8])], [array([8])], [array([12])], [array([7])]]
# VACJ [[array([2])], [array([2])], [array([12])], [array([4])], [array([2])]]
# VACJ [[array([0])], [array([0])], [array([0])], [array([9])], [array([5])]]
# VACJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([1])]]
# VACJ [[array([1])], [array([0])], [array([0])], [array([0])], [array([0])]]
# VACJ [[array([0])], [array([0])], [array([0])], [array([1])], [array([2])]]
# VACJ [[array([0])], [array([0])], [array([0])], [array([1])], [array([1])]]
# VACJ [[array([1])], [array([1])], [array([0])], [array([1])], [array([0])]]
# VACJ [[array([0])], [array([7])], [array([0])], [array([34])], [array([3])]]
# VACJ [[array([14])], [array([0])], [array([5])], [array([14])], [array([7])]]
# VACJ [[array([13])], [array([3])], [array([22])], [array([18])], [array([5])]]
# VACJ [[array([8])], [array([0])], [array([1])], [array([0])], [array([8])]]
# VACJ [[array([4])], [array([1])], [array([1])], [array([3])], [array([1])]]
# VACJ [[array([3])], [array([24])], [array([17])], [array([1])], [array([0])]]
# VACJ [[array([4])], [array([0])], [array([1])], [array([20])], [array([4])]]
# VACJ [[array([11])], [array([0])], [array([3])], [array([0])], [array([1])]]
# VACJ [[array([3])], [array([0])], [array([1])], [array([8])], [array([8])]]
# VACJ [[array([4])], [array([8])], [array([11])], [array([6])], [array([1])]]
# VACJ [[array([0])], [array([6])], [array([0])], [array([3])], [array([3])]]
# VACJ [[array([4])], [array([3])], [array([4])], [array([3])], [array([5])]]
# VACJ [[array([18])], [array([0])], [array([0])], [array([0])], [array([4])]]
# VACJ [[array([5])], [array([9])], [array([21])], [array([7])], [array([0])]]
# VACJ [[array([0])], [array([0])], [array([3])], [array([4])], [array([15])]]
# VACJ [[array([0])], [array([16])], [array([0])], [array([0])], [array([9])]]
# VACJ [[array([0])], [array([9])], [array([0])], [array([6])], [array([0])]]
# VACJ [[array([4])], [array([3])], [array([0])], [array([2])], [array([0])]]
# VACJ [[array([2])], [array([0])], [array([1])], [array([0])], [array([0])]]
# VACJ [[array([0])], [array([0])], [array([5])], [array([3])], [array([3])]]
# VACJ [[array([7])], [array([3])], [array([7])], [array([3])], [array([0])]]
# VACJ [[array([11])], [array([5])], [array([5])], [array([3])], [array([3])]]
# VACJ [[array([5])], [array([0])], [array([3])], [array([2])], [array([0])]]
# VACJ [[array([0])], [array([1])], [array([0])], [array([0])], [array([2])]]
# VACJ [[array([0])], [array([22])], [array([1])], [array([7])], [array([5])]]
# VACJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([0])]]
# VACJ [[array([0])], [array([0])], [array([0])], [array([2])], [array([0])]]
# VACJ [[array([1])], [array([0])], [array([0])], [array([0])], [array([0])]]
# VACJ [[array([0])], [array([0])], [array([0])], [array([0])], [array([0])]]
# VACJ [[array([2])], [array([0])], [array([2])], [array([5])], [array([4])]]
# VACJ [[array([4])], [array([1])], [array([2])], [array([3])], [array([4])]]
# VACJ [[array([8])], [array([8])], [array([0])], [array([3])], [array([8])]]
# VACJ [[array([0])], [array([5])], [array([0])], [array([1])], [array([1])]]
# VACJ [[array([0])], [array([0])], [array([0])], [array([18])], [array([8])]]
# VACJ [[array([2])], [array([0])], [array([0])], [array([0])], [array([0])]]
# VACJ [[array([2])], [array([3])], [array([5])], [array([0])], [array([1])]]
# VACJ [[array([0])], [array([0])], [array([0])], [array([11])], [array([1])]]
# VACJ [[array([18])], [array([1])], [array([1])], [array([2])], [array([12])]]
# VACJ [[array([3])], [array([0])], [array([0])], [array([0])], [array([2])]]
# VACJ [[array([3])], [array([13])], [array([5])], [array([8])], [array([4])]]
# VACJ [[array([17])], [array([3])], [array([7])], [array([7])], [array([3])]]
# VACJ [[array([4])], [array([5])], [array([3])], [array([2])], [array([0])]]
# VACJ [[array([2])], [array([3])], [array([23])], [array([3])], [array([11])]]
# VACJ [[array([3])], [array([3])], [array([3])], [array([3])], [array([5])]]
# VACJ [[array([8])], [array([2])], [array([5])], [array([4])], [array([3])]]
# VACJ [[array([3])], [array([3])], [array([5])], [array([3])], [array([0])]]
# VACJ [[array([0])], [array([4])], [array([3])], [array([3])], [array([0])]]
# VACJ [[array([2])], [array([2])], [array([2])], [array([2])], [array([2])]]
# VACJ [[array([6])], [array([0])], [array([10])], [array([1])], [array([3])]]
# VACJ [[array([0])], [array([16])], [array([3])], [array([0])], [array([2])]]
# VACJ [[array([0])], [array([0])], [array([4])], [array([0])], [array([5])]]
# VACJ [[array([1])], [array([15])], [array([5])], [array([3])], [array([10])]]
# VACJ [[array([3])], [array([3])], [array([3])], [array([1])], [array([2])]]
# VACJ [[array([18])], [array([6])], [array([3])], [array([1])], [array([3])]]
# VACJ [[array([3])], [array([3])], [array([7])], [array([4])], [array([1])]]
# VACJ [[array([0])], [array([1])], [array([3])], [array([0])], [array([13])]]
# VACJ [[array([4])], [array([1])], [array([16])], [array([1])], [array([5])]]
# VACJ [[array([1])], [array([5])], [array([3])], [array([1])], [array([9])]]
# VACJ [[array([1])], [array([0])], [array([4])], [array([0])], [array([5])]]
# VACJ [[array([3])], [array([1])], [array([6])], [array([0])], [array([5])]]
# VACJ [[array([4])], [array([4])], [array([0])], [array([8])], [array([7])]]
# VACJ [[array([2])], [array([3])], [array([8])], [array([5])], [array([5])]]
# VACJ [[array([5])], [array([1])], [array([3])], [array([5])], [array([3])]]
# VACJ [[array([2])], [array([1])], [array([8])], [array([6])], [array([0])]]
# VACJ [[array([1])], [array([1])], [array([7])], [array([1])], [array([1])]]
# VACJ [[array([9])], [array([10])], [array([0])], [array([4])], [array([1])]]
# VACJ [[array([13])], [array([1])], [array([2])], [array([5])], [array([11])]]
# VACJ [[array([1])], [array([7])], [array([1])], [array([3])], [array([1])]]
# VACJ [[array([3])], [array([6])], [array([3])], [array([1])], [array([3])]]
# VACJ [[array([3])], [array([3])], [array([1])], [array([3])], [array([1])]]
# VACJ [[array([3])], [array([10])], [array([0])], [array([3])], [array([0])]]
# VACJ [[array([0])], [array([3])], [array([3])], [array([1])], [array([1])]]
# VACJ [[array([15])], [array([5])], [array([3])], [array([3])], [array([1])]]
# VACJ [[array([9])], [array([1])], [array([2])], [array([1])], [array([2])]]
# VACJ [[array([1])], [array([2])], [array([10])], [array([1])], [array([1])]]
# VACJ [[array([1])], [array([7])], [array([1])], [array([30])], [array([10])]]
# VACJ [[array([3])], [array([5])], [array([0])], [array([8])], [array([2])]]
# VACJ [[array([1])], [array([6])], [array([6])], [array([3])], [array([0])]]
# VACJ [[array([7])], [array([11])], [array([0])], [array([0])], [array([0])]]
# VACJ [[array([2])], [array([1])], [array([3])], [array([11])], [array([1])]]
# VACJ [[array([0])], [array([0])], [array([1])], [array([6])], [array([2])]]
# VACJ [[array([1])], [array([4])], [array([2])], [array([4])], [array([0])]]
# VACJ [[array([4])], [array([6])], [array([1])], [array([0])], [array([6])]]
# VACJ [[array([2])], [array([2])], [array([2])], [array([2])], [array([2])]]
# VACJ [[array([15])], [array([8])], [array([2])], [array([3])], [array([9])]]
# VACJ [[array([0])], [array([1])], [array([3])], [array([1])], [array([0])]]
# VACJ [[array([4])], [array([3])], [array([2])], [array([2])], [array([3])]]
# VACJ [[array([5])], [array([3])], [array([2])], [array([4])], [array([5])]]
# VACJ [[array([3])], [array([2])], [array([4])], [array([3])], [array([9])]]
# VACJ [[array([3])], [array([0])], [array([3])], [array([1])], [array([0])]]
# VACJ [[array([6])], [array([3])], [array([1])], [array([1])], [array([5])]]
# VACJ [[array([5])], [array([5])], [array([4])], [array([3])], [array([1])]]
# VACJ [[array([0])], [array([3])], [array([11])], [array([1])], [array([4])]]
# VACJ [[array([4])], [array([4])], [array([4])], [array([3])], [array([4])]]
# VACJ [[array([4])], [array([1])], [array([4])], [array([4])], [array([5])]]
# VACJ [[array([1])], [array([4])], [array([1])], [array([5])], [array([2])]]
# VACJ [[array([3])], [array([6])], [array([2])], [array([1])], [array([1])]]
# VACJ [[array([0])], [array([8])], [array([4])], [array([7])], [array([5])]]
# VACJ [[array([0])], [array([0])], [array([2])], [array([0])], [array([0])]]
# VACJ (5, 35, 5) (5, 175, 1, 1)
# SEMC [[array([33])], [array([0])], [array([1])], [array([24])], [array([31])]]
# SEMC [[array([5])], [array([1])], [array([1])], [array([2])], [array([19])]]
# SEMC [[array([0])], [array([0])], [array([2])], [array([2])], [array([16])]]
# SEMC [[array([3])], [array([26])], [array([6])], [array([16])], [array([2])]]
# SEMC [[array([1])], [array([1])], [array([29])], [array([1])], [array([1])]]
# SEMC [[(4,)], [(2, 11)], [(0,)], [(8,)], [(0,)]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-65358b102f66> in <module>()
#      16             print(su,feat)
#      17             scores = np.vstack((scores,score)) if np.size(scores) else score
# ---> 18             sels =  np.vstack((sels,feat)) if np.size(sels) else feat
#      19         scores, sels = scores[np.newaxis], sels[np.newaxis]
#      20         su_scores = np.vstack((su_scores,scores)) if np.size(su_scores) else scores
#
# ~/anaconda3/lib/python3.5/site-packages/numpy/core/shape_base.py in vstack(tup)
#     235
#     236     """
# --> 237     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     238
#     239 def hstack(tup):
#
# ValueError: all the input arrays must have same number of dimensions

# %% [markdown]
# ### Scores AUC global by freq

# %%
from brainpipe.visual import *
from brainpipe.statistics import bino_p2da
import matplotlib.pyplot as plt
from scipy.stats import sem

freqs = ['theta','alpha','beta','gamma1','gamma2']
thrs =  {'None':0.,'0.05':0.67, '0.01': 0.75, '0.001': 0.79} #binomial thr for p 0.05 0.01 0.001

for thr in thrs:
    score_all = np.array([])
    for su in subjects:
        mat = np.load(PATH_MF+'npz/{}_Pow_MF_scores.npz'.format(su))
        score = np.ravel(mat['score'],order='C')
        sel = np.ravel(mat['sel'],order='C')
        idx_s = np.where(score>thrs[thr])
        sel_sig = sel[idx_s]
        score_sig = score[idx_s]

        score_su = []
        for f in sorted(freqs):
            #select scores by freq
            idx_f = [i for i,s in enumerate(sel_sig) if f in s]
            x = np.mean(score_sig[idx_f])
            score_su.append(x)
        score_all = np.vstack((score_all,score_su)) if np.size(score_all) else score_su
    #print(score_all)
    
    # plot and figure parameters
    fig = plt.figure(1,figsize=(5,5))
    title = 'MF AUC Score all elecs at p<{}'.format(thr)
    fig.suptitle(title, fontsize=12)
    xpts = range(len(freqs))

    # Plot the POW + STATS
    plt.bar(xpts,np.mean(score_all,axis=0),yerr=np.std(score_all,axis=0),color='darkblue',
           ecolor='white')
    plt.xticks(xpts,sorted(freqs),rotation='vertical')
    plt.ylabel('Mean AUC Score')
    addLines(plt.gca(), hLines=[thrs[thr]], hColor=['r'], hShape=['--'], hWidth=[2])
    rmaxis(plt.gca(), ['right', 'top'])
    plt.tight_layout()
    #plt.ylim(0.65,0.85)
    plt.savefig(PATH_MF+'plots/MF_elecs_scores_sing{}.png'.format(thr))
    plt.clf()
    plt.close()

# %% [markdown]
# ### Score global by combination

# %%
from brainpipe.visual import *
from brainpipe.statistics import bino_p2da
import matplotlib.pyplot as plt
from scipy.stats import sem
from itertools import combinations

freqs = ['theta','alpha','beta','gamma1','gamma2']
thrs =  {'None':0.,'0.05':0.67, '0.01': 0.75, '0.001': 0.79} #binomial thr for p 0.05 0.01 0.001

#create all combinations of frequencies
l_combs = np.array([])
for r in range(1,6):
    combs = [c for c in combinations(freqs,r)]
    combs = ["_".join(c) for c in combs]
    l_combs = np.hstack((l_combs,combs)) if np.size(l_combs) else combs
    
for thr in thrs:
    score_all = np.array([])
    for su in subjects:
        mat = np.load(PATH_MF+'npz/{}_Pow_MF_scores.npz'.format(su))
        score = np.ravel(mat['score'],order='C')
        sel = np.ravel(mat['sel'],order='C')
        idx_s = np.where(score>thrs[thr])
        sel_sig = sel[idx_s]
        score_sig = score[idx_s]
        
        score_su = []
        for f in sorted(l_combs):
            #select scores by freq
            idx = [i for i,s in enumerate(sel_sig) if f == s]
            x = np.mean(score_sig[idx])
            score_su.append(x)
        score_all = np.vstack((score_all,score_su)) if np.size(score_all) else score_su
    print(score_all.shape)

    # plot and figure parameters
    fig = plt.figure(1,figsize=(7,7))
    title = 'MF AUC Score all elecs at p<{}'.format(thr)
    fig.suptitle(title, fontsize=12)
    xpts = range(len(l_combs))

    # Plot the POW + STATS
    mu = np.nanmean(score_all,axis=0)
    sigma = [sem(score_all[:,x]) for x in range(score_all.shape[1])]
    plt.bar(xpts,mu,yerr=sigma,color='orange',ecolor='black')
    plt.xticks(xpts,sorted(l_combs),rotation='vertical')
    plt.ylabel('Mean AUC Score at p<'.format(thr))
    #plt.ylim(0.5,0.7)
    rmaxis(plt.gca(), ['right', 'top'])
    addLines(plt.gca(), hLines=[thrs[thr]], hColor=['r'], hShape=['--'], hWidth=[2])
    plt.tight_layout()
    plt.savefig(PATH_MF+'plots/MF_elecs_scores_combs{}.png'.format(thr))
    plt.clf()
    plt.close()
# Out:
# (6, 31)
# (6, 31)
# (6, 31)
# (6, 31)

# %% [markdown]
# ### Score global by combination and brain region

# %%
from brainpipe.visual import *
from brainpipe.statistics import bino_p2da
import matplotlib.pyplot as plt
from scipy.stats import sem

freqs = ['theta','alpha','beta','gamma1','gamma2']

#create all combinations of frequencies
l_combs = np.array([])
for r in range(1,6):
    combs = [c for c in combinations(freqs,r)]
    combs = ["_".join(c) for c in combs]
    l_combs = np.hstack((l_combs,combs)) if np.size(l_combs) else combs

for region in regions:
    score_c, thr_r = np.array([]), []
    for su in subjects:
        mat = np.load(PATH_MF+'npz/{}_Pow_MF_scores.npz'.format(su))       
        scores = np.ravel(mat['score'],order='C')
        sels = np.ravel(mat['sel'],order='C')
        labels = mat['regions']
        labels_new = [[l]*mat['sel'].shape[1]*mat['sel'].shape[2] for l in labels]
        labels_new = np.concatenate(np.asarray(labels_new),axis=0)
        thrs = np.asarray(bino_p2da(mat['labels'],[0.05])/100)[0]
    
        #select scores by freq
        idx = np.where(labels_new==region)
        score_r = scores[idx]
        sel_r = sels[idx]
        bins = len(l_combs)
        
        tot_score = []
        for key in sorted(l_combs):
            idx_c = [i for i,sel in enumerate(sel_r) if key == sel]
            x = np.mean(scores[idx_c])
            tot_score.append(x)
        thr_r.append(thrs)
        score_c = np.vstack((score_c,tot_score)) if np.size(score_c) else tot_score
    
    # plot and figure parameters
    fig = plt.figure(1,figsize=(7,7))
    title = 'MF AUC Score for elecs in {}'.format(region)
    fig.suptitle(title, fontsize=12)
    xpts = range(len(l_combs))

    # Plot the POW + STATS
    mu = np.nanmean(score_c,axis=0)
    plt.bar(xpts,mu,yerr=np.nanstd(score_c,axis=0)/6,color='orange',ecolor='black')
    plt.xticks(xpts,sorted(l_combs),rotation='vertical')
    plt.ylabel('Mean AUC Score')
    plt.ylim(0.55,0.75)
    rmaxis(plt.gca(), ['right', 'top'])
    addLines(plt.gca(), hLines=[np.max(thr_r)], hColor=['r'], hShape=['--'], hWidth=[2])
    plt.tight_layout()
    plt.savefig(PATH_MF+'plots/MF_auc_scores_combs_{}.png'.format(region))
    plt.clf()
    plt.close()

# %% [markdown]
# ### Occurences of each freq combination

# %%
from brainpipe.visual import *
import matplotlib.pyplot as plt
from scipy.stats import sem
from collections import Counter
from itertools import combinations

freqs = ['theta','alpha','beta','gamma1','gamma2']
thrs =  {'0.05':0.67, '0.01': 0.75, '0.001': 0.79} #binomial thr for p 0.05 0.01 0.001

#create all combinations of frequencies
l_combs = np.array([])
for r in range(1,6):
    combs = [c for c in combinations(freqs,r)]
    combs = ["_".join(c) for c in combs]
    l_combs = np.hstack((l_combs,combs)) if np.size(l_combs) else combs

#plot all combinations histogram
colors = {'CHAF':'darkblue', 'FERJ':'royalblue', 'LEFC':'deepskyblue', 
        'SEMC':'mediumspringgreen','PIRJ':'yellow', 'VACJ':'darkorange', 'MICP':'red'}

for thr in thrs:
    bottom = np.zeros(len(l_combs))
    for su in subjects:
        mat = np.load(PATH_MF+'npz/{}_Pow_MF_scores.npz'.format(su))
        sel, score = mat['sel'], mat['score']
        score = np.ravel(score,order='C')
        sel = np.ravel(sel,order='C')

        #select only significant data
        idx_s = np.where(score>thrs[thr])
        sel_sig = sel[idx_s]

        tot_sel = []
        for key in sorted(l_combs):
            c = len([i for i,s in enumerate(sel_sig) if s == key])
            tot_sel.append(c)

        # plot and figure parameters
        fig = plt.figure(1,figsize=(7,7))
        title = 'MF all elecs'
        fig.suptitle(title, fontsize=12)
        xpts = range(len(l_combs))

        # Plot the POW + STATS    
        plt.bar(xpts, tot_sel, color=colors[su], label=su, bottom=bottom)
        bottom += tot_sel

    plt.xticks(xpts,sorted(l_combs),rotation='vertical')
    rmaxis(plt.gca(), ['right', 'top'])    
    plt.ylabel('Nb of occurences')
    plt.legend(loc=0,handletextpad=0.1, frameon=False)
    plt.tight_layout()
    plt.savefig(PATH_MF+'plots/MF_elecs_occurences_combs{}.png'.format(thr))
    plt.clf()
    plt.close()

# %% [markdown]
# ### Occurences of each freq single

# %%
from brainpipe.visual import *
import matplotlib.pyplot as plt
from scipy.stats import sem
from collections import Counter
from itertools import combinations

freqs = ['theta','alpha','beta','gamma1','gamma2']
thrs =  {'0.05':0.67, '0.01': 0.75, '0.001': 0.79} #binomial thr for p 0.05 0.01 0.001

#plot all combinations histogram
colors = {'CHAF':'darkblue', 'FERJ':'royalblue', 'LEFC':'deepskyblue', 
        'SEMC':'mediumspringgreen','PIRJ':'yellow', 'VACJ':'darkorange', 'MICP':'red'}

for thr in thrs:
    bottom = np.zeros(len(freqs))
    for su in subjects:
        mat = np.load(PATH_MF+'npz/{}_Pow_MF_scores.npz'.format(su))
        sel, score = mat['sel'], mat['score']
        score = np.ravel(score,order='C')
        sel = np.ravel(sel,order='C')
        
        idx_s = np.where(score>thrs[thr]) #significant elecs
        sel_sig = sel[idx_s]
        
        sel = [f.split('_') for f in sel_sig] #all occurences of each freq
        sel = np.concatenate(np.asarray(sel),axis=0)

        tot_sel = []
        for key in sorted(freqs):
            c = list(sel).count(key)
            tot_sel.append(c)

        # plot and figure parameters
        fig = plt.figure(1,figsize=(5,5))
        title = 'MF all elecs at p < {}'.format(thr)
        fig.suptitle(title, fontsize=12)
        xpts = range(len(freqs))

        # Plot the POW + STATS    
        plt.bar(xpts, tot_sel, color=colors[su], label=su, bottom=bottom)
        bottom += tot_sel

    plt.xticks(xpts,sorted(freqs),rotation='vertical')
    rmaxis(plt.gca(), ['right', 'top'])    
    plt.ylabel('Nb of occurences')
    #plt.legend(loc=0,handletextpad=0.1, frameon=False)
    plt.savefig(PATH_MF+'plots/MF_elecs_occurences_sing{}.png'.format(thr))
    plt.clf()
    plt.close()

# %% [markdown]
# ### Occurences of each freq combination by brain region

# %%
from brainpipe.visual import *
import matplotlib.pyplot as plt
from scipy.stats import sem
from collections import Counter
from itertools import combinations

freqs = ['theta','alpha','beta','gamma1','gamma2']
regions = ['Frontal','MTL','Olf','Temporal']

#create all combinations of frequencies
l_combs = np.array([])
for r in range(1,6):
    combs = [c for c in combinations(freqs,r)]
    combs = ["_".join(c) for c in combs]
    l_combs = np.hstack((l_combs,combs)) if np.size(l_combs) else combs

#plot all combinations histogram
colors = {'CHAF':'darkblue', 'FERJ':'royalblue', 'LEFC':'deepskyblue', 
        'SEMC':'mediumspringgreen','PIRJ':'yellow', 'VACJ':'darkorange', 'MICP':'red'}

thrs =  {'0.05':0.67, '0.01': 0.75, '0.001': 0.79} #binomial thr for p 0.05 0.01 0.001
for thr in thrs:
    for region in regions:
        bottom = np.zeros(len(l_combs))
        for su in subjects:
            mat = np.load(PATH_MF+'npz/{}_Pow_MF_scores.npz'.format(su))
            sel, score, labels = mat['sel'], mat['score'], mat['regions']
            score = np.ravel(score,order='C')
            sel = np.ravel(sel,order='C')
            labels_new = [[l]*mat['sel'].shape[1]*mat['sel'].shape[2] for l in labels]
            labels_new = np.concatenate(np.asarray(labels_new),axis=0)
            #print(len(score),len(sel),len(labels_new))

            idx_s = np.ravel(np.where(score>thrs[thr]))
            idx_r = np.ravel(np.where(labels_new==region)) #significant elecs
            idx_f = [idx for idx in idx_s if idx in idx_r]
            sel_sig = sel[idx_f]
            bins = len(l_combs)

            tot_sel = []
            for key in sorted(l_combs):
                c = list(sel_sig).count(key)
                tot_sel.append(c)

            # plot and figure parameters
            fig = plt.figure(1,figsize=(7,7))
            title = 'MF all elecs in {} at p< {}'.format(region,thr)
            fig.suptitle(title, fontsize=12)
            xpts = range(len(l_combs))

            # Plot the POW + STATS    
            plt.bar(xpts, tot_sel, color=colors[su], label=su, bottom=bottom)
            bottom += tot_sel

        plt.xticks(xpts,sorted(l_combs),rotation='vertical')
        rmaxis(plt.gca(), ['right', 'top'])    
        plt.ylabel('Nb of occurences')
        plt.legend(loc=0,handletextpad=0.1, frameon=False)
        plt.tight_layout()
        plt.savefig(PATH_MF+'plots/MF_elecs_occurences_combs_{}_{}.png'.format(region,thr))
        plt.clf()
        plt.close()
